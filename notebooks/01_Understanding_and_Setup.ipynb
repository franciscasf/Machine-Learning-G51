# %% [markdown]
# Project Guide

# %% [markdown]
# General structure:
# - Business Understanding;
# - Exploratory Data Analysis (EDA);
# - Preprocessing and Feature engineering
# - Experimental Setup
# - Models and Training
# - Model Comparison, Final Selection and Takeaways
# - Open-Ended Topic 1: Prediction Submission Interface
# - Open-Ended Topic 2: Distribution Shift (Train vs Test)

# %% [markdown]
# ## Interface Instructions

# %% [markdown]
# The interface is done in Streamlit and is hosted locally, so the in order to run it one must have the necessary dependencies installed and the 'train.csv' available in the correct path.
