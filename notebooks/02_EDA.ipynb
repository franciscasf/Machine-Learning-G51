# %% [markdown]
# # EXPLORATORY DATA ANALYSIS (EDA)

# %% [markdown]
# ### __Introduction__

# %% [markdown]
# - This section consists of the exploratory data analysis of the entire dataset.
# - Our main goals are conducting descriptive analyses, identifying missing values and outliers, uncovering relevant patterns, anomalies and multivariate relationships between features.
# - This analysis is performed before preprocessing the data. However, some minor adjustments were applied to certain features for clarity (for instance, converting categorical variables to uppercase or stripping whitespace).

# %% [markdown]
# ## 1. Dataset Overview

# %% [markdown]
# ## 2. Descriptive Statistics

# %% [markdown]
# ## 3. Missing Values Analysis

# %% [markdown]
# ## 4. Outlier Detection and Inspection

# %% [markdown]
# ## 5. Univariate Analysis

# %% [markdown]
# ## 6. Multivariate Analysis

# %% [markdown]
# ## 7. Target Variable (Price) Exploration

# %% [markdown]
# ## 8. Key Insights and Implications for Preprocessing
