# %% [markdown]
# # DATA CLEANING AND PREPROCESSING

# %% [markdown]
# ### __Introduction__

# %% [markdown]
# - ...

# %% [markdown]
# ## 1. Data Quality Assessment (summary of issues detected in the EDA)

# %% [markdown]
# ## 2. Categorical Variable Processing

# %% [markdown]
# ## 3. Numerical Variable Processing

# %% [markdown]
# ## 4. Feature Engineering

# %% [markdown]
# ## 5. Scaling and Normalisation

# %% [markdown]
# ## 6. Final Preprocessed Dataset Summary
