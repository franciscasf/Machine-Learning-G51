# %% [markdown]
# # FEATURE SELECTION

# %% [markdown]
# In this notebook, we developed our feature selection functions.
# We used the general dataset to help us develop them and trying to understand if they were corrcetly made and make sense.
# But the actual feature selection will only be ocnducted inside the k fold algorithm, because ....
# This Notebook is merely just for the function development and correctness of them.

# %% [markdown]
# ### __Introduction__

# %% [markdown]
# - In this notebook, we focus on the design and implementation of the feature selection functions.<br>
# - The full training dataset is used here solely for exploratory purposes and to verify the internal correctness and behaviour of these functions.<br>
# - The actual feature selection step in our project will be performed exclusively within the k-fold cross-validation procedure (i.e., per fold) in order to avoid data leakage.<br>
# - In summary, this notebook should be regarded as a development and validation environment for the feature selection code, rather than as part of the final modeling workflow.

# %% [markdown]
# ## 1. Theoretical Context
