# %% [markdown]
# # GRADIENT BOOSTING

# %% [markdown]
# __INDEX__
# 1. [Understanding Gradient Tree Boosting](#understanding)
# 2. [Setup and Data Preparation](#setup)
# 3. [Cross-Validation Framework](#crossvalframe)
# 4. [Experimental Runs](#expruns)
# 5. [Final Configuration](#finalconfig)

# %% [markdown]
# ## 1. Understanding Gradient Tree Boosting
# <a id="understanding"></a>

# %% [markdown]
# - Gradient-boosted trees consists in an algorithm that ensembles the predictions of weker prediction models, particularly decision trees. Each of these predictors will correct their predecessor. Unlike many algorithms, this one doesn't just deal with improving weights at each iteration, instead tries to learn frrom the previous predictors residual errors and fit the following predictor to those.
# - This algorithm can be seen as an optimization one bassed on a certain loss function.

# %% [markdown]
# ### 1.2. Gradient Tree Boosting (GTB) in Scikit learn

# %% [markdown]
# - Scikit-learn (0.21) provides us with two options to implement this algorithm (they are availabl both for classification and regression, but we will only focus on the regression ones), both of them inspired by LightGBM:
#     - __'HistGradientBoostingRegressor'__ and
#     - __'GradientBoostingRegressor'__
# - An interesting detail about this implementations is that they support missing values and for the __'HistGradientBoostingRegressor'__ one categorical data is supported aswell.
# - For small datasets, the use of bins might contribute to very close split points, ence why, in this case, __'GradientBoostingRegressor'__ is preferible. However, our dataset granularity is moderatly high and, as indicated by the official documentation, for a sample with tens of thousands of samples, __'HistGradientBoostingRegressor'__ is preferible.
# - In addition, __'HistGradientBoostingRegressor'__ has the advantage of increased time efficiency and complexity (that will be later on explained in the notebook) compared to __'GradientBoostingRegressor'__. However, the former does not natively support some features of the latter.
#
# Note: all of these informations are available at the scikit learn documentation.

# %% [markdown]
# ### 1.3. Understanding __'HistGradientBoostingRegressor'__

# %% [markdown]
# - We decided to use this algorithm because of the infra citated reasons as well as because of the reasons citated in ths section.

# %% [markdown]
# ## 2. Setup and Data Preparation  <a id="setup"></a>

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import KFold, ParameterSampler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, median_absolute_error, mean_absolute_percentage_error
import os
from sklearn.feature_selection import SelectFromModel
import random
import logging
from IPython.display import display

# %%
# All of our preprocessing helper functions are in this notebook
# %run 05_0_preproc_helpers.ipynb  

# this is the target column - the value we want to predict 
TARGET_COL = "price"  

# separate features and target variable from the full training datase
y = full_train_dataset[TARGET_COL].copy()
X = full_train_dataset.drop(columns=[TARGET_COL]).copy()

# at this point, this are all the features in use 
categorical_features = ['Brand', 'model', 'transmission', 'fuelType']              
numeric_features = ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners']

print("X shape:", X.shape)
print("y shape:", y.shape)
print("Num features:", numeric_features)
print("Cat features:", categorical_features)

N_SPLITS = 8 # the number of folds for K-Fold cross-validation
RANDOM_STATE = 42 # seed to control randomness
# ---------------------------------------------------------
# 0) CONFIGS GERAIS
# ---------------------------------------------------------
N_SPLITS = 8
N_ITER = 10
RANDOM_STATE = 42
# Out:
# X shape: (75973, 10)
# y shape: (75973,)
# Num features: ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners']
# Cat features: ['Brand', 'model', 'transmission', 'fuelType']

# %% [markdown]
# ## 3. Cross-Validation Framework
# <a id="crossvalframe"></a>

# %% [markdown]
# ## 4. Experimental Runs  <a id="expruns"></a>

# %% [markdown]
# ### 4.1. All Features Baseline

# %% [markdown]
# - In this section, we performed a random search to check wether the chosen hyperparameters search space was reasonable and to establish baseline results for the next improvements.

# %%
# we will use an 8-fold cross-validation strategy
N_SPLITS = 8 

# shuffles the data, in order to, at least theoretically, have more balanced folds
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)


# hyperparameter space that we are going to use to random search
# each configuration will get 1 value from each of these lists
param_distributions = {
    "max_iter": [600, 800, 1000], # max number of trees 
    "learning_rate": [0.05, 0.1, 0.15], # shrinkage factor (for the leaves values) 
    "max_leaf_nodes": [31, 63, 127], # max number of leaves for each tree
    "max_depth": [None, 10, 20, 11, 15], # max depth of each tree
    "l2_regularization": [0, 1, 2, 5], # regularization (penalization) factor for small hessian values leaves  
    "min_samples_leaf": [20, 40] # min number of samples for each leaf
}

N_RANDOM_CONFIGS = 10 # this is a short random search, enough for baseline results

# we get N_RANDOM_CONFIGS (10) random parameter combinations from param_distributions 
sampler = ParameterSampler(param_distributions, n_iter=N_RANDOM_CONFIGS, random_state=RANDOM_STATE)

search_results = [] # to store results of each configuration, to store the ranking

# tracking the best configuration according to validation RMSE 
best_rmse = np.inf 
best_config = None 

# to store our fold results
log_dir = "gb_logs" # directory to save log files that is not present in this final version but was useful during development
os.makedirs(log_dir, exist_ok=True)  # creates the log directory if it doesn't exist
log_filename = "2gb_complete_nof_log.txt"
log_path = os.path.join(log_dir, log_filename)
# Note: this section is mainly for organizational purposes and is not particularly relevant 


with open(log_path, "w", encoding="utf-8") as log_file:

    # this function allows printing the messages to the screen and to the log file 
    def log(msg: str):
        print(msg) 
        log_file.write(msg + "\n") 
        log_file.flush() 

    # header for the log file - just for readability and general info
    log("# =============================")
    log(f"# START OF HGB SEARCH (DETAILED METRICS: R2, RMSE, MAE, BIAS)")
    log(f"# LOG FILE SAVED TO: {log_path}")
    log("# =============================")
    
    # loop that iterates over each random configuration
    for config_id, params in enumerate(sampler, start=1):
        log("")
        log(f"######## CONFIG {config_id}/{N_RANDOM_CONFIGS} ########") 
        log(f"Parameters: {params}")

        # we are storing the metrics for each fold here
        fold_rmses_val, fold_maes_val, fold_r2s_val, fold_bias_val = [], [], [], []
        fold_rmses_tr, fold_maes_tr, fold_r2s_tr, fold_bias_tr = [], [], [], []
        fold_med_ae = []

        # for each configuration, we do K-Fold cross-validation
        for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):
            
            # data split for the current fold
            X_train, X_val = X.iloc[train_idx].copy(), X.iloc[val_idx].copy()
            y_train, y_val = y.iloc[train_idx].copy(), y.iloc[val_idx].copy()

            log(f"\n[C{config_id}|F{fold}] Processing fold...")


            # -> Preprocessing Steps 
            # fit is only done with the training data 
            # we aplly the transformations (some obtained through fit) to both train and validation sets
            # all preprocessing functions are explained before, here we just apply them in order
            year_state = fit_year_median(X_train, year_col="year", model_col="model")
            X_train = transform_year_with_model_median(X_train, state=year_state)
            X_val   = transform_year_with_model_median(X_val,   state=year_state)

            engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
            X_train = transform_engine_size_imputer(X_train, state=engine_state)
            X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

            X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
            X_val   = transform_tax_custom_rules(X_val, "tax", "year", "fuelType", "engineSize")

            mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
            X_train = transform_mpg_imputer(X_train, state=mpg_state)
            X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

            owners_state = fit_previous_owners_imputer(X_train, "previousOwners", "year", "mileage")
            X_train = transform_previous_owners_imputer(X_train, state=owners_state)
            X_val   = transform_previous_owners_imputer(X_val,   state=owners_state)

            brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
            X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
            X_val, _, _   = transform_ambiguous_brands(X_val, brand_state)

            model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
            X_train, _, _ = transform_invalid_models(X_train, model_state)
            X_val, _, _   = transform_invalid_models(X_val, model_state)

            transm_state = fit_transmission_resolver(X_train, valid_transmissions)
            X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
            X_val, _, _   = transform_transmission_resolver(X_val, transm_state)
            
            fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
            X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
            X_val, _, _   = transform_fueltype_resolver(X_val, fuel_state)


            # -> Feature Encoding
            # applied to categorical features only
            # we separate high cardinality and low cardinality categorical features
            high_card_features = ["Brand", "model"] # target encoding for these
            low_card_features  = [c for c in categorical_features if c not in high_card_features]

            te = MyTargetEncoder(smoothing=5)
            te.fit(X_train[high_card_features], y_train) # fit on training data
            X_train_high = te.transform(X_train[high_card_features])
            X_val_high   = te.transform(X_val[high_card_features])

            ohe = MyOneHotEncoder()
            ohe.fit(X_train[low_card_features]) # fit on training data
            X_train_low = ohe.transform(X_train[low_card_features])
            X_val_low   = ohe.transform(X_val[low_card_features])

            # rejoining the categorical features (that are now encoded)
            X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
            X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

            # joining numerical and categorical (encoded) features 
            X_train_final = pd.concat([X_train[numeric_features], X_train_cat], axis=1)
            X_val_final   = pd.concat([X_val[numeric_features],   X_val_cat],   axis=1)

            # here, we log the features name, to keep track of what is being used from the original set
            # but also because the columns increase due to encoding
            if fold == 1:
                feature_names = list(X_train_final.columns)
                log(f"  > Features Used ({len(feature_names)}): {feature_names}")
            
            # -> Model Training 
            # params contains the hyperparameters for this configuration
            hgb_model = HistGradientBoostingRegressor(random_state=RANDOM_STATE, **params)
            hgb_model.fit(X_train_final, y_train)

            # predictions on train and validation fold
            y_pred_train = hgb_model.predict(X_train_final)
            y_pred_val   = hgb_model.predict(X_val_final)

            # -> Metrics Calculation
            # Training metrics:
            mae_tr = mean_absolute_error(y_train, y_pred_train)
            rmse_tr = np.sqrt(mean_squared_error(y_train, y_pred_train))
            r2_tr = r2_score(y_train, y_pred_train)
            bias_tr = np.mean(y_train - y_pred_train)
            # Validation metrics:
            mae_val = mean_absolute_error(y_val, y_pred_val)
            rmse_val = np.sqrt(mean_squared_error(y_val, y_pred_val))
            r2_val = r2_score(y_val, y_pred_val)
            bias_val = np.mean(y_val - y_pred_val)
            med_ae_val = median_absolute_error(y_val, y_pred_val)

            # logging the metrics of this fold
            log(f"  > [TRAIN] R2: {r2_tr:.4f} | RMSE: {rmse_tr:.0f} | MAE: {mae_tr:.0f} | Bias: {bias_tr:.1f}")
            log(f"  > [VAL]   R2: {r2_val:.4f} | RMSE: {rmse_val:.0f} | MAE: {mae_val:.0f} | Bias: {bias_val:.1f}")
            # storing the metrics of this fold
            fold_maes_tr.append(mae_tr); fold_rmses_tr.append(rmse_tr); fold_r2s_tr.append(r2_tr); fold_bias_tr.append(bias_tr)
            fold_maes_val.append(mae_val); fold_rmses_val.append(rmse_val); fold_r2s_val.append(r2_val); fold_bias_val.append(bias_val)
            fold_med_ae.append(med_ae_val)

        # after all folds, we calculate the mean metrics across them
        mean_rmse_val = np.mean(fold_rmses_val)
        mean_mae_val  = np.mean(fold_maes_val)
        mean_r2_val   = np.mean(fold_r2s_val)
        mean_bias_val = np.mean(fold_bias_val)
        
        mean_mae_tr   = np.mean(fold_maes_tr)
        mean_r2_tr    = np.mean(fold_r2s_tr)
        mean_bias_tr  = np.mean(fold_bias_tr)
        
        # logging and storing these results
        log("")
        log(f"Config {config_id} SUMMARY:")
        log(f"  [TRAIN AVG] MAE: {mean_mae_tr:.1f} | R2: {mean_r2_tr:.4f} | Bias: {mean_bias_tr:.1f}")
        log(f"  [VAL AVG]   MAE: {mean_mae_val:.1f} | R2: {mean_r2_val:.4f} | Bias: {mean_bias_val:.1f} | RMSE: {mean_rmse_val:.1f}")

        search_results.append({
            "config_id": config_id,
            **params,
            
            "val_rmse": mean_rmse_val,
            "val_mae": mean_mae_val,
            "val_r2": mean_r2_val,
            "val_bias": mean_bias_val,

            "train_mae": mean_mae_tr,
            "train_r2": mean_r2_tr,
            "train_bias": mean_bias_tr,

            "val_med_ae": np.mean(fold_med_ae)
        })

        # our best configuration is defined by the best rmse
        # by best, we mean the lowest rmse
        if mean_rmse_val < best_rmse:
            best_rmse = mean_rmse_val
            best_config = {**params}
            log(f"[NEW BEST RMSE] Config {config_id}")

    log("# END OF SEARCH")


# Results
results_df = pd.DataFrame(search_results)
results_df_sorted = results_df.sort_values(by="val_rmse", ascending=True)

print("\nTop 5 Configurations by RMSE:")
cols = ["config_id", "learning_rate", "max_iter", "val_rmse", "val_mae", "val_r2", "train_r2", "val_bias"]
display(results_df_sorted[cols].head(5))

print("\nBest Config found:")
print(best_config)
# Out:
# # =============================
# # START OF HGB SEARCH (DETAILED METRICS: R2, RMSE, MAE, BIAS)
# # LOG FILE SAVED TO: gb_logs/2gb_complete_nof_log.txt
# # =============================
#
# ######## CONFIG 1/10 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 1000, 'max_depth': 20, 'learning_rate': 0.05, 'l2_regularization': 5}
#
# [C1|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9612 | RMSE: 1924 | MAE: 1181 | Bias: 6.3
#   > [VAL]   R2: 0.9563 | RMSE: 1990 | MAE: 1309 | Bias: -36.9
#
# [C1|F2] Processing fold...
#   > [TRAIN] R2: 0.9679 | RMSE: 1746 | MAE: 1139 | Bias: 1.1
#   > [VAL]   R2: 0.9498 | RMSE: 2169 | MAE: 1323 | Bias: -11.4
#
# [C1|F3] Processing fold...
#   > [TRAIN] R2: 0.9629 | RMSE: 1877 | MAE: 1189 | Bias: 2.9
#   > [VAL]   R2: 0.9487 | RMSE: 2196 | MAE: 1332 | Bias: 31.6
#
# [C1|F4] Processing fold...
#   > [TRAIN] R2: 0.9689 | RMSE: 1707 | MAE: 1144 | Bias: -1.2
#   > [VAL]   R2: 0.9323 | RMSE: 2637 | MAE: 1339 | Bias: 21.6
#
# [C1|F5] Processing fold...
#   > [TRAIN] R2: 0.9683 | RMSE: 1731 | MAE: 1126 | Bias: -4.8
#   > [VAL]   R2: 0.9558 | RMSE: 2062 | MAE: 1289 | Bias: -8.6
#
# [C1|F6] Processing fold...
#   > [TRAIN] R2: 0.9643 | RMSE: 1838 | MAE: 1189 | Bias: 0.1
#   > [VAL]   R2: 0.9523 | RMSE: 2144 | MAE: 1313 | Bias: 15.8
#
# [C1|F7] Processing fold...
#   > [TRAIN] R2: 0.9694 | RMSE: 1703 | MAE: 1107 | Bias: 3.4
#   > [VAL]   R2: 0.9562 | RMSE: 2035 | MAE: 1268 | Bias: 31.1
#
# [C1|F8] Processing fold...
#   > [TRAIN] R2: 0.9703 | RMSE: 1684 | MAE: 1101 | Bias: 1.5
#   > [VAL]   R2: 0.9558 | RMSE: 1998 | MAE: 1246 | Bias: -18.2
#
# Config 1 SUMMARY:
#   [TRAIN AVG] MAE: 1147.1 | R2: 0.9667 | Bias: 1.2
#   [VAL AVG]   MAE: 1302.4 | R2: 0.9509 | Bias: 3.1 | RMSE: 2153.7
# [NEW BEST RMSE] Config 1
#
# ######## CONFIG 2/10 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 31, 'max_iter': 600, 'max_depth': 11, 'learning_rate': 0.15, 'l2_regularization': 5}
#
# [C2|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9549 | RMSE: 2074 | MAE: 1289 | Bias: 5.4
#   > [VAL]   R2: 0.9532 | RMSE: 2059 | MAE: 1363 | Bias: -33.1
#
# [C2|F2] Processing fold...
#   > [TRAIN] R2: 0.9647 | RMSE: 1830 | MAE: 1198 | Bias: 0.7
#   > [VAL]   R2: 0.9494 | RMSE: 2179 | MAE: 1352 | Bias: -18.3
#
# [C2|F3] Processing fold...
#   > [TRAIN] R2: 0.9594 | RMSE: 1964 | MAE: 1255 | Bias: 1.9
#   > [VAL]   R2: 0.9475 | RMSE: 2220 | MAE: 1373 | Bias: 30.7
#
# [C2|F4] Processing fold...
#   > [TRAIN] R2: 0.9664 | RMSE: 1775 | MAE: 1191 | Bias: -1.9
#   > [VAL]   R2: 0.9326 | RMSE: 2631 | MAE: 1364 | Bias: 20.2
#
# [C2|F5] Processing fold...
#   > [TRAIN] R2: 0.9684 | RMSE: 1730 | MAE: 1130 | Bias: -5.5
#   > [VAL]   R2: 0.9555 | RMSE: 2068 | MAE: 1296 | Bias: -13.1
#
# [C2|F6] Processing fold...
#   > [TRAIN] R2: 0.9656 | RMSE: 1805 | MAE: 1171 | Bias: 0.7
#   > [VAL]   R2: 0.9544 | RMSE: 2098 | MAE: 1304 | Bias: 16.5
#
# [C2|F7] Processing fold...
#   > [TRAIN] R2: 0.9627 | RMSE: 1882 | MAE: 1227 | Bias: 3.9
#   > [VAL]   R2: 0.9549 | RMSE: 2066 | MAE: 1326 | Bias: 22.5
#
# [C2|F8] Processing fold...
#   > [TRAIN] R2: 0.9614 | RMSE: 1919 | MAE: 1254 | Bias: 1.6
#   > [VAL]   R2: 0.9513 | RMSE: 2096 | MAE: 1332 | Bias: -30.0
#
# Config 2 SUMMARY:
#   [TRAIN AVG] MAE: 1214.5 | R2: 0.9629 | Bias: 0.9
#   [VAL AVG]   MAE: 1338.8 | R2: 0.9498 | Bias: -0.6 | RMSE: 2177.2
#
# ######## CONFIG 3/10 ########
# Parameters: {'min_samples_leaf': 40, 'max_leaf_nodes': 31, 'max_iter': 1000, 'max_depth': 10, 'learning_rate': 0.1, 'l2_regularization': 0}
#
# [C3|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9572 | RMSE: 2022 | MAE: 1243 | Bias: 5.6
#   > [VAL]   R2: 0.9543 | RMSE: 2033 | MAE: 1331 | Bias: -35.3
#
# [C3|F2] Processing fold...
#   > [TRAIN] R2: 0.9560 | RMSE: 2043 | MAE: 1313 | Bias: 1.0
#   > [VAL]   R2: 0.9453 | RMSE: 2265 | MAE: 1409 | Bias: -22.3
#
# [C3|F3] Processing fold...
#   > [TRAIN] R2: 0.9596 | RMSE: 1959 | MAE: 1241 | Bias: 1.9
#   > [VAL]   R2: 0.9474 | RMSE: 2223 | MAE: 1357 | Bias: 36.8
#
# [C3|F4] Processing fold...
#   > [TRAIN] R2: 0.9637 | RMSE: 1844 | MAE: 1222 | Bias: -2.1
#   > [VAL]   R2: 0.9310 | RMSE: 2662 | MAE: 1379 | Bias: 23.2
#
# [C3|F5] Processing fold...
#   > [TRAIN] R2: 0.9646 | RMSE: 1831 | MAE: 1186 | Bias: -5.5
#   > [VAL]   R2: 0.9539 | RMSE: 2105 | MAE: 1311 | Bias: -9.3
#
# [C3|F6] Processing fold...
#   > [TRAIN] R2: 0.9625 | RMSE: 1883 | MAE: 1218 | Bias: 1.2
#   > [VAL]   R2: 0.9520 | RMSE: 2151 | MAE: 1330 | Bias: 15.5
#
# [C3|F7] Processing fold...
#   > [TRAIN] R2: 0.9674 | RMSE: 1758 | MAE: 1139 | Bias: 3.6
#   > [VAL]   R2: 0.9562 | RMSE: 2035 | MAE: 1274 | Bias: 33.2
#
# [C3|F8] Processing fold...
#   > [TRAIN] R2: 0.9578 | RMSE: 2007 | MAE: 1294 | Bias: 2.4
#   > [VAL]   R2: 0.9500 | RMSE: 2125 | MAE: 1346 | Bias: -25.1
#
# Config 3 SUMMARY:
#   [TRAIN AVG] MAE: 1232.0 | R2: 0.9611 | Bias: 1.0
#   [VAL AVG]   MAE: 1342.3 | R2: 0.9488 | Bias: 2.1 | RMSE: 2199.9
#
# ######## CONFIG 4/10 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': None, 'learning_rate': 0.15, 'l2_regularization': 1}
#
# [C4|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9664 | RMSE: 1791 | MAE: 1091 | Bias: 5.5
#   > [VAL]   R2: 0.9566 | RMSE: 1983 | MAE: 1291 | Bias: -42.8
#
# [C4|F2] Processing fold...
#   > [TRAIN] R2: 0.9721 | RMSE: 1628 | MAE: 1061 | Bias: 0.9
#   > [VAL]   R2: 0.9511 | RMSE: 2141 | MAE: 1302 | Bias: -12.4
#
# [C4|F3] Processing fold...
#   > [TRAIN] R2: 0.9675 | RMSE: 1757 | MAE: 1120 | Bias: 4.4
#   > [VAL]   R2: 0.9488 | RMSE: 2192 | MAE: 1327 | Bias: 39.7
#
# [C4|F4] Processing fold...
#   > [TRAIN] R2: 0.9759 | RMSE: 1501 | MAE: 1009 | Bias: -0.3
#   > [VAL]   R2: 0.9336 | RMSE: 2611 | MAE: 1318 | Bias: 36.6
#
# [C4|F5] Processing fold...
#   > [TRAIN] R2: 0.9748 | RMSE: 1543 | MAE: 1008 | Bias: -5.1
#   > [VAL]   R2: 0.9563 | RMSE: 2049 | MAE: 1278 | Bias: -10.1
#
# [C4|F6] Processing fold...
#   > [TRAIN] R2: 0.9752 | RMSE: 1531 | MAE: 992 | Bias: -0.2
#   > [VAL]   R2: 0.9558 | RMSE: 2064 | MAE: 1262 | Bias: 11.6
#
# [C4|F7] Processing fold...
#   > [TRAIN] R2: 0.9738 | RMSE: 1575 | MAE: 1024 | Bias: 2.1
#   > [VAL]   R2: 0.9553 | RMSE: 2056 | MAE: 1267 | Bias: 16.7
#
# [C4|F8] Processing fold...
#   > [TRAIN] R2: 0.9702 | RMSE: 1687 | MAE: 1100 | Bias: 1.4
#   > [VAL]   R2: 0.9545 | RMSE: 2026 | MAE: 1261 | Bias: -10.2
#
# Config 4 SUMMARY:
#   [TRAIN AVG] MAE: 1050.6 | R2: 0.9720 | Bias: 1.1
#   [VAL AVG]   MAE: 1288.4 | R2: 0.9515 | Bias: 3.7 | RMSE: 2140.3
# [NEW BEST RMSE] Config 4
#
# ######## CONFIG 5/10 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 31, 'max_iter': 800, 'max_depth': 11, 'learning_rate': 0.05, 'l2_regularization': 1}
#
# [C5|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9535 | RMSE: 2106 | MAE: 1315 | Bias: 5.0
#   > [VAL]   R2: 0.9520 | RMSE: 2084 | MAE: 1384 | Bias: -26.8
#
# [C5|F2] Processing fold...
#   > [TRAIN] R2: 0.9621 | RMSE: 1897 | MAE: 1241 | Bias: 0.8
#   > [VAL]   R2: 0.9487 | RMSE: 2193 | MAE: 1368 | Bias: -16.9
#
# [C5|F3] Processing fold...
#   > [TRAIN] R2: 0.9583 | RMSE: 1990 | MAE: 1273 | Bias: 2.0
#   > [VAL]   R2: 0.9461 | RMSE: 2250 | MAE: 1378 | Bias: 44.3
#
# [C5|F4] Processing fold...
#   > [TRAIN] R2: 0.9645 | RMSE: 1824 | MAE: 1220 | Bias: -1.8
#   > [VAL]   R2: 0.9333 | RMSE: 2618 | MAE: 1373 | Bias: 21.1
#
# [C5|F5] Processing fold...
#   > [TRAIN] R2: 0.9620 | RMSE: 1897 | MAE: 1233 | Bias: -5.8
#   > [VAL]   R2: 0.9528 | RMSE: 2130 | MAE: 1341 | Bias: -13.3
#
# [C5|F6] Processing fold...
#   > [TRAIN] R2: 0.9616 | RMSE: 1906 | MAE: 1237 | Bias: 1.2
#   > [VAL]   R2: 0.9511 | RMSE: 2172 | MAE: 1339 | Bias: 16.9
#
# [C5|F7] Processing fold...
#   > [TRAIN] R2: 0.9616 | RMSE: 1909 | MAE: 1245 | Bias: 4.4
#   > [VAL]   R2: 0.9539 | RMSE: 2088 | MAE: 1333 | Bias: 21.6
#
# [C5|F8] Processing fold...
#   > [TRAIN] R2: 0.9620 | RMSE: 1904 | MAE: 1243 | Bias: 2.3
#   > [VAL]   R2: 0.9525 | RMSE: 2071 | MAE: 1311 | Bias: -22.9
#
# Config 5 SUMMARY:
#   [TRAIN AVG] MAE: 1250.9 | R2: 0.9607 | Bias: 1.0
#   [VAL AVG]   MAE: 1353.3 | R2: 0.9488 | Bias: 3.0 | RMSE: 2200.8
#
# ######## CONFIG 6/10 ########
# Parameters: {'min_samples_leaf': 40, 'max_leaf_nodes': 63, 'max_iter': 1000, 'max_depth': 15, 'learning_rate': 0.05, 'l2_regularization': 0}
#
# [C6|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9574 | RMSE: 2017 | MAE: 1225 | Bias: 5.1
#   > [VAL]   R2: 0.9543 | RMSE: 2033 | MAE: 1321 | Bias: -33.3
#
# [C6|F2] Processing fold...
#   > [TRAIN] R2: 0.9643 | RMSE: 1840 | MAE: 1178 | Bias: 0.6
#   > [VAL]   R2: 0.9480 | RMSE: 2209 | MAE: 1336 | Bias: -23.6
#
# [C6|F3] Processing fold...
#   > [TRAIN] R2: 0.9604 | RMSE: 1939 | MAE: 1209 | Bias: 2.9
#   > [VAL]   R2: 0.9477 | RMSE: 2217 | MAE: 1339 | Bias: 39.4
#
# [C6|F4] Processing fold...
#   > [TRAIN] R2: 0.9680 | RMSE: 1731 | MAE: 1150 | Bias: -0.8
#   > [VAL]   R2: 0.9331 | RMSE: 2621 | MAE: 1342 | Bias: 21.6
#
# [C6|F5] Processing fold...
#   > [TRAIN] R2: 0.9639 | RMSE: 1848 | MAE: 1184 | Bias: -4.9
#   > [VAL]   R2: 0.9533 | RMSE: 2119 | MAE: 1313 | Bias: -11.9
#
# [C6|F6] Processing fold...
#   > [TRAIN] R2: 0.9608 | RMSE: 1926 | MAE: 1219 | Bias: 0.4
#   > [VAL]   R2: 0.9476 | RMSE: 2248 | MAE: 1332 | Bias: 11.9
#
# [C6|F7] Processing fold...
#   > [TRAIN] R2: 0.9661 | RMSE: 1793 | MAE: 1149 | Bias: 3.2
#   > [VAL]   R2: 0.9559 | RMSE: 2042 | MAE: 1277 | Bias: 28.2
#
# [C6|F8] Processing fold...
#   > [TRAIN] R2: 0.9619 | RMSE: 1907 | MAE: 1223 | Bias: 1.7
#   > [VAL]   R2: 0.9526 | RMSE: 2069 | MAE: 1299 | Bias: -16.6
#
# Config 6 SUMMARY:
#   [TRAIN AVG] MAE: 1192.1 | R2: 0.9629 | Bias: 1.0
#   [VAL AVG]   MAE: 1320.1 | R2: 0.9491 | Bias: 2.0 | RMSE: 2194.7
#
# ######## CONFIG 7/10 ########
# Parameters: {'min_samples_leaf': 40, 'max_leaf_nodes': 31, 'max_iter': 800, 'max_depth': 11, 'learning_rate': 0.05, 'l2_regularization': 5}
#
# [C7|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9555 | RMSE: 2061 | MAE: 1268 | Bias: 5.2
#   > [VAL]   R2: 0.9534 | RMSE: 2054 | MAE: 1347 | Bias: -38.3
#
# [C7|F2] Processing fold...
#   > [TRAIN] R2: 0.9580 | RMSE: 1997 | MAE: 1286 | Bias: 0.8
#   > [VAL]   R2: 0.9463 | RMSE: 2244 | MAE: 1392 | Bias: -23.0
#
# [C7|F3] Processing fold...
#   > [TRAIN] R2: 0.9568 | RMSE: 2025 | MAE: 1278 | Bias: 1.6
#   > [VAL]   R2: 0.9451 | RMSE: 2272 | MAE: 1380 | Bias: 42.8
#
# [C7|F4] Processing fold...
#   > [TRAIN] R2: 0.9612 | RMSE: 1906 | MAE: 1263 | Bias: -1.8
#   > [VAL]   R2: 0.9299 | RMSE: 2684 | MAE: 1400 | Bias: 19.1
#
# [C7|F5] Processing fold...
#   > [TRAIN] R2: 0.9587 | RMSE: 1977 | MAE: 1277 | Bias: -6.0
#   > [VAL]   R2: 0.9515 | RMSE: 2160 | MAE: 1366 | Bias: -12.4
#
# [C7|F6] Processing fold...
#   > [TRAIN] R2: 0.9584 | RMSE: 1984 | MAE: 1271 | Bias: 1.1
#   > [VAL]   R2: 0.9487 | RMSE: 2224 | MAE: 1353 | Bias: 17.4
#
# [C7|F7] Processing fold...
#   > [TRAIN] R2: 0.9589 | RMSE: 1975 | MAE: 1267 | Bias: 4.1
#   > [VAL]   R2: 0.9523 | RMSE: 2125 | MAE: 1337 | Bias: 31.3
#
# [C7|F8] Processing fold...
#   > [TRAIN] R2: 0.9550 | RMSE: 2072 | MAE: 1327 | Bias: 1.7
#   > [VAL]   R2: 0.9491 | RMSE: 2143 | MAE: 1361 | Bias: -27.5
#
# Config 7 SUMMARY:
#   [TRAIN AVG] MAE: 1279.5 | R2: 0.9578 | Bias: 0.8
#   [VAL AVG]   MAE: 1366.9 | R2: 0.9470 | Bias: 1.2 | RMSE: 2238.2
#
# ######## CONFIG 8/10 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 600, 'max_depth': 20, 'learning_rate': 0.1, 'l2_regularization': 0}
#
# [C8|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9636 | RMSE: 1865 | MAE: 1138 | Bias: 7.1
#   > [VAL]   R2: 0.9570 | RMSE: 1972 | MAE: 1294 | Bias: -36.9
#
# [C8|F2] Processing fold...
#   > [TRAIN] R2: 0.9735 | RMSE: 1587 | MAE: 1033 | Bias: 0.7
#   > [VAL]   R2: 0.9511 | RMSE: 2143 | MAE: 1298 | Bias: -12.6
#
# [C8|F3] Processing fold...
#   > [TRAIN] R2: 0.9705 | RMSE: 1674 | MAE: 1062 | Bias: 4.9
#   > [VAL]   R2: 0.9514 | RMSE: 2137 | MAE: 1296 | Bias: 41.2
#
# [C8|F4] Processing fold...
#   > [TRAIN] R2: 0.9712 | RMSE: 1644 | MAE: 1097 | Bias: -0.1
#   > [VAL]   R2: 0.9336 | RMSE: 2613 | MAE: 1330 | Bias: 30.0
#
# [C8|F5] Processing fold...
#   > [TRAIN] R2: 0.9769 | RMSE: 1478 | MAE: 962 | Bias: -6.0
#   > [VAL]   R2: 0.9562 | RMSE: 2052 | MAE: 1264 | Bias: -8.1
#
# [C8|F6] Processing fold...
#   > [TRAIN] R2: 0.9720 | RMSE: 1626 | MAE: 1048 | Bias: 0.7
#   > [VAL]   R2: 0.9546 | RMSE: 2092 | MAE: 1272 | Bias: 9.5
#
# [C8|F7] Processing fold...
#   > [TRAIN] R2: 0.9732 | RMSE: 1594 | MAE: 1033 | Bias: 2.0
#   > [VAL]   R2: 0.9565 | RMSE: 2028 | MAE: 1254 | Bias: 22.1
#
# [C8|F8] Processing fold...
#   > [TRAIN] R2: 0.9696 | RMSE: 1703 | MAE: 1106 | Bias: 1.7
#   > [VAL]   R2: 0.9538 | RMSE: 2043 | MAE: 1262 | Bias: -12.4
#
# Config 8 SUMMARY:
#   [TRAIN AVG] MAE: 1059.6 | R2: 0.9713 | Bias: 1.4
#   [VAL AVG]   MAE: 1283.8 | R2: 0.9518 | Bias: 4.1 | RMSE: 2134.9
# [NEW BEST RMSE] Config 8
#
# ######## CONFIG 9/10 ########
# Parameters: {'min_samples_leaf': 40, 'max_leaf_nodes': 31, 'max_iter': 1000, 'max_depth': 20, 'learning_rate': 0.15, 'l2_regularization': 2}
#
# [C9|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9569 | RMSE: 2028 | MAE: 1246 | Bias: 5.4
#   > [VAL]   R2: 0.9538 | RMSE: 2044 | MAE: 1343 | Bias: -39.3
#
# [C9|F2] Processing fold...
#   > [TRAIN] R2: 0.9588 | RMSE: 1977 | MAE: 1280 | Bias: 0.1
#   > [VAL]   R2: 0.9465 | RMSE: 2240 | MAE: 1395 | Bias: -31.9
#
# [C9|F3] Processing fold...
#   > [TRAIN] R2: 0.9573 | RMSE: 2013 | MAE: 1280 | Bias: 1.9
#   > [VAL]   R2: 0.9442 | RMSE: 2290 | MAE: 1389 | Bias: 38.0
#
# [C9|F4] Processing fold...
#   > [TRAIN] R2: 0.9667 | RMSE: 1767 | MAE: 1180 | Bias: -0.8
#   > [VAL]   R2: 0.9320 | RMSE: 2644 | MAE: 1353 | Bias: 23.2
#
# [C9|F5] Processing fold...
#   > [TRAIN] R2: 0.9608 | RMSE: 1926 | MAE: 1247 | Bias: -5.3
#   > [VAL]   R2: 0.9519 | RMSE: 2152 | MAE: 1354 | Bias: -23.1
#
# [C9|F6] Processing fold...
#   > [TRAIN] R2: 0.9599 | RMSE: 1949 | MAE: 1255 | Bias: 1.0
#   > [VAL]   R2: 0.9504 | RMSE: 2185 | MAE: 1344 | Bias: 27.5
#
# [C9|F7] Processing fold...
#   > [TRAIN] R2: 0.9678 | RMSE: 1747 | MAE: 1133 | Bias: 3.6
#   > [VAL]   R2: 0.9566 | RMSE: 2026 | MAE: 1275 | Bias: 30.1
#
# [C9|F8] Processing fold...
#   > [TRAIN] R2: 0.9675 | RMSE: 1762 | MAE: 1155 | Bias: 2.4
#   > [VAL]   R2: 0.9540 | RMSE: 2036 | MAE: 1283 | Bias: -18.8
#
# Config 9 SUMMARY:
#   [TRAIN AVG] MAE: 1221.9 | R2: 0.9620 | Bias: 1.1
#   [VAL AVG]   MAE: 1342.2 | R2: 0.9487 | Bias: 0.7 | RMSE: 2202.2
#
# ######## CONFIG 10/10 ########
# Parameters: {'min_samples_leaf': 40, 'max_leaf_nodes': 31, 'max_iter': 600, 'max_depth': 15, 'learning_rate': 0.05, 'l2_regularization': 1}
#
# [C10|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9537 | RMSE: 2101 | MAE: 1293 | Bias: 5.3
#   > [VAL]   R2: 0.9526 | RMSE: 2071 | MAE: 1362 | Bias: -32.5
#
# [C10|F2] Processing fold...
#   > [TRAIN] R2: 0.9564 | RMSE: 2034 | MAE: 1309 | Bias: 0.3
#   > [VAL]   R2: 0.9457 | RMSE: 2256 | MAE: 1409 | Bias: -31.3
#
# [C10|F3] Processing fold...
#   > [TRAIN] R2: 0.9561 | RMSE: 2041 | MAE: 1288 | Bias: 1.0
#   > [VAL]   R2: 0.9445 | RMSE: 2284 | MAE: 1386 | Bias: 42.8
#
# [C10|F4] Processing fold...
#   > [TRAIN] R2: 0.9594 | RMSE: 1950 | MAE: 1283 | Bias: -2.1
#   > [VAL]   R2: 0.9293 | RMSE: 2696 | MAE: 1410 | Bias: 20.4
#
# [C10|F5] Processing fold...
#   > [TRAIN] R2: 0.9566 | RMSE: 2026 | MAE: 1301 | Bias: -5.5
#   > [VAL]   R2: 0.9502 | RMSE: 2188 | MAE: 1383 | Bias: -11.5
#
# [C10|F6] Processing fold...
#   > [TRAIN] R2: 0.9562 | RMSE: 2036 | MAE: 1301 | Bias: 0.9
#   > [VAL]   R2: 0.9470 | RMSE: 2259 | MAE: 1376 | Bias: 18.5
#
# [C10|F7] Processing fold...
#   > [TRAIN] R2: 0.9568 | RMSE: 2024 | MAE: 1297 | Bias: 4.6
#   > [VAL]   R2: 0.9520 | RMSE: 2131 | MAE: 1355 | Bias: 26.8
#
# [C10|F8] Processing fold...
#   > [TRAIN] R2: 0.9574 | RMSE: 2017 | MAE: 1297 | Bias: 1.6
#   > [VAL]   R2: 0.9504 | RMSE: 2117 | MAE: 1343 | Bias: -22.0
#
# Config 10 SUMMARY:
#   [TRAIN AVG] MAE: 1296.2 | R2: 0.9566 | Bias: 0.8
#   [VAL AVG]   MAE: 1378.0 | R2: 0.9465 | Bias: 1.4 | RMSE: 2250.2
# # END OF SEARCH
#
# Top 5 Configurations by RMSE:
#    config_id  learning_rate  max_iter     val_rmse      val_mae    val_r2  \
# 7          8           0.10       600  2134.871525  1283.759934  0.951767
# 3          4           0.15      1000  2140.256753  1288.369477  0.951520
# 0          1           0.05      1000  2153.685454  1302.447808  0.950903
# 1          2           0.15       600  2177.221894  1338.780521  0.949841
# 5          6           0.05      1000  2194.741353  1320.073472  0.949063
#
#    train_r2  val_bias
# 7  0.971301  4.099316
# 3  0.971999  3.652892
# 0  0.966652  3.115471
# 1  0.962922 -0.559954
# 5  0.962856  1.958502
# Best Config found:
# {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 600, 'max_depth': 20, 'learning_rate': 0.1, 'l2_regularization': 0}

# %% [markdown]
# ### 4.2. Dropping the Previous Owners Feature

# %% [markdown]
# - As previously stated, we noticed some inconsistencies in values present in this column.
# - We decided to conduct an attempt without this feature.

# %%
numeric_features = ['year', 'mileage', 'engineSize', 'tax', 'mpg'] # we removed previousOwners feature from here

# %%
# we will use an 8-fold cross-validation strategy
N_SPLITS = 8

# shuffles the data, in order to (at least theoretically) have more balanced folds
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# we explicitly exclude this feature from the model input
# (even if it still exists in X, it will be dropped before building X_train_final / X_val_final)
DROP_FROM_MODEL = ["previousOwners"]

# hyperparameter space that we are going to use for random search
# each configuration will get 1 value from each of these lists
param_distributions = {
    "loss": ["squared_error", "absolute_error"],
    "learning_rate": [0.07, 0.085, 0.1, 0.115],
    "max_iter": [600, 800, 1000, 1200],
    "max_leaf_nodes": [63, 127, 191, 255],
    "l2_regularization": [0.3, 1.0, 3.0],
    "min_samples_leaf": [12, 16, 20, 28],
    "max_depth": [15, 20, 25, None],
}

N_RANDOM_CONFIGS = 15  # short random search, enough for baseline results

# we get N_RANDOM_CONFIGS random parameter combinations from param_distributions
sampler = ParameterSampler(param_distributions, n_iter=N_RANDOM_CONFIGS, random_state=RANDOM_STATE)

search_results = []  # stores results for ranking

# tracking the best configuration according to validation RMSE
best_rmse = np.inf
best_config = None

# log setup (mainly for development and traceability)
log_dir = "gb_logs"
os.makedirs(log_dir, exist_ok=True)
log_filename = "2gb_noowners_nof_log.txt"
log_path = os.path.join(log_dir, log_filename)

# Note: this section is included mainly for organizational purposes

with open(log_path, "w", encoding="utf-8") as log_file:

    # prints to screen and writes to the log file
    def log(msg: str):
        print(msg)
        log_file.write(msg + "\n")
        log_file.flush()

    # header for the log file
    log("# =============================")
    log("# START OF HGB SEARCH (DETAILED METRICS: R2, RMSE, MAE, BIAS)")
    log(f"# LOG FILE SAVED TO: {log_path}")
    log("# =============================")

    # loop over random configurations
    for config_id, params in enumerate(sampler, start=1):
        log("")
        log(f"######## CONFIG {config_id}/{N_RANDOM_CONFIGS} ########")
        log(f"Parameters: {params}")

        # store metrics for each fold
        fold_rmses_val, fold_maes_val, fold_r2s_val, fold_bias_val = [], [], [], []
        fold_rmses_tr,  fold_maes_tr,  fold_r2s_tr,  fold_bias_tr  = [], [], [], []
        fold_med_ae = []

        # K-Fold cross-validation for this configuration
        for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):

            # data split for the current fold
            X_train, X_val = X.iloc[train_idx].copy(), X.iloc[val_idx].copy()
            y_train, y_val = y.iloc[train_idx].copy(), y.iloc[val_idx].copy()

            log(f"\n[C{config_id}|F{fold}] Processing fold...")

            # -> Preprocessing steps
            # fit is only done on the training fold, then applied to both train and validation
            year_state = fit_year_median(X_train, year_col="year", model_col="model")
            X_train = transform_year_with_model_median(X_train, state=year_state)
            X_val   = transform_year_with_model_median(X_val,   state=year_state)

            engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
            X_train = transform_engine_size_imputer(X_train, state=engine_state)
            X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

            X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
            X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

            mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
            X_train = transform_mpg_imputer(X_train, state=mpg_state)
            X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

            brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
            X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
            X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

            model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
            X_train, _, _ = transform_invalid_models(X_train, model_state)
            X_val,   _, _ = transform_invalid_models(X_val,   model_state)

            transm_state = fit_transmission_resolver(X_train, valid_transmissions)
            X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
            X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

            fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
            X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
            X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

            # hard guarantee: previousOwners is not used by the model in this section
            X_train = X_train.drop(columns=DROP_FROM_MODEL, errors="ignore")
            X_val   = X_val.drop(columns=DROP_FROM_MODEL, errors="ignore")

            # -> Feature encoding (categorical only)
            high_card_features = ["Brand", "model"]  # target encoding for these
            low_card_features  = [c for c in categorical_features if c not in high_card_features]

            te = MyTargetEncoder(smoothing=5)
            te.fit(X_train[high_card_features], y_train)  # fit on training fold only
            X_train_high = te.transform(X_train[high_card_features])
            X_val_high   = te.transform(X_val[high_card_features])

            ohe = MyOneHotEncoder()
            ohe.fit(X_train[low_card_features])  # fit on training fold only
            X_train_low = ohe.transform(X_train[low_card_features])
            X_val_low   = ohe.transform(X_val[low_card_features])

            # rejoin encoded categorical features
            X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
            X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

            # join numerical and categorical (encoded) features
            X_train_final = pd.concat([X_train[numeric_features], X_train_cat], axis=1)
            X_val_final   = pd.concat([X_val[numeric_features],   X_val_cat],   axis=1)

            # log feature names once per config (fold 1)
            if fold == 1:
                feature_names = list(X_train_final.columns)
                log(f"  > Features Used ({len(feature_names)}): {feature_names}")

            # -> Model training
            hgb_model = HistGradientBoostingRegressor(random_state=RANDOM_STATE, **params)
            hgb_model.fit(X_train_final, y_train)

            # predictions
            y_pred_train = hgb_model.predict(X_train_final)
            y_pred_val   = hgb_model.predict(X_val_final)

            # -> Metrics calculation
            mae_tr  = mean_absolute_error(y_train, y_pred_train)
            rmse_tr = np.sqrt(mean_squared_error(y_train, y_pred_train))
            r2_tr   = r2_score(y_train, y_pred_train)
            bias_tr = np.mean(y_train - y_pred_train)

            mae_val  = mean_absolute_error(y_val, y_pred_val)
            rmse_val = np.sqrt(mean_squared_error(y_val, y_pred_val))
            r2_val   = r2_score(y_val, y_pred_val)
            bias_val = np.mean(y_val - y_pred_val)

            med_ae_val = median_absolute_error(y_val, y_pred_val)

            log(f"  > [TRAIN] R2: {r2_tr:.4f} | RMSE: {rmse_tr:.0f} | MAE: {mae_tr:.0f} | Bias: {bias_tr:.1f}")
            log(f"  > [VAL]   R2: {r2_val:.4f} | RMSE: {rmse_val:.0f} | MAE: {mae_val:.0f} | Bias: {bias_val:.1f}")

            fold_maes_tr.append(mae_tr);   fold_rmses_tr.append(rmse_tr);   fold_r2s_tr.append(r2_tr);   fold_bias_tr.append(bias_tr)
            fold_maes_val.append(mae_val); fold_rmses_val.append(rmse_val); fold_r2s_val.append(r2_val); fold_bias_val.append(bias_val)
            fold_med_ae.append(med_ae_val)

        # mean metrics across folds
        mean_rmse_val = np.mean(fold_rmses_val)
        mean_mae_val  = np.mean(fold_maes_val)
        mean_r2_val   = np.mean(fold_r2s_val)
        mean_bias_val = np.mean(fold_bias_val)

        mean_mae_tr   = np.mean(fold_maes_tr)
        mean_r2_tr    = np.mean(fold_r2s_tr)
        mean_bias_tr  = np.mean(fold_bias_tr)

        log("")
        log(f"Config {config_id} SUMMARY:")
        log(f"  [TRAIN AVG] MAE: {mean_mae_tr:.1f} | R2: {mean_r2_tr:.4f} | Bias: {mean_bias_tr:.1f}")
        log(f"  [VAL AVG]   MAE: {mean_mae_val:.1f} | R2: {mean_r2_val:.4f} | Bias: {mean_bias_val:.1f} | RMSE: {mean_rmse_val:.1f}")

        search_results.append({
            "config_id": config_id,
            **params,

            "val_rmse": mean_rmse_val,
            "val_mae": mean_mae_val,
            "val_r2": mean_r2_val,
            "val_bias": mean_bias_val,

            "train_mae": mean_mae_tr,
            "train_r2": mean_r2_tr,
            "train_bias": mean_bias_tr,

            "val_med_ae": np.mean(fold_med_ae)
        })

        # best = lowest validation RMSE
        if mean_rmse_val < best_rmse:
            best_rmse = mean_rmse_val
            best_config = {**params}
            log(f"[NEW BEST RMSE] Config {config_id}")

    log("# END OF SEARCH")

# Results
results_df = pd.DataFrame(search_results)
results_df_sorted = results_df.sort_values(by="val_rmse", ascending=True)

print("\nTop 5 Configurations by RMSE:")
cols = ["config_id", "learning_rate", "max_iter", "val_rmse", "val_mae", "val_r2", "train_r2", "val_bias"]
display(results_df_sorted[cols].head(5))

print("\nBest Config found:")
print(best_config)
# Out:
# # =============================
# # START OF HGB SEARCH (DETAILED METRICS: R2, RMSE, MAE, BIAS)
# # LOG FILE SAVED TO: gb_logs/2gb_noowners_nof_log.txt
# # =============================
#
# ######## CONFIG 1/15 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 255, 'max_iter': 800, 'max_depth': 20, 'loss': 'absolute_error', 'learning_rate': 0.085, 'l2_regularization': 0.3}
#
# [C1|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9569 | RMSE: 2029 | MAE: 1072 | Bias: 136.0
#   > [VAL]   R2: 0.9560 | RMSE: 1995 | MAE: 1266 | Bias: 84.7
#
# [C1|F2] Processing fold...
#   > [TRAIN] R2: 0.9661 | RMSE: 1794 | MAE: 912 | Bias: 117.1
#   > [VAL]   R2: 0.9548 | RMSE: 2058 | MAE: 1242 | Bias: 98.0
#
# [C1|F3] Processing fold...
#   > [TRAIN] R2: 0.9667 | RMSE: 1779 | MAE: 900 | Bias: 114.7
#   > [VAL]   R2: 0.9433 | RMSE: 2308 | MAE: 1252 | Bias: 150.7
#
# [C1|F4] Processing fold...
#   > [TRAIN] R2: 0.9674 | RMSE: 1746 | MAE: 928 | Bias: 120.3
#   > [VAL]   R2: 0.9333 | RMSE: 2618 | MAE: 1278 | Bias: 159.0
#
# [C1|F5] Processing fold...
#   > [TRAIN] R2: 0.9630 | RMSE: 1871 | MAE: 970 | Bias: 114.3
#   > [VAL]   R2: 0.9501 | RMSE: 2191 | MAE: 1249 | Bias: 111.2
#
# [C1|F6] Processing fold...
#   > [TRAIN] R2: 0.9643 | RMSE: 1837 | MAE: 963 | Bias: 121.9
#   > [VAL]   R2: 0.9457 | RMSE: 2288 | MAE: 1243 | Bias: 148.9
#
# [C1|F7] Processing fold...
#   > [TRAIN] R2: 0.9594 | RMSE: 1963 | MAE: 1016 | Bias: 137.2
#   > [VAL]   R2: 0.9553 | RMSE: 2058 | MAE: 1236 | Bias: 157.4
#
# [C1|F8] Processing fold...
#   > [TRAIN] R2: 0.9665 | RMSE: 1790 | MAE: 894 | Bias: 114.2
#   > [VAL]   R2: 0.9558 | RMSE: 1997 | MAE: 1205 | Bias: 86.5
#
# Config 1 SUMMARY:
#   [TRAIN AVG] MAE: 956.8 | R2: 0.9638 | Bias: 122.0
#   [VAL AVG]   MAE: 1246.3 | R2: 0.9493 | Bias: 124.6 | RMSE: 2189.1
# [NEW BEST RMSE] Config 1
#
# ######## CONFIG 2/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 255, 'max_iter': 600, 'max_depth': 15, 'loss': 'absolute_error', 'learning_rate': 0.1, 'l2_regularization': 3.0}
#
# [C2|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9592 | RMSE: 1974 | MAE: 1004 | Bias: 130.0
#   > [VAL]   R2: 0.9573 | RMSE: 1965 | MAE: 1247 | Bias: 82.2
#
# [C2|F2] Processing fold...
#   > [TRAIN] R2: 0.9620 | RMSE: 1899 | MAE: 988 | Bias: 124.7
#   > [VAL]   R2: 0.9524 | RMSE: 2112 | MAE: 1260 | Bias: 97.6
#
# [C2|F3] Processing fold...
#   > [TRAIN] R2: 0.9620 | RMSE: 1898 | MAE: 973 | Bias: 125.5
#   > [VAL]   R2: 0.9416 | RMSE: 2342 | MAE: 1269 | Bias: 158.4
#
# [C2|F4] Processing fold...
#   > [TRAIN] R2: 0.9653 | RMSE: 1803 | MAE: 955 | Bias: 118.6
#   > [VAL]   R2: 0.9314 | RMSE: 2654 | MAE: 1291 | Bias: 158.9
#
# [C2|F5] Processing fold...
#   > [TRAIN] R2: 0.9596 | RMSE: 1955 | MAE: 1024 | Bias: 124.4
#   > [VAL]   R2: 0.9512 | RMSE: 2167 | MAE: 1256 | Bias: 115.6
#
# [C2|F6] Processing fold...
#   > [TRAIN] R2: 0.9637 | RMSE: 1853 | MAE: 970 | Bias: 119.5
#   > [VAL]   R2: 0.9456 | RMSE: 2290 | MAE: 1243 | Bias: 142.3
#
# [C2|F7] Processing fold...
#   > [TRAIN] R2: 0.9595 | RMSE: 1960 | MAE: 994 | Bias: 131.8
#   > [VAL]   R2: 0.9554 | RMSE: 2053 | MAE: 1233 | Bias: 153.6
#
# [C2|F8] Processing fold...
#   > [TRAIN] R2: 0.9605 | RMSE: 1941 | MAE: 1011 | Bias: 126.0
#   > [VAL]   R2: 0.9554 | RMSE: 2006 | MAE: 1215 | Bias: 99.9
#
# Config 2 SUMMARY:
#   [TRAIN AVG] MAE: 990.0 | R2: 0.9615 | Bias: 125.1
#   [VAL AVG]   MAE: 1251.8 | R2: 0.9488 | Bias: 126.1 | RMSE: 2198.7
#
# ######## CONFIG 3/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 3.0}
#
# [C3|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9659 | RMSE: 1804 | MAE: 1085 | Bias: 7.1
#   > [VAL]   R2: 0.9579 | RMSE: 1951 | MAE: 1263 | Bias: -50.3
#
# [C3|F2] Processing fold...
#   > [TRAIN] R2: 0.9719 | RMSE: 1634 | MAE: 1056 | Bias: 1.6
#   > [VAL]   R2: 0.9523 | RMSE: 2116 | MAE: 1282 | Bias: -7.0
#
# [C3|F3] Processing fold...
#   > [TRAIN] R2: 0.9714 | RMSE: 1648 | MAE: 1032 | Bias: 3.3
#   > [VAL]   R2: 0.9523 | RMSE: 2116 | MAE: 1273 | Bias: 32.2
#
# [C3|F4] Processing fold...
#   > [TRAIN] R2: 0.9721 | RMSE: 1616 | MAE: 1067 | Bias: 0.1
#   > [VAL]   R2: 0.9327 | RMSE: 2630 | MAE: 1322 | Bias: 34.0
#
# [C3|F5] Processing fold...
#   > [TRAIN] R2: 0.9732 | RMSE: 1592 | MAE: 1021 | Bias: -4.9
#   > [VAL]   R2: 0.9552 | RMSE: 2077 | MAE: 1272 | Bias: 0.2
#
# [C3|F6] Processing fold...
#   > [TRAIN] R2: 0.9698 | RMSE: 1690 | MAE: 1075 | Bias: 0.1
#   > [VAL]   R2: 0.9547 | RMSE: 2090 | MAE: 1264 | Bias: 3.7
#
# [C3|F7] Processing fold...
#   > [TRAIN] R2: 0.9749 | RMSE: 1544 | MAE: 996 | Bias: 2.3
#   > [VAL]   R2: 0.9575 | RMSE: 2004 | MAE: 1227 | Bias: 18.8
#
# [C3|F8] Processing fold...
#   > [TRAIN] R2: 0.9708 | RMSE: 1670 | MAE: 1077 | Bias: 1.2
#   > [VAL]   R2: 0.9553 | RMSE: 2008 | MAE: 1240 | Bias: -16.5
#
# Config 3 SUMMARY:
#   [TRAIN AVG] MAE: 1051.1 | R2: 0.9712 | Bias: 1.3
#   [VAL AVG]   MAE: 1267.7 | R2: 0.9522 | Bias: 1.9 | RMSE: 2124.0
# [NEW BEST RMSE] Config 3
#
# ######## CONFIG 4/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 600, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 3.0}
#
# [C4|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9617 | RMSE: 1911 | MAE: 1154 | Bias: 7.0
#   > [VAL]   R2: 0.9561 | RMSE: 1994 | MAE: 1291 | Bias: -41.9
#
# [C4|F2] Processing fold...
#   > [TRAIN] R2: 0.9674 | RMSE: 1758 | MAE: 1123 | Bias: 0.2
#   > [VAL]   R2: 0.9514 | RMSE: 2135 | MAE: 1304 | Bias: -18.3
#
# [C4|F3] Processing fold...
#   > [TRAIN] R2: 0.9676 | RMSE: 1753 | MAE: 1101 | Bias: 3.0
#   > [VAL]   R2: 0.9517 | RMSE: 2130 | MAE: 1291 | Bias: 30.5
#
# [C4|F4] Processing fold...
#   > [TRAIN] R2: 0.9700 | RMSE: 1676 | MAE: 1105 | Bias: -0.1
#   > [VAL]   R2: 0.9325 | RMSE: 2632 | MAE: 1328 | Bias: 29.7
#
# [C4|F5] Processing fold...
#   > [TRAIN] R2: 0.9721 | RMSE: 1625 | MAE: 1046 | Bias: -4.6
#   > [VAL]   R2: 0.9564 | RMSE: 2049 | MAE: 1268 | Bias: -15.5
#
# [C4|F6] Processing fold...
#   > [TRAIN] R2: 0.9708 | RMSE: 1663 | MAE: 1061 | Bias: 0.4
#   > [VAL]   R2: 0.9558 | RMSE: 2064 | MAE: 1260 | Bias: 11.3
#
# [C4|F7] Processing fold...
#   > [TRAIN] R2: 0.9704 | RMSE: 1675 | MAE: 1074 | Bias: 2.0
#   > [VAL]   R2: 0.9576 | RMSE: 2002 | MAE: 1243 | Bias: 30.3
#
# [C4|F8] Processing fold...
#   > [TRAIN] R2: 0.9674 | RMSE: 1765 | MAE: 1128 | Bias: 1.9
#   > [VAL]   R2: 0.9552 | RMSE: 2010 | MAE: 1249 | Bias: -17.5
#
# Config 4 SUMMARY:
#   [TRAIN AVG] MAE: 1099.0 | R2: 0.9684 | Bias: 1.2
#   [VAL AVG]   MAE: 1279.4 | R2: 0.9521 | Bias: 1.1 | RMSE: 2127.0
#
# ######## CONFIG 5/15 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 255, 'max_iter': 1200, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 1.0}
#
# [C5|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9708 | RMSE: 1669 | MAE: 1010 | Bias: 6.5
#   > [VAL]   R2: 0.9573 | RMSE: 1966 | MAE: 1259 | Bias: -47.2
#
# [C5|F2] Processing fold...
#   > [TRAIN] R2: 0.9762 | RMSE: 1502 | MAE: 979 | Bias: 2.2
#   > [VAL]   R2: 0.9521 | RMSE: 2120 | MAE: 1276 | Bias: -2.1
#
# [C5|F3] Processing fold...
#   > [TRAIN] R2: 0.9742 | RMSE: 1565 | MAE: 990 | Bias: 2.5
#   > [VAL]   R2: 0.9523 | RMSE: 2116 | MAE: 1279 | Bias: 29.8
#
# [C5|F4] Processing fold...
#   > [TRAIN] R2: 0.9787 | RMSE: 1413 | MAE: 943 | Bias: 0.3
#   > [VAL]   R2: 0.9333 | RMSE: 2617 | MAE: 1295 | Bias: 33.0
#
# [C5|F5] Processing fold...
#   > [TRAIN] R2: 0.9794 | RMSE: 1395 | MAE: 907 | Bias: -4.5
#   > [VAL]   R2: 0.9573 | RMSE: 2027 | MAE: 1255 | Bias: -9.9
#
# [C5|F6] Processing fold...
#   > [TRAIN] R2: 0.9746 | RMSE: 1549 | MAE: 1006 | Bias: -0.1
#   > [VAL]   R2: 0.9569 | RMSE: 2038 | MAE: 1256 | Bias: 12.0
#
# [C5|F7] Processing fold...
#   > [TRAIN] R2: 0.9757 | RMSE: 1518 | MAE: 985 | Bias: 2.5
#   > [VAL]   R2: 0.9569 | RMSE: 2019 | MAE: 1237 | Bias: 35.5
#
# [C5|F8] Processing fold...
#   > [TRAIN] R2: 0.9749 | RMSE: 1548 | MAE: 1012 | Bias: 2.7
#   > [VAL]   R2: 0.9553 | RMSE: 2007 | MAE: 1227 | Bias: -16.5
#
# Config 5 SUMMARY:
#   [TRAIN AVG] MAE: 979.0 | R2: 0.9756 | Bias: 1.5
#   [VAL AVG]   MAE: 1260.3 | R2: 0.9527 | Bias: 4.3 | RMSE: 2113.9
# [NEW BEST RMSE] Config 5
#
# ######## CONFIG 6/15 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C6|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9642 | RMSE: 1849 | MAE: 1138 | Bias: 5.9
#   > [VAL]   R2: 0.9572 | RMSE: 1968 | MAE: 1287 | Bias: -38.5
#
# [C6|F2] Processing fold...
#   > [TRAIN] R2: 0.9755 | RMSE: 1525 | MAE: 994 | Bias: 1.2
#   > [VAL]   R2: 0.9535 | RMSE: 2088 | MAE: 1274 | Bias: -9.0
#
# [C6|F3] Processing fold...
#   > [TRAIN] R2: 0.9696 | RMSE: 1698 | MAE: 1079 | Bias: 2.5
#   > [VAL]   R2: 0.9540 | RMSE: 2079 | MAE: 1287 | Bias: 31.1
#
# [C6|F4] Processing fold...
#   > [TRAIN] R2: 0.9736 | RMSE: 1574 | MAE: 1057 | Bias: -0.1
#   > [VAL]   R2: 0.9326 | RMSE: 2631 | MAE: 1311 | Bias: 27.1
#
# [C6|F5] Processing fold...
#   > [TRAIN] R2: 0.9767 | RMSE: 1485 | MAE: 972 | Bias: -5.4
#   > [VAL]   R2: 0.9569 | RMSE: 2036 | MAE: 1252 | Bias: -16.6
#
# [C6|F6] Processing fold...
#   > [TRAIN] R2: 0.9715 | RMSE: 1642 | MAE: 1068 | Bias: -0.3
#   > [VAL]   R2: 0.9579 | RMSE: 2015 | MAE: 1256 | Bias: 15.7
#
# [C6|F7] Processing fold...
#   > [TRAIN] R2: 0.9757 | RMSE: 1517 | MAE: 986 | Bias: 2.5
#   > [VAL]   R2: 0.9578 | RMSE: 1999 | MAE: 1230 | Bias: 27.4
#
# [C6|F8] Processing fold...
#   > [TRAIN] R2: 0.9739 | RMSE: 1579 | MAE: 1032 | Bias: 2.7
#   > [VAL]   R2: 0.9558 | RMSE: 1997 | MAE: 1229 | Bias: -21.4
#
# Config 6 SUMMARY:
#   [TRAIN AVG] MAE: 1040.7 | R2: 0.9726 | Bias: 1.1
#   [VAL AVG]   MAE: 1265.8 | R2: 0.9532 | Bias: 2.0 | RMSE: 2101.7
# [NEW BEST RMSE] Config 6
#
# ######## CONFIG 7/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 3.0}
#
# [C7|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9646 | RMSE: 1838 | MAE: 1111 | Bias: 6.3
#   > [VAL]   R2: 0.9579 | RMSE: 1951 | MAE: 1270 | Bias: -45.9
#
# [C7|F2] Processing fold...
#   > [TRAIN] R2: 0.9726 | RMSE: 1614 | MAE: 1044 | Bias: 0.9
#   > [VAL]   R2: 0.9523 | RMSE: 2116 | MAE: 1288 | Bias: -10.6
#
# [C7|F3] Processing fold...
#   > [TRAIN] R2: 0.9668 | RMSE: 1776 | MAE: 1121 | Bias: 4.0
#   > [VAL]   R2: 0.9505 | RMSE: 2156 | MAE: 1307 | Bias: 32.5
#
# [C7|F4] Processing fold...
#   > [TRAIN] R2: 0.9715 | RMSE: 1634 | MAE: 1090 | Bias: -0.7
#   > [VAL]   R2: 0.9335 | RMSE: 2613 | MAE: 1324 | Bias: 35.5
#
# [C7|F5] Processing fold...
#   > [TRAIN] R2: 0.9719 | RMSE: 1631 | MAE: 1055 | Bias: -4.4
#   > [VAL]   R2: 0.9563 | RMSE: 2049 | MAE: 1269 | Bias: -10.4
#
# [C7|F6] Processing fold...
#   > [TRAIN] R2: 0.9704 | RMSE: 1673 | MAE: 1073 | Bias: 0.5
#   > [VAL]   R2: 0.9556 | RMSE: 2069 | MAE: 1262 | Bias: 13.8
#
# [C7|F7] Processing fold...
#   > [TRAIN] R2: 0.9744 | RMSE: 1559 | MAE: 1008 | Bias: 2.5
#   > [VAL]   R2: 0.9575 | RMSE: 2005 | MAE: 1233 | Bias: 29.2
#
# [C7|F8] Processing fold...
#   > [TRAIN] R2: 0.9715 | RMSE: 1649 | MAE: 1069 | Bias: 2.3
#   > [VAL]   R2: 0.9560 | RMSE: 1991 | MAE: 1235 | Bias: -14.7
#
# Config 7 SUMMARY:
#   [TRAIN AVG] MAE: 1071.5 | R2: 0.9705 | Bias: 1.4
#   [VAL AVG]   MAE: 1273.3 | R2: 0.9525 | Bias: 3.7 | RMSE: 2118.9
#
# ######## CONFIG 8/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 800, 'max_depth': None, 'loss': 'absolute_error', 'learning_rate': 0.07, 'l2_regularization': 0.3}
#
# [C8|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9555 | RMSE: 2061 | MAE: 1091 | Bias: 133.0
#   > [VAL]   R2: 0.9563 | RMSE: 1989 | MAE: 1263 | Bias: 90.7
#
# [C8|F2] Processing fold...
#   > [TRAIN] R2: 0.9575 | RMSE: 2009 | MAE: 1088 | Bias: 132.2
#   > [VAL]   R2: 0.9517 | RMSE: 2129 | MAE: 1276 | Bias: 108.2
#
# [C8|F3] Processing fold...
#   > [TRAIN] R2: 0.9571 | RMSE: 2017 | MAE: 1089 | Bias: 130.9
#   > [VAL]   R2: 0.9414 | RMSE: 2345 | MAE: 1290 | Bias: 166.8
#
# [C8|F4] Processing fold...
#   > [TRAIN] R2: 0.9596 | RMSE: 1945 | MAE: 1089 | Bias: 128.4
#   > [VAL]   R2: 0.9298 | RMSE: 2685 | MAE: 1315 | Bias: 165.4
#
# [C8|F5] Processing fold...
#   > [TRAIN] R2: 0.9569 | RMSE: 2019 | MAE: 1098 | Bias: 124.3
#   > [VAL]   R2: 0.9497 | RMSE: 2200 | MAE: 1279 | Bias: 108.6
#
# [C8|F6] Processing fold...
#   > [TRAIN] R2: 0.9583 | RMSE: 1987 | MAE: 1090 | Bias: 130.1
#   > [VAL]   R2: 0.9432 | RMSE: 2340 | MAE: 1277 | Bias: 153.8
#
# [C8|F7] Processing fold...
#   > [TRAIN] R2: 0.9553 | RMSE: 2059 | MAE: 1105 | Bias: 138.7
#   > [VAL]   R2: 0.9536 | RMSE: 2095 | MAE: 1258 | Bias: 160.3
#
# [C8|F8] Processing fold...
#   > [TRAIN] R2: 0.9569 | RMSE: 2029 | MAE: 1089 | Bias: 130.4
#   > [VAL]   R2: 0.9541 | RMSE: 2034 | MAE: 1237 | Bias: 99.1
#
# Config 8 SUMMARY:
#   [TRAIN AVG] MAE: 1092.4 | R2: 0.9571 | Bias: 131.0
#   [VAL AVG]   MAE: 1274.2 | R2: 0.9475 | Bias: 131.6 | RMSE: 2227.1
#
# ######## CONFIG 9/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 3.0}
#
# [C9|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9681 | RMSE: 1745 | MAE: 1048 | Bias: 6.8
#   > [VAL]   R2: 0.9582 | RMSE: 1945 | MAE: 1258 | Bias: -43.8
#
# [C9|F2] Processing fold...
#   > [TRAIN] R2: 0.9723 | RMSE: 1623 | MAE: 1054 | Bias: 0.8
#   > [VAL]   R2: 0.9519 | RMSE: 2124 | MAE: 1282 | Bias: -6.3
#
# [C9|F3] Processing fold...
#   > [TRAIN] R2: 0.9650 | RMSE: 1823 | MAE: 1154 | Bias: 3.0
#   > [VAL]   R2: 0.9486 | RMSE: 2197 | MAE: 1323 | Bias: 35.3
#
# [C9|F4] Processing fold...
#   > [TRAIN] R2: 0.9721 | RMSE: 1615 | MAE: 1078 | Bias: 0.1
#   > [VAL]   R2: 0.9351 | RMSE: 2581 | MAE: 1315 | Bias: 34.6
#
# [C9|F5] Processing fold...
#   > [TRAIN] R2: 0.9765 | RMSE: 1490 | MAE: 965 | Bias: -4.5
#   > [VAL]   R2: 0.9570 | RMSE: 2034 | MAE: 1252 | Bias: -3.0
#
# [C9|F6] Processing fold...
#   > [TRAIN] R2: 0.9731 | RMSE: 1594 | MAE: 1023 | Bias: -0.1
#   > [VAL]   R2: 0.9571 | RMSE: 2034 | MAE: 1249 | Bias: 5.1
#
# [C9|F7] Processing fold...
#   > [TRAIN] R2: 0.9706 | RMSE: 1671 | MAE: 1076 | Bias: 2.4
#   > [VAL]   R2: 0.9573 | RMSE: 2009 | MAE: 1248 | Bias: 27.6
#
# [C9|F8] Processing fold...
#   > [TRAIN] R2: 0.9700 | RMSE: 1692 | MAE: 1093 | Bias: 2.2
#   > [VAL]   R2: 0.9555 | RMSE: 2004 | MAE: 1241 | Bias: -19.9
#
# Config 9 SUMMARY:
#   [TRAIN AVG] MAE: 1061.3 | R2: 0.9710 | Bias: 1.3
#   [VAL AVG]   MAE: 1270.9 | R2: 0.9526 | Bias: 3.7 | RMSE: 2116.0
#
# ######## CONFIG 10/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': 20, 'loss': 'absolute_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}
#
# [C10|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9575 | RMSE: 2014 | MAE: 1030 | Bias: 127.4
#   > [VAL]   R2: 0.9560 | RMSE: 1997 | MAE: 1253 | Bias: 82.2
#
# [C10|F2] Processing fold...
#   > [TRAIN] R2: 0.9619 | RMSE: 1901 | MAE: 980 | Bias: 123.7
#   > [VAL]   R2: 0.9530 | RMSE: 2100 | MAE: 1253 | Bias: 102.5
#
# [C10|F3] Processing fold...
#   > [TRAIN] R2: 0.9615 | RMSE: 1913 | MAE: 985 | Bias: 122.7
#   > [VAL]   R2: 0.9425 | RMSE: 2324 | MAE: 1265 | Bias: 156.8
#
# [C10|F4] Processing fold...
#   > [TRAIN] R2: 0.9648 | RMSE: 1815 | MAE: 962 | Bias: 117.6
#   > [VAL]   R2: 0.9316 | RMSE: 2650 | MAE: 1277 | Bias: 161.8
#
# [C10|F5] Processing fold...
#   > [TRAIN] R2: 0.9621 | RMSE: 1895 | MAE: 981 | Bias: 118.2
#   > [VAL]   R2: 0.9525 | RMSE: 2137 | MAE: 1246 | Bias: 102.6
#
# [C10|F6] Processing fold...
#   > [TRAIN] R2: 0.9606 | RMSE: 1931 | MAE: 1020 | Bias: 123.7
#   > [VAL]   R2: 0.9444 | RMSE: 2315 | MAE: 1249 | Bias: 145.5
#
# [C10|F7] Processing fold...
#   > [TRAIN] R2: 0.9583 | RMSE: 1989 | MAE: 1018 | Bias: 133.5
#   > [VAL]   R2: 0.9540 | RMSE: 2085 | MAE: 1239 | Bias: 156.9
#
# [C10|F8] Processing fold...
#   > [TRAIN] R2: 0.9625 | RMSE: 1893 | MAE: 966 | Bias: 119.4
#   > [VAL]   R2: 0.9560 | RMSE: 1992 | MAE: 1206 | Bias: 100.7
#
# Config 10 SUMMARY:
#   [TRAIN AVG] MAE: 992.9 | R2: 0.9611 | Bias: 123.3
#   [VAL AVG]   MAE: 1248.4 | R2: 0.9488 | Bias: 126.1 | RMSE: 2199.9
#
# ######## CONFIG 11/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': None, 'loss': 'absolute_error', 'learning_rate': 0.1, 'l2_regularization': 3.0}
#
# [C11|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9600 | RMSE: 1953 | MAE: 992 | Bias: 126.3
#   > [VAL]   R2: 0.9574 | RMSE: 1963 | MAE: 1239 | Bias: 84.9
#
# [C11|F2] Processing fold...
#   > [TRAIN] R2: 0.9630 | RMSE: 1874 | MAE: 945 | Bias: 119.9
#   > [VAL]   R2: 0.9538 | RMSE: 2083 | MAE: 1245 | Bias: 98.3
#
# [C11|F3] Processing fold...
#   > [TRAIN] R2: 0.9643 | RMSE: 1841 | MAE: 917 | Bias: 116.7
#   > [VAL]   R2: 0.9422 | RMSE: 2331 | MAE: 1254 | Bias: 155.4
#
# [C11|F4] Processing fold...
#   > [TRAIN] R2: 0.9638 | RMSE: 1842 | MAE: 977 | Bias: 123.6
#   > [VAL]   R2: 0.9309 | RMSE: 2664 | MAE: 1287 | Bias: 159.4
#
# [C11|F5] Processing fold...
#   > [TRAIN] R2: 0.9641 | RMSE: 1844 | MAE: 936 | Bias: 110.0
#   > [VAL]   R2: 0.9518 | RMSE: 2153 | MAE: 1245 | Bias: 102.0
#
# [C11|F6] Processing fold...
#   > [TRAIN] R2: 0.9625 | RMSE: 1883 | MAE: 972 | Bias: 119.6
#   > [VAL]   R2: 0.9457 | RMSE: 2287 | MAE: 1246 | Bias: 148.9
#
# [C11|F7] Processing fold...
#   > [TRAIN] R2: 0.9570 | RMSE: 2020 | MAE: 1043 | Bias: 133.6
#   > [VAL]   R2: 0.9544 | RMSE: 2078 | MAE: 1239 | Bias: 149.2
#
# [C11|F8] Processing fold...
#   > [TRAIN] R2: 0.9620 | RMSE: 1905 | MAE: 968 | Bias: 119.7
#   > [VAL]   R2: 0.9550 | RMSE: 2016 | MAE: 1221 | Bias: 88.2
#
# Config 11 SUMMARY:
#   [TRAIN AVG] MAE: 968.6 | R2: 0.9621 | Bias: 121.2
#   [VAL AVG]   MAE: 1247.0 | R2: 0.9489 | Bias: 123.3 | RMSE: 2197.0
#
# ######## CONFIG 12/15 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 127, 'max_iter': 1200, 'max_depth': 20, 'loss': 'absolute_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C12|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9583 | RMSE: 1996 | MAE: 1058 | Bias: 129.0
#   > [VAL]   R2: 0.9553 | RMSE: 2011 | MAE: 1271 | Bias: 82.4
#
# [C12|F2] Processing fold...
#   > [TRAIN] R2: 0.9584 | RMSE: 1987 | MAE: 1061 | Bias: 132.4
#   > [VAL]   R2: 0.9526 | RMSE: 2109 | MAE: 1268 | Bias: 113.7
#
# [C12|F3] Processing fold...
#   > [TRAIN] R2: 0.9626 | RMSE: 1883 | MAE: 984 | Bias: 122.4
#   > [VAL]   R2: 0.9424 | RMSE: 2325 | MAE: 1274 | Bias: 157.2
#
# [C12|F4] Processing fold...
#   > [TRAIN] R2: 0.9640 | RMSE: 1836 | MAE: 998 | Bias: 121.6
#   > [VAL]   R2: 0.9305 | RMSE: 2672 | MAE: 1296 | Bias: 163.2
#
# [C12|F5] Processing fold...
#   > [TRAIN] R2: 0.9624 | RMSE: 1886 | MAE: 1009 | Bias: 119.1
#   > [VAL]   R2: 0.9499 | RMSE: 2196 | MAE: 1269 | Bias: 103.8
#
# [C12|F6] Processing fold...
#   > [TRAIN] R2: 0.9621 | RMSE: 1892 | MAE: 1018 | Bias: 125.1
#   > [VAL]   R2: 0.9459 | RMSE: 2284 | MAE: 1254 | Bias: 148.5
#
# [C12|F7] Processing fold...
#   > [TRAIN] R2: 0.9596 | RMSE: 1958 | MAE: 1046 | Bias: 134.6
#   > [VAL]   R2: 0.9553 | RMSE: 2057 | MAE: 1242 | Bias: 156.8
#
# [C12|F8] Processing fold...
#   > [TRAIN] R2: 0.9620 | RMSE: 1904 | MAE: 1010 | Bias: 123.6
#   > [VAL]   R2: 0.9552 | RMSE: 2011 | MAE: 1223 | Bias: 96.6
#
# Config 12 SUMMARY:
#   [TRAIN AVG] MAE: 1022.9 | R2: 0.9612 | Bias: 126.0
#   [VAL AVG]   MAE: 1262.0 | R2: 0.9484 | Bias: 127.8 | RMSE: 2208.0
#
# ######## CONFIG 13/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 63, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C13|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9617 | RMSE: 1911 | MAE: 1165 | Bias: 5.0
#   > [VAL]   R2: 0.9576 | RMSE: 1960 | MAE: 1286 | Bias: -43.7
#
# [C13|F2] Processing fold...
#   > [TRAIN] R2: 0.9675 | RMSE: 1756 | MAE: 1138 | Bias: 0.0
#   > [VAL]   R2: 0.9496 | RMSE: 2175 | MAE: 1317 | Bias: -20.2
#
# [C13|F3] Processing fold...
#   > [TRAIN] R2: 0.9691 | RMSE: 1711 | MAE: 1085 | Bias: 2.6
#   > [VAL]   R2: 0.9543 | RMSE: 2071 | MAE: 1285 | Bias: 36.6
#
# [C13|F4] Processing fold...
#   > [TRAIN] R2: 0.9686 | RMSE: 1715 | MAE: 1142 | Bias: -1.2
#   > [VAL]   R2: 0.9335 | RMSE: 2613 | MAE: 1337 | Bias: 26.6
#
# [C13|F5] Processing fold...
#   > [TRAIN] R2: 0.9705 | RMSE: 1670 | MAE: 1087 | Bias: -4.9
#   > [VAL]   R2: 0.9560 | RMSE: 2058 | MAE: 1280 | Bias: -9.0
#
# [C13|F6] Processing fold...
#   > [TRAIN] R2: 0.9669 | RMSE: 1769 | MAE: 1139 | Bias: 0.8
#   > [VAL]   R2: 0.9562 | RMSE: 2055 | MAE: 1279 | Bias: 16.4
#
# [C13|F7] Processing fold...
#   > [TRAIN] R2: 0.9649 | RMSE: 1825 | MAE: 1178 | Bias: 3.2
#   > [VAL]   R2: 0.9562 | RMSE: 2035 | MAE: 1285 | Bias: 30.0
#
# [C13|F8] Processing fold...
#   > [TRAIN] R2: 0.9671 | RMSE: 1772 | MAE: 1152 | Bias: 2.3
#   > [VAL]   R2: 0.9547 | RMSE: 2023 | MAE: 1268 | Bias: -16.5
#
# Config 13 SUMMARY:
#   [TRAIN AVG] MAE: 1135.8 | R2: 0.9671 | Bias: 1.0
#   [VAL AVG]   MAE: 1292.2 | R2: 0.9523 | Bias: 2.5 | RMSE: 2123.8
#
# ######## CONFIG 14/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 20, 'loss': 'absolute_error', 'learning_rate': 0.085, 'l2_regularization': 1.0}
#
# [C14|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9583 | RMSE: 1996 | MAE: 1012 | Bias: 127.4
#   > [VAL]   R2: 0.9575 | RMSE: 1962 | MAE: 1241 | Bias: 74.0
#
# [C14|F2] Processing fold...
#   > [TRAIN] R2: 0.9600 | RMSE: 1948 | MAE: 997 | Bias: 123.5
#   > [VAL]   R2: 0.9509 | RMSE: 2146 | MAE: 1262 | Bias: 104.2
#
# [C14|F3] Processing fold...
#   > [TRAIN] R2: 0.9605 | RMSE: 1937 | MAE: 1002 | Bias: 124.7
#   > [VAL]   R2: 0.9415 | RMSE: 2345 | MAE: 1266 | Bias: 161.6
#
# [C14|F4] Processing fold...
#   > [TRAIN] R2: 0.9627 | RMSE: 1869 | MAE: 1006 | Bias: 122.7
#   > [VAL]   R2: 0.9322 | RMSE: 2639 | MAE: 1289 | Bias: 162.8
#
# [C14|F5] Processing fold...
#   > [TRAIN] R2: 0.9621 | RMSE: 1895 | MAE: 975 | Bias: 109.6
#   > [VAL]   R2: 0.9509 | RMSE: 2173 | MAE: 1247 | Bias: 99.0
#
# [C14|F6] Processing fold...
#   > [TRAIN] R2: 0.9601 | RMSE: 1943 | MAE: 1023 | Bias: 123.6
#   > [VAL]   R2: 0.9450 | RMSE: 2303 | MAE: 1255 | Bias: 152.4
#
# [C14|F7] Processing fold...
#   > [TRAIN] R2: 0.9556 | RMSE: 2053 | MAE: 1058 | Bias: 136.6
#   > [VAL]   R2: 0.9516 | RMSE: 2140 | MAE: 1248 | Bias: 165.2
#
# [C14|F8] Processing fold...
#   > [TRAIN] R2: 0.9592 | RMSE: 1974 | MAE: 1018 | Bias: 123.4
#   > [VAL]   R2: 0.9543 | RMSE: 2032 | MAE: 1228 | Bias: 94.1
#
# Config 14 SUMMARY:
#   [TRAIN AVG] MAE: 1011.3 | R2: 0.9598 | Bias: 123.9
#   [VAL AVG]   MAE: 1254.5 | R2: 0.9480 | Bias: 126.7 | RMSE: 2217.7
#
# ######## CONFIG 15/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 600, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 0.3}
#
# [C15|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9622 | RMSE: 1899 | MAE: 1166 | Bias: 5.3
#   > [VAL]   R2: 0.9572 | RMSE: 1969 | MAE: 1294 | Bias: -38.0
#
# [C15|F2] Processing fold...
#   > [TRAIN] R2: 0.9598 | RMSE: 1953 | MAE: 1268 | Bias: 1.6
#   > [VAL]   R2: 0.9474 | RMSE: 2221 | MAE: 1385 | Bias: -20.8
#
# [C15|F3] Processing fold...
#   > [TRAIN] R2: 0.9648 | RMSE: 1829 | MAE: 1164 | Bias: 2.6
#   > [VAL]   R2: 0.9511 | RMSE: 2144 | MAE: 1320 | Bias: 33.1
#
# [C15|F4] Processing fold...
#   > [TRAIN] R2: 0.9721 | RMSE: 1616 | MAE: 1082 | Bias: -0.8
#   > [VAL]   R2: 0.9352 | RMSE: 2579 | MAE: 1313 | Bias: 22.5
#
# [C15|F5] Processing fold...
#   > [TRAIN] R2: 0.9702 | RMSE: 1678 | MAE: 1094 | Bias: -5.7
#   > [VAL]   R2: 0.9564 | RMSE: 2047 | MAE: 1275 | Bias: -11.5
#
# [C15|F6] Processing fold...
#   > [TRAIN] R2: 0.9693 | RMSE: 1704 | MAE: 1103 | Bias: 0.4
#   > [VAL]   R2: 0.9570 | RMSE: 2036 | MAE: 1268 | Bias: 9.9
#
# [C15|F7] Processing fold...
#   > [TRAIN] R2: 0.9701 | RMSE: 1685 | MAE: 1093 | Bias: 2.9
#   > [VAL]   R2: 0.9576 | RMSE: 2003 | MAE: 1247 | Bias: 34.0
#
# [C15|F8] Processing fold...
#   > [TRAIN] R2: 0.9700 | RMSE: 1693 | MAE: 1105 | Bias: 2.4
#   > [VAL]   R2: 0.9556 | RMSE: 2002 | MAE: 1248 | Bias: -15.8
#
# Config 15 SUMMARY:
#   [TRAIN AVG] MAE: 1134.4 | R2: 0.9673 | Bias: 1.1
#   [VAL AVG]   MAE: 1293.6 | R2: 0.9522 | Bias: 1.7 | RMSE: 2125.0
# # END OF SEARCH
#
# Top 5 Configurations by RMSE:
#     config_id  learning_rate  max_iter     val_rmse      val_mae    val_r2  \
# 5           6          0.100       800  2101.688269  1265.756682  0.953208
# 4           5          0.115      1200  2113.885366  1260.268582  0.952684
# 8           9          0.100       800  2116.038670  1270.936643  0.952595
# 6           7          0.115      1000  2118.870711  1273.344326  0.952468
# 12         13          0.100      1000  2123.789002  1292.161495  0.952252
#
#     train_r2  val_bias
# 5   0.972580  1.986830
# 4   0.975571  4.319300
# 8   0.970960  3.702756
# 6   0.970458  3.680613
# 12  0.967054  2.509011
# Best Config found:
# {'min_samples_leaf': 12, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}

# %%
import os
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, ParameterSampler
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, median_absolute_error

# we will use an 8-fold cross-validation strategy
N_SPLITS = 8

# shuffles the data, in order to (at least theoretically) have more balanced folds
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# we explicitly exclude this feature from the model input
DROP_FROM_MODEL = ["previousOwners"]

# keep 80% of features after encoding (feature selection step)
FS_KEEP_RATIO = 0.80

# RandomForest used only for feature selection (importance-based)
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

# hyperparameter space that we are going to use for random search
# each configuration will get 1 value from each of these lists
param_distributions = {
    "loss": ["squared_error"],
    "learning_rate": [0.07, 0.085, 0.1, 0.115],
    "max_iter": [600, 800, 1000, 1200],
    "max_leaf_nodes": [63, 127, 191, 255],
    "l2_regularization": [0.3, 1.0, 3.0],
    "min_samples_leaf": [12, 16, 20, 28],
    "max_depth": [15, 20, 25, None],
}

N_RANDOM_CONFIGS = 15  

# we get N_RANDOM_CONFIGS random parameter combinations from param_distributions
sampler = ParameterSampler(param_distributions, n_iter=N_RANDOM_CONFIGS, random_state=RANDOM_STATE)

search_results = []  # stores results for ranking

# tracking the best configuration according to validation RMSE
best_rmse = np.inf
best_config = None

# log setup (mainly for development and traceability)
log_dir = "gb_logs"
os.makedirs(log_dir, exist_ok=True)
log_filename = "2gb_noowners_fs80_log.txt"
log_path = os.path.join(log_dir, log_filename)

# Note: this section is included mainly for organizational purposes
with open(log_path, "w", encoding="utf-8") as log_file:

    # prints to screen and writes to the log file
    def log(msg: str):
        print(msg)
        log_file.write(msg + "\n")
        log_file.flush()

    # header for the log file
    log("# =============================")
    log("# START OF HGB SEARCH WITH FEATURE SELECTION (KEEP 80%)")
    log("# METRICS: R2, RMSE, MAE, BIAS")
    log(f"# LOG FILE SAVED TO: {log_path}")
    log("# =============================")

    # loop over random configurations
    for config_id, params in enumerate(sampler, start=1):
        log("")
        log(f"######## CONFIG {config_id}/{N_RANDOM_CONFIGS} ########")
        log(f"Parameters: {params}")

        # store metrics for each fold
        fold_rmses_val, fold_maes_val, fold_r2s_val, fold_bias_val = [], [], [], []
        fold_rmses_tr,  fold_maes_tr,  fold_r2s_tr,  fold_bias_tr  = [], [], [], []
        fold_med_ae = []
        fold_nsel = []

        # K-Fold cross-validation for this configuration
        for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):

            # data split for the current fold
            X_train, X_val = X.iloc[train_idx].copy(), X.iloc[val_idx].copy()
            y_train, y_val = y.iloc[train_idx].copy(), y.iloc[val_idx].copy()

            log(f"\n[C{config_id}|F{fold}] Processing fold...")

            # -> Preprocessing steps
            # fit is only done on the training fold, then applied to both train and validation
            year_state = fit_year_median(X_train, year_col="year", model_col="model")
            X_train = transform_year_with_model_median(X_train, state=year_state)
            X_val   = transform_year_with_model_median(X_val,   state=year_state)

            engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
            X_train = transform_engine_size_imputer(X_train, state=engine_state)
            X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

            X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
            X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

            mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
            X_train = transform_mpg_imputer(X_train, state=mpg_state)
            X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

            brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
            X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
            X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

            model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
            X_train, _, _ = transform_invalid_models(X_train, model_state)
            X_val,   _, _ = transform_invalid_models(X_val,   model_state)

            transm_state = fit_transmission_resolver(X_train, valid_transmissions)
            X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
            X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

            fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
            X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
            X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

            # hard guarantee: previousOwners is not used by the model in this section
            X_train = X_train.drop(columns=DROP_FROM_MODEL, errors="ignore")
            X_val   = X_val.drop(columns=DROP_FROM_MODEL, errors="ignore")

            # -> Feature encoding (categorical only)
            high_card_features = ["Brand", "model"]  # target encoding for these
            low_card_features  = [c for c in categorical_features if c not in high_card_features]

            te = MyTargetEncoder(smoothing=5)
            te.fit(X_train[high_card_features], y_train)  # fit on training fold only
            X_train_high = te.transform(X_train[high_card_features])
            X_val_high   = te.transform(X_val[high_card_features])

            ohe = MyOneHotEncoder()
            ohe.fit(X_train[low_card_features])  # fit on training fold only
            X_train_low = ohe.transform(X_train[low_card_features])
            X_val_low   = ohe.transform(X_val[low_card_features])

            # rejoin encoded categorical features
            X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
            X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

            # join numerical and categorical (encoded) features
            X_train_final = pd.concat([X_train[numeric_features], X_train_cat], axis=1)
            X_val_final   = pd.concat([X_val[numeric_features],   X_val_cat],   axis=1)

            # make sure validation has exactly the same columns as training
            X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

            # log original feature space once per config (fold 1)
            if fold == 1:
                feature_names = list(X_train_final.columns)
                log(f"  > Features before FS ({len(feature_names)}): {feature_names}")

            # -> Feature selection (keep top 80% features by RF importance)
            n_feats = X_train_final.shape[1]
            k = int(np.ceil(FS_KEEP_RATIO * n_feats))
            k = max(1, min(k, n_feats))

            rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
            rf_fs.fit(X_train_final, y_train)

            selector = SelectFromModel(
                estimator=rf_fs,
                threshold=-np.inf,   # keep the top max_features, regardless of absolute importance values
                max_features=k,
                prefit=True
            )

            selected_cols = X_train_final.columns[selector.get_support()]
            fold_nsel.append(len(selected_cols))

            X_train_sel = X_train_final[selected_cols]
            X_val_sel   = X_val_final[selected_cols]

            if fold == 1:
                log(f"  > Selected features ({len(selected_cols)}/{n_feats}) with FS_KEEP_RATIO={FS_KEEP_RATIO:.2f}")

            # -> Model training (HGB on selected features)
            hgb_model = HistGradientBoostingRegressor(random_state=RANDOM_STATE, **params)
            hgb_model.fit(X_train_sel, y_train)

            # predictions
            y_pred_train = hgb_model.predict(X_train_sel)
            y_pred_val   = hgb_model.predict(X_val_sel)

            # -> Metrics calculation
            mae_tr  = mean_absolute_error(y_train, y_pred_train)
            rmse_tr = np.sqrt(mean_squared_error(y_train, y_pred_train))
            r2_tr   = r2_score(y_train, y_pred_train)
            bias_tr = np.mean(y_train - y_pred_train)

            mae_val  = mean_absolute_error(y_val, y_pred_val)
            rmse_val = np.sqrt(mean_squared_error(y_val, y_pred_val))
            r2_val   = r2_score(y_val, y_pred_val)
            bias_val = np.mean(y_val - y_pred_val)

            med_ae_val = median_absolute_error(y_val, y_pred_val)

            log(f"  > [TRAIN] R2: {r2_tr:.4f} | RMSE: {rmse_tr:.0f} | MAE: {mae_tr:.0f} | Bias: {bias_tr:.1f}")
            log(f"  > [VAL]   R2: {r2_val:.4f} | RMSE: {rmse_val:.0f} | MAE: {mae_val:.0f} | Bias: {bias_val:.1f}")

            fold_maes_tr.append(mae_tr);   fold_rmses_tr.append(rmse_tr);   fold_r2s_tr.append(r2_tr);   fold_bias_tr.append(bias_tr)
            fold_maes_val.append(mae_val); fold_rmses_val.append(rmse_val); fold_r2s_val.append(r2_val); fold_bias_val.append(bias_val)
            fold_med_ae.append(med_ae_val)

        # mean metrics across folds
        mean_rmse_val = np.mean(fold_rmses_val)
        mean_mae_val  = np.mean(fold_maes_val)
        mean_r2_val   = np.mean(fold_r2s_val)
        mean_bias_val = np.mean(fold_bias_val)

        mean_mae_tr   = np.mean(fold_maes_tr)
        mean_r2_tr    = np.mean(fold_r2s_tr)
        mean_bias_tr  = np.mean(fold_bias_tr)

        mean_nsel = float(np.mean(fold_nsel))

        log("")
        log(f"Config {config_id} SUMMARY:")
        log(f"  Selected features (avg): {mean_nsel:.0f}")
        log(f"  [TRAIN AVG] MAE: {mean_mae_tr:.1f} | R2: {mean_r2_tr:.4f} | Bias: {mean_bias_tr:.1f}")
        log(f"  [VAL AVG]   MAE: {mean_mae_val:.1f} | R2: {mean_r2_val:.4f} | Bias: {mean_bias_val:.1f} | RMSE: {mean_rmse_val:.1f}")

        search_results.append({
            "config_id": config_id,
            **params,

            "fs_keep_ratio": FS_KEEP_RATIO,
            "avg_selected_features": mean_nsel,

            "val_rmse": mean_rmse_val,
            "val_mae": mean_mae_val,
            "val_r2": mean_r2_val,
            "val_bias": mean_bias_val,

            "train_mae": mean_mae_tr,
            "train_r2": mean_r2_tr,
            "train_bias": mean_bias_tr,

            "val_med_ae": np.mean(fold_med_ae)
        })

        # best = lowest validation RMSE
        if mean_rmse_val < best_rmse:
            best_rmse = mean_rmse_val
            best_config = {**params}
            log(f"[NEW BEST RMSE] Config {config_id}")

    log("# END OF SEARCH")

# Results
results_df = pd.DataFrame(search_results)
results_df_sorted = results_df.sort_values(by="val_rmse", ascending=True)

print("\nTop 5 Configurations by RMSE:")
cols = [
    "config_id", "fs_keep_ratio", "avg_selected_features",
    "learning_rate", "max_iter", "max_leaf_nodes", "max_depth",
    "val_rmse", "val_mae", "val_r2", "train_r2", "val_bias"
]
display(results_df_sorted[cols].head(5))

print("\nBest Config found:")
print(best_config)
# Out:
# # =============================
# # START OF HGB SEARCH WITH FEATURE SELECTION (KEEP 80%)
# # METRICS: R2, RMSE, MAE, BIAS
# # LOG FILE SAVED TO: gb_logs/2gb_noowners_fs80_log.txt
# # =============================
#
# ######## CONFIG 1/15 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 255, 'max_iter': 800, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 0.3}
#
# [C1|F1] Processing fold...
#   > Features before FS (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9677 | RMSE: 1756 | MAE: 1081 | Bias: 5.4
#   > [VAL]   R2: 0.9561 | RMSE: 1993 | MAE: 1285 | Bias: -52.6
#
# [C1|F2] Processing fold...
#   > [TRAIN] R2: 0.9734 | RMSE: 1589 | MAE: 1036 | Bias: 1.5
#   > [VAL]   R2: 0.9522 | RMSE: 2119 | MAE: 1283 | Bias: 1.5
#
# [C1|F3] Processing fold...
#   > [TRAIN] R2: 0.9729 | RMSE: 1604 | MAE: 1014 | Bias: 3.0
#   > [VAL]   R2: 0.9521 | RMSE: 2120 | MAE: 1282 | Bias: 27.8
#
# [C1|F4] Processing fold...
#   > [TRAIN] R2: 0.9797 | RMSE: 1379 | MAE: 917 | Bias: 0.8
#   > [VAL]   R2: 0.9336 | RMSE: 2612 | MAE: 1288 | Bias: 35.0
#
# [C1|F5] Processing fold...
#   > [TRAIN] R2: 0.9816 | RMSE: 1318 | MAE: 856 | Bias: -5.3
#   > [VAL]   R2: 0.9567 | RMSE: 2041 | MAE: 1251 | Bias: -17.3
#
# [C1|F6] Processing fold...
#   > [TRAIN] R2: 0.9748 | RMSE: 1543 | MAE: 1001 | Bias: 0.2
#   > [VAL]   R2: 0.9570 | RMSE: 2035 | MAE: 1253 | Bias: 12.1
#
# [C1|F7] Processing fold...
#   > [TRAIN] R2: 0.9777 | RMSE: 1456 | MAE: 945 | Bias: 1.6
#   > [VAL]   R2: 0.9561 | RMSE: 2037 | MAE: 1234 | Bias: 32.2
#
# [C1|F8] Processing fold...
#   > [TRAIN] R2: 0.9770 | RMSE: 1481 | MAE: 971 | Bias: 3.7
#   > [VAL]   R2: 0.9545 | RMSE: 2026 | MAE: 1226 | Bias: -11.8
#
# Config 1 SUMMARY:
#   Selected features (avg): 12
#   [TRAIN AVG] MAE: 977.6 | R2: 0.9756 | Bias: 1.4
#   [VAL AVG]   MAE: 1262.9 | R2: 0.9523 | Bias: 3.4 | RMSE: 2122.8
# [NEW BEST RMSE] Config 1
#
# ######## CONFIG 2/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 255, 'max_iter': 600, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 1.0}
#
# [C2|F1] Processing fold...
#   > Features before FS (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9659 | RMSE: 1804 | MAE: 1087 | Bias: 7.0
#   > [VAL]   R2: 0.9576 | RMSE: 1959 | MAE: 1269 | Bias: -49.0
#
# [C2|F2] Processing fold...
#   > [TRAIN] R2: 0.9692 | RMSE: 1711 | MAE: 1104 | Bias: 1.1
#   > [VAL]   R2: 0.9514 | RMSE: 2135 | MAE: 1301 | Bias: -9.8
#
# [C2|F3] Processing fold...
#   > [TRAIN] R2: 0.9700 | RMSE: 1688 | MAE: 1061 | Bias: 3.8
#   > [VAL]   R2: 0.9513 | RMSE: 2140 | MAE: 1289 | Bias: 36.4
#
# [C2|F4] Processing fold...
#   > [TRAIN] R2: 0.9725 | RMSE: 1606 | MAE: 1063 | Bias: -0.2
#   > [VAL]   R2: 0.9332 | RMSE: 2619 | MAE: 1314 | Bias: 33.9
#
# [C2|F5] Processing fold...
#   > [TRAIN] R2: 0.9771 | RMSE: 1472 | MAE: 955 | Bias: -5.2
#   > [VAL]   R2: 0.9570 | RMSE: 2034 | MAE: 1252 | Bias: -8.4
#
# [C2|F6] Processing fold...
#   > [TRAIN] R2: 0.9656 | RMSE: 1804 | MAE: 1142 | Bias: 1.1
#   > [VAL]   R2: 0.9510 | RMSE: 2174 | MAE: 1297 | Bias: 16.3
#
# [C2|F7] Processing fold...
#   > [TRAIN] R2: 0.9719 | RMSE: 1632 | MAE: 1048 | Bias: 2.0
#   > [VAL]   R2: 0.9560 | RMSE: 2041 | MAE: 1252 | Bias: 24.0
#
# [C2|F8] Processing fold...
#   > [TRAIN] R2: 0.9687 | RMSE: 1730 | MAE: 1111 | Bias: 2.1
#   > [VAL]   R2: 0.9538 | RMSE: 2043 | MAE: 1255 | Bias: -18.9
#
# Config 2 SUMMARY:
#   Selected features (avg): 12
#   [TRAIN AVG] MAE: 1071.4 | R2: 0.9701 | Bias: 1.5
#   [VAL AVG]   MAE: 1278.6 | R2: 0.9514 | Bias: 3.1 | RMSE: 2143.0
#
# ######## CONFIG 3/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C3|F1] Processing fold...
#   > Features before FS (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9678 | RMSE: 1754 | MAE: 1054 | Bias: 7.0
#   > [VAL]   R2: 0.9583 | RMSE: 1943 | MAE: 1254 | Bias: -43.8
#
# [C3|F2] Processing fold...
#   > [TRAIN] R2: 0.9706 | RMSE: 1670 | MAE: 1075 | Bias: 1.8
#   > [VAL]   R2: 0.9520 | RMSE: 2122 | MAE: 1290 | Bias: -10.4
#
# [C3|F3] Processing fold...
#   > [TRAIN] R2: 0.9701 | RMSE: 1683 | MAE: 1058 | Bias: 3.6
#   > [VAL]   R2: 0.9512 | RMSE: 2140 | MAE: 1286 | Bias: 32.1
#
# [C3|F4] Processing fold...
#   > [TRAIN] R2: 0.9778 | RMSE: 1442 | MAE: 955 | Bias: 0.3
#   > [VAL]   R2: 0.9350 | RMSE: 2584 | MAE: 1289 | Bias: 29.7
#
# [C3|F5] Processing fold...
#   > [TRAIN] R2: 0.9764 | RMSE: 1496 | MAE: 966 | Bias: -4.9
#   > [VAL]   R2: 0.9573 | RMSE: 2027 | MAE: 1250 | Bias: -2.6
#
# [C3|F6] Processing fold...
#   > [TRAIN] R2: 0.9712 | RMSE: 1651 | MAE: 1053 | Bias: 0.7
#   > [VAL]   R2: 0.9551 | RMSE: 2080 | MAE: 1259 | Bias: 12.7
#
# [C3|F7] Processing fold...
#   > [TRAIN] R2: 0.9747 | RMSE: 1548 | MAE: 992 | Bias: 2.5
#   > [VAL]   R2: 0.9570 | RMSE: 2017 | MAE: 1228 | Bias: 23.7
#
# [C3|F8] Processing fold...
#   > [TRAIN] R2: 0.9713 | RMSE: 1656 | MAE: 1066 | Bias: 2.3
#   > [VAL]   R2: 0.9550 | RMSE: 2014 | MAE: 1235 | Bias: -13.4
#
# Config 3 SUMMARY:
#   Selected features (avg): 12
#   [TRAIN AVG] MAE: 1027.4 | R2: 0.9725 | Bias: 1.7
#   [VAL AVG]   MAE: 1261.2 | R2: 0.9526 | Bias: 3.5 | RMSE: 2115.7
# [NEW BEST RMSE] Config 3
#
# ######## CONFIG 4/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 600, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C4|F1] Processing fold...
#   > Features before FS (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9669 | RMSE: 1778 | MAE: 1067 | Bias: 6.7
#   > [VAL]   R2: 0.9584 | RMSE: 1939 | MAE: 1255 | Bias: -45.1
#
# [C4|F2] Processing fold...
#   > [TRAIN] R2: 0.9665 | RMSE: 1782 | MAE: 1138 | Bias: 1.4
#   > [VAL]   R2: 0.9506 | RMSE: 2153 | MAE: 1311 | Bias: -17.8
#
# [C4|F3] Processing fold...
#   > [TRAIN] R2: 0.9690 | RMSE: 1714 | MAE: 1076 | Bias: 2.7
#   > [VAL]   R2: 0.9524 | RMSE: 2115 | MAE: 1285 | Bias: 33.7
#
# [C4|F4] Processing fold...
#   > [TRAIN] R2: 0.9750 | RMSE: 1531 | MAE: 1020 | Bias: -0.5
#   > [VAL]   R2: 0.9344 | RMSE: 2597 | MAE: 1297 | Bias: 28.2
#
# [C4|F5] Processing fold...
#   > [TRAIN] R2: 0.9701 | RMSE: 1681 | MAE: 1081 | Bias: -5.7
#   > [VAL]   R2: 0.9557 | RMSE: 2064 | MAE: 1277 | Bias: -16.2
#
# [C4|F6] Processing fold...
#   > [TRAIN] R2: 0.9679 | RMSE: 1743 | MAE: 1107 | Bias: 0.7
#   > [VAL]   R2: 0.9539 | RMSE: 2108 | MAE: 1271 | Bias: 11.6
#
# [C4|F7] Processing fold...
#   > [TRAIN] R2: 0.9694 | RMSE: 1703 | MAE: 1087 | Bias: 2.3
#   > [VAL]   R2: 0.9577 | RMSE: 2000 | MAE: 1247 | Bias: 32.5
#
# [C4|F8] Processing fold...
#   > [TRAIN] R2: 0.9703 | RMSE: 1684 | MAE: 1079 | Bias: 2.2
#   > [VAL]   R2: 0.9560 | RMSE: 1993 | MAE: 1232 | Bias: -13.3
#
# Config 4 SUMMARY:
#   Selected features (avg): 12
#   [TRAIN AVG] MAE: 1082.1 | R2: 0.9694 | Bias: 1.2
#   [VAL AVG]   MAE: 1271.8 | R2: 0.9524 | Bias: 1.7 | RMSE: 2121.1
#
# ######## CONFIG 5/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C5|F1] Processing fold...
#   > Features before FS (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9670 | RMSE: 1776 | MAE: 1075 | Bias: 6.3
#   > [VAL]   R2: 0.9583 | RMSE: 1944 | MAE: 1263 | Bias: -39.8
#
# [C5|F2] Processing fold...
#   > [TRAIN] R2: 0.9721 | RMSE: 1626 | MAE: 1053 | Bias: 1.2
#   > [VAL]   R2: 0.9512 | RMSE: 2141 | MAE: 1285 | Bias: -15.9
#
# [C5|F3] Processing fold...
#   > [TRAIN] R2: 0.9688 | RMSE: 1721 | MAE: 1090 | Bias: 3.9
#   > [VAL]   R2: 0.9518 | RMSE: 2127 | MAE: 1300 | Bias: 40.6
#
# [C5|F4] Processing fold...
#   > [TRAIN] R2: 0.9731 | RMSE: 1588 | MAE: 1059 | Bias: -0.1
#   > [VAL]   R2: 0.9360 | RMSE: 2564 | MAE: 1313 | Bias: 34.4
#
# [C5|F5] Processing fold...
#   > [TRAIN] R2: 0.9751 | RMSE: 1535 | MAE: 999 | Bias: -5.6
#   > [VAL]   R2: 0.9567 | RMSE: 2040 | MAE: 1255 | Bias: -8.2
#
# [C5|F6] Processing fold...
#   > [TRAIN] R2: 0.9687 | RMSE: 1720 | MAE: 1103 | Bias: 0.2
#   > [VAL]   R2: 0.9546 | RMSE: 2091 | MAE: 1273 | Bias: 11.5
#
# [C5|F7] Processing fold...
#   > [TRAIN] R2: 0.9723 | RMSE: 1621 | MAE: 1048 | Bias: 2.3
#   > [VAL]   R2: 0.9573 | RMSE: 2010 | MAE: 1238 | Bias: 27.6
#
# [C5|F8] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1695 | MAE: 1098 | Bias: 2.8
#   > [VAL]   R2: 0.9547 | RMSE: 2022 | MAE: 1250 | Bias: -14.7
#
# Config 5 SUMMARY:
#   Selected features (avg): 12
#   [TRAIN AVG] MAE: 1065.7 | R2: 0.9709 | Bias: 1.4
#   [VAL AVG]   MAE: 1272.3 | R2: 0.9526 | Bias: 4.4 | RMSE: 2117.3
#
# ######## CONFIG 6/15 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 191, 'max_iter': 1200, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}
#
# [C6|F1] Processing fold...
#   > Features before FS (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9671 | RMSE: 1772 | MAE: 1073 | Bias: 6.7
#   > [VAL]   R2: 0.9579 | RMSE: 1953 | MAE: 1264 | Bias: -51.8
#
# [C6|F2] Processing fold...
#   > [TRAIN] R2: 0.9740 | RMSE: 1570 | MAE: 1015 | Bias: 1.6
#   > [VAL]   R2: 0.9529 | RMSE: 2103 | MAE: 1271 | Bias: -3.7
#
# [C6|F3] Processing fold...
#   > [TRAIN] R2: 0.9670 | RMSE: 1771 | MAE: 1118 | Bias: 4.1
#   > [VAL]   R2: 0.9490 | RMSE: 2189 | MAE: 1310 | Bias: 35.7
#
# [C6|F4] Processing fold...
#   > [TRAIN] R2: 0.9772 | RMSE: 1463 | MAE: 975 | Bias: -0.5
#   > [VAL]   R2: 0.9335 | RMSE: 2615 | MAE: 1298 | Bias: 22.9
#
# [C6|F5] Processing fold...
#   > [TRAIN] R2: 0.9766 | RMSE: 1488 | MAE: 965 | Bias: -5.1
#   > [VAL]   R2: 0.9574 | RMSE: 2025 | MAE: 1250 | Bias: -7.2
#
# [C6|F6] Processing fold...
#   > [TRAIN] R2: 0.9688 | RMSE: 1718 | MAE: 1101 | Bias: -0.4
#   > [VAL]   R2: 0.9543 | RMSE: 2098 | MAE: 1270 | Bias: 13.1
#
# [C6|F7] Processing fold...
#   > [TRAIN] R2: 0.9744 | RMSE: 1559 | MAE: 1005 | Bias: 1.7
#   > [VAL]   R2: 0.9575 | RMSE: 2006 | MAE: 1233 | Bias: 25.5
#
# [C6|F8] Processing fold...
#   > [TRAIN] R2: 0.9772 | RMSE: 1476 | MAE: 958 | Bias: 2.9
#   > [VAL]   R2: 0.9558 | RMSE: 1997 | MAE: 1219 | Bias: -12.7
#
# Config 6 SUMMARY:
#   Selected features (avg): 12
#   [TRAIN AVG] MAE: 1026.2 | R2: 0.9728 | Bias: 1.4
#   [VAL AVG]   MAE: 1264.5 | R2: 0.9523 | Bias: 2.7 | RMSE: 2123.1
#
# ######## CONFIG 7/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 800, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 0.3}
#
# [C7|F1] Processing fold...
#   > Features before FS (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9584 | RMSE: 1992 | MAE: 1229 | Bias: 5.6
#   > [VAL]   R2: 0.9548 | RMSE: 2022 | MAE: 1332 | Bias: -42.4
#
# [C7|F2] Processing fold...
#   > [TRAIN] R2: 0.9637 | RMSE: 1857 | MAE: 1209 | Bias: 0.0
#   > [VAL]   R2: 0.9488 | RMSE: 2192 | MAE: 1349 | Bias: -21.4
#
# [C7|F3] Processing fold...
#   > [TRAIN] R2: 0.9645 | RMSE: 1836 | MAE: 1170 | Bias: 2.7
#   > [VAL]   R2: 0.9504 | RMSE: 2158 | MAE: 1322 | Bias: 32.0
#
# [C7|F4] Processing fold...
#   > [TRAIN] R2: 0.9714 | RMSE: 1636 | MAE: 1097 | Bias: -1.1
#   > [VAL]   R2: 0.9351 | RMSE: 2581 | MAE: 1322 | Bias: 26.4
#
# [C7|F5] Processing fold...
#   > [TRAIN] R2: 0.9656 | RMSE: 1804 | MAE: 1176 | Bias: -6.2
#   > [VAL]   R2: 0.9545 | RMSE: 2093 | MAE: 1309 | Bias: -21.1
#
# [C7|F6] Processing fold...
#   > [TRAIN] R2: 0.9665 | RMSE: 1780 | MAE: 1153 | Bias: 0.4
#   > [VAL]   R2: 0.9557 | RMSE: 2066 | MAE: 1294 | Bias: 13.3
#
# [C7|F7] Processing fold...
#   > [TRAIN] R2: 0.9684 | RMSE: 1731 | MAE: 1126 | Bias: 3.7
#   > [VAL]   R2: 0.9574 | RMSE: 2008 | MAE: 1265 | Bias: 26.2
#
# [C7|F8] Processing fold...
#   > [TRAIN] R2: 0.9688 | RMSE: 1726 | MAE: 1130 | Bias: 2.6
#   > [VAL]   R2: 0.9548 | RMSE: 2020 | MAE: 1256 | Bias: -11.3
#
# Config 7 SUMMARY:
#   Selected features (avg): 12
#   [TRAIN AVG] MAE: 1161.3 | R2: 0.9659 | Bias: 1.0
#   [VAL AVG]   MAE: 1306.2 | R2: 0.9514 | Bias: 0.2 | RMSE: 2142.6
#
# ######## CONFIG 8/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C8|F1] Processing fold...
#   > Features before FS (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9670 | RMSE: 1775 | MAE: 1074 | Bias: 6.1
#   > [VAL]   R2: 0.9587 | RMSE: 1933 | MAE: 1257 | Bias: -45.3
#
# [C8|F2] Processing fold...
#   > [TRAIN] R2: 0.9707 | RMSE: 1669 | MAE: 1081 | Bias: 1.0
#   > [VAL]   R2: 0.9517 | RMSE: 2129 | MAE: 1291 | Bias: -12.3
#
# [C8|F3] Processing fold...
#   > [TRAIN] R2: 0.9700 | RMSE: 1688 | MAE: 1069 | Bias: 3.3
#   > [VAL]   R2: 0.9524 | RMSE: 2114 | MAE: 1287 | Bias: 30.1
#
# [C8|F4] Processing fold...
#   > [TRAIN] R2: 0.9750 | RMSE: 1529 | MAE: 1022 | Bias: -0.4
#   > [VAL]   R2: 0.9349 | RMSE: 2586 | MAE: 1304 | Bias: 33.5
#
# [C8|F5] Processing fold...
#   > [TRAIN] R2: 0.9739 | RMSE: 1571 | MAE: 1016 | Bias: -5.1
#   > [VAL]   R2: 0.9572 | RMSE: 2028 | MAE: 1247 | Bias: -9.2
#
# [C8|F6] Processing fold...
#   > [TRAIN] R2: 0.9713 | RMSE: 1648 | MAE: 1058 | Bias: 0.5
#   > [VAL]   R2: 0.9558 | RMSE: 2065 | MAE: 1258 | Bias: 12.7
#
# [C8|F7] Processing fold...
#   > [TRAIN] R2: 0.9733 | RMSE: 1591 | MAE: 1026 | Bias: 2.0
#   > [VAL]   R2: 0.9573 | RMSE: 2011 | MAE: 1236 | Bias: 21.2
#
# [C8|F8] Processing fold...
#   > [TRAIN] R2: 0.9700 | RMSE: 1693 | MAE: 1098 | Bias: 2.1
#   > [VAL]   R2: 0.9552 | RMSE: 2011 | MAE: 1242 | Bias: -14.1
#
# Config 8 SUMMARY:
#   Selected features (avg): 12
#   [TRAIN AVG] MAE: 1055.4 | R2: 0.9714 | Bias: 1.2
#   [VAL AVG]   MAE: 1265.2 | R2: 0.9529 | Bias: 2.1 | RMSE: 2109.5
# [NEW BEST RMSE] Config 8
#
# ######## CONFIG 9/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 0.3}
#
# [C9|F1] Processing fold...
#   > Features before FS (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9686 | RMSE: 1731 | MAE: 1039 | Bias: 6.7
#   > [VAL]   R2: 0.9592 | RMSE: 1921 | MAE: 1248 | Bias: -51.5
#
# [C9|F2] Processing fold...
#   > [TRAIN] R2: 0.9750 | RMSE: 1541 | MAE: 996 | Bias: 1.3
#   > [VAL]   R2: 0.9525 | RMSE: 2112 | MAE: 1275 | Bias: -4.1
#
# [C9|F3] Processing fold...
#   > [TRAIN] R2: 0.9715 | RMSE: 1645 | MAE: 1036 | Bias: 3.0
#   > [VAL]   R2: 0.9516 | RMSE: 2133 | MAE: 1289 | Bias: 33.3
#
# [C9|F4] Processing fold...
#   > [TRAIN] R2: 0.9768 | RMSE: 1474 | MAE: 977 | Bias: 0.6
#   > [VAL]   R2: 0.9352 | RMSE: 2579 | MAE: 1289 | Bias: 38.1
#
# [C9|F5] Processing fold...
#   > [TRAIN] R2: 0.9740 | RMSE: 1568 | MAE: 1017 | Bias: -4.9
#   > [VAL]   R2: 0.9562 | RMSE: 2053 | MAE: 1258 | Bias: -5.4
#
# [C9|F6] Processing fold...
#   > [TRAIN] R2: 0.9701 | RMSE: 1681 | MAE: 1073 | Bias: 0.2
#   > [VAL]   R2: 0.9544 | RMSE: 2096 | MAE: 1266 | Bias: 9.5
#
# [C9|F7] Processing fold...
#   > [TRAIN] R2: 0.9740 | RMSE: 1571 | MAE: 1012 | Bias: 2.4
#   > [VAL]   R2: 0.9567 | RMSE: 2024 | MAE: 1237 | Bias: 22.5
#
# [C9|F8] Processing fold...
#   > [TRAIN] R2: 0.9696 | RMSE: 1704 | MAE: 1096 | Bias: 1.8
#   > [VAL]   R2: 0.9543 | RMSE: 2030 | MAE: 1248 | Bias: -16.2
#
# Config 9 SUMMARY:
#   Selected features (avg): 12
#   [TRAIN AVG] MAE: 1030.7 | R2: 0.9724 | Bias: 1.4
#   [VAL AVG]   MAE: 1263.8 | R2: 0.9525 | Bias: 3.3 | RMSE: 2118.5
#
# ######## CONFIG 10/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 1.0}
#
# [C10|F1] Processing fold...
#   > Features before FS (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9693 | RMSE: 1711 | MAE: 1027 | Bias: 6.6
#   > [VAL]   R2: 0.9582 | RMSE: 1945 | MAE: 1252 | Bias: -46.7
#
# [C10|F2] Processing fold...
#   > [TRAIN] R2: 0.9748 | RMSE: 1547 | MAE: 998 | Bias: 1.9
#   > [VAL]   R2: 0.9519 | RMSE: 2125 | MAE: 1272 | Bias: -0.9
#
# [C10|F3] Processing fold...
#   > [TRAIN] R2: 0.9721 | RMSE: 1627 | MAE: 1021 | Bias: 3.7
#   > [VAL]   R2: 0.9519 | RMSE: 2125 | MAE: 1277 | Bias: 33.1
#
# [C10|F4] Processing fold...
#   > [TRAIN] R2: 0.9775 | RMSE: 1451 | MAE: 964 | Bias: 0.1
#   > [VAL]   R2: 0.9345 | RMSE: 2593 | MAE: 1288 | Bias: 36.4
#
# [C10|F5] Processing fold...
#   > [TRAIN] R2: 0.9755 | RMSE: 1522 | MAE: 981 | Bias: -4.8
#   > [VAL]   R2: 0.9570 | RMSE: 2034 | MAE: 1255 | Bias: -6.6
#
# [C10|F6] Processing fold...
#   > [TRAIN] R2: 0.9738 | RMSE: 1574 | MAE: 1002 | Bias: 0.1
#   > [VAL]   R2: 0.9556 | RMSE: 2070 | MAE: 1250 | Bias: 13.3
#
# [C10|F7] Processing fold...
#   > [TRAIN] R2: 0.9740 | RMSE: 1572 | MAE: 1008 | Bias: 2.4
#   > [VAL]   R2: 0.9569 | RMSE: 2020 | MAE: 1238 | Bias: 25.4
#
# [C10|F8] Processing fold...
#   > [TRAIN] R2: 0.9707 | RMSE: 1671 | MAE: 1072 | Bias: 2.0
#   > [VAL]   R2: 0.9551 | RMSE: 2014 | MAE: 1236 | Bias: -15.0
#
# Config 10 SUMMARY:
#   Selected features (avg): 12
#   [TRAIN AVG] MAE: 1009.2 | R2: 0.9735 | Bias: 1.5
#   [VAL AVG]   MAE: 1258.3 | R2: 0.9526 | Bias: 4.9 | RMSE: 2115.7
#
# ######## CONFIG 11/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}
#
# [C11|F1] Processing fold...
#   > Features before FS (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9649 | RMSE: 1829 | MAE: 1102 | Bias: 6.8
#   > [VAL]   R2: 0.9573 | RMSE: 1966 | MAE: 1270 | Bias: -47.1
#
# [C11|F2] Processing fold...
#   > [TRAIN] R2: 0.9679 | RMSE: 1745 | MAE: 1112 | Bias: 0.9
#   > [VAL]   R2: 0.9511 | RMSE: 2141 | MAE: 1299 | Bias: -17.6
#
# [C11|F3] Processing fold...
#   > [TRAIN] R2: 0.9665 | RMSE: 1783 | MAE: 1118 | Bias: 2.9
#   > [VAL]   R2: 0.9498 | RMSE: 2172 | MAE: 1302 | Bias: 34.6
#
# [C11|F4] Processing fold...
#   > [TRAIN] R2: 0.9693 | RMSE: 1695 | MAE: 1115 | Bias: -0.6
#   > [VAL]   R2: 0.9329 | RMSE: 2625 | MAE: 1326 | Bias: 26.7
#
# [C11|F5] Processing fold...
#   > [TRAIN] R2: 0.9719 | RMSE: 1632 | MAE: 1052 | Bias: -4.8
#   > [VAL]   R2: 0.9563 | RMSE: 2051 | MAE: 1268 | Bias: -13.8
#
# [C11|F6] Processing fold...
#   > [TRAIN] R2: 0.9711 | RMSE: 1654 | MAE: 1054 | Bias: 0.6
#   > [VAL]   R2: 0.9560 | RMSE: 2060 | MAE: 1253 | Bias: 7.1
#
# [C11|F7] Processing fold...
#   > [TRAIN] R2: 0.9735 | RMSE: 1585 | MAE: 1015 | Bias: 1.6
#   > [VAL]   R2: 0.9584 | RMSE: 1983 | MAE: 1224 | Bias: 29.0
#
# [C11|F8] Processing fold...
#   > [TRAIN] R2: 0.9687 | RMSE: 1729 | MAE: 1107 | Bias: 2.3
#   > [VAL]   R2: 0.9555 | RMSE: 2004 | MAE: 1245 | Bias: -12.3
#
# Config 11 SUMMARY:
#   Selected features (avg): 12
#   [TRAIN AVG] MAE: 1084.4 | R2: 0.9692 | Bias: 1.2
#   [VAL AVG]   MAE: 1273.3 | R2: 0.9522 | Bias: 0.8 | RMSE: 2125.4
#
# ######## CONFIG 12/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 3.0}
#
# [C12|F1] Processing fold...
#   > Features before FS (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9661 | RMSE: 1799 | MAE: 1086 | Bias: 6.9
#   > [VAL]   R2: 0.9573 | RMSE: 1965 | MAE: 1270 | Bias: -46.7
#
# [C12|F2] Processing fold...
#   > [TRAIN] R2: 0.9733 | RMSE: 1591 | MAE: 1022 | Bias: 0.9
#   > [VAL]   R2: 0.9516 | RMSE: 2131 | MAE: 1280 | Bias: -10.4
#
# [C12|F3] Processing fold...
#   > [TRAIN] R2: 0.9690 | RMSE: 1715 | MAE: 1077 | Bias: 3.6
#   > [VAL]   R2: 0.9520 | RMSE: 2124 | MAE: 1291 | Bias: 28.7
#
# [C12|F4] Processing fold...
#   > [TRAIN] R2: 0.9745 | RMSE: 1545 | MAE: 1028 | Bias: -0.0
#   > [VAL]   R2: 0.9341 | RMSE: 2602 | MAE: 1304 | Bias: 27.2
#
# [C12|F5] Processing fold...
#   > [TRAIN] R2: 0.9704 | RMSE: 1674 | MAE: 1075 | Bias: -5.2
#   > [VAL]   R2: 0.9558 | RMSE: 2062 | MAE: 1275 | Bias: -9.9
#
# [C12|F6] Processing fold...
#   > [TRAIN] R2: 0.9684 | RMSE: 1728 | MAE: 1103 | Bias: 0.8
#   > [VAL]   R2: 0.9536 | RMSE: 2114 | MAE: 1276 | Bias: 11.5
#
# [C12|F7] Processing fold...
#   > [TRAIN] R2: 0.9737 | RMSE: 1581 | MAE: 1014 | Bias: 1.8
#   > [VAL]   R2: 0.9582 | RMSE: 1989 | MAE: 1233 | Bias: 33.5
#
# [C12|F8] Processing fold...
#   > [TRAIN] R2: 0.9693 | RMSE: 1713 | MAE: 1094 | Bias: 1.6
#   > [VAL]   R2: 0.9555 | RMSE: 2004 | MAE: 1239 | Bias: -12.2
#
# Config 12 SUMMARY:
#   Selected features (avg): 12
#   [TRAIN AVG] MAE: 1062.5 | R2: 0.9706 | Bias: 1.3
#   [VAL AVG]   MAE: 1271.0 | R2: 0.9523 | Bias: 2.7 | RMSE: 2123.8
#
# ######## CONFIG 13/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 600, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 0.3}
#
# [C13|F1] Processing fold...
#   > Features before FS (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9602 | RMSE: 1948 | MAE: 1200 | Bias: 5.6
#   > [VAL]   R2: 0.9561 | RMSE: 1993 | MAE: 1309 | Bias: -37.1
#
# [C13|F2] Processing fold...
#   > [TRAIN] R2: 0.9689 | RMSE: 1719 | MAE: 1121 | Bias: 1.4
#   > [VAL]   R2: 0.9510 | RMSE: 2144 | MAE: 1309 | Bias: -13.0
#
# [C13|F3] Processing fold...
#   > [TRAIN] R2: 0.9663 | RMSE: 1789 | MAE: 1138 | Bias: 1.9
#   > [VAL]   R2: 0.9524 | RMSE: 2115 | MAE: 1304 | Bias: 30.3
#
# [C13|F4] Processing fold...
#   > [TRAIN] R2: 0.9683 | RMSE: 1724 | MAE: 1150 | Bias: -1.6
#   > [VAL]   R2: 0.9348 | RMSE: 2589 | MAE: 1338 | Bias: 28.0
#
# [C13|F5] Processing fold...
#   > [TRAIN] R2: 0.9703 | RMSE: 1676 | MAE: 1094 | Bias: -5.7
#   > [VAL]   R2: 0.9564 | RMSE: 2048 | MAE: 1272 | Bias: -10.9
#
# [C13|F6] Processing fold...
#   > [TRAIN] R2: 0.9678 | RMSE: 1745 | MAE: 1132 | Bias: 0.1
#   > [VAL]   R2: 0.9563 | RMSE: 2051 | MAE: 1279 | Bias: 12.5
#
# [C13|F7] Processing fold...
#   > [TRAIN] R2: 0.9701 | RMSE: 1685 | MAE: 1093 | Bias: 3.4
#   > [VAL]   R2: 0.9575 | RMSE: 2005 | MAE: 1253 | Bias: 30.2
#
# [C13|F8] Processing fold...
#   > [TRAIN] R2: 0.9705 | RMSE: 1679 | MAE: 1095 | Bias: 2.1
#   > [VAL]   R2: 0.9559 | RMSE: 1995 | MAE: 1239 | Bias: -17.5
#
# Config 13 SUMMARY:
#   Selected features (avg): 12
#   [TRAIN AVG] MAE: 1128.0 | R2: 0.9678 | Bias: 0.9
#   [VAL AVG]   MAE: 1287.8 | R2: 0.9525 | Bias: 2.8 | RMSE: 2117.5
#
# ######## CONFIG 14/15 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C14|F1] Processing fold...
#   > Features before FS (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9638 | RMSE: 1858 | MAE: 1143 | Bias: 6.3
#   > [VAL]   R2: 0.9568 | RMSE: 1977 | MAE: 1292 | Bias: -35.7
#
# [C14|F2] Processing fold...
#   > [TRAIN] R2: 0.9736 | RMSE: 1582 | MAE: 1030 | Bias: 0.9
#   > [VAL]   R2: 0.9535 | RMSE: 2089 | MAE: 1280 | Bias: -11.1
#
# [C14|F3] Processing fold...
#   > [TRAIN] R2: 0.9684 | RMSE: 1732 | MAE: 1099 | Bias: 3.2
#   > [VAL]   R2: 0.9516 | RMSE: 2133 | MAE: 1302 | Bias: 26.7
#
# [C14|F4] Processing fold...
#   > [TRAIN] R2: 0.9706 | RMSE: 1659 | MAE: 1113 | Bias: -0.9
#   > [VAL]   R2: 0.9325 | RMSE: 2634 | MAE: 1335 | Bias: 33.2
#
# [C14|F5] Processing fold...
#   > [TRAIN] R2: 0.9738 | RMSE: 1576 | MAE: 1030 | Bias: -6.2
#   > [VAL]   R2: 0.9575 | RMSE: 2022 | MAE: 1255 | Bias: -9.5
#
# [C14|F6] Processing fold...
#   > [TRAIN] R2: 0.9723 | RMSE: 1618 | MAE: 1044 | Bias: -0.6
#   > [VAL]   R2: 0.9571 | RMSE: 2034 | MAE: 1258 | Bias: 18.3
#
# [C14|F7] Processing fold...
#   > [TRAIN] R2: 0.9735 | RMSE: 1586 | MAE: 1032 | Bias: 2.3
#   > [VAL]   R2: 0.9573 | RMSE: 2010 | MAE: 1248 | Bias: 31.8
#
# [C14|F8] Processing fold...
#   > [TRAIN] R2: 0.9776 | RMSE: 1463 | MAE: 949 | Bias: 2.5
#   > [VAL]   R2: 0.9560 | RMSE: 1991 | MAE: 1213 | Bias: -18.3
#
# Config 14 SUMMARY:
#   Selected features (avg): 12
#   [TRAIN AVG] MAE: 1055.0 | R2: 0.9717 | Bias: 0.9
#   [VAL AVG]   MAE: 1272.9 | R2: 0.9528 | Bias: 4.4 | RMSE: 2111.2
#
# ######## CONFIG 15/15 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 63, 'max_iter': 600, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 0.3}
#
# [C15|F1] Processing fold...
#   > Features before FS (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9635 | RMSE: 1867 | MAE: 1144 | Bias: 5.8
#   > [VAL]   R2: 0.9570 | RMSE: 1972 | MAE: 1292 | Bias: -41.1
#
# [C15|F2] Processing fold...
#   > [TRAIN] R2: 0.9658 | RMSE: 1803 | MAE: 1178 | Bias: 1.1
#   > [VAL]   R2: 0.9507 | RMSE: 2150 | MAE: 1334 | Bias: -18.5
#
# [C15|F3] Processing fold...
#   > [TRAIN] R2: 0.9640 | RMSE: 1848 | MAE: 1181 | Bias: 2.8
#   > [VAL]   R2: 0.9498 | RMSE: 2171 | MAE: 1333 | Bias: 35.1
#
# [C15|F4] Processing fold...
#   > [TRAIN] R2: 0.9728 | RMSE: 1596 | MAE: 1068 | Bias: -2.3
#   > [VAL]   R2: 0.9345 | RMSE: 2593 | MAE: 1315 | Bias: 15.1
#
# [C15|F5] Processing fold...
#   > [TRAIN] R2: 0.9707 | RMSE: 1665 | MAE: 1089 | Bias: -6.2
#   > [VAL]   R2: 0.9567 | RMSE: 2041 | MAE: 1276 | Bias: -14.4
#
# [C15|F6] Processing fold...
#   > [TRAIN] R2: 0.9695 | RMSE: 1700 | MAE: 1105 | Bias: 0.8
#   > [VAL]   R2: 0.9562 | RMSE: 2056 | MAE: 1281 | Bias: 5.4
#
# [C15|F7] Processing fold...
#   > [TRAIN] R2: 0.9682 | RMSE: 1735 | MAE: 1136 | Bias: 2.8
#   > [VAL]   R2: 0.9564 | RMSE: 2031 | MAE: 1278 | Bias: 25.6
#
# [C15|F8] Processing fold...
#   > [TRAIN] R2: 0.9744 | RMSE: 1562 | MAE: 1026 | Bias: 2.4
#   > [VAL]   R2: 0.9557 | RMSE: 2000 | MAE: 1227 | Bias: -19.6
#
# Config 15 SUMMARY:
#   Selected features (avg): 12
#   [TRAIN AVG] MAE: 1115.8 | R2: 0.9686 | Bias: 0.9
#   [VAL AVG]   MAE: 1292.0 | R2: 0.9521 | Bias: -1.6 | RMSE: 2126.8
# # END OF SEARCH
#
# Top 5 Configurations by RMSE:
#     config_id  fs_keep_ratio  avg_selected_features  learning_rate  max_iter  \
# 7           8            0.8                   12.0          0.070       800
# 13         14            0.8                   12.0          0.100       800
# 2           3            0.8                   12.0          0.070      1000
# 9          10            0.8                   12.0          0.085       600
# 4           5            0.8                   12.0          0.100      1000
#
#     max_leaf_nodes  max_depth     val_rmse      val_mae    val_r2  train_r2  \
# 7              127        NaN  2109.510831  1265.154176  0.952900  0.971396
# 13             127       25.0  2111.207607  1272.928828  0.952785  0.971699
# 2              191       20.0  2115.711639  1261.176586  0.952630  0.972485
# 9              191        NaN  2115.732597  1258.300417  0.952625  0.973474
# 4              127       20.0  2117.276096  1272.314731  0.952577  0.970879
#
#     val_bias
# 7   2.069663
# 13  4.415285
# 2   3.494479
# 9   4.883296
# 4   4.437931
# Best Config found:
# {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}

# %%
import os
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, ParameterSampler
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, median_absolute_error

# we will use an 8-fold cross-validation strategy
N_SPLITS = 8

# shuffles the data, in order to (at least theoretically) have more balanced folds
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# we explicitly exclude this feature from the model input
DROP_FROM_MODEL = ["previousOwners"]

# keep 80% of features after encoding (feature selection step)
FS_KEEP_RATIO = 0.90

# RandomForest used only for feature selection (importance-based)
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

# hyperparameter space that we are going to use for random search
# each configuration will get 1 value from each of these lists
param_distributions = {
    "loss": ["squared_error"],
    "learning_rate": [0.07, 0.085, 0.1, 0.115],
    "max_iter": [600, 800, 1000, 1200],
    "max_leaf_nodes": [63, 127, 191, 255],
    "l2_regularization": [0.3, 1.0, 3.0],
    "min_samples_leaf": [12, 16, 20, 28],
    "max_depth": [15, 20, 25, None],
}

N_RANDOM_CONFIGS = 15  

# we get N_RANDOM_CONFIGS random parameter combinations from param_distributions
sampler = ParameterSampler(param_distributions, n_iter=N_RANDOM_CONFIGS, random_state=RANDOM_STATE)

search_results = []  # stores results for ranking

# tracking the best configuration according to validation RMSE
best_rmse = np.inf
best_config = None

# log setup (mainly for development and traceability)
log_dir = "gb_logs"
os.makedirs(log_dir, exist_ok=True)
log_filename = "2gb_noowners_fs90_log.txt"
log_path = os.path.join(log_dir, log_filename)

# Note: this section is included mainly for organizational purposes
with open(log_path, "w", encoding="utf-8") as log_file:

    # prints to screen and writes to the log file
    def log(msg: str):
        print(msg)
        log_file.write(msg + "\n")
        log_file.flush()

    # header for the log file
    log("# =============================")
    log("# START OF HGB SEARCH WITH FEATURE SELECTION (KEEP 80%)")
    log("# METRICS: R2, RMSE, MAE, BIAS")
    log(f"# LOG FILE SAVED TO: {log_path}")
    log("# =============================")

    # loop over random configurations
    for config_id, params in enumerate(sampler, start=1):
        log("")
        log(f"######## CONFIG {config_id}/{N_RANDOM_CONFIGS} ########")
        log(f"Parameters: {params}")

        # store metrics for each fold
        fold_rmses_val, fold_maes_val, fold_r2s_val, fold_bias_val = [], [], [], []
        fold_rmses_tr,  fold_maes_tr,  fold_r2s_tr,  fold_bias_tr  = [], [], [], []
        fold_med_ae = []
        fold_nsel = []

        # K-Fold cross-validation for this configuration
        for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):

            # data split for the current fold
            X_train, X_val = X.iloc[train_idx].copy(), X.iloc[val_idx].copy()
            y_train, y_val = y.iloc[train_idx].copy(), y.iloc[val_idx].copy()

            log(f"\n[C{config_id}|F{fold}] Processing fold...")

            # -> Preprocessing steps
            # fit is only done on the training fold, then applied to both train and validation
            year_state = fit_year_median(X_train, year_col="year", model_col="model")
            X_train = transform_year_with_model_median(X_train, state=year_state)
            X_val   = transform_year_with_model_median(X_val,   state=year_state)

            engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
            X_train = transform_engine_size_imputer(X_train, state=engine_state)
            X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

            X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
            X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

            mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
            X_train = transform_mpg_imputer(X_train, state=mpg_state)
            X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

            brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
            X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
            X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

            model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
            X_train, _, _ = transform_invalid_models(X_train, model_state)
            X_val,   _, _ = transform_invalid_models(X_val,   model_state)

            transm_state = fit_transmission_resolver(X_train, valid_transmissions)
            X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
            X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

            fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
            X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
            X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

            # hard guarantee: previousOwners is not used by the model in this section
            X_train = X_train.drop(columns=DROP_FROM_MODEL, errors="ignore")
            X_val   = X_val.drop(columns=DROP_FROM_MODEL, errors="ignore")

            # -> Feature encoding (categorical only)
            high_card_features = ["Brand", "model"]  # target encoding for these
            low_card_features  = [c for c in categorical_features if c not in high_card_features]

            te = MyTargetEncoder(smoothing=5)
            te.fit(X_train[high_card_features], y_train)  # fit on training fold only
            X_train_high = te.transform(X_train[high_card_features])
            X_val_high   = te.transform(X_val[high_card_features])

            ohe = MyOneHotEncoder()
            ohe.fit(X_train[low_card_features])  # fit on training fold only
            X_train_low = ohe.transform(X_train[low_card_features])
            X_val_low   = ohe.transform(X_val[low_card_features])

            # rejoin encoded categorical features
            X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
            X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

            # join numerical and categorical (encoded) features
            X_train_final = pd.concat([X_train[numeric_features], X_train_cat], axis=1)
            X_val_final   = pd.concat([X_val[numeric_features],   X_val_cat],   axis=1)

            # make sure validation has exactly the same columns as training
            X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

            # log original feature space once per config (fold 1)
            if fold == 1:
                feature_names = list(X_train_final.columns)
                log(f"  > Features before FS ({len(feature_names)}): {feature_names}")

            # -> Feature selection (keep top 80% features by RF importance)
            n_feats = X_train_final.shape[1]
            k = int(np.ceil(FS_KEEP_RATIO * n_feats))
            k = max(1, min(k, n_feats))

            rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
            rf_fs.fit(X_train_final, y_train)

            selector = SelectFromModel(
                estimator=rf_fs,
                threshold=-np.inf,   # keep the top max_features, regardless of absolute importance values
                max_features=k,
                prefit=True
            )

            selected_cols = X_train_final.columns[selector.get_support()]
            fold_nsel.append(len(selected_cols))

            X_train_sel = X_train_final[selected_cols]
            X_val_sel   = X_val_final[selected_cols]

            if fold == 1:
                log(f"  > Selected features ({len(selected_cols)}/{n_feats}) with FS_KEEP_RATIO={FS_KEEP_RATIO:.2f}")

            # -> Model training (HGB on selected features)
            hgb_model = HistGradientBoostingRegressor(random_state=RANDOM_STATE, **params)
            hgb_model.fit(X_train_sel, y_train)

            # predictions
            y_pred_train = hgb_model.predict(X_train_sel)
            y_pred_val   = hgb_model.predict(X_val_sel)

            # -> Metrics calculation
            mae_tr  = mean_absolute_error(y_train, y_pred_train)
            rmse_tr = np.sqrt(mean_squared_error(y_train, y_pred_train))
            r2_tr   = r2_score(y_train, y_pred_train)
            bias_tr = np.mean(y_train - y_pred_train)

            mae_val  = mean_absolute_error(y_val, y_pred_val)
            rmse_val = np.sqrt(mean_squared_error(y_val, y_pred_val))
            r2_val   = r2_score(y_val, y_pred_val)
            bias_val = np.mean(y_val - y_pred_val)

            med_ae_val = median_absolute_error(y_val, y_pred_val)

            log(f"  > [TRAIN] R2: {r2_tr:.4f} | RMSE: {rmse_tr:.0f} | MAE: {mae_tr:.0f} | Bias: {bias_tr:.1f}")
            log(f"  > [VAL]   R2: {r2_val:.4f} | RMSE: {rmse_val:.0f} | MAE: {mae_val:.0f} | Bias: {bias_val:.1f}")

            fold_maes_tr.append(mae_tr);   fold_rmses_tr.append(rmse_tr);   fold_r2s_tr.append(r2_tr);   fold_bias_tr.append(bias_tr)
            fold_maes_val.append(mae_val); fold_rmses_val.append(rmse_val); fold_r2s_val.append(r2_val); fold_bias_val.append(bias_val)
            fold_med_ae.append(med_ae_val)

        # mean metrics across folds
        mean_rmse_val = np.mean(fold_rmses_val)
        mean_mae_val  = np.mean(fold_maes_val)
        mean_r2_val   = np.mean(fold_r2s_val)
        mean_bias_val = np.mean(fold_bias_val)

        mean_mae_tr   = np.mean(fold_maes_tr)
        mean_r2_tr    = np.mean(fold_r2s_tr)
        mean_bias_tr  = np.mean(fold_bias_tr)

        mean_nsel = float(np.mean(fold_nsel))

        log("")
        log(f"Config {config_id} SUMMARY:")
        log(f"  Selected features (avg): {mean_nsel:.0f}")
        log(f"  [TRAIN AVG] MAE: {mean_mae_tr:.1f} | R2: {mean_r2_tr:.4f} | Bias: {mean_bias_tr:.1f}")
        log(f"  [VAL AVG]   MAE: {mean_mae_val:.1f} | R2: {mean_r2_val:.4f} | Bias: {mean_bias_val:.1f} | RMSE: {mean_rmse_val:.1f}")

        search_results.append({
            "config_id": config_id,
            **params,

            "fs_keep_ratio": FS_KEEP_RATIO,
            "avg_selected_features": mean_nsel,

            "val_rmse": mean_rmse_val,
            "val_mae": mean_mae_val,
            "val_r2": mean_r2_val,
            "val_bias": mean_bias_val,

            "train_mae": mean_mae_tr,
            "train_r2": mean_r2_tr,
            "train_bias": mean_bias_tr,

            "val_med_ae": np.mean(fold_med_ae)
        })

        # best = lowest validation RMSE
        if mean_rmse_val < best_rmse:
            best_rmse = mean_rmse_val
            best_config = {**params}
            log(f"[NEW BEST RMSE] Config {config_id}")

    log("# END OF SEARCH")

# Results
results_df = pd.DataFrame(search_results)
results_df_sorted = results_df.sort_values(by="val_rmse", ascending=True)

print("\nTop 5 Configurations by RMSE:")
cols = [
    "config_id", "fs_keep_ratio", "avg_selected_features",
    "learning_rate", "max_iter", "max_leaf_nodes", "max_depth",
    "val_rmse", "val_mae", "val_r2", "train_r2", "val_bias"
]
display(results_df_sorted[cols].head(5))

print("\nBest Config found:")
print(best_config)

# %% [markdown]
# ### 4.3. Feature Engineering and Feature Selection configurations

# %% [markdown]
# #### 4.3.1. Without Feature Selection

# %% [markdown]
# - We ran a small random search without feature selection. We did not expect strong results, because keeping all of the engineered features would likely increase redundancy, but served as a baseline for comparison.

# %%
logging.basicConfig(
    filename="random_search_results_testing.log",
    level=logging.INFO,
    format="%(asctime)s - %(message)s",
    filemode="w"
)
logging.info("- 10 iterations")


param_distributions = {
    "min_samples_leaf": [20, 30, 40],
    "max_leaf_nodes": [31, 63, 127],
    "max_iter": [600, 800, 1000, 1500],
    "max_depth": [None, 10, 15, 20, 25],
    "learning_rate": np.linspace(0.08, 0.15, 20),
    "l2_regularization": np.linspace(0.5, 2.5, 20),
    "max_bins": [255],
    "random_state": [RANDOM_STATE],
}

def get_random_configs(n_iter: int):
    configs = []
    keys = list(param_distributions.keys())

    for i in range(n_iter):
        params = {}
        for key in keys:
            params[key] = random.choice(list(param_distributions[key]))

        name = (
            f"R{i}_iter{params['max_iter']}"
            f"_lr{float(params['learning_rate']):.3f}"
            f"_l2{float(params['l2_regularization']):.2f}"
            f"_leaf{params['max_leaf_nodes']}"
        )
        configs.append((name, params))
    return configs

CONFIGS = get_random_configs(N_ITER)
print(f"Geradas {len(CONFIGS)} configurações aleatórias. A iniciar testes...")

kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]
high_card_features = ["Brand", "model"]
low_card_features  = [c for c in categorical_features if c not in high_card_features]

def _normalize_cats(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    for col in cols_to_normalize:
        if col in df.columns:
            df[col] = fill_unknown(df[col])
            df = column_string_transformer(
                df, column=col, remove_middle_spaces=True, allow_extra_chars=""
            )
    return df


def eval_one_config(name: str, params: dict) -> dict:
    fold_rows = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):
        X_train = X.iloc[train_idx].copy()
        X_val   = X.iloc[val_idx].copy()
        y_train = y.iloc[train_idx].copy()
        y_val   = y.iloc[val_idx].copy()

        y_train_log = np.log1p(y_train)

        X_train = _normalize_cats(X_train)
        X_val   = _normalize_cats(X_val)

        base_cols = [c for c in (numeric_features + categorical_features) if c in X_train.columns]
        X_train = X_train[base_cols].copy()
        X_val   = X_val[base_cols].copy()


        year_state = fit_year_median(X_train, year_col="year", model_col="model")
        X_train = transform_year_with_model_median(X_train, state=year_state)
        X_val   = transform_year_with_model_median(X_val,   state=year_state)

        engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
        X_train = transform_engine_size_imputer(X_train, state=engine_state)
        X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

        X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
        X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

        mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
        X_train = transform_mpg_imputer(X_train, state=mpg_state)
        X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

        owners_state = fit_previous_owners_imputer(X_train, "previousOwners", "year", "mileage")
        X_train = transform_previous_owners_imputer(X_train, state=owners_state)
        X_val   = transform_previous_owners_imputer(X_val,   state=owners_state)

        
        brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
        X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
        X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

        model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
        X_train, _, _ = transform_invalid_models(X_train, model_state)
        X_val,   _, _ = transform_invalid_models(X_val,   model_state)

        transm_state = fit_transmission_resolver(X_train, valid_transmissions)
        X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
        X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

        fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
        X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
        X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

        

        X_train = add_owners_flagged(X_train, owners_col="previousOwners", new_col="owners_flagged", drop_original=True)
        X_val   = add_owners_flagged(X_val,   owners_col="previousOwners", new_col="owners_flagged", drop_original=True)

        X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
        X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

        X_train = add_mileage_features(X_train, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
        X_val   = add_mileage_features(X_val,   mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)

        X_train = add_engine_bins(X_train, engine_col="engineSize", new_col="engine_bin")
        X_val   = add_engine_bins(X_val,   engine_col="engineSize", new_col="engine_bin")

        X_train["engine_bin"] = X_train["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        X_val["engine_bin"]   = X_val["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")

        low_card_curr = low_card_features + ["engine_bin"]

        te = MyTargetEncoder(smoothing=5)
        te.fit(X_train[high_card_features], y_train_log)
        X_train_high = te.transform(X_train[high_card_features])
        X_val_high   = te.transform(X_val[high_card_features])

        ohe = MyOneHotEncoder()
        ohe.fit(X_train[low_card_curr])
        X_train_low = ohe.transform(X_train[low_card_curr])
        X_val_low   = ohe.transform(X_val[low_card_curr])

        X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
        X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

        drop_for_numeric = set(high_card_features + low_card_curr)
        numeric_features_curr = [c for c in X_train.columns if c not in drop_for_numeric]

        X_train_final = pd.concat([X_train[numeric_features_curr], X_train_cat], axis=1)
        X_val_final   = pd.concat([X_val[numeric_features_curr],   X_val_cat],   axis=1)

        X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

       
        model = HistGradientBoostingRegressor(**params)
        model.fit(X_train_final, y_train_log)

        pred_tr_log  = model.predict(X_train_final)
        pred_val_log = model.predict(X_val_final)

        pred_tr  = np.expm1(pred_tr_log)
        pred_val = np.expm1(pred_val_log)

        mae_tr  = mean_absolute_error(y_train, pred_tr)
        mae_val = mean_absolute_error(y_val,   pred_val)

        fold_rows.append({
            "config": name,
            "fold": fold,
            "train_mae": mae_tr,
            "val_mae": mae_val
        })

    df_folds = pd.DataFrame(fold_rows)
    mean_mae_tr  = df_folds["train_mae"].mean()
    mean_mae_val = df_folds["val_mae"].mean()

    print(f"   >> [{name}] Train MAE: {mean_mae_tr:.2f} | Val MAE: {mean_mae_val:.2f}")
    logging.info(f"{name} | Train MAE: {mean_mae_tr:.4f} | Val MAE: {mean_mae_val:.4f} | Params: {params}")

    out = {
        "config": name,
        "val_mae_mean": mean_mae_val,
        "train_mae_mean": mean_mae_tr,
        **params
    }
    return out


results = []
for i, (name, params) in enumerate(CONFIGS):
    if i % 5 == 0:
        print(f"\n--- A processar {i+1}/{len(CONFIGS)} ---")

    res = eval_one_config(name, params)
    results.append(res)

results_df = pd.DataFrame(results)


print("\n=== TOP 10 MELHORES CONFIGURAÇÕES ===")
results_df_sorted = results_df.sort_values("val_mae_mean", ascending=True)

cols_show = [
    "config",
    "val_mae_mean", "train_mae_mean",
    "learning_rate", "max_iter", "l2_regularization", "max_leaf_nodes", "max_depth", "min_samples_leaf"
]

display(results_df_sorted[cols_show].head(10))

results_df_sorted.to_csv("random_search_final_results.csv", index=False)
print("Guardado: random_search_final_results.csv")
print("Guardado log: random_search_results.log")
# Out:
# Geradas 10 configurações aleatórias. A iniciar testes...
#
# --- A processar 1/10 ---
#    >> [R0_iter600_lr0.084_l20.50_leaf31] Train MAE: 1214.35 | Val MAE: 1322.45
#    >> [R1_iter800_lr0.146_l21.03_leaf127] Train MAE: 1116.98 | Val MAE: 1289.89
#    >> [R2_iter1500_lr0.087_l20.92_leaf127] Train MAE: 996.58 | Val MAE: 1256.58
#    >> [R3_iter1500_lr0.146_l22.50_leaf127] Train MAE: 1033.52 | Val MAE: 1272.90
#    >> [R4_iter1500_lr0.128_l20.82_leaf63] Train MAE: 1075.44 | Val MAE: 1272.16
#
# --- A processar 6/10 ---
#    >> [R5_iter800_lr0.080_l21.66_leaf63] Train MAE: 1141.81 | Val MAE: 1289.35
#    >> [R6_iter1000_lr0.106_l21.34_leaf127] Train MAE: 1039.14 | Val MAE: 1265.58
#    >> [R7_iter1500_lr0.139_l22.29_leaf31] Train MAE: 1198.26 | Val MAE: 1315.55
#    >> [R8_iter600_lr0.084_l21.66_leaf127] Train MAE: 1072.79 | Val MAE: 1274.83
#    >> [R9_iter1500_lr0.080_l21.13_leaf63] Train MAE: 1096.70 | Val MAE: 1272.69
#
# === TOP 10 MELHORES CONFIGURAÇÕES ===
#                                config  val_mae_mean  train_mae_mean  \
# 2  R2_iter1500_lr0.087_l20.92_leaf127   1256.578731      996.576759
# 6  R6_iter1000_lr0.106_l21.34_leaf127   1265.576273     1039.136049
# 4   R4_iter1500_lr0.128_l20.82_leaf63   1272.155654     1075.442789
# 9   R9_iter1500_lr0.080_l21.13_leaf63   1272.686265     1096.698205
# 3  R3_iter1500_lr0.146_l22.50_leaf127   1272.903714     1033.520589
# 8   R8_iter600_lr0.084_l21.66_leaf127   1274.833602     1072.788230
# 5    R5_iter800_lr0.080_l21.66_leaf63   1289.349284     1141.807531
# 1   R1_iter800_lr0.146_l21.03_leaf127   1289.892316     1116.975504
# 7   R7_iter1500_lr0.139_l22.29_leaf31   1315.552940     1198.258439
# 0    R0_iter600_lr0.084_l20.50_leaf31   1322.451619     1214.351604
#
#    learning_rate  max_iter  l2_regularization  max_leaf_nodes  max_depth  \
# 2       0.087368      1500           0.921053             127       20.0
# 6       0.105789      1000           1.342105             127        NaN
# 4       0.127895      1500           0.815789              63        NaN
# 9       0.080000      1500           1.131579              63       20.0
# 3       0.146316      1500           2.500000             127       25.0
# 8       0.083684       600           1.657895             127       10.0
# 5       0.080000       800           1.657895              63       15.0
# 1       0.146316       800           1.026316             127       10.0
# 7       0.138947      1500           2.289474              31       15.0
# 0       0.083684       600           0.500000              31       10.0
#
#    min_samples_leaf
# 2                20
# 6                30
# 4                30
# 9                20
# 3                30
# 8                20
# 5                40
# 1                40
# 7                40
# 0                30
# Guardado: random_search_final_results.csv
# Guardado log: random_search_results.log

# %% [markdown]
# ### 4.3.2. Age, price log and no previous owners

# %%
import os
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, ParameterSampler
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, median_absolute_error


def create_age_and_drop_year(df, year_col="year", base_year=2020, clip_future=True):
    # creates an "age" feature from year, and drops the original year column
    df = df.copy()
    year = pd.to_numeric(df[year_col], errors="coerce")
    age = base_year - year
    if clip_future:
        age = age.clip(lower=0)
    df["age"] = age
    df = df.drop(columns=[year_col])
    return df


# numeric features used by the model (year is replaced by age; previousOwners is excluded)
numeric_features = ["mileage", "engineSize", "tax", "mpg", "age"]

# we will use an 8-fold cross-validation strategy
N_SPLITS = 8

# shuffles the data, in order to (at least theoretically) have more balanced folds
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# we explicitly exclude this feature from the model input
DROP_FROM_MODEL = ["previousOwners"]

# hyperparameter space that we are going to use for random search
# each configuration will get 1 value from each of these lists
param_distributions = {
    "loss": ["squared_error"],
    "learning_rate": [0.07, 0.085, 0.1, 0.115],
    "max_iter": [600, 800, 1000, 1200],
    "max_leaf_nodes": [63, 127, 191, 255],
    "l2_regularization": [0.3, 1.0, 3.0],
    "min_samples_leaf": [12, 16, 20, 28],
    "max_depth": [15, 20, 25, None],
}

N_RANDOM_CONFIGS = 15  # short random search, enough for baseline results

# we get N_RANDOM_CONFIGS random parameter combinations from param_distributions
sampler = ParameterSampler(param_distributions, n_iter=N_RANDOM_CONFIGS, random_state=RANDOM_STATE)

search_results = []  # stores results for ranking
best_rmse = np.inf
best_config = None

# log setup (mainly for development and traceability)
log_dir = "gb_logs"
os.makedirs(log_dir, exist_ok=True)
log_filename = "2gb_noowners_age_logprice_log.txt"
log_path = os.path.join(log_dir, log_filename)

# Note: this section is included mainly for organizational purposes
with open(log_path, "w", encoding="utf-8") as log_file:

    def log(msg: str):
        print(msg)
        log_file.write(msg + "\n")
        log_file.flush()

    log("# =============================")
    log("# START OF HGB SEARCH (LOG TARGET + AGE FEATURE)")
    log("# METRICS ON ORIGINAL SCALE: R2, RMSE, MAE, BIAS")
    log(f"# LOG FILE SAVED TO: {log_path}")
    log("# =============================")

    for config_id, params in enumerate(sampler, start=1):
        log("")
        log(f"######## CONFIG {config_id}/{N_RANDOM_CONFIGS} ########")
        log(f"Parameters: {params}")

        fold_rmses_val, fold_maes_val, fold_r2s_val, fold_bias_val = [], [], [], []
        fold_rmses_tr,  fold_maes_tr,  fold_r2s_tr,  fold_bias_tr  = [], [], [], []
        fold_med_ae = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):

            X_train, X_val = X.iloc[train_idx].copy(), X.iloc[val_idx].copy()
            y_train, y_val = y.iloc[train_idx].copy(), y.iloc[val_idx].copy()

            # log-transform target for training
            y_train_log = np.log1p(y_train)

            log(f"\n[C{config_id}|F{fold}] Processing fold...")

            # -> Preprocessing steps (fit only on training fold, apply to both)
            year_state = fit_year_median(X_train, year_col="year", model_col="model")
            X_train = transform_year_with_model_median(X_train, state=year_state)
            X_val   = transform_year_with_model_median(X_val,   state=year_state)

            engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
            X_train = transform_engine_size_imputer(X_train, state=engine_state)
            X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

            X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
            X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

            mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
            X_train = transform_mpg_imputer(X_train, state=mpg_state)
            X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

            brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
            X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
            X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

            model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
            X_train, _, _ = transform_invalid_models(X_train, model_state)
            X_val,   _, _ = transform_invalid_models(X_val,   model_state)

            transm_state = fit_transmission_resolver(X_train, valid_transmissions)
            X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
            X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

            fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
            X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
            X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

            # -> Feature engineering: create age and drop year (do this after all year-based steps)
            X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
            X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

            # hard guarantee: previousOwners is not used by the model
            X_train = X_train.drop(columns=DROP_FROM_MODEL, errors="ignore")
            X_val   = X_val.drop(columns=DROP_FROM_MODEL, errors="ignore")

            # -> Feature encoding (categorical only)
            high_card_features = ["Brand", "model"]
            low_card_features  = [c for c in categorical_features if c not in high_card_features]

            te = MyTargetEncoder(smoothing=5)
            te.fit(X_train[high_card_features], y_train_log)  # fit using log-target
            X_train_high = te.transform(X_train[high_card_features])
            X_val_high   = te.transform(X_val[high_card_features])

            ohe = MyOneHotEncoder()
            ohe.fit(X_train[low_card_features])
            X_train_low = ohe.transform(X_train[low_card_features])
            X_val_low   = ohe.transform(X_val[low_card_features])

            X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
            X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

            # join numerical and categorical (encoded) features
            X_train_final = pd.concat([X_train[numeric_features], X_train_cat], axis=1)
            X_val_final   = pd.concat([X_val[numeric_features],   X_val_cat],   axis=1)

            # align columns to avoid mismatch due to encoding
            X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

            if fold == 1:
                feature_names = list(X_train_final.columns)
                log(f"  > Features Used ({len(feature_names)}): {feature_names}")

            # -> Model training (train on log-target)
            hgb_model = HistGradientBoostingRegressor(random_state=RANDOM_STATE, **params)
            hgb_model.fit(X_train_final, y_train_log)

            # predictions (log scale), then invert to original scale
            y_pred_train_log = hgb_model.predict(X_train_final)
            y_pred_val_log   = hgb_model.predict(X_val_final)

            y_pred_train = np.expm1(y_pred_train_log)
            y_pred_val   = np.expm1(y_pred_val_log)

            # -> Metrics on original scale
            mae_tr  = mean_absolute_error(y_train, y_pred_train)
            rmse_tr = np.sqrt(mean_squared_error(y_train, y_pred_train))
            r2_tr   = r2_score(y_train, y_pred_train)
            bias_tr = np.mean(y_train - y_pred_train)

            mae_val  = mean_absolute_error(y_val, y_pred_val)
            rmse_val = np.sqrt(mean_squared_error(y_val, y_pred_val))
            r2_val   = r2_score(y_val, y_pred_val)
            bias_val = np.mean(y_val - y_pred_val)

            med_ae_val = median_absolute_error(y_val, y_pred_val)

            log(f"  > [TRAIN] R2: {r2_tr:.4f} | RMSE: {rmse_tr:.0f} | MAE: {mae_tr:.0f} | Bias: {bias_tr:.1f}")
            log(f"  > [VAL]   R2: {r2_val:.4f} | RMSE: {rmse_val:.0f} | MAE: {mae_val:.0f} | Bias: {bias_val:.1f}")

            fold_maes_tr.append(mae_tr);   fold_rmses_tr.append(rmse_tr);   fold_r2s_tr.append(r2_tr);   fold_bias_tr.append(bias_tr)
            fold_maes_val.append(mae_val); fold_rmses_val.append(rmse_val); fold_r2s_val.append(r2_val); fold_bias_val.append(bias_val)
            fold_med_ae.append(med_ae_val)

        mean_rmse_val = np.mean(fold_rmses_val)
        mean_mae_val  = np.mean(fold_maes_val)
        mean_r2_val   = np.mean(fold_r2s_val)
        mean_bias_val = np.mean(fold_bias_val)

        mean_mae_tr   = np.mean(fold_maes_tr)
        mean_r2_tr    = np.mean(fold_r2s_tr)
        mean_bias_tr  = np.mean(fold_bias_tr)

        log("")
        log(f"Config {config_id} SUMMARY:")
        log(f"  [TRAIN AVG] MAE: {mean_mae_tr:.1f} | R2: {mean_r2_tr:.4f} | Bias: {mean_bias_tr:.1f}")
        log(f"  [VAL AVG]   MAE: {mean_mae_val:.1f} | R2: {mean_r2_val:.4f} | Bias: {mean_bias_val:.1f} | RMSE: {mean_rmse_val:.1f}")

        search_results.append({
            "config_id": config_id,
            **params,

            "val_rmse": mean_rmse_val,
            "val_mae": mean_mae_val,
            "val_r2": mean_r2_val,
            "val_bias": mean_bias_val,

            "train_mae": mean_mae_tr,
            "train_r2": mean_r2_tr,
            "train_bias": mean_bias_tr,

            "val_med_ae": np.mean(fold_med_ae)
        })

        if mean_rmse_val < best_rmse:
            best_rmse = mean_rmse_val
            best_config = {**params}
            log(f"[NEW BEST RMSE] Config {config_id}")

    log("# END OF SEARCH")

# Results
results_df = pd.DataFrame(search_results)
results_df_sorted = results_df.sort_values(by="val_rmse", ascending=True)

print("\nTop 5 Configurations by RMSE:")
cols = ["config_id", "learning_rate", "max_iter", "val_rmse", "val_mae", "val_r2", "train_r2", "val_bias"]
display(results_df_sorted[cols].head(5))

print("\nBest Config found:")
print(best_config)
# Out:
# # =============================
# # START OF HGB SEARCH (LOG TARGET + AGE FEATURE)
# # METRICS ON ORIGINAL SCALE: R2, RMSE, MAE, BIAS
# # LOG FILE SAVED TO: gb_logs/2gb_noowners_age_logprice_log.txt
# # =============================
#
# ######## CONFIG 1/15 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 255, 'max_iter': 800, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 0.3}
#
# [C1|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9711 | RMSE: 1662 | MAE: 938 | Bias: 78.9
#   > [VAL]   R2: 0.9594 | RMSE: 1916 | MAE: 1223 | Bias: 48.9
#
# [C1|F2] Processing fold...
#   > [TRAIN] R2: 0.9781 | RMSE: 1442 | MAE: 876 | Bias: 67.1
#   > [VAL]   R2: 0.9489 | RMSE: 2190 | MAE: 1261 | Bias: 83.6
#
# [C1|F3] Processing fold...
#   > [TRAIN] R2: 0.9749 | RMSE: 1543 | MAE: 901 | Bias: 72.9
#   > [VAL]   R2: 0.9492 | RMSE: 2183 | MAE: 1250 | Bias: 135.8
#
# [C1|F4] Processing fold...
#   > [TRAIN] R2: 0.9791 | RMSE: 1400 | MAE: 884 | Bias: 65.9
#   > [VAL]   R2: 0.9347 | RMSE: 2591 | MAE: 1266 | Bias: 127.7
#
# [C1|F5] Processing fold...
#   > [TRAIN] R2: 0.9758 | RMSE: 1515 | MAE: 928 | Bias: 67.8
#   > [VAL]   R2: 0.9566 | RMSE: 2042 | MAE: 1236 | Bias: 77.9
#
# [C1|F6] Processing fold...
#   > [TRAIN] R2: 0.9718 | RMSE: 1633 | MAE: 989 | Bias: 80.5
#   > [VAL]   R2: 0.9506 | RMSE: 2183 | MAE: 1243 | Bias: 117.2
#
# [C1|F7] Processing fold...
#   > [TRAIN] R2: 0.9762 | RMSE: 1503 | MAE: 912 | Bias: 73.8
#   > [VAL]   R2: 0.9563 | RMSE: 2033 | MAE: 1214 | Bias: 125.8
#
# [C1|F8] Processing fold...
#   > [TRAIN] R2: 0.9718 | RMSE: 1640 | MAE: 1016 | Bias: 85.5
#   > [VAL]   R2: 0.9559 | RMSE: 1995 | MAE: 1221 | Bias: 76.7
#
# Config 1 SUMMARY:
#   [TRAIN AVG] MAE: 930.5 | R2: 0.9748 | Bias: 74.1
#   [VAL AVG]   MAE: 1239.4 | R2: 0.9514 | Bias: 99.2 | RMSE: 2141.8
# [NEW BEST RMSE] Config 1
#
# ######## CONFIG 2/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 255, 'max_iter': 600, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 1.0}
#
# [C2|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9694 | RMSE: 1707 | MAE: 966 | Bias: 80.3
#   > [VAL]   R2: 0.9592 | RMSE: 1921 | MAE: 1222 | Bias: 51.8
#
# [C2|F2] Processing fold...
#   > [TRAIN] R2: 0.9717 | RMSE: 1638 | MAE: 1004 | Bias: 78.7
#   > [VAL]   R2: 0.9491 | RMSE: 2186 | MAE: 1263 | Bias: 91.6
#
# [C2|F3] Processing fold...
#   > [TRAIN] R2: 0.9707 | RMSE: 1667 | MAE: 989 | Bias: 80.0
#   > [VAL]   R2: 0.9492 | RMSE: 2183 | MAE: 1260 | Bias: 135.6
#
# [C2|F4] Processing fold...
#   > [TRAIN] R2: 0.9718 | RMSE: 1624 | MAE: 1028 | Bias: 77.8
#   > [VAL]   R2: 0.9326 | RMSE: 2632 | MAE: 1291 | Bias: 134.5
#
# [C2|F5] Processing fold...
#   > [TRAIN] R2: 0.9749 | RMSE: 1541 | MAE: 944 | Bias: 66.9
#   > [VAL]   R2: 0.9579 | RMSE: 2013 | MAE: 1232 | Bias: 75.6
#
# [C2|F6] Processing fold...
#   > [TRAIN] R2: 0.9711 | RMSE: 1652 | MAE: 1003 | Bias: 80.2
#   > [VAL]   R2: 0.9524 | RMSE: 2141 | MAE: 1240 | Bias: 110.6
#
# [C2|F7] Processing fold...
#   > [TRAIN] R2: 0.9654 | RMSE: 1812 | MAE: 1095 | Bias: 92.6
#   > [VAL]   R2: 0.9561 | RMSE: 2037 | MAE: 1243 | Bias: 130.7
#
# [C2|F8] Processing fold...
#   > [TRAIN] R2: 0.9714 | RMSE: 1653 | MAE: 1022 | Bias: 82.5
#   > [VAL]   R2: 0.9563 | RMSE: 1986 | MAE: 1215 | Bias: 74.8
#
# Config 2 SUMMARY:
#   [TRAIN AVG] MAE: 1006.4 | R2: 0.9708 | Bias: 79.9
#   [VAL AVG]   MAE: 1245.7 | R2: 0.9516 | Bias: 100.6 | RMSE: 2137.4
# [NEW BEST RMSE] Config 2
#
# ######## CONFIG 3/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C3|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9672 | RMSE: 1769 | MAE: 1005 | Bias: 86.4
#   > [VAL]   R2: 0.9593 | RMSE: 1919 | MAE: 1225 | Bias: 50.1
#
# [C3|F2] Processing fold...
#   > [TRAIN] R2: 0.9715 | RMSE: 1644 | MAE: 1003 | Bias: 79.8
#   > [VAL]   R2: 0.9503 | RMSE: 2159 | MAE: 1264 | Bias: 89.9
#
# [C3|F3] Processing fold...
#   > [TRAIN] R2: 0.9705 | RMSE: 1673 | MAE: 989 | Bias: 81.8
#   > [VAL]   R2: 0.9486 | RMSE: 2198 | MAE: 1254 | Bias: 137.8
#
# [C3|F4] Processing fold...
#   > [TRAIN] R2: 0.9740 | RMSE: 1561 | MAE: 981 | Bias: 74.1
#   > [VAL]   R2: 0.9340 | RMSE: 2605 | MAE: 1276 | Bias: 128.4
#
# [C3|F5] Processing fold...
#   > [TRAIN] R2: 0.9755 | RMSE: 1523 | MAE: 930 | Bias: 67.5
#   > [VAL]   R2: 0.9583 | RMSE: 2003 | MAE: 1220 | Bias: 86.4
#
# [C3|F6] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1689 | MAE: 1019 | Bias: 82.1
#   > [VAL]   R2: 0.9515 | RMSE: 2162 | MAE: 1238 | Bias: 109.5
#
# [C3|F7] Processing fold...
#   > [TRAIN] R2: 0.9698 | RMSE: 1693 | MAE: 1026 | Bias: 85.1
#   > [VAL]   R2: 0.9573 | RMSE: 2011 | MAE: 1216 | Bias: 116.4
#
# [C3|F8] Processing fold...
#   > [TRAIN] R2: 0.9713 | RMSE: 1657 | MAE: 1016 | Bias: 83.4
#   > [VAL]   R2: 0.9566 | RMSE: 1980 | MAE: 1210 | Bias: 74.5
#
# Config 3 SUMMARY:
#   [TRAIN AVG] MAE: 996.2 | R2: 0.9712 | Bias: 80.0
#   [VAL AVG]   MAE: 1237.9 | R2: 0.9520 | Bias: 99.1 | RMSE: 2129.5
# [NEW BEST RMSE] Config 3
#
# ######## CONFIG 4/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 600, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C4|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9625 | RMSE: 1891 | MAE: 1092 | Bias: 96.2
#   > [VAL]   R2: 0.9581 | RMSE: 1948 | MAE: 1247 | Bias: 59.7
#
# [C4|F2] Processing fold...
#   > [TRAIN] R2: 0.9649 | RMSE: 1825 | MAE: 1106 | Bias: 91.2
#   > [VAL]   R2: 0.9486 | RMSE: 2196 | MAE: 1290 | Bias: 86.8
#
# [C4|F3] Processing fold...
#   > [TRAIN] R2: 0.9690 | RMSE: 1717 | MAE: 1014 | Bias: 83.9
#   > [VAL]   R2: 0.9484 | RMSE: 2201 | MAE: 1254 | Bias: 139.7
#
# [C4|F4] Processing fold...
#   > [TRAIN] R2: 0.9674 | RMSE: 1748 | MAE: 1085 | Bias: 85.2
#   > [VAL]   R2: 0.9329 | RMSE: 2625 | MAE: 1299 | Bias: 133.1
#
# [C4|F5] Processing fold...
#   > [TRAIN] R2: 0.9715 | RMSE: 1642 | MAE: 999 | Bias: 74.0
#   > [VAL]   R2: 0.9575 | RMSE: 2023 | MAE: 1236 | Bias: 82.8
#
# [C4|F6] Processing fold...
#   > [TRAIN] R2: 0.9684 | RMSE: 1728 | MAE: 1046 | Bias: 84.9
#   > [VAL]   R2: 0.9519 | RMSE: 2153 | MAE: 1240 | Bias: 115.1
#
# [C4|F7] Processing fold...
#   > [TRAIN] R2: 0.9672 | RMSE: 1763 | MAE: 1063 | Bias: 89.8
#   > [VAL]   R2: 0.9564 | RMSE: 2030 | MAE: 1228 | Bias: 123.0
#
# [C4|F8] Processing fold...
#   > [TRAIN] R2: 0.9694 | RMSE: 1709 | MAE: 1049 | Bias: 87.0
#   > [VAL]   R2: 0.9573 | RMSE: 1963 | MAE: 1206 | Bias: 68.9
#
# Config 4 SUMMARY:
#   [TRAIN AVG] MAE: 1056.8 | R2: 0.9675 | Bias: 86.5
#   [VAL AVG]   MAE: 1250.1 | R2: 0.9514 | Bias: 101.2 | RMSE: 2142.3
#
# ######## CONFIG 5/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C5|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9664 | RMSE: 1790 | MAE: 1032 | Bias: 90.0
#   > [VAL]   R2: 0.9583 | RMSE: 1942 | MAE: 1239 | Bias: 54.7
#
# [C5|F2] Processing fold...
#   > [TRAIN] R2: 0.9678 | RMSE: 1749 | MAE: 1068 | Bias: 86.7
#   > [VAL]   R2: 0.9499 | RMSE: 2169 | MAE: 1281 | Bias: 86.6
#
# [C5|F3] Processing fold...
#   > [TRAIN] R2: 0.9685 | RMSE: 1731 | MAE: 1028 | Bias: 85.2
#   > [VAL]   R2: 0.9466 | RMSE: 2239 | MAE: 1265 | Bias: 140.9
#
# [C5|F4] Processing fold...
#   > [TRAIN] R2: 0.9732 | RMSE: 1585 | MAE: 999 | Bias: 76.7
#   > [VAL]   R2: 0.9331 | RMSE: 2622 | MAE: 1285 | Bias: 130.7
#
# [C5|F5] Processing fold...
#   > [TRAIN] R2: 0.9757 | RMSE: 1518 | MAE: 925 | Bias: 65.1
#   > [VAL]   R2: 0.9581 | RMSE: 2008 | MAE: 1225 | Bias: 72.4
#
# [C5|F6] Processing fold...
#   > [TRAIN] R2: 0.9674 | RMSE: 1755 | MAE: 1067 | Bias: 86.6
#   > [VAL]   R2: 0.9503 | RMSE: 2188 | MAE: 1256 | Bias: 116.7
#
# [C5|F7] Processing fold...
#   > [TRAIN] R2: 0.9700 | RMSE: 1686 | MAE: 1029 | Bias: 86.1
#   > [VAL]   R2: 0.9569 | RMSE: 2019 | MAE: 1221 | Bias: 127.8
#
# [C5|F8] Processing fold...
#   > [TRAIN] R2: 0.9720 | RMSE: 1634 | MAE: 1010 | Bias: 82.9
#   > [VAL]   R2: 0.9577 | RMSE: 1953 | MAE: 1201 | Bias: 66.6
#
# Config 5 SUMMARY:
#   [TRAIN AVG] MAE: 1019.6 | R2: 0.9701 | Bias: 82.4
#   [VAL AVG]   MAE: 1246.8 | R2: 0.9514 | Bias: 99.5 | RMSE: 2142.6
#
# ######## CONFIG 6/15 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 191, 'max_iter': 1200, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}
#
# [C6|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9675 | RMSE: 1760 | MAE: 1004 | Bias: 87.4
#   > [VAL]   R2: 0.9590 | RMSE: 1926 | MAE: 1229 | Bias: 56.1
#
# [C6|F2] Processing fold...
#   > [TRAIN] R2: 0.9707 | RMSE: 1667 | MAE: 1018 | Bias: 82.6
#   > [VAL]   R2: 0.9505 | RMSE: 2155 | MAE: 1266 | Bias: 94.3
#
# [C6|F3] Processing fold...
#   > [TRAIN] R2: 0.9706 | RMSE: 1670 | MAE: 989 | Bias: 81.4
#   > [VAL]   R2: 0.9474 | RMSE: 2223 | MAE: 1258 | Bias: 134.0
#
# [C6|F4] Processing fold...
#   > [TRAIN] R2: 0.9728 | RMSE: 1598 | MAE: 1006 | Bias: 77.9
#   > [VAL]   R2: 0.9342 | RMSE: 2600 | MAE: 1283 | Bias: 130.3
#
# [C6|F5] Processing fold...
#   > [TRAIN] R2: 0.9753 | RMSE: 1528 | MAE: 935 | Bias: 68.4
#   > [VAL]   R2: 0.9587 | RMSE: 1993 | MAE: 1225 | Bias: 79.4
#
# [C6|F6] Processing fold...
#   > [TRAIN] R2: 0.9735 | RMSE: 1585 | MAE: 958 | Bias: 76.8
#   > [VAL]   R2: 0.9543 | RMSE: 2099 | MAE: 1223 | Bias: 109.9
#
# [C6|F7] Processing fold...
#   > [TRAIN] R2: 0.9686 | RMSE: 1727 | MAE: 1043 | Bias: 88.0
#   > [VAL]   R2: 0.9570 | RMSE: 2017 | MAE: 1221 | Bias: 126.9
#
# [C6|F8] Processing fold...
#   > [TRAIN] R2: 0.9726 | RMSE: 1618 | MAE: 997 | Bias: 82.5
#   > [VAL]   R2: 0.9576 | RMSE: 1956 | MAE: 1202 | Bias: 73.3
#
# Config 6 SUMMARY:
#   [TRAIN AVG] MAE: 993.8 | R2: 0.9714 | Bias: 80.6
#   [VAL AVG]   MAE: 1238.5 | R2: 0.9523 | Bias: 100.5 | RMSE: 2121.2
# [NEW BEST RMSE] Config 6
#
# ######## CONFIG 7/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 800, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 0.3}
#
# [C7|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9583 | RMSE: 1995 | MAE: 1179 | Bias: 106.0
#   > [VAL]   R2: 0.9560 | RMSE: 1996 | MAE: 1286 | Bias: 67.6
#
# [C7|F2] Processing fold...
#   > [TRAIN] R2: 0.9662 | RMSE: 1792 | MAE: 1100 | Bias: 90.3
#   > [VAL]   R2: 0.9506 | RMSE: 2153 | MAE: 1279 | Bias: 96.1
#
# [C7|F3] Processing fold...
#   > [TRAIN] R2: 0.9627 | RMSE: 1881 | MAE: 1134 | Bias: 98.1
#   > [VAL]   R2: 0.9449 | RMSE: 2275 | MAE: 1300 | Bias: 154.8
#
# [C7|F4] Processing fold...
#   > [TRAIN] R2: 0.9672 | RMSE: 1753 | MAE: 1107 | Bias: 89.3
#   > [VAL]   R2: 0.9336 | RMSE: 2612 | MAE: 1298 | Bias: 139.4
#
# [C7|F5] Processing fold...
#   > [TRAIN] R2: 0.9669 | RMSE: 1770 | MAE: 1086 | Bias: 84.5
#   > [VAL]   R2: 0.9572 | RMSE: 2029 | MAE: 1250 | Bias: 87.9
#
# [C7|F6] Processing fold...
#   > [TRAIN] R2: 0.9667 | RMSE: 1775 | MAE: 1084 | Bias: 89.8
#   > [VAL]   R2: 0.9511 | RMSE: 2171 | MAE: 1251 | Bias: 121.9
#
# [C7|F7] Processing fold...
#   > [TRAIN] R2: 0.9668 | RMSE: 1774 | MAE: 1088 | Bias: 93.0
#   > [VAL]   R2: 0.9573 | RMSE: 2009 | MAE: 1233 | Bias: 119.7
#
# [C7|F8] Processing fold...
#   > [TRAIN] R2: 0.9643 | RMSE: 1845 | MAE: 1134 | Bias: 97.8
#   > [VAL]   R2: 0.9546 | RMSE: 2023 | MAE: 1250 | Bias: 77.6
#
# Config 7 SUMMARY:
#   [TRAIN AVG] MAE: 1113.8 | R2: 0.9649 | Bias: 93.6
#   [VAL AVG]   MAE: 1268.4 | R2: 0.9507 | Bias: 108.1 | RMSE: 2158.6
#
# ######## CONFIG 8/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C8|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9673 | RMSE: 1766 | MAE: 1016 | Bias: 87.5
#   > [VAL]   R2: 0.9592 | RMSE: 1922 | MAE: 1230 | Bias: 54.3
#
# [C8|F2] Processing fold...
#   > [TRAIN] R2: 0.9671 | RMSE: 1767 | MAE: 1081 | Bias: 88.3
#   > [VAL]   R2: 0.9505 | RMSE: 2155 | MAE: 1281 | Bias: 91.8
#
# [C8|F3] Processing fold...
#   > [TRAIN] R2: 0.9685 | RMSE: 1729 | MAE: 1023 | Bias: 86.7
#   > [VAL]   R2: 0.9480 | RMSE: 2211 | MAE: 1257 | Bias: 141.0
#
# [C8|F4] Processing fold...
#   > [TRAIN] R2: 0.9714 | RMSE: 1636 | MAE: 1030 | Bias: 80.9
#   > [VAL]   R2: 0.9333 | RMSE: 2618 | MAE: 1286 | Bias: 127.3
#
# [C8|F5] Processing fold...
#   > [TRAIN] R2: 0.9724 | RMSE: 1617 | MAE: 985 | Bias: 74.4
#   > [VAL]   R2: 0.9580 | RMSE: 2010 | MAE: 1227 | Bias: 82.2
#
# [C8|F6] Processing fold...
#   > [TRAIN] R2: 0.9681 | RMSE: 1736 | MAE: 1050 | Bias: 87.1
#   > [VAL]   R2: 0.9509 | RMSE: 2176 | MAE: 1245 | Bias: 117.8
#
# [C8|F7] Processing fold...
#   > [TRAIN] R2: 0.9659 | RMSE: 1798 | MAE: 1091 | Bias: 92.7
#   > [VAL]   R2: 0.9574 | RMSE: 2007 | MAE: 1230 | Bias: 123.4
#
# [C8|F8] Processing fold...
#   > [TRAIN] R2: 0.9725 | RMSE: 1620 | MAE: 998 | Bias: 82.5
#   > [VAL]   R2: 0.9572 | RMSE: 1965 | MAE: 1199 | Bias: 72.4
#
# Config 8 SUMMARY:
#   [TRAIN AVG] MAE: 1034.3 | R2: 0.9692 | Bias: 85.0
#   [VAL AVG]   MAE: 1244.2 | R2: 0.9518 | Bias: 101.3 | RMSE: 2133.0
#
# ######## CONFIG 9/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 0.3}
#
# [C9|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9674 | RMSE: 1763 | MAE: 1002 | Bias: 86.0
#   > [VAL]   R2: 0.9597 | RMSE: 1911 | MAE: 1222 | Bias: 55.7
#
# [C9|F2] Processing fold...
#   > [TRAIN] R2: 0.9698 | RMSE: 1693 | MAE: 1034 | Bias: 83.0
#   > [VAL]   R2: 0.9494 | RMSE: 2179 | MAE: 1277 | Bias: 93.9
#
# [C9|F3] Processing fold...
#   > [TRAIN] R2: 0.9734 | RMSE: 1590 | MAE: 928 | Bias: 75.2
#   > [VAL]   R2: 0.9503 | RMSE: 2161 | MAE: 1244 | Bias: 133.3
#
# [C9|F4] Processing fold...
#   > [TRAIN] R2: 0.9713 | RMSE: 1639 | MAE: 1026 | Bias: 79.1
#   > [VAL]   R2: 0.9321 | RMSE: 2640 | MAE: 1292 | Bias: 134.2
#
# [C9|F5] Processing fold...
#   > [TRAIN] R2: 0.9736 | RMSE: 1581 | MAE: 962 | Bias: 70.2
#   > [VAL]   R2: 0.9577 | RMSE: 2018 | MAE: 1236 | Bias: 85.0
#
# [C9|F6] Processing fold...
#   > [TRAIN] R2: 0.9715 | RMSE: 1643 | MAE: 993 | Bias: 79.3
#   > [VAL]   R2: 0.9510 | RMSE: 2173 | MAE: 1243 | Bias: 113.3
#
# [C9|F7] Processing fold...
#   > [TRAIN] R2: 0.9663 | RMSE: 1788 | MAE: 1084 | Bias: 91.5
#   > [VAL]   R2: 0.9570 | RMSE: 2017 | MAE: 1233 | Bias: 125.6
#
# [C9|F8] Processing fold...
#   > [TRAIN] R2: 0.9731 | RMSE: 1602 | MAE: 984 | Bias: 78.9
#   > [VAL]   R2: 0.9571 | RMSE: 1968 | MAE: 1203 | Bias: 67.2
#
# Config 9 SUMMARY:
#   [TRAIN AVG] MAE: 1001.5 | R2: 0.9708 | Bias: 80.4
#   [VAL AVG]   MAE: 1243.8 | R2: 0.9518 | Bias: 101.0 | RMSE: 2133.3
#
# ######## CONFIG 10/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 1.0}
#
# [C10|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9692 | RMSE: 1715 | MAE: 968 | Bias: 82.7
#   > [VAL]   R2: 0.9599 | RMSE: 1905 | MAE: 1219 | Bias: 53.0
#
# [C10|F2] Processing fold...
#   > [TRAIN] R2: 0.9718 | RMSE: 1635 | MAE: 1003 | Bias: 79.1
#   > [VAL]   R2: 0.9501 | RMSE: 2163 | MAE: 1273 | Bias: 87.8
#
# [C10|F3] Processing fold...
#   > [TRAIN] R2: 0.9675 | RMSE: 1756 | MAE: 1035 | Bias: 87.2
#   > [VAL]   R2: 0.9466 | RMSE: 2240 | MAE: 1264 | Bias: 143.6
#
# [C10|F4] Processing fold...
#   > [TRAIN] R2: 0.9745 | RMSE: 1546 | MAE: 972 | Bias: 73.9
#   > [VAL]   R2: 0.9341 | RMSE: 2603 | MAE: 1279 | Bias: 122.4
#
# [C10|F5] Processing fold...
#   > [TRAIN] R2: 0.9737 | RMSE: 1576 | MAE: 956 | Bias: 70.3
#   > [VAL]   R2: 0.9575 | RMSE: 2021 | MAE: 1230 | Bias: 85.4
#
# [C10|F6] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1687 | MAE: 1017 | Bias: 82.2
#   > [VAL]   R2: 0.9509 | RMSE: 2174 | MAE: 1244 | Bias: 115.8
#
# [C10|F7] Processing fold...
#   > [TRAIN] R2: 0.9709 | RMSE: 1661 | MAE: 1003 | Bias: 82.8
#   > [VAL]   R2: 0.9584 | RMSE: 1983 | MAE: 1207 | Bias: 120.6
#
# [C10|F8] Processing fold...
#   > [TRAIN] R2: 0.9721 | RMSE: 1633 | MAE: 1002 | Bias: 81.7
#   > [VAL]   R2: 0.9572 | RMSE: 1965 | MAE: 1207 | Bias: 64.9
#
# Config 10 SUMMARY:
#   [TRAIN AVG] MAE: 994.5 | R2: 0.9712 | Bias: 80.0
#   [VAL AVG]   MAE: 1240.3 | R2: 0.9519 | Bias: 99.2 | RMSE: 2131.7
#
# ######## CONFIG 11/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}
#
# [C11|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9660 | RMSE: 1802 | MAE: 1038 | Bias: 88.8
#   > [VAL]   R2: 0.9590 | RMSE: 1927 | MAE: 1236 | Bias: 45.7
#
# [C11|F2] Processing fold...
#   > [TRAIN] R2: 0.9656 | RMSE: 1808 | MAE: 1095 | Bias: 89.5
#   > [VAL]   R2: 0.9487 | RMSE: 2193 | MAE: 1285 | Bias: 92.6
#
# [C11|F3] Processing fold...
#   > [TRAIN] R2: 0.9675 | RMSE: 1756 | MAE: 1038 | Bias: 86.0
#   > [VAL]   R2: 0.9474 | RMSE: 2223 | MAE: 1262 | Bias: 143.9
#
# [C11|F4] Processing fold...
#   > [TRAIN] R2: 0.9641 | RMSE: 1834 | MAE: 1131 | Bias: 91.9
#   > [VAL]   R2: 0.9318 | RMSE: 2646 | MAE: 1316 | Bias: 143.5
#
# [C11|F5] Processing fold...
#   > [TRAIN] R2: 0.9705 | RMSE: 1670 | MAE: 1015 | Bias: 75.5
#   > [VAL]   R2: 0.9575 | RMSE: 2022 | MAE: 1235 | Bias: 82.0
#
# [C11|F6] Processing fold...
#   > [TRAIN] R2: 0.9689 | RMSE: 1715 | MAE: 1044 | Bias: 84.6
#   > [VAL]   R2: 0.9526 | RMSE: 2138 | MAE: 1241 | Bias: 113.4
#
# [C11|F7] Processing fold...
#   > [TRAIN] R2: 0.9669 | RMSE: 1771 | MAE: 1069 | Bias: 89.5
#   > [VAL]   R2: 0.9577 | RMSE: 2001 | MAE: 1225 | Bias: 118.2
#
# [C11|F8] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1695 | MAE: 1041 | Bias: 86.7
#   > [VAL]   R2: 0.9567 | RMSE: 1977 | MAE: 1212 | Bias: 68.8
#
# Config 11 SUMMARY:
#   [TRAIN AVG] MAE: 1059.0 | R2: 0.9674 | Bias: 86.6
#   [VAL AVG]   MAE: 1251.5 | R2: 0.9514 | Bias: 101.0 | RMSE: 2140.8
#
# ######## CONFIG 12/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 3.0}
#
# [C12|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9660 | RMSE: 1802 | MAE: 1030 | Bias: 87.3
#   > [VAL]   R2: 0.9589 | RMSE: 1929 | MAE: 1234 | Bias: 55.1
#
# [C12|F2] Processing fold...
#   > [TRAIN] R2: 0.9674 | RMSE: 1760 | MAE: 1076 | Bias: 86.0
#   > [VAL]   R2: 0.9487 | RMSE: 2194 | MAE: 1285 | Bias: 88.8
#
# [C12|F3] Processing fold...
#   > [TRAIN] R2: 0.9696 | RMSE: 1697 | MAE: 1003 | Bias: 81.5
#   > [VAL]   R2: 0.9483 | RMSE: 2203 | MAE: 1257 | Bias: 137.9
#
# [C12|F4] Processing fold...
#   > [TRAIN] R2: 0.9731 | RMSE: 1587 | MAE: 999 | Bias: 74.5
#   > [VAL]   R2: 0.9344 | RMSE: 2595 | MAE: 1278 | Bias: 134.7
#
# [C12|F5] Processing fold...
#   > [TRAIN] R2: 0.9697 | RMSE: 1692 | MAE: 1029 | Bias: 76.8
#   > [VAL]   R2: 0.9561 | RMSE: 2054 | MAE: 1248 | Bias: 81.4
#
# [C12|F6] Processing fold...
#   > [TRAIN] R2: 0.9661 | RMSE: 1790 | MAE: 1082 | Bias: 87.8
#   > [VAL]   R2: 0.9507 | RMSE: 2181 | MAE: 1253 | Bias: 114.0
#
# [C12|F7] Processing fold...
#   > [TRAIN] R2: 0.9649 | RMSE: 1826 | MAE: 1102 | Bias: 92.0
#   > [VAL]   R2: 0.9571 | RMSE: 2015 | MAE: 1238 | Bias: 123.4
#
# [C12|F8] Processing fold...
#   > [TRAIN] R2: 0.9690 | RMSE: 1721 | MAE: 1057 | Bias: 86.8
#   > [VAL]   R2: 0.9558 | RMSE: 1998 | MAE: 1224 | Bias: 71.4
#
# Config 12 SUMMARY:
#   [TRAIN AVG] MAE: 1047.2 | R2: 0.9682 | Bias: 84.1
#   [VAL AVG]   MAE: 1252.1 | R2: 0.9513 | Bias: 100.8 | RMSE: 2146.1
#
# ######## CONFIG 13/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 600, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 0.3}
#
# [C13|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9629 | RMSE: 1881 | MAE: 1099 | Bias: 95.8
#   > [VAL]   R2: 0.9580 | RMSE: 1951 | MAE: 1249 | Bias: 59.4
#
# [C13|F2] Processing fold...
#   > [TRAIN] R2: 0.9654 | RMSE: 1812 | MAE: 1119 | Bias: 93.9
#   > [VAL]   R2: 0.9506 | RMSE: 2153 | MAE: 1284 | Bias: 98.0
#
# [C13|F3] Processing fold...
#   > [TRAIN] R2: 0.9650 | RMSE: 1822 | MAE: 1096 | Bias: 93.0
#   > [VAL]   R2: 0.9466 | RMSE: 2240 | MAE: 1278 | Bias: 145.6
#
# [C13|F4] Processing fold...
#   > [TRAIN] R2: 0.9683 | RMSE: 1722 | MAE: 1090 | Bias: 87.7
#   > [VAL]   R2: 0.9335 | RMSE: 2613 | MAE: 1299 | Bias: 126.9
#
# [C13|F5] Processing fold...
#   > [TRAIN] R2: 0.9662 | RMSE: 1789 | MAE: 1097 | Bias: 85.3
#   > [VAL]   R2: 0.9572 | RMSE: 2030 | MAE: 1252 | Bias: 83.0
#
# [C13|F6] Processing fold...
#   > [TRAIN] R2: 0.9660 | RMSE: 1793 | MAE: 1095 | Bias: 91.9
#   > [VAL]   R2: 0.9515 | RMSE: 2163 | MAE: 1252 | Bias: 121.1
#
# [C13|F7] Processing fold...
#   > [TRAIN] R2: 0.9663 | RMSE: 1788 | MAE: 1095 | Bias: 93.7
#   > [VAL]   R2: 0.9581 | RMSE: 1990 | MAE: 1229 | Bias: 120.6
#
# [C13|F8] Processing fold...
#   > [TRAIN] R2: 0.9666 | RMSE: 1786 | MAE: 1099 | Bias: 93.8
#   > [VAL]   R2: 0.9557 | RMSE: 2000 | MAE: 1237 | Bias: 78.7
#
# Config 13 SUMMARY:
#   [TRAIN AVG] MAE: 1098.7 | R2: 0.9658 | Bias: 91.9
#   [VAL AVG]   MAE: 1260.0 | R2: 0.9514 | Bias: 104.2 | RMSE: 2142.5
#
# ######## CONFIG 14/15 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C14|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9693 | RMSE: 1713 | MAE: 981 | Bias: 83.3
#   > [VAL]   R2: 0.9595 | RMSE: 1914 | MAE: 1223 | Bias: 57.2
#
# [C14|F2] Processing fold...
#   > [TRAIN] R2: 0.9713 | RMSE: 1650 | MAE: 1012 | Bias: 81.5
#   > [VAL]   R2: 0.9508 | RMSE: 2147 | MAE: 1266 | Bias: 82.9
#
# [C14|F3] Processing fold...
#   > [TRAIN] R2: 0.9707 | RMSE: 1667 | MAE: 986 | Bias: 82.8
#   > [VAL]   R2: 0.9479 | RMSE: 2213 | MAE: 1260 | Bias: 144.6
#
# [C14|F4] Processing fold...
#   > [TRAIN] R2: 0.9719 | RMSE: 1624 | MAE: 1027 | Bias: 80.4
#   > [VAL]   R2: 0.9346 | RMSE: 2593 | MAE: 1285 | Bias: 132.3
#
# [C14|F5] Processing fold...
#   > [TRAIN] R2: 0.9719 | RMSE: 1630 | MAE: 1004 | Bias: 75.3
#   > [VAL]   R2: 0.9572 | RMSE: 2029 | MAE: 1242 | Bias: 81.5
#
# [C14|F6] Processing fold...
#   > [TRAIN] R2: 0.9725 | RMSE: 1613 | MAE: 979 | Bias: 79.1
#   > [VAL]   R2: 0.9534 | RMSE: 2119 | MAE: 1231 | Bias: 113.9
#
# [C14|F7] Processing fold...
#   > [TRAIN] R2: 0.9704 | RMSE: 1676 | MAE: 1026 | Bias: 86.3
#   > [VAL]   R2: 0.9586 | RMSE: 1978 | MAE: 1214 | Bias: 119.4
#
# [C14|F8] Processing fold...
#   > [TRAIN] R2: 0.9692 | RMSE: 1713 | MAE: 1057 | Bias: 89.0
#   > [VAL]   R2: 0.9558 | RMSE: 1996 | MAE: 1225 | Bias: 79.2
#
# Config 14 SUMMARY:
#   [TRAIN AVG] MAE: 1009.0 | R2: 0.9709 | Bias: 82.2
#   [VAL AVG]   MAE: 1243.3 | R2: 0.9522 | Bias: 101.4 | RMSE: 2123.7
#
# ######## CONFIG 15/15 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 63, 'max_iter': 600, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 0.3}
#
# [C15|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9635 | RMSE: 1866 | MAE: 1095 | Bias: 93.8
#   > [VAL]   R2: 0.9584 | RMSE: 1941 | MAE: 1254 | Bias: 56.7
#
# [C15|F2] Processing fold...
#   > [TRAIN] R2: 0.9661 | RMSE: 1795 | MAE: 1112 | Bias: 92.4
#   > [VAL]   R2: 0.9497 | RMSE: 2171 | MAE: 1292 | Bias: 98.1
#
# [C15|F3] Processing fold...
#   > [TRAIN] R2: 0.9654 | RMSE: 1813 | MAE: 1090 | Bias: 91.5
#   > [VAL]   R2: 0.9480 | RMSE: 2209 | MAE: 1283 | Bias: 140.3
#
# [C15|F4] Processing fold...
#   > [TRAIN] R2: 0.9689 | RMSE: 1707 | MAE: 1082 | Bias: 85.7
#   > [VAL]   R2: 0.9330 | RMSE: 2623 | MAE: 1303 | Bias: 133.0
#
# [C15|F5] Processing fold...
#   > [TRAIN] R2: 0.9697 | RMSE: 1694 | MAE: 1041 | Bias: 78.4
#   > [VAL]   R2: 0.9566 | RMSE: 2044 | MAE: 1247 | Bias: 86.2
#
# [C15|F6] Processing fold...
#   > [TRAIN] R2: 0.9682 | RMSE: 1734 | MAE: 1059 | Bias: 86.6
#   > [VAL]   R2: 0.9529 | RMSE: 2131 | MAE: 1249 | Bias: 121.2
#
# [C15|F7] Processing fold...
#   > [TRAIN] R2: 0.9663 | RMSE: 1788 | MAE: 1102 | Bias: 93.9
#   > [VAL]   R2: 0.9565 | RMSE: 2028 | MAE: 1241 | Bias: 121.2
#
# [C15|F8] Processing fold...
#   > [TRAIN] R2: 0.9695 | RMSE: 1708 | MAE: 1058 | Bias: 87.9
#   > [VAL]   R2: 0.9556 | RMSE: 2001 | MAE: 1230 | Bias: 73.5
#
# Config 15 SUMMARY:
#   [TRAIN AVG] MAE: 1080.0 | R2: 0.9672 | Bias: 88.8
#   [VAL AVG]   MAE: 1262.4 | R2: 0.9513 | Bias: 103.8 | RMSE: 2143.6
# # END OF SEARCH
#
# Top 5 Configurations by RMSE:
#     config_id  learning_rate  max_iter     val_rmse      val_mae    val_r2  \
# 5           6          0.070      1200  2121.223318  1238.538884  0.952332
# 13         14          0.100       800  2123.676237  1243.303216  0.952237
# 2           3          0.070      1000  2129.452632  1237.858309  0.951975
# 9          10          0.085       600  2131.680261  1240.302790  0.951854
# 7           8          0.070       800  2132.950761  1244.230460  0.951805
#
#     train_r2    val_bias
# 5   0.971441  100.510994
# 13  0.970903  101.387925
# 2   0.971202   99.126210
# 9   0.971210   99.187575
# 7   0.969162  101.263735
# Best Config found:
# {'min_samples_leaf': 16, 'max_leaf_nodes': 191, 'max_iter': 1200, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}

# %% [markdown]
# #### 4.3.1. Conducting a Random Search

# %% [markdown]
# - We performed a random search to identify an appropriate feature selection configuration when using the additional engineered features.
# - We then conducted a stricter search restricting the retained feature ratio to 60-70%, since this range produced the best results and kept the feature count closest to the original set.
# - We did not observe an improvement over our previously obtained RMSE values, hence why we ran another search.

# %%
numeric_features = ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners']

# %%
import numpy as np
import pandas as pd
import random
import logging

from IPython.display import display
from sklearn.model_selection import KFold
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# ---------------------------------------------------------
# 0) GENERAL CONFIG
# ---------------------------------------------------------
N_SPLITS = 8
N_ITER = 40
RANDOM_STATE = 42

FS_KEEP_CHOICES = [0.30, 0.40, 0.50, 0.60, 0.70, 0.80]

RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

# ---------------------------------------------------------
# 0.1) FILES
# ---------------------------------------------------------
LOG_FILE = "random_search_hgb_fsweep_40.log"
CSV_FILE = "random_search_hgb_fsweep_40.csv"

logging.basicConfig(
    filename=LOG_FILE,
    level=logging.INFO,
    format="%(asctime)s - %(message)s",
    filemode="w",
    force=True
)
logging.info(f"- {N_ITER} configs")

# ---------------------------------------------------------
# 0.2) RANDOM SEARCH SPACE (HGB)
# ---------------------------------------------------------
param_distributions = {
    "min_samples_leaf": [20, 30, 40],
    "max_leaf_nodes": [31, 63, 127],
    "max_iter": [600, 800, 1000],
    "max_depth": [None, 15, 20, 25],
    "learning_rate": np.linspace(0.08, 0.15, 20),
    "l2_regularization": np.linspace(0.5, 2.5, 20),
    "max_bins": [255],
    "random_state": [RANDOM_STATE],
}

def get_random_configs(n_iter: int):
    configs = []
    keys = list(param_distributions.keys())

    for i in range(n_iter):
        params = {}
        for key in keys:
            params[key] = random.choice(list(param_distributions[key]))

        fs_keep_ratio = random.choice(FS_KEEP_CHOICES)

        name = (
            f"R{i}"
            f"_iter{params['max_iter']}"
            f"_lr{float(params['learning_rate']):.3f}"
            f"_l2{float(params['l2_regularization']):.2f}"
            f"_leaf{params['max_leaf_nodes']}"
            f"_fs{int(fs_keep_ratio*100)}"
        )

        configs.append((name, params, fs_keep_ratio))
    return configs

CONFIGS = get_random_configs(N_ITER)

# ---------------------------------------------------------
# 1) K-FOLD
# ---------------------------------------------------------
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# Assume you already have in the notebook:
# X, y
# numeric_features, categorical_features
# fill_unknown, column_string_transformer
# fit_* and transform_* steps
# valid_brands, valid_models_by_brand, valid_transmissions, valid_fueltypes
# MyTargetEncoder, MyOneHotEncoder

cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]
high_card_features = ["Brand", "model"]
low_card_features  = [c for c in categorical_features if c not in high_card_features]

def _normalize_cats(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    for col in cols_to_normalize:
        if col in df.columns:
            df[col] = fill_unknown(df[col])
            df = column_string_transformer(
                df, column=col, remove_middle_spaces=True, allow_extra_chars=""
            )
    return df

# ---------------------------------------------------------
# 1.1) FEATURE ENGINEERING
# ---------------------------------------------------------
def create_age_and_drop_year(df, year_col="year", base_year=2020, clip_future=True):
    df = df.copy()
    year = pd.to_numeric(df[year_col], errors="coerce")
    age = base_year - year
    if clip_future:
        age = age.clip(lower=0)
    df["age"] = age
    df = df.drop(columns=[year_col])
    return df

def add_owners_flagged(
    df,
    owners_col="previousOwners",
    new_col="owners_flagged",
    drop_original=True,
    na_as_zero=True
):
    df = df.copy()
    owners = pd.to_numeric(df[owners_col], errors="coerce")

    if na_as_zero:
        owners_filled = owners.fillna(0)
        df[new_col] = (owners_filled > 1).astype("int8")
    else:
        df[new_col] = (owners > 1).fillna(False).astype("int8")

    if drop_original and owners_col in df.columns:
        df = df.drop(columns=[owners_col])

    return df

def add_mileage_features(df, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True):
    df = df.copy()

    mileage = pd.to_numeric(df[mileage_col], errors="coerce")
    mileage = mileage.where(mileage >= 0, np.nan)

    df["log_mileage"] = np.log1p(mileage)

    age = pd.to_numeric(df[age_col], errors="coerce")
    age_safe = age.clip(lower=1)
    df["miles_per_year"] = mileage / age_safe
    df["log_miles_per_year"] = np.log1p(df["miles_per_year"])

    if drop_ratio and "miles_per_year" in df.columns:
        df = df.drop(columns=["miles_per_year"])

    if drop_original and mileage_col in df.columns:
        df = df.drop(columns=[mileage_col])

    return df

def add_engine_bins(df, engine_col="engineSize", new_col="engine_bin", bins=None):
    df = df.copy()

    engine = pd.to_numeric(df[engine_col], errors="coerce")
    engine = engine.where(engine >= 0, np.nan)

    if bins is None:
        bins = [0, 1.0, 1.3, 1.6, 2.0, 2.5, 3.0, 4.0, np.inf]

    df[new_col] = pd.cut(engine, bins=bins, include_lowest=True, labels=False).astype("Int64")
    return df

# ---------------------------------------------------------
# 1.2) METRICS
# ---------------------------------------------------------
def _rmse(y_true, y_pred) -> float:
    return float(np.sqrt(mean_squared_error(y_true, y_pred)))

def _bias(y_true, y_pred) -> float:
    # mean error: positive => overprediction
    return float(np.mean(y_pred - y_true))

# ---------------------------------------------------------
# 1.3) EVAL ONE CONFIG
# ---------------------------------------------------------
def eval_one_config(name: str, params: dict, fs_keep_ratio: float) -> dict:
    fold_rows = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):
        X_train = X.iloc[train_idx].copy()
        X_val   = X.iloc[val_idx].copy()
        y_train = y.iloc[train_idx].copy()
        y_val   = y.iloc[val_idx].copy()

        y_train_log = np.log1p(y_train)

        X_train = _normalize_cats(X_train)
        X_val   = _normalize_cats(X_val)

        base_cols = [c for c in (numeric_features + categorical_features) if c in X_train.columns]
        X_train = X_train[base_cols].copy()
        X_val   = X_val[base_cols].copy()

        # A) CLEANING
        year_state = fit_year_median(X_train, year_col="year", model_col="model")
        X_train = transform_year_with_model_median(X_train, state=year_state)
        X_val   = transform_year_with_model_median(X_val,   state=year_state)

        engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
        X_train = transform_engine_size_imputer(X_train, state=engine_state)
        X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

        X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
        X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

        mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
        X_train = transform_mpg_imputer(X_train, state=mpg_state)
        X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

        owners_state = fit_previous_owners_imputer(X_train, "previousOwners", "year", "mileage")
        X_train = transform_previous_owners_imputer(X_train, state=owners_state)
        X_val   = transform_previous_owners_imputer(X_val,   state=owners_state)

        # B) RESOLVERS
        brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
        X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
        X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

        model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
        X_train, _, _ = transform_invalid_models(X_train, model_state)
        X_val,   _, _ = transform_invalid_models(X_val,   model_state)

        transm_state = fit_transmission_resolver(X_train, valid_transmissions)
        X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
        X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

        fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
        X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
        X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

        # C) FEATURE ENGINEERING
        X_train = add_owners_flagged(X_train, owners_col="previousOwners", new_col="owners_flagged", drop_original=True)
        X_val   = add_owners_flagged(X_val,   owners_col="previousOwners", new_col="owners_flagged", drop_original=True)

        X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
        X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

        X_train = add_mileage_features(X_train, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
        X_val   = add_mileage_features(X_val,   mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)

        X_train = add_engine_bins(X_train, engine_col="engineSize", new_col="engine_bin")
        X_val   = add_engine_bins(X_val,   engine_col="engineSize", new_col="engine_bin")

        X_train["engine_bin"] = X_train["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        X_val["engine_bin"]   = X_val["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")

        low_card_curr = low_card_features + ["engine_bin"]

        # D) ENCODING
        te = MyTargetEncoder(smoothing=5)
        te.fit(X_train[high_card_features], y_train_log)
        X_train_high = te.transform(X_train[high_card_features])
        X_val_high   = te.transform(X_val[high_card_features])

        ohe = MyOneHotEncoder()
        ohe.fit(X_train[low_card_curr])
        X_train_low = ohe.transform(X_train[low_card_curr])
        X_val_low   = ohe.transform(X_val[low_card_curr])

        X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
        X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

        drop_for_numeric = set(high_card_features + low_card_curr)
        numeric_features_curr = [c for c in X_train.columns if c not in drop_for_numeric]

        X_train_final = pd.concat([X_train[numeric_features_curr], X_train_cat], axis=1)
        X_val_final   = pd.concat([X_val[numeric_features_curr],   X_val_cat],   axis=1)
        X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

        # D.1) FEATURE SELECTION (ratio per config)
        n_feats = X_train_final.shape[1]
        k = int(np.ceil(fs_keep_ratio * n_feats))
        k = max(1, min(k, n_feats))

        rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
        rf_fs.fit(X_train_final, y_train_log)

        selector = SelectFromModel(
            estimator=rf_fs,
            threshold=-np.inf,
            max_features=k,
            prefit=True
        )

        selected_cols = X_train_final.columns[selector.get_support()]
        X_train_sel = X_train_final[selected_cols]
        X_val_sel   = X_val_final[selected_cols]

        # E) TRAIN (HGB)
        model = HistGradientBoostingRegressor(**params)
        model.fit(X_train_sel, y_train_log)

        pred_tr_log  = model.predict(X_train_sel)
        pred_val_log = model.predict(X_val_sel)

        pred_tr  = np.expm1(pred_tr_log)
        pred_val = np.expm1(pred_val_log)

        # metrics on original scale
        rmse_tr = _rmse(y_train, pred_tr)
        rmse_v  = _rmse(y_val,   pred_val)
        mae_tr  = mean_absolute_error(y_train, pred_tr)
        mae_v   = mean_absolute_error(y_val,   pred_val)
        r2_tr   = r2_score(y_train, pred_tr)
        r2_v    = r2_score(y_val,   pred_val)
        bias_tr = _bias(y_train.to_numpy(), pred_tr)
        bias_v  = _bias(y_val.to_numpy(),   pred_val)

        fold_rows.append({
            "config": name,
            "fold": fold,
            "fs_keep_ratio": fs_keep_ratio,
            "n_features_total": n_feats,
            "n_features_selected": len(selected_cols),

            "train_rmse": rmse_tr,
            "val_rmse": rmse_v,
            "train_mae": mae_tr,
            "val_mae": mae_v,
            "train_r2": r2_tr,
            "val_r2": r2_v,
            "train_bias": bias_tr,
            "val_bias": bias_v,
        })

    df_folds = pd.DataFrame(fold_rows)

    out = {
        "config": name,
        "fs_keep_ratio": fs_keep_ratio,
        "avg_selected_features": float(df_folds["n_features_selected"].mean()),

        "train_rmse_mean": float(df_folds["train_rmse"].mean()),
        "val_rmse_mean": float(df_folds["val_rmse"].mean()),
        "train_mae_mean": float(df_folds["train_mae"].mean()),
        "val_mae_mean": float(df_folds["val_mae"].mean()),
        "train_r2_mean": float(df_folds["train_r2"].mean()),
        "val_r2_mean": float(df_folds["val_r2"].mean()),
        "train_bias_mean": float(df_folds["train_bias"].mean()),
        "val_bias_mean": float(df_folds["val_bias"].mean()),

        **params
    }

    print(
        f"- {name} | fs_keep={int(fs_keep_ratio*100)}% | sel={out['avg_selected_features']:.0f} feats | "
        f"train: rmse={out['train_rmse_mean']:.2f}, mae={out['train_mae_mean']:.2f}, r2={out['train_r2_mean']:.4f}, bias={out['train_bias_mean']:.2f} | "
        f"val: rmse={out['val_rmse_mean']:.2f}, mae={out['val_mae_mean']:.2f}, r2={out['val_r2_mean']:.4f}, bias={out['val_bias_mean']:.2f}"
    )

    logging.info(
        f"{name} | fs_keep={int(fs_keep_ratio*100)}% | "
        f"train rmse={out['train_rmse_mean']:.4f} mae={out['train_mae_mean']:.4f} r2={out['train_r2_mean']:.6f} bias={out['train_bias_mean']:.4f} | "
        f"val rmse={out['val_rmse_mean']:.4f} mae={out['val_mae_mean']:.4f} r2={out['val_r2_mean']:.6f} bias={out['val_bias_mean']:.4f} | "
        f"params={params}"
    )

    return out

# ---------------------------------------------------------
# 2) RUN ALL CONFIGS
# ---------------------------------------------------------
results = []
for i, (name, params, fs_keep_ratio) in enumerate(CONFIGS, start=1):
    if i % 5 == 1:
        print(f"\n- running {i}/{len(CONFIGS)}")
    results.append(eval_one_config(name, params, fs_keep_ratio))

results_df = pd.DataFrame(results)

# ---------------------------------------------------------
# 3) FINAL RESULTS (SORT BY VAL RMSE)
# ---------------------------------------------------------
results_df_sorted = results_df.sort_values("val_rmse_mean", ascending=True)

print("\n- top 10 by validation RMSE")
cols_show = [
    "config", "fs_keep_ratio", "avg_selected_features",
    "val_rmse_mean", "val_mae_mean", "val_r2_mean", "val_bias_mean",
    "train_rmse_mean", "train_mae_mean", "train_r2_mean", "train_bias_mean",
    "learning_rate", "max_iter", "l2_regularization", "max_leaf_nodes", "max_depth", "min_samples_leaf"
]
display(results_df_sorted[cols_show].head(10))

results_df_sorted.to_csv(CSV_FILE, index=False)
print(f"- saved csv: {CSV_FILE}")
print(f"- saved log: {LOG_FILE}")
# Out:
# - running 1/40
# - R0_iter800_lr0.135_l21.13_leaf63_fs80 | fs_keep=80% | sel=20 feats | train: rmse=1835.63, mae=1116.59, r2=0.9644, bias=-91.38 | val: rmse=2177.80, mae=1283.96, r2=0.9498, bias=-103.11
# - R1_iter800_lr0.121_l20.92_leaf127_fs40 | fs_keep=40% | sel=10 feats | train: rmse=1718.14, mae=1037.33, r2=0.9688, bias=-85.90 | val: rmse=2180.02, mae=1277.78, r2=0.9497, bias=-103.81
# - R2_iter1000_lr0.146_l21.34_leaf63_fs30 | fs_keep=30% | sel=8 feats | train: rmse=1879.02, mae=1135.12, r2=0.9627, bias=-92.89 | val: rmse=2192.43, mae=1287.56, r2=0.9491, bias=-101.29
# - R3_iter1000_lr0.135_l22.18_leaf63_fs30 | fs_keep=30% | sel=8 feats | train: rmse=1852.46, mae=1118.92, r2=0.9638, bias=-91.57 | val: rmse=2190.03, mae=1282.74, r2=0.9492, bias=-102.27
# - R4_iter600_lr0.124_l20.61_leaf127_fs40 | fs_keep=40% | sel=10 feats | train: rmse=1765.17, mae=1056.88, r2=0.9671, bias=-86.72 | val: rmse=2195.81, mae=1281.08, r2=0.9490, bias=-101.29
#
# - running 6/40
# - R5_iter1000_lr0.124_l20.61_leaf63_fs30 | fs_keep=30% | sel=8 feats | train: rmse=1841.33, mae=1117.24, r2=0.9641, bias=-91.86 | val: rmse=2187.76, mae=1281.64, r2=0.9494, bias=-104.40
# - R6_iter600_lr0.113_l22.50_leaf63_fs40 | fs_keep=40% | sel=10 feats | train: rmse=1888.02, mae=1139.31, r2=0.9623, bias=-96.71 | val: rmse=2212.89, mae=1299.27, r2=0.9482, bias=-107.48
# - R7_iter600_lr0.139_l20.50_leaf31_fs70 | fs_keep=70% | sel=18 feats | train: rmse=1934.67, mae=1177.96, r2=0.9604, bias=-98.35 | val: rmse=2209.76, mae=1307.72, r2=0.9483, bias=-106.70
# - R8_iter1000_lr0.143_l22.08_leaf31_fs30 | fs_keep=30% | sel=8 feats | train: rmse=1959.38, mae=1197.65, r2=0.9594, bias=-101.70 | val: rmse=2217.50, mae=1317.11, r2=0.9480, bias=-109.08
# - R9_iter1000_lr0.132_l20.92_leaf31_fs60 | fs_keep=60% | sel=15 feats | train: rmse=1891.20, mae=1160.16, r2=0.9622, bias=-97.86 | val: rmse=2190.61, mae=1300.87, r2=0.9492, bias=-109.41
#
# - running 11/40
# - R10_iter1000_lr0.143_l21.55_leaf63_fs30 | fs_keep=30% | sel=8 feats | train: rmse=1823.05, mae=1110.84, r2=0.9649, bias=-91.10 | val: rmse=2177.94, mae=1282.14, r2=0.9498, bias=-101.86
# - R11_iter600_lr0.132_l21.34_leaf127_fs50 | fs_keep=50% | sel=13 feats | train: rmse=1757.92, mae=1054.04, r2=0.9674, bias=-87.20 | val: rmse=2200.63, mae=1280.07, r2=0.9487, bias=-101.95
# - R12_iter800_lr0.080_l20.92_leaf31_fs40 | fs_keep=40% | sel=10 feats | train: rmse=2061.35, mae=1241.30, r2=0.9551, bias=-109.95 | val: rmse=2275.93, mae=1341.81, r2=0.9452, bias=-120.65
# - R13_iter1000_lr0.087_l21.97_leaf63_fs70 | fs_keep=70% | sel=18 feats | train: rmse=1800.35, mae=1091.88, r2=0.9657, bias=-91.21 | val: rmse=2175.47, mae=1272.31, r2=0.9499, bias=-104.36
# - R14_iter600_lr0.146_l22.39_leaf63_fs30 | fs_keep=30% | sel=8 feats | train: rmse=1851.82, mae=1122.34, r2=0.9638, bias=-91.93 | val: rmse=2188.57, mae=1283.47, r2=0.9493, bias=-102.91
#
# - running 16/40
# - R15_iter800_lr0.102_l21.34_leaf31_fs60 | fs_keep=60% | sel=15 feats | train: rmse=1943.39, mae=1186.29, r2=0.9601, bias=-102.08 | val: rmse=2200.26, mae=1304.71, r2=0.9488, bias=-111.23
# - R16_iter1000_lr0.109_l21.97_leaf63_fs50 | fs_keep=50% | sel=13 feats | train: rmse=1909.40, mae=1154.44, r2=0.9614, bias=-97.72 | val: rmse=2240.64, mae=1308.73, r2=0.9469, bias=-110.74
# - R17_iter1000_lr0.106_l21.97_leaf31_fs70 | fs_keep=70% | sel=18 feats | train: rmse=1903.24, mae=1160.35, r2=0.9618, bias=-97.90 | val: rmse=2184.36, mae=1294.31, r2=0.9495, bias=-107.89
# - R18_iter600_lr0.109_l20.50_leaf31_fs50 | fs_keep=50% | sel=13 feats | train: rmse=2016.21, mae=1218.24, r2=0.9571, bias=-105.98 | val: rmse=2268.68, mae=1334.02, r2=0.9456, bias=-116.23
# - R19_iter800_lr0.117_l20.92_leaf31_fs40 | fs_keep=40% | sel=10 feats | train: rmse=1948.18, mae=1186.38, r2=0.9599, bias=-102.48 | val: rmse=2218.82, mae=1317.44, r2=0.9479, bias=-112.40
#
# - running 21/40
# - R20_iter800_lr0.121_l22.39_leaf31_fs40 | fs_keep=40% | sel=10 feats | train: rmse=1966.88, mae=1200.72, r2=0.9591, bias=-104.35 | val: rmse=2234.92, mae=1323.96, r2=0.9471, bias=-114.12
# - R21_iter600_lr0.098_l21.55_leaf31_fs40 | fs_keep=40% | sel=10 feats | train: rmse=1980.99, mae=1206.70, r2=0.9586, bias=-105.74 | val: rmse=2240.53, mae=1326.97, r2=0.9469, bias=-116.78
# - R22_iter800_lr0.146_l21.24_leaf63_fs70 | fs_keep=70% | sel=18 feats | train: rmse=1776.96, mae=1085.67, r2=0.9666, bias=-89.10 | val: rmse=2158.91, mae=1277.97, r2=0.9507, bias=-103.74
# - R23_iter800_lr0.146_l20.71_leaf127_fs80 | fs_keep=80% | sel=20 feats | train: rmse=1705.30, mae=1034.30, r2=0.9693, bias=-83.94 | val: rmse=2166.55, mae=1266.31, r2=0.9503, bias=-102.78
# - R24_iter800_lr0.084_l21.24_leaf31_fs50 | fs_keep=50% | sel=13 feats | train: rmse=1994.47, mae=1207.19, r2=0.9580, bias=-104.83 | val: rmse=2250.79, mae=1324.50, r2=0.9464, bias=-114.66
#
# - running 26/40
# - R25_iter600_lr0.102_l22.18_leaf127_fs70 | fs_keep=70% | sel=18 feats | train: rmse=1769.56, mae=1070.28, r2=0.9669, bias=-87.53 | val: rmse=2167.12, mae=1270.68, r2=0.9503, bias=-102.45
# - R26_iter600_lr0.117_l21.13_leaf127_fs70 | fs_keep=70% | sel=18 feats | train: rmse=1711.26, mae=1030.06, r2=0.9691, bias=-83.68 | val: rmse=2158.36, mae=1262.99, r2=0.9507, bias=-100.64
# - R27_iter1000_lr0.087_l21.66_leaf127_fs40 | fs_keep=40% | sel=10 feats | train: rmse=1816.53, mae=1087.98, r2=0.9651, bias=-90.66 | val: rmse=2201.61, mae=1284.96, r2=0.9487, bias=-103.16
# - R28_iter600_lr0.080_l21.45_leaf31_fs40 | fs_keep=40% | sel=10 feats | train: rmse=2018.31, mae=1229.37, r2=0.9570, bias=-109.42 | val: rmse=2252.91, mae=1337.04, r2=0.9463, bias=-117.94
# - R29_iter600_lr0.124_l21.24_leaf63_fs70 | fs_keep=70% | sel=18 feats | train: rmse=1790.96, mae=1093.10, r2=0.9661, bias=-90.29 | val: rmse=2171.98, mae=1276.98, r2=0.9501, bias=-102.16
#
# - running 31/40
# - R30_iter800_lr0.146_l22.18_leaf127_fs50 | fs_keep=50% | sel=13 feats | train: rmse=1767.46, mae=1067.59, r2=0.9670, bias=-86.65 | val: rmse=2199.63, mae=1284.75, r2=0.9488, bias=-103.52
# - R31_iter800_lr0.095_l22.08_leaf63_fs80 | fs_keep=80% | sel=20 feats | train: rmse=1835.05, mae=1112.60, r2=0.9644, bias=-92.92 | val: rmse=2182.29, mae=1277.46, r2=0.9496, bias=-106.61
# - R32_iter800_lr0.139_l22.29_leaf63_fs30 | fs_keep=30% | sel=8 feats | train: rmse=1819.61, mae=1107.81, r2=0.9650, bias=-91.01 | val: rmse=2168.94, mae=1281.24, r2=0.9502, bias=-100.34
# - R33_iter800_lr0.132_l21.55_leaf63_fs40 | fs_keep=40% | sel=10 feats | train: rmse=1869.17, mae=1129.53, r2=0.9631, bias=-94.15 | val: rmse=2221.53, mae=1300.20, r2=0.9478, bias=-107.26
# - R34_iter800_lr0.084_l21.24_leaf63_fs60 | fs_keep=60% | sel=15 feats | train: rmse=1810.41, mae=1106.14, r2=0.9654, bias=-93.78 | val: rmse=2168.33, mae=1278.08, r2=0.9502, bias=-106.19
#
# - running 36/40
# - R35_iter600_lr0.121_l21.66_leaf127_fs40 | fs_keep=40% | sel=10 feats | train: rmse=1784.39, mae=1071.17, r2=0.9664, bias=-88.90 | val: rmse=2199.02, mae=1283.13, r2=0.9489, bias=-102.80
# - R36_iter1000_lr0.117_l22.29_leaf127_fs80 | fs_keep=80% | sel=20 feats | train: rmse=1740.48, mae=1048.05, r2=0.9680, bias=-84.46 | val: rmse=2155.23, mae=1264.59, r2=0.9508, bias=-100.59
# - R37_iter600_lr0.087_l22.50_leaf127_fs60 | fs_keep=60% | sel=15 feats | train: rmse=1756.62, mae=1053.87, r2=0.9674, bias=-86.91 | val: rmse=2159.76, mae=1263.29, r2=0.9506, bias=-102.88
# - R38_iter1000_lr0.150_l21.03_leaf63_fs80 | fs_keep=80% | sel=20 feats | train: rmse=1830.72, mae=1110.46, r2=0.9646, bias=-90.56 | val: rmse=2190.69, mae=1287.27, r2=0.9492, bias=-103.34
# - R39_iter1000_lr0.080_l21.55_leaf127_fs70 | fs_keep=70% | sel=18 feats | train: rmse=1745.55, mae=1048.65, r2=0.9678, bias=-86.68 | val: rmse=2161.63, mae=1261.37, r2=0.9505, bias=-104.68
#
# - top 10 by validation RMSE
#                                       config  fs_keep_ratio  \
# 36  R36_iter1000_lr0.117_l22.29_leaf127_fs80            0.8
# 26   R26_iter600_lr0.117_l21.13_leaf127_fs70            0.7
# 22    R22_iter800_lr0.146_l21.24_leaf63_fs70            0.7
# 37   R37_iter600_lr0.087_l22.50_leaf127_fs60            0.6
# 39  R39_iter1000_lr0.080_l21.55_leaf127_fs70            0.7
# 23   R23_iter800_lr0.146_l20.71_leaf127_fs80            0.8
# 25   R25_iter600_lr0.102_l22.18_leaf127_fs70            0.7
# 34    R34_iter800_lr0.084_l21.24_leaf63_fs60            0.6
# 32    R32_iter800_lr0.139_l22.29_leaf63_fs30            0.3
# 29    R29_iter600_lr0.124_l21.24_leaf63_fs70            0.7
#
#     avg_selected_features  val_rmse_mean  val_mae_mean  val_r2_mean  \
# 36                   20.0    2155.230434   1264.585016     0.950822
# 26                   18.0    2158.357424   1262.985714     0.950673
# 22                   18.0    2158.913958   1277.974368     0.950726
# 37                   15.0    2159.758437   1263.291749     0.950648
# 39                   18.0    2161.625395   1261.372041     0.950531
# 23                   20.0    2166.546194   1266.308757     0.950302
# 25                   18.0    2167.124011   1270.682010     0.950310
# 34                   15.0    2168.325574   1278.079322     0.950229
# 32                    8.0    2168.935934   1281.235299     0.950219
# 29                   18.0    2171.975364   1276.978357     0.950081
#
#     val_bias_mean  train_rmse_mean  train_mae_mean  train_r2_mean  \
# 36    -100.593180      1740.475316     1048.053647       0.968014
# 26    -100.639513      1711.257857     1030.060286       0.969060
# 22    -103.742262      1776.955212     1085.670216       0.966623
# 37    -102.878490      1756.616432     1053.866584       0.967396
# 39    -104.681407      1745.554784     1048.651881       0.967844
# 23    -102.777320      1705.303653     1034.298309       0.969296
# 25    -102.452070      1769.564907     1070.283495       0.966902
# 34    -106.187363      1810.406033     1106.137402       0.965369
# 32    -100.335570      1819.605340     1107.811639       0.964995
# 29    -102.155948      1790.955598     1093.101198       0.966138
#
#     train_bias_mean  learning_rate  max_iter  l2_regularization  \
# 36       -84.461704       0.116842      1000           2.289474
# 26       -83.675129       0.116842       600           1.131579
# 22       -89.096429       0.146316       800           1.236842
# 37       -86.914372       0.087368       600           2.500000
# 39       -86.676325       0.080000      1000           1.552632
# 23       -83.938467       0.146316       800           0.710526
# 25       -87.529580       0.102105       600           2.184211
# 34       -93.782906       0.083684       800           1.236842
# 32       -91.010508       0.138947       800           2.289474
# 29       -90.286317       0.124211       600           1.236842
#
#     max_leaf_nodes  max_depth  min_samples_leaf
# 36             127       20.0                40
# 26             127        NaN                30
# 22              63       15.0                20
# 37             127        NaN                40
# 39             127        NaN                30
# 23             127        NaN                20
# 25             127       15.0                30
# 34              63       15.0                20
# 32              63       20.0                20
# 29              63       15.0                20
# - saved csv: random_search_hgb_fsweep_40.csv
# - saved log: random_search_hgb_fsweep_40.log

# %% [markdown]
# #### 4.3.2. With Feature Selection

# %% [markdown]
# - In this experiments, we perfomed a random search with different percentages of most useful features to access the best features selection strategy.

# %% [markdown]
# ##### __80%__

# %%
# este 
import numpy as np
import pandas as pd
import random
import logging

from IPython.display import display
from sklearn.model_selection import KFold
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import mean_absolute_error

# ---------------------------------------------------------
# 0) CONFIGS GERAIS
# ---------------------------------------------------------
N_SPLITS = 8
N_ITER = 15
RANDOM_STATE = 42

# Percentagem de features a manter no SelectFromModel
FS_KEEP_RATIO = 0.80

# RandomForest para Feature Selection (podes ajustar)
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

# ---------------------------------------------------------
# 0.1) CONFIGURAÇÃO DO LOGGING
# ---------------------------------------------------------

logging.basicConfig(
    filename="random_search_fe_fs_results.log",
    level=logging.INFO,
    format="%(asctime)s - %(message)s",
    filemode="w",
    force=True
)
logging.info("- 10 iterations")

# ---------------------------------------------------------
# 0.2) CONFIGURAÇÃO DO RANDOM SEARCH
# ---------------------------------------------------------
param_distributions = {
    "min_samples_leaf": [20, 30, 40],
    "max_leaf_nodes": [31, 63, 127],
    "max_iter": [600, 800, 1000, 1500],
    "max_depth": [None, 10, 15, 20, 25],
    "learning_rate": np.linspace(0.08, 0.15, 20),
    "l2_regularization": np.linspace(0.5, 2.5, 20),
    "max_bins": [255],
    "random_state": [RANDOM_STATE],
}

def get_random_configs(n_iter: int):
    configs = []
    keys = list(param_distributions.keys())

    for i in range(n_iter):
        params = {}
        for key in keys:
            params[key] = random.choice(list(param_distributions[key]))

        name = (
            f"R{i}_iter{params['max_iter']}"
            f"_lr{float(params['learning_rate']):.3f}"
            f"_l2{float(params['l2_regularization']):.2f}"
            f"_leaf{params['max_leaf_nodes']}"
        )
        configs.append((name, params))
    return configs

CONFIGS = get_random_configs(N_ITER)

# ---------------------------------------------------------
# 1) K-FOLD E SETUP
# ---------------------------------------------------------
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# Assume que já tens no notebook:
# - X, y
# - numeric_features, categorical_features
# - fill_unknown, column_string_transformer
# - fit_* e transform_* (os teus passos)
# - valid_brands, valid_models_by_brand, valid_transmissions, valid_fueltypes
# - MyTargetEncoder, MyOneHotEncoder

cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]
high_card_features = ["Brand", "model"]
low_card_features  = [c for c in categorical_features if c not in high_card_features]

def _normalize_cats(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    for col in cols_to_normalize:
        if col in df.columns:
            df[col] = fill_unknown(df[col])
            df = column_string_transformer(
                df, column=col, remove_middle_spaces=True, allow_extra_chars=""
            )
    return df

# ---------------------------------------------------------
# 1.1) FEATURE ENGINEERING (FUNÇÕES)
# ---------------------------------------------------------
def create_age_and_drop_year(df, year_col="year", base_year=2020, clip_future=True):
    df = df.copy()
    year = pd.to_numeric(df[year_col], errors="coerce")
    age = base_year - year
    if clip_future:
        age = age.clip(lower=0)
    df["age"] = age
    df = df.drop(columns=[year_col])
    return df

def add_owners_flagged(
    df,
    owners_col="previousOwners",
    new_col="owners_flagged",
    drop_original=True,
    na_as_zero=True
):
    df = df.copy()
    owners = pd.to_numeric(df[owners_col], errors="coerce")

    if na_as_zero:
        owners_filled = owners.fillna(0)
        df[new_col] = (owners_filled > 1).astype("int8")
    else:
        df[new_col] = (owners > 1).fillna(False).astype("int8")

    if drop_original and owners_col in df.columns:
        df = df.drop(columns=[owners_col])

    return df

def add_mileage_features(df, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True):
    df = df.copy()

    mileage = pd.to_numeric(df[mileage_col], errors="coerce")
    mileage = mileage.where(mileage >= 0, np.nan)

    df["log_mileage"] = np.log1p(mileage)

    age = pd.to_numeric(df[age_col], errors="coerce")
    age_safe = age.clip(lower=1)  # só para divisão
    df["miles_per_year"] = mileage / age_safe
    df["log_miles_per_year"] = np.log1p(df["miles_per_year"])

    if drop_ratio and "miles_per_year" in df.columns:
        df = df.drop(columns=["miles_per_year"])

    if drop_original and mileage_col in df.columns:
        df = df.drop(columns=[mileage_col])

    return df

def add_engine_bins(df, engine_col="engineSize", new_col="engine_bin", bins=None):
    df = df.copy()

    engine = pd.to_numeric(df[engine_col], errors="coerce")
    engine = engine.where(engine >= 0, np.nan)

    if bins is None:
        bins = [0, 1.0, 1.3, 1.6, 2.0, 2.5, 3.0, 4.0, np.inf]

    df[new_col] = pd.cut(engine, bins=bins, include_lowest=True, labels=False).astype("Int64")
    return df

# ---------------------------------------------------------
# 1.2) EVAL DE 1 CONFIG
# ---------------------------------------------------------
def eval_one_config(name: str, params: dict) -> dict:
    fold_rows = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):
        X_train = X.iloc[train_idx].copy()
        X_val   = X.iloc[val_idx].copy()
        y_train = y.iloc[train_idx].copy()
        y_val   = y.iloc[val_idx].copy()

        # TARGET (LOG)
        y_train_log = np.log1p(y_train)

        # Normalizar categóricas base
        X_train = _normalize_cats(X_train)
        X_val   = _normalize_cats(X_val)

        # Restringir às colunas base (mantém previousOwners e mileage para cleaning)
        base_cols = [c for c in (numeric_features + categorical_features) if c in X_train.columns]
        X_train = X_train[base_cols].copy()
        X_val   = X_val[base_cols].copy()

        # -----------------------------------------------------
        # A) CLEANING
        # -----------------------------------------------------
        year_state = fit_year_median(X_train, year_col="year", model_col="model")
        X_train = transform_year_with_model_median(X_train, state=year_state)
        X_val   = transform_year_with_model_median(X_val,   state=year_state)

        engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
        X_train = transform_engine_size_imputer(X_train, state=engine_state)
        X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

        X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
        X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

        mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
        X_train = transform_mpg_imputer(X_train, state=mpg_state)
        X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

        owners_state = fit_previous_owners_imputer(X_train, "previousOwners", "year", "mileage")
        X_train = transform_previous_owners_imputer(X_train, state=owners_state)
        X_val   = transform_previous_owners_imputer(X_val,   state=owners_state)

        # -----------------------------------------------------
        # B) RESOLVERS
        # -----------------------------------------------------
        brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
        X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
        X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

        model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
        X_train, _, _ = transform_invalid_models(X_train, model_state)
        X_val,   _, _ = transform_invalid_models(X_val,   model_state)

        transm_state = fit_transmission_resolver(X_train, valid_transmissions)
        X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
        X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

        fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
        X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
        X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

        # -----------------------------------------------------
        # C) FEATURE ENGINEERING
        # -----------------------------------------------------
        X_train = add_owners_flagged(X_train, owners_col="previousOwners", new_col="owners_flagged", drop_original=True)
        X_val   = add_owners_flagged(X_val,   owners_col="previousOwners", new_col="owners_flagged", drop_original=True)

        X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
        X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

        X_train = add_mileage_features(X_train, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
        X_val   = add_mileage_features(X_val,   mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)

        X_train = add_engine_bins(X_train, engine_col="engineSize", new_col="engine_bin")
        X_val   = add_engine_bins(X_val,   engine_col="engineSize", new_col="engine_bin")

        # engine_bin como low-card para OHE (robusto a NaNs)
        X_train["engine_bin"] = X_train["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        X_val["engine_bin"]   = X_val["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")

        low_card_curr = low_card_features + ["engine_bin"]

        # -----------------------------------------------------
        # D) ENCODING
        # -----------------------------------------------------
        te = MyTargetEncoder(smoothing=5)
        te.fit(X_train[high_card_features], y_train_log)
        X_train_high = te.transform(X_train[high_card_features])
        X_val_high   = te.transform(X_val[high_card_features])

        ohe = MyOneHotEncoder()
        ohe.fit(X_train[low_card_curr])
        X_train_low = ohe.transform(X_train[low_card_curr])
        X_val_low   = ohe.transform(X_val[low_card_curr])

        X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
        X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

        drop_for_numeric = set(high_card_features + low_card_curr)
        numeric_features_curr = [c for c in X_train.columns if c not in drop_for_numeric]

        X_train_final = pd.concat([X_train[numeric_features_curr], X_train_cat], axis=1)
        X_val_final   = pd.concat([X_val[numeric_features_curr],   X_val_cat],   axis=1)

        # alinhar colunas
        X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

        # -----------------------------------------------------
        # D.1) FEATURE SELECTION (SelectFromModel + RandomForest)
        #     - threshold=-np.inf
        #     - max_features = 80% das features
        # -----------------------------------------------------
        n_feats = X_train_final.shape[1]
        k = int(np.ceil(FS_KEEP_RATIO * n_feats))
        k = max(1, min(k, n_feats))

        rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
        rf_fs.fit(X_train_final, y_train_log)

        selector = SelectFromModel(
            estimator=rf_fs,
            threshold=-np.inf,
            max_features=k,
            prefit=True
        )

        support = selector.get_support()
        selected_cols = X_train_final.columns[support]

        X_train_sel = X_train_final[selected_cols]
        X_val_sel   = X_val_final[selected_cols]

        # -----------------------------------------------------
        # E) TREINO (HGB)
        # -----------------------------------------------------
        model = HistGradientBoostingRegressor(**params)
        model.fit(X_train_sel, y_train_log)

        pred_tr_log  = model.predict(X_train_sel)
        pred_val_log = model.predict(X_val_sel)

        pred_tr  = np.expm1(pred_tr_log)
        pred_val = np.expm1(pred_val_log)

        mae_tr  = mean_absolute_error(y_train, pred_tr)
        mae_val = mean_absolute_error(y_val,   pred_val)

        fold_rows.append({
            "config": name,
            "fold": fold,
            "n_features_total": n_feats,
            "n_features_selected": len(selected_cols),
            "train_mae": mae_tr,
            "val_mae": mae_val
        })

    df_folds = pd.DataFrame(fold_rows)
    mean_mae_tr  = df_folds["train_mae"].mean()
    mean_mae_val = df_folds["val_mae"].mean()
    mean_sel     = df_folds["n_features_selected"].mean()

    print(f"   >> [{name}] Train MAE: {mean_mae_tr:.2f} | Val MAE: {mean_mae_val:.2f} | Sel: {mean_sel:.0f} feats")
    logging.info(
        f"{name} | Train MAE: {mean_mae_tr:.4f} | Val MAE: {mean_mae_val:.4f} | "
        f"AvgSelected: {mean_sel:.1f} | Params: {params}"
    )

    out = {
        "config": name,
        "val_mae_mean": mean_mae_val,
        "train_mae_mean": mean_mae_tr,
        "avg_selected_features": float(mean_sel),
        **params
    }
    return out

# ---------------------------------------------------------
# 2) CORRER TODAS AS CONFIGS
# ---------------------------------------------------------
results = []
for i, (name, params) in enumerate(CONFIGS):
    if i % 5 == 0:
        print(f"\n-- doing {i+1}/{len(CONFIGS)}")

    res = eval_one_config(name, params)
    results.append(res)

results_df = pd.DataFrame(results)

# ---------------------------------------------------------
# 3) RESULTADOS FINAIS
# ---------------------------------------------------------
print("\n- 10 BEST Configurations")
results_df_sorted = results_df.sort_values("val_mae_mean", ascending=True)

cols_show = [
    "config",
    "val_mae_mean", "train_mae_mean",
    "avg_selected_features",
    "learning_rate", "max_iter", "l2_regularization", "max_leaf_nodes", "max_depth", "min_samples_leaf"
]

display(results_df_sorted[cols_show].head(10))

results_df_sorted.to_csv("random_search_fe_fs_results.csv", index=False)
print("stored at: random_search_fe_fs_results.csv")
print(" log in: random_search_fe_fs_results.log")
# Out:
# -- doing 1/15
#    >> [R0_iter800_lr0.150_l21.34_leaf63] Train MAE: 1150.19 | Val MAE: 1301.44 | Sel: 20 feats
#    >> [R1_iter1500_lr0.117_l22.08_leaf127] Train MAE: 1049.87 | Val MAE: 1267.03 | Sel: 20 feats
#    >> [R2_iter800_lr0.095_l21.24_leaf31] Train MAE: 1154.68 | Val MAE: 1295.28 | Sel: 20 feats
#    >> [R3_iter600_lr0.098_l22.18_leaf127] Train MAE: 1040.17 | Val MAE: 1263.01 | Sel: 20 feats
#    >> [R4_iter1500_lr0.124_l21.66_leaf127] Train MAE: 1044.36 | Val MAE: 1268.02 | Sel: 20 feats
#
# -- doing 6/15
#    >> [R5_iter600_lr0.117_l22.39_leaf31] Train MAE: 1168.81 | Val MAE: 1298.09 | Sel: 20 feats
#    >> [R6_iter1000_lr0.080_l21.97_leaf63] Train MAE: 1115.98 | Val MAE: 1277.13 | Sel: 20 feats
#    >> [R7_iter600_lr0.080_l20.92_leaf31] Train MAE: 1209.38 | Val MAE: 1316.44 | Sel: 20 feats
#    >> [R8_iter800_lr0.098_l21.13_leaf63] Train MAE: 1088.03 | Val MAE: 1269.95 | Sel: 20 feats
#    >> [R9_iter800_lr0.113_l21.03_leaf63] Train MAE: 1100.94 | Val MAE: 1278.36 | Sel: 20 feats
#
# -- doing 11/15
#    >> [R10_iter1000_lr0.091_l21.76_leaf127] Train MAE: 1009.15 | Val MAE: 1252.63 | Sel: 20 feats
#    >> [R11_iter600_lr0.091_l21.24_leaf31] Train MAE: 1198.38 | Val MAE: 1313.79 | Sel: 20 feats
#    >> [R12_iter1500_lr0.095_l20.61_leaf31] Train MAE: 1163.24 | Val MAE: 1297.39 | Sel: 20 feats
#    >> [R13_iter1500_lr0.146_l20.82_leaf63] Train MAE: 1113.30 | Val MAE: 1287.22 | Sel: 20 feats
#    >> [R14_iter600_lr0.139_l20.71_leaf127] Train MAE: 1079.74 | Val MAE: 1277.01 | Sel: 20 feats
#
# - 10 BEST Configurations
#                                  config  val_mae_mean  train_mae_mean  \
# 10  R10_iter1000_lr0.091_l21.76_leaf127   1252.630196     1009.152409
# 3     R3_iter600_lr0.098_l22.18_leaf127   1263.013510     1040.173371
# 1    R1_iter1500_lr0.117_l22.08_leaf127   1267.032613     1049.868542
# 4    R4_iter1500_lr0.124_l21.66_leaf127   1268.020348     1044.361099
# 8      R8_iter800_lr0.098_l21.13_leaf63   1269.949345     1088.025548
# 14   R14_iter600_lr0.139_l20.71_leaf127   1277.007332     1079.741646
# 6     R6_iter1000_lr0.080_l21.97_leaf63   1277.132114     1115.978164
# 9      R9_iter800_lr0.113_l21.03_leaf63   1278.363524     1100.935909
# 13   R13_iter1500_lr0.146_l20.82_leaf63   1287.216976     1113.303473
# 2      R2_iter800_lr0.095_l21.24_leaf31   1295.281678     1154.675361
#
#     avg_selected_features  learning_rate  max_iter  l2_regularization  \
# 10                   20.0       0.091053      1000           1.763158
# 3                    20.0       0.098421       600           2.184211
# 1                    20.0       0.116842      1500           2.078947
# 4                    20.0       0.124211      1500           1.657895
# 8                    20.0       0.098421       800           1.131579
# 14                   20.0       0.138947       600           0.710526
# 6                    20.0       0.080000      1000           1.973684
# 9                    20.0       0.113158       800           1.026316
# 13                   20.0       0.146316      1500           0.815789
# 2                    20.0       0.094737       800           1.236842
#
#     max_leaf_nodes  max_depth  min_samples_leaf
# 10             127        NaN                20
# 3              127       20.0                30
# 1              127       15.0                30
# 4              127       15.0                30
# 8               63       25.0                30
# 14             127       15.0                40
# 6               63       15.0                40
# 9               63       25.0                30
# 13              63       20.0                40
# 2               31       25.0                20
# stored at: random_search_fe_fs_results.csv
#  log in: random_search_fe_fs_results.log

# %% [markdown]
# ##### __85%__

# %%
import numpy as np
import pandas as pd
import random
import logging

from IPython.display import display
from sklearn.model_selection import KFold
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import mean_absolute_error

# ---------------------------------------------------------
# 0) CONFIGS GERAIS
# ---------------------------------------------------------
N_SPLITS = 8
N_ITER = 15
RANDOM_STATE = 42

# Percentagem de features a manter no SelectFromModel
FS_KEEP_RATIO = 0.85

# RandomForest para Feature Selection (podes ajustar)
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

# ---------------------------------------------------------
# 0.1) CONFIGURAÇÃO DO LOGGING
# ---------------------------------------------------------

logging.basicConfig(
    filename="random_search_fe_fs_results_85.log",
    level=logging.INFO,
    format="%(asctime)s - %(message)s",
    filemode="w",
    force=True
)
logging.info("- 10 iterations")

# ---------------------------------------------------------
# 0.2) CONFIGURAÇÃO DO RANDOM SEARCH
# ---------------------------------------------------------
param_distributions = {
    "min_samples_leaf": [20, 30, 40],
    "max_leaf_nodes": [31, 63, 127],
    "max_iter": [600, 800, 1000, 1500],
    "max_depth": [None, 10, 15, 20, 25],
    "learning_rate": np.linspace(0.08, 0.15, 20),
    "l2_regularization": np.linspace(0.5, 2.5, 20),
    "max_bins": [255],
    "random_state": [RANDOM_STATE],
}

def get_random_configs(n_iter: int):
    configs = []
    keys = list(param_distributions.keys())

    for i in range(n_iter):
        params = {}
        for key in keys:
            params[key] = random.choice(list(param_distributions[key]))

        name = (
            f"R{i}_iter{params['max_iter']}"
            f"_lr{float(params['learning_rate']):.3f}"
            f"_l2{float(params['l2_regularization']):.2f}"
            f"_leaf{params['max_leaf_nodes']}"
        )
        configs.append((name, params))
    return configs

CONFIGS = get_random_configs(N_ITER)

# ---------------------------------------------------------
# 1) K-FOLD E SETUP
# ---------------------------------------------------------
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# Assume que já tens no notebook:
# - X, y
# - numeric_features, categorical_features
# - fill_unknown, column_string_transformer
# - fit_* e transform_* (os teus passos)
# - valid_brands, valid_models_by_brand, valid_transmissions, valid_fueltypes
# - MyTargetEncoder, MyOneHotEncoder

cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]
high_card_features = ["Brand", "model"]
low_card_features  = [c for c in categorical_features if c not in high_card_features]

def _normalize_cats(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    for col in cols_to_normalize:
        if col in df.columns:
            df[col] = fill_unknown(df[col])
            df = column_string_transformer(
                df, column=col, remove_middle_spaces=True, allow_extra_chars=""
            )
    return df

# ---------------------------------------------------------
# 1.1) FEATURE ENGINEERING (FUNÇÕES)
# ---------------------------------------------------------
def create_age_and_drop_year(df, year_col="year", base_year=2020, clip_future=True):
    df = df.copy()
    year = pd.to_numeric(df[year_col], errors="coerce")
    age = base_year - year
    if clip_future:
        age = age.clip(lower=0)
    df["age"] = age
    df = df.drop(columns=[year_col])
    return df

def add_owners_flagged(
    df,
    owners_col="previousOwners",
    new_col="owners_flagged",
    drop_original=True,
    na_as_zero=True
):
    df = df.copy()
    owners = pd.to_numeric(df[owners_col], errors="coerce")

    if na_as_zero:
        owners_filled = owners.fillna(0)
        df[new_col] = (owners_filled > 1).astype("int8")
    else:
        df[new_col] = (owners > 1).fillna(False).astype("int8")

    if drop_original and owners_col in df.columns:
        df = df.drop(columns=[owners_col])

    return df

def add_mileage_features(df, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True):
    df = df.copy()

    mileage = pd.to_numeric(df[mileage_col], errors="coerce")
    mileage = mileage.where(mileage >= 0, np.nan)

    df["log_mileage"] = np.log1p(mileage)

    age = pd.to_numeric(df[age_col], errors="coerce")
    age_safe = age.clip(lower=1)  # só para divisão
    df["miles_per_year"] = mileage / age_safe
    df["log_miles_per_year"] = np.log1p(df["miles_per_year"])

    if drop_ratio and "miles_per_year" in df.columns:
        df = df.drop(columns=["miles_per_year"])

    if drop_original and mileage_col in df.columns:
        df = df.drop(columns=[mileage_col])

    return df

def add_engine_bins(df, engine_col="engineSize", new_col="engine_bin", bins=None):
    df = df.copy()

    engine = pd.to_numeric(df[engine_col], errors="coerce")
    engine = engine.where(engine >= 0, np.nan)

    if bins is None:
        bins = [0, 1.0, 1.3, 1.6, 2.0, 2.5, 3.0, 4.0, np.inf]

    df[new_col] = pd.cut(engine, bins=bins, include_lowest=True, labels=False).astype("Int64")
    return df

# ---------------------------------------------------------
# 1.2) EVAL DE 1 CONFIG
# ---------------------------------------------------------
def eval_one_config(name: str, params: dict) -> dict:
    fold_rows = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):
        X_train = X.iloc[train_idx].copy()
        X_val   = X.iloc[val_idx].copy()
        y_train = y.iloc[train_idx].copy()
        y_val   = y.iloc[val_idx].copy()

        # TARGET (LOG)
        y_train_log = np.log1p(y_train)

        # Normalizar categóricas base
        X_train = _normalize_cats(X_train)
        X_val   = _normalize_cats(X_val)

        # Restringir às colunas base (mantém previousOwners e mileage para cleaning)
        base_cols = [c for c in (numeric_features + categorical_features) if c in X_train.columns]
        X_train = X_train[base_cols].copy()
        X_val   = X_val[base_cols].copy()

        # -----------------------------------------------------
        # A) CLEANING
        # -----------------------------------------------------
        year_state = fit_year_median(X_train, year_col="year", model_col="model")
        X_train = transform_year_with_model_median(X_train, state=year_state)
        X_val   = transform_year_with_model_median(X_val,   state=year_state)

        engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
        X_train = transform_engine_size_imputer(X_train, state=engine_state)
        X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

        X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
        X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

        mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
        X_train = transform_mpg_imputer(X_train, state=mpg_state)
        X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

        owners_state = fit_previous_owners_imputer(X_train, "previousOwners", "year", "mileage")
        X_train = transform_previous_owners_imputer(X_train, state=owners_state)
        X_val   = transform_previous_owners_imputer(X_val,   state=owners_state)

        # -----------------------------------------------------
        # B) RESOLVERS
        # -----------------------------------------------------
        brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
        X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
        X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

        model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
        X_train, _, _ = transform_invalid_models(X_train, model_state)
        X_val,   _, _ = transform_invalid_models(X_val,   model_state)

        transm_state = fit_transmission_resolver(X_train, valid_transmissions)
        X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
        X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

        fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
        X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
        X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

        # -----------------------------------------------------
        # C) FEATURE ENGINEERING
        # -----------------------------------------------------
        X_train = add_owners_flagged(X_train, owners_col="previousOwners", new_col="owners_flagged", drop_original=True)
        X_val   = add_owners_flagged(X_val,   owners_col="previousOwners", new_col="owners_flagged", drop_original=True)

        X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
        X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

        X_train = add_mileage_features(X_train, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
        X_val   = add_mileage_features(X_val,   mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)

        X_train = add_engine_bins(X_train, engine_col="engineSize", new_col="engine_bin")
        X_val   = add_engine_bins(X_val,   engine_col="engineSize", new_col="engine_bin")

        # engine_bin como low-card para OHE (robusto a NaNs)
        X_train["engine_bin"] = X_train["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        X_val["engine_bin"]   = X_val["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")

        low_card_curr = low_card_features + ["engine_bin"]

        # -----------------------------------------------------
        # D) ENCODING
        # -----------------------------------------------------
        te = MyTargetEncoder(smoothing=5)
        te.fit(X_train[high_card_features], y_train_log)
        X_train_high = te.transform(X_train[high_card_features])
        X_val_high   = te.transform(X_val[high_card_features])

        ohe = MyOneHotEncoder()
        ohe.fit(X_train[low_card_curr])
        X_train_low = ohe.transform(X_train[low_card_curr])
        X_val_low   = ohe.transform(X_val[low_card_curr])

        X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
        X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

        drop_for_numeric = set(high_card_features + low_card_curr)
        numeric_features_curr = [c for c in X_train.columns if c not in drop_for_numeric]

        X_train_final = pd.concat([X_train[numeric_features_curr], X_train_cat], axis=1)
        X_val_final   = pd.concat([X_val[numeric_features_curr],   X_val_cat],   axis=1)

        # alinhar colunas
        X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

        # -----------------------------------------------------
        # D.1) FEATURE SELECTION (SelectFromModel + RandomForest)
        #     - threshold=-np.inf
        #     - max_features = 80% das features
        # -----------------------------------------------------
        n_feats = X_train_final.shape[1]
        k = int(np.ceil(FS_KEEP_RATIO * n_feats))
        k = max(1, min(k, n_feats))

        rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
        rf_fs.fit(X_train_final, y_train_log)

        selector = SelectFromModel(
            estimator=rf_fs,
            threshold=-np.inf,
            max_features=k,
            prefit=True
        )

        support = selector.get_support()
        selected_cols = X_train_final.columns[support]

        X_train_sel = X_train_final[selected_cols]
        X_val_sel   = X_val_final[selected_cols]

        # -----------------------------------------------------
        # E) TREINO (HGB)
        # -----------------------------------------------------
        model = HistGradientBoostingRegressor(**params)
        model.fit(X_train_sel, y_train_log)

        pred_tr_log  = model.predict(X_train_sel)
        pred_val_log = model.predict(X_val_sel)

        pred_tr  = np.expm1(pred_tr_log)
        pred_val = np.expm1(pred_val_log)

        mae_tr  = mean_absolute_error(y_train, pred_tr)
        mae_val = mean_absolute_error(y_val,   pred_val)

        fold_rows.append({
            "config": name,
            "fold": fold,
            "n_features_total": n_feats,
            "n_features_selected": len(selected_cols),
            "train_mae": mae_tr,
            "val_mae": mae_val
        })

    df_folds = pd.DataFrame(fold_rows)
    mean_mae_tr  = df_folds["train_mae"].mean()
    mean_mae_val = df_folds["val_mae"].mean()
    mean_sel     = df_folds["n_features_selected"].mean()

    print(f"   >> [{name}] Train MAE: {mean_mae_tr:.2f} | Val MAE: {mean_mae_val:.2f} | Sel: {mean_sel:.0f} feats")
    logging.info(
        f"{name} | Train MAE: {mean_mae_tr:.4f} | Val MAE: {mean_mae_val:.4f} | "
        f"AvgSelected: {mean_sel:.1f} | Params: {params}"
    )

    out = {
        "config": name,
        "val_mae_mean": mean_mae_val,
        "train_mae_mean": mean_mae_tr,
        "avg_selected_features": float(mean_sel),
        **params
    }
    return out

# ---------------------------------------------------------
# 2) CORRER TODAS AS CONFIGS
# ---------------------------------------------------------
results = []
for i, (name, params) in enumerate(CONFIGS):
    if i % 5 == 0:
        print(f"\n-- doing {i+1}/{len(CONFIGS)}")

    res = eval_one_config(name, params)
    results.append(res)

results_df = pd.DataFrame(results)

# ---------------------------------------------------------
# 3) RESULTADOS FINAIS
# ---------------------------------------------------------
print("\n- 10 BEST Configurations")
results_df_sorted = results_df.sort_values("val_mae_mean", ascending=True)

cols_show = [
    "config",
    "val_mae_mean", "train_mae_mean",
    "avg_selected_features",
    "learning_rate", "max_iter", "l2_regularization", "max_leaf_nodes", "max_depth", "min_samples_leaf"
]

display(results_df_sorted[cols_show].head(10))

results_df_sorted.to_csv("random_search_fe_fs_results_85.csv", index=False)
print("stored at: random_search_fe_fs_results_85.csv")
print(" log in: random_search_fe_fs_results_85.log")
# Out:
# -- doing 1/15
#    >> [R0_iter600_lr0.109_l22.39_leaf127] Train MAE: 1033.95 | Val MAE: 1261.15 | Sel: 22 feats
#    >> [R1_iter1500_lr0.109_l21.13_leaf127] Train MAE: 1119.99 | Val MAE: 1291.19 | Sel: 22 feats
#    >> [R2_iter800_lr0.102_l22.18_leaf63] Train MAE: 1110.00 | Val MAE: 1278.37 | Sel: 22 feats
#    >> [R3_iter800_lr0.098_l21.55_leaf63] Train MAE: 1124.44 | Val MAE: 1285.85 | Sel: 22 feats
#    >> [R4_iter1500_lr0.121_l21.87_leaf31] Train MAE: 1139.62 | Val MAE: 1288.76 | Sel: 22 feats
#
# -- doing 6/15
#    >> [R5_iter1500_lr0.080_l21.66_leaf127] Train MAE: 1079.51 | Val MAE: 1271.39 | Sel: 22 feats
#    >> [R6_iter1000_lr0.146_l20.92_leaf31] Train MAE: 1177.45 | Val MAE: 1308.59 | Sel: 22 feats
#    >> [R7_iter600_lr0.109_l22.39_leaf63] Train MAE: 1112.38 | Val MAE: 1281.58 | Sel: 22 feats
#    >> [R8_iter800_lr0.095_l22.50_leaf127] Train MAE: 1042.85 | Val MAE: 1264.37 | Sel: 22 feats
#    >> [R9_iter800_lr0.091_l21.24_leaf127] Train MAE: 1039.44 | Val MAE: 1262.52 | Sel: 22 feats
#
# -- doing 11/15
#    >> [R10_iter1000_lr0.080_l20.71_leaf31] Train MAE: 1196.11 | Val MAE: 1307.50 | Sel: 22 feats
#    >> [R11_iter1000_lr0.146_l21.66_leaf127] Train MAE: 1027.89 | Val MAE: 1269.09 | Sel: 22 feats
#    >> [R12_iter1500_lr0.091_l22.08_leaf127] Train MAE: 1045.25 | Val MAE: 1263.81 | Sel: 22 feats
#    >> [R13_iter800_lr0.135_l22.18_leaf63] Train MAE: 1090.58 | Val MAE: 1279.31 | Sel: 22 feats
#    >> [R14_iter1000_lr0.098_l21.97_leaf31] Train MAE: 1163.19 | Val MAE: 1298.19 | Sel: 22 feats
#
# - 10 BEST Configurations
#                                  config  val_mae_mean  train_mae_mean  \
# 0     R0_iter600_lr0.109_l22.39_leaf127   1261.151179     1033.949108
# 9     R9_iter800_lr0.091_l21.24_leaf127   1262.516028     1039.439003
# 12  R12_iter1500_lr0.091_l22.08_leaf127   1263.808871     1045.245355
# 8     R8_iter800_lr0.095_l22.50_leaf127   1264.371280     1042.846505
# 11  R11_iter1000_lr0.146_l21.66_leaf127   1269.086650     1027.890915
# 5    R5_iter1500_lr0.080_l21.66_leaf127   1271.392670     1079.508578
# 2      R2_iter800_lr0.102_l22.18_leaf63   1278.372020     1109.995980
# 13    R13_iter800_lr0.135_l22.18_leaf63   1279.305564     1090.580480
# 7      R7_iter600_lr0.109_l22.39_leaf63   1281.583236     1112.379328
# 3      R3_iter800_lr0.098_l21.55_leaf63   1285.853635     1124.440418
#
#     avg_selected_features  learning_rate  max_iter  l2_regularization  \
# 0                    22.0       0.109474       600           2.394737
# 9                    22.0       0.091053       800           1.236842
# 12                   22.0       0.091053      1500           2.078947
# 8                    22.0       0.094737       800           2.500000
# 11                   22.0       0.146316      1000           1.657895
# 5                    22.0       0.080000      1500           1.657895
# 2                    22.0       0.102105       800           2.184211
# 13                   22.0       0.135263       800           2.184211
# 7                    22.0       0.109474       600           2.394737
# 3                    22.0       0.098421       800           1.552632
#
#     max_leaf_nodes  max_depth  min_samples_leaf
# 0              127       20.0                30
# 9              127       15.0                30
# 12             127        NaN                20
# 8              127       20.0                20
# 11             127       20.0                20
# 5              127        NaN                40
# 2               63        NaN                30
# 13              63       25.0                20
# 7               63        NaN                40
# 3               63       10.0                30
# stored at: random_search_fe_fs_results_85.csv
#  log in: random_search_fe_fs_results_85.log

# %% [markdown]
# ##### __75%__

# %%
import numpy as np
import pandas as pd
import random
import logging

from IPython.display import display
from sklearn.model_selection import KFold
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import mean_absolute_error

# ---------------------------------------------------------
# 0) CONFIGS GERAIS
# ---------------------------------------------------------
N_SPLITS = 8
N_ITER = 100
RANDOM_STATE = 42

# Percentagem de features a manter no SelectFromModel
FS_KEEP_RATIO = 0.75

# RandomForest para Feature Selection (podes ajustar)
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

# ---------------------------------------------------------
# 0.1) CONFIGURAÇÃO DO LOGGING
# ---------------------------------------------------------

logging.basicConfig(
    filename="random_search_fe_fs_results_75.log",
    level=logging.INFO,
    format="%(asctime)s - %(message)s",
    filemode="w",
    force=True
)
logging.info("- 10 iterations")

# ---------------------------------------------------------
# 0.2) CONFIGURAÇÃO DO RANDOM SEARCH
# ---------------------------------------------------------
param_distributions = {
    "min_samples_leaf": [20, 30, 40],
    "max_leaf_nodes": [31, 63, 127],
    "max_iter": [600, 800, 1000, 1500],
    "max_depth": [None, 10, 15, 20, 25],
    "learning_rate": np.linspace(0.08, 0.15, 20),
    "l2_regularization": np.linspace(0.5, 2.5, 20),
    "max_bins": [255],
    "random_state": [RANDOM_STATE],
}

def get_random_configs(n_iter: int):
    configs = []
    keys = list(param_distributions.keys())

    for i in range(n_iter):
        params = {}
        for key in keys:
            params[key] = random.choice(list(param_distributions[key]))

        name = (
            f"R{i}_iter{params['max_iter']}"
            f"_lr{float(params['learning_rate']):.3f}"
            f"_l2{float(params['l2_regularization']):.2f}"
            f"_leaf{params['max_leaf_nodes']}"
        )
        configs.append((name, params))
    return configs

CONFIGS = get_random_configs(N_ITER)

# ---------------------------------------------------------
# 1) K-FOLD E SETUP
# ---------------------------------------------------------
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# Assume que já tens no notebook:
# - X, y
# - numeric_features, categorical_features
# - fill_unknown, column_string_transformer
# - fit_* e transform_* (os teus passos)
# - valid_brands, valid_models_by_brand, valid_transmissions, valid_fueltypes
# - MyTargetEncoder, MyOneHotEncoder

cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]
high_card_features = ["Brand", "model"]
low_card_features  = [c for c in categorical_features if c not in high_card_features]

def _normalize_cats(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    for col in cols_to_normalize:
        if col in df.columns:
            df[col] = fill_unknown(df[col])
            df = column_string_transformer(
                df, column=col, remove_middle_spaces=True, allow_extra_chars=""
            )
    return df

# ---------------------------------------------------------
# 1.1) FEATURE ENGINEERING (FUNÇÕES)
# ---------------------------------------------------------
def create_age_and_drop_year(df, year_col="year", base_year=2020, clip_future=True):
    df = df.copy()
    year = pd.to_numeric(df[year_col], errors="coerce")
    age = base_year - year
    if clip_future:
        age = age.clip(lower=0)
    df["age"] = age
    df = df.drop(columns=[year_col])
    return df

def add_owners_flagged(
    df,
    owners_col="previousOwners",
    new_col="owners_flagged",
    drop_original=True,
    na_as_zero=True
):
    df = df.copy()
    owners = pd.to_numeric(df[owners_col], errors="coerce")

    if na_as_zero:
        owners_filled = owners.fillna(0)
        df[new_col] = (owners_filled > 1).astype("int8")
    else:
        df[new_col] = (owners > 1).fillna(False).astype("int8")

    if drop_original and owners_col in df.columns:
        df = df.drop(columns=[owners_col])

    return df

def add_mileage_features(df, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True):
    df = df.copy()

    mileage = pd.to_numeric(df[mileage_col], errors="coerce")
    mileage = mileage.where(mileage >= 0, np.nan)

    df["log_mileage"] = np.log1p(mileage)

    age = pd.to_numeric(df[age_col], errors="coerce")
    age_safe = age.clip(lower=1)  # só para divisão
    df["miles_per_year"] = mileage / age_safe
    df["log_miles_per_year"] = np.log1p(df["miles_per_year"])

    if drop_ratio and "miles_per_year" in df.columns:
        df = df.drop(columns=["miles_per_year"])

    if drop_original and mileage_col in df.columns:
        df = df.drop(columns=[mileage_col])

    return df

def add_engine_bins(df, engine_col="engineSize", new_col="engine_bin", bins=None):
    df = df.copy()

    engine = pd.to_numeric(df[engine_col], errors="coerce")
    engine = engine.where(engine >= 0, np.nan)

    if bins is None:
        bins = [0, 1.0, 1.3, 1.6, 2.0, 2.5, 3.0, 4.0, np.inf]

    df[new_col] = pd.cut(engine, bins=bins, include_lowest=True, labels=False).astype("Int64")
    return df

# ---------------------------------------------------------
# 1.2) EVAL DE 1 CONFIG
# ---------------------------------------------------------
def eval_one_config(name: str, params: dict) -> dict:
    fold_rows = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):
        X_train = X.iloc[train_idx].copy()
        X_val   = X.iloc[val_idx].copy()
        y_train = y.iloc[train_idx].copy()
        y_val   = y.iloc[val_idx].copy()

        # TARGET (LOG)
        y_train_log = np.log1p(y_train)

        # Normalizar categóricas base
        X_train = _normalize_cats(X_train)
        X_val   = _normalize_cats(X_val)

        # Restringir às colunas base (mantém previousOwners e mileage para cleaning)
        base_cols = [c for c in (numeric_features + categorical_features) if c in X_train.columns]
        X_train = X_train[base_cols].copy()
        X_val   = X_val[base_cols].copy()

        # -----------------------------------------------------
        # A) CLEANING
        # -----------------------------------------------------
        year_state = fit_year_median(X_train, year_col="year", model_col="model")
        X_train = transform_year_with_model_median(X_train, state=year_state)
        X_val   = transform_year_with_model_median(X_val,   state=year_state)

        engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
        X_train = transform_engine_size_imputer(X_train, state=engine_state)
        X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

        X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
        X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

        mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
        X_train = transform_mpg_imputer(X_train, state=mpg_state)
        X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

        owners_state = fit_previous_owners_imputer(X_train, "previousOwners", "year", "mileage")
        X_train = transform_previous_owners_imputer(X_train, state=owners_state)
        X_val   = transform_previous_owners_imputer(X_val,   state=owners_state)

        # -----------------------------------------------------
        # B) RESOLVERS
        # -----------------------------------------------------
        brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
        X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
        X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

        model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
        X_train, _, _ = transform_invalid_models(X_train, model_state)
        X_val,   _, _ = transform_invalid_models(X_val,   model_state)

        transm_state = fit_transmission_resolver(X_train, valid_transmissions)
        X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
        X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

        fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
        X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
        X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

        # -----------------------------------------------------
        # C) FEATURE ENGINEERING
        # -----------------------------------------------------
        X_train = add_owners_flagged(X_train, owners_col="previousOwners", new_col="owners_flagged", drop_original=True)
        X_val   = add_owners_flagged(X_val,   owners_col="previousOwners", new_col="owners_flagged", drop_original=True)

        X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
        X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

        X_train = add_mileage_features(X_train, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
        X_val   = add_mileage_features(X_val,   mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)

        X_train = add_engine_bins(X_train, engine_col="engineSize", new_col="engine_bin")
        X_val   = add_engine_bins(X_val,   engine_col="engineSize", new_col="engine_bin")

        # engine_bin como low-card para OHE (robusto a NaNs)
        X_train["engine_bin"] = X_train["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        X_val["engine_bin"]   = X_val["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")

        low_card_curr = low_card_features + ["engine_bin"]

        # -----------------------------------------------------
        # D) ENCODING
        # -----------------------------------------------------
        te = MyTargetEncoder(smoothing=5)
        te.fit(X_train[high_card_features], y_train_log)
        X_train_high = te.transform(X_train[high_card_features])
        X_val_high   = te.transform(X_val[high_card_features])

        ohe = MyOneHotEncoder()
        ohe.fit(X_train[low_card_curr])
        X_train_low = ohe.transform(X_train[low_card_curr])
        X_val_low   = ohe.transform(X_val[low_card_curr])

        X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
        X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

        drop_for_numeric = set(high_card_features + low_card_curr)
        numeric_features_curr = [c for c in X_train.columns if c not in drop_for_numeric]

        X_train_final = pd.concat([X_train[numeric_features_curr], X_train_cat], axis=1)
        X_val_final   = pd.concat([X_val[numeric_features_curr],   X_val_cat],   axis=1)

        # alinhar colunas
        X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

        # -----------------------------------------------------
        # D.1) FEATURE SELECTION (SelectFromModel + RandomForest)
        #     - threshold=-np.inf
        #     - max_features = 80% das features
        # -----------------------------------------------------
        n_feats = X_train_final.shape[1]
        k = int(np.ceil(FS_KEEP_RATIO * n_feats))
        k = max(1, min(k, n_feats))

        rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
        rf_fs.fit(X_train_final, y_train_log)

        selector = SelectFromModel(
            estimator=rf_fs,
            threshold=-np.inf,
            max_features=k,
            prefit=True
        )

        support = selector.get_support()
        selected_cols = X_train_final.columns[support]

        X_train_sel = X_train_final[selected_cols]
        X_val_sel   = X_val_final[selected_cols]

        # -----------------------------------------------------
        # E) TREINO (HGB)
        # -----------------------------------------------------
        model = HistGradientBoostingRegressor(**params)
        model.fit(X_train_sel, y_train_log)

        pred_tr_log  = model.predict(X_train_sel)
        pred_val_log = model.predict(X_val_sel)

        pred_tr  = np.expm1(pred_tr_log)
        pred_val = np.expm1(pred_val_log)

        mae_tr  = mean_absolute_error(y_train, pred_tr)
        mae_val = mean_absolute_error(y_val,   pred_val)

        fold_rows.append({
            "config": name,
            "fold": fold,
            "n_features_total": n_feats,
            "n_features_selected": len(selected_cols),
            "train_mae": mae_tr,
            "val_mae": mae_val
        })

    df_folds = pd.DataFrame(fold_rows)
    mean_mae_tr  = df_folds["train_mae"].mean()
    mean_mae_val = df_folds["val_mae"].mean()
    mean_sel     = df_folds["n_features_selected"].mean()

    print(f"   >> [{name}] Train MAE: {mean_mae_tr:.2f} | Val MAE: {mean_mae_val:.2f} | Sel: {mean_sel:.0f} feats")
    logging.info(
        f"{name} | Train MAE: {mean_mae_tr:.4f} | Val MAE: {mean_mae_val:.4f} | "
        f"AvgSelected: {mean_sel:.1f} | Params: {params}"
    )

    out = {
        "config": name,
        "val_mae_mean": mean_mae_val,
        "train_mae_mean": mean_mae_tr,
        "avg_selected_features": float(mean_sel),
        **params
    }
    return out

# ---------------------------------------------------------
# 2) CORRER TODAS AS CONFIGS
# ---------------------------------------------------------
results = []
for i, (name, params) in enumerate(CONFIGS):
    if i % 5 == 0:
        print(f"\n-- doing {i+1}/{len(CONFIGS)}")

    res = eval_one_config(name, params)
    results.append(res)

results_df = pd.DataFrame(results)

# ---------------------------------------------------------
# 3) RESULTADOS FINAIS
# ---------------------------------------------------------
print("\n- 10 BEST Configurations")
results_df_sorted = results_df.sort_values("val_mae_mean", ascending=True)

cols_show = [
    "config",
    "val_mae_mean", "train_mae_mean",
    "avg_selected_features",
    "learning_rate", "max_iter", "l2_regularization", "max_leaf_nodes", "max_depth", "min_samples_leaf"
]

display(results_df_sorted[cols_show].head(10))

results_df_sorted.to_csv("random_search_fe_fs_results_75.csv", index=False)
print("stored at: random_search_fe_fs_results_75.csv")
print(" log in: random_search_fe_fs_results_75.log")
# Out:
# -- doing 1/100
#    >> [R0_iter1000_lr0.135_l21.97_leaf31] Train MAE: 1180.45 | Val MAE: 1304.01 | Sel: 19 feats
#    >> [R1_iter1000_lr0.091_l20.92_leaf63] Train MAE: 1128.71 | Val MAE: 1285.48 | Sel: 19 feats
#    >> [R2_iter1500_lr0.102_l20.71_leaf63] Train MAE: 1072.85 | Val MAE: 1270.03 | Sel: 19 feats
#    >> [R3_iter600_lr0.087_l21.03_leaf63] Train MAE: 1140.61 | Val MAE: 1290.58 | Sel: 19 feats
#    >> [R4_iter1000_lr0.135_l22.18_leaf31] Train MAE: 1188.32 | Val MAE: 1307.31 | Sel: 19 feats
#
# -- doing 6/100
#    >> [R5_iter1500_lr0.146_l22.50_leaf127] Train MAE: 1031.09 | Val MAE: 1265.65 | Sel: 19 feats
#    >> [R6_iter1000_lr0.139_l20.61_leaf31] Train MAE: 1150.44 | Val MAE: 1296.03 | Sel: 19 feats
#    >> [R7_iter600_lr0.095_l21.87_leaf63] Train MAE: 1083.03 | Val MAE: 1266.26 | Sel: 19 feats
#    >> [R8_iter1500_lr0.091_l20.50_leaf31] Train MAE: 1164.07 | Val MAE: 1298.15 | Sel: 19 feats
#    >> [R9_iter800_lr0.132_l22.18_leaf127] Train MAE: 1015.12 | Val MAE: 1264.00 | Sel: 19 feats
#
# -- doing 11/100
#    >> [R10_iter1500_lr0.143_l21.24_leaf63] Train MAE: 1108.51 | Val MAE: 1283.88 | Sel: 19 feats
#    >> [R11_iter800_lr0.080_l21.03_leaf63] Train MAE: 1129.03 | Val MAE: 1283.80 | Sel: 19 feats
#    >> [R12_iter1500_lr0.084_l22.18_leaf31] Train MAE: 1206.93 | Val MAE: 1316.34 | Sel: 19 feats
#    >> [R13_iter1000_lr0.084_l21.87_leaf63] Train MAE: 1103.91 | Val MAE: 1272.85 | Sel: 19 feats
#    >> [R14_iter800_lr0.102_l21.66_leaf63] Train MAE: 1155.86 | Val MAE: 1296.78 | Sel: 19 feats
#
# -- doing 16/100
#    >> [R15_iter1500_lr0.091_l21.34_leaf63] Train MAE: 1149.29 | Val MAE: 1295.00 | Sel: 19 feats
#    >> [R16_iter800_lr0.132_l20.50_leaf127] Train MAE: 1036.41 | Val MAE: 1265.01 | Sel: 19 feats
#    >> [R17_iter1000_lr0.132_l21.55_leaf63] Train MAE: 1084.95 | Val MAE: 1273.36 | Sel: 19 feats
#    >> [R18_iter800_lr0.098_l21.13_leaf31] Train MAE: 1198.96 | Val MAE: 1312.53 | Sel: 19 feats
#    >> [R19_iter1000_lr0.128_l20.61_leaf127] Train MAE: 1050.70 | Val MAE: 1267.87 | Sel: 19 feats
#
# -- doing 21/100
#    >> [R20_iter1500_lr0.106_l21.66_leaf127] Train MAE: 1080.27 | Val MAE: 1272.91 | Sel: 19 feats
#    >> [R21_iter1500_lr0.139_l21.87_leaf127] Train MAE: 1113.22 | Val MAE: 1287.11 | Sel: 19 feats
#    >> [R22_iter600_lr0.135_l21.66_leaf31] Train MAE: 1160.26 | Val MAE: 1298.52 | Sel: 19 feats
#    >> [R23_iter600_lr0.091_l22.08_leaf127] Train MAE: 1029.94 | Val MAE: 1258.57 | Sel: 19 feats
#    >> [R24_iter1000_lr0.132_l20.82_leaf63] Train MAE: 1121.67 | Val MAE: 1285.33 | Sel: 19 feats
#
# -- doing 26/100
#    >> [R25_iter600_lr0.117_l20.71_leaf63] Train MAE: 1171.87 | Val MAE: 1309.84 | Sel: 19 feats
#    >> [R26_iter1500_lr0.124_l20.71_leaf31] Train MAE: 1176.34 | Val MAE: 1302.52 | Sel: 19 feats
#    >> [R27_iter1500_lr0.132_l22.50_leaf31] Train MAE: 1177.62 | Val MAE: 1304.83 | Sel: 19 feats
#    >> [R28_iter600_lr0.095_l22.39_leaf31] Train MAE: 1211.40 | Val MAE: 1317.93 | Sel: 19 feats
#    >> [R29_iter800_lr0.080_l21.03_leaf63] Train MAE: 1101.04 | Val MAE: 1273.43 | Sel: 19 feats
#
# -- doing 31/100
#    >> [R30_iter600_lr0.132_l20.92_leaf127] Train MAE: 1009.43 | Val MAE: 1259.39 | Sel: 19 feats
#    >> [R31_iter800_lr0.139_l21.76_leaf63] Train MAE: 1142.05 | Val MAE: 1295.63 | Sel: 19 feats
#    >> [R32_iter800_lr0.095_l21.76_leaf127] Train MAE: 1015.66 | Val MAE: 1255.90 | Sel: 19 feats
#    >> [R33_iter1000_lr0.143_l22.29_leaf63] Train MAE: 1159.35 | Val MAE: 1304.90 | Sel: 19 feats
#    >> [R34_iter600_lr0.098_l22.08_leaf63] Train MAE: 1122.20 | Val MAE: 1280.53 | Sel: 19 feats
#
# -- doing 36/100
#    >> [R35_iter800_lr0.113_l21.45_leaf63] Train MAE: 1092.84 | Val MAE: 1272.50 | Sel: 19 feats
#    >> [R36_iter1500_lr0.084_l22.18_leaf127] Train MAE: 1084.49 | Val MAE: 1271.46 | Sel: 19 feats
#    >> [R37_iter800_lr0.084_l20.50_leaf31] Train MAE: 1185.14 | Val MAE: 1305.42 | Sel: 19 feats
#    >> [R38_iter600_lr0.143_l22.29_leaf127] Train MAE: 1033.68 | Val MAE: 1266.89 | Sel: 19 feats
#    >> [R39_iter800_lr0.143_l21.76_leaf63] Train MAE: 1078.47 | Val MAE: 1272.07 | Sel: 19 feats
#
# -- doing 41/100
#    >> [R40_iter800_lr0.146_l21.24_leaf31] Train MAE: 1154.80 | Val MAE: 1295.26 | Sel: 19 feats
#    >> [R41_iter1000_lr0.109_l21.45_leaf63] Train MAE: 1121.52 | Val MAE: 1282.22 | Sel: 19 feats
#    >> [R42_iter1500_lr0.124_l22.39_leaf63] Train MAE: 1105.10 | Val MAE: 1281.01 | Sel: 19 feats
#    >> [R43_iter1500_lr0.146_l21.24_leaf31] Train MAE: 1188.75 | Val MAE: 1310.22 | Sel: 19 feats
#    >> [R44_iter800_lr0.084_l21.87_leaf127] Train MAE: 1048.79 | Val MAE: 1263.52 | Sel: 19 feats
#
# -- doing 46/100
#    >> [R45_iter800_lr0.080_l22.08_leaf31] Train MAE: 1189.88 | Val MAE: 1308.84 | Sel: 19 feats
#    >> [R46_iter600_lr0.132_l22.29_leaf63] Train MAE: 1106.52 | Val MAE: 1278.83 | Sel: 19 feats
#    >> [R47_iter800_lr0.121_l22.39_leaf63] Train MAE: 1092.04 | Val MAE: 1276.41 | Sel: 19 feats
#    >> [R48_iter800_lr0.091_l22.50_leaf63] Train MAE: 1066.65 | Val MAE: 1263.39 | Sel: 19 feats
#    >> [R49_iter1500_lr0.121_l22.29_leaf63] Train MAE: 1111.22 | Val MAE: 1284.25 | Sel: 19 feats
#
# -- doing 51/100
#    >> [R50_iter1500_lr0.091_l21.55_leaf127] Train MAE: 1124.85 | Val MAE: 1288.30 | Sel: 19 feats
#    >> [R51_iter800_lr0.146_l21.55_leaf127] Train MAE: 1027.18 | Val MAE: 1266.92 | Sel: 19 feats
#    >> [R52_iter800_lr0.098_l20.50_leaf63] Train MAE: 1085.09 | Val MAE: 1271.47 | Sel: 19 feats
#    >> [R53_iter600_lr0.146_l22.18_leaf63] Train MAE: 1137.70 | Val MAE: 1295.18 | Sel: 19 feats
#    >> [R54_iter600_lr0.124_l21.24_leaf31] Train MAE: 1178.83 | Val MAE: 1304.04 | Sel: 19 feats
#
# -- doing 56/100
#    >> [R55_iter600_lr0.084_l21.34_leaf63] Train MAE: 1126.11 | Val MAE: 1282.29 | Sel: 19 feats
#    >> [R56_iter1500_lr0.080_l21.03_leaf127] Train MAE: 1101.93 | Val MAE: 1280.99 | Sel: 19 feats
#    >> [R57_iter1000_lr0.150_l22.39_leaf63] Train MAE: 1073.88 | Val MAE: 1273.06 | Sel: 19 feats
#    >> [R58_iter600_lr0.084_l22.29_leaf127] Train MAE: 1045.07 | Val MAE: 1264.81 | Sel: 19 feats
#    >> [R59_iter1000_lr0.102_l22.50_leaf127] Train MAE: 1048.36 | Val MAE: 1264.99 | Sel: 19 feats
#
# -- doing 61/100
#    >> [R60_iter600_lr0.106_l21.34_leaf63] Train MAE: 1129.89 | Val MAE: 1289.26 | Sel: 19 feats
#    >> [R61_iter600_lr0.132_l22.50_leaf31] Train MAE: 1164.86 | Val MAE: 1300.25 | Sel: 19 feats
#    >> [R62_iter800_lr0.124_l22.08_leaf63] Train MAE: 1128.66 | Val MAE: 1290.99 | Sel: 19 feats
#    >> [R63_iter1500_lr0.150_l20.50_leaf63] Train MAE: 1112.73 | Val MAE: 1285.96 | Sel: 19 feats
#    >> [R64_iter600_lr0.084_l21.45_leaf31] Train MAE: 1200.63 | Val MAE: 1313.79 | Sel: 19 feats
#
# -- doing 66/100
#    >> [R65_iter1500_lr0.106_l22.39_leaf63] Train MAE: 1084.60 | Val MAE: 1269.19 | Sel: 19 feats
#    >> [R66_iter1000_lr0.132_l21.45_leaf31] Train MAE: 1163.95 | Val MAE: 1302.64 | Sel: 19 feats
#    >> [R67_iter1500_lr0.135_l20.71_leaf127] Train MAE: 1108.39 | Val MAE: 1286.77 | Sel: 19 feats
#    >> [R68_iter1000_lr0.102_l22.39_leaf127] Train MAE: 1045.18 | Val MAE: 1262.62 | Sel: 19 feats
#    >> [R69_iter600_lr0.087_l21.03_leaf63] Train MAE: 1089.84 | Val MAE: 1269.27 | Sel: 19 feats
#
# -- doing 71/100
#    >> [R70_iter800_lr0.150_l22.39_leaf63] Train MAE: 1157.94 | Val MAE: 1303.06 | Sel: 19 feats
#    >> [R71_iter1500_lr0.084_l20.71_leaf127] Train MAE: 1051.00 | Val MAE: 1264.76 | Sel: 19 feats
#    >> [R72_iter1000_lr0.087_l21.97_leaf63] Train MAE: 1159.26 | Val MAE: 1299.91 | Sel: 19 feats
#    >> [R73_iter1000_lr0.095_l22.50_leaf31] Train MAE: 1191.10 | Val MAE: 1307.37 | Sel: 19 feats
#    >> [R74_iter600_lr0.098_l20.82_leaf31] Train MAE: 1188.09 | Val MAE: 1304.62 | Sel: 19 feats
#
# -- doing 76/100
#    >> [R75_iter1500_lr0.106_l21.66_leaf127] Train MAE: 1159.24 | Val MAE: 1301.93 | Sel: 19 feats
#    >> [R76_iter800_lr0.135_l20.71_leaf31] Train MAE: 1159.17 | Val MAE: 1299.45 | Sel: 19 feats
#    >> [R77_iter800_lr0.084_l22.50_leaf63] Train MAE: 1093.77 | Val MAE: 1272.98 | Sel: 19 feats
#    >> [R78_iter600_lr0.091_l22.39_leaf63] Train MAE: 1104.04 | Val MAE: 1274.55 | Sel: 19 feats
#    >> [R79_iter600_lr0.139_l21.66_leaf63] Train MAE: 1086.74 | Val MAE: 1275.62 | Sel: 19 feats
#
# -- doing 81/100
#    >> [R80_iter1000_lr0.102_l21.55_leaf63] Train MAE: 1089.93 | Val MAE: 1273.65 | Sel: 19 feats
#    >> [R81_iter1500_lr0.102_l20.82_leaf63] Train MAE: 1075.37 | Val MAE: 1266.76 | Sel: 19 feats
#    >> [R82_iter600_lr0.095_l20.82_leaf63] Train MAE: 1085.60 | Val MAE: 1271.33 | Sel: 19 feats
#    >> [R83_iter1000_lr0.102_l20.92_leaf31] Train MAE: 1201.80 | Val MAE: 1312.88 | Sel: 19 feats
#    >> [R84_iter1000_lr0.091_l21.34_leaf127] Train MAE: 1167.88 | Val MAE: 1306.97 | Sel: 19 feats
#
# -- doing 86/100
#    >> [R85_iter800_lr0.095_l22.29_leaf127] Train MAE: 1060.18 | Val MAE: 1265.66 | Sel: 19 feats
#    >> [R86_iter800_lr0.098_l20.61_leaf31] Train MAE: 1175.78 | Val MAE: 1299.90 | Sel: 19 feats
#    >> [R87_iter600_lr0.143_l20.82_leaf127] Train MAE: 1037.01 | Val MAE: 1269.02 | Sel: 19 feats
#    >> [R88_iter600_lr0.135_l22.50_leaf127] Train MAE: 1098.89 | Val MAE: 1282.99 | Sel: 19 feats
#    >> [R89_iter1000_lr0.143_l22.29_leaf63] Train MAE: 1086.59 | Val MAE: 1277.78 | Sel: 19 feats
#
# -- doing 91/100
#    >> [R90_iter1000_lr0.095_l21.03_leaf31] Train MAE: 1181.41 | Val MAE: 1300.84 | Sel: 19 feats
#    >> [R91_iter600_lr0.109_l21.03_leaf127] Train MAE: 1031.84 | Val MAE: 1261.16 | Sel: 19 feats
#    >> [R92_iter1000_lr0.124_l21.24_leaf127] Train MAE: 1053.47 | Val MAE: 1268.17 | Sel: 19 feats
#    >> [R93_iter1000_lr0.146_l21.13_leaf127] Train MAE: 1032.04 | Val MAE: 1266.47 | Sel: 19 feats
#    >> [R94_iter800_lr0.080_l20.61_leaf127] Train MAE: 1055.13 | Val MAE: 1262.37 | Sel: 19 feats
#
# -- doing 96/100
#    >> [R95_iter800_lr0.091_l20.61_leaf63] Train MAE: 1113.31 | Val MAE: 1281.61 | Sel: 19 feats
#    >> [R96_iter800_lr0.084_l21.55_leaf63] Train MAE: 1124.34 | Val MAE: 1283.07 | Sel: 19 feats
#    >> [R97_iter600_lr0.146_l20.50_leaf63] Train MAE: 1080.02 | Val MAE: 1274.27 | Sel: 19 feats
#    >> [R98_iter1000_lr0.124_l22.08_leaf63] Train MAE: 1140.88 | Val MAE: 1294.14 | Sel: 19 feats
#    >> [R99_iter600_lr0.132_l22.29_leaf127] Train MAE: 1025.56 | Val MAE: 1263.05 | Sel: 19 feats
#
# - 10 BEST Configurations
#                                  config  val_mae_mean  train_mae_mean  \
# 32   R32_iter800_lr0.095_l21.76_leaf127   1255.900728     1015.664073
# 23   R23_iter600_lr0.091_l22.08_leaf127   1258.573143     1029.943084
# 30   R30_iter600_lr0.132_l20.92_leaf127   1259.392651     1009.426981
# 91   R91_iter600_lr0.109_l21.03_leaf127   1261.156148     1031.844597
# 94   R94_iter800_lr0.080_l20.61_leaf127   1262.365200     1055.133620
# 68  R68_iter1000_lr0.102_l22.39_leaf127   1262.616877     1045.177011
# 99   R99_iter600_lr0.132_l22.29_leaf127   1263.048537     1025.556081
# 48    R48_iter800_lr0.091_l22.50_leaf63   1263.392331     1066.654068
# 44   R44_iter800_lr0.084_l21.87_leaf127   1263.521698     1048.792860
# 9     R9_iter800_lr0.132_l22.18_leaf127   1263.999785     1015.120707
#
#     avg_selected_features  learning_rate  max_iter  l2_regularization  \
# 32                   19.0       0.094737       800           1.763158
# 23                   19.0       0.091053       600           2.078947
# 30                   19.0       0.131579       600           0.921053
# 91                   19.0       0.109474       600           1.026316
# 94                   19.0       0.080000       800           0.605263
# 68                   19.0       0.102105      1000           2.394737
# 99                   19.0       0.131579       600           2.289474
# 48                   19.0       0.091053       800           2.500000
# 44                   19.0       0.083684       800           1.868421
# 9                    19.0       0.131579       800           2.184211
#
#     max_leaf_nodes  max_depth  min_samples_leaf
# 32             127       20.0                20
# 23             127       15.0                20
# 30             127       20.0                20
# 91             127       15.0                20
# 94             127       15.0                30
# 68             127       20.0                30
# 99             127       20.0                20
# 48              63       15.0                20
# 44             127       15.0                20
# 9              127       25.0                30
# stored at: random_search_fe_fs_results_75.csv
#  log in: random_search_fe_fs_results_75.log

# %% [markdown]
# ##### __80%__

# %%
import numpy as np
import pandas as pd
import random
import logging

from IPython.display import display
from sklearn.model_selection import KFold
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import mean_absolute_error

# ---------------------------------------------------------
# 0) CONFIGS GERAIS
# ---------------------------------------------------------
N_SPLITS = 8
N_ITER = 100
RANDOM_STATE = 42

# Percentagem de features a manter no SelectFromModel
FS_KEEP_RATIO = 0.8

# RandomForest para Feature Selection (podes ajustar)
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

# ---------------------------------------------------------
# 0.1) CONFIGURAÇÃO DO LOGGING
# ---------------------------------------------------------

logging.basicConfig(
    filename="random_search_fe_fs_results_80.log",
    level=logging.INFO,
    format="%(asctime)s - %(message)s",
    filemode="w",
    force=True
)
logging.info("- 10 iterations")

# ---------------------------------------------------------
# 0.2) CONFIGURAÇÃO DO RANDOM SEARCH
# ---------------------------------------------------------
param_distributions = {
    "min_samples_leaf": [20, 30, 40],
    "max_leaf_nodes": [31, 63, 127],
    "max_iter": [600, 800, 1000, 1500],
    "max_depth": [None, 10, 15, 20, 25],
    "learning_rate": np.linspace(0.08, 0.15, 20),
    "l2_regularization": np.linspace(0.5, 2.5, 20),
    "max_bins": [255],
    "random_state": [RANDOM_STATE],
}

def get_random_configs(n_iter: int):
    configs = []
    keys = list(param_distributions.keys())

    for i in range(n_iter):
        params = {}
        for key in keys:
            params[key] = random.choice(list(param_distributions[key]))

        name = (
            f"R{i}_iter{params['max_iter']}"
            f"_lr{float(params['learning_rate']):.3f}"
            f"_l2{float(params['l2_regularization']):.2f}"
            f"_leaf{params['max_leaf_nodes']}"
        )
        configs.append((name, params))
    return configs

CONFIGS = get_random_configs(N_ITER)

# ---------------------------------------------------------
# 1) K-FOLD E SETUP
# ---------------------------------------------------------
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# Assume que já tens no notebook:
# - X, y
# - numeric_features, categorical_features
# - fill_unknown, column_string_transformer
# - fit_* e transform_* (os teus passos)
# - valid_brands, valid_models_by_brand, valid_transmissions, valid_fueltypes
# - MyTargetEncoder, MyOneHotEncoder

cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]
high_card_features = ["Brand", "model"]
low_card_features  = [c for c in categorical_features if c not in high_card_features]

def _normalize_cats(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    for col in cols_to_normalize:
        if col in df.columns:
            df[col] = fill_unknown(df[col])
            df = column_string_transformer(
                df, column=col, remove_middle_spaces=True, allow_extra_chars=""
            )
    return df

# ---------------------------------------------------------
# 1.1) FEATURE ENGINEERING (FUNÇÕES)
# ---------------------------------------------------------
def create_age_and_drop_year(df, year_col="year", base_year=2020, clip_future=True):
    df = df.copy()
    year = pd.to_numeric(df[year_col], errors="coerce")
    age = base_year - year
    if clip_future:
        age = age.clip(lower=0)
    df["age"] = age
    df = df.drop(columns=[year_col])
    return df

def add_owners_flagged(
    df,
    owners_col="previousOwners",
    new_col="owners_flagged",
    drop_original=True,
    na_as_zero=True
):
    df = df.copy()
    owners = pd.to_numeric(df[owners_col], errors="coerce")

    if na_as_zero:
        owners_filled = owners.fillna(0)
        df[new_col] = (owners_filled > 1).astype("int8")
    else:
        df[new_col] = (owners > 1).fillna(False).astype("int8")

    if drop_original and owners_col in df.columns:
        df = df.drop(columns=[owners_col])

    return df

def add_mileage_features(df, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True):
    df = df.copy()

    mileage = pd.to_numeric(df[mileage_col], errors="coerce")
    mileage = mileage.where(mileage >= 0, np.nan)

    df["log_mileage"] = np.log1p(mileage)

    age = pd.to_numeric(df[age_col], errors="coerce")
    age_safe = age.clip(lower=1)  # só para divisão
    df["miles_per_year"] = mileage / age_safe
    df["log_miles_per_year"] = np.log1p(df["miles_per_year"])

    if drop_ratio and "miles_per_year" in df.columns:
        df = df.drop(columns=["miles_per_year"])

    if drop_original and mileage_col in df.columns:
        df = df.drop(columns=[mileage_col])

    return df

def add_engine_bins(df, engine_col="engineSize", new_col="engine_bin", bins=None):
    df = df.copy()

    engine = pd.to_numeric(df[engine_col], errors="coerce")
    engine = engine.where(engine >= 0, np.nan)

    if bins is None:
        bins = [0, 1.0, 1.3, 1.6, 2.0, 2.5, 3.0, 4.0, np.inf]

    df[new_col] = pd.cut(engine, bins=bins, include_lowest=True, labels=False).astype("Int64")
    return df

# ---------------------------------------------------------
# 1.2) EVAL DE 1 CONFIG
# ---------------------------------------------------------
def eval_one_config(name: str, params: dict) -> dict:
    fold_rows = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):
        X_train = X.iloc[train_idx].copy()
        X_val   = X.iloc[val_idx].copy()
        y_train = y.iloc[train_idx].copy()
        y_val   = y.iloc[val_idx].copy()

        # TARGET (LOG)
        y_train_log = np.log1p(y_train)

        # Normalizar categóricas base
        X_train = _normalize_cats(X_train)
        X_val   = _normalize_cats(X_val)

        # Restringir às colunas base (mantém previousOwners e mileage para cleaning)
        base_cols = [c for c in (numeric_features + categorical_features) if c in X_train.columns]
        X_train = X_train[base_cols].copy()
        X_val   = X_val[base_cols].copy()

        # -----------------------------------------------------
        # A) CLEANING
        # -----------------------------------------------------
        year_state = fit_year_median(X_train, year_col="year", model_col="model")
        X_train = transform_year_with_model_median(X_train, state=year_state)
        X_val   = transform_year_with_model_median(X_val,   state=year_state)

        engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
        X_train = transform_engine_size_imputer(X_train, state=engine_state)
        X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

        X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
        X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

        mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
        X_train = transform_mpg_imputer(X_train, state=mpg_state)
        X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

        owners_state = fit_previous_owners_imputer(X_train, "previousOwners", "year", "mileage")
        X_train = transform_previous_owners_imputer(X_train, state=owners_state)
        X_val   = transform_previous_owners_imputer(X_val,   state=owners_state)

        # -----------------------------------------------------
        # B) RESOLVERS
        # -----------------------------------------------------
        brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
        X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
        X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

        model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
        X_train, _, _ = transform_invalid_models(X_train, model_state)
        X_val,   _, _ = transform_invalid_models(X_val,   model_state)

        transm_state = fit_transmission_resolver(X_train, valid_transmissions)
        X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
        X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

        fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
        X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
        X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

        # -----------------------------------------------------
        # C) FEATURE ENGINEERING
        # -----------------------------------------------------
        X_train = add_owners_flagged(X_train, owners_col="previousOwners", new_col="owners_flagged", drop_original=True)
        X_val   = add_owners_flagged(X_val,   owners_col="previousOwners", new_col="owners_flagged", drop_original=True)

        X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
        X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

        X_train = add_mileage_features(X_train, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
        X_val   = add_mileage_features(X_val,   mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)

        X_train = add_engine_bins(X_train, engine_col="engineSize", new_col="engine_bin")
        X_val   = add_engine_bins(X_val,   engine_col="engineSize", new_col="engine_bin")

        # engine_bin como low-card para OHE (robusto a NaNs)
        X_train["engine_bin"] = X_train["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        X_val["engine_bin"]   = X_val["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")

        low_card_curr = low_card_features + ["engine_bin"]

        # -----------------------------------------------------
        # D) ENCODING
        # -----------------------------------------------------
        te = MyTargetEncoder(smoothing=5)
        te.fit(X_train[high_card_features], y_train_log)
        X_train_high = te.transform(X_train[high_card_features])
        X_val_high   = te.transform(X_val[high_card_features])

        ohe = MyOneHotEncoder()
        ohe.fit(X_train[low_card_curr])
        X_train_low = ohe.transform(X_train[low_card_curr])
        X_val_low   = ohe.transform(X_val[low_card_curr])

        X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
        X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

        drop_for_numeric = set(high_card_features + low_card_curr)
        numeric_features_curr = [c for c in X_train.columns if c not in drop_for_numeric]

        X_train_final = pd.concat([X_train[numeric_features_curr], X_train_cat], axis=1)
        X_val_final   = pd.concat([X_val[numeric_features_curr],   X_val_cat],   axis=1)

        # alinhar colunas
        X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

        # -----------------------------------------------------
        # D.1) FEATURE SELECTION (SelectFromModel + RandomForest)
        #     - threshold=-np.inf
        #     - max_features = 80% das features
        # -----------------------------------------------------
        n_feats = X_train_final.shape[1]
        k = int(np.ceil(FS_KEEP_RATIO * n_feats))
        k = max(1, min(k, n_feats))

        rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
        rf_fs.fit(X_train_final, y_train_log)

        selector = SelectFromModel(
            estimator=rf_fs,
            threshold=-np.inf,
            max_features=k,
            prefit=True
        )

        support = selector.get_support()
        selected_cols = X_train_final.columns[support]

        X_train_sel = X_train_final[selected_cols]
        X_val_sel   = X_val_final[selected_cols]

        # -----------------------------------------------------
        # E) TREINO (HGB)
        # -----------------------------------------------------
        model = HistGradientBoostingRegressor(**params)
        model.fit(X_train_sel, y_train_log)

        pred_tr_log  = model.predict(X_train_sel)
        pred_val_log = model.predict(X_val_sel)

        pred_tr  = np.expm1(pred_tr_log)
        pred_val = np.expm1(pred_val_log)

        mae_tr  = mean_absolute_error(y_train, pred_tr)
        mae_val = mean_absolute_error(y_val,   pred_val)

        fold_rows.append({
            "config": name,
            "fold": fold,
            "n_features_total": n_feats,
            "n_features_selected": len(selected_cols),
            "train_mae": mae_tr,
            "val_mae": mae_val
        })

    df_folds = pd.DataFrame(fold_rows)
    mean_mae_tr  = df_folds["train_mae"].mean()
    mean_mae_val = df_folds["val_mae"].mean()
    mean_sel     = df_folds["n_features_selected"].mean()

    print(f"   >> [{name}] Train MAE: {mean_mae_tr:.2f} | Val MAE: {mean_mae_val:.2f} | Sel: {mean_sel:.0f} feats")
    logging.info(
        f"{name} | Train MAE: {mean_mae_tr:.4f} | Val MAE: {mean_mae_val:.4f} | "
        f"AvgSelected: {mean_sel:.1f} | Params: {params}"
    )

    out = {
        "config": name,
        "val_mae_mean": mean_mae_val,
        "train_mae_mean": mean_mae_tr,
        "avg_selected_features": float(mean_sel),
        **params
    }
    return out

# ---------------------------------------------------------
# 2) CORRER TODAS AS CONFIGS
# ---------------------------------------------------------
results = []
for i, (name, params) in enumerate(CONFIGS):
    if i % 5 == 0:
        print(f"\n-- doing {i+1}/{len(CONFIGS)}")

    res = eval_one_config(name, params)
    results.append(res)

results_df = pd.DataFrame(results)

# ---------------------------------------------------------
# 3) RESULTADOS FINAIS
# ---------------------------------------------------------
print("\n- 10 BEST Configurations")
results_df_sorted = results_df.sort_values("val_mae_mean", ascending=True)

cols_show = [
    "config",
    "val_mae_mean", "train_mae_mean",
    "avg_selected_features",
    "learning_rate", "max_iter", "l2_regularization", "max_leaf_nodes", "max_depth", "min_samples_leaf"
]

display(results_df_sorted[cols_show].head(10))

results_df_sorted.to_csv("random_search_fe_fs_results_80.csv", index=False)
print("stored at: random_search_fe_fs_results_80.csv")
print(" log in: random_search_fe_fs_results_80.log")
# Out:
# -- doing 1/100
#    >> [R0_iter800_lr0.121_l21.45_leaf127] Train MAE: 1036.81 | Val MAE: 1264.29 | Sel: 20 feats
#    >> [R1_iter600_lr0.080_l22.08_leaf63] Train MAE: 1131.76 | Val MAE: 1285.66 | Sel: 20 feats
#    >> [R2_iter600_lr0.091_l21.55_leaf31] Train MAE: 1196.95 | Val MAE: 1311.68 | Sel: 20 feats
#    >> [R3_iter800_lr0.087_l22.29_leaf31] Train MAE: 1213.84 | Val MAE: 1320.26 | Sel: 20 feats
#    >> [R4_iter1000_lr0.098_l21.03_leaf127] Train MAE: 1039.67 | Val MAE: 1259.13 | Sel: 20 feats
#
# -- doing 6/100
#    >> [R5_iter1500_lr0.098_l20.82_leaf127] Train MAE: 1097.56 | Val MAE: 1280.49 | Sel: 20 feats
#    >> [R6_iter600_lr0.087_l21.03_leaf31] Train MAE: 1208.61 | Val MAE: 1316.05 | Sel: 20 feats
#    >> [R7_iter1000_lr0.121_l22.50_leaf63] Train MAE: 1114.01 | Val MAE: 1282.69 | Sel: 20 feats
#    >> [R8_iter800_lr0.146_l20.71_leaf31] Train MAE: 1178.16 | Val MAE: 1309.55 | Sel: 20 feats
#    >> [R9_iter600_lr0.135_l21.76_leaf31] Train MAE: 1172.03 | Val MAE: 1301.57 | Sel: 20 feats
#
# -- doing 11/100
#    >> [R10_iter600_lr0.080_l21.97_leaf63] Train MAE: 1115.60 | Val MAE: 1277.74 | Sel: 20 feats
#    >> [R11_iter800_lr0.143_l21.76_leaf63] Train MAE: 1110.30 | Val MAE: 1283.64 | Sel: 20 feats
#    >> [R12_iter800_lr0.098_l20.82_leaf31] Train MAE: 1193.19 | Val MAE: 1308.24 | Sel: 20 feats
#    >> [R13_iter600_lr0.143_l21.24_leaf63] Train MAE: 1110.57 | Val MAE: 1283.92 | Sel: 20 feats
#    >> [R14_iter1000_lr0.091_l22.29_leaf63] Train MAE: 1116.34 | Val MAE: 1279.25 | Sel: 20 feats
#
# -- doing 16/100
#    >> [R15_iter1500_lr0.095_l20.50_leaf127] Train MAE: 1022.64 | Val MAE: 1258.24 | Sel: 20 feats
#    >> [R16_iter1500_lr0.095_l20.61_leaf31] Train MAE: 1153.94 | Val MAE: 1290.49 | Sel: 20 feats
#    >> [R17_iter1500_lr0.084_l22.50_leaf31] Train MAE: 1197.15 | Val MAE: 1312.80 | Sel: 20 feats
#    >> [R18_iter800_lr0.087_l20.61_leaf63] Train MAE: 1095.96 | Val MAE: 1274.84 | Sel: 20 feats
#    >> [R19_iter1500_lr0.106_l20.61_leaf63] Train MAE: 1157.06 | Val MAE: 1296.90 | Sel: 20 feats
#
# -- doing 21/100
#    >> [R20_iter800_lr0.146_l22.29_leaf127] Train MAE: 1094.51 | Val MAE: 1285.11 | Sel: 20 feats
#    >> [R21_iter1500_lr0.143_l20.92_leaf63] Train MAE: 1104.92 | Val MAE: 1280.51 | Sel: 20 feats
#    >> [R22_iter600_lr0.080_l20.61_leaf127] Train MAE: 1056.01 | Val MAE: 1264.88 | Sel: 20 feats
#    >> [R23_iter1000_lr0.139_l21.97_leaf127] Train MAE: 1048.43 | Val MAE: 1268.74 | Sel: 20 feats
#    >> [R24_iter800_lr0.098_l20.50_leaf127] Train MAE: 1027.28 | Val MAE: 1257.21 | Sel: 20 feats
#
# -- doing 26/100
#    >> [R25_iter1500_lr0.095_l20.61_leaf63] Train MAE: 1089.25 | Val MAE: 1275.15 | Sel: 20 feats
#    >> [R26_iter800_lr0.113_l22.39_leaf127] Train MAE: 1053.55 | Val MAE: 1266.14 | Sel: 20 feats
#    >> [R27_iter1500_lr0.132_l21.34_leaf63] Train MAE: 1107.56 | Val MAE: 1282.90 | Sel: 20 feats
#    >> [R28_iter1000_lr0.124_l20.82_leaf31] Train MAE: 1168.59 | Val MAE: 1300.21 | Sel: 20 feats
#    >> [R29_iter1500_lr0.109_l21.24_leaf31] Train MAE: 1177.46 | Val MAE: 1304.71 | Sel: 20 feats
#
# -- doing 31/100
#    >> [R30_iter1000_lr0.135_l20.50_leaf63] Train MAE: 1129.19 | Val MAE: 1290.38 | Sel: 20 feats
#    >> [R31_iter1500_lr0.117_l22.18_leaf63] Train MAE: 1084.27 | Val MAE: 1276.87 | Sel: 20 feats
#    >> [R32_iter1500_lr0.109_l20.92_leaf31] Train MAE: 1182.18 | Val MAE: 1308.24 | Sel: 20 feats
#    >> [R33_iter1000_lr0.091_l21.66_leaf63] Train MAE: 1114.39 | Val MAE: 1280.84 | Sel: 20 feats
#    >> [R34_iter800_lr0.139_l21.55_leaf31] Train MAE: 1192.09 | Val MAE: 1317.91 | Sel: 20 feats
#
# -- doing 36/100
#    >> [R35_iter600_lr0.080_l20.50_leaf127] Train MAE: 1035.05 | Val MAE: 1257.90 | Sel: 20 feats
#    >> [R36_iter1500_lr0.117_l21.24_leaf63] Train MAE: 1094.86 | Val MAE: 1275.22 | Sel: 20 feats
#    >> [R37_iter800_lr0.098_l22.08_leaf127] Train MAE: 1054.44 | Val MAE: 1264.83 | Sel: 20 feats
#    >> [R38_iter600_lr0.117_l21.34_leaf63] Train MAE: 1080.60 | Val MAE: 1269.97 | Sel: 20 feats
#    >> [R39_iter600_lr0.080_l20.50_leaf127] Train MAE: 1128.70 | Val MAE: 1288.08 | Sel: 20 feats
#
# -- doing 41/100
#    >> [R40_iter1000_lr0.098_l22.18_leaf127] Train MAE: 1021.63 | Val MAE: 1259.07 | Sel: 20 feats
#    >> [R41_iter800_lr0.113_l22.39_leaf63] Train MAE: 1092.16 | Val MAE: 1274.11 | Sel: 20 feats
#    >> [R42_iter600_lr0.139_l22.39_leaf127] Train MAE: 1055.96 | Val MAE: 1271.52 | Sel: 20 feats
#    >> [R43_iter800_lr0.135_l21.03_leaf31] Train MAE: 1152.43 | Val MAE: 1292.03 | Sel: 20 feats
#    >> [R44_iter800_lr0.109_l21.34_leaf127] Train MAE: 1068.38 | Val MAE: 1269.20 | Sel: 20 feats
#
# -- doing 46/100
#    >> [R45_iter600_lr0.150_l20.92_leaf63] Train MAE: 1071.87 | Val MAE: 1273.20 | Sel: 20 feats
#    >> [R46_iter1500_lr0.091_l21.34_leaf31] Train MAE: 1176.69 | Val MAE: 1303.52 | Sel: 20 feats
#    >> [R47_iter800_lr0.102_l21.34_leaf127] Train MAE: 1052.19 | Val MAE: 1263.55 | Sel: 20 feats
#    >> [R48_iter800_lr0.106_l21.03_leaf127] Train MAE: 1024.23 | Val MAE: 1260.01 | Sel: 20 feats
#    >> [R49_iter1500_lr0.150_l21.13_leaf63] Train MAE: 1108.62 | Val MAE: 1283.19 | Sel: 20 feats
#
# -- doing 51/100
#    >> [R50_iter1000_lr0.121_l22.50_leaf127] Train MAE: 1026.09 | Val MAE: 1261.49 | Sel: 20 feats
#    >> [R51_iter600_lr0.087_l21.97_leaf31] Train MAE: 1199.43 | Val MAE: 1313.36 | Sel: 20 feats
#    >> [R52_iter800_lr0.113_l22.50_leaf127] Train MAE: 1056.98 | Val MAE: 1267.03 | Sel: 20 feats
#    >> [R53_iter1000_lr0.146_l21.03_leaf127] Train MAE: 1060.58 | Val MAE: 1273.69 | Sel: 20 feats
#    >> [R54_iter1000_lr0.121_l21.13_leaf31] Train MAE: 1185.56 | Val MAE: 1309.08 | Sel: 20 feats
#
# -- doing 56/100
#    >> [R55_iter1000_lr0.121_l21.87_leaf127] Train MAE: 1013.37 | Val MAE: 1258.52 | Sel: 20 feats
#    >> [R56_iter600_lr0.117_l22.39_leaf127] Train MAE: 1028.06 | Val MAE: 1258.75 | Sel: 20 feats
#    >> [R57_iter1000_lr0.087_l21.55_leaf127] Train MAE: 1126.35 | Val MAE: 1289.81 | Sel: 20 feats
#    >> [R58_iter600_lr0.124_l22.18_leaf63] Train MAE: 1091.26 | Val MAE: 1276.11 | Sel: 20 feats
#    >> [R59_iter1500_lr0.139_l21.55_leaf127] Train MAE: 1021.58 | Val MAE: 1266.60 | Sel: 20 feats
#
# -- doing 61/100
#    >> [R60_iter1500_lr0.132_l21.55_leaf127] Train MAE: 1062.90 | Val MAE: 1273.96 | Sel: 20 feats
#    >> [R61_iter1000_lr0.084_l21.97_leaf63] Train MAE: 1091.05 | Val MAE: 1269.41 | Sel: 20 feats
#    >> [R62_iter1000_lr0.080_l20.50_leaf31] Train MAE: 1187.85 | Val MAE: 1304.93 | Sel: 20 feats
#    >> [R63_iter1000_lr0.124_l21.45_leaf63] Train MAE: 1106.13 | Val MAE: 1279.89 | Sel: 20 feats
#    >> [R64_iter800_lr0.098_l22.08_leaf31] Train MAE: 1205.83 | Val MAE: 1317.31 | Sel: 20 feats
#
# -- doing 66/100
#    >> [R65_iter1000_lr0.084_l22.18_leaf31] Train MAE: 1166.65 | Val MAE: 1298.98 | Sel: 20 feats
#    >> [R66_iter1500_lr0.146_l22.18_leaf31] Train MAE: 1180.78 | Val MAE: 1309.06 | Sel: 20 feats
#    >> [R67_iter600_lr0.080_l21.03_leaf127] Train MAE: 1047.15 | Val MAE: 1261.46 | Sel: 20 feats
#    >> [R68_iter1000_lr0.143_l21.24_leaf127] Train MAE: 1012.21 | Val MAE: 1263.59 | Sel: 20 feats
#    >> [R69_iter800_lr0.098_l22.08_leaf63] Train MAE: 1123.99 | Val MAE: 1286.33 | Sel: 20 feats
#
# -- doing 71/100
#    >> [R70_iter1500_lr0.091_l22.50_leaf127] Train MAE: 1057.66 | Val MAE: 1266.58 | Sel: 20 feats
#    >> [R71_iter800_lr0.106_l22.18_leaf31] Train MAE: 1151.24 | Val MAE: 1292.17 | Sel: 20 feats
#    >> [R72_iter1500_lr0.098_l20.82_leaf63] Train MAE: 1097.04 | Val MAE: 1273.73 | Sel: 20 feats
#    >> [R73_iter1500_lr0.121_l21.87_leaf127] Train MAE: 1031.86 | Val MAE: 1264.99 | Sel: 20 feats
#    >> [R74_iter1000_lr0.095_l21.13_leaf127] Train MAE: 998.04 | Val MAE: 1250.81 | Sel: 20 feats
#
# -- doing 76/100
#    >> [R75_iter1000_lr0.106_l21.13_leaf127] Train MAE: 1026.75 | Val MAE: 1261.90 | Sel: 20 feats
#    >> [R76_iter600_lr0.150_l20.50_leaf127] Train MAE: 1039.16 | Val MAE: 1268.87 | Sel: 20 feats
#    >> [R77_iter1000_lr0.117_l21.55_leaf31] Train MAE: 1176.70 | Val MAE: 1303.11 | Sel: 20 feats
#    >> [R78_iter600_lr0.146_l20.50_leaf63] Train MAE: 1101.63 | Val MAE: 1280.53 | Sel: 20 feats
#    >> [R79_iter800_lr0.098_l21.55_leaf127] Train MAE: 1067.31 | Val MAE: 1267.41 | Sel: 20 feats
#
# -- doing 81/100
#    >> [R80_iter800_lr0.139_l21.76_leaf127] Train MAE: 1085.89 | Val MAE: 1280.16 | Sel: 20 feats
#    >> [R81_iter1500_lr0.139_l21.34_leaf31] Train MAE: 1196.07 | Val MAE: 1312.67 | Sel: 20 feats
#    >> [R82_iter600_lr0.113_l20.71_leaf127] Train MAE: 1025.60 | Val MAE: 1261.12 | Sel: 20 feats
#    >> [R83_iter1000_lr0.080_l21.76_leaf127] Train MAE: 1028.85 | Val MAE: 1257.27 | Sel: 20 feats
#    >> [R84_iter600_lr0.106_l21.03_leaf127] Train MAE: 1077.66 | Val MAE: 1271.01 | Sel: 20 feats
#
# -- doing 86/100
#    >> [R85_iter1500_lr0.128_l21.66_leaf63] Train MAE: 1081.48 | Val MAE: 1270.82 | Sel: 20 feats
#    >> [R86_iter800_lr0.113_l22.39_leaf63] Train MAE: 1111.27 | Val MAE: 1283.39 | Sel: 20 feats
#    >> [R87_iter800_lr0.109_l22.29_leaf127] Train MAE: 1020.24 | Val MAE: 1258.44 | Sel: 20 feats
#    >> [R88_iter1000_lr0.124_l21.55_leaf127] Train MAE: 1162.48 | Val MAE: 1306.07 | Sel: 20 feats
#    >> [R89_iter800_lr0.113_l21.66_leaf63] Train MAE: 1109.16 | Val MAE: 1278.59 | Sel: 20 feats
#
# -- doing 91/100
#    >> [R90_iter600_lr0.132_l21.76_leaf31] Train MAE: 1165.75 | Val MAE: 1299.18 | Sel: 20 feats
#    >> [R91_iter600_lr0.128_l21.87_leaf63] Train MAE: 1105.83 | Val MAE: 1279.54 | Sel: 20 feats
#    >> [R92_iter1000_lr0.095_l20.82_leaf31] Train MAE: 1192.23 | Val MAE: 1311.54 | Sel: 20 feats
#    >> [R93_iter1500_lr0.132_l21.97_leaf31] Train MAE: 1167.06 | Val MAE: 1298.64 | Sel: 20 feats
#    >> [R94_iter1000_lr0.113_l22.39_leaf63] Train MAE: 1107.19 | Val MAE: 1278.98 | Sel: 20 feats
#
# -- doing 96/100
#    >> [R95_iter1000_lr0.106_l21.97_leaf31] Train MAE: 1192.20 | Val MAE: 1312.15 | Sel: 20 feats
#    >> [R96_iter1000_lr0.102_l21.24_leaf63] Train MAE: 1117.31 | Val MAE: 1282.72 | Sel: 20 feats
#    >> [R97_iter1500_lr0.084_l21.97_leaf127] Train MAE: 1061.08 | Val MAE: 1264.05 | Sel: 20 feats
#    >> [R98_iter800_lr0.091_l21.76_leaf127] Train MAE: 1151.53 | Val MAE: 1301.39 | Sel: 20 feats
#    >> [R99_iter600_lr0.087_l20.82_leaf63] Train MAE: 1142.36 | Val MAE: 1290.68 | Sel: 20 feats
#
# - 10 BEST Configurations
#                                  config  val_mae_mean  train_mae_mean  \
# 74  R74_iter1000_lr0.095_l21.13_leaf127   1250.814305      998.037088
# 24   R24_iter800_lr0.098_l20.50_leaf127   1257.213990     1027.283721
# 83  R83_iter1000_lr0.080_l21.76_leaf127   1257.267903     1028.851515
# 35   R35_iter600_lr0.080_l20.50_leaf127   1257.896845     1035.049646
# 15  R15_iter1500_lr0.095_l20.50_leaf127   1258.239632     1022.641400
# 87   R87_iter800_lr0.109_l22.29_leaf127   1258.436234     1020.237767
# 55  R55_iter1000_lr0.121_l21.87_leaf127   1258.524347     1013.367800
# 56   R56_iter600_lr0.117_l22.39_leaf127   1258.754556     1028.059346
# 40  R40_iter1000_lr0.098_l22.18_leaf127   1259.067651     1021.625841
# 4    R4_iter1000_lr0.098_l21.03_leaf127   1259.133364     1039.666950
#
#     avg_selected_features  learning_rate  max_iter  l2_regularization  \
# 74                   20.0       0.094737      1000           1.131579
# 24                   20.0       0.098421       800           0.500000
# 83                   20.0       0.080000      1000           1.763158
# 35                   20.0       0.080000       600           0.500000
# 15                   20.0       0.094737      1500           0.500000
# 87                   20.0       0.109474       800           2.289474
# 55                   20.0       0.120526      1000           1.868421
# 56                   20.0       0.116842       600           2.394737
# 40                   20.0       0.098421      1000           2.184211
# 4                    20.0       0.098421      1000           1.026316
#
#     max_leaf_nodes  max_depth  min_samples_leaf
# 74             127        NaN                20
# 24             127       15.0                20
# 83             127        NaN                30
# 35             127       20.0                30
# 15             127       15.0                20
# 87             127        NaN                20
# 55             127       25.0                20
# 56             127       20.0                30
# 40             127       20.0                20
# 4              127        NaN                30
# stored at: random_search_fe_fs_results_80.csv
#  log in: random_search_fe_fs_results_80.log

# %% [markdown]
# ##### __65%__

# %%
import numpy as np
import pandas as pd
import random
import logging

from IPython.display import display
from sklearn.model_selection import KFold
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import mean_absolute_error

# ---------------------------------------------------------
# 0) CONFIGS GERAIS
# ---------------------------------------------------------
N_SPLITS = 8
N_ITER = 50
RANDOM_STATE = 42

# Percentagem de features a manter no SelectFromModel
FS_KEEP_RATIO = 0.65

# RandomForest para Feature Selection (podes ajustar)
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

# ---------------------------------------------------------
# 0.1) CONFIGURAÇÃO DO LOGGING
# ---------------------------------------------------------

logging.basicConfig(
    filename="random_search_fe_fs_results_65.log",
    level=logging.INFO,
    format="%(asctime)s - %(message)s",
    filemode="w",
    force=True
)
logging.info("- 10 iterations")

# ---------------------------------------------------------
# 0.2) CONFIGURAÇÃO DO RANDOM SEARCH
# ---------------------------------------------------------
param_distributions = {
    "min_samples_leaf": [20, 30, 40],
    "max_leaf_nodes": [31, 63, 127],
    "max_iter": [600, 800, 1000, 1500],
    "max_depth": [None, 10, 15, 20, 25],
    "learning_rate": np.linspace(0.08, 0.15, 20),
    "l2_regularization": np.linspace(0.5, 2.5, 20),
    "max_bins": [255],
    "random_state": [RANDOM_STATE],
}

def get_random_configs(n_iter: int):
    configs = []
    keys = list(param_distributions.keys())

    for i in range(n_iter):
        params = {}
        for key in keys:
            params[key] = random.choice(list(param_distributions[key]))

        name = (
            f"R{i}_iter{params['max_iter']}"
            f"_lr{float(params['learning_rate']):.3f}"
            f"_l2{float(params['l2_regularization']):.2f}"
            f"_leaf{params['max_leaf_nodes']}"
        )
        configs.append((name, params))
    return configs

CONFIGS = get_random_configs(N_ITER)

# ---------------------------------------------------------
# 1) K-FOLD E SETUP
# ---------------------------------------------------------
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# Assume que já tens no notebook:
# - X, y
# - numeric_features, categorical_features
# - fill_unknown, column_string_transformer
# - fit_* e transform_* (os teus passos)
# - valid_brands, valid_models_by_brand, valid_transmissions, valid_fueltypes
# - MyTargetEncoder, MyOneHotEncoder

cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]
high_card_features = ["Brand", "model"]
low_card_features  = [c for c in categorical_features if c not in high_card_features]

def _normalize_cats(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    for col in cols_to_normalize:
        if col in df.columns:
            df[col] = fill_unknown(df[col])
            df = column_string_transformer(
                df, column=col, remove_middle_spaces=True, allow_extra_chars=""
            )
    return df

# ---------------------------------------------------------
# 1.1) FEATURE ENGINEERING (FUNÇÕES)
# ---------------------------------------------------------
def create_age_and_drop_year(df, year_col="year", base_year=2020, clip_future=True):
    df = df.copy()
    year = pd.to_numeric(df[year_col], errors="coerce")
    age = base_year - year
    if clip_future:
        age = age.clip(lower=0)
    df["age"] = age
    df = df.drop(columns=[year_col])
    return df

def add_owners_flagged(
    df,
    owners_col="previousOwners",
    new_col="owners_flagged",
    drop_original=True,
    na_as_zero=True
):
    df = df.copy()
    owners = pd.to_numeric(df[owners_col], errors="coerce")

    if na_as_zero:
        owners_filled = owners.fillna(0)
        df[new_col] = (owners_filled > 1).astype("int8")
    else:
        df[new_col] = (owners > 1).fillna(False).astype("int8")

    if drop_original and owners_col in df.columns:
        df = df.drop(columns=[owners_col])

    return df

def add_mileage_features(df, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True):
    df = df.copy()

    mileage = pd.to_numeric(df[mileage_col], errors="coerce")
    mileage = mileage.where(mileage >= 0, np.nan)

    df["log_mileage"] = np.log1p(mileage)

    age = pd.to_numeric(df[age_col], errors="coerce")
    age_safe = age.clip(lower=1)  # só para divisão
    df["miles_per_year"] = mileage / age_safe
    df["log_miles_per_year"] = np.log1p(df["miles_per_year"])

    if drop_ratio and "miles_per_year" in df.columns:
        df = df.drop(columns=["miles_per_year"])

    if drop_original and mileage_col in df.columns:
        df = df.drop(columns=[mileage_col])

    return df

def add_engine_bins(df, engine_col="engineSize", new_col="engine_bin", bins=None):
    df = df.copy()

    engine = pd.to_numeric(df[engine_col], errors="coerce")
    engine = engine.where(engine >= 0, np.nan)

    if bins is None:
        bins = [0, 1.0, 1.3, 1.6, 2.0, 2.5, 3.0, 4.0, np.inf]

    df[new_col] = pd.cut(engine, bins=bins, include_lowest=True, labels=False).astype("Int64")
    return df

# ---------------------------------------------------------
# 1.2) EVAL DE 1 CONFIG
# ---------------------------------------------------------
def eval_one_config(name: str, params: dict) -> dict:
    fold_rows = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):
        X_train = X.iloc[train_idx].copy()
        X_val   = X.iloc[val_idx].copy()
        y_train = y.iloc[train_idx].copy()
        y_val   = y.iloc[val_idx].copy()

        # TARGET (LOG)
        y_train_log = np.log1p(y_train)

        # Normalizar categóricas base
        X_train = _normalize_cats(X_train)
        X_val   = _normalize_cats(X_val)

        # Restringir às colunas base (mantém previousOwners e mileage para cleaning)
        base_cols = [c for c in (numeric_features + categorical_features) if c in X_train.columns]
        X_train = X_train[base_cols].copy()
        X_val   = X_val[base_cols].copy()

        # -----------------------------------------------------
        # A) CLEANING
        # -----------------------------------------------------
        year_state = fit_year_median(X_train, year_col="year", model_col="model")
        X_train = transform_year_with_model_median(X_train, state=year_state)
        X_val   = transform_year_with_model_median(X_val,   state=year_state)

        engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
        X_train = transform_engine_size_imputer(X_train, state=engine_state)
        X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

        X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
        X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

        mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
        X_train = transform_mpg_imputer(X_train, state=mpg_state)
        X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

        owners_state = fit_previous_owners_imputer(X_train, "previousOwners", "year", "mileage")
        X_train = transform_previous_owners_imputer(X_train, state=owners_state)
        X_val   = transform_previous_owners_imputer(X_val,   state=owners_state)

        # -----------------------------------------------------
        # B) RESOLVERS
        # -----------------------------------------------------
        brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
        X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
        X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

        model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
        X_train, _, _ = transform_invalid_models(X_train, model_state)
        X_val,   _, _ = transform_invalid_models(X_val,   model_state)

        transm_state = fit_transmission_resolver(X_train, valid_transmissions)
        X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
        X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

        fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
        X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
        X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

        # -----------------------------------------------------
        # C) FEATURE ENGINEERING
        # -----------------------------------------------------
        X_train = add_owners_flagged(X_train, owners_col="previousOwners", new_col="owners_flagged", drop_original=True)
        X_val   = add_owners_flagged(X_val,   owners_col="previousOwners", new_col="owners_flagged", drop_original=True)

        X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
        X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

        X_train = add_mileage_features(X_train, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
        X_val   = add_mileage_features(X_val,   mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)

        X_train = add_engine_bins(X_train, engine_col="engineSize", new_col="engine_bin")
        X_val   = add_engine_bins(X_val,   engine_col="engineSize", new_col="engine_bin")

        # engine_bin como low-card para OHE (robusto a NaNs)
        X_train["engine_bin"] = X_train["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        X_val["engine_bin"]   = X_val["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")

        low_card_curr = low_card_features + ["engine_bin"]

        # -----------------------------------------------------
        # D) ENCODING
        # -----------------------------------------------------
        te = MyTargetEncoder(smoothing=5)
        te.fit(X_train[high_card_features], y_train_log)
        X_train_high = te.transform(X_train[high_card_features])
        X_val_high   = te.transform(X_val[high_card_features])

        ohe = MyOneHotEncoder()
        ohe.fit(X_train[low_card_curr])
        X_train_low = ohe.transform(X_train[low_card_curr])
        X_val_low   = ohe.transform(X_val[low_card_curr])

        X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
        X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

        drop_for_numeric = set(high_card_features + low_card_curr)
        numeric_features_curr = [c for c in X_train.columns if c not in drop_for_numeric]

        X_train_final = pd.concat([X_train[numeric_features_curr], X_train_cat], axis=1)
        X_val_final   = pd.concat([X_val[numeric_features_curr],   X_val_cat],   axis=1)

        # alinhar colunas
        X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

        # -----------------------------------------------------
        # D.1) FEATURE SELECTION (SelectFromModel + RandomForest)
        #     - threshold=-np.inf
        #     - max_features = 80% das features
        # -----------------------------------------------------
        n_feats = X_train_final.shape[1]
        k = int(np.ceil(FS_KEEP_RATIO * n_feats))
        k = max(1, min(k, n_feats))

        rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
        rf_fs.fit(X_train_final, y_train_log)

        selector = SelectFromModel(
            estimator=rf_fs,
            threshold=-np.inf,
            max_features=k,
            prefit=True
        )

        support = selector.get_support()
        selected_cols = X_train_final.columns[support]

        X_train_sel = X_train_final[selected_cols]
        X_val_sel   = X_val_final[selected_cols]

        # -----------------------------------------------------
        # E) TREINO (HGB)
        # -----------------------------------------------------
        model = HistGradientBoostingRegressor(**params)
        model.fit(X_train_sel, y_train_log)

        pred_tr_log  = model.predict(X_train_sel)
        pred_val_log = model.predict(X_val_sel)

        pred_tr  = np.expm1(pred_tr_log)
        pred_val = np.expm1(pred_val_log)

        mae_tr  = mean_absolute_error(y_train, pred_tr)
        mae_val = mean_absolute_error(y_val,   pred_val)

        fold_rows.append({
            "config": name,
            "fold": fold,
            "n_features_total": n_feats,
            "n_features_selected": len(selected_cols),
            "train_mae": mae_tr,
            "val_mae": mae_val
        })

    df_folds = pd.DataFrame(fold_rows)
    mean_mae_tr  = df_folds["train_mae"].mean()
    mean_mae_val = df_folds["val_mae"].mean()
    mean_sel     = df_folds["n_features_selected"].mean()

    print(f"   >> [{name}] Train MAE: {mean_mae_tr:.2f} | Val MAE: {mean_mae_val:.2f} | Sel: {mean_sel:.0f} feats")
    logging.info(
        f"{name} | Train MAE: {mean_mae_tr:.4f} | Val MAE: {mean_mae_val:.4f} | "
        f"AvgSelected: {mean_sel:.1f} | Params: {params}"
    )

    out = {
        "config": name,
        "val_mae_mean": mean_mae_val,
        "train_mae_mean": mean_mae_tr,
        "avg_selected_features": float(mean_sel),
        **params
    }
    return out

# ---------------------------------------------------------
# 2) CORRER TODAS AS CONFIGS
# ---------------------------------------------------------
results = []
for i, (name, params) in enumerate(CONFIGS):
    if i % 5 == 0:
        print(f"\n-- doing {i+1}/{len(CONFIGS)}")

    res = eval_one_config(name, params)
    results.append(res)

results_df = pd.DataFrame(results)

# ---------------------------------------------------------
# 3) RESULTADOS FINAIS
# ---------------------------------------------------------
print("\n- 10 BEST Configurations")
results_df_sorted = results_df.sort_values("val_mae_mean", ascending=True)

cols_show = [
    "config",
    "val_mae_mean", "train_mae_mean",
    "avg_selected_features",
    "learning_rate", "max_iter", "l2_regularization", "max_leaf_nodes", "max_depth", "min_samples_leaf"
]

display(results_df_sorted[cols_show].head(10))

results_df_sorted.to_csv("random_search_fe_fs_results_65.csv", index=False)
print("stored at: random_search_fe_fs_results_65.csv")
print(" log in: random_search_fe_fs_results_65.log")
# Out:
# -- doing 1/50
#    >> [R0_iter1000_lr0.080_l22.18_leaf127] Train MAE: 1047.06 | Val MAE: 1261.41 | Sel: 17 feats
#    >> [R1_iter600_lr0.143_l21.34_leaf127] Train MAE: 1016.30 | Val MAE: 1261.05 | Sel: 17 feats
#    >> [R2_iter1000_lr0.091_l20.50_leaf127] Train MAE: 1073.02 | Val MAE: 1268.02 | Sel: 17 feats
#    >> [R3_iter1000_lr0.132_l20.71_leaf127] Train MAE: 1054.86 | Val MAE: 1272.51 | Sel: 17 feats
#    >> [R4_iter600_lr0.146_l20.50_leaf127] Train MAE: 1031.84 | Val MAE: 1265.95 | Sel: 17 feats
#
# -- doing 6/50
#    >> [R5_iter800_lr0.117_l20.92_leaf31] Train MAE: 1174.86 | Val MAE: 1301.93 | Sel: 17 feats
#    >> [R6_iter1000_lr0.150_l22.50_leaf63] Train MAE: 1088.01 | Val MAE: 1278.55 | Sel: 17 feats
#    >> [R7_iter600_lr0.098_l20.50_leaf31] Train MAE: 1216.49 | Val MAE: 1321.52 | Sel: 17 feats
#    >> [R8_iter1500_lr0.128_l21.87_leaf31] Train MAE: 1159.14 | Val MAE: 1293.35 | Sel: 17 feats
#    >> [R9_iter800_lr0.146_l21.87_leaf63] Train MAE: 1102.32 | Val MAE: 1281.97 | Sel: 17 feats
#
# -- doing 11/50
#    >> [R10_iter1500_lr0.150_l20.92_leaf127] Train MAE: 1041.05 | Val MAE: 1271.30 | Sel: 17 feats
#    >> [R11_iter800_lr0.098_l22.29_leaf63] Train MAE: 1115.37 | Val MAE: 1278.41 | Sel: 17 feats
#    >> [R12_iter600_lr0.098_l20.82_leaf127] Train MAE: 1043.27 | Val MAE: 1264.16 | Sel: 17 feats
#    >> [R13_iter1500_lr0.106_l21.87_leaf31] Train MAE: 1146.31 | Val MAE: 1291.19 | Sel: 17 feats
#    >> [R14_iter1000_lr0.150_l21.76_leaf63] Train MAE: 1092.22 | Val MAE: 1275.70 | Sel: 17 feats
#
# -- doing 16/50
#    >> [R15_iter800_lr0.109_l21.24_leaf31] Train MAE: 1212.35 | Val MAE: 1319.29 | Sel: 17 feats
#    >> [R16_iter800_lr0.139_l22.18_leaf63] Train MAE: 1081.36 | Val MAE: 1275.24 | Sel: 17 feats
#    >> [R17_iter1500_lr0.146_l21.03_leaf127] Train MAE: 1085.88 | Val MAE: 1281.81 | Sel: 17 feats
#    >> [R18_iter600_lr0.121_l22.29_leaf31] Train MAE: 1175.36 | Val MAE: 1306.04 | Sel: 17 feats
#    >> [R19_iter800_lr0.150_l20.61_leaf127] Train MAE: 1032.68 | Val MAE: 1269.21 | Sel: 17 feats
#
# -- doing 21/50
#    >> [R20_iter1500_lr0.121_l21.55_leaf127] Train MAE: 1019.07 | Val MAE: 1259.79 | Sel: 17 feats
#    >> [R21_iter1000_lr0.139_l20.92_leaf63] Train MAE: 1109.00 | Val MAE: 1283.34 | Sel: 17 feats
#    >> [R22_iter800_lr0.150_l20.71_leaf127] Train MAE: 1078.45 | Val MAE: 1285.19 | Sel: 17 feats
#    >> [R23_iter800_lr0.084_l21.34_leaf31] Train MAE: 1200.55 | Val MAE: 1312.91 | Sel: 17 feats
#    >> [R24_iter1500_lr0.095_l21.24_leaf127] Train MAE: 1060.76 | Val MAE: 1269.27 | Sel: 17 feats
#
# -- doing 26/50
#    >> [R25_iter1000_lr0.143_l20.92_leaf127] Train MAE: 1060.77 | Val MAE: 1271.12 | Sel: 17 feats
#    >> [R26_iter1000_lr0.080_l22.39_leaf127] Train MAE: 1072.22 | Val MAE: 1268.30 | Sel: 17 feats
#    >> [R27_iter800_lr0.102_l21.55_leaf31] Train MAE: 1187.44 | Val MAE: 1307.41 | Sel: 17 feats
#    >> [R28_iter1000_lr0.106_l22.39_leaf127] Train MAE: 1045.15 | Val MAE: 1264.33 | Sel: 17 feats
#    >> [R29_iter600_lr0.113_l22.08_leaf63] Train MAE: 1126.64 | Val MAE: 1286.13 | Sel: 17 feats
#
# -- doing 31/50
#    >> [R30_iter800_lr0.109_l21.87_leaf31] Train MAE: 1147.16 | Val MAE: 1291.62 | Sel: 17 feats
#    >> [R31_iter600_lr0.109_l20.50_leaf127] Train MAE: 1015.23 | Val MAE: 1259.72 | Sel: 17 feats
#    >> [R32_iter800_lr0.106_l21.55_leaf127] Train MAE: 1042.18 | Val MAE: 1262.70 | Sel: 17 feats
#    >> [R33_iter1000_lr0.106_l22.08_leaf31] Train MAE: 1174.37 | Val MAE: 1301.16 | Sel: 17 feats
#    >> [R34_iter600_lr0.132_l21.76_leaf31] Train MAE: 1177.06 | Val MAE: 1304.23 | Sel: 17 feats
#
# -- doing 36/50
#    >> [R35_iter800_lr0.121_l21.55_leaf127] Train MAE: 1060.08 | Val MAE: 1267.25 | Sel: 17 feats
#    >> [R36_iter1500_lr0.106_l20.92_leaf127] Train MAE: 1033.79 | Val MAE: 1260.76 | Sel: 17 feats
#    >> [R37_iter800_lr0.132_l21.45_leaf127] Train MAE: 1055.20 | Val MAE: 1266.16 | Sel: 17 feats
#    >> [R38_iter1500_lr0.113_l20.71_leaf31] Train MAE: 1188.35 | Val MAE: 1309.20 | Sel: 17 feats
#    >> [R39_iter800_lr0.132_l20.61_leaf63] Train MAE: 1108.42 | Val MAE: 1287.90 | Sel: 17 feats
#
# -- doing 41/50
#    >> [R40_iter1000_lr0.128_l21.03_leaf31] Train MAE: 1199.28 | Val MAE: 1314.00 | Sel: 17 feats
#    >> [R41_iter800_lr0.095_l21.45_leaf31] Train MAE: 1197.83 | Val MAE: 1312.45 | Sel: 17 feats
#    >> [R42_iter1500_lr0.139_l22.39_leaf127] Train MAE: 1054.21 | Val MAE: 1271.61 | Sel: 17 feats
#    >> [R43_iter800_lr0.084_l20.92_leaf63] Train MAE: 1097.36 | Val MAE: 1275.80 | Sel: 17 feats
#    >> [R44_iter1000_lr0.113_l21.13_leaf127] Train MAE: 1019.55 | Val MAE: 1258.53 | Sel: 17 feats
#
# -- doing 46/50
#    >> [R45_iter600_lr0.080_l22.39_leaf127] Train MAE: 1055.54 | Val MAE: 1263.38 | Sel: 17 feats
#    >> [R46_iter800_lr0.139_l21.97_leaf127] Train MAE: 1018.70 | Val MAE: 1261.13 | Sel: 17 feats
#    >> [R47_iter800_lr0.113_l21.76_leaf127] Train MAE: 1103.72 | Val MAE: 1284.45 | Sel: 17 feats
#    >> [R48_iter800_lr0.124_l21.66_leaf127] Train MAE: 1067.55 | Val MAE: 1275.60 | Sel: 17 feats
#    >> [R49_iter1000_lr0.087_l20.82_leaf127] Train MAE: 1048.88 | Val MAE: 1263.53 | Sel: 17 feats
#
# - 10 BEST Configurations
#                                  config  val_mae_mean  train_mae_mean  \
# 44  R44_iter1000_lr0.113_l21.13_leaf127   1258.527405     1019.545063
# 31   R31_iter600_lr0.109_l20.50_leaf127   1259.715016     1015.226144
# 20  R20_iter1500_lr0.121_l21.55_leaf127   1259.786309     1019.074451
# 36  R36_iter1500_lr0.106_l20.92_leaf127   1260.764864     1033.791004
# 1     R1_iter600_lr0.143_l21.34_leaf127   1261.049514     1016.298928
# 46   R46_iter800_lr0.139_l21.97_leaf127   1261.125917     1018.703741
# 0    R0_iter1000_lr0.080_l22.18_leaf127   1261.414278     1047.062383
# 32   R32_iter800_lr0.106_l21.55_leaf127   1262.695340     1042.179948
# 45   R45_iter600_lr0.080_l22.39_leaf127   1263.377982     1055.538162
# 49  R49_iter1000_lr0.087_l20.82_leaf127   1263.534816     1048.879433
#
#     avg_selected_features  learning_rate  max_iter  l2_regularization  \
# 44                   17.0       0.113158      1000           1.131579
# 31                   17.0       0.109474       600           0.500000
# 20                   17.0       0.120526      1500           1.552632
# 36                   17.0       0.105789      1500           0.921053
# 1                    17.0       0.142632       600           1.342105
# 46                   17.0       0.138947       800           1.973684
# 0                    17.0       0.080000      1000           2.184211
# 32                   17.0       0.105789       800           1.552632
# 45                   17.0       0.080000       600           2.394737
# 49                   17.0       0.087368      1000           0.815789
#
#     max_leaf_nodes  max_depth  min_samples_leaf
# 44             127       25.0                20
# 31             127       15.0                20
# 20             127       25.0                30
# 36             127       25.0                30
# 1              127       25.0                20
# 46             127       20.0                20
# 0              127       25.0                30
# 32             127       20.0                30
# 45             127        NaN                40
# 49             127        NaN                40
# stored at: random_search_fe_fs_results_65.csv
#  log in: random_search_fe_fs_results_65.log

# %% [markdown]
# ##### __60%__

# %%
import numpy as np
import pandas as pd
import random
import logging

from IPython.display import display
from sklearn.model_selection import KFold
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import mean_absolute_error

# ---------------------------------------------------------
# 0) CONFIGS GERAIS
# ---------------------------------------------------------
N_SPLITS = 8
N_ITER = 15
RANDOM_STATE = 42

# Percentagem de features a manter no SelectFromModel
FS_KEEP_RATIO = 0.60

# RandomForest para Feature Selection (podes ajustar)
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

# ---------------------------------------------------------
# 0.1) CONFIGURAÇÃO DO LOGGING
# ---------------------------------------------------------

logging.basicConfig(
    filename="random_search_fe_fs_results_60.log",
    level=logging.INFO,
    format="%(asctime)s - %(message)s",
    filemode="w",
    force=True
)
logging.info("- 10 iterations")

# ---------------------------------------------------------
# 0.2) CONFIGURAÇÃO DO RANDOM SEARCH
# ---------------------------------------------------------
param_distributions = {
    "min_samples_leaf": [20, 30, 40],
    "max_leaf_nodes": [31, 63, 127],
    "max_iter": [600, 800, 1000, 1500],
    "max_depth": [None, 10, 15, 20, 25],
    "learning_rate": np.linspace(0.08, 0.15, 20),
    "l2_regularization": np.linspace(0.5, 2.5, 20),
    "max_bins": [255],
    "random_state": [RANDOM_STATE],
}

def get_random_configs(n_iter: int):
    configs = []
    keys = list(param_distributions.keys())

    for i in range(n_iter):
        params = {}
        for key in keys:
            params[key] = random.choice(list(param_distributions[key]))

        name = (
            f"R{i}_iter{params['max_iter']}"
            f"_lr{float(params['learning_rate']):.3f}"
            f"_l2{float(params['l2_regularization']):.2f}"
            f"_leaf{params['max_leaf_nodes']}"
        )
        configs.append((name, params))
    return configs

CONFIGS = get_random_configs(N_ITER)

# ---------------------------------------------------------
# 1) K-FOLD E SETUP
# ---------------------------------------------------------
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# Assume que já tens no notebook:
# - X, y
# - numeric_features, categorical_features
# - fill_unknown, column_string_transformer
# - fit_* e transform_* (os teus passos)
# - valid_brands, valid_models_by_brand, valid_transmissions, valid_fueltypes
# - MyTargetEncoder, MyOneHotEncoder

cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]
high_card_features = ["Brand", "model"]
low_card_features  = [c for c in categorical_features if c not in high_card_features]

def _normalize_cats(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    for col in cols_to_normalize:
        if col in df.columns:
            df[col] = fill_unknown(df[col])
            df = column_string_transformer(
                df, column=col, remove_middle_spaces=True, allow_extra_chars=""
            )
    return df

# ---------------------------------------------------------
# 1.1) FEATURE ENGINEERING (FUNÇÕES)
# ---------------------------------------------------------
def create_age_and_drop_year(df, year_col="year", base_year=2020, clip_future=True):
    df = df.copy()
    year = pd.to_numeric(df[year_col], errors="coerce")
    age = base_year - year
    if clip_future:
        age = age.clip(lower=0)
    df["age"] = age
    df = df.drop(columns=[year_col])
    return df

def add_owners_flagged(
    df,
    owners_col="previousOwners",
    new_col="owners_flagged",
    drop_original=True,
    na_as_zero=True
):
    df = df.copy()
    owners = pd.to_numeric(df[owners_col], errors="coerce")

    if na_as_zero:
        owners_filled = owners.fillna(0)
        df[new_col] = (owners_filled > 1).astype("int8")
    else:
        df[new_col] = (owners > 1).fillna(False).astype("int8")

    if drop_original and owners_col in df.columns:
        df = df.drop(columns=[owners_col])

    return df

def add_mileage_features(df, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True):
    df = df.copy()

    mileage = pd.to_numeric(df[mileage_col], errors="coerce")
    mileage = mileage.where(mileage >= 0, np.nan)

    df["log_mileage"] = np.log1p(mileage)

    age = pd.to_numeric(df[age_col], errors="coerce")
    age_safe = age.clip(lower=1)  # só para divisão
    df["miles_per_year"] = mileage / age_safe
    df["log_miles_per_year"] = np.log1p(df["miles_per_year"])

    if drop_ratio and "miles_per_year" in df.columns:
        df = df.drop(columns=["miles_per_year"])

    if drop_original and mileage_col in df.columns:
        df = df.drop(columns=[mileage_col])

    return df

def add_engine_bins(df, engine_col="engineSize", new_col="engine_bin", bins=None):
    df = df.copy()

    engine = pd.to_numeric(df[engine_col], errors="coerce")
    engine = engine.where(engine >= 0, np.nan)

    if bins is None:
        bins = [0, 1.0, 1.3, 1.6, 2.0, 2.5, 3.0, 4.0, np.inf]

    df[new_col] = pd.cut(engine, bins=bins, include_lowest=True, labels=False).astype("Int64")
    return df

# ---------------------------------------------------------
# 1.2) EVAL DE 1 CONFIG
# ---------------------------------------------------------
def eval_one_config(name: str, params: dict) -> dict:
    fold_rows = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):
        X_train = X.iloc[train_idx].copy()
        X_val   = X.iloc[val_idx].copy()
        y_train = y.iloc[train_idx].copy()
        y_val   = y.iloc[val_idx].copy()

        # TARGET (LOG)
        y_train_log = np.log1p(y_train)

        # Normalizar categóricas base
        X_train = _normalize_cats(X_train)
        X_val   = _normalize_cats(X_val)

        # Restringir às colunas base (mantém previousOwners e mileage para cleaning)
        base_cols = [c for c in (numeric_features + categorical_features) if c in X_train.columns]
        X_train = X_train[base_cols].copy()
        X_val   = X_val[base_cols].copy()

        # -----------------------------------------------------
        # A) CLEANING
        # -----------------------------------------------------
        year_state = fit_year_median(X_train, year_col="year", model_col="model")
        X_train = transform_year_with_model_median(X_train, state=year_state)
        X_val   = transform_year_with_model_median(X_val,   state=year_state)

        engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
        X_train = transform_engine_size_imputer(X_train, state=engine_state)
        X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

        X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
        X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

        mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
        X_train = transform_mpg_imputer(X_train, state=mpg_state)
        X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

        owners_state = fit_previous_owners_imputer(X_train, "previousOwners", "year", "mileage")
        X_train = transform_previous_owners_imputer(X_train, state=owners_state)
        X_val   = transform_previous_owners_imputer(X_val,   state=owners_state)

        # -----------------------------------------------------
        # B) RESOLVERS
        # -----------------------------------------------------
        brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
        X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
        X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

        model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
        X_train, _, _ = transform_invalid_models(X_train, model_state)
        X_val,   _, _ = transform_invalid_models(X_val,   model_state)

        transm_state = fit_transmission_resolver(X_train, valid_transmissions)
        X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
        X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

        fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
        X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
        X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

        # -----------------------------------------------------
        # C) FEATURE ENGINEERING
        # -----------------------------------------------------
        X_train = add_owners_flagged(X_train, owners_col="previousOwners", new_col="owners_flagged", drop_original=True)
        X_val   = add_owners_flagged(X_val,   owners_col="previousOwners", new_col="owners_flagged", drop_original=True)

        X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
        X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

        X_train = add_mileage_features(X_train, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
        X_val   = add_mileage_features(X_val,   mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)

        X_train = add_engine_bins(X_train, engine_col="engineSize", new_col="engine_bin")
        X_val   = add_engine_bins(X_val,   engine_col="engineSize", new_col="engine_bin")

        # engine_bin como low-card para OHE (robusto a NaNs)
        X_train["engine_bin"] = X_train["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        X_val["engine_bin"]   = X_val["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")

        low_card_curr = low_card_features + ["engine_bin"]

        # -----------------------------------------------------
        # D) ENCODING
        # -----------------------------------------------------
        te = MyTargetEncoder(smoothing=5)
        te.fit(X_train[high_card_features], y_train_log)
        X_train_high = te.transform(X_train[high_card_features])
        X_val_high   = te.transform(X_val[high_card_features])

        ohe = MyOneHotEncoder()
        ohe.fit(X_train[low_card_curr])
        X_train_low = ohe.transform(X_train[low_card_curr])
        X_val_low   = ohe.transform(X_val[low_card_curr])

        X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
        X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

        drop_for_numeric = set(high_card_features + low_card_curr)
        numeric_features_curr = [c for c in X_train.columns if c not in drop_for_numeric]

        X_train_final = pd.concat([X_train[numeric_features_curr], X_train_cat], axis=1)
        X_val_final   = pd.concat([X_val[numeric_features_curr],   X_val_cat],   axis=1)

        # alinhar colunas
        X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

        # -----------------------------------------------------
        # D.1) FEATURE SELECTION (SelectFromModel + RandomForest)
        #     - threshold=-np.inf
        #     - max_features = 80% das features
        # -----------------------------------------------------
        n_feats = X_train_final.shape[1]
        k = int(np.ceil(FS_KEEP_RATIO * n_feats))
        k = max(1, min(k, n_feats))

        rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
        rf_fs.fit(X_train_final, y_train_log)

        selector = SelectFromModel(
            estimator=rf_fs,
            threshold=-np.inf,
            max_features=k,
            prefit=True
        )

        support = selector.get_support()
        selected_cols = X_train_final.columns[support]

        X_train_sel = X_train_final[selected_cols]
        X_val_sel   = X_val_final[selected_cols]

        # -----------------------------------------------------
        # E) TREINO (HGB)
        # -----------------------------------------------------
        model = HistGradientBoostingRegressor(**params)
        model.fit(X_train_sel, y_train_log)

        pred_tr_log  = model.predict(X_train_sel)
        pred_val_log = model.predict(X_val_sel)

        pred_tr  = np.expm1(pred_tr_log)
        pred_val = np.expm1(pred_val_log)

        mae_tr  = mean_absolute_error(y_train, pred_tr)
        mae_val = mean_absolute_error(y_val,   pred_val)

        fold_rows.append({
            "config": name,
            "fold": fold,
            "n_features_total": n_feats,
            "n_features_selected": len(selected_cols),
            "train_mae": mae_tr,
            "val_mae": mae_val
        })

    df_folds = pd.DataFrame(fold_rows)
    mean_mae_tr  = df_folds["train_mae"].mean()
    mean_mae_val = df_folds["val_mae"].mean()
    mean_sel     = df_folds["n_features_selected"].mean()

    print(f"   >> [{name}] Train MAE: {mean_mae_tr:.2f} | Val MAE: {mean_mae_val:.2f} | Sel: {mean_sel:.0f} feats")
    logging.info(
        f"{name} | Train MAE: {mean_mae_tr:.4f} | Val MAE: {mean_mae_val:.4f} | "
        f"AvgSelected: {mean_sel:.1f} | Params: {params}"
    )

    out = {
        "config": name,
        "val_mae_mean": mean_mae_val,
        "train_mae_mean": mean_mae_tr,
        "avg_selected_features": float(mean_sel),
        **params
    }
    return out

# ---------------------------------------------------------
# 2) CORRER TODAS AS CONFIGS
# ---------------------------------------------------------
results = []
for i, (name, params) in enumerate(CONFIGS):
    if i % 5 == 0:
        print(f"\n-- doing {i+1}/{len(CONFIGS)}")

    res = eval_one_config(name, params)
    results.append(res)

results_df = pd.DataFrame(results)

# ---------------------------------------------------------
# 3) RESULTADOS FINAIS
# ---------------------------------------------------------
print("\n- 10 BEST Configurations")
results_df_sorted = results_df.sort_values("val_mae_mean", ascending=True)

cols_show = [
    "config",
    "val_mae_mean", "train_mae_mean",
    "avg_selected_features",
    "learning_rate", "max_iter", "l2_regularization", "max_leaf_nodes", "max_depth", "min_samples_leaf"
]

display(results_df_sorted[cols_show].head(10))

results_df_sorted.to_csv("random_search_fe_fs_results_60.csv", index=False)
print("stored at: random_search_fe_fs_results_60.csv")
print(" log in: random_search_fe_fs_results_60.log")
# Out:
# -- doing 1/15
#    >> [R0_iter1500_lr0.121_l21.45_leaf63] Train MAE: 1106.51 | Val MAE: 1283.89 | Sel: 15 feats
#    >> [R1_iter1500_lr0.135_l21.76_leaf63] Train MAE: 1117.38 | Val MAE: 1285.01 | Sel: 15 feats
#    >> [R2_iter600_lr0.102_l22.08_leaf63] Train MAE: 1112.34 | Val MAE: 1280.45 | Sel: 15 feats
#    >> [R3_iter1500_lr0.102_l21.87_leaf63] Train MAE: 1153.44 | Val MAE: 1298.55 | Sel: 15 feats
#    >> [R4_iter1000_lr0.128_l20.61_leaf31] Train MAE: 1141.06 | Val MAE: 1292.35 | Sel: 15 feats
#
# -- doing 6/15
#    >> [R5_iter800_lr0.091_l22.08_leaf127] Train MAE: 1088.28 | Val MAE: 1275.84 | Sel: 15 feats
#    >> [R6_iter600_lr0.143_l21.66_leaf31] Train MAE: 1194.94 | Val MAE: 1313.93 | Sel: 15 feats
#    >> [R7_iter800_lr0.106_l22.18_leaf63] Train MAE: 1111.96 | Val MAE: 1285.82 | Sel: 15 feats
#    >> [R8_iter800_lr0.143_l22.29_leaf31] Train MAE: 1185.84 | Val MAE: 1310.23 | Sel: 15 feats
#    >> [R9_iter1500_lr0.135_l22.18_leaf31] Train MAE: 1149.84 | Val MAE: 1295.84 | Sel: 15 feats
#
# -- doing 11/15
#    >> [R10_iter600_lr0.135_l22.18_leaf31] Train MAE: 1169.30 | Val MAE: 1300.55 | Sel: 15 feats
#    >> [R11_iter1000_lr0.095_l20.82_leaf63] Train MAE: 1099.22 | Val MAE: 1278.36 | Sel: 15 feats
#    >> [R12_iter1000_lr0.113_l22.18_leaf31] Train MAE: 1175.64 | Val MAE: 1305.27 | Sel: 15 feats
#    >> [R13_iter800_lr0.150_l22.50_leaf31] Train MAE: 1146.29 | Val MAE: 1296.31 | Sel: 15 feats
#    >> [R14_iter800_lr0.102_l20.71_leaf127] Train MAE: 1121.27 | Val MAE: 1289.15 | Sel: 15 feats
#
# - 10 BEST Configurations
#                                 config  val_mae_mean  train_mae_mean  \
# 5    R5_iter800_lr0.091_l22.08_leaf127   1275.840313     1088.276340
# 11  R11_iter1000_lr0.095_l20.82_leaf63   1278.359416     1099.218006
# 2     R2_iter600_lr0.102_l22.08_leaf63   1280.450074     1112.344579
# 0    R0_iter1500_lr0.121_l21.45_leaf63   1283.885507     1106.507437
# 1    R1_iter1500_lr0.135_l21.76_leaf63   1285.009472     1117.376320
# 7     R7_iter800_lr0.106_l22.18_leaf63   1285.822965     1111.955653
# 14  R14_iter800_lr0.102_l20.71_leaf127   1289.153572     1121.269383
# 4    R4_iter1000_lr0.128_l20.61_leaf31   1292.348023     1141.062070
# 9    R9_iter1500_lr0.135_l22.18_leaf31   1295.838672     1149.835597
# 13   R13_iter800_lr0.150_l22.50_leaf31   1296.312575     1146.289248
#
#     avg_selected_features  learning_rate  max_iter  l2_regularization  \
# 5                    15.0       0.091053       800           2.078947
# 11                   15.0       0.094737      1000           0.815789
# 2                    15.0       0.102105       600           2.078947
# 0                    15.0       0.120526      1500           1.447368
# 1                    15.0       0.135263      1500           1.763158
# 7                    15.0       0.105789       800           2.184211
# 14                   15.0       0.102105       800           0.710526
# 4                    15.0       0.127895      1000           0.605263
# 9                    15.0       0.135263      1500           2.184211
# 13                   15.0       0.150000       800           2.500000
#
#     max_leaf_nodes  max_depth  min_samples_leaf
# 5              127       15.0                40
# 11              63       20.0                20
# 2               63       20.0                40
# 0               63       10.0                20
# 1               63       25.0                40
# 7               63       25.0                40
# 14             127       10.0                30
# 4               31       10.0                20
# 9               31       25.0                20
# 13              31       15.0                20
# stored at: random_search_fe_fs_results_60.csv
#  log in: random_search_fe_fs_results_60.log

# %% [markdown]
# ## 5. Final Configuration <a id="finalconfig"></a>

# %% [markdown]
# ### 5.1. CV

# %%
import os
import numpy as np
import pandas as pd
import logging

from IPython.display import display
from sklearn.model_selection import KFold
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import mean_absolute_error

# ---------------------------------------------------------
# 0) FIXED CONFIG (YOUR BEST PARAMS)
# ---------------------------------------------------------
final_params = {
    "min_samples_leaf": 20,
    "max_leaf_nodes": 127,
    "max_iter": 600,
    "max_depth": 25,
    "learning_rate": float(np.float64(0.09105263157894737)),
    "l2_regularization": float(np.float64(1.4473684210526314)),
    "max_bins": 255,
    "random_state": 42,
}

# ---------------------------------------------------------
# 1) GLOBAL SETTINGS
# ---------------------------------------------------------
N_SPLITS = 8
RANDOM_STATE = 42

FS_KEEP_RATIO = 0.65  # keep top 90% features by RF importance
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

# ---------------------------------------------------------
# 2) OUTPUTS + LOGGING (JUPYTER-SAFE)
# ---------------------------------------------------------
OUT_DIR = os.path.abspath("./outputs")
os.makedirs(OUT_DIR, exist_ok=True)

LOG_PATH = os.path.join(OUT_DIR, "config_cv.log")
logging.basicConfig(
    filename=LOG_PATH,
    level=logging.INFO,
    format="%(asctime)s - %(message)s",
    filemode="w",
    force=True
)
logging.info("cv started")
print(f"- output dir: {OUT_DIR}")
print(f"- log file: {LOG_PATH}")

# ---------------------------------------------------------
# 3) CV SETUP
# ---------------------------------------------------------
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)



cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]
high_card_features = ["Brand", "model"]
low_card_features = [c for c in categorical_features if c not in high_card_features]

def _normalize_cats(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    for col in cols_to_normalize:
        if col in df.columns:
            df[col] = fill_unknown(df[col])
            df = column_string_transformer(df, column=col, remove_middle_spaces=True, allow_extra_chars="")
    return df


# ---------------------------------------------------------
# 5) CV EVALUATION FOR ONE FIXED CONFIG
# ---------------------------------------------------------
def run_cv_for_params(name: str, params: dict):
    fold_rows = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):
        X_train = X.iloc[train_idx].copy()
        X_val   = X.iloc[val_idx].copy()
        y_train = y.iloc[train_idx].copy()
        y_val   = y.iloc[val_idx].copy()

        y_train_log = np.log1p(y_train)

        X_train = _normalize_cats(X_train)
        X_val   = _normalize_cats(X_val)

        base_cols = [c for c in (numeric_features + categorical_features) if c in X_train.columns]
        X_train = X_train[base_cols].copy()
        X_val   = X_val[base_cols].copy()

        # A) cleaning (fit on train, apply on val)
        year_state = fit_year_median(X_train, year_col="year", model_col="model")
        X_train = transform_year_with_model_median(X_train, state=year_state)
        X_val   = transform_year_with_model_median(X_val,   state=year_state)

        engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
        X_train = transform_engine_size_imputer(X_train, state=engine_state)
        X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

        X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
        X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

        mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
        X_train = transform_mpg_imputer(X_train, state=mpg_state)
        X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

        owners_state = fit_previous_owners_imputer(X_train, "previousOwners", "year", "mileage")
        X_train = transform_previous_owners_imputer(X_train, state=owners_state)
        X_val   = transform_previous_owners_imputer(X_val,   state=owners_state)

        # B) resolvers
        brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
        X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
        X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

        model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
        X_train, _, _ = transform_invalid_models(X_train, model_state)
        X_val,   _, _ = transform_invalid_models(X_val,   model_state)

        transm_state = fit_transmission_resolver(X_train, valid_transmissions)
        X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
        X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

        fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
        X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
        X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

        # C) feature engineering
        X_train = add_owners_flagged(X_train, owners_col="previousOwners", new_col="owners_flagged", drop_original=True)
        X_val   = add_owners_flagged(X_val,   owners_col="previousOwners", new_col="owners_flagged", drop_original=True)

        X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
        X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

        X_train = add_mileage_features(X_train, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
        X_val   = add_mileage_features(X_val,   mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)

        X_train = add_engine_bins(X_train, engine_col="engineSize", new_col="engine_bin")
        X_val   = add_engine_bins(X_val,   engine_col="engineSize", new_col="engine_bin")

        X_train["engine_bin"] = X_train["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        X_val["engine_bin"]   = X_val["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")

        low_card_curr = low_card_features + ["engine_bin"]

        # D) encoding
        te = MyTargetEncoder(smoothing=5)
        te.fit(X_train[high_card_features], y_train_log)
        X_train_high = te.transform(X_train[high_card_features])
        X_val_high   = te.transform(X_val[high_card_features])

        ohe = MyOneHotEncoder()
        ohe.fit(X_train[low_card_curr])
        X_train_low = ohe.transform(X_train[low_card_curr])
        X_val_low   = ohe.transform(X_val[low_card_curr])

        X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
        X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

        drop_for_numeric = set(high_card_features + low_card_curr)
        numeric_features_curr = [c for c in X_train.columns if c not in drop_for_numeric]

        X_train_final = pd.concat([X_train[numeric_features_curr], X_train_cat], axis=1)
        X_val_final   = pd.concat([X_val[numeric_features_curr],   X_val_cat],   axis=1)

        X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

        # D.1) feature selection (RF -> SelectFromModel)
        n_feats = X_train_final.shape[1]
        k = int(np.ceil(FS_KEEP_RATIO * n_feats))
        k = max(1, min(k, n_feats))

        rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
        rf_fs.fit(X_train_final, y_train_log)

        selector = SelectFromModel(
            estimator=rf_fs,
            threshold=-np.inf,
            max_features=k,
            prefit=True
        )

        selected_cols = X_train_final.columns[selector.get_support()]
        X_train_sel = X_train_final[selected_cols]
        X_val_sel   = X_val_final[selected_cols]

        # E) train HGB
        model = HistGradientBoostingRegressor(**params)
        model.fit(X_train_sel, y_train_log)

        pred_tr_log  = model.predict(X_train_sel)
        pred_val_log = model.predict(X_val_sel)

        pred_tr  = np.expm1(pred_tr_log)
        pred_val = np.expm1(pred_val_log)

        mae_tr  = mean_absolute_error(y_train, pred_tr)
        mae_val = mean_absolute_error(y_val,   pred_val)

        fold_rows.append({
            "config": name,
            "fold": fold,
            "n_features_total": int(n_feats),
            "n_features_selected": int(len(selected_cols)),
            "train_mae": float(mae_tr),
            "val_mae": float(mae_val),
        })

        print(f"- fold {fold} | train_mae={mae_tr:.2f} | val_mae={mae_val:.2f} | selected={len(selected_cols)}")
        logging.info(f"fold {fold} | train_mae={mae_tr:.6f} | val_mae={mae_val:.6f} | selected={len(selected_cols)}")

    folds_df = pd.DataFrame(fold_rows)

    summary = {
        "config": name,
        "train_mae_mean": float(folds_df["train_mae"].mean()),
        "train_mae_std":  float(folds_df["train_mae"].std(ddof=1)),
        "val_mae_mean":   float(folds_df["val_mae"].mean()),
        "val_mae_std":    float(folds_df["val_mae"].std(ddof=1)),
        "selected_mean":  float(folds_df["n_features_selected"].mean()),
        "selected_std":   float(folds_df["n_features_selected"].std(ddof=1)),
        **params
    }

    print(f"- done | train_mae_mean={summary['train_mae_mean']:.2f} | val_mae_mean={summary['val_mae_mean']:.2f}")
    logging.info(f"done | train_mae_mean={summary['train_mae_mean']:.6f} | val_mae_mean={summary['val_mae_mean']:.6f}")

    return folds_df, pd.DataFrame([summary])

# ---------------------------------------------------------
# 6) RUN
# ---------------------------------------------------------
print("- starting CV for final_params")
logging.info(f"config params: {final_params}")

folds_df, summary_df = run_cv_for_params("final_config", final_params)

display(folds_df)
display(summary_df)

FOLDS_CSV = os.path.join(OUT_DIR, "final_config_cv_folds.csv")
SUMMARY_CSV = os.path.join(OUT_DIR, "final_config_cv_summary.csv")

folds_df.to_csv(FOLDS_CSV, index=False)
summary_df.to_csv(SUMMARY_CSV, index=False)

print(f"- saved folds: {FOLDS_CSV}")
print(f"- saved summary: {SUMMARY_CSV}")
print(f"- log file: {LOG_PATH}")

logging.info(f"saved folds: {FOLDS_CSV}")
logging.info(f"saved summary: {SUMMARY_CSV}")
logging.info("cv finished")
logging.shutdown()
# Out:
# - output dir: /Users/franciscafernandes/Desktop/MachineLearning/projeto/Machine-Learning-G51/notebooks/model_assessment_optimazation/outputs
# - log file: /Users/franciscafernandes/Desktop/MachineLearning/projeto/Machine-Learning-G51/notebooks/model_assessment_optimazation/outputs/config_cv.log
# - starting CV for final_params
# - fold 1 | train_mae=1073.43 | val_mae=1260.50 | selected=17
# - fold 2 | train_mae=1072.35 | val_mae=1285.75 | selected=17
# - fold 3 | train_mae=1064.59 | val_mae=1283.89 | selected=17
# - fold 4 | train_mae=1024.11 | val_mae=1290.84 | selected=17
# - fold 5 | train_mae=983.87 | val_mae=1249.15 | selected=17
# - fold 6 | train_mae=987.28 | val_mae=1247.20 | selected=17
# - fold 7 | train_mae=1020.06 | val_mae=1235.25 | selected=17
# - fold 8 | train_mae=1034.28 | val_mae=1228.62 | selected=17
# - done | train_mae_mean=1032.50 | val_mae_mean=1260.15
#          config  fold  n_features_total  n_features_selected    train_mae  \
# 0  final_config     1                25                   17  1073.433847
# 1  final_config     2                25                   17  1072.354716
# 2  final_config     3                25                   17  1064.585480
# 3  final_config     4                25                   17  1024.112416
# 4  final_config     5                25                   17   983.873171
# 5  final_config     6                25                   17   987.278480
# 6  final_config     7                25                   17  1020.059804
# 7  final_config     8                25                   17  1034.282904
#
#        val_mae
# 0  1260.504796
# 1  1285.747898
# 2  1283.886655
# 3  1290.843950
# 4  1249.154135
# 5  1247.196078
# 6  1235.252404
# 7  1228.620799
#          config  train_mae_mean  train_mae_std  val_mae_mean  val_mae_std  \
# 0  final_config     1032.497602      35.719741    1260.15084    24.093922
#
#    selected_mean  selected_std  min_samples_leaf  max_leaf_nodes  max_iter  \
# 0           17.0           0.0                20             127       600
#
#    max_depth  learning_rate  l2_regularization  max_bins  random_state
# 0         25       0.091053           1.447368       255            42
# - saved folds: /Users/franciscafernandes/Desktop/MachineLearning/projeto/Machine-Learning-G51/notebooks/model_assessment_optimazation/outputs/final_config_cv_folds.csv
# - saved summary: /Users/franciscafernandes/Desktop/MachineLearning/projeto/Machine-Learning-G51/notebooks/model_assessment_optimazation/outputs/final_config_cv_summary.csv
# - log file: /Users/franciscafernandes/Desktop/MachineLearning/projeto/Machine-Learning-G51/notebooks/model_assessment_optimazation/outputs/config_cv.log

# %% [markdown]
# ### 5.2. Final Model and Kaggle Submission

# %%
# ==============================================================================
# 0) SETTINGS
# ==============================================================================
RANDOM_STATE = 42

final_params = {
    "min_samples_leaf": 20,
    "max_leaf_nodes": 127,
    "max_iter": 600,
    "max_depth": 25,
    "learning_rate": float(np.float64(0.09105263157894737)),
    "l2_regularization": float(np.float64(1.4473684210526314)),
    "max_bins": 255,
    "random_state": 42,
}

FS_KEEP_RATIO = 0.65
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

print(f"- using params: {final_params}")
print(f"- FS_KEEP_RATIO: {FS_KEEP_RATIO}")

# ==============================================================================
# 1) LOAD TEST + IDS
# ==============================================================================
try:
    test_df_raw = pd.read_csv("test.csv")
except:
    test_df_raw = pd.read_csv("../../project_data/test.csv")

ID_CANDIDATES = ["id", "carID", "carId", "car_id"]
ID_COL = next((c for c in ID_CANDIDATES if c in test_df_raw.columns), None)

if ID_COL is not None:
    test_ids = test_df_raw[ID_COL].copy()
    test_df = test_df_raw.drop(columns=[ID_COL]).copy()
else:
    test_ids = test_df_raw.index.copy()
    test_df = test_df_raw.copy()

# ==============================================================================
# 2) START DATA
# ==============================================================================
X_full = X.copy()
y_full = y.copy()
y_full_log = np.log1p(y_full)

cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]
high_card_features = ["Brand", "model"]
low_card_features = [c for c in categorical_features if c not in high_card_features]

# ==============================================================================
# 4) STRING NORMALIZATION (TRAIN + TEST)
# ==============================================================================
for col in cols_to_normalize:
    if col in X_full.columns:
        X_full[col] = fill_unknown(X_full[col])
        X_full = column_string_transformer(X_full, column=col, remove_middle_spaces=True, allow_extra_chars="")
    if col in test_df.columns:
        test_df[col] = fill_unknown(test_df[col])
        test_df = column_string_transformer(test_df, column=col, remove_middle_spaces=True, allow_extra_chars="")

# Restrict to expected columns (train schema)
expected_cols = [c for c in (numeric_features + categorical_features) if c in X_full.columns]
X_full = X_full[expected_cols].copy()
X_test = test_df.reindex(columns=expected_cols, fill_value=np.nan).copy()

# ==============================================================================
# 5) FIT + TRANSFORM ON FULL TRAIN
# ==============================================================================
print("- fitting transforms on full train")

year_state = fit_year_median(X_full, year_col="year", model_col="model")
X_full = transform_year_with_model_median(X_full, state=year_state)

engine_state = fit_engine_size_imputer(X_full, engine_col="engineSize")
X_full = transform_engine_size_imputer(X_full, state=engine_state)

X_full = transform_tax_custom_rules(X_full, "tax", "year", "fuelType", "engineSize")

mpg_state = fit_mpg_imputer(X_full, mpg_col="mpg", do_abs=True)
X_full = transform_mpg_imputer(X_full, state=mpg_state)

# IMPORTANT: owners imputer must happen BEFORE dropping previousOwners
owners_state = fit_previous_owners_imputer(X_full, "previousOwners", "year", "mileage")
X_full = transform_previous_owners_imputer(X_full, state=owners_state)

brand_state = fit_ambiguous_brand_resolver(X_full, valid_brands)
X_full, _, _ = transform_ambiguous_brands(X_full, brand_state)

model_state = fit_invalid_model_resolver(X_full, valid_models_by_brand)
X_full, _, _ = transform_invalid_models(X_full, model_state)

transm_state = fit_transmission_resolver(X_full, valid_transmissions)
X_full, _, _ = transform_transmission_resolver(X_full, transm_state)

fuel_state = fit_fueltype_resolver(X_full, valid_fueltypes)
X_full, _, _ = transform_fueltype_resolver(X_full, fuel_state)

# ==============================================================================
# 6) FEATURE ENGINEERING (FULL TRAIN)
# ==============================================================================
print("- creating engineered features on full train")

X_full = add_owners_flagged(X_full, owners_col="previousOwners", new_col="owners_flagged", drop_original=True)
X_full = create_age_and_drop_year(X_full, year_col="year", base_year=2020)
X_full = add_mileage_features(X_full, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
X_full = add_engine_bins(X_full, engine_col="engineSize", new_col="engine_bin")

# engine_bin as low-card categorical
X_full["engine_bin"] = X_full["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
low_card_curr = low_card_features + ["engine_bin"]

# ==============================================================================
# 7) ENCODING (FIT ON FULL TRAIN)
# ==============================================================================
print("- fitting encoders on full train")

te = MyTargetEncoder(smoothing=5)
te.fit(X_full[high_card_features], y_full_log)
X_full_high = te.transform(X_full[high_card_features])

ohe = MyOneHotEncoder()
ohe.fit(X_full[low_card_curr])
X_full_low = ohe.transform(X_full[low_card_curr])

X_full_cat = pd.concat([X_full_high, X_full_low], axis=1)

drop_for_numeric = set(high_card_features + low_card_curr)
numeric_features_curr = [c for c in X_full.columns if c not in drop_for_numeric]

X_full_final = pd.concat([X_full[numeric_features_curr], X_full_cat], axis=1)
print(f"- train matrix shape: {X_full_final.shape}")

# ==============================================================================
# 8) FEATURE SELECTION (FIT ON FULL TRAIN)
# ==============================================================================
print("- fitting feature selector (RF)")

n_feats = X_full_final.shape[1]
k = int(np.ceil(FS_KEEP_RATIO * n_feats))
k = max(1, min(k, n_feats))

rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
rf_fs.fit(X_full_final, y_full_log)

selector = SelectFromModel(
    estimator=rf_fs,
    threshold=-np.inf,
    max_features=k,
    prefit=True
)

selected_cols = X_full_final.columns[selector.get_support()]
X_full_sel = X_full_final[selected_cols]
print(f"- selected features: {len(selected_cols)}/{n_feats}")

# ==============================================================================
# 9) TRAIN FINAL HGB (LOG TARGET)
# ==============================================================================
print("- training final HGB")
hgb_final = HistGradientBoostingRegressor(**final_params)
hgb_final.fit(X_full_sel, y_full_log)
print("- model trained")

# ==============================================================================
# 10) TRANSFORM TEST (TRANSFORM-ONLY) + SAME FE + SAME ENCODING + SAME FS
# ==============================================================================
print("- transforming test set")

X_test = transform_year_with_model_median(X_test, state=year_state)
X_test = transform_engine_size_imputer(X_test, state=engine_state)
X_test = transform_tax_custom_rules(X_test, "tax", "year", "fuelType", "engineSize")
X_test = transform_mpg_imputer(X_test, state=mpg_state)

X_test = transform_previous_owners_imputer(X_test, state=owners_state)

X_test, _, _ = transform_ambiguous_brands(X_test, brand_state)
X_test, _, _ = transform_invalid_models(X_test, model_state)
X_test, _, _ = transform_transmission_resolver(X_test, transm_state)
X_test, _, _ = transform_fueltype_resolver(X_test, fuel_state)

# same FE
X_test = add_owners_flagged(X_test, owners_col="previousOwners", new_col="owners_flagged", drop_original=True)
X_test = create_age_and_drop_year(X_test, year_col="year", base_year=2020)
X_test = add_mileage_features(X_test, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
X_test = add_engine_bins(X_test, engine_col="engineSize", new_col="engine_bin")

X_test["engine_bin"] = X_test["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")

# encoding transform-only
X_test_high = te.transform(X_test[high_card_features])
X_test_low  = ohe.transform(X_test[low_card_curr])
X_test_cat  = pd.concat([X_test_high, X_test_low], axis=1)

drop_for_numeric = set(high_card_features + low_card_curr)
numeric_features_curr_test = [c for c in X_test.columns if c not in drop_for_numeric]

X_test_final = pd.concat([X_test[numeric_features_curr_test], X_test_cat], axis=1)

# align to train columns before selecting
X_test_final = X_test_final.reindex(columns=X_full_final.columns, fill_value=0)

# apply same selected columns
X_test_sel = X_test_final.reindex(columns=selected_cols, fill_value=0)

print(f"- test matrix shape: {X_test_sel.shape}")

# ==============================================================================
# 11) PREDICT + SUBMISSION
# ==============================================================================
pred_log = hgb_final.predict(X_test_sel)
pred_final = np.expm1(pred_log)
pred_final = np.maximum(pred_final, 0)

submission = pd.DataFrame({
    (ID_COL if ID_COL is not None else "id"): test_ids,
    "price": pred_final
})

submission_filename = "submission_hgb_log_target_fs5.csv"
submission.to_csv(submission_filename, index=False)

print(f"- saved: {submission_filename}")
print(submission.head())
# Out:
# - using params: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 600, 'max_depth': 25, 'learning_rate': 0.09105263157894737, 'l2_regularization': 1.4473684210526314, 'max_bins': 255, 'random_state': 42}
# - FS_KEEP_RATIO: 0.65
# - fitting transforms on full train
# - creating engineered features on full train
# - fitting encoders on full train
# - train matrix shape: (75973, 25)
# - fitting feature selector (RF)
# - selected features: 17/25
# - training final HGB
# - model trained
# - transforming test set
# - test matrix shape: (32567, 17)
# - saved: submission_hgb_log_target_fs5.csv
#     carID         price
# 0   89856   6490.349255
# 1  106581  23638.774903
# 2   80886  14125.008808
# 3  100174  16889.942184
# 4   81376  22648.157405

# %% [markdown]
# ### 5.3. Visualization and Final Regards about the Implementation

# %%
import numpy as np
import pandas as pd
import random
import logging

from IPython.display import display
from sklearn.model_selection import KFold
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import mean_absolute_error

# ---------------------------------------------------------
# 0) CONFIGS GERAIS
# ---------------------------------------------------------
N_SPLITS = 8
N_ITER = 15
RANDOM_STATE = 42

# Percentagem de features a manter no SelectFromModel
FS_KEEP_RATIO = 0.60

# RandomForest para Feature Selection (podes ajustar)
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

# ---------------------------------------------------------
# 0.1) CONFIGURAÇÃO DO LOGGING
# ---------------------------------------------------------

logging.basicConfig(
    filename="random_search_fe_fs_results_60.log",
    level=logging.INFO,
    format="%(asctime)s - %(message)s",
    filemode="w",
    force=True
)
logging.info("- 10 iterations")

# ---------------------------------------------------------
# 0.2) CONFIGURAÇÃO DO RANDOM SEARCH
# ---------------------------------------------------------
param_distributions = {
    "min_samples_leaf": [20, 30, 40],
    "max_leaf_nodes": [31, 63, 127],
    "max_iter": [600, 800, 1000],
    "max_depth": [None, 15, 20, 25],
    "learning_rate": np.linspace(0.08, 0.15, 20),
    "l2_regularization": np.linspace(0.5, 2.5, 20),
    "max_bins": [255],
    "random_state": [RANDOM_STATE],
}

def get_random_configs(n_iter: int):
    configs = []
    keys = list(param_distributions.keys())

    for i in range(n_iter):
        params = {}
        for key in keys:
            params[key] = random.choice(list(param_distributions[key]))

        name = (
            f"R{i}_iter{params['max_iter']}"
            f"_lr{float(params['learning_rate']):.3f}"
            f"_l2{float(params['l2_regularization']):.2f}"
            f"_leaf{params['max_leaf_nodes']}"
        )
        configs.append((name, params))
    return configs

CONFIGS = get_random_configs(N_ITER)

# ---------------------------------------------------------
# 1) K-FOLD E SETUP
# ---------------------------------------------------------
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# Assume que já tens no notebook:
# - X, y
# - numeric_features, categorical_features
# - fill_unknown, column_string_transformer
# - fit_* e transform_* (os teus passos)
# - valid_brands, valid_models_by_brand, valid_transmissions, valid_fueltypes
# - MyTargetEncoder, MyOneHotEncoder

cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]
high_card_features = ["Brand", "model"]
low_card_features  = [c for c in categorical_features if c not in high_card_features]

def _normalize_cats(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    for col in cols_to_normalize:
        if col in df.columns:
            df[col] = fill_unknown(df[col])
            df = column_string_transformer(
                df, column=col, remove_middle_spaces=True, allow_extra_chars=""
            )
    return df

# ---------------------------------------------------------
# 1.1) FEATURE ENGINEERING (FUNÇÕES)
# ---------------------------------------------------------
def create_age_and_drop_year(df, year_col="year", base_year=2020, clip_future=True):
    df = df.copy()
    year = pd.to_numeric(df[year_col], errors="coerce")
    age = base_year - year
    if clip_future:
        age = age.clip(lower=0)
    df["age"] = age
    df = df.drop(columns=[year_col])
    return df

def add_owners_flagged(
    df,
    owners_col="previousOwners",
    new_col="owners_flagged",
    drop_original=True,
    na_as_zero=True
):
    df = df.copy()
    owners = pd.to_numeric(df[owners_col], errors="coerce")

    if na_as_zero:
        owners_filled = owners.fillna(0)
        df[new_col] = (owners_filled > 1).astype("int8")
    else:
        df[new_col] = (owners > 1).fillna(False).astype("int8")

    if drop_original and owners_col in df.columns:
        df = df.drop(columns=[owners_col])

    return df

def add_mileage_features(df, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True):
    df = df.copy()

    mileage = pd.to_numeric(df[mileage_col], errors="coerce")
    mileage = mileage.where(mileage >= 0, np.nan)

    df["log_mileage"] = np.log1p(mileage)

    age = pd.to_numeric(df[age_col], errors="coerce")
    age_safe = age.clip(lower=1)  # só para divisão
    df["miles_per_year"] = mileage / age_safe
    df["log_miles_per_year"] = np.log1p(df["miles_per_year"])

    if drop_ratio and "miles_per_year" in df.columns:
        df = df.drop(columns=["miles_per_year"])

    if drop_original and mileage_col in df.columns:
        df = df.drop(columns=[mileage_col])

    return df

def add_engine_bins(df, engine_col="engineSize", new_col="engine_bin", bins=None):
    df = df.copy()

    engine = pd.to_numeric(df[engine_col], errors="coerce")
    engine = engine.where(engine >= 0, np.nan)

    if bins is None:
        bins = [0, 1.0, 1.3, 1.6, 2.0, 2.5, 3.0, 4.0, np.inf]

    df[new_col] = pd.cut(engine, bins=bins, include_lowest=True, labels=False).astype("Int64")
    return df

# ---------------------------------------------------------
# 1.2) EVAL DE 1 CONFIG
# ---------------------------------------------------------
def eval_one_config(name: str, params: dict) -> dict:
    fold_rows = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):
        X_train = X.iloc[train_idx].copy()
        X_val   = X.iloc[val_idx].copy()
        y_train = y.iloc[train_idx].copy()
        y_val   = y.iloc[val_idx].copy()

        # TARGET (LOG)
        y_train_log = np.log1p(y_train)

        # Normalizar categóricas base
        X_train = _normalize_cats(X_train)
        X_val   = _normalize_cats(X_val)

        # Restringir às colunas base (mantém previousOwners e mileage para cleaning)
        base_cols = [c for c in (numeric_features + categorical_features) if c in X_train.columns]
        X_train = X_train[base_cols].copy()
        X_val   = X_val[base_cols].copy()

        # -----------------------------------------------------
        # A) CLEANING
        # -----------------------------------------------------
        year_state = fit_year_median(X_train, year_col="year", model_col="model")
        X_train = transform_year_with_model_median(X_train, state=year_state)
        X_val   = transform_year_with_model_median(X_val,   state=year_state)

        engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
        X_train = transform_engine_size_imputer(X_train, state=engine_state)
        X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

        X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
        X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

        mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
        X_train = transform_mpg_imputer(X_train, state=mpg_state)
        X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

        owners_state = fit_previous_owners_imputer(X_train, "previousOwners", "year", "mileage")
        X_train = transform_previous_owners_imputer(X_train, state=owners_state)
        X_val   = transform_previous_owners_imputer(X_val,   state=owners_state)

        # -----------------------------------------------------
        # B) RESOLVERS
        # -----------------------------------------------------
        brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
        X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
        X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

        model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
        X_train, _, _ = transform_invalid_models(X_train, model_state)
        X_val,   _, _ = transform_invalid_models(X_val,   model_state)

        transm_state = fit_transmission_resolver(X_train, valid_transmissions)
        X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
        X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

        fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
        X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
        X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

        # -----------------------------------------------------
        # C) FEATURE ENGINEERING
        # -----------------------------------------------------
        X_train = add_owners_flagged(X_train, owners_col="previousOwners", new_col="owners_flagged", drop_original=True)
        X_val   = add_owners_flagged(X_val,   owners_col="previousOwners", new_col="owners_flagged", drop_original=True)

        X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
        X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

        X_train = add_mileage_features(X_train, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
        X_val   = add_mileage_features(X_val,   mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)

        X_train = add_engine_bins(X_train, engine_col="engineSize", new_col="engine_bin")
        X_val   = add_engine_bins(X_val,   engine_col="engineSize", new_col="engine_bin")

        # engine_bin como low-card para OHE (robusto a NaNs)
        X_train["engine_bin"] = X_train["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        X_val["engine_bin"]   = X_val["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")

        low_card_curr = low_card_features + ["engine_bin"]

        # -----------------------------------------------------
        # D) ENCODING
        # -----------------------------------------------------
        te = MyTargetEncoder(smoothing=5)
        te.fit(X_train[high_card_features], y_train_log)
        X_train_high = te.transform(X_train[high_card_features])
        X_val_high   = te.transform(X_val[high_card_features])

        ohe = MyOneHotEncoder()
        ohe.fit(X_train[low_card_curr])
        X_train_low = ohe.transform(X_train[low_card_curr])
        X_val_low   = ohe.transform(X_val[low_card_curr])

        X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
        X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

        drop_for_numeric = set(high_card_features + low_card_curr)
        numeric_features_curr = [c for c in X_train.columns if c not in drop_for_numeric]

        X_train_final = pd.concat([X_train[numeric_features_curr], X_train_cat], axis=1)
        X_val_final   = pd.concat([X_val[numeric_features_curr],   X_val_cat],   axis=1)

        # alinhar colunas
        X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

        # -----------------------------------------------------
        # D.1) FEATURE SELECTION (SelectFromModel + RandomForest)
        #     - threshold=-np.inf
        #     - max_features = 80% das features
        # -----------------------------------------------------
        n_feats = X_train_final.shape[1]
        k = int(np.ceil(FS_KEEP_RATIO * n_feats))
        k = max(1, min(k, n_feats))

        rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
        rf_fs.fit(X_train_final, y_train_log)

        selector = SelectFromModel(
            estimator=rf_fs,
            threshold=-np.inf,
            max_features=k,
            prefit=True
        )

        support = selector.get_support()
        selected_cols = X_train_final.columns[support]

        X_train_sel = X_train_final[selected_cols]
        X_val_sel   = X_val_final[selected_cols]

        # -----------------------------------------------------
        # E) TREINO (HGB)
        # -----------------------------------------------------
        model = HistGradientBoostingRegressor(**params)
        model.fit(X_train_sel, y_train_log)

        pred_tr_log  = model.predict(X_train_sel)
        pred_val_log = model.predict(X_val_sel)

        pred_tr  = np.expm1(pred_tr_log)
        pred_val = np.expm1(pred_val_log)

        mae_tr  = mean_absolute_error(y_train, pred_tr)
        mae_val = mean_absolute_error(y_val,   pred_val)

        fold_rows.append({
            "config": name,
            "fold": fold,
            "n_features_total": n_feats,
            "n_features_selected": len(selected_cols),
            "train_mae": mae_tr,
            "val_mae": mae_val
        })

    df_folds = pd.DataFrame(fold_rows)
    mean_mae_tr  = df_folds["train_mae"].mean()
    mean_mae_val = df_folds["val_mae"].mean()
    mean_sel     = df_folds["n_features_selected"].mean()

    print(f"   >> [{name}] Train MAE: {mean_mae_tr:.2f} | Val MAE: {mean_mae_val:.2f} | Sel: {mean_sel:.0f} feats")
    logging.info(
        f"{name} | Train MAE: {mean_mae_tr:.4f} | Val MAE: {mean_mae_val:.4f} | "
        f"AvgSelected: {mean_sel:.1f} | Params: {params}"
    )

    out = {
        "config": name,
        "val_mae_mean": mean_mae_val,
        "train_mae_mean": mean_mae_tr,
        "avg_selected_features": float(mean_sel),
        **params
    }
    return out

# ---------------------------------------------------------
# 2) CORRER TODAS AS CONFIGS
# ---------------------------------------------------------
results = []
for i, (name, params) in enumerate(CONFIGS):
    if i % 5 == 0:
        print(f"\n-- doing {i+1}/{len(CONFIGS)}")

    res = eval_one_config(name, params)
    results.append(res)

results_df = pd.DataFrame(results)

# ---------------------------------------------------------
# 3) RESULTADOS FINAIS
# ---------------------------------------------------------
print("\n- 10 BEST Configurations")
results_df_sorted = results_df.sort_values("val_mae_mean", ascending=True)

cols_show = [
    "config",
    "val_mae_mean", "train_mae_mean",
    "avg_selected_features",
    "learning_rate", "max_iter", "l2_regularization", "max_leaf_nodes", "max_depth", "min_samples_leaf"
]

display(results_df_sorted[cols_show].head(10))

results_df_sorted.to_csv("random_search_fe_fs_results_60.csv", index=False)
print("stored at: random_search_fe_fs_results_60.csv")
print(" log in: random_search_fe_fs_results_60.log")
