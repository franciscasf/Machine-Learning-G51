# %% [markdown]
# # GRADIENT BOOSTING

# %% [markdown]
# __INDEX__
# 1. [Understanding Gradient Tree Boosting](#understanding)
# 2. [Setup and Data Preparation](#setup)
# 3. [Model Selection Experiments (Random Search and 8-Fold CV)](#expruns)
#
#     3.1. [Full Feature Set (no Feature Engineering and no Feature Selection)](#allfeat)
#
#     3.2. [Feature Ablation: Excluding `previousOwners`](#noprevown)
#
#     3.3. [Feature Engineering Ablations and Additions](#feateng)
#
# 4. [Final Model: Selected Configuration and Submission File](#finalconfig)

# %% [markdown]
# ## 1. Understanding Gradient Tree Boosting
# <a id="understanding"></a>

# %% [markdown]
# - Gradient-boosted trees consists in an algorithm that ensembles the predictions of weaker prediction models, particularly decision trees. Each of these predictors will correct their predecessor. Unlike many algorithms, this one doesn't just deal with improving weights at each iteration, instead tries to learn frrom the previous predictors residual errors and fit the following predictor to those.
# - This algorithm can be seen as an optimization one bassed on a certain loss function.

# %% [markdown]
# ### 1.2. Gradient Tree Boosting (GTB) in Scikit learn

# %% [markdown]
# - Scikit-learn (0.21) provides us with two options to implement this algorithm (they are availabl both for classification and regression, but we will only focus on the regression ones), both of them inspired by LightGBM:
#     - __'HistGradientBoostingRegressor'__ and
#     - __'GradientBoostingRegressor'__
# - An interesting detail about this implementations is that they support missing values and for the __'HistGradientBoostingRegressor'__ one categorical data is supported aswell.
# - For small datasets, the use of bins might contribute to very close split points, ence why, in this case, __'GradientBoostingRegressor'__ is preferible. However, our dataset granularity is moderatly high and, as indicated by the official documentation, for a sample with tens of thousands of samples, __'HistGradientBoostingRegressor'__ is preferible.
# - In addition, __'HistGradientBoostingRegressor'__ has the advantage of increased time efficiency and complexity (that will be later on explained in the notebook) compared to __'GradientBoostingRegressor'__. However, the former does not natively support some features of the latter.
#
# Note: all of these informations are available at the scikit learn documentation.

# %% [markdown]
# ### 1.3. Understanding __'HistGradientBoostingRegressor'__

# %% [markdown]
# - We decided to use this algorithm because of the infra citated reasons as well as because of the reasons citated in ths section.

# %% [markdown]
# ## 2. Setup and Data Preparation  <a id="setup"></a>

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import KFold, ParameterSampler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, median_absolute_error, mean_absolute_percentage_error
import os
from sklearn.feature_selection import SelectFromModel
import random
import logging
from IPython.display import display

# %%
def rmse(y_true, y_pred) -> float:
    return float(np.sqrt(mean_squared_error(y_true, y_pred)))

def bias(y_true, y_pred) -> float:
    return float(np.mean(np.asarray(y_true) - np.asarray(y_pred)))

def get_random_configs(n_iter: int):
    configs = []
    keys = list(param_distributions.keys())
    for i in range(n_iter):
        params = {k: random.choice(list(param_distributions[k])) for k in keys}

        name = (
            f"R{i}_iter{params['max_iter']}"
            f"_lr{float(params['learning_rate']):.3f}"
            f"_l2{float(params['l2_regularization']):.2f}"
            f"_leaf{params['max_leaf_nodes']}"
        )
        configs.append((name, params))
    return configs

def _normalize_cats(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    for col in cols_to_normalize:
        if col in df.columns:
            df[col] = fill_unknown(df[col])
            df = column_string_transformer(df, column=col, remove_middle_spaces=True, allow_extra_chars="")
    return df

# %%
# %run 05_0.1_visualization_helpers.ipynb

# %%
random.seed(RANDOM_STATE) # additional randomness control
np.random.seed(RANDOM_STATE) # additional randomness control - for numpy

# All of our preprocessing helper functions are in this notebook
# %run 05_0_preproc_helpers.ipynb  

# this is the target column - the value we want to predict 
TARGET_COL = "price"  

# separate features and target variable from the full training datase
y = full_train_dataset[TARGET_COL].copy()
X = full_train_dataset.drop(columns=[TARGET_COL]).copy()

# at this point, this are all the features in use 
categorical_features = ['Brand', 'model', 'transmission', 'fuelType']              
numeric_features = ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners']

print("X shape:", X.shape)
print("y shape:", y.shape)
print("Num features:", numeric_features)
print("Cat features:", categorical_features)

N_SPLITS = 8 # the number of folds for K-Fold cross-validation
RANDOM_STATE = 42 # seed to control randomness
# Out:
# X shape: (75973, 10)
# y shape: (75973,)
# Num features: ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners']
# Cat features: ['Brand', 'model', 'transmission', 'fuelType']

# %% [markdown]
# ## 3. Model Selection Experiments (Random Search and 8-Fold CV)  <a id="expruns"></a>

# %% [markdown]
# ### 3.1. Full Feature Set (no Feature Engineering and no Feature Selection) <a id="allfeat"></a>

# %% [markdown]
# - In this section, we performed a random search to check wether the chosen hyperparameters search space was reasonable and to establish baseline results for the next improvements.

# %%
# shuffles the data, in order to, at least theoretically, have more balanced folds
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)


# hyperparameter space that we are going to use to random search
# each configuration will get 1 value from each of these lists
param_distributions = {
    "max_iter": [600, 800, 1000], # max number of trees 
    "learning_rate": [0.05, 0.1, 0.15], # shrinkage factor (for the leaves values) 
    "max_leaf_nodes": [31, 63, 127], # max number of leaves for each tree
    "max_depth": [None, 10, 20, 11, 15], # max depth of each tree
    "l2_regularization": [0, 1, 2, 5], # regularization (penalization) factor for small hessian values leaves  
    "min_samples_leaf": [20, 40] # min number of samples for each leaf
}

N_RANDOM_CONFIGS = 10 # this is a short random search, enough for baseline results

# we get N_RANDOM_CONFIGS (10) random parameter combinations from param_distributions 
sampler = ParameterSampler(param_distributions, n_iter=N_RANDOM_CONFIGS, random_state=RANDOM_STATE)

search_results = [] # to store results of each configuration, to store the ranking

# tracking the best configuration according to validation RMSE 
best_rmse = np.inf 
best_config = None 

# to store our fold results
log_dir = "gb_logs" # directory to save log files that is not present in this final version but was useful during development
os.makedirs(log_dir, exist_ok=True)  # creates the log directory if it doesn't exist
log_filename = "2gb_complete_nof_log2.txt"
log_path = os.path.join(log_dir, log_filename)
# Note: this section is mainly for organization purposes and is not particularly relevant 


with open(log_path, "w", encoding="utf-8") as log_file:

    # this function allows printing the messages to the screen and to the log file 
    def log(msg: str):
        print(msg) 
        log_file.write(msg + "\n") 
        log_file.flush() 

    # header for the log file - just for readability and general info
    log("# =============================")
    log(f"# START OF HGB SEARCH (DETAILED METRICS: R2, RMSE, MAE, BIAS)")
    log(f"# LOG FILE SAVED TO: {log_path}")
    log("# =============================")
    
    # loop that iterates over each random configuration
    for config_id, params in enumerate(sampler, start=1):
        log("")
        log(f"######## CONFIG {config_id}/{N_RANDOM_CONFIGS} ########") 
        log(f"Parameters: {params}")

        # we are storing the metrics for each fold here
        fold_rmses_val, fold_maes_val, fold_r2s_val, fold_bias_val = [], [], [], []
        fold_rmses_tr, fold_maes_tr, fold_r2s_tr, fold_bias_tr = [], [], [], []
        fold_med_ae = []

        # for each configuration, we do K-Fold cross-validation
        for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):
            
            # data split for the current fold
            X_train, X_val = X.iloc[train_idx].copy(), X.iloc[val_idx].copy()
            y_train, y_val = y.iloc[train_idx].copy(), y.iloc[val_idx].copy()

            log(f"\n[C{config_id}|F{fold}] Processing fold...")


            # -> Preprocessing Steps 
            # fit is only done with the training data 
            # we aplly the transformations (some obtained through fit) to both train and validation sets
            # all preprocessing functions are explained before, here we just apply them in order
            year_state = fit_year_median(X_train, year_col="year", model_col="model")
            X_train = transform_year_with_model_median(X_train, state=year_state)
            X_val   = transform_year_with_model_median(X_val,   state=year_state)

            mileage_state = fit_mileage_imputer(X_train, mileage_col="mileage", do_abs=True)
            X_train = transform_mileage_imputer(X_train, state=mileage_state)
            X_val   = transform_mileage_imputer(X_val,   state=mileage_state) 

            engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
            X_train = transform_engine_size_imputer(X_train, state=engine_state)
            X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

            X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
            X_val   = transform_tax_custom_rules(X_val, "tax", "year", "fuelType", "engineSize")

            mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
            X_train = transform_mpg_imputer(X_train, state=mpg_state)
            X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

            owners_state = fit_previous_owners_imputer(X_train, "previousOwners", "year", "mileage")
            X_train = transform_previous_owners_imputer(X_train, state=owners_state)
            X_val   = transform_previous_owners_imputer(X_val,   state=owners_state)

            brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
            X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
            X_val, _, _   = transform_ambiguous_brands(X_val, brand_state)

            model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
            X_train, _, _ = transform_invalid_models(X_train, model_state)
            X_val, _, _   = transform_invalid_models(X_val, model_state)

            transm_state = fit_transmission_resolver(X_train, valid_transmissions)
            X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
            X_val, _, _   = transform_transmission_resolver(X_val, transm_state)
            
            fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
            X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
            X_val, _, _   = transform_fueltype_resolver(X_val, fuel_state)


            # -> Feature Encoding
            # applied to categorical features only
            # we separate high cardinality and low cardinality categorical features
            high_card_features = ["Brand", "model"] # target encoding for these
            low_card_features  = [c for c in categorical_features if c not in high_card_features]

            te = MyTargetEncoder(smoothing=5)
            te.fit(X_train[high_card_features], y_train) # fit on training data
            X_train_high = te.transform(X_train[high_card_features])
            X_val_high   = te.transform(X_val[high_card_features])

            ohe = MyOneHotEncoder()
            ohe.fit(X_train[low_card_features]) # fit on training data
            X_train_low = ohe.transform(X_train[low_card_features])
            X_val_low   = ohe.transform(X_val[low_card_features])

            # rejoining the categorical features (that are now encoded)
            X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
            X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

            # joining numerical and categorical (encoded) features 
            X_train_final = pd.concat([X_train[numeric_features], X_train_cat], axis=1)
            X_val_final   = pd.concat([X_val[numeric_features],   X_val_cat],   axis=1)

            # here, we log the features name, to keep track of what is being used from the original set
            # but also because the columns increase due to encoding
            if fold == 1:
                feature_names = list(X_train_final.columns)
                log(f"  > Features Used ({len(feature_names)}): {feature_names}")
            
            # -> Model Training 
            # params contains the hyperparameters for this configuration
            hgb_model = HistGradientBoostingRegressor(random_state=RANDOM_STATE, **params)
            hgb_model.fit(X_train_final, y_train)

            # predictions on train and validation fold
            y_pred_train = hgb_model.predict(X_train_final)
            y_pred_val   = hgb_model.predict(X_val_final)

            # -> Metrics Calculation
            # Training metrics:
            mae_tr = mean_absolute_error(y_train, y_pred_train)
            rmse_tr = np.sqrt(mean_squared_error(y_train, y_pred_train))
            r2_tr = r2_score(y_train, y_pred_train)
            bias_tr = np.mean(y_train - y_pred_train)
            # Validation metrics:
            mae_val = mean_absolute_error(y_val, y_pred_val)
            rmse_val = np.sqrt(mean_squared_error(y_val, y_pred_val))
            r2_val = r2_score(y_val, y_pred_val)
            bias_val = np.mean(y_val - y_pred_val)
            med_ae_val = median_absolute_error(y_val, y_pred_val)

            # logging the metrics of this fold
            log(f"  > [TRAIN] R2: {r2_tr:.4f} | RMSE: {rmse_tr:.0f} | MAE: {mae_tr:.0f} | Bias: {bias_tr:.1f}")
            log(f"  > [VAL]   R2: {r2_val:.4f} | RMSE: {rmse_val:.0f} | MAE: {mae_val:.0f} | Bias: {bias_val:.1f}")
            # storing the metrics of this fold
            fold_maes_tr.append(mae_tr); fold_rmses_tr.append(rmse_tr); fold_r2s_tr.append(r2_tr); fold_bias_tr.append(bias_tr)
            fold_maes_val.append(mae_val); fold_rmses_val.append(rmse_val); fold_r2s_val.append(r2_val); fold_bias_val.append(bias_val)
            fold_med_ae.append(med_ae_val)

        # after all folds, we calculate the mean metrics across them
        mean_rmse_val = np.mean(fold_rmses_val)
        mean_mae_val  = np.mean(fold_maes_val)
        mean_r2_val   = np.mean(fold_r2s_val)
        mean_bias_val = np.mean(fold_bias_val)
        
        mean_mae_tr   = np.mean(fold_maes_tr)
        mean_r2_tr    = np.mean(fold_r2s_tr)
        mean_bias_tr  = np.mean(fold_bias_tr)
        
        # logging and storing these results
        log("")
        log(f"Config {config_id} SUMMARY:")
        log(f"  [TRAIN AVG] MAE: {mean_mae_tr:.1f} | R2: {mean_r2_tr:.4f} | Bias: {mean_bias_tr:.1f}")
        log(f"  [VAL AVG]   MAE: {mean_mae_val:.1f} | R2: {mean_r2_val:.4f} | Bias: {mean_bias_val:.1f} | RMSE: {mean_rmse_val:.1f}")

        search_results.append({
            "config_id": config_id,
            **params,
            
            "val_rmse": mean_rmse_val,
            "val_mae": mean_mae_val,
            "val_r2": mean_r2_val,
            "val_bias": mean_bias_val,

            "train_mae": mean_mae_tr,
            "train_r2": mean_r2_tr,
            "train_bias": mean_bias_tr,

            "val_med_ae": np.mean(fold_med_ae)
        })

        # our best configuration is defined by the best rmse
        # by best, we mean the lowest rmse
        if mean_rmse_val < best_rmse:
            best_rmse = mean_rmse_val
            best_config = {**params}
            log(f"[NEW BEST RMSE] Config {config_id}")

    log("# END OF SEARCH")


# Results
results_df = pd.DataFrame(search_results)
results_df_sorted = results_df.sort_values(by="val_rmse", ascending=True)

print("\nTop 5 Configurations by RMSE:")
cols = ["config_id", "learning_rate", "max_iter", "val_rmse", "val_mae", "val_r2", "train_r2", "val_bias"]
display(results_df_sorted[cols].head(5))

print("\nBest Config found:")
print(best_config)
# Out:
# # =============================
# # START OF HGB SEARCH (DETAILED METRICS: R2, RMSE, MAE, BIAS)
# # LOG FILE SAVED TO: gb_logs/2gb_complete_nof_log2.txt
# # =============================
#
# ######## CONFIG 1/10 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 1000, 'max_depth': 20, 'learning_rate': 0.05, 'l2_regularization': 5}
#
# [C1|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9612 | RMSE: 1925 | MAE: 1184 | Bias: 5.8
#   > [VAL]   R2: 0.9560 | RMSE: 1994 | MAE: 1309 | Bias: -34.4
#
# [C1|F2] Processing fold...
#   > [TRAIN] R2: 0.9652 | RMSE: 1817 | MAE: 1181 | Bias: 1.3
#   > [VAL]   R2: 0.9492 | RMSE: 2183 | MAE: 1338 | Bias: -17.5
#
# [C1|F3] Processing fold...
#   > [TRAIN] R2: 0.9654 | RMSE: 1812 | MAE: 1153 | Bias: 2.7
#   > [VAL]   R2: 0.9497 | RMSE: 2173 | MAE: 1318 | Bias: 30.5
#
# [C1|F4] Processing fold...
#   > [TRAIN] R2: 0.9704 | RMSE: 1666 | MAE: 1118 | Bias: -0.7
#   > [VAL]   R2: 0.9334 | RMSE: 2616 | MAE: 1332 | Bias: 20.0
#
# [C1|F5] Processing fold...
#   > [TRAIN] R2: 0.9705 | RMSE: 1670 | MAE: 1085 | Bias: -4.6
#   > [VAL]   R2: 0.9567 | RMSE: 2041 | MAE: 1267 | Bias: 1.2
#
# [C1|F6] Processing fold...
#   > [TRAIN] R2: 0.9652 | RMSE: 1815 | MAE: 1172 | Bias: 1.1
#   > [VAL]   R2: 0.9534 | RMSE: 2120 | MAE: 1296 | Bias: 17.5
#
# [C1|F7] Processing fold...
#   > [TRAIN] R2: 0.9705 | RMSE: 1673 | MAE: 1089 | Bias: 3.1
#   > [VAL]   R2: 0.9566 | RMSE: 2026 | MAE: 1260 | Bias: 28.4
#
# [C1|F8] Processing fold...
#   > [TRAIN] R2: 0.9655 | RMSE: 1816 | MAE: 1184 | Bias: 2.1
#   > [VAL]   R2: 0.9539 | RMSE: 2039 | MAE: 1284 | Bias: -15.1
#
# Config 1 SUMMARY:
#   [TRAIN AVG] MAE: 1145.8 | R2: 0.9667 | Bias: 1.4
#   [VAL AVG]   MAE: 1300.5 | R2: 0.9511 | Bias: 3.8 | RMSE: 2149.2
# [NEW BEST RMSE] Config 1
#
# ######## CONFIG 2/10 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 31, 'max_iter': 600, 'max_depth': 11, 'learning_rate': 0.15, 'l2_regularization': 5}
#
# [C2|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9566 | RMSE: 2034 | MAE: 1261 | Bias: 4.3
#   > [VAL]   R2: 0.9546 | RMSE: 2028 | MAE: 1341 | Bias: -39.2
#
# [C2|F2] Processing fold...
#   > [TRAIN] R2: 0.9625 | RMSE: 1888 | MAE: 1230 | Bias: 0.2
#   > [VAL]   R2: 0.9477 | RMSE: 2215 | MAE: 1370 | Bias: -18.2
#
# [C2|F3] Processing fold...
#   > [TRAIN] R2: 0.9634 | RMSE: 1865 | MAE: 1197 | Bias: 3.0
#   > [VAL]   R2: 0.9495 | RMSE: 2178 | MAE: 1339 | Bias: 39.4
#
# [C2|F4] Processing fold...
#   > [TRAIN] R2: 0.9656 | RMSE: 1796 | MAE: 1200 | Bias: -1.4
#   > [VAL]   R2: 0.9325 | RMSE: 2634 | MAE: 1366 | Bias: 25.4
#
# [C2|F5] Processing fold...
#   > [TRAIN] R2: 0.9596 | RMSE: 1954 | MAE: 1277 | Bias: -4.9
#   > [VAL]   R2: 0.9524 | RMSE: 2140 | MAE: 1365 | Bias: -6.2
#
# [C2|F6] Processing fold...
#   > [TRAIN] R2: 0.9670 | RMSE: 1766 | MAE: 1149 | Bias: 2.5
#   > [VAL]   R2: 0.9546 | RMSE: 2092 | MAE: 1295 | Bias: 17.2
#
# [C2|F7] Processing fold...
#   > [TRAIN] R2: 0.9645 | RMSE: 1835 | MAE: 1194 | Bias: 4.5
#   > [VAL]   R2: 0.9554 | RMSE: 2053 | MAE: 1302 | Bias: 26.6
#
# [C2|F8] Processing fold...
#   > [TRAIN] R2: 0.9678 | RMSE: 1755 | MAE: 1150 | Bias: 1.5
#   > [VAL]   R2: 0.9534 | RMSE: 2051 | MAE: 1282 | Bias: -15.9
#
# Config 2 SUMMARY:
#   [TRAIN AVG] MAE: 1207.2 | R2: 0.9634 | Bias: 1.2
#   [VAL AVG]   MAE: 1332.5 | R2: 0.9500 | Bias: 3.6 | RMSE: 2174.0
#
# ######## CONFIG 3/10 ########
# Parameters: {'min_samples_leaf': 40, 'max_leaf_nodes': 31, 'max_iter': 1000, 'max_depth': 10, 'learning_rate': 0.1, 'l2_regularization': 0}
#
# [C3|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9587 | RMSE: 1984 | MAE: 1217 | Bias: 5.2
#   > [VAL]   R2: 0.9561 | RMSE: 1994 | MAE: 1311 | Bias: -38.2
#
# [C3|F2] Processing fold...
#   > [TRAIN] R2: 0.9583 | RMSE: 1990 | MAE: 1282 | Bias: 1.0
#   > [VAL]   R2: 0.9462 | RMSE: 2248 | MAE: 1393 | Bias: -32.3
#
# [C3|F3] Processing fold...
#   > [TRAIN] R2: 0.9591 | RMSE: 1971 | MAE: 1246 | Bias: 2.3
#   > [VAL]   R2: 0.9464 | RMSE: 2243 | MAE: 1360 | Bias: 39.4
#
# [C3|F4] Processing fold...
#   > [TRAIN] R2: 0.9616 | RMSE: 1896 | MAE: 1257 | Bias: -1.6
#   > [VAL]   R2: 0.9308 | RMSE: 2667 | MAE: 1395 | Bias: 18.2
#
# [C3|F5] Processing fold...
#   > [TRAIN] R2: 0.9599 | RMSE: 1948 | MAE: 1260 | Bias: -5.0
#   > [VAL]   R2: 0.9523 | RMSE: 2142 | MAE: 1350 | Bias: -10.4
#
# [C3|F6] Processing fold...
#   > [TRAIN] R2: 0.9647 | RMSE: 1827 | MAE: 1182 | Bias: 1.8
#   > [VAL]   R2: 0.9551 | RMSE: 2079 | MAE: 1299 | Bias: 22.4
#
# [C3|F7] Processing fold...
#   > [TRAIN] R2: 0.9645 | RMSE: 1835 | MAE: 1185 | Bias: 3.7
#   > [VAL]   R2: 0.9547 | RMSE: 2071 | MAE: 1294 | Bias: 31.6
#
# [C3|F8] Processing fold...
#   > [TRAIN] R2: 0.9616 | RMSE: 1915 | MAE: 1242 | Bias: 1.4
#   > [VAL]   R2: 0.9518 | RMSE: 2086 | MAE: 1319 | Bias: -23.8
#
# Config 3 SUMMARY:
#   [TRAIN AVG] MAE: 1234.0 | R2: 0.9610 | Bias: 1.1
#   [VAL AVG]   MAE: 1340.1 | R2: 0.9492 | Bias: 0.9 | RMSE: 2191.2
#
# ######## CONFIG 4/10 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': None, 'learning_rate': 0.15, 'l2_regularization': 1}
#
# [C4|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9681 | RMSE: 1746 | MAE: 1059 | Bias: 5.9
#   > [VAL]   R2: 0.9577 | RMSE: 1957 | MAE: 1271 | Bias: -37.2
#
# [C4|F2] Processing fold...
#   > [TRAIN] R2: 0.9744 | RMSE: 1559 | MAE: 1013 | Bias: 1.0
#   > [VAL]   R2: 0.9507 | RMSE: 2151 | MAE: 1290 | Bias: -5.0
#
# [C4|F3] Processing fold...
#   > [TRAIN] R2: 0.9684 | RMSE: 1733 | MAE: 1100 | Bias: 3.7
#   > [VAL]   R2: 0.9490 | RMSE: 2188 | MAE: 1317 | Bias: 37.0
#
# [C4|F4] Processing fold...
#   > [TRAIN] R2: 0.9708 | RMSE: 1655 | MAE: 1106 | Bias: -0.5
#   > [VAL]   R2: 0.9329 | RMSE: 2626 | MAE: 1342 | Bias: 28.8
#
# [C4|F5] Processing fold...
#   > [TRAIN] R2: 0.9749 | RMSE: 1542 | MAE: 1005 | Bias: -5.0
#   > [VAL]   R2: 0.9567 | RMSE: 2040 | MAE: 1270 | Bias: -0.0
#
# [C4|F6] Processing fold...
#   > [TRAIN] R2: 0.9696 | RMSE: 1696 | MAE: 1095 | Bias: 1.1
#   > [VAL]   R2: 0.9537 | RMSE: 2112 | MAE: 1281 | Bias: 5.6
#
# [C4|F7] Processing fold...
#   > [TRAIN] R2: 0.9750 | RMSE: 1540 | MAE: 998 | Bias: 2.3
#   > [VAL]   R2: 0.9563 | RMSE: 2032 | MAE: 1255 | Bias: 21.1
#
# [C4|F8] Processing fold...
#   > [TRAIN] R2: 0.9728 | RMSE: 1610 | MAE: 1055 | Bias: 1.5
#   > [VAL]   R2: 0.9546 | RMSE: 2025 | MAE: 1258 | Bias: -17.4
#
# Config 4 SUMMARY:
#   [TRAIN AVG] MAE: 1054.1 | R2: 0.9717 | Bias: 1.2
#   [VAL AVG]   MAE: 1285.5 | R2: 0.9515 | Bias: 4.1 | RMSE: 2141.2
# [NEW BEST RMSE] Config 4
#
# ######## CONFIG 5/10 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 31, 'max_iter': 800, 'max_depth': 11, 'learning_rate': 0.05, 'l2_regularization': 1}
#
# [C5|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9573 | RMSE: 2018 | MAE: 1248 | Bias: 4.6
#   > [VAL]   R2: 0.9552 | RMSE: 2013 | MAE: 1329 | Bias: -28.4
#
# [C5|F2] Processing fold...
#   > [TRAIN] R2: 0.9621 | RMSE: 1898 | MAE: 1237 | Bias: 1.2
#   > [VAL]   R2: 0.9488 | RMSE: 2191 | MAE: 1359 | Bias: -26.0
#
# [C5|F3] Processing fold...
#   > [TRAIN] R2: 0.9548 | RMSE: 2071 | MAE: 1325 | Bias: 1.2
#   > [VAL]   R2: 0.9429 | RMSE: 2316 | MAE: 1417 | Bias: 38.0
#
# [C5|F4] Processing fold...
#   > [TRAIN] R2: 0.9635 | RMSE: 1848 | MAE: 1232 | Bias: -1.4
#   > [VAL]   R2: 0.9322 | RMSE: 2639 | MAE: 1379 | Bias: 18.6
#
# [C5|F5] Processing fold...
#   > [TRAIN] R2: 0.9605 | RMSE: 1934 | MAE: 1258 | Bias: -5.0
#   > [VAL]   R2: 0.9528 | RMSE: 2130 | MAE: 1347 | Bias: -1.7
#
# [C5|F6] Processing fold...
#   > [TRAIN] R2: 0.9582 | RMSE: 1987 | MAE: 1285 | Bias: 1.4
#   > [VAL]   R2: 0.9484 | RMSE: 2231 | MAE: 1368 | Bias: 28.5
#
# [C5|F7] Processing fold...
#   > [TRAIN] R2: 0.9617 | RMSE: 1907 | MAE: 1241 | Bias: 4.9
#   > [VAL]   R2: 0.9548 | RMSE: 2067 | MAE: 1326 | Bias: 17.8
#
# [C5|F8] Processing fold...
#   > [TRAIN] R2: 0.9601 | RMSE: 1951 | MAE: 1272 | Bias: 1.8
#   > [VAL]   R2: 0.9508 | RMSE: 2106 | MAE: 1337 | Bias: -19.8
#
# Config 5 SUMMARY:
#   [TRAIN AVG] MAE: 1262.3 | R2: 0.9598 | Bias: 1.1
#   [VAL AVG]   MAE: 1357.7 | R2: 0.9483 | Bias: 3.4 | RMSE: 2211.5
#
# ######## CONFIG 6/10 ########
# Parameters: {'min_samples_leaf': 40, 'max_leaf_nodes': 63, 'max_iter': 1000, 'max_depth': 15, 'learning_rate': 0.05, 'l2_regularization': 0}
#
# [C6|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9570 | RMSE: 2027 | MAE: 1231 | Bias: 5.4
#   > [VAL]   R2: 0.9548 | RMSE: 2023 | MAE: 1321 | Bias: -42.4
#
# [C6|F2] Processing fold...
#   > [TRAIN] R2: 0.9629 | RMSE: 1877 | MAE: 1201 | Bias: 0.7
#   > [VAL]   R2: 0.9478 | RMSE: 2212 | MAE: 1348 | Bias: -28.0
#
# [C6|F3] Processing fold...
#   > [TRAIN] R2: 0.9554 | RMSE: 2058 | MAE: 1280 | Bias: 3.1
#   > [VAL]   R2: 0.9419 | RMSE: 2336 | MAE: 1398 | Bias: 42.0
#
# [C6|F4] Processing fold...
#   > [TRAIN] R2: 0.9658 | RMSE: 1790 | MAE: 1180 | Bias: -0.9
#   > [VAL]   R2: 0.9329 | RMSE: 2626 | MAE: 1356 | Bias: 21.2
#
# [C6|F5] Processing fold...
#   > [TRAIN] R2: 0.9642 | RMSE: 1841 | MAE: 1175 | Bias: -5.4
#   > [VAL]   R2: 0.9545 | RMSE: 2092 | MAE: 1305 | Bias: -9.6
#
# [C6|F6] Processing fold...
#   > [TRAIN] R2: 0.9617 | RMSE: 1903 | MAE: 1208 | Bias: 2.0
#   > [VAL]   R2: 0.9492 | RMSE: 2213 | MAE: 1318 | Bias: 18.4
#
# [C6|F7] Processing fold...
#   > [TRAIN] R2: 0.9673 | RMSE: 1760 | MAE: 1129 | Bias: 2.9
#   > [VAL]   R2: 0.9561 | RMSE: 2038 | MAE: 1269 | Bias: 33.1
#
# [C6|F8] Processing fold...
#   > [TRAIN] R2: 0.9644 | RMSE: 1843 | MAE: 1185 | Bias: 2.2
#   > [VAL]   R2: 0.9536 | RMSE: 2047 | MAE: 1279 | Bias: -15.4
#
# Config 6 SUMMARY:
#   [TRAIN AVG] MAE: 1198.7 | R2: 0.9623 | Bias: 1.3
#   [VAL AVG]   MAE: 1324.3 | R2: 0.9488 | Bias: 2.4 | RMSE: 2198.6
#
# ######## CONFIG 7/10 ########
# Parameters: {'min_samples_leaf': 40, 'max_leaf_nodes': 31, 'max_iter': 800, 'max_depth': 11, 'learning_rate': 0.05, 'l2_regularization': 5}
#
# [C7|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9510 | RMSE: 2163 | MAE: 1333 | Bias: 5.0
#   > [VAL]   R2: 0.9509 | RMSE: 2107 | MAE: 1385 | Bias: -31.4
#
# [C7|F2] Processing fold...
#   > [TRAIN] R2: 0.9563 | RMSE: 2038 | MAE: 1309 | Bias: 1.3
#   > [VAL]   R2: 0.9450 | RMSE: 2273 | MAE: 1413 | Bias: -26.4
#
# [C7|F3] Processing fold...
#   > [TRAIN] R2: 0.9567 | RMSE: 2028 | MAE: 1279 | Bias: 1.8
#   > [VAL]   R2: 0.9446 | RMSE: 2281 | MAE: 1382 | Bias: 40.8
#
# [C7|F4] Processing fold...
#   > [TRAIN] R2: 0.9607 | RMSE: 1918 | MAE: 1266 | Bias: -1.5
#   > [VAL]   R2: 0.9293 | RMSE: 2696 | MAE: 1400 | Bias: 16.4
#
# [C7|F5] Processing fold...
#   > [TRAIN] R2: 0.9578 | RMSE: 1998 | MAE: 1285 | Bias: -5.6
#   > [VAL]   R2: 0.9515 | RMSE: 2160 | MAE: 1363 | Bias: -4.3
#
# [C7|F6] Processing fold...
#   > [TRAIN] R2: 0.9579 | RMSE: 1995 | MAE: 1279 | Bias: 1.7
#   > [VAL]   R2: 0.9485 | RMSE: 2227 | MAE: 1357 | Bias: 24.1
#
# [C7|F7] Processing fold...
#   > [TRAIN] R2: 0.9586 | RMSE: 1982 | MAE: 1271 | Bias: 4.0
#   > [VAL]   R2: 0.9527 | RMSE: 2115 | MAE: 1342 | Bias: 27.1
#
# [C7|F8] Processing fold...
#   > [TRAIN] R2: 0.9582 | RMSE: 1998 | MAE: 1290 | Bias: 2.3
#   > [VAL]   R2: 0.9511 | RMSE: 2100 | MAE: 1338 | Bias: -20.7
#
# Config 7 SUMMARY:
#   [TRAIN AVG] MAE: 1289.0 | R2: 0.9571 | Bias: 1.1
#   [VAL AVG]   MAE: 1372.4 | R2: 0.9467 | Bias: 3.2 | RMSE: 2244.9
#
# ######## CONFIG 8/10 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 600, 'max_depth': 20, 'learning_rate': 0.1, 'l2_regularization': 0}
#
# [C8|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9652 | RMSE: 1822 | MAE: 1110 | Bias: 4.6
#   > [VAL]   R2: 0.9563 | RMSE: 1989 | MAE: 1279 | Bias: -38.8
#
# [C8|F2] Processing fold...
#   > [TRAIN] R2: 0.9714 | RMSE: 1649 | MAE: 1072 | Bias: 1.3
#   > [VAL]   R2: 0.9519 | RMSE: 2125 | MAE: 1295 | Bias: -6.3
#
# [C8|F3] Processing fold...
#   > [TRAIN] R2: 0.9704 | RMSE: 1677 | MAE: 1061 | Bias: 4.0
#   > [VAL]   R2: 0.9515 | RMSE: 2135 | MAE: 1297 | Bias: 31.8
#
# [C8|F4] Processing fold...
#   > [TRAIN] R2: 0.9747 | RMSE: 1538 | MAE: 1030 | Bias: -0.1
#   > [VAL]   R2: 0.9339 | RMSE: 2605 | MAE: 1320 | Bias: 25.8
#
# [C8|F5] Processing fold...
#   > [TRAIN] R2: 0.9752 | RMSE: 1531 | MAE: 994 | Bias: -4.2
#   > [VAL]   R2: 0.9563 | RMSE: 2051 | MAE: 1259 | Bias: 0.6
#
# [C8|F6] Processing fold...
#   > [TRAIN] R2: 0.9702 | RMSE: 1680 | MAE: 1083 | Bias: 1.9
#   > [VAL]   R2: 0.9554 | RMSE: 2073 | MAE: 1268 | Bias: 9.7
#
# [C8|F7] Processing fold...
#   > [TRAIN] R2: 0.9748 | RMSE: 1546 | MAE: 1000 | Bias: 1.7
#   > [VAL]   R2: 0.9573 | RMSE: 2010 | MAE: 1247 | Bias: 26.9
#
# [C8|F8] Processing fold...
#   > [TRAIN] R2: 0.9724 | RMSE: 1624 | MAE: 1056 | Bias: 1.9
#   > [VAL]   R2: 0.9551 | RMSE: 2012 | MAE: 1243 | Bias: -11.8
#
# Config 8 SUMMARY:
#   [TRAIN AVG] MAE: 1050.8 | R2: 0.9718 | Bias: 1.4
#   [VAL AVG]   MAE: 1276.0 | R2: 0.9522 | Bias: 4.7 | RMSE: 2125.2
# [NEW BEST RMSE] Config 8
#
# ######## CONFIG 9/10 ########
# Parameters: {'min_samples_leaf': 40, 'max_leaf_nodes': 31, 'max_iter': 1000, 'max_depth': 20, 'learning_rate': 0.15, 'l2_regularization': 2}
#
# [C9|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9551 | RMSE: 2069 | MAE: 1277 | Bias: 5.4
#   > [VAL]   R2: 0.9532 | RMSE: 2057 | MAE: 1357 | Bias: -36.3
#
# [C9|F2] Processing fold...
#   > [TRAIN] R2: 0.9581 | RMSE: 1995 | MAE: 1286 | Bias: 0.3
#   > [VAL]   R2: 0.9453 | RMSE: 2265 | MAE: 1404 | Bias: -38.4
#
# [C9|F3] Processing fold...
#   > [TRAIN] R2: 0.9586 | RMSE: 1982 | MAE: 1257 | Bias: 1.9
#   > [VAL]   R2: 0.9465 | RMSE: 2241 | MAE: 1370 | Bias: 40.0
#
# [C9|F4] Processing fold...
#   > [TRAIN] R2: 0.9670 | RMSE: 1757 | MAE: 1174 | Bias: -1.4
#   > [VAL]   R2: 0.9325 | RMSE: 2632 | MAE: 1349 | Bias: 12.5
#
# [C9|F5] Processing fold...
#   > [TRAIN] R2: 0.9637 | RMSE: 1853 | MAE: 1204 | Bias: -5.0
#   > [VAL]   R2: 0.9539 | RMSE: 2107 | MAE: 1320 | Bias: -3.2
#
# [C9|F6] Processing fold...
#   > [TRAIN] R2: 0.9676 | RMSE: 1750 | MAE: 1137 | Bias: 1.4
#   > [VAL]   R2: 0.9565 | RMSE: 2047 | MAE: 1279 | Bias: 20.4
#
# [C9|F7] Processing fold...
#   > [TRAIN] R2: 0.9673 | RMSE: 1760 | MAE: 1140 | Bias: 3.3
#   > [VAL]   R2: 0.9562 | RMSE: 2037 | MAE: 1274 | Bias: 33.7
#
# [C9|F8] Processing fold...
#   > [TRAIN] R2: 0.9660 | RMSE: 1801 | MAE: 1173 | Bias: 1.7
#   > [VAL]   R2: 0.9538 | RMSE: 2042 | MAE: 1279 | Bias: -16.9
#
# Config 9 SUMMARY:
#   [TRAIN AVG] MAE: 1206.0 | R2: 0.9629 | Bias: 1.0
#   [VAL AVG]   MAE: 1329.1 | R2: 0.9497 | Bias: 1.5 | RMSE: 2178.6
#
# ######## CONFIG 10/10 ########
# Parameters: {'min_samples_leaf': 40, 'max_leaf_nodes': 31, 'max_iter': 600, 'max_depth': 15, 'learning_rate': 0.05, 'l2_regularization': 1}
#
# [C10|F1] Processing fold...
#   > Features Used (16): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'previousOwners', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9534 | RMSE: 2108 | MAE: 1300 | Bias: 5.1
#   > [VAL]   R2: 0.9527 | RMSE: 2068 | MAE: 1362 | Bias: -32.9
#
# [C10|F2] Processing fold...
#   > [TRAIN] R2: 0.9566 | RMSE: 2029 | MAE: 1305 | Bias: 1.0
#   > [VAL]   R2: 0.9455 | RMSE: 2262 | MAE: 1407 | Bias: -34.7
#
# [C10|F3] Processing fold...
#   > [TRAIN] R2: 0.9555 | RMSE: 2055 | MAE: 1295 | Bias: 2.1
#   > [VAL]   R2: 0.9430 | RMSE: 2313 | MAE: 1393 | Bias: 44.7
#
# [C10|F4] Processing fold...
#   > [TRAIN] R2: 0.9589 | RMSE: 1962 | MAE: 1294 | Bias: -1.2
#   > [VAL]   R2: 0.9295 | RMSE: 2692 | MAE: 1416 | Bias: 18.8
#
# [C10|F5] Processing fold...
#   > [TRAIN] R2: 0.9562 | RMSE: 2036 | MAE: 1309 | Bias: -5.6
#   > [VAL]   R2: 0.9501 | RMSE: 2191 | MAE: 1380 | Bias: -11.2
#
# [C10|F6] Processing fold...
#   > [TRAIN] R2: 0.9560 | RMSE: 2041 | MAE: 1306 | Bias: 2.4
#   > [VAL]   R2: 0.9471 | RMSE: 2258 | MAE: 1375 | Bias: 29.5
#
# [C10|F7] Processing fold...
#   > [TRAIN] R2: 0.9562 | RMSE: 2037 | MAE: 1305 | Bias: 4.6
#   > [VAL]   R2: 0.9515 | RMSE: 2142 | MAE: 1367 | Bias: 23.7
#
# [C10|F8] Processing fold...
#   > [TRAIN] R2: 0.9566 | RMSE: 2036 | MAE: 1312 | Bias: 1.7
#   > [VAL]   R2: 0.9493 | RMSE: 2138 | MAE: 1360 | Bias: -20.4
#
# Config 10 SUMMARY:
#   [TRAIN AVG] MAE: 1303.4 | R2: 0.9562 | Bias: 1.3
#   [VAL AVG]   MAE: 1382.7 | R2: 0.9461 | Bias: 2.2 | RMSE: 2258.0
# # END OF SEARCH
#
# Top 5 Configurations by RMSE:
#    config_id  learning_rate  max_iter     val_rmse      val_mae    val_r2  \
# 7          8           0.10       600  2125.233451  1275.983400  0.952201
# 3          4           0.15      1000  2141.241796  1285.491288  0.951461
# 0          1           0.05      1000  2149.155596  1300.537692  0.951116
# 1          2           0.15       600  2173.992172  1332.511138  0.949999
# 8          9           0.15      1000  2178.584487  1329.102007  0.949742
#
#    train_r2  val_bias
# 7  0.971785  4.737378
# 3  0.971734  4.125591
# 0  0.966733  3.805484
# 1  0.963367  3.648160
# 8  0.962944  1.478192
# Best Config found:
# {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 600, 'max_depth': 20, 'learning_rate': 0.1, 'l2_regularization': 0}

# %% [markdown]
# ### 3.2. Feature Ablation: Excluding `previousOwners` <a id="noprevown"></a>

# %% [markdown]
# - As previously stated, we observed some inconsistencies in the values of this column.
# - To assess its impact, we ran an ablation experiment by removing this feature.

# %%
numeric_features = ['year', 'mileage', 'engineSize', 'tax', 'mpg'] # we removed previousOwners feature from here

# shuffles the data, in order to (at least theoretically) have more balanced folds
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# we remove previousOwners from the features used by the model
# by doing this, we ensure it won't be in X_train/_val
DROP_FROM_MODEL = ["previousOwners"]

# hyperparameter space that we are going to use for random search
# each configuration will get 1 value from each of these lists
param_distributions = {
    "loss": ["squared_error", "absolute_error"], # loss function used for boosting
    "learning_rate": [0.07, 0.085, 0.1, 0.115], # shrinkage factor (for the leaves values) 
    "max_iter": [600, 800, 1000, 1200], # max number of trees 
    "max_leaf_nodes": [63, 127, 191, 255], # max number of leaves for each tree
    "l2_regularization": [0.3, 1.0, 3.0], # regularization (penalization) factor for small hessian values leaves  
    "min_samples_leaf": [12, 16, 20, 28], # min number of samples for each leaf
    "max_depth": [15, 20, 25, None], # max depth of each tree
}

N_RANDOM_CONFIGS = 15  # short random search, enough for baseline results

# we get N_RANDOM_CONFIGS (15) random parameter combinations from param_distributions
sampler = ParameterSampler(param_distributions, n_iter=N_RANDOM_CONFIGS, random_state=RANDOM_STATE)

search_results = [] # to store results of each configuration, to store the ranking

# tracking the best configuration according to validation RMSE
best_rmse = np.inf
best_config = None

# to store our fold results
log_dir = "gb_logs" # directory to save log files that is not present in this final version but was useful during development
os.makedirs(log_dir, exist_ok=True) # creates the log directory if it doesn't exist
log_filename = "2gb_noowners_nof_log.txt"
log_path = os.path.join(log_dir, log_filename)
# Note: this section was mainly for organization purposes and is not particularly relevant 

with open(log_path, "w", encoding="utf-8") as log_file:

    # this function allows printing the messages to the screen and to the log file 
    def log(msg: str):
        print(msg)
        log_file.write(msg + "\n")
        log_file.flush()

    # header for the log file - just for readability and general info
    log("# =============================")
    log("# START OF HGB SEARCH (DETAILED METRICS: R2, RMSE, MAE, BIAS)")
    log(f"# LOG FILE SAVED TO: {log_path}")
    log("# =============================")

    # loop that iterates over each random configuration
    for config_id, params in enumerate(sampler, start=1):
        log("")
        log(f"######## CONFIG {config_id}/{N_RANDOM_CONFIGS} ########")
        log(f"Parameters: {params}")

        # we are storing the metrics for each fold here
        fold_rmses_val, fold_maes_val, fold_r2s_val, fold_bias_val = [], [], [], []
        fold_rmses_tr,  fold_maes_tr,  fold_r2s_tr,  fold_bias_tr  = [], [], [], []
        fold_med_ae = []

        # for each configuration, we do K-Fold cross-validation
        for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):

            # data split for the current fold
            X_train, X_val = X.iloc[train_idx].copy(), X.iloc[val_idx].copy()
            y_train, y_val = y.iloc[train_idx].copy(), y.iloc[val_idx].copy()

            log(f"\n[C{config_id}|F{fold}] Processing fold...")

            # -> Preprocessing Steps 
            # fit is only done with the training data 
            # we aplly the transformations (some obtained through fit) to both train and validation sets
            # all preprocessing functions are explained before, here we just apply them in order
            year_state = fit_year_median(X_train, year_col="year", model_col="model")
            X_train = transform_year_with_model_median(X_train, state=year_state)
            X_val   = transform_year_with_model_median(X_val,   state=year_state)

            mileage_state = fit_mileage_imputer(X_train, mileage_col="mileage", do_abs=True)
            X_train = transform_mileage_imputer(X_train, state=mileage_state)
            X_val   = transform_mileage_imputer(X_val,   state=mileage_state)

            engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
            X_train = transform_engine_size_imputer(X_train, state=engine_state)
            X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

            X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
            X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

            mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
            X_train = transform_mpg_imputer(X_train, state=mpg_state)
            X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

            brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
            X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
            X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

            model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
            X_train, _, _ = transform_invalid_models(X_train, model_state)
            X_val,   _, _ = transform_invalid_models(X_val,   model_state)

            transm_state = fit_transmission_resolver(X_train, valid_transmissions)
            X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
            X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

            fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
            X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
            X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

            # ensures previousOwners is not used by the model 
            X_train = X_train.drop(columns=DROP_FROM_MODEL, errors="ignore")
            X_val   = X_val.drop(columns=DROP_FROM_MODEL, errors="ignore")

            # -> Feature Encoding
            # applied to categorical features only
            # we separate high cardinality and low cardinality categorical features
            high_card_features = ["Brand", "model"]  # target encoding for these
            low_card_features  = [c for c in categorical_features if c not in high_card_features]

            te = MyTargetEncoder(smoothing=5)
            te.fit(X_train[high_card_features], y_train)  # fit on training fold only
            X_train_high = te.transform(X_train[high_card_features])
            X_val_high   = te.transform(X_val[high_card_features])

            ohe = MyOneHotEncoder()
            ohe.fit(X_train[low_card_features])  # fit on training fold only
            X_train_low = ohe.transform(X_train[low_card_features])
            X_val_low   = ohe.transform(X_val[low_card_features])

            # rejoining the categorical features (that are now encoded)
            X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
            X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

            # joining numerical and categorical (encoded) features 
            X_train_final = pd.concat([X_train[numeric_features], X_train_cat], axis=1)
            X_val_final   = pd.concat([X_val[numeric_features],   X_val_cat],   axis=1)

            # here, we log the features name, to keep track of what is being used from the original set
            # but also because the columns increase due to encoding
            if fold == 1:
                feature_names = list(X_train_final.columns)
                log(f"  > Features Used ({len(feature_names)}): {feature_names}")

            # -> Model training
            # params contains the hyperparameters for this configuration
            hgb_model = HistGradientBoostingRegressor(random_state=RANDOM_STATE, **params)
            hgb_model.fit(X_train_final, y_train)

            # predictions on train and validation fold
            y_pred_train = hgb_model.predict(X_train_final)
            y_pred_val   = hgb_model.predict(X_val_final)

            # -> Metrics calculation
            # Training metrics:
            mae_tr  = mean_absolute_error(y_train, y_pred_train)
            rmse_tr = np.sqrt(mean_squared_error(y_train, y_pred_train))
            r2_tr   = r2_score(y_train, y_pred_train)
            bias_tr = np.mean(y_train - y_pred_train)
            # Validation metrics:
            mae_val  = mean_absolute_error(y_val, y_pred_val)
            rmse_val = np.sqrt(mean_squared_error(y_val, y_pred_val))
            r2_val   = r2_score(y_val, y_pred_val)
            bias_val = np.mean(y_val - y_pred_val)
            med_ae_val = median_absolute_error(y_val, y_pred_val)

            # logging the metrics of this fold
            log(f"  > [TRAIN] R2: {r2_tr:.4f} | RMSE: {rmse_tr:.0f} | MAE: {mae_tr:.0f} | Bias: {bias_tr:.1f}")
            log(f"  > [VAL]   R2: {r2_val:.4f} | RMSE: {rmse_val:.0f} | MAE: {mae_val:.0f} | Bias: {bias_val:.1f}")

            # storing the metrics of this fold
            fold_maes_tr.append(mae_tr);   fold_rmses_tr.append(rmse_tr);   fold_r2s_tr.append(r2_tr);   fold_bias_tr.append(bias_tr)
            fold_maes_val.append(mae_val); fold_rmses_val.append(rmse_val); fold_r2s_val.append(r2_val); fold_bias_val.append(bias_val)
            fold_med_ae.append(med_ae_val)

        # after all folds, we calculate the mean metrics across them
        mean_rmse_val = np.mean(fold_rmses_val)
        mean_mae_val  = np.mean(fold_maes_val)
        mean_r2_val   = np.mean(fold_r2s_val)
        mean_bias_val = np.mean(fold_bias_val)

        mean_mae_tr   = np.mean(fold_maes_tr)
        mean_r2_tr    = np.mean(fold_r2s_tr)
        mean_bias_tr  = np.mean(fold_bias_tr)

        # logging and storing these results
        log("")
        log(f"Config {config_id} SUMMARY:")
        log(f"  [TRAIN AVG] MAE: {mean_mae_tr:.1f} | R2: {mean_r2_tr:.4f} | Bias: {mean_bias_tr:.1f}")
        log(f"  [VAL AVG]   MAE: {mean_mae_val:.1f} | R2: {mean_r2_val:.4f} | Bias: {mean_bias_val:.1f} | RMSE: {mean_rmse_val:.1f}")

        search_results.append({
            "config_id": config_id,
            **params,

            "val_rmse": mean_rmse_val,
            "val_mae": mean_mae_val,
            "val_r2": mean_r2_val,
            "val_bias": mean_bias_val,

            "train_mae": mean_mae_tr,
            "train_r2": mean_r2_tr,
            "train_bias": mean_bias_tr,

            "val_med_ae": np.mean(fold_med_ae)
        })

        # our best configuration is defined by the best rmse
        # by best, we mean the lowest rmse
        if mean_rmse_val < best_rmse:
            best_rmse = mean_rmse_val
            best_config = {**params}
            log(f"[NEW BEST RMSE] Config {config_id}")

    log("# END OF SEARCH")

# Results
results_df = pd.DataFrame(search_results)
results_df_sorted = results_df.sort_values(by="val_rmse", ascending=True)

print("\nTop 5 Configurations by RMSE:")
cols = ["config_id", "learning_rate", "max_iter", "val_rmse", "val_mae", "val_r2", "train_r2", "val_bias"]
display(results_df_sorted[cols].head(5))

print("\nBest Config found:")
print(best_config)
# Out:
# # =============================
# # START OF HGB SEARCH (DETAILED METRICS: R2, RMSE, MAE, BIAS)
# # LOG FILE SAVED TO: gb_logs/2gb_noowners_nof_log.txt
# # =============================
#
# ######## CONFIG 1/15 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 255, 'max_iter': 800, 'max_depth': 20, 'loss': 'absolute_error', 'learning_rate': 0.085, 'l2_regularization': 0.3}
#
# [C1|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9626 | RMSE: 1890 | MAE: 944 | Bias: 127.2
#   > [VAL]   R2: 0.9577 | RMSE: 1956 | MAE: 1234 | Bias: 81.4
#
# [C1|F2] Processing fold...
#   > [TRAIN] R2: 0.9652 | RMSE: 1819 | MAE: 947 | Bias: 117.9
#   > [VAL]   R2: 0.9543 | RMSE: 2072 | MAE: 1243 | Bias: 89.8
#
# [C1|F3] Processing fold...
#   > [TRAIN] R2: 0.9664 | RMSE: 1786 | MAE: 905 | Bias: 115.6
#   > [VAL]   R2: 0.9440 | RMSE: 2294 | MAE: 1252 | Bias: 156.9
#
# [C1|F4] Processing fold...
#   > [TRAIN] R2: 0.9688 | RMSE: 1709 | MAE: 920 | Bias: 108.6
#   > [VAL]   R2: 0.9344 | RMSE: 2595 | MAE: 1269 | Bias: 148.3
#
# [C1|F5] Processing fold...
#   > [TRAIN] R2: 0.9649 | RMSE: 1823 | MAE: 948 | Bias: 109.9
#   > [VAL]   R2: 0.9521 | RMSE: 2148 | MAE: 1248 | Bias: 110.9
#
# [C1|F6] Processing fold...
#   > [TRAIN] R2: 0.9664 | RMSE: 1782 | MAE: 924 | Bias: 111.1
#   > [VAL]   R2: 0.9469 | RMSE: 2263 | MAE: 1241 | Bias: 138.0
#
# [C1|F7] Processing fold...
#   > [TRAIN] R2: 0.9604 | RMSE: 1937 | MAE: 997 | Bias: 129.9
#   > [VAL]   R2: 0.9564 | RMSE: 2031 | MAE: 1221 | Bias: 135.1
#
# [C1|F8] Processing fold...
#   > [TRAIN] R2: 0.9645 | RMSE: 1840 | MAE: 944 | Bias: 121.6
#   > [VAL]   R2: 0.9560 | RMSE: 1992 | MAE: 1205 | Bias: 95.9
#
# Config 1 SUMMARY:
#   [TRAIN AVG] MAE: 941.1 | R2: 0.9649 | Bias: 117.7
#   [VAL AVG]   MAE: 1239.2 | R2: 0.9502 | Bias: 119.5 | RMSE: 2168.8
# [NEW BEST RMSE] Config 1
#
# ######## CONFIG 2/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 255, 'max_iter': 600, 'max_depth': 15, 'loss': 'absolute_error', 'learning_rate': 0.1, 'l2_regularization': 3.0}
#
# [C2|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9613 | RMSE: 1921 | MAE: 971 | Bias: 122.3
#   > [VAL]   R2: 0.9578 | RMSE: 1954 | MAE: 1235 | Bias: 71.3
#
# [C2|F2] Processing fold...
#   > [TRAIN] R2: 0.9627 | RMSE: 1882 | MAE: 987 | Bias: 122.3
#   > [VAL]   R2: 0.9511 | RMSE: 2141 | MAE: 1265 | Bias: 106.1
#
# [C2|F3] Processing fold...
#   > [TRAIN] R2: 0.9599 | RMSE: 1951 | MAE: 1019 | Bias: 127.9
#   > [VAL]   R2: 0.9404 | RMSE: 2365 | MAE: 1277 | Bias: 170.9
#
# [C2|F4] Processing fold...
#   > [TRAIN] R2: 0.9652 | RMSE: 1806 | MAE: 972 | Bias: 116.1
#   > [VAL]   R2: 0.9336 | RMSE: 2611 | MAE: 1285 | Bias: 156.1
#
# [C2|F5] Processing fold...
#   > [TRAIN] R2: 0.9619 | RMSE: 1900 | MAE: 994 | Bias: 118.2
#   > [VAL]   R2: 0.9505 | RMSE: 2182 | MAE: 1258 | Bias: 119.4
#
# [C2|F6] Processing fold...
#   > [TRAIN] R2: 0.9591 | RMSE: 1968 | MAE: 1056 | Bias: 130.0
#   > [VAL]   R2: 0.9436 | RMSE: 2332 | MAE: 1255 | Bias: 160.2
#
# [C2|F7] Processing fold...
#   > [TRAIN] R2: 0.9587 | RMSE: 1979 | MAE: 1013 | Bias: 135.8
#   > [VAL]   R2: 0.9545 | RMSE: 2074 | MAE: 1228 | Bias: 154.0
#
# [C2|F8] Processing fold...
#   > [TRAIN] R2: 0.9603 | RMSE: 1948 | MAE: 1009 | Bias: 130.9
#   > [VAL]   R2: 0.9556 | RMSE: 2001 | MAE: 1217 | Bias: 96.8
#
# Config 2 SUMMARY:
#   [TRAIN AVG] MAE: 1002.6 | R2: 0.9611 | Bias: 125.4
#   [VAL AVG]   MAE: 1252.5 | R2: 0.9484 | Bias: 129.3 | RMSE: 2207.3
#
# ######## CONFIG 3/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 3.0}
#
# [C3|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9697 | RMSE: 1700 | MAE: 1022 | Bias: 6.5
#   > [VAL]   R2: 0.9589 | RMSE: 1928 | MAE: 1246 | Bias: -47.0
#
# [C3|F2] Processing fold...
#   > [TRAIN] R2: 0.9749 | RMSE: 1543 | MAE: 993 | Bias: 1.1
#   > [VAL]   R2: 0.9522 | RMSE: 2119 | MAE: 1268 | Bias: -7.7
#
# [C3|F3] Processing fold...
#   > [TRAIN] R2: 0.9722 | RMSE: 1624 | MAE: 1019 | Bias: 3.2
#   > [VAL]   R2: 0.9520 | RMSE: 2123 | MAE: 1276 | Bias: 29.6
#
# [C3|F4] Processing fold...
#   > [TRAIN] R2: 0.9752 | RMSE: 1524 | MAE: 1014 | Bias: 0.2
#   > [VAL]   R2: 0.9357 | RMSE: 2571 | MAE: 1300 | Bias: 27.2
#
# [C3|F5] Processing fold...
#   > [TRAIN] R2: 0.9753 | RMSE: 1528 | MAE: 988 | Bias: -4.1
#   > [VAL]   R2: 0.9573 | RMSE: 2026 | MAE: 1252 | Bias: 7.8
#
# [C3|F6] Processing fold...
#   > [TRAIN] R2: 0.9710 | RMSE: 1655 | MAE: 1056 | Bias: 0.0
#   > [VAL]   R2: 0.9566 | RMSE: 2045 | MAE: 1249 | Bias: 7.7
#
# [C3|F7] Processing fold...
#   > [TRAIN] R2: 0.9755 | RMSE: 1525 | MAE: 982 | Bias: 2.3
#   > [VAL]   R2: 0.9585 | RMSE: 1982 | MAE: 1223 | Bias: 25.1
#
# [C3|F8] Processing fold...
#   > [TRAIN] R2: 0.9735 | RMSE: 1591 | MAE: 1027 | Bias: 2.5
#   > [VAL]   R2: 0.9556 | RMSE: 2002 | MAE: 1230 | Bias: -7.7
#
# Config 3 SUMMARY:
#   [TRAIN AVG] MAE: 1012.5 | R2: 0.9734 | Bias: 1.5
#   [VAL AVG]   MAE: 1255.5 | R2: 0.9533 | Bias: 4.4 | RMSE: 2099.5
# [NEW BEST RMSE] Config 3
#
# ######## CONFIG 4/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 600, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 3.0}
#
# [C4|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9654 | RMSE: 1818 | MAE: 1096 | Bias: 6.2
#   > [VAL]   R2: 0.9576 | RMSE: 1959 | MAE: 1265 | Bias: -44.8
#
# [C4|F2] Processing fold...
#   > [TRAIN] R2: 0.9693 | RMSE: 1706 | MAE: 1088 | Bias: 1.6
#   > [VAL]   R2: 0.9513 | RMSE: 2138 | MAE: 1294 | Bias: -15.9
#
# [C4|F3] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1692 | MAE: 1063 | Bias: 2.7
#   > [VAL]   R2: 0.9531 | RMSE: 2098 | MAE: 1277 | Bias: 29.6
#
# [C4|F4] Processing fold...
#   > [TRAIN] R2: 0.9709 | RMSE: 1650 | MAE: 1092 | Bias: 0.0
#   > [VAL]   R2: 0.9324 | RMSE: 2635 | MAE: 1323 | Bias: 26.6
#
# [C4|F5] Processing fold...
#   > [TRAIN] R2: 0.9744 | RMSE: 1556 | MAE: 1005 | Bias: -4.2
#   > [VAL]   R2: 0.9571 | RMSE: 2031 | MAE: 1255 | Bias: -2.2
#
# [C4|F6] Processing fold...
#   > [TRAIN] R2: 0.9721 | RMSE: 1626 | MAE: 1038 | Bias: 0.6
#   > [VAL]   R2: 0.9574 | RMSE: 2025 | MAE: 1239 | Bias: 7.1
#
# [C4|F7] Processing fold...
#   > [TRAIN] R2: 0.9727 | RMSE: 1608 | MAE: 1027 | Bias: 2.5
#   > [VAL]   R2: 0.9582 | RMSE: 1988 | MAE: 1233 | Bias: 31.0
#
# [C4|F8] Processing fold...
#   > [TRAIN] R2: 0.9696 | RMSE: 1705 | MAE: 1093 | Bias: 1.7
#   > [VAL]   R2: 0.9554 | RMSE: 2006 | MAE: 1241 | Bias: -14.5
#
# Config 4 SUMMARY:
#   [TRAIN AVG] MAE: 1062.8 | R2: 0.9705 | Bias: 1.4
#   [VAL AVG]   MAE: 1265.9 | R2: 0.9528 | Bias: 2.1 | RMSE: 2110.1
#
# ######## CONFIG 5/15 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 255, 'max_iter': 1200, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 1.0}
#
# [C5|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9698 | RMSE: 1696 | MAE: 1032 | Bias: 6.5
#   > [VAL]   R2: 0.9574 | RMSE: 1963 | MAE: 1255 | Bias: -37.1
#
# [C5|F2] Processing fold...
#   > [TRAIN] R2: 0.9742 | RMSE: 1566 | MAE: 1020 | Bias: 1.7
#   > [VAL]   R2: 0.9524 | RMSE: 2114 | MAE: 1280 | Bias: -5.7
#
# [C5|F3] Processing fold...
#   > [TRAIN] R2: 0.9785 | RMSE: 1429 | MAE: 894 | Bias: 2.9
#   > [VAL]   R2: 0.9532 | RMSE: 2097 | MAE: 1265 | Bias: 21.3
#
# [C5|F4] Processing fold...
#   > [TRAIN] R2: 0.9774 | RMSE: 1456 | MAE: 975 | Bias: -0.1
#   > [VAL]   R2: 0.9342 | RMSE: 2601 | MAE: 1298 | Bias: 26.5
#
# [C5|F5] Processing fold...
#   > [TRAIN] R2: 0.9764 | RMSE: 1496 | MAE: 977 | Bias: -4.4
#   > [VAL]   R2: 0.9569 | RMSE: 2035 | MAE: 1257 | Bias: -11.0
#
# [C5|F6] Processing fold...
#   > [TRAIN] R2: 0.9772 | RMSE: 1467 | MAE: 941 | Bias: 0.1
#   > [VAL]   R2: 0.9586 | RMSE: 1998 | MAE: 1238 | Bias: 16.6
#
# [C5|F7] Processing fold...
#   > [TRAIN] R2: 0.9785 | RMSE: 1429 | MAE: 926 | Bias: 3.4
#   > [VAL]   R2: 0.9565 | RMSE: 2028 | MAE: 1230 | Bias: 24.2
#
# [C5|F8] Processing fold...
#   > [TRAIN] R2: 0.9780 | RMSE: 1450 | MAE: 952 | Bias: 2.9
#   > [VAL]   R2: 0.9557 | RMSE: 1998 | MAE: 1223 | Bias: -12.3
#
# Config 5 SUMMARY:
#   [TRAIN AVG] MAE: 964.6 | R2: 0.9762 | Bias: 1.6
#   [VAL AVG]   MAE: 1255.8 | R2: 0.9531 | Bias: 2.8 | RMSE: 2104.2
#
# ######## CONFIG 6/15 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C6|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9665 | RMSE: 1787 | MAE: 1092 | Bias: 5.1
#   > [VAL]   R2: 0.9575 | RMSE: 1960 | MAE: 1265 | Bias: -33.3
#
# [C6|F2] Processing fold...
#   > [TRAIN] R2: 0.9753 | RMSE: 1532 | MAE: 1000 | Bias: 1.6
#   > [VAL]   R2: 0.9538 | RMSE: 2082 | MAE: 1273 | Bias: -5.9
#
# [C6|F3] Processing fold...
#   > [TRAIN] R2: 0.9695 | RMSE: 1702 | MAE: 1082 | Bias: 2.8
#   > [VAL]   R2: 0.9522 | RMSE: 2118 | MAE: 1298 | Bias: 32.2
#
# [C6|F4] Processing fold...
#   > [TRAIN] R2: 0.9719 | RMSE: 1623 | MAE: 1089 | Bias: -0.4
#   > [VAL]   R2: 0.9322 | RMSE: 2639 | MAE: 1323 | Bias: 16.1
#
# [C6|F5] Processing fold...
#   > [TRAIN] R2: 0.9742 | RMSE: 1564 | MAE: 1023 | Bias: -4.8
#   > [VAL]   R2: 0.9577 | RMSE: 2018 | MAE: 1258 | Bias: -4.9
#
# [C6|F6] Processing fold...
#   > [TRAIN] R2: 0.9723 | RMSE: 1617 | MAE: 1048 | Bias: 0.7
#   > [VAL]   R2: 0.9582 | RMSE: 2006 | MAE: 1253 | Bias: 12.3
#
# [C6|F7] Processing fold...
#   > [TRAIN] R2: 0.9755 | RMSE: 1523 | MAE: 991 | Bias: 3.1
#   > [VAL]   R2: 0.9584 | RMSE: 1984 | MAE: 1229 | Bias: 31.6
#
# [C6|F8] Processing fold...
#   > [TRAIN] R2: 0.9749 | RMSE: 1547 | MAE: 1014 | Bias: 2.9
#   > [VAL]   R2: 0.9553 | RMSE: 2009 | MAE: 1230 | Bias: -15.8
#
# Config 6 SUMMARY:
#   [TRAIN AVG] MAE: 1042.3 | R2: 0.9725 | Bias: 1.4
#   [VAL AVG]   MAE: 1266.0 | R2: 0.9532 | Bias: 4.0 | RMSE: 2102.1
#
# ######## CONFIG 7/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 3.0}
#
# [C7|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9645 | RMSE: 1840 | MAE: 1112 | Bias: 7.1
#   > [VAL]   R2: 0.9580 | RMSE: 1949 | MAE: 1272 | Bias: -46.6
#
# [C7|F2] Processing fold...
#   > [TRAIN] R2: 0.9713 | RMSE: 1651 | MAE: 1066 | Bias: 1.8
#   > [VAL]   R2: 0.9514 | RMSE: 2135 | MAE: 1284 | Bias: -8.2
#
# [C7|F3] Processing fold...
#   > [TRAIN] R2: 0.9686 | RMSE: 1726 | MAE: 1087 | Bias: 4.4
#   > [VAL]   R2: 0.9522 | RMSE: 2119 | MAE: 1290 | Bias: 28.7
#
# [C7|F4] Processing fold...
#   > [TRAIN] R2: 0.9758 | RMSE: 1506 | MAE: 1006 | Bias: -0.7
#   > [VAL]   R2: 0.9355 | RMSE: 2574 | MAE: 1292 | Bias: 28.2
#
# [C7|F5] Processing fold...
#   > [TRAIN] R2: 0.9743 | RMSE: 1560 | MAE: 1012 | Bias: -4.8
#   > [VAL]   R2: 0.9573 | RMSE: 2028 | MAE: 1254 | Bias: -4.2
#
# [C7|F6] Processing fold...
#   > [TRAIN] R2: 0.9715 | RMSE: 1643 | MAE: 1055 | Bias: 0.2
#   > [VAL]   R2: 0.9580 | RMSE: 2012 | MAE: 1247 | Bias: 13.6
#
# [C7|F7] Processing fold...
#   > [TRAIN] R2: 0.9739 | RMSE: 1573 | MAE: 1015 | Bias: 2.4
#   > [VAL]   R2: 0.9577 | RMSE: 2001 | MAE: 1238 | Bias: 26.6
#
# [C7|F8] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1696 | MAE: 1103 | Bias: 2.2
#   > [VAL]   R2: 0.9554 | RMSE: 2006 | MAE: 1253 | Bias: -15.6
#
# Config 7 SUMMARY:
#   [TRAIN AVG] MAE: 1057.0 | R2: 0.9712 | Bias: 1.6
#   [VAL AVG]   MAE: 1266.1 | R2: 0.9532 | Bias: 2.8 | RMSE: 2103.1
#
# ######## CONFIG 8/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 800, 'max_depth': None, 'loss': 'absolute_error', 'learning_rate': 0.07, 'l2_regularization': 0.3}
#
# [C8|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9557 | RMSE: 2056 | MAE: 1094 | Bias: 133.3
#   > [VAL]   R2: 0.9560 | RMSE: 1996 | MAE: 1265 | Bias: 98.7
#
# [C8|F2] Processing fold...
#   > [TRAIN] R2: 0.9572 | RMSE: 2015 | MAE: 1091 | Bias: 133.5
#   > [VAL]   R2: 0.9514 | RMSE: 2136 | MAE: 1282 | Bias: 118.8
#
# [C8|F3] Processing fold...
#   > [TRAIN] R2: 0.9530 | RMSE: 2111 | MAE: 1162 | Bias: 141.1
#   > [VAL]   R2: 0.9379 | RMSE: 2416 | MAE: 1328 | Bias: 183.8
#
# [C8|F4] Processing fold...
#   > [TRAIN] R2: 0.9590 | RMSE: 1959 | MAE: 1100 | Bias: 131.3
#   > [VAL]   R2: 0.9306 | RMSE: 2671 | MAE: 1312 | Bias: 161.6
#
# [C8|F5] Processing fold...
#   > [TRAIN] R2: 0.9565 | RMSE: 2030 | MAE: 1098 | Bias: 130.1
#   > [VAL]   R2: 0.9497 | RMSE: 2199 | MAE: 1275 | Bias: 121.5
#
# [C8|F6] Processing fold...
#   > [TRAIN] R2: 0.9561 | RMSE: 2038 | MAE: 1120 | Bias: 135.1
#   > [VAL]   R2: 0.9423 | RMSE: 2359 | MAE: 1283 | Bias: 164.7
#
# [C8|F7] Processing fold...
#   > [TRAIN] R2: 0.9534 | RMSE: 2103 | MAE: 1140 | Bias: 143.4
#   > [VAL]   R2: 0.9519 | RMSE: 2134 | MAE: 1279 | Bias: 166.7
#
# [C8|F8] Processing fold...
#   > [TRAIN] R2: 0.9566 | RMSE: 2035 | MAE: 1101 | Bias: 130.2
#   > [VAL]   R2: 0.9535 | RMSE: 2048 | MAE: 1247 | Bias: 95.9
#
# Config 8 SUMMARY:
#   [TRAIN AVG] MAE: 1113.2 | R2: 0.9559 | Bias: 134.7
#   [VAL AVG]   MAE: 1283.9 | R2: 0.9467 | Bias: 138.9 | RMSE: 2244.6
#
# ######## CONFIG 9/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 3.0}
#
# [C9|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9672 | RMSE: 1770 | MAE: 1068 | Bias: 6.3
#   > [VAL]   R2: 0.9587 | RMSE: 1934 | MAE: 1257 | Bias: -38.5
#
# [C9|F2] Processing fold...
#   > [TRAIN] R2: 0.9702 | RMSE: 1683 | MAE: 1086 | Bias: 1.8
#   > [VAL]   R2: 0.9514 | RMSE: 2135 | MAE: 1297 | Bias: -12.2
#
# [C9|F3] Processing fold...
#   > [TRAIN] R2: 0.9701 | RMSE: 1683 | MAE: 1059 | Bias: 3.5
#   > [VAL]   R2: 0.9513 | RMSE: 2138 | MAE: 1293 | Bias: 31.3
#
# [C9|F4] Processing fold...
#   > [TRAIN] R2: 0.9737 | RMSE: 1570 | MAE: 1049 | Bias: -1.0
#   > [VAL]   R2: 0.9350 | RMSE: 2584 | MAE: 1309 | Bias: 28.6
#
# [C9|F5] Processing fold...
#   > [TRAIN] R2: 0.9732 | RMSE: 1592 | MAE: 1031 | Bias: -4.2
#   > [VAL]   R2: 0.9574 | RMSE: 2023 | MAE: 1258 | Bias: 5.3
#
# [C9|F6] Processing fold...
#   > [TRAIN] R2: 0.9732 | RMSE: 1591 | MAE: 1020 | Bias: -0.2
#   > [VAL]   R2: 0.9586 | RMSE: 1997 | MAE: 1239 | Bias: 7.8
#
# [C9|F7] Processing fold...
#   > [TRAIN] R2: 0.9732 | RMSE: 1594 | MAE: 1029 | Bias: 2.3
#   > [VAL]   R2: 0.9577 | RMSE: 2000 | MAE: 1236 | Bias: 31.5
#
# [C9|F8] Processing fold...
#   > [TRAIN] R2: 0.9728 | RMSE: 1612 | MAE: 1046 | Bias: 3.2
#   > [VAL]   R2: 0.9560 | RMSE: 1992 | MAE: 1231 | Bias: -17.9
#
# Config 9 SUMMARY:
#   [TRAIN AVG] MAE: 1048.5 | R2: 0.9717 | Bias: 1.4
#   [VAL AVG]   MAE: 1264.8 | R2: 0.9533 | Bias: 4.5 | RMSE: 2100.5
#
# ######## CONFIG 10/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': 20, 'loss': 'absolute_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}
#
# [C10|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9586 | RMSE: 1987 | MAE: 1009 | Bias: 133.2
#   > [VAL]   R2: 0.9564 | RMSE: 1986 | MAE: 1246 | Bias: 88.3
#
# [C10|F2] Processing fold...
#   > [TRAIN] R2: 0.9615 | RMSE: 1912 | MAE: 987 | Bias: 126.9
#   > [VAL]   R2: 0.9517 | RMSE: 2128 | MAE: 1259 | Bias: 106.7
#
# [C10|F3] Processing fold...
#   > [TRAIN] R2: 0.9622 | RMSE: 1896 | MAE: 968 | Bias: 122.5
#   > [VAL]   R2: 0.9416 | RMSE: 2341 | MAE: 1257 | Bias: 171.6
#
# [C10|F4] Processing fold...
#   > [TRAIN] R2: 0.9652 | RMSE: 1804 | MAE: 961 | Bias: 117.3
#   > [VAL]   R2: 0.9330 | RMSE: 2624 | MAE: 1275 | Bias: 157.8
#
# [C10|F5] Processing fold...
#   > [TRAIN] R2: 0.9589 | RMSE: 1971 | MAE: 1035 | Bias: 127.1
#   > [VAL]   R2: 0.9511 | RMSE: 2169 | MAE: 1262 | Bias: 116.9
#
# [C10|F6] Processing fold...
#   > [TRAIN] R2: 0.9626 | RMSE: 1881 | MAE: 976 | Bias: 122.9
#   > [VAL]   R2: 0.9441 | RMSE: 2321 | MAE: 1242 | Bias: 149.4
#
# [C10|F7] Processing fold...
#   > [TRAIN] R2: 0.9600 | RMSE: 1947 | MAE: 981 | Bias: 127.5
#   > [VAL]   R2: 0.9559 | RMSE: 2042 | MAE: 1219 | Bias: 147.6
#
# [C10|F8] Processing fold...
#   > [TRAIN] R2: 0.9607 | RMSE: 1938 | MAE: 991 | Bias: 126.0
#   > [VAL]   R2: 0.9553 | RMSE: 2009 | MAE: 1214 | Bias: 95.2
#
# Config 10 SUMMARY:
#   [TRAIN AVG] MAE: 988.5 | R2: 0.9612 | Bias: 125.4
#   [VAL AVG]   MAE: 1246.8 | R2: 0.9486 | Bias: 129.2 | RMSE: 2202.5
#
# ######## CONFIG 11/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': None, 'loss': 'absolute_error', 'learning_rate': 0.1, 'l2_regularization': 3.0}
#
# [C11|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9612 | RMSE: 1925 | MAE: 970 | Bias: 121.7
#   > [VAL]   R2: 0.9570 | RMSE: 1973 | MAE: 1242 | Bias: 77.6
#
# [C11|F2] Processing fold...
#   > [TRAIN] R2: 0.9620 | RMSE: 1901 | MAE: 972 | Bias: 123.9
#   > [VAL]   R2: 0.9530 | RMSE: 2100 | MAE: 1254 | Bias: 105.9
#
# [C11|F3] Processing fold...
#   > [TRAIN] R2: 0.9625 | RMSE: 1886 | MAE: 954 | Bias: 123.9
#   > [VAL]   R2: 0.9406 | RMSE: 2362 | MAE: 1263 | Bias: 166.3
#
# [C11|F4] Processing fold...
#   > [TRAIN] R2: 0.9662 | RMSE: 1778 | MAE: 940 | Bias: 119.6
#   > [VAL]   R2: 0.9323 | RMSE: 2636 | MAE: 1277 | Bias: 155.4
#
# [C11|F5] Processing fold...
#   > [TRAIN] R2: 0.9630 | RMSE: 1871 | MAE: 963 | Bias: 114.0
#   > [VAL]   R2: 0.9517 | RMSE: 2156 | MAE: 1253 | Bias: 118.5
#
# [C11|F6] Processing fold...
#   > [TRAIN] R2: 0.9638 | RMSE: 1851 | MAE: 947 | Bias: 119.9
#   > [VAL]   R2: 0.9458 | RMSE: 2285 | MAE: 1239 | Bias: 145.1
#
# [C11|F7] Processing fold...
#   > [TRAIN] R2: 0.9593 | RMSE: 1964 | MAE: 998 | Bias: 126.1
#   > [VAL]   R2: 0.9541 | RMSE: 2085 | MAE: 1236 | Bias: 142.6
#
# [C11|F8] Processing fold...
#   > [TRAIN] R2: 0.9622 | RMSE: 1900 | MAE: 966 | Bias: 122.6
#   > [VAL]   R2: 0.9549 | RMSE: 2016 | MAE: 1216 | Bias: 93.3
#
# Config 11 SUMMARY:
#   [TRAIN AVG] MAE: 963.9 | R2: 0.9625 | Bias: 121.5
#   [VAL AVG]   MAE: 1247.6 | R2: 0.9487 | Bias: 125.6 | RMSE: 2201.6
#
# ######## CONFIG 12/15 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 127, 'max_iter': 1200, 'max_depth': 20, 'loss': 'absolute_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C12|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9607 | RMSE: 1935 | MAE: 1002 | Bias: 121.5
#   > [VAL]   R2: 0.9574 | RMSE: 1963 | MAE: 1248 | Bias: 69.8
#
# [C12|F2] Processing fold...
#   > [TRAIN] R2: 0.9612 | RMSE: 1919 | MAE: 1018 | Bias: 125.4
#   > [VAL]   R2: 0.9528 | RMSE: 2105 | MAE: 1266 | Bias: 106.4
#
# [C12|F3] Processing fold...
#   > [TRAIN] R2: 0.9627 | RMSE: 1882 | MAE: 988 | Bias: 124.2
#   > [VAL]   R2: 0.9420 | RMSE: 2334 | MAE: 1280 | Bias: 163.2
#
# [C12|F4] Processing fold...
#   > [TRAIN] R2: 0.9648 | RMSE: 1815 | MAE: 1009 | Bias: 119.9
#   > [VAL]   R2: 0.9321 | RMSE: 2641 | MAE: 1292 | Bias: 151.0
#
# [C12|F5] Processing fold...
#   > [TRAIN] R2: 0.9604 | RMSE: 1935 | MAE: 1043 | Bias: 122.4
#   > [VAL]   R2: 0.9486 | RMSE: 2224 | MAE: 1273 | Bias: 124.0
#
# [C12|F6] Processing fold...
#   > [TRAIN] R2: 0.9607 | RMSE: 1927 | MAE: 1055 | Bias: 130.7
#   > [VAL]   R2: 0.9468 | RMSE: 2265 | MAE: 1263 | Bias: 159.0
#
# [C12|F7] Processing fold...
#   > [TRAIN] R2: 0.9612 | RMSE: 1919 | MAE: 1011 | Bias: 128.8
#   > [VAL]   R2: 0.9566 | RMSE: 2026 | MAE: 1229 | Bias: 147.4
#
# [C12|F8] Processing fold...
#   > [TRAIN] R2: 0.9614 | RMSE: 1919 | MAE: 1016 | Bias: 123.8
#   > [VAL]   R2: 0.9549 | RMSE: 2018 | MAE: 1227 | Bias: 90.3
#
# Config 12 SUMMARY:
#   [TRAIN AVG] MAE: 1017.7 | R2: 0.9617 | Bias: 124.6
#   [VAL AVG]   MAE: 1259.9 | R2: 0.9489 | Bias: 126.4 | RMSE: 2196.8
#
# ######## CONFIG 13/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 63, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C13|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9638 | RMSE: 1859 | MAE: 1135 | Bias: 5.7
#   > [VAL]   R2: 0.9583 | RMSE: 1942 | MAE: 1272 | Bias: -32.8
#
# [C13|F2] Processing fold...
#   > [TRAIN] R2: 0.9652 | RMSE: 1818 | MAE: 1172 | Bias: 0.1
#   > [VAL]   R2: 0.9487 | RMSE: 2194 | MAE: 1326 | Bias: -25.3
#
# [C13|F3] Processing fold...
#   > [TRAIN] R2: 0.9675 | RMSE: 1757 | MAE: 1110 | Bias: 2.6
#   > [VAL]   R2: 0.9529 | RMSE: 2104 | MAE: 1302 | Bias: 33.4
#
# [C13|F4] Processing fold...
#   > [TRAIN] R2: 0.9721 | RMSE: 1618 | MAE: 1084 | Bias: -0.5
#   > [VAL]   R2: 0.9357 | RMSE: 2571 | MAE: 1313 | Bias: 20.6
#
# [C13|F5] Processing fold...
#   > [TRAIN] R2: 0.9684 | RMSE: 1728 | MAE: 1120 | Bias: -4.9
#   > [VAL]   R2: 0.9561 | RMSE: 2055 | MAE: 1283 | Bias: -10.7
#
# [C13|F6] Processing fold...
#   > [TRAIN] R2: 0.9669 | RMSE: 1770 | MAE: 1139 | Bias: 1.5
#   > [VAL]   R2: 0.9567 | RMSE: 2044 | MAE: 1270 | Bias: 14.8
#
# [C13|F7] Processing fold...
#   > [TRAIN] R2: 0.9717 | RMSE: 1639 | MAE: 1060 | Bias: 2.5
#   > [VAL]   R2: 0.9587 | RMSE: 1977 | MAE: 1241 | Bias: 27.2
#
# [C13|F8] Processing fold...
#   > [TRAIN] R2: 0.9695 | RMSE: 1708 | MAE: 1110 | Bias: 2.7
#   > [VAL]   R2: 0.9557 | RMSE: 2000 | MAE: 1245 | Bias: -12.9
#
# Config 13 SUMMARY:
#   [TRAIN AVG] MAE: 1116.4 | R2: 0.9681 | Bias: 1.2
#   [VAL AVG]   MAE: 1281.4 | R2: 0.9528 | Bias: 1.8 | RMSE: 2110.8
#
# ######## CONFIG 14/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 20, 'loss': 'absolute_error', 'learning_rate': 0.085, 'l2_regularization': 1.0}
#
# [C14|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9584 | RMSE: 1992 | MAE: 998 | Bias: 129.1
#   > [VAL]   R2: 0.9575 | RMSE: 1962 | MAE: 1233 | Bias: 76.2
#
# [C14|F2] Processing fold...
#   > [TRAIN] R2: 0.9585 | RMSE: 1984 | MAE: 1035 | Bias: 127.5
#   > [VAL]   R2: 0.9512 | RMSE: 2141 | MAE: 1272 | Bias: 106.7
#
# [C14|F3] Processing fold...
#   > [TRAIN] R2: 0.9574 | RMSE: 2011 | MAE: 1054 | Bias: 132.7
#   > [VAL]   R2: 0.9397 | RMSE: 2380 | MAE: 1280 | Bias: 168.7
#
# [C14|F4] Processing fold...
#   > [TRAIN] R2: 0.9626 | RMSE: 1872 | MAE: 1004 | Bias: 121.2
#   > [VAL]   R2: 0.9304 | RMSE: 2675 | MAE: 1288 | Bias: 154.0
#
# [C14|F5] Processing fold...
#   > [TRAIN] R2: 0.9607 | RMSE: 1928 | MAE: 995 | Bias: 119.1
#   > [VAL]   R2: 0.9503 | RMSE: 2187 | MAE: 1251 | Bias: 116.6
#
# [C14|F6] Processing fold...
#   > [TRAIN] R2: 0.9610 | RMSE: 1919 | MAE: 1003 | Bias: 124.5
#   > [VAL]   R2: 0.9457 | RMSE: 2287 | MAE: 1247 | Bias: 148.7
#
# [C14|F7] Processing fold...
#   > [TRAIN] R2: 0.9571 | RMSE: 2017 | MAE: 1023 | Bias: 133.4
#   > [VAL]   R2: 0.9532 | RMSE: 2105 | MAE: 1231 | Bias: 159.6
#
# [C14|F8] Processing fold...
#   > [TRAIN] R2: 0.9593 | RMSE: 1972 | MAE: 1019 | Bias: 125.4
#   > [VAL]   R2: 0.9549 | RMSE: 2018 | MAE: 1215 | Bias: 99.3
#
# Config 14 SUMMARY:
#   [TRAIN AVG] MAE: 1016.2 | R2: 0.9594 | Bias: 126.6
#   [VAL AVG]   MAE: 1252.2 | R2: 0.9478 | Bias: 128.7 | RMSE: 2219.2
#
# ######## CONFIG 15/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 600, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 0.3}
#
# [C15|F1] Processing fold...
#   > Features Used (15): ['year', 'mileage', 'engineSize', 'tax', 'mpg', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9598 | RMSE: 1959 | MAE: 1206 | Bias: 5.4
#   > [VAL]   R2: 0.9561 | RMSE: 1994 | MAE: 1308 | Bias: -36.8
#
# [C15|F2] Processing fold...
#   > [TRAIN] R2: 0.9694 | RMSE: 1705 | MAE: 1109 | Bias: 1.1
#   > [VAL]   R2: 0.9514 | RMSE: 2134 | MAE: 1300 | Bias: -19.3
#
# [C15|F3] Processing fold...
#   > [TRAIN] R2: 0.9671 | RMSE: 1767 | MAE: 1121 | Bias: 2.7
#   > [VAL]   R2: 0.9530 | RMSE: 2102 | MAE: 1293 | Bias: 21.7
#
# [C15|F4] Processing fold...
#   > [TRAIN] R2: 0.9681 | RMSE: 1729 | MAE: 1155 | Bias: -1.3
#   > [VAL]   R2: 0.9342 | RMSE: 2600 | MAE: 1339 | Bias: 15.9
#
# [C15|F5] Processing fold...
#   > [TRAIN] R2: 0.9698 | RMSE: 1692 | MAE: 1098 | Bias: -5.5
#   > [VAL]   R2: 0.9568 | RMSE: 2038 | MAE: 1271 | Bias: -7.1
#
# [C15|F6] Processing fold...
#   > [TRAIN] R2: 0.9668 | RMSE: 1773 | MAE: 1146 | Bias: 0.8
#   > [VAL]   R2: 0.9562 | RMSE: 2055 | MAE: 1277 | Bias: 16.3
#
# [C15|F7] Processing fold...
#   > [TRAIN] R2: 0.9697 | RMSE: 1695 | MAE: 1100 | Bias: 3.6
#   > [VAL]   R2: 0.9576 | RMSE: 2002 | MAE: 1254 | Bias: 28.2
#
# [C15|F8] Processing fold...
#   > [TRAIN] R2: 0.9682 | RMSE: 1742 | MAE: 1138 | Bias: 2.2
#   > [VAL]   R2: 0.9551 | RMSE: 2012 | MAE: 1256 | Bias: -15.4
#
# Config 15 SUMMARY:
#   [TRAIN AVG] MAE: 1134.1 | R2: 0.9673 | Bias: 1.1
#   [VAL AVG]   MAE: 1287.3 | R2: 0.9526 | Bias: 0.4 | RMSE: 2117.0
# # END OF SEARCH
#
# Top 5 Configurations by RMSE:
#    config_id  learning_rate  max_iter     val_rmse      val_mae    val_r2  \
# 2          3          0.100      1000  2099.530914  1255.499221  0.953341
# 8          9          0.100       800  2100.504347  1264.771234  0.953275
# 5          6          0.100       800  2102.091424  1266.021280  0.953168
# 6          7          0.115      1000  2103.075081  1266.134703  0.953180
# 4          5          0.115      1200  2104.173989  1255.819905  0.953120
#
#    train_r2  val_bias
# 2  0.973422  4.377196
# 8  0.971701  4.474108
# 5  0.972517  4.034098
# 6  0.971217  2.799125
# 4  0.976241  2.805482
# Best Config found:
# {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 3.0}

# %% [markdown]
# - Although the number of iterations was small, we observed small improvements among the top five validation RMSE and MAE scores. This suggests that this feature may contain inconsistencies that do not reflect the values in reality, as also indicated in the visualization stage.

# %% [markdown]
# ### 3.3. Feature Engineering Ablations and Additions <a id="feateng"></a>

# %% [markdown]
# - In this section, we will analyse the behaviour of the model with different sets of features.
# - We will start by evaluating the model's overall performance with the complete set of original features (without paint quality and damage columns) together with the engineered ones, first without feature selection and then with feature selection. We will analyse different feature selection percentages, most specificly the ones that attained the best two validation RMSE scores and the worst performing setting.
# - Finally, we will combine the previous owners feature with just the engineered age feature.
# - Throughout this section, we use a log-target strategy for the price (i.e., training on log(1 + price) and inverting predictions back to currency for evaluation).

# %% [markdown]
# #### 3.3.1. All Engineered Features (no Feature Selection) <a id="featengnosel"></a>

# %% [markdown]
# - We ran a small random search without feature selection. We did not expect strong results, because keeping all of the engineered features would likely increase redundancy, but served as a baseline for comparison.

# %%
N_ITER = 10 #number of iterations testing configurations in random search
# this is a short random search, enough for baseline results

random.seed(RANDOM_STATE) # additional randomness control
np.random.seed(RANDOM_STATE) # additional randomness control - for numpy

# logging configurations
LOG_FILE = "random_search_fe_results_rmse_no_fs_iter10.log"
logging.basicConfig(
    filename=LOG_FILE,
    level=logging.INFO,
    format="%(asctime)s - %(message)s",
    filemode="w", # overwrite log on each run
    force=True # ensures this config overrides any previous logging setup
)
logging.info(f"- {N_ITER} iterations | {N_SPLITS}-fold | NO_FEATURE_SELECTION")

# hyperparameter space that we are going to use to random search
# each configuration will get 1 value from each of these lists
param_distributions = {
    "min_samples_leaf": [20, 30, 40], # min number of samples for each leaf
    "max_leaf_nodes": [31, 63, 127], # max number of leaves for each tree
    "max_iter": [600, 800, 1000, 1500], # max number of trees 
    "max_depth": [None, 10, 15, 20, 25], # max depth of each tree
    "learning_rate": np.linspace(0.08, 0.15, 20), # shrinkage factor (for the leaves values) 
    "l2_regularization": np.linspace(0.5, 2.5, 20), # regularization (penalization) factor for small hessian values leaves  
    "max_bins": [255], # this is already the default, but was added for completeness
    "random_state": [RANDOM_STATE],
}
# Note: linspace(a,b,n) will generate an array of n equally spaced values between a and b (inclusive)

# Sample N_ITER configs from the distributions 
CONFIGS = get_random_configs(N_ITER)

# shuffles the data, in order to, at least theoretically, have more balanced folds
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]

# separate high and low cardinality categorical features for future encoding steps
high_card_features = ["Brand", "model"] # these for target encoding
low_card_features  = [c for c in categorical_features if c not in high_card_features] # these for one-hot encoding

# evaluates the configuration 
def eval_one_config(name: str, params: dict) -> dict:
    fold_rows = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):
        # kf.split(X) returns the row indices for the train/validation split of each CV fold
        # fold starts at 1 just for cleaner logging (Fold 1, Fold 2, etc) 

        # Extract fold data by integer position
        # .copy() prevents in-fold transformations from accidentally affecting the original 
        X_train = X.iloc[train_idx].copy()
        X_val   = X.iloc[val_idx].copy()
        y_train = y.iloc[train_idx].copy()
        y_val   = y.iloc[val_idx].copy()

        # train in log space to stabilize variance and therefore reduce target skew 
        # y_log = log(1 + y). then we invert with expm1() to evaluate in currency
        y_train_log = np.log1p(y_train)

        # this was already performed, but just for safety
        X_train = _normalize_cats(X_train) 
        X_val   = _normalize_cats(X_val) 

        # keep only expected base columns (prevents accidental leakage / extra columns wrongfully added)
        base_cols = [c for c in (numeric_features + categorical_features) if c in X_train.columns]
        X_train = X_train[base_cols].copy()
        X_val   = X_val[base_cols].copy()

        # guards 
        required = ["year", "mileage", "engineSize", "tax", "mpg", "previousOwners", "Brand", "model"]
        missing = [c for c in required if c not in X_train.columns]
        if missing:
            raise KeyError(f"[Fold {fold}] missing necessary columns in pipeline: {missing}")

        # -> Preprocessing Steps 
        # fit is only done with the training data 
        # we aplly the transformations (some obtained through fit) to both train and validation sets
        # all preprocessing functions are explained before, here we just apply them in order
        year_state = fit_year_median(X_train, year_col="year", model_col="model")
        X_train = transform_year_with_model_median(X_train, state=year_state)
        X_val   = transform_year_with_model_median(X_val,   state=year_state)

        mileage_state = fit_mileage_imputer(X_train, mileage_col="mileage", do_abs=True)
        X_train = transform_mileage_imputer(X_train, state=mileage_state)
        X_val   = transform_mileage_imputer(X_val,   state=mileage_state)

        engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
        X_train = transform_engine_size_imputer(X_train, state=engine_state)
        X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

        X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
        X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

        mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
        X_train = transform_mpg_imputer(X_train, state=mpg_state)
        X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

        owners_state = fit_previous_owners_imputer(X_train, "previousOwners", "year", "mileage")
        X_train = transform_previous_owners_imputer(X_train, state=owners_state)
        X_val   = transform_previous_owners_imputer(X_val,   state=owners_state)

        brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
        X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
        X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

        model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
        X_train, _, _ = transform_invalid_models(X_train, model_state)
        X_val,   _, _ = transform_invalid_models(X_val,   model_state)

        transm_state = fit_transmission_resolver(X_train, valid_transmissions)
        X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
        X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

        fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
        X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
        X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)


        # -> Feature Engineering
        # replace previousOwners feature with a more robust derived feature (and drop original)
        X_train = add_owners_flagged(X_train, owners_col="previousOwners", new_col="owners_flagged", drop_original=True)
        X_val   = add_owners_flagged(X_val,   owners_col="previousOwners", new_col="owners_flagged", drop_original=True)

        # age feature: uses a fixed reference year (base_year=2020)
        X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
        X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

        # mileage-derived features; drops original mileage, and optionally drops ratio feature
        X_train = add_mileage_features(X_train, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
        X_val   = add_mileage_features(X_val,   mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)

        # discretize engineSize into bins; treat as categorical (string) for OHE
        X_train = add_engine_bins(X_train, engine_col="engineSize", new_col="engine_bin")
        X_val   = add_engine_bins(X_val,   engine_col="engineSize", new_col="engine_bin")

        X_train["engine_bin"] = X_train["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        X_val["engine_bin"]   = X_val["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        low_card_curr = low_card_features + ["engine_bin"]

        # -> Encoding 
        # target encoder fits on train fold using y_train_log (preventing data leakage)
        te = MyTargetEncoder(smoothing=5)
        te.fit(X_train[high_card_features], y_train_log)
        X_train_high = te.transform(X_train[high_card_features])
        X_val_high   = te.transform(X_val[high_card_features])

        # One-hot encode low-cardinality categoricals; fits on train fold only
        ohe = MyOneHotEncoder()
        ohe.fit(X_train[low_card_curr])
        X_train_low = ohe.transform(X_train[low_card_curr])
        X_val_low   = ohe.transform(X_val[low_card_curr])

        X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
        X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

        # numerics are the ones left after encoding (because those encoded were the categorical) 
        drop_for_numeric = set(high_card_features + low_card_curr)
        numeric_features_curr = [c for c in X_train.columns if c not in drop_for_numeric]

        X_train_final = pd.concat([X_train[numeric_features_curr], X_train_cat], axis=1)
        X_val_final   = pd.concat([X_val[numeric_features_curr],   X_val_cat],   axis=1)

        # ensure validation has exactly the same columns/order as train 
        X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

        # --> train on log target and for prediction invert back to currency
        n_feats = int(X_train_final.shape[1])

        model = HistGradientBoostingRegressor(**params)
        model.fit(X_train_final, y_train_log)

        pred_tr_log  = model.predict(X_train_final)
        pred_val_log = model.predict(X_val_final)

        pred_tr  = np.expm1(pred_tr_log)   
        pred_val = np.expm1(pred_val_log)  

       
        # --> metrics 
        fold_rows.append({
            "config": name,
            "fold": fold,
            "n_features": n_feats,

            "train_rmse": rmse(y_train, pred_tr),
            "val_rmse":   rmse(y_val,   pred_val),

            "train_mae": float(mean_absolute_error(y_train, pred_tr)),
            "val_mae":   float(mean_absolute_error(y_val,   pred_val)),

            "train_r2": float(r2_score(y_train, pred_tr)),
            "val_r2":   float(r2_score(y_val,   pred_val)),

            "train_bias": bias(y_train, pred_tr),
            "val_bias":   bias(y_val,   pred_val),
        })

    df_folds = pd.DataFrame(fold_rows)

    # mean after folds
    out = {
        "config": name,

        "val_rmse_mean": float(df_folds["val_rmse"].mean()),
        "train_rmse_mean": float(df_folds["train_rmse"].mean()),
        "val_mae_mean": float(df_folds["val_mae"].mean()),
        "train_mae_mean": float(df_folds["train_mae"].mean()),
        "val_r2_mean": float(df_folds["val_r2"].mean()),
        "train_r2_mean": float(df_folds["train_r2"].mean()),
        "val_bias_mean": float(df_folds["val_bias"].mean()),
        "train_bias_mean": float(df_folds["train_bias"].mean()),

        "avg_features": float(df_folds["n_features"].mean()),
        **params,
    }

    print(
        f"   >> [{name}] "
        f"VAL RMSE: {out['val_rmse_mean']:.1f} | VAL R2: {out['val_r2_mean']:.4f} | "
        f"VAL MAE: {out['val_mae_mean']:.1f} | VAL Bias: {out['val_bias_mean']:.1f} | "
        f"Feats: {out['avg_features']:.0f}"
    )

    logging.info(
        f"{name} | "
        f"VAL_RMSE={out['val_rmse_mean']:.6f} | VAL_MAE={out['val_mae_mean']:.6f} | "
        f"VAL_R2={out['val_r2_mean']:.6f} | VAL_BIAS={out['val_bias_mean']:.6f} | "
        f"TRAIN_RMSE={out['train_rmse_mean']:.6f} | TRAIN_MAE={out['train_mae_mean']:.6f} | "
        f"Params={params}"
    )

    return out

# results to store 
results = [] # stores the summary dict returned by each evaluated configuration
best_rmse = np.inf # to store the lowest therefore best validation rmse 
best_row = None # stores the full result dict of the current best config

# iterate over the sampled configurations (name, params)
for i, (name, params) in enumerate(CONFIGS):
    # just to oganize in blocks of 5 for easier result tracking while running 
    if i % 5 == 0:
        print(f"\n-- doing {i+1}/{len(CONFIGS)}")

    # evaluate one configuration (returns fold metrics and params)
    res = eval_one_config(name, params)
    results.append(res)

    # we are looking for the best rmse, the lowest 
    if res["val_rmse_mean"] < best_rmse:
        best_rmse = res["val_rmse_mean"]
        best_row = res

results_df = pd.DataFrame(results) # converting to a dataframe for a better exploration of results 

# final results 
print("\n- TOP 10 Configurations (sorted by VAL RMSE)")
# sort configurations by validation RMSE (ascending = best first)
results_df_sorted = results_df.sort_values("val_rmse_mean", ascending=True)

# columns to display in the summary table
cols_show = [
    "config",
    "val_rmse_mean", "val_mae_mean", "val_r2_mean", "val_bias_mean",
    "train_rmse_mean", "train_mae_mean", "train_r2_mean", "train_bias_mean",
    "avg_features",
    "learning_rate", "max_iter", "l2_regularization", "max_leaf_nodes", "max_depth", "min_samples_leaf"
]

display(results_df_sorted[cols_show].head(10))

OUT_CSV = "random_search_fe_results_rmse_no_fs_iter10.csv"
results_df_sorted.to_csv(OUT_CSV, index=False)
print(f"stored at: {OUT_CSV}")
print(f"log in: {LOG_FILE}")

print("\n- BEST CONFIG (by VAL RMSE)")
print(f"Best config name: {best_row['config']}")
print(f"VAL RMSE: {best_row['val_rmse_mean']:.3f}")
print(f"VAL R2:   {best_row['val_r2_mean']:.6f}")
print(f"VAL MAE:  {best_row['val_mae_mean']:.3f}")
print(f"VAL Bias: {best_row['val_bias_mean']:.3f}")
print("Params:")
best_params = {k: best_row[k] for k in param_distributions.keys() if k in best_row}
print(best_params)
# Out:
# -- doing 1/10
#    >> [R0_iter600_lr0.106_l21.24_leaf31] VAL RMSE: 2225.2 | VAL R2: 0.9476 | VAL MAE: 1307.9 | VAL Bias: 111.5 | Feats: 25
#    >> [R1_iter600_lr0.128_l20.61_leaf127] VAL RMSE: 2175.0 | VAL R2: 0.9499 | VAL MAE: 1271.0 | VAL Bias: 101.4 | Feats: 25
#    >> [R2_iter600_lr0.102_l22.29_leaf31] VAL RMSE: 2193.7 | VAL R2: 0.9491 | VAL MAE: 1301.1 | VAL Bias: 115.0 | Feats: 25
#    >> [R3_iter1000_lr0.098_l21.87_leaf127] VAL RMSE: 2173.4 | VAL R2: 0.9500 | VAL MAE: 1265.0 | VAL Bias: 102.9 | Feats: 25
#    >> [R4_iter1000_lr0.087_l21.76_leaf31] VAL RMSE: 2189.9 | VAL R2: 0.9492 | VAL MAE: 1294.7 | VAL Bias: 112.4 | Feats: 25
#
# -- doing 6/10
#    >> [R5_iter1000_lr0.132_l22.29_leaf127] VAL RMSE: 2167.0 | VAL R2: 0.9503 | VAL MAE: 1264.1 | VAL Bias: 101.6 | Feats: 25
#    >> [R6_iter1000_lr0.121_l22.39_leaf127] VAL RMSE: 2170.0 | VAL R2: 0.9501 | VAL MAE: 1266.2 | VAL Bias: 104.0 | Feats: 25
#    >> [R7_iter800_lr0.087_l21.24_leaf127] VAL RMSE: 2166.4 | VAL R2: 0.9503 | VAL MAE: 1263.0 | VAL Bias: 104.3 | Feats: 25
#    >> [R8_iter1000_lr0.121_l21.66_leaf63] VAL RMSE: 2177.6 | VAL R2: 0.9498 | VAL MAE: 1280.5 | VAL Bias: 105.2 | Feats: 25
#    >> [R9_iter600_lr0.098_l22.29_leaf127] VAL RMSE: 2170.7 | VAL R2: 0.9501 | VAL MAE: 1268.2 | VAL Bias: 102.6 | Feats: 25
#
# - TOP 10 Configurations (sorted by VAL RMSE)
#                                config  val_rmse_mean  val_mae_mean  \
# 7   R7_iter800_lr0.087_l21.24_leaf127    2166.385636   1262.987293
# 5  R5_iter1000_lr0.132_l22.29_leaf127    2166.981137   1264.079945
# 6  R6_iter1000_lr0.121_l22.39_leaf127    2169.994360   1266.230068
# 9   R9_iter600_lr0.098_l22.29_leaf127    2170.726456   1268.151996
# 3  R3_iter1000_lr0.098_l21.87_leaf127    2173.421628   1264.973215
# 1   R1_iter600_lr0.128_l20.61_leaf127    2175.046506   1270.965401
# 8   R8_iter1000_lr0.121_l21.66_leaf63    2177.618806   1280.533570
# 4   R4_iter1000_lr0.087_l21.76_leaf31    2189.868643   1294.659359
# 2    R2_iter600_lr0.102_l22.29_leaf31    2193.745759   1301.096574
# 0    R0_iter600_lr0.106_l21.24_leaf31    2225.164094   1307.947911
#
#    val_r2_mean  val_bias_mean  train_rmse_mean  train_mae_mean  train_r2_mean  \
# 7     0.950291     104.271149      1697.414446     1028.139550       0.969588
# 5     0.950273     101.644585      1717.620724     1033.924597       0.968850
# 6     0.950115     104.016112      1700.687504     1028.594273       0.969443
# 9     0.950127     102.562385      1751.553143     1051.351428       0.967598
# 3     0.949975     102.927068      1727.576938     1036.941120       0.968480
# 1     0.949919     101.432846      1756.899416     1055.321461       0.967371
# 8     0.949837     105.213004      1817.881511     1104.956383       0.965112
# 4     0.949240     112.414340      1896.325233     1161.230452       0.962056
# 2     0.949088     114.985999      1919.419481     1174.947244       0.961134
# 0     0.947640     111.548682      1965.545765     1190.466069       0.959240
#
#    train_bias_mean  avg_features  learning_rate  max_iter  l2_regularization  \
# 7        85.164179          25.0       0.087368       800           1.236842
# 5        84.632881          25.0       0.131579      1000           2.289474
# 6        85.630438          25.0       0.120526      1000           2.394737
# 9        86.618482          25.0       0.098421       600           2.289474
# 3        85.725725          25.0       0.098421      1000           1.868421
# 1        86.493603          25.0       0.127895       600           0.605263
# 8        90.584649          25.0       0.120526      1000           1.657895
# 4        99.985493          25.0       0.087368      1000           1.763158
# 2       101.419823          25.0       0.102105       600           2.289474
# 0       102.107846          25.0       0.105789       600           1.236842
#
#    max_leaf_nodes  max_depth  min_samples_leaf
# 7             127       15.0                20
# 5             127        NaN                30
# 6             127       25.0                20
# 9             127       25.0                40
# 3             127        NaN                30
# 1             127       25.0                40
# 8              63       10.0                30
# 4              31        NaN                20
# 2              31       25.0                20
# 0              31       15.0                40
# stored at: random_search_fe_results_rmse_no_fs_iter10.csv
# log in: random_search_fe_results_rmse_no_fs_iter10.log
#
# - BEST CONFIG (by VAL RMSE)
# Best config name: R7_iter800_lr0.087_l21.24_leaf127
# VAL RMSE: 2166.386
# VAL R2:   0.950291
# VAL MAE:  1262.987
# VAL Bias: 104.271
# Params:
# {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 15, 'learning_rate': np.float64(0.08736842105263158), 'l2_regularization': np.float64(1.236842105263158), 'max_bins': 255, 'random_state': 42}

# %% [markdown]
# #### 3.3.2. Engineered Features with Feature Selection <a id="featengsel"></a>

# %% [markdown]
# - In these experiments, we ran multiple random searches with different feature selection percentages to evaluate which one performs the best.
# - We tested the following percentages of feature selection: 40%, 55%, 60%, 65%, 70%, 75% and 80%. We only kept, in this notebook, the percentages 40% (the worst result obtained), 70% (the second best) and 75% (the best result).

# %% [markdown]
# ##### 3.3.2.1. Top 65% Features by Importance

# %%
N_ITER = 35 #number of iterations testing configurations in random search

FS_KEEP_RATIO = 0.65  # feature ratio to keep after feature selection (65%)

# there are parameters for the Random Forest used in feature selection
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

random.seed(RANDOM_STATE) # additional randomness control
np.random.seed(RANDOM_STATE) # additional randomness control - for numpy

# log configurations
LOG_FILE = "random_search_fe_fs_results_rmse_fs65m_iter35.log"
logging.basicConfig(
    filename=LOG_FILE,
    level=logging.INFO,
    format="%(asctime)s - %(message)s",
    filemode="w", # overwrite log on each run
    force=True # ensures this configuration overrides any previous logging setup
)
logging.info(f"- {N_ITER} iterations | {N_SPLITS}-fold | FS_KEEP_RATIO={FS_KEEP_RATIO}")

# hyperparameter space that we are going to use to random search
# each configuration will get 1 value from each of these lists
param_distributions = {
    "min_samples_leaf": [20, 30, 40], # min number of samples for each leaf
    "max_leaf_nodes": [31, 63, 127], # max number of leaves for each tree
    "max_iter": [600, 800, 1000, 1500], # max number of trees 
    "max_depth": [None, 10, 15, 20, 25], # max depth of each tree
    "learning_rate": np.linspace(0.08, 0.15, 20), # shrinkage factor (for the leaves values) 
    "l2_regularization": np.linspace(0.5, 2.5, 20), # regularization (penalization) factor for small hessian values leaves  
    "max_bins": [255], # this is already the default, but was added for completeness
    "random_state": [RANDOM_STATE],
}
# Note: linspace(a,b,n) will generate an array of n equally spaced values between a and b (inclusive)

CONFIGS = get_random_configs(N_ITER) # Sample N_ITER configs from the distributions 


# shuffles the data, in order to, at least theoretically, have more balanced folds
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]

# separate high and low cardinality categorical features for future encoding steps
high_card_features = ["Brand", "model"] # these for target encoding
low_card_features  = [c for c in categorical_features if c not in high_card_features] # these for one-hot encoding


# evaluates the configuration 
def eval_one_config(name: str, params: dict) -> dict:
    fold_rows = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):
        # kf.split(X) returns the row indices for the train/validation split of each CV fold
        # fold starts at 1 just for cleaner logging (Fold 1, Fold 2, etc) 

        # Extract fold data by integer position
        # .copy() prevents in-fold transformations from accidentally affecting the original 
        X_train = X.iloc[train_idx].copy()
        X_val   = X.iloc[val_idx].copy()
        y_train = y.iloc[train_idx].copy()
        y_val   = y.iloc[val_idx].copy()

        # train in log space to stabilize variance and therefore reduce target skew 
        # y_log = log(1 + y). then we invert with expm1() to evaluate in currency
        y_train_log = np.log1p(y_train)

        # this was already performed, but just for safety
        X_train = _normalize_cats(X_train)
        X_val   = _normalize_cats(X_val)

        # keep only expected base columns (prevents accidental leakage / extra columns wrongfully added)
        base_cols = [c for c in (numeric_features + categorical_features) if c in X_train.columns]
        X_train = X_train[base_cols].copy()
        X_val   = X_val[base_cols].copy()

        # guards
        required = ["year", "mileage", "engineSize", "tax", "mpg", "previousOwners", "Brand", "model"]
        missing = [c for c in required if c not in X_train.columns]
        if missing:
            raise KeyError(f"[Fold {fold}] faltam colunas necessárias no pipeline: {missing}")

        # -> Preprocessing Steps 
        # fit is only done with the training data 
        # we aplly the transformations (some obtained through fit) to both train and validation sets
        # all preprocessing functions are explained before, here we just apply them in order
        year_state = fit_year_median(X_train, year_col="year", model_col="model")
        X_train = transform_year_with_model_median(X_train, state=year_state)
        X_val   = transform_year_with_model_median(X_val,   state=year_state)

        mileage_state = fit_mileage_imputer(X_train, mileage_col="mileage", do_abs=True)
        X_train = transform_mileage_imputer(X_train, state=mileage_state)
        X_val   = transform_mileage_imputer(X_val,   state=mileage_state)

        engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
        X_train = transform_engine_size_imputer(X_train, state=engine_state)
        X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

        X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
        X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

        mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
        X_train = transform_mpg_imputer(X_train, state=mpg_state)
        X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

        owners_state = fit_previous_owners_imputer(X_train, "previousOwners", "year", "mileage")
        X_train = transform_previous_owners_imputer(X_train, state=owners_state)
        X_val   = transform_previous_owners_imputer(X_val,   state=owners_state)

        brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
        X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
        X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

        model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
        X_train, _, _ = transform_invalid_models(X_train, model_state)
        X_val,   _, _ = transform_invalid_models(X_val,   model_state)

        transm_state = fit_transmission_resolver(X_train, valid_transmissions)
        X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
        X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

        fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
        X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
        X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)


        # -> Feature Engineering
        # replace previousOwners feature with a more robust derived feature (and drop original)
        X_train = add_owners_flagged(X_train, owners_col="previousOwners", new_col="owners_flagged", drop_original=True)
        X_val   = add_owners_flagged(X_val,   owners_col="previousOwners", new_col="owners_flagged", drop_original=True)

        # age feature: uses a fixed reference year (base_year=2020)
        X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
        X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

        # mileage-derived features; drops original mileage
        X_train = add_mileage_features(X_train, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
        X_val   = add_mileage_features(X_val,   mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
    
        # discretize engineSize into bins; treat as categorical (string) for OHE
        X_train = add_engine_bins(X_train, engine_col="engineSize", new_col="engine_bin")
        X_val   = add_engine_bins(X_val,   engine_col="engineSize", new_col="engine_bin")

        X_train["engine_bin"] = X_train["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        X_val["engine_bin"]   = X_val["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        low_card_curr = low_card_features + ["engine_bin"]

        # -> Encoding 
        # target encoder fits on train fold using y_train_log (preventing data leakage)
        te = MyTargetEncoder(smoothing=5)
        te.fit(X_train[high_card_features], y_train_log)
        X_train_high = te.transform(X_train[high_card_features])
        X_val_high   = te.transform(X_val[high_card_features])

        # One-hot encode low-cardinality categoricals; fits on train fold only
        ohe = MyOneHotEncoder()
        ohe.fit(X_train[low_card_curr])
        X_train_low = ohe.transform(X_train[low_card_curr])
        X_val_low   = ohe.transform(X_val[low_card_curr])

        X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
        X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

        # numerics are the ones left after encoding (because those encoded were the categorical) 
        drop_for_numeric = set(high_card_features + low_card_curr)
        numeric_features_curr = [c for c in X_train.columns if c not in drop_for_numeric]

        X_train_final = pd.concat([X_train[numeric_features_curr], X_train_cat], axis=1)
        X_val_final   = pd.concat([X_val[numeric_features_curr],   X_val_cat],   axis=1)

        # ensure validation has exactly the same columns/order as train 
        X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)


        # --> Feature Selection
        n_feats = X_train_final.shape[1] # total number of engineered + encoded features available in this fold
        
        # ceil ensures we don't keep fewer features due to rounding
        # clamp to [1, n_feats] guarantees a valid number of selected features
        k = int(np.ceil(FS_KEEP_RATIO * n_feats))
        k = max(1, min(k, n_feats))

        # train a random forest on the train fold only to estimate feature importances
        # We use y_train_log because the main model is trained in log-target space as well
        rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
        rf_fs.fit(X_train_final, y_train_log)

        # SelectFromModel will keep the k most important features
        # threshold = -inf means not filtering by importance threshold
        #   selection is controlled primarily by max_features = k
        # - prefit=True indicates rf_fs is already fitted, so SelectFromModel won't refit it.
        selector = SelectFromModel(
            estimator=rf_fs,
            threshold=-np.inf,
            max_features=k,
            prefit=True
        )

        # Boolean mask of selected features based on rf_fs.feature_importances_
        selected_cols = X_train_final.columns[selector.get_support()]

        # Apply the same selected feature subset to both train and validation folds
        # this ensures a fair validation: the validation data is never used to decide the features
        X_train_sel = X_train_final[selected_cols]
        X_val_sel   = X_val_final[selected_cols]

        # --> train on log target and for prediction invert back to currency
        model = HistGradientBoostingRegressor(**params)
        model.fit(X_train_sel, y_train_log)

        pred_tr_log  = model.predict(X_train_sel)
        pred_val_log = model.predict(X_val_sel)

        pred_tr  = np.expm1(pred_tr_log)   
        pred_val = np.expm1(pred_val_log)  

        # --> metrics 
        rmse_tr = rmse(y_train, pred_tr)
        rmse_val = rmse(y_val, pred_val)

        mae_tr = float(mean_absolute_error(y_train, pred_tr))
        mae_val = float(mean_absolute_error(y_val, pred_val))

        r2_tr = float(r2_score(y_train, pred_tr))
        r2_val = float(r2_score(y_val, pred_val))

        bias_tr = bias(y_train, pred_tr)
        bias_val = bias(y_val, pred_val)

        fold_rows.append({
            "config": name,
            "fold": fold,
            "n_features_total": int(n_feats),
            "n_features_selected": int(len(selected_cols)),

            "train_rmse": rmse_tr,
            "val_rmse": rmse_val,
            "train_mae": mae_tr,
            "val_mae": mae_val,
            "train_r2": r2_tr,
            "val_r2": r2_val,
            "train_bias": bias_tr,
            "val_bias": bias_val,
        })

    df_folds = pd.DataFrame(fold_rows)

    # mean after folds
    out = {
        "config": name,

        "val_rmse_mean": float(df_folds["val_rmse"].mean()),
        "train_rmse_mean": float(df_folds["train_rmse"].mean()),
        "val_mae_mean": float(df_folds["val_mae"].mean()),
        "train_mae_mean": float(df_folds["train_mae"].mean()),
        "val_r2_mean": float(df_folds["val_r2"].mean()),
        "train_r2_mean": float(df_folds["train_r2"].mean()),
        "val_bias_mean": float(df_folds["val_bias"].mean()),
        "train_bias_mean": float(df_folds["train_bias"].mean()),

        "avg_selected_features": float(df_folds["n_features_selected"].mean()),
        "avg_total_features": float(df_folds["n_features_total"].mean()),
        **params,
    }

    print(
        f"   >> [{name}] "
        f"VAL RMSE: {out['val_rmse_mean']:.1f} | VAL R2: {out['val_r2_mean']:.4f} | "
        f"VAL MAE: {out['val_mae_mean']:.1f} | VAL Bias: {out['val_bias_mean']:.1f} | "
        f"Sel: {out['avg_selected_features']:.0f} feats"
    )

    logging.info(
        f"{name} | "
        f"VAL_RMSE={out['val_rmse_mean']:.6f} | VAL_MAE={out['val_mae_mean']:.6f} | "
        f"VAL_R2={out['val_r2_mean']:.6f} | VAL_BIAS={out['val_bias_mean']:.6f} | "
        f"TRAIN_RMSE={out['train_rmse_mean']:.6f} | TRAIN_MAE={out['train_mae_mean']:.6f} | "
        f"SelAvg={out['avg_selected_features']:.3f} | Params={params}"
    )

    return out

# results to store 
results = [] # stores the summary dict returned by each evaluated configuration
best_rmse = np.inf # to store the lowest therefore best validation rmse 
best_row = None  # stores the full result dict of the current best config

# iterate over the sampled configurations (name, params)
for i, (name, params) in enumerate(CONFIGS):
    # just to oganize in blocks of 5 for easier result tracking while running 
    if i % 5 == 0:
        print(f"\n-- doing {i+1}/{len(CONFIGS)}")

    # evaluate one configuration (returns fold metrics and params)
    res = eval_one_config(name, params)
    results.append(res)

    # we are looking for the best rmse, the lowest 
    if res["val_rmse_mean"] < best_rmse:
        best_rmse = res["val_rmse_mean"]
        best_row = res

results_df = pd.DataFrame(results) # converting to a dataframe for a better exploration of results 

# final results 
print("\n- TOP 10 Configurations (sorted by VAL RMSE)")
# sort configurations by validation RMSE (ascending = best first)
results_df_sorted = results_df.sort_values("val_rmse_mean", ascending=True)

# columns to display in the summary table
cols_show = [
    "config",
    "val_rmse_mean", "val_mae_mean", "val_r2_mean", "val_bias_mean",
    "train_rmse_mean", "train_mae_mean", "train_r2_mean", "train_bias_mean",
    "avg_selected_features",
    "learning_rate", "max_iter", "l2_regularization", "max_leaf_nodes", "max_depth", "min_samples_leaf"
]

display(results_df_sorted[cols_show].head(10))

OUT_CSV = "random_search_fe_fs_results_rmse_fs65m_iter35.csv"
results_df_sorted.to_csv(OUT_CSV, index=False)
print(f"stored at: {OUT_CSV}")
print(f"log in: {LOG_FILE}")

print("\n- BEST CONFIG (by VAL RMSE)")
print(f"Best config name: {best_row['config']}")
print(f"VAL RMSE: {best_row['val_rmse_mean']:.3f}")
print(f"VAL R2:   {best_row['val_r2_mean']:.6f}")
print(f"VAL MAE:  {best_row['val_mae_mean']:.3f}")
print(f"VAL Bias: {best_row['val_bias_mean']:.3f}")
print("Params:")
best_params = {k: best_row[k] for k in param_distributions.keys() if k in best_row}
print(best_params)
# Out:
# -- doing 1/35
#    >> [R0_iter600_lr0.106_l21.24_leaf31] VAL RMSE: 2216.7 | VAL R2: 0.9480 | VAL MAE: 1308.7 | VAL Bias: 111.4 | Sel: 17 feats
#    >> [R1_iter600_lr0.128_l20.61_leaf127] VAL RMSE: 2164.8 | VAL R2: 0.9504 | VAL MAE: 1268.1 | VAL Bias: 101.9 | Sel: 17 feats
#    >> [R2_iter600_lr0.102_l22.29_leaf31] VAL RMSE: 2198.1 | VAL R2: 0.9489 | VAL MAE: 1306.0 | VAL Bias: 112.5 | Sel: 17 feats
#    >> [R3_iter1000_lr0.098_l21.87_leaf127] VAL RMSE: 2171.3 | VAL R2: 0.9501 | VAL MAE: 1264.7 | VAL Bias: 103.9 | Sel: 17 feats
#    >> [R4_iter1000_lr0.087_l21.76_leaf31] VAL RMSE: 2183.8 | VAL R2: 0.9496 | VAL MAE: 1294.7 | VAL Bias: 111.9 | Sel: 17 feats
#
# -- doing 6/35
#    >> [R5_iter1000_lr0.132_l22.29_leaf127] VAL RMSE: 2164.9 | VAL R2: 0.9504 | VAL MAE: 1265.3 | VAL Bias: 103.3 | Sel: 17 feats
#    >> [R6_iter1000_lr0.121_l22.39_leaf127] VAL RMSE: 2138.9 | VAL R2: 0.9516 | VAL MAE: 1255.0 | VAL Bias: 103.2 | Sel: 17 feats
#    >> [R7_iter800_lr0.087_l21.24_leaf127] VAL RMSE: 2146.3 | VAL R2: 0.9512 | VAL MAE: 1255.6 | VAL Bias: 102.7 | Sel: 17 feats
#    >> [R8_iter1000_lr0.121_l21.66_leaf63] VAL RMSE: 2157.9 | VAL R2: 0.9507 | VAL MAE: 1277.7 | VAL Bias: 101.9 | Sel: 17 feats
#    >> [R9_iter600_lr0.098_l22.29_leaf127] VAL RMSE: 2160.9 | VAL R2: 0.9506 | VAL MAE: 1263.8 | VAL Bias: 104.6 | Sel: 17 feats
#
# -- doing 11/35
#    >> [R10_iter1000_lr0.106_l21.55_leaf63] VAL RMSE: 2184.4 | VAL R2: 0.9495 | VAL MAE: 1278.7 | VAL Bias: 106.8 | Sel: 17 feats
#    >> [R11_iter1500_lr0.087_l21.13_leaf63] VAL RMSE: 2163.1 | VAL R2: 0.9505 | VAL MAE: 1275.3 | VAL Bias: 106.0 | Sel: 17 feats
#    >> [R12_iter1500_lr0.095_l21.34_leaf63] VAL RMSE: 2175.6 | VAL R2: 0.9499 | VAL MAE: 1275.4 | VAL Bias: 107.0 | Sel: 17 feats
#    >> [R13_iter1000_lr0.128_l22.39_leaf127] VAL RMSE: 2165.2 | VAL R2: 0.9504 | VAL MAE: 1266.7 | VAL Bias: 102.0 | Sel: 17 feats
#    >> [R14_iter1500_lr0.084_l20.82_leaf31] VAL RMSE: 2202.9 | VAL R2: 0.9486 | VAL MAE: 1303.9 | VAL Bias: 114.2 | Sel: 17 feats
#
# -- doing 16/35
#    >> [R15_iter600_lr0.124_l22.50_leaf63] VAL RMSE: 2183.1 | VAL R2: 0.9496 | VAL MAE: 1279.8 | VAL Bias: 106.2 | Sel: 17 feats
#    >> [R16_iter600_lr0.109_l21.55_leaf31] VAL RMSE: 2215.1 | VAL R2: 0.9481 | VAL MAE: 1308.2 | VAL Bias: 110.3 | Sel: 17 feats
#    >> [R17_iter1500_lr0.109_l22.18_leaf31] VAL RMSE: 2197.3 | VAL R2: 0.9489 | VAL MAE: 1300.8 | VAL Bias: 110.7 | Sel: 17 feats
#    >> [R18_iter800_lr0.121_l21.03_leaf63] VAL RMSE: 2192.3 | VAL R2: 0.9492 | VAL MAE: 1290.9 | VAL Bias: 106.8 | Sel: 17 feats
#    >> [R19_iter600_lr0.113_l21.24_leaf31] VAL RMSE: 2197.3 | VAL R2: 0.9490 | VAL MAE: 1301.7 | VAL Bias: 110.5 | Sel: 17 feats
#
# -- doing 21/35
#    >> [R20_iter600_lr0.087_l22.29_leaf31] VAL RMSE: 2225.2 | VAL R2: 0.9476 | VAL MAE: 1315.3 | VAL Bias: 115.6 | Sel: 17 feats
#    >> [R21_iter800_lr0.139_l22.50_leaf63] VAL RMSE: 2177.0 | VAL R2: 0.9498 | VAL MAE: 1280.6 | VAL Bias: 103.4 | Sel: 17 feats
#    >> [R22_iter800_lr0.124_l21.66_leaf127] VAL RMSE: 2189.5 | VAL R2: 0.9492 | VAL MAE: 1281.4 | VAL Bias: 104.5 | Sel: 17 feats
#    >> [R23_iter800_lr0.117_l20.50_leaf31] VAL RMSE: 2200.0 | VAL R2: 0.9488 | VAL MAE: 1302.8 | VAL Bias: 112.5 | Sel: 17 feats
#    >> [R24_iter600_lr0.087_l20.61_leaf31] VAL RMSE: 2212.0 | VAL R2: 0.9483 | VAL MAE: 1315.5 | VAL Bias: 116.8 | Sel: 17 feats
#
# -- doing 26/35
#    >> [R25_iter1000_lr0.102_l22.29_leaf31] VAL RMSE: 2222.1 | VAL R2: 0.9478 | VAL MAE: 1312.1 | VAL Bias: 116.9 | Sel: 17 feats
#    >> [R26_iter1500_lr0.091_l20.82_leaf63] VAL RMSE: 2174.8 | VAL R2: 0.9499 | VAL MAE: 1283.4 | VAL Bias: 108.1 | Sel: 17 feats
#    >> [R27_iter1500_lr0.091_l20.61_leaf63] VAL RMSE: 2169.0 | VAL R2: 0.9502 | VAL MAE: 1270.7 | VAL Bias: 105.3 | Sel: 17 feats
#    >> [R28_iter800_lr0.143_l21.97_leaf31] VAL RMSE: 2187.9 | VAL R2: 0.9494 | VAL MAE: 1302.8 | VAL Bias: 110.0 | Sel: 17 feats
#    >> [R29_iter1500_lr0.087_l21.97_leaf63] VAL RMSE: 2165.7 | VAL R2: 0.9504 | VAL MAE: 1274.2 | VAL Bias: 106.2 | Sel: 17 feats
#
# -- doing 31/35
#    >> [R30_iter600_lr0.106_l21.03_leaf127] VAL RMSE: 2172.1 | VAL R2: 0.9501 | VAL MAE: 1267.9 | VAL Bias: 104.1 | Sel: 17 feats
#    >> [R31_iter1500_lr0.098_l21.76_leaf31] VAL RMSE: 2197.7 | VAL R2: 0.9489 | VAL MAE: 1301.6 | VAL Bias: 114.6 | Sel: 17 feats
#    >> [R32_iter1000_lr0.143_l22.08_leaf63] VAL RMSE: 2175.1 | VAL R2: 0.9499 | VAL MAE: 1275.8 | VAL Bias: 102.1 | Sel: 17 feats
#    >> [R33_iter600_lr0.143_l20.61_leaf31] VAL RMSE: 2203.4 | VAL R2: 0.9487 | VAL MAE: 1302.8 | VAL Bias: 110.1 | Sel: 17 feats
#    >> [R34_iter1500_lr0.139_l21.03_leaf127] VAL RMSE: 2162.6 | VAL R2: 0.9505 | VAL MAE: 1258.1 | VAL Bias: 99.7 | Sel: 17 feats
#
# - TOP 10 Configurations (sorted by VAL RMSE)
#                                  config  val_rmse_mean  val_mae_mean  \
# 6    R6_iter1000_lr0.121_l22.39_leaf127    2138.946463   1254.963079
# 7     R7_iter800_lr0.087_l21.24_leaf127    2146.293246   1255.629198
# 8     R8_iter1000_lr0.121_l21.66_leaf63    2157.920751   1277.729013
# 9     R9_iter600_lr0.098_l22.29_leaf127    2160.865464   1263.816194
# 34  R34_iter1500_lr0.139_l21.03_leaf127    2162.574254   1258.106493
# 11   R11_iter1500_lr0.087_l21.13_leaf63    2163.110780   1275.262067
# 1     R1_iter600_lr0.128_l20.61_leaf127    2164.811904   1268.102162
# 5    R5_iter1000_lr0.132_l22.29_leaf127    2164.863203   1265.272584
# 13  R13_iter1000_lr0.128_l22.39_leaf127    2165.156544   1266.720002
# 29   R29_iter1500_lr0.087_l21.97_leaf63    2165.709023   1274.214984
#
#     val_r2_mean  val_bias_mean  train_rmse_mean  train_mae_mean  \
# 6      0.951583     103.213963      1656.389980     1000.731919
# 7      0.951206     102.687599      1682.127425     1019.793927
# 8      0.950724     101.917490      1806.662760     1101.812486
# 9      0.950583     104.621739      1753.936585     1053.095915
# 34     0.950473      99.677590      1662.200825     1006.441463
# 11     0.950530     106.011979      1803.525756     1102.379204
# 1      0.950376     101.889555      1761.153552     1056.443370
# 5      0.950386     103.267536      1728.950756     1042.026496
# 13     0.950371     101.999496      1723.995264     1037.305368
# 29     0.950372     106.154620      1795.347691     1098.920566
#
#     train_r2_mean  train_bias_mean  avg_selected_features  learning_rate  \
# 6        0.971014        82.265408                   17.0       0.120526
# 7        0.970105        83.743940                   17.0       0.087368
# 8        0.965512        89.622359                   17.0       0.120526
# 9        0.967526        86.500598                   17.0       0.098421
# 34       0.970830        81.860099                   17.0       0.138947
# 11       0.965650        93.020385                   17.0       0.087368
# 1        0.967263        86.124336                   17.0       0.127895
# 5        0.968432        85.004594                   17.0       0.131579
# 13       0.968615        83.795121                   17.0       0.127895
# 29       0.965967        91.154450                   17.0       0.087368
#
#     max_iter  l2_regularization  max_leaf_nodes  max_depth  min_samples_leaf
# 6       1000           2.394737             127       25.0                20
# 7        800           1.236842             127       15.0                20
# 8       1000           1.657895              63       10.0                30
# 9        600           2.289474             127       25.0                40
# 34      1500           1.026316             127       25.0                20
# 11      1500           1.131579              63       15.0                20
# 1        600           0.605263             127       25.0                40
# 5       1000           2.289474             127        NaN                30
# 13      1000           2.394737             127       25.0                40
# 29      1500           1.973684              63       10.0                20
# stored at: random_search_fe_fs_results_rmse_fs65m_iter35.csv
# log in: random_search_fe_fs_results_rmse_fs65m_iter35.log
#
# - BEST CONFIG (by VAL RMSE)
# Best config name: R6_iter1000_lr0.121_l22.39_leaf127
# VAL RMSE: 2138.946
# VAL R2:   0.951583
# VAL MAE:  1254.963
# VAL Bias: 103.214
# Params:
# {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 25, 'learning_rate': np.float64(0.12052631578947368), 'l2_regularization': np.float64(2.394736842105263), 'max_bins': 255, 'random_state': 42}

# %% [markdown]
# ##### 3.3.2.2. Top 70% Features by Importance

# %%
N_ITER = 35 #number of iterations testing configurations in random search

FS_KEEP_RATIO = 0.70  # feature ratio to keep after feature selection (70%)

# there are parameters for the Random Forest used in feature selection
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

random.seed(RANDOM_STATE) # additional randomness control
np.random.seed(RANDOM_STATE) # additional randomness control - for numpy

# log configurations
LOG_FILE = "random_search_fe_fs_results_rmse_fs70m_iter35.log"
logging.basicConfig(
    filename=LOG_FILE,
    level=logging.INFO,
    format="%(asctime)s - %(message)s",
    filemode="w", # overwrite log on each run
    force=True # ensures this configuration overrides any previous logging setup
)
logging.info(f"- {N_ITER} iterations | {N_SPLITS}-fold | FS_KEEP_RATIO={FS_KEEP_RATIO}")


# hyperparameter space that we are going to use to random search
# each configuration will get 1 value from each of these lists
param_distributions = {
    "min_samples_leaf": [20, 30, 40], # min number of samples for each leaf
    "max_leaf_nodes": [31, 63, 127], # max number of leaves for each tree
    "max_iter": [600, 800, 1000, 1500], # max number of trees 
    "max_depth": [None, 10, 15, 20, 25], # max depth of each tree
    "learning_rate": np.linspace(0.08, 0.15, 20), # shrinkage factor (for the leaves values) 
    "l2_regularization": np.linspace(0.5, 2.5, 20), # regularization (penalization) factor for small hessian values leaves  
    "max_bins": [255], # this is already the default, but was added for completeness
    "random_state": [RANDOM_STATE],
}
# Note: linspace(a,b,n) will generate an array of n equally spaced values between a and b (inclusive)


CONFIGS = get_random_configs(N_ITER) # Sample N_ITER configs from the distributions 


# shuffles the data, in order to, at least theoretically, have more balanced folds
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)


cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]

# separate high and low cardinality categorical features for future encoding steps
high_card_features = ["Brand", "model"]
low_card_features  = [c for c in categorical_features if c not in high_card_features]


# evaluates the configuration 
def eval_one_config(name: str, params: dict) -> dict:
    fold_rows = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):
        # kf.split(X) returns the row indices for the train/validation split of each CV fold
        # fold starts at 1 just for cleaner logging (Fold 1, Fold 2, etc) 

        # Extract fold data by integer position
        # .copy() prevents in-fold transformations from accidentally affecting the original 
        X_train = X.iloc[train_idx].copy()
        X_val   = X.iloc[val_idx].copy()
        y_train = y.iloc[train_idx].copy()
        y_val   = y.iloc[val_idx].copy()

        # train in log space to stabilize variance and therefore reduce target skew 
        # y_log = log(1 + y). then we invert with expm1() to evaluate in currency
        y_train_log = np.log1p(y_train)

        # this was already performed, but just for safety
        X_train = _normalize_cats(X_train)
        X_val   = _normalize_cats(X_val)

        # keep only expected base columns (prevents accidental leakage / extra columns wrongfully added)
        base_cols = [c for c in (numeric_features + categorical_features) if c in X_train.columns]
        X_train = X_train[base_cols].copy()
        X_val   = X_val[base_cols].copy()

        # guards
        required = ["year", "mileage", "engineSize", "tax", "mpg", "previousOwners", "Brand", "model"]
        missing = [c for c in required if c not in X_train.columns]
        if missing:
            raise KeyError(f"[Fold {fold}] faltam colunas necessárias no pipeline: {missing}")


        # -> Preprocessing Steps 
        # fit is only done with the training data 
        # we aplly the transformations (some obtained through fit) to both train and validation sets
        # all preprocessing functions are explained before, here we just apply them in order
        year_state = fit_year_median(X_train, year_col="year", model_col="model")
        X_train = transform_year_with_model_median(X_train, state=year_state)
        X_val   = transform_year_with_model_median(X_val,   state=year_state)

        mileage_state = fit_mileage_imputer(X_train, mileage_col="mileage", do_abs=True)
        X_train = transform_mileage_imputer(X_train, state=mileage_state)
        X_val   = transform_mileage_imputer(X_val,   state=mileage_state)

        engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
        X_train = transform_engine_size_imputer(X_train, state=engine_state)
        X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

        X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
        X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

        mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
        X_train = transform_mpg_imputer(X_train, state=mpg_state)
        X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

        owners_state = fit_previous_owners_imputer(X_train, "previousOwners", "year", "mileage")
        X_train = transform_previous_owners_imputer(X_train, state=owners_state)
        X_val   = transform_previous_owners_imputer(X_val,   state=owners_state)

        brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
        X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
        X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

        model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
        X_train, _, _ = transform_invalid_models(X_train, model_state)
        X_val,   _, _ = transform_invalid_models(X_val,   model_state)

        transm_state = fit_transmission_resolver(X_train, valid_transmissions)
        X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
        X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

        fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
        X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
        X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)


        # -> Feature Engineering
        # replace previousOwners feature with a more robust derived feature (and drop original)
        X_train = add_owners_flagged(X_train, owners_col="previousOwners", new_col="owners_flagged", drop_original=True)
        X_val   = add_owners_flagged(X_val,   owners_col="previousOwners", new_col="owners_flagged", drop_original=True)

        # age feature: uses a fixed reference year (base_year=2020)
        X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
        X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

        # mileage-derived features; drops original mileage
        X_train = add_mileage_features(X_train, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
        X_val   = add_mileage_features(X_val,   mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
    
        # discretize engineSize into bins; treat as categorical (string) for OHE
        X_train = add_engine_bins(X_train, engine_col="engineSize", new_col="engine_bin")
        X_val   = add_engine_bins(X_val,   engine_col="engineSize", new_col="engine_bin")

        X_train["engine_bin"] = X_train["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        X_val["engine_bin"]   = X_val["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        low_card_curr = low_card_features + ["engine_bin"]

        # -> Encoding 
        # target encoder fits on train fold using y_train_log (preventing data leakage)
        te = MyTargetEncoder(smoothing=5)
        te.fit(X_train[high_card_features], y_train_log)
        X_train_high = te.transform(X_train[high_card_features])
        X_val_high   = te.transform(X_val[high_card_features])

        # One-hot encode low-cardinality categoricals; fits on train fold only
        ohe = MyOneHotEncoder()
        ohe.fit(X_train[low_card_curr])
        X_train_low = ohe.transform(X_train[low_card_curr])
        X_val_low   = ohe.transform(X_val[low_card_curr])

        X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
        X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

        # numerics are the ones left after encoding (because those encoded were the categorical) 
        drop_for_numeric = set(high_card_features + low_card_curr)
        numeric_features_curr = [c for c in X_train.columns if c not in drop_for_numeric]

        X_train_final = pd.concat([X_train[numeric_features_curr], X_train_cat], axis=1)
        X_val_final   = pd.concat([X_val[numeric_features_curr],   X_val_cat],   axis=1)

        # ensure validation has exactly the same columns/order as train 
        X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

        # --> Feature Selection
        n_feats = X_train_final.shape[1]  # total number of engineered + encoded features available in this fold
        
        # ceil ensures we don't keep fewer features due to rounding
        # clamp to [1, n_feats] guarantees a valid number of selected features
        k = int(np.ceil(FS_KEEP_RATIO * n_feats))
        k = max(1, min(k, n_feats))

        # train a random forest on the train fold only to estimate feature importances
        # We use y_train_log because the main model is trained in log-target space as well
        rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
        rf_fs.fit(X_train_final, y_train_log)

        # SelectFromModel will keep the k most important features
        # threshold = -inf means not filtering by importance threshold
        # selection is controlled primarily by max_features = k
        # prefit=True indicates rf_fs is already fitted, so SelectFromModel won't refit it.
        selector = SelectFromModel(
            estimator=rf_fs,
            threshold=-np.inf,
            max_features=k,
            prefit=True
        )

        # Boolean mask of selected features based on rf_fs.feature_importances_
        selected_cols = X_train_final.columns[selector.get_support()]

        # Apply the same selected feature subset to both train and validation folds
        # this ensures a fair validation: the validation data is never used to decide the features
        X_train_sel = X_train_final[selected_cols]
        X_val_sel   = X_val_final[selected_cols]

        # --> train on log target and for prediction invert back to price
        model = HistGradientBoostingRegressor(**params)
        model.fit(X_train_sel, y_train_log)

        pred_tr_log  = model.predict(X_train_sel)
        pred_val_log = model.predict(X_val_sel)

        pred_tr  = np.expm1(pred_tr_log)   
        pred_val = np.expm1(pred_val_log)  

        # --> metrics 
        rmse_tr = rmse(y_train, pred_tr)
        rmse_val = rmse(y_val, pred_val)

        mae_tr = float(mean_absolute_error(y_train, pred_tr))
        mae_val = float(mean_absolute_error(y_val, pred_val))

        r2_tr = float(r2_score(y_train, pred_tr))
        r2_val = float(r2_score(y_val, pred_val))

        bias_tr = bias(y_train, pred_tr)
        bias_val = bias(y_val, pred_val)

        fold_rows.append({
            "config": name,
            "fold": fold,
            "n_features_total": int(n_feats),
            "n_features_selected": int(len(selected_cols)),

            "train_rmse": rmse_tr,
            "val_rmse": rmse_val,
            "train_mae": mae_tr,
            "val_mae": mae_val,
            "train_r2": r2_tr,
            "val_r2": r2_val,
            "train_bias": bias_tr,
            "val_bias": bias_val,
        })

    df_folds = pd.DataFrame(fold_rows)

    # mean after folds
    out = {
        "config": name,

        "val_rmse_mean": float(df_folds["val_rmse"].mean()),
        "train_rmse_mean": float(df_folds["train_rmse"].mean()),
        "val_mae_mean": float(df_folds["val_mae"].mean()),
        "train_mae_mean": float(df_folds["train_mae"].mean()),
        "val_r2_mean": float(df_folds["val_r2"].mean()),
        "train_r2_mean": float(df_folds["train_r2"].mean()),
        "val_bias_mean": float(df_folds["val_bias"].mean()),
        "train_bias_mean": float(df_folds["train_bias"].mean()),

        "avg_selected_features": float(df_folds["n_features_selected"].mean()),
        "avg_total_features": float(df_folds["n_features_total"].mean()),
        **params,
    }

    print(
        f"   >> [{name}] "
        f"VAL RMSE: {out['val_rmse_mean']:.1f} | VAL R2: {out['val_r2_mean']:.4f} | "
        f"VAL MAE: {out['val_mae_mean']:.1f} | VAL Bias: {out['val_bias_mean']:.1f} | "
        f"Sel: {out['avg_selected_features']:.0f} feats"
    )

    logging.info(
        f"{name} | "
        f"VAL_RMSE={out['val_rmse_mean']:.6f} | VAL_MAE={out['val_mae_mean']:.6f} | "
        f"VAL_R2={out['val_r2_mean']:.6f} | VAL_BIAS={out['val_bias_mean']:.6f} | "
        f"TRAIN_RMSE={out['train_rmse_mean']:.6f} | TRAIN_MAE={out['train_mae_mean']:.6f} | "
        f"SelAvg={out['avg_selected_features']:.3f} | Params={params}"
    )

    return out

# results to store 
results = [] # stores the summary dict returned by each evaluated configuration
best_rmse = np.inf # to store the lowest therefore best validation rmse 
best_row = None  # stores the full result dict of the current best config

# iterate over the sampled configurations (name, params)
for i, (name, params) in enumerate(CONFIGS):
    # just to oganize in blocks of 5 for easier result tracking while running 
    if i % 5 == 0:
        print(f"\n-- doing {i+1}/{len(CONFIGS)}")

    # evaluate one configuration (returns fold metrics and params)
    res = eval_one_config(name, params)
    results.append(res)

    # we are looking for the best rmse, the lowest 
    if res["val_rmse_mean"] < best_rmse:
        best_rmse = res["val_rmse_mean"]
        best_row = res

results_df = pd.DataFrame(results) # converting to a dataframe for a better exploration of results 


# final results 
print("\n- TOP 10 Configurations (sorted by VAL RMSE)")
# sort configurations by validation RMSE (ascending = best first)
results_df_sorted = results_df.sort_values("val_rmse_mean", ascending=True)

# columns to display in the summary table
cols_show = [
    "config",
    "val_rmse_mean", "val_mae_mean", "val_r2_mean", "val_bias_mean",
    "train_rmse_mean", "train_mae_mean", "train_r2_mean", "train_bias_mean",
    "avg_selected_features",
    "learning_rate", "max_iter", "l2_regularization", "max_leaf_nodes", "max_depth", "min_samples_leaf"
]

display(results_df_sorted[cols_show].head(10))

OUT_CSV = "random_search_fe_fs_results_rmse_fs70m_iter35.csv"
results_df_sorted.to_csv(OUT_CSV, index=False)
print(f"stored at: {OUT_CSV}")
print(f"log in: {LOG_FILE}")

print("\n- BEST CONFIG (by VAL RMSE)")
print(f"Best config name: {best_row['config']}")
print(f"VAL RMSE: {best_row['val_rmse_mean']:.3f}")
print(f"VAL R2:   {best_row['val_r2_mean']:.6f}")
print(f"VAL MAE:  {best_row['val_mae_mean']:.3f}")
print(f"VAL Bias: {best_row['val_bias_mean']:.3f}")
print("Params:")
best_params = {k: best_row[k] for k in param_distributions.keys() if k in best_row}
print(best_params)
# Out:
# -- doing 1/35
#    >> [R0_iter600_lr0.106_l21.24_leaf31] VAL RMSE: 2223.7 | VAL R2: 0.9477 | VAL MAE: 1312.9 | VAL Bias: 112.7 | Sel: 18 feats
#    >> [R1_iter600_lr0.128_l20.61_leaf127] VAL RMSE: 2167.3 | VAL R2: 0.9502 | VAL MAE: 1265.7 | VAL Bias: 100.2 | Sel: 18 feats
#    >> [R2_iter600_lr0.102_l22.29_leaf31] VAL RMSE: 2204.2 | VAL R2: 0.9486 | VAL MAE: 1306.5 | VAL Bias: 115.5 | Sel: 18 feats
#    >> [R3_iter1000_lr0.098_l21.87_leaf127] VAL RMSE: 2162.7 | VAL R2: 0.9505 | VAL MAE: 1262.4 | VAL Bias: 101.4 | Sel: 18 feats
#    >> [R4_iter1000_lr0.087_l21.76_leaf31] VAL RMSE: 2188.4 | VAL R2: 0.9493 | VAL MAE: 1297.3 | VAL Bias: 111.9 | Sel: 18 feats
#
# -- doing 6/35
#    >> [R5_iter1000_lr0.132_l22.29_leaf127] VAL RMSE: 2161.4 | VAL R2: 0.9506 | VAL MAE: 1260.4 | VAL Bias: 101.2 | Sel: 18 feats
#    >> [R6_iter1000_lr0.121_l22.39_leaf127] VAL RMSE: 2149.5 | VAL R2: 0.9511 | VAL MAE: 1255.4 | VAL Bias: 100.6 | Sel: 18 feats
#    >> [R7_iter800_lr0.087_l21.24_leaf127] VAL RMSE: 2155.3 | VAL R2: 0.9508 | VAL MAE: 1261.3 | VAL Bias: 102.4 | Sel: 18 feats
#    >> [R8_iter1000_lr0.121_l21.66_leaf63] VAL RMSE: 2166.0 | VAL R2: 0.9504 | VAL MAE: 1275.5 | VAL Bias: 102.6 | Sel: 18 feats
#    >> [R9_iter600_lr0.098_l22.29_leaf127] VAL RMSE: 2155.1 | VAL R2: 0.9508 | VAL MAE: 1261.2 | VAL Bias: 101.4 | Sel: 18 feats
#
# -- doing 11/35
#    >> [R10_iter1000_lr0.106_l21.55_leaf63] VAL RMSE: 2172.4 | VAL R2: 0.9501 | VAL MAE: 1274.3 | VAL Bias: 104.9 | Sel: 18 feats
#    >> [R11_iter1500_lr0.087_l21.13_leaf63] VAL RMSE: 2150.5 | VAL R2: 0.9511 | VAL MAE: 1264.5 | VAL Bias: 106.6 | Sel: 18 feats
#    >> [R12_iter1500_lr0.095_l21.34_leaf63] VAL RMSE: 2173.5 | VAL R2: 0.9500 | VAL MAE: 1276.7 | VAL Bias: 107.7 | Sel: 18 feats
#    >> [R13_iter1000_lr0.128_l22.39_leaf127] VAL RMSE: 2169.3 | VAL R2: 0.9502 | VAL MAE: 1266.9 | VAL Bias: 102.1 | Sel: 18 feats
#    >> [R14_iter1500_lr0.084_l20.82_leaf31] VAL RMSE: 2183.4 | VAL R2: 0.9496 | VAL MAE: 1297.5 | VAL Bias: 112.7 | Sel: 18 feats
#
# -- doing 16/35
#    >> [R15_iter600_lr0.124_l22.50_leaf63] VAL RMSE: 2188.6 | VAL R2: 0.9493 | VAL MAE: 1283.9 | VAL Bias: 107.4 | Sel: 18 feats
#    >> [R16_iter600_lr0.109_l21.55_leaf31] VAL RMSE: 2233.8 | VAL R2: 0.9472 | VAL MAE: 1315.0 | VAL Bias: 111.7 | Sel: 18 feats
#    >> [R17_iter1500_lr0.109_l22.18_leaf31] VAL RMSE: 2191.6 | VAL R2: 0.9492 | VAL MAE: 1295.4 | VAL Bias: 108.0 | Sel: 18 feats
#    >> [R18_iter800_lr0.121_l21.03_leaf63] VAL RMSE: 2206.9 | VAL R2: 0.9485 | VAL MAE: 1297.5 | VAL Bias: 105.6 | Sel: 18 feats
#    >> [R19_iter600_lr0.113_l21.24_leaf31] VAL RMSE: 2193.9 | VAL R2: 0.9491 | VAL MAE: 1300.0 | VAL Bias: 108.0 | Sel: 18 feats
#
# -- doing 21/35
#    >> [R20_iter600_lr0.087_l22.29_leaf31] VAL RMSE: 2234.8 | VAL R2: 0.9472 | VAL MAE: 1320.2 | VAL Bias: 116.4 | Sel: 18 feats
#    >> [R21_iter800_lr0.139_l22.50_leaf63] VAL RMSE: 2181.2 | VAL R2: 0.9496 | VAL MAE: 1279.1 | VAL Bias: 101.7 | Sel: 18 feats
#    >> [R22_iter800_lr0.124_l21.66_leaf127] VAL RMSE: 2188.0 | VAL R2: 0.9493 | VAL MAE: 1279.0 | VAL Bias: 105.0 | Sel: 18 feats
#    >> [R23_iter800_lr0.117_l20.50_leaf31] VAL RMSE: 2207.3 | VAL R2: 0.9484 | VAL MAE: 1314.9 | VAL Bias: 114.9 | Sel: 18 feats
#    >> [R24_iter600_lr0.087_l20.61_leaf31] VAL RMSE: 2214.7 | VAL R2: 0.9481 | VAL MAE: 1315.8 | VAL Bias: 114.5 | Sel: 18 feats
#
# -- doing 26/35
#    >> [R25_iter1000_lr0.102_l22.29_leaf31] VAL RMSE: 2214.4 | VAL R2: 0.9482 | VAL MAE: 1303.9 | VAL Bias: 109.8 | Sel: 18 feats
#    >> [R26_iter1500_lr0.091_l20.82_leaf63] VAL RMSE: 2151.6 | VAL R2: 0.9510 | VAL MAE: 1264.3 | VAL Bias: 101.9 | Sel: 18 feats
#    >> [R27_iter1500_lr0.091_l20.61_leaf63] VAL RMSE: 2163.5 | VAL R2: 0.9505 | VAL MAE: 1271.4 | VAL Bias: 104.9 | Sel: 18 feats
#    >> [R28_iter800_lr0.143_l21.97_leaf31] VAL RMSE: 2175.4 | VAL R2: 0.9499 | VAL MAE: 1292.8 | VAL Bias: 108.0 | Sel: 18 feats
#    >> [R29_iter1500_lr0.087_l21.97_leaf63] VAL RMSE: 2179.7 | VAL R2: 0.9497 | VAL MAE: 1283.8 | VAL Bias: 108.3 | Sel: 18 feats
#
# -- doing 31/35
#    >> [R30_iter600_lr0.106_l21.03_leaf127] VAL RMSE: 2169.9 | VAL R2: 0.9502 | VAL MAE: 1265.6 | VAL Bias: 104.3 | Sel: 18 feats
#    >> [R31_iter1500_lr0.098_l21.76_leaf31] VAL RMSE: 2191.7 | VAL R2: 0.9492 | VAL MAE: 1298.7 | VAL Bias: 111.1 | Sel: 18 feats
#    >> [R32_iter1000_lr0.143_l22.08_leaf63] VAL RMSE: 2182.3 | VAL R2: 0.9496 | VAL MAE: 1279.4 | VAL Bias: 100.2 | Sel: 18 feats
#    >> [R33_iter600_lr0.143_l20.61_leaf31] VAL RMSE: 2177.7 | VAL R2: 0.9498 | VAL MAE: 1289.4 | VAL Bias: 107.0 | Sel: 18 feats
#    >> [R34_iter1500_lr0.139_l21.03_leaf127] VAL RMSE: 2157.7 | VAL R2: 0.9507 | VAL MAE: 1258.6 | VAL Bias: 96.9 | Sel: 18 feats
#
# - TOP 10 Configurations (sorted by VAL RMSE)
#                                  config  val_rmse_mean  val_mae_mean  \
# 6    R6_iter1000_lr0.121_l22.39_leaf127    2149.486899   1255.365480
# 11   R11_iter1500_lr0.087_l21.13_leaf63    2150.540530   1264.492294
# 26   R26_iter1500_lr0.091_l20.82_leaf63    2151.628145   1264.322161
# 9     R9_iter600_lr0.098_l22.29_leaf127    2155.058949   1261.175673
# 7     R7_iter800_lr0.087_l21.24_leaf127    2155.285251   1261.287479
# 34  R34_iter1500_lr0.139_l21.03_leaf127    2157.707074   1258.568731
# 5    R5_iter1000_lr0.132_l22.29_leaf127    2161.440351   1260.417202
# 3    R3_iter1000_lr0.098_l21.87_leaf127    2162.670933   1262.448176
# 27   R27_iter1500_lr0.091_l20.61_leaf63    2163.497447   1271.361581
# 8     R8_iter1000_lr0.121_l21.66_leaf63    2165.982166   1275.458212
#
#     val_r2_mean  val_bias_mean  train_rmse_mean  train_mae_mean  \
# 6      0.951091     100.621177      1667.777278     1009.710420
# 11     0.951070     106.577821      1762.616870     1074.902653
# 26     0.951010     101.939894      1753.643053     1071.892283
# 9      0.950848     101.439520      1739.197220     1042.201055
# 7      0.950826     102.424106      1700.257382     1030.907505
# 34     0.950681      96.898871      1664.807531     1006.751577
# 5      0.950568     101.239346      1709.005084     1028.116552
# 3      0.950480     101.363261      1723.241875     1036.555604
# 27     0.950484     104.935083      1808.048030     1095.457843
# 8      0.950367     102.552505      1789.044181     1091.542814
#
#     train_r2_mean  train_bias_mean  avg_selected_features  learning_rate  \
# 6        0.970567        82.566036                   18.0       0.120526
# 11       0.967180        89.565962                   18.0       0.087368
# 26       0.967548        87.685155                   18.0       0.091053
# 9        0.968070        84.992474                   18.0       0.098421
# 7        0.969456        85.195487                   18.0       0.087368
# 34       0.970754        81.820878                   18.0       0.138947
# 5        0.969156        83.441708                   18.0       0.131579
# 3        0.968645        85.346624                   18.0       0.098421
# 27       0.965467        91.847214                   18.0       0.091053
# 8        0.966205        88.151555                   18.0       0.120526
#
#     max_iter  l2_regularization  max_leaf_nodes  max_depth  min_samples_leaf
# 6       1000           2.394737             127       25.0                20
# 11      1500           1.131579              63       15.0                20
# 26      1500           0.815789              63       10.0                20
# 9        600           2.289474             127       25.0                40
# 7        800           1.236842             127       15.0                20
# 34      1500           1.026316             127       25.0                20
# 5       1000           2.289474             127        NaN                30
# 3       1000           1.868421             127        NaN                30
# 27      1500           0.605263              63        NaN                30
# 8       1000           1.657895              63       10.0                30
# stored at: random_search_fe_fs_results_rmse_fs70m_iter35.csv
# log in: random_search_fe_fs_results_rmse_fs70m_iter35.log
#
# - BEST CONFIG (by VAL RMSE)
# Best config name: R6_iter1000_lr0.121_l22.39_leaf127
# VAL RMSE: 2149.487
# VAL R2:   0.951091
# VAL MAE:  1255.365
# VAL Bias: 100.621
# Params:
# {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 25, 'learning_rate': np.float64(0.12052631578947368), 'l2_regularization': np.float64(2.394736842105263), 'max_bins': 255, 'random_state': 42}

# %% [markdown]
# ##### 3.3.2.2. Top 40% Features by Importance

# %%
N_ITER = 10 #number of iterations testing configurations in random search

FS_KEEP_RATIO = 0.40  # feature ratio to keep after feature selection (40%)

# there are parameters for the Random Forest used in feature selection
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

random.seed(RANDOM_STATE)  # additional randomness control
np.random.seed(RANDOM_STATE) # additional randomness control - for numpy

# log configurations
LOG_FILE = "random_search_fe_fs_results_rmse_fs40m.log"
logging.basicConfig(
    filename=LOG_FILE,
    level=logging.INFO,
    format="%(asctime)s - %(message)s",
    filemode="w", # overwrite log on each run
    force=True # ensures this configuration overrides any previous logging setup
)
logging.info(f"- {N_ITER} iterations | {N_SPLITS}-fold | FS_KEEP_RATIO={FS_KEEP_RATIO}")

# hyperparameter space that we are going to use to random search
# each configuration will get 1 value from each of these lists
param_distributions = {
    "min_samples_leaf": [20, 30, 40], # min number of samples for each leaf
    "max_leaf_nodes": [31, 63, 127], # max number of leaves for each tree
    "max_iter": [600, 800, 1000, 1500], # max number of trees 
    "max_depth": [None, 10, 15, 20, 25], # max depth of each tree
    "learning_rate": np.linspace(0.08, 0.15, 20), # shrinkage factor (for the leaves values) 
    "l2_regularization": np.linspace(0.5, 2.5, 20), # regularization (penalization) factor for small hessian values leaves  
    "max_bins": [255], # this is already the default, but was added for completeness
    "random_state": [RANDOM_STATE],
}
# Note: linspace(a,b,n) will generate an array of n equally spaced values between a and b (inclusive)

CONFIGS = get_random_configs(N_ITER) # Sample N_ITER configs from the distributions 

# shuffles the data, in order to, at least theoretically, have more balanced folds
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)


cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]

# separate high and low cardinality categorical features for future encoding steps
high_card_features = ["Brand", "model"]
low_card_features  = [c for c in categorical_features if c not in high_card_features]

# evaluates the configuration 
def eval_one_config(name: str, params: dict) -> dict:
    fold_rows = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):
        # kf.split(X) returns the row indices for the train/validation split of each CV fold
        # fold starts at 1 just for cleaner logging (Fold 1, Fold 2, etc) 

        # Extract fold data by integer position
        # .copy() prevents in-fold transformations from accidentally affecting the original 
        X_train = X.iloc[train_idx].copy()
        X_val   = X.iloc[val_idx].copy()
        y_train = y.iloc[train_idx].copy()
        y_val   = y.iloc[val_idx].copy()

        # train in log space to stabilize variance and therefore reduce target skew 
        # y_log = log(1 + y). then we invert with expm1() to evaluate in currency
        y_train_log = np.log1p(y_train)

        # this was already performed, but just for safety
        X_train = _normalize_cats(X_train)
        X_val   = _normalize_cats(X_val)

        # keep only expected base columns (prevents accidental leakage / extra columns wrongfully added)
        base_cols = [c for c in (numeric_features + categorical_features) if c in X_train.columns]
        X_train = X_train[base_cols].copy()
        X_val   = X_val[base_cols].copy()

        # guards
        required = ["year", "mileage", "engineSize", "tax", "mpg", "previousOwners", "Brand", "model"]
        missing = [c for c in required if c not in X_train.columns]
        if missing:
            raise KeyError(f"[Fold {fold}] faltam colunas necessárias no pipeline: {missing}")

        # -> Preprocessing Steps 
        # fit is only done with the training data 
        # we aplly the transformations (some obtained through fit) to both train and validation sets
        # all preprocessing functions are explained before, here we just apply them in order
        year_state = fit_year_median(X_train, year_col="year", model_col="model")
        X_train = transform_year_with_model_median(X_train, state=year_state)
        X_val   = transform_year_with_model_median(X_val,   state=year_state)

        mileage_state = fit_mileage_imputer(X_train, mileage_col="mileage", do_abs=True)
        X_train = transform_mileage_imputer(X_train, state=mileage_state)
        X_val   = transform_mileage_imputer(X_val,   state=mileage_state)

        engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
        X_train = transform_engine_size_imputer(X_train, state=engine_state)
        X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

        X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
        X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

        mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
        X_train = transform_mpg_imputer(X_train, state=mpg_state)
        X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

        owners_state = fit_previous_owners_imputer(X_train, "previousOwners", "year", "mileage")
        X_train = transform_previous_owners_imputer(X_train, state=owners_state)
        X_val   = transform_previous_owners_imputer(X_val,   state=owners_state)

        brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
        X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
        X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

        model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
        X_train, _, _ = transform_invalid_models(X_train, model_state)
        X_val,   _, _ = transform_invalid_models(X_val,   model_state)

        transm_state = fit_transmission_resolver(X_train, valid_transmissions)
        X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
        X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

        fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
        X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
        X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)


        # -> Feature Engineering
        # replace previousOwners feature with a more robust derived feature (and drop original)
        X_train = add_owners_flagged(X_train, owners_col="previousOwners", new_col="owners_flagged", drop_original=True)
        X_val   = add_owners_flagged(X_val,   owners_col="previousOwners", new_col="owners_flagged", drop_original=True)

        # age feature: uses a fixed reference year (base_year=2020)
        X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
        X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

        # mileage-derived features; drops original mileage
        X_train = add_mileage_features(X_train, mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
        X_val   = add_mileage_features(X_val,   mileage_col="mileage", age_col="age", drop_original=True, drop_ratio=True)
    
        # discretize engineSize into bins; treat as categorical (string) for OHE
        X_train = add_engine_bins(X_train, engine_col="engineSize", new_col="engine_bin")
        X_val   = add_engine_bins(X_val,   engine_col="engineSize", new_col="engine_bin")

        X_train["engine_bin"] = X_train["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        X_val["engine_bin"]   = X_val["engine_bin"].astype("Int64").astype("string").fillna("UNKNOWN")
        low_card_curr = low_card_features + ["engine_bin"]

        # -> Encoding 
        # target encoder fits on train fold using y_train_log (preventing data leakage)
        te = MyTargetEncoder(smoothing=5)
        te.fit(X_train[high_card_features], y_train_log)
        X_train_high = te.transform(X_train[high_card_features])
        X_val_high   = te.transform(X_val[high_card_features])

        # One-hot encode low-cardinality categoricals; fits on train fold only
        ohe = MyOneHotEncoder()
        ohe.fit(X_train[low_card_curr])
        X_train_low = ohe.transform(X_train[low_card_curr])
        X_val_low   = ohe.transform(X_val[low_card_curr])

        X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
        X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

        # numerics are the ones left after encoding (because those encoded were the categorical) 
        drop_for_numeric = set(high_card_features + low_card_curr)
        numeric_features_curr = [c for c in X_train.columns if c not in drop_for_numeric]

        X_train_final = pd.concat([X_train[numeric_features_curr], X_train_cat], axis=1)
        X_val_final   = pd.concat([X_val[numeric_features_curr],   X_val_cat],   axis=1)

        # ensure validation has exactly the same columns/order as train 
        X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

        # --> Feature Selection
        n_feats = X_train_final.shape[1] # total number of engineered + encoded features available in this fold

        # ceil ensures we don't keep fewer features due to rounding
        # clamp to [1, n_feats] guarantees a valid number of selected features
        k = int(np.ceil(FS_KEEP_RATIO * n_feats))
        k = max(1, min(k, n_feats))

        # train a random forest on the train fold only to estimate feature importances
        # We use y_train_log because the main model is trained in log-target space as well
        rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
        rf_fs.fit(X_train_final, y_train_log)

        # SelectFromModel will keep the k most important features
        # threshold = -inf means not filtering by importance threshold
        #   selection is controlled primarily by max_features = k
        # - prefit=True indicates rf_fs is already fitted, so SelectFromModel won't refit it
        selector = SelectFromModel(
            estimator=rf_fs,
            threshold=-np.inf,
            max_features=k,
            prefit=True
        )

        # Boolean mask of selected features based on rf_fs.feature_importances_
        selected_cols = X_train_final.columns[selector.get_support()]

        # Apply the same selected feature subset to both train and validation folds
        # this ensures a fair validation: the validation data is never used to decide the features
        X_train_sel = X_train_final[selected_cols]
        X_val_sel   = X_val_final[selected_cols]

        # --> train on log target and for prediction invert back to currency
        model = HistGradientBoostingRegressor(**params)
        model.fit(X_train_sel, y_train_log)

        pred_tr_log  = model.predict(X_train_sel)
        pred_val_log = model.predict(X_val_sel)

        pred_tr  = np.expm1(pred_tr_log)   
        pred_val = np.expm1(pred_val_log)  
        
        # --> metrics 
        rmse_tr = rmse(y_train, pred_tr)
        rmse_val =rmse(y_val, pred_val)

        mae_tr = float(mean_absolute_error(y_train, pred_tr))
        mae_val = float(mean_absolute_error(y_val, pred_val))

        r2_tr = float(r2_score(y_train, pred_tr))
        r2_val = float(r2_score(y_val, pred_val))

        bias_tr = bias(y_train, pred_tr)
        bias_val = bias(y_val, pred_val)

        fold_rows.append({
            "config": name,
            "fold": fold,
            "n_features_total": int(n_feats),
            "n_features_selected": int(len(selected_cols)),

            "train_rmse": rmse_tr,
            "val_rmse": rmse_val,
            "train_mae": mae_tr,
            "val_mae": mae_val,
            "train_r2": r2_tr,
            "val_r2": r2_val,
            "train_bias": bias_tr,
            "val_bias": bias_val,
        })

    df_folds = pd.DataFrame(fold_rows)

    # mean after folds
    out = {
        "config": name,

        "val_rmse_mean": float(df_folds["val_rmse"].mean()),
        "train_rmse_mean": float(df_folds["train_rmse"].mean()),
        "val_mae_mean": float(df_folds["val_mae"].mean()),
        "train_mae_mean": float(df_folds["train_mae"].mean()),
        "val_r2_mean": float(df_folds["val_r2"].mean()),
        "train_r2_mean": float(df_folds["train_r2"].mean()),
        "val_bias_mean": float(df_folds["val_bias"].mean()),
        "train_bias_mean": float(df_folds["train_bias"].mean()),

        "avg_selected_features": float(df_folds["n_features_selected"].mean()),
        "avg_total_features": float(df_folds["n_features_total"].mean()),
        **params,
    }

    print(
        f"   >> [{name}] "
        f"VAL RMSE: {out['val_rmse_mean']:.1f} | VAL R2: {out['val_r2_mean']:.4f} | "
        f"VAL MAE: {out['val_mae_mean']:.1f} | VAL Bias: {out['val_bias_mean']:.1f} | "
        f"Sel: {out['avg_selected_features']:.0f} feats"
    )

    logging.info(
        f"{name} | "
        f"VAL_RMSE={out['val_rmse_mean']:.6f} | VAL_MAE={out['val_mae_mean']:.6f} | "
        f"VAL_R2={out['val_r2_mean']:.6f} | VAL_BIAS={out['val_bias_mean']:.6f} | "
        f"TRAIN_RMSE={out['train_rmse_mean']:.6f} | TRAIN_MAE={out['train_mae_mean']:.6f} | "
        f"SelAvg={out['avg_selected_features']:.3f} | Params={params}"
    )

    return out

# results to store 
results = [] # stores the summary dict returned by each evaluated configuration
best_rmse = np.inf # to store the lowest therefore best validation rmse 
best_row = None  # stores the full result dict of the current best config

# iterate over the sampled configurations (name, params)
for i, (name, params) in enumerate(CONFIGS):
    # just to oganize in blocks of 5 for easier result tracking while running 
    if i % 5 == 0:
        print(f"\n-- doing {i+1}/{len(CONFIGS)}")

    # evaluate one configuration (returns fold metrics and params)
    res = eval_one_config(name, params)
    results.append(res)

    # we are looking for the best rmse, the lowest 
    if res["val_rmse_mean"] < best_rmse:
        best_rmse = res["val_rmse_mean"]
        best_row = res

results_df = pd.DataFrame(results) # converting to a dataframe for a better exploration of results 


# final results 
print("\n- TOP 10 Configurations (sorted by VAL RMSE)")
# sort configurations by validation RMSE (ascending = best first)
results_df_sorted = results_df.sort_values("val_rmse_mean", ascending=True)

# columns to display in the summary table
cols_show = [
    "config",
    "val_rmse_mean", "val_mae_mean", "val_r2_mean", "val_bias_mean",
    "train_rmse_mean", "train_mae_mean", "train_r2_mean", "train_bias_mean",
    "avg_selected_features",
    "learning_rate", "max_iter", "l2_regularization", "max_leaf_nodes", "max_depth", "min_samples_leaf"
]

display(results_df_sorted[cols_show].head(10))

OUT_CSV = "random_search_fe_fs_results_rmse_fs40m.csv"
results_df_sorted.to_csv(OUT_CSV, index=False)
print(f"stored at: {OUT_CSV}")
print(f"log in: {LOG_FILE}")

print("\n- BEST CONFIG (by VAL RMSE)")
print(f"Best config name: {best_row['config']}")
print(f"VAL RMSE: {best_row['val_rmse_mean']:.3f}")
print(f"VAL R2:   {best_row['val_r2_mean']:.6f}")
print(f"VAL MAE:  {best_row['val_mae_mean']:.3f}")
print(f"VAL Bias: {best_row['val_bias_mean']:.3f}")
print("Params:")
best_params = {k: best_row[k] for k in param_distributions.keys() if k in best_row}
print(best_params)
# Out:
# -- doing 1/10
#    >> [R0_iter600_lr0.106_l21.24_leaf31] VAL RMSE: 2258.0 | VAL R2: 0.9460 | VAL MAE: 1330.5 | VAL Bias: 115.2 | Sel: 10 feats
#    >> [R1_iter600_lr0.128_l20.61_leaf127] VAL RMSE: 2204.1 | VAL R2: 0.9486 | VAL MAE: 1283.1 | VAL Bias: 106.2 | Sel: 10 feats
#    >> [R2_iter600_lr0.102_l22.29_leaf31] VAL RMSE: 2214.7 | VAL R2: 0.9481 | VAL MAE: 1315.4 | VAL Bias: 113.7 | Sel: 10 feats
#    >> [R3_iter1000_lr0.098_l21.87_leaf127] VAL RMSE: 2198.2 | VAL R2: 0.9488 | VAL MAE: 1274.9 | VAL Bias: 102.8 | Sel: 10 feats
#    >> [R4_iter1000_lr0.087_l21.76_leaf31] VAL RMSE: 2224.5 | VAL R2: 0.9477 | VAL MAE: 1315.9 | VAL Bias: 115.8 | Sel: 10 feats
#
# -- doing 6/10
#    >> [R5_iter1000_lr0.132_l22.29_leaf127] VAL RMSE: 2187.3 | VAL R2: 0.9494 | VAL MAE: 1277.1 | VAL Bias: 102.0 | Sel: 10 feats
#    >> [R6_iter1000_lr0.121_l22.39_leaf127] VAL RMSE: 2191.1 | VAL R2: 0.9492 | VAL MAE: 1278.9 | VAL Bias: 106.3 | Sel: 10 feats
#    >> [R7_iter800_lr0.087_l21.24_leaf127] VAL RMSE: 2177.3 | VAL R2: 0.9498 | VAL MAE: 1272.9 | VAL Bias: 103.7 | Sel: 10 feats
#    >> [R8_iter1000_lr0.121_l21.66_leaf63] VAL RMSE: 2212.4 | VAL R2: 0.9482 | VAL MAE: 1298.1 | VAL Bias: 104.2 | Sel: 10 feats
#    >> [R9_iter600_lr0.098_l22.29_leaf127] VAL RMSE: 2192.2 | VAL R2: 0.9491 | VAL MAE: 1279.7 | VAL Bias: 103.9 | Sel: 10 feats
#
# - TOP 10 Configurations (sorted by VAL RMSE)
#                                config  val_rmse_mean  val_mae_mean  \
# 7   R7_iter800_lr0.087_l21.24_leaf127    2177.292010   1272.940690
# 5  R5_iter1000_lr0.132_l22.29_leaf127    2187.304950   1277.071765
# 6  R6_iter1000_lr0.121_l22.39_leaf127    2191.110307   1278.852152
# 9   R9_iter600_lr0.098_l22.29_leaf127    2192.174319   1279.665634
# 3  R3_iter1000_lr0.098_l21.87_leaf127    2198.229609   1274.853201
# 1   R1_iter600_lr0.128_l20.61_leaf127    2204.139364   1283.100182
# 8   R8_iter1000_lr0.121_l21.66_leaf63    2212.415800   1298.064926
# 2    R2_iter600_lr0.102_l22.29_leaf31    2214.660210   1315.444672
# 4   R4_iter1000_lr0.087_l21.76_leaf31    2224.474110   1315.882189
# 0    R0_iter600_lr0.106_l21.24_leaf31    2257.974041   1330.500056
#
#    val_r2_mean  val_bias_mean  train_rmse_mean  train_mae_mean  train_r2_mean  \
# 7     0.949809     103.732736      1726.908290     1041.011240       0.968481
# 5     0.949351     101.952819      1761.374143     1055.953663       0.967246
# 6     0.949191     106.335251      1752.768900     1056.397581       0.967517
# 9     0.949135     103.853989      1796.868191     1075.050526       0.965902
# 3     0.948846     102.752827      1759.065276     1052.338516       0.967306
# 1     0.948575     106.234771      1786.664902     1068.486536       0.966268
# 8     0.948217     104.175475      1863.179141     1129.129543       0.963345
# 2     0.948126     113.726211      1955.026018     1191.439421       0.959679
# 4     0.947663     115.808582      1947.869050     1187.089553       0.959961
# 0     0.946031     115.217229      2021.779228     1221.232065       0.956853
#
#    train_bias_mean  avg_selected_features  learning_rate  max_iter  \
# 7        87.399401                   10.0       0.087368       800
# 5        87.531484                   10.0       0.131579      1000
# 6        88.837337                   10.0       0.120526      1000
# 9        89.668026                   10.0       0.098421       600
# 3        87.895684                   10.0       0.098421      1000
# 1        88.212971                   10.0       0.127895       600
# 8        93.973927                   10.0       0.120526      1000
# 2       104.215276                   10.0       0.102105       600
# 4       104.434594                   10.0       0.087368      1000
# 0       106.550312                   10.0       0.105789       600
#
#    l2_regularization  max_leaf_nodes  max_depth  min_samples_leaf
# 7           1.236842             127       15.0                20
# 5           2.289474             127        NaN                30
# 6           2.394737             127       25.0                20
# 9           2.289474             127       25.0                40
# 3           1.868421             127        NaN                30
# 1           0.605263             127       25.0                40
# 8           1.657895              63       10.0                30
# 2           2.289474              31       25.0                20
# 4           1.763158              31        NaN                20
# 0           1.236842              31       15.0                40
# stored at: random_search_fe_fs_results_rmse_fs40m.csv
# log in: random_search_fe_fs_results_rmse_fs40m.log
#
# - BEST CONFIG (by VAL RMSE)
# Best config name: R7_iter800_lr0.087_l21.24_leaf127
# VAL RMSE: 2177.292
# VAL R2:   0.949809
# VAL MAE:  1272.941
# VAL Bias: 103.733
# Params:
# {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 15, 'learning_rate': np.float64(0.08736842105263158), 'l2_regularization': np.float64(1.236842105263158), 'max_bins': 255, 'random_state': 42}

# %% [markdown]
# - By selecting only up to 40% of most useful features, we were severely restriting our model.
# - This percentage corresponds to only 10 features. This value is even smaller than the amount of features used in section xxx (12).
# - The results were even worse than with the full engineered features (i.e. with no feature selection).

# %% [markdown]
# #### 3.3.3. Combining `age` and Excluding `previousOwners` Features

# %% [markdown]
# ##### 3.3.3.1. Without Feature Selection <a id="333nofs"></a>

# %%
# numeric features used by the model (year is replaced by age; previousOwners is excluded)
numeric_features = ["mileage", "engineSize", "tax", "mpg", "age"]

# shuffles the data, in order to (at least theoretically) have more balanced folds
# we will use an 8-fold cross-validation strategy
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# we explicitly exclude this feature from the model input
DROP_FROM_MODEL = ["previousOwners"]

# hyperparameter space that we are going to use for random search
# each configuration will get 1 value from each of these lists
param_distributions = {
    "loss": ["squared_error"],
    "learning_rate": [0.07, 0.085, 0.1, 0.115],
    "max_iter": [600, 800, 1000, 1200],
    "max_leaf_nodes": [63, 127, 191, 255],
    "l2_regularization": [0.3, 1.0, 3.0],
    "min_samples_leaf": [12, 16, 20, 28],
    "max_depth": [15, 20, 25, None],
}

N_RANDOM_CONFIGS = 15  # short random search, enough for baseline results

# we get N_RANDOM_CONFIGS random parameter combinations from param_distributions
sampler = ParameterSampler(param_distributions, n_iter=N_RANDOM_CONFIGS, random_state=RANDOM_STATE)

search_results = []  # stores results for ranking
best_rmse = np.inf
best_config = None

# log setup (mainly for development and traceability)
log_dir = "gb_logs"
os.makedirs(log_dir, exist_ok=True)
log_filename = "2gb_noowners_age_logprice_log2.txt"
log_path = os.path.join(log_dir, log_filename)

# Note: this section is included mainly for organization purposes
with open(log_path, "w", encoding="utf-8") as log_file:

    def log(msg: str):
        print(msg)
        log_file.write(msg + "\n")
        log_file.flush()

    log("# =============================")
    log("# START OF HGB SEARCH (LOG TARGET + AGE FEATURE)")
    log("# METRICS ON ORIGINAL SCALE: R2, RMSE, MAE, BIAS")
    log(f"# LOG FILE SAVED TO: {log_path}")
    log("# =============================")

    for config_id, params in enumerate(sampler, start=1):
        log("")
        log(f"######## CONFIG {config_id}/{N_RANDOM_CONFIGS} ########")
        log(f"Parameters: {params}")

        fold_rmses_val, fold_maes_val, fold_r2s_val, fold_bias_val = [], [], [], []
        fold_rmses_tr,  fold_maes_tr,  fold_r2s_tr,  fold_bias_tr  = [], [], [], []
        fold_med_ae = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):

            X_train, X_val = X.iloc[train_idx].copy(), X.iloc[val_idx].copy()
            y_train, y_val = y.iloc[train_idx].copy(), y.iloc[val_idx].copy()

            # log-transform target for training
            y_train_log = np.log1p(y_train)

            log(f"\n[C{config_id}|F{fold}] Processing fold...")

            # -> Preprocessing steps (fit only on training fold, apply to both)
            year_state = fit_year_median(X_train, year_col="year", model_col="model")
            X_train = transform_year_with_model_median(X_train, state=year_state)
            X_val   = transform_year_with_model_median(X_val,   state=year_state)

            mileage_state = fit_mileage_imputer(X_train, mileage_col="mileage", do_abs=True)
            X_train = transform_mileage_imputer(X_train, state=mileage_state)
            X_val   = transform_mileage_imputer(X_val,   state=mileage_state)

            engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
            X_train = transform_engine_size_imputer(X_train, state=engine_state)
            X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

            X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
            X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

            mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
            X_train = transform_mpg_imputer(X_train, state=mpg_state)
            X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

            brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
            X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
            X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

            model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
            X_train, _, _ = transform_invalid_models(X_train, model_state)
            X_val,   _, _ = transform_invalid_models(X_val,   model_state)

            transm_state = fit_transmission_resolver(X_train, valid_transmissions)
            X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
            X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

            fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
            X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
            X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

            # -> Feature engineering: create age and drop year (do this after all year-based steps)
            X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
            X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

            # hard guarantee: previousOwners is not used by the model
            X_train = X_train.drop(columns=DROP_FROM_MODEL, errors="ignore")
            X_val   = X_val.drop(columns=DROP_FROM_MODEL, errors="ignore")

            # -> Feature encoding (categorical only)
            high_card_features = ["Brand", "model"]
            low_card_features  = [c for c in categorical_features if c not in high_card_features]

            te = MyTargetEncoder(smoothing=5)
            te.fit(X_train[high_card_features], y_train_log)  # fit using log-target
            X_train_high = te.transform(X_train[high_card_features])
            X_val_high   = te.transform(X_val[high_card_features])

            ohe = MyOneHotEncoder()
            ohe.fit(X_train[low_card_features])
            X_train_low = ohe.transform(X_train[low_card_features])
            X_val_low   = ohe.transform(X_val[low_card_features])

            X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
            X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

            # join numerical and categorical (encoded) features
            X_train_final = pd.concat([X_train[numeric_features], X_train_cat], axis=1)
            X_val_final   = pd.concat([X_val[numeric_features],   X_val_cat],   axis=1)

            # align columns to avoid mismatch due to encoding
            X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

            if fold == 1:
                feature_names = list(X_train_final.columns)
                log(f"  > Features Used ({len(feature_names)}): {feature_names}")

            # -> Model training (train on log-target)
            hgb_model = HistGradientBoostingRegressor(random_state=RANDOM_STATE, **params)
            hgb_model.fit(X_train_final, y_train_log)

            # predictions (log scale), then invert to original scale
            y_pred_train_log = hgb_model.predict(X_train_final)
            y_pred_val_log   = hgb_model.predict(X_val_final)

            y_pred_train = np.expm1(y_pred_train_log)
            y_pred_val   = np.expm1(y_pred_val_log)

            # -> Metrics on original scale
            mae_tr  = mean_absolute_error(y_train, y_pred_train)
            rmse_tr = np.sqrt(mean_squared_error(y_train, y_pred_train))
            r2_tr   = r2_score(y_train, y_pred_train)
            bias_tr = np.mean(y_train - y_pred_train)

            mae_val  = mean_absolute_error(y_val, y_pred_val)
            rmse_val = np.sqrt(mean_squared_error(y_val, y_pred_val))
            r2_val   = r2_score(y_val, y_pred_val)
            bias_val = np.mean(y_val - y_pred_val)

            med_ae_val = median_absolute_error(y_val, y_pred_val)

            log(f"  > [TRAIN] R2: {r2_tr:.4f} | RMSE: {rmse_tr:.0f} | MAE: {mae_tr:.0f} | Bias: {bias_tr:.1f}")
            log(f"  > [VAL]   R2: {r2_val:.4f} | RMSE: {rmse_val:.0f} | MAE: {mae_val:.0f} | Bias: {bias_val:.1f}")

            fold_maes_tr.append(mae_tr);   fold_rmses_tr.append(rmse_tr);   fold_r2s_tr.append(r2_tr);   fold_bias_tr.append(bias_tr)
            fold_maes_val.append(mae_val); fold_rmses_val.append(rmse_val); fold_r2s_val.append(r2_val); fold_bias_val.append(bias_val)
            fold_med_ae.append(med_ae_val)

        mean_rmse_val = np.mean(fold_rmses_val)
        mean_mae_val  = np.mean(fold_maes_val)
        mean_r2_val   = np.mean(fold_r2s_val)
        mean_bias_val = np.mean(fold_bias_val)

        mean_mae_tr   = np.mean(fold_maes_tr)
        mean_r2_tr    = np.mean(fold_r2s_tr)
        mean_bias_tr  = np.mean(fold_bias_tr)

        log("")
        log(f"Config {config_id} SUMMARY:")
        log(f"  [TRAIN AVG] MAE: {mean_mae_tr:.1f} | R2: {mean_r2_tr:.4f} | Bias: {mean_bias_tr:.1f}")
        log(f"  [VAL AVG]   MAE: {mean_mae_val:.1f} | R2: {mean_r2_val:.4f} | Bias: {mean_bias_val:.1f} | RMSE: {mean_rmse_val:.1f}")

        search_results.append({
            "config_id": config_id,
            **params,

            "val_rmse": mean_rmse_val,
            "val_mae": mean_mae_val,
            "val_r2": mean_r2_val,
            "val_bias": mean_bias_val,

            "train_mae": mean_mae_tr,
            "train_r2": mean_r2_tr,
            "train_bias": mean_bias_tr,

            "val_med_ae": np.mean(fold_med_ae)
        })

        if mean_rmse_val < best_rmse:
            best_rmse = mean_rmse_val
            best_config = {**params}
            log(f"[NEW BEST RMSE] Config {config_id}")

    log("# END OF SEARCH")

# Results
results_df = pd.DataFrame(search_results)
results_df_sorted = results_df.sort_values(by="val_rmse", ascending=True)

print("\nTop 5 Configurations by RMSE:")
cols = ["config_id", "learning_rate", "max_iter", "val_rmse", "val_mae", "val_r2", "train_r2", "val_bias"]
display(results_df_sorted[cols].head(5))

print("\nBest Config found:")
print(best_config)
# Out:
# # =============================
# # START OF HGB SEARCH (LOG TARGET + AGE FEATURE)
# # METRICS ON ORIGINAL SCALE: R2, RMSE, MAE, BIAS
# # LOG FILE SAVED TO: gb_logs/2gb_noowners_age_logprice_log2.txt
# # =============================
#
# ######## CONFIG 1/15 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 255, 'max_iter': 800, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 0.3}
#
# [C1|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9675 | RMSE: 1761 | MAE: 1007 | Bias: 86.2
#   > [VAL]   R2: 0.9584 | RMSE: 1940 | MAE: 1238 | Bias: 61.7
#
# [C1|F2] Processing fold...
#   > [TRAIN] R2: 0.9733 | RMSE: 1593 | MAE: 973 | Bias: 76.6
#   > [VAL]   R2: 0.9494 | RMSE: 2179 | MAE: 1265 | Bias: 92.5
#
# [C1|F3] Processing fold...
#   > [TRAIN] R2: 0.9740 | RMSE: 1570 | MAE: 920 | Bias: 74.4
#   > [VAL]   R2: 0.9493 | RMSE: 2183 | MAE: 1254 | Bias: 137.9
#
# [C1|F4] Processing fold...
#   > [TRAIN] R2: 0.9765 | RMSE: 1485 | MAE: 937 | Bias: 72.1
#   > [VAL]   R2: 0.9333 | RMSE: 2618 | MAE: 1274 | Bias: 121.1
#
# [C1|F5] Processing fold...
#   > [TRAIN] R2: 0.9775 | RMSE: 1459 | MAE: 889 | Bias: 64.5
#   > [VAL]   R2: 0.9571 | RMSE: 2032 | MAE: 1229 | Bias: 91.0
#
# [C1|F6] Processing fold...
#   > [TRAIN] R2: 0.9765 | RMSE: 1492 | MAE: 902 | Bias: 72.8
#   > [VAL]   R2: 0.9537 | RMSE: 2112 | MAE: 1237 | Bias: 114.3
#
# [C1|F7] Processing fold...
#   > [TRAIN] R2: 0.9740 | RMSE: 1570 | MAE: 951 | Bias: 76.7
#   > [VAL]   R2: 0.9570 | RMSE: 2016 | MAE: 1216 | Bias: 112.1
#
# [C1|F8] Processing fold...
#   > [TRAIN] R2: 0.9765 | RMSE: 1499 | MAE: 926 | Bias: 75.2
#   > [VAL]   R2: 0.9556 | RMSE: 2001 | MAE: 1210 | Bias: 74.6
#
# Config 1 SUMMARY:
#   [TRAIN AVG] MAE: 938.2 | R2: 0.9745 | Bias: 74.8
#   [VAL AVG]   MAE: 1240.4 | R2: 0.9517 | Bias: 100.6 | RMSE: 2135.1
# [NEW BEST RMSE] Config 1
#
# ######## CONFIG 2/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 255, 'max_iter': 600, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 1.0}
#
# [C2|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9670 | RMSE: 1775 | MAE: 1015 | Bias: 85.8
#   > [VAL]   R2: 0.9583 | RMSE: 1943 | MAE: 1235 | Bias: 55.9
#
# [C2|F2] Processing fold...
#   > [TRAIN] R2: 0.9729 | RMSE: 1604 | MAE: 987 | Bias: 76.1
#   > [VAL]   R2: 0.9492 | RMSE: 2183 | MAE: 1262 | Bias: 83.7
#
# [C2|F3] Processing fold...
#   > [TRAIN] R2: 0.9706 | RMSE: 1670 | MAE: 990 | Bias: 80.4
#   > [VAL]   R2: 0.9488 | RMSE: 2193 | MAE: 1259 | Bias: 133.5
#
# [C2|F4] Processing fold...
#   > [TRAIN] R2: 0.9751 | RMSE: 1528 | MAE: 966 | Bias: 70.8
#   > [VAL]   R2: 0.9340 | RMSE: 2604 | MAE: 1280 | Bias: 123.4
#
# [C2|F5] Processing fold...
#   > [TRAIN] R2: 0.9710 | RMSE: 1656 | MAE: 1011 | Bias: 75.5
#   > [VAL]   R2: 0.9567 | RMSE: 2041 | MAE: 1252 | Bias: 86.5
#
# [C2|F6] Processing fold...
#   > [TRAIN] R2: 0.9712 | RMSE: 1650 | MAE: 999 | Bias: 80.6
#   > [VAL]   R2: 0.9535 | RMSE: 2118 | MAE: 1230 | Bias: 108.1
#
# [C2|F7] Processing fold...
#   > [TRAIN] R2: 0.9688 | RMSE: 1721 | MAE: 1045 | Bias: 85.9
#   > [VAL]   R2: 0.9571 | RMSE: 2014 | MAE: 1220 | Bias: 123.2
#
# [C2|F8] Processing fold...
#   > [TRAIN] R2: 0.9727 | RMSE: 1614 | MAE: 995 | Bias: 78.7
#   > [VAL]   R2: 0.9564 | RMSE: 1983 | MAE: 1211 | Bias: 70.8
#
# Config 2 SUMMARY:
#   [TRAIN AVG] MAE: 1001.0 | R2: 0.9712 | Bias: 79.2
#   [VAL AVG]   MAE: 1243.6 | R2: 0.9517 | Bias: 98.1 | RMSE: 2134.8
# [NEW BEST RMSE] Config 2
#
# ######## CONFIG 3/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C3|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9691 | RMSE: 1717 | MAE: 976 | Bias: 82.5
#   > [VAL]   R2: 0.9599 | RMSE: 1906 | MAE: 1216 | Bias: 48.9
#
# [C3|F2] Processing fold...
#   > [TRAIN] R2: 0.9694 | RMSE: 1705 | MAE: 1042 | Bias: 84.0
#   > [VAL]   R2: 0.9497 | RMSE: 2173 | MAE: 1269 | Bias: 86.9
#
# [C3|F3] Processing fold...
#   > [TRAIN] R2: 0.9713 | RMSE: 1651 | MAE: 974 | Bias: 80.5
#   > [VAL]   R2: 0.9474 | RMSE: 2223 | MAE: 1257 | Bias: 142.7
#
# [C3|F4] Processing fold...
#   > [TRAIN] R2: 0.9738 | RMSE: 1566 | MAE: 987 | Bias: 74.9
#   > [VAL]   R2: 0.9343 | RMSE: 2598 | MAE: 1279 | Bias: 130.6
#
# [C3|F5] Processing fold...
#   > [TRAIN] R2: 0.9731 | RMSE: 1595 | MAE: 972 | Bias: 72.2
#   > [VAL]   R2: 0.9577 | RMSE: 2018 | MAE: 1234 | Bias: 88.4
#
# [C3|F6] Processing fold...
#   > [TRAIN] R2: 0.9689 | RMSE: 1716 | MAE: 1032 | Bias: 85.7
#   > [VAL]   R2: 0.9502 | RMSE: 2191 | MAE: 1238 | Bias: 116.9
#
# [C3|F7] Processing fold...
#   > [TRAIN] R2: 0.9712 | RMSE: 1651 | MAE: 1004 | Bias: 83.2
#   > [VAL]   R2: 0.9581 | RMSE: 1992 | MAE: 1208 | Bias: 119.3
#
# [C3|F8] Processing fold...
#   > [TRAIN] R2: 0.9716 | RMSE: 1648 | MAE: 1015 | Bias: 82.6
#   > [VAL]   R2: 0.9569 | RMSE: 1972 | MAE: 1205 | Bias: 73.1
#
# Config 3 SUMMARY:
#   [TRAIN AVG] MAE: 1000.1 | R2: 0.9710 | Bias: 80.7
#   [VAL AVG]   MAE: 1238.0 | R2: 0.9517 | Bias: 100.8 | RMSE: 2134.2
# [NEW BEST RMSE] Config 3
#
# ######## CONFIG 4/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 600, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C4|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9658 | RMSE: 1806 | MAE: 1036 | Bias: 89.2
#   > [VAL]   R2: 0.9583 | RMSE: 1942 | MAE: 1236 | Bias: 57.9
#
# [C4|F2] Processing fold...
#   > [TRAIN] R2: 0.9678 | RMSE: 1748 | MAE: 1067 | Bias: 87.3
#   > [VAL]   R2: 0.9499 | RMSE: 2169 | MAE: 1280 | Bias: 88.9
#
# [C4|F3] Processing fold...
#   > [TRAIN] R2: 0.9671 | RMSE: 1768 | MAE: 1047 | Bias: 88.1
#   > [VAL]   R2: 0.9466 | RMSE: 2239 | MAE: 1266 | Bias: 139.7
#
# [C4|F4] Processing fold...
#   > [TRAIN] R2: 0.9723 | RMSE: 1610 | MAE: 1016 | Bias: 77.3
#   > [VAL]   R2: 0.9355 | RMSE: 2573 | MAE: 1273 | Bias: 125.3
#
# [C4|F5] Processing fold...
#   > [TRAIN] R2: 0.9701 | RMSE: 1682 | MAE: 1024 | Bias: 76.9
#   > [VAL]   R2: 0.9565 | RMSE: 2046 | MAE: 1243 | Bias: 88.5
#
# [C4|F6] Processing fold...
#   > [TRAIN] R2: 0.9686 | RMSE: 1723 | MAE: 1045 | Bias: 86.1
#   > [VAL]   R2: 0.9523 | RMSE: 2144 | MAE: 1234 | Bias: 113.0
#
# [C4|F7] Processing fold...
#   > [TRAIN] R2: 0.9673 | RMSE: 1762 | MAE: 1064 | Bias: 90.5
#   > [VAL]   R2: 0.9573 | RMSE: 2010 | MAE: 1225 | Bias: 125.8
#
# [C4|F8] Processing fold...
#   > [TRAIN] R2: 0.9674 | RMSE: 1763 | MAE: 1077 | Bias: 90.2
#   > [VAL]   R2: 0.9563 | RMSE: 1987 | MAE: 1220 | Bias: 70.3
#
# Config 4 SUMMARY:
#   [TRAIN AVG] MAE: 1046.9 | R2: 0.9683 | Bias: 85.7
#   [VAL AVG]   MAE: 1247.1 | R2: 0.9516 | Bias: 101.2 | RMSE: 2138.7
#
# ######## CONFIG 5/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C5|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9654 | RMSE: 1816 | MAE: 1046 | Bias: 90.1
#   > [VAL]   R2: 0.9587 | RMSE: 1934 | MAE: 1234 | Bias: 64.4
#
# [C5|F2] Processing fold...
#   > [TRAIN] R2: 0.9675 | RMSE: 1757 | MAE: 1072 | Bias: 88.8
#   > [VAL]   R2: 0.9507 | RMSE: 2151 | MAE: 1273 | Bias: 90.6
#
# [C5|F3] Processing fold...
#   > [TRAIN] R2: 0.9714 | RMSE: 1647 | MAE: 976 | Bias: 80.4
#   > [VAL]   R2: 0.9489 | RMSE: 2191 | MAE: 1256 | Bias: 136.4
#
# [C5|F4] Processing fold...
#   > [TRAIN] R2: 0.9680 | RMSE: 1732 | MAE: 1092 | Bias: 87.5
#   > [VAL]   R2: 0.9331 | RMSE: 2621 | MAE: 1303 | Bias: 132.2
#
# [C5|F5] Processing fold...
#   > [TRAIN] R2: 0.9727 | RMSE: 1608 | MAE: 981 | Bias: 72.5
#   > [VAL]   R2: 0.9574 | RMSE: 2024 | MAE: 1233 | Bias: 84.4
#
# [C5|F6] Processing fold...
#   > [TRAIN] R2: 0.9712 | RMSE: 1652 | MAE: 998 | Bias: 80.3
#   > [VAL]   R2: 0.9532 | RMSE: 2125 | MAE: 1232 | Bias: 107.6
#
# [C5|F7] Processing fold...
#   > [TRAIN] R2: 0.9689 | RMSE: 1717 | MAE: 1041 | Bias: 87.5
#   > [VAL]   R2: 0.9576 | RMSE: 2004 | MAE: 1224 | Bias: 123.4
#
# [C5|F8] Processing fold...
#   > [TRAIN] R2: 0.9745 | RMSE: 1559 | MAE: 962 | Bias: 76.8
#   > [VAL]   R2: 0.9573 | RMSE: 1964 | MAE: 1203 | Bias: 65.8
#
# Config 5 SUMMARY:
#   [TRAIN AVG] MAE: 1021.1 | R2: 0.9700 | Bias: 83.0
#   [VAL AVG]   MAE: 1244.9 | R2: 0.9521 | Bias: 100.6 | RMSE: 2126.5
# [NEW BEST RMSE] Config 5
#
# ######## CONFIG 6/15 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 191, 'max_iter': 1200, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}
#
# [C6|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9700 | RMSE: 1691 | MAE: 957 | Bias: 81.3
#   > [VAL]   R2: 0.9593 | RMSE: 1920 | MAE: 1221 | Bias: 53.8
#
# [C6|F2] Processing fold...
#   > [TRAIN] R2: 0.9717 | RMSE: 1638 | MAE: 1004 | Bias: 80.5
#   > [VAL]   R2: 0.9513 | RMSE: 2137 | MAE: 1261 | Bias: 96.7
#
# [C6|F3] Processing fold...
#   > [TRAIN] R2: 0.9727 | RMSE: 1610 | MAE: 953 | Bias: 79.0
#   > [VAL]   R2: 0.9493 | RMSE: 2183 | MAE: 1248 | Bias: 139.0
#
# [C6|F4] Processing fold...
#   > [TRAIN] R2: 0.9746 | RMSE: 1543 | MAE: 976 | Bias: 75.3
#   > [VAL]   R2: 0.9352 | RMSE: 2580 | MAE: 1273 | Bias: 127.4
#
# [C6|F5] Processing fold...
#   > [TRAIN] R2: 0.9754 | RMSE: 1526 | MAE: 933 | Bias: 69.1
#   > [VAL]   R2: 0.9576 | RMSE: 2019 | MAE: 1230 | Bias: 92.8
#
# [C6|F6] Processing fold...
#   > [TRAIN] R2: 0.9752 | RMSE: 1532 | MAE: 929 | Bias: 74.7
#   > [VAL]   R2: 0.9555 | RMSE: 2072 | MAE: 1219 | Bias: 107.3
#
# [C6|F7] Processing fold...
#   > [TRAIN] R2: 0.9709 | RMSE: 1660 | MAE: 1009 | Bias: 84.5
#   > [VAL]   R2: 0.9574 | RMSE: 2009 | MAE: 1211 | Bias: 121.1
#
# [C6|F8] Processing fold...
#   > [TRAIN] R2: 0.9726 | RMSE: 1617 | MAE: 993 | Bias: 82.3
#   > [VAL]   R2: 0.9567 | RMSE: 1976 | MAE: 1205 | Bias: 73.7
#
# Config 6 SUMMARY:
#   [TRAIN AVG] MAE: 969.2 | R2: 0.9729 | Bias: 78.4
#   [VAL AVG]   MAE: 1233.6 | R2: 0.9528 | Bias: 101.5 | RMSE: 2112.0
# [NEW BEST RMSE] Config 6
#
# ######## CONFIG 7/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 800, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 0.3}
#
# [C7|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9618 | RMSE: 1909 | MAE: 1117 | Bias: 98.7
#   > [VAL]   R2: 0.9574 | RMSE: 1963 | MAE: 1260 | Bias: 64.8
#
# [C7|F2] Processing fold...
#   > [TRAIN] R2: 0.9641 | RMSE: 1845 | MAE: 1134 | Bias: 96.3
#   > [VAL]   R2: 0.9495 | RMSE: 2177 | MAE: 1293 | Bias: 94.5
#
# [C7|F3] Processing fold...
#   > [TRAIN] R2: 0.9610 | RMSE: 1923 | MAE: 1150 | Bias: 100.5
#   > [VAL]   R2: 0.9444 | RMSE: 2286 | MAE: 1302 | Bias: 154.5
#
# [C7|F4] Processing fold...
#   > [TRAIN] R2: 0.9692 | RMSE: 1698 | MAE: 1074 | Bias: 85.6
#   > [VAL]   R2: 0.9356 | RMSE: 2572 | MAE: 1284 | Bias: 125.1
#
# [C7|F5] Processing fold...
#   > [TRAIN] R2: 0.9697 | RMSE: 1694 | MAE: 1042 | Bias: 80.1
#   > [VAL]   R2: 0.9572 | RMSE: 2028 | MAE: 1237 | Bias: 87.7
#
# [C7|F6] Processing fold...
#   > [TRAIN] R2: 0.9686 | RMSE: 1724 | MAE: 1053 | Bias: 87.6
#   > [VAL]   R2: 0.9519 | RMSE: 2152 | MAE: 1243 | Bias: 111.5
#
# [C7|F7] Processing fold...
#   > [TRAIN] R2: 0.9683 | RMSE: 1734 | MAE: 1059 | Bias: 90.1
#   > [VAL]   R2: 0.9573 | RMSE: 2010 | MAE: 1224 | Bias: 117.1
#
# [C7|F8] Processing fold...
#   > [TRAIN] R2: 0.9683 | RMSE: 1739 | MAE: 1077 | Bias: 90.6
#   > [VAL]   R2: 0.9552 | RMSE: 2011 | MAE: 1237 | Bias: 75.9
#
# Config 7 SUMMARY:
#   [TRAIN AVG] MAE: 1088.2 | R2: 0.9664 | Bias: 91.2
#   [VAL AVG]   MAE: 1259.9 | R2: 0.9511 | Bias: 103.9 | RMSE: 2150.0
#
# ######## CONFIG 8/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C8|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9650 | RMSE: 1827 | MAE: 1054 | Bias: 92.7
#   > [VAL]   R2: 0.9576 | RMSE: 1959 | MAE: 1243 | Bias: 65.4
#
# [C8|F2] Processing fold...
#   > [TRAIN] R2: 0.9710 | RMSE: 1660 | MAE: 1014 | Bias: 82.5
#   > [VAL]   R2: 0.9503 | RMSE: 2158 | MAE: 1263 | Bias: 89.1
#
# [C8|F3] Processing fold...
#   > [TRAIN] R2: 0.9722 | RMSE: 1625 | MAE: 958 | Bias: 78.9
#   > [VAL]   R2: 0.9492 | RMSE: 2185 | MAE: 1246 | Bias: 135.9
#
# [C8|F4] Processing fold...
#   > [TRAIN] R2: 0.9702 | RMSE: 1672 | MAE: 1050 | Bias: 83.4
#   > [VAL]   R2: 0.9334 | RMSE: 2615 | MAE: 1290 | Bias: 131.0
#
# [C8|F5] Processing fold...
#   > [TRAIN] R2: 0.9713 | RMSE: 1649 | MAE: 1007 | Bias: 76.4
#   > [VAL]   R2: 0.9561 | RMSE: 2056 | MAE: 1246 | Bias: 92.2
#
# [C8|F6] Processing fold...
#   > [TRAIN] R2: 0.9722 | RMSE: 1621 | MAE: 980 | Bias: 79.2
#   > [VAL]   R2: 0.9537 | RMSE: 2113 | MAE: 1227 | Bias: 108.0
#
# [C8|F7] Processing fold...
#   > [TRAIN] R2: 0.9642 | RMSE: 1843 | MAE: 1115 | Bias: 98.5
#   > [VAL]   R2: 0.9556 | RMSE: 2050 | MAE: 1249 | Bias: 127.2
#
# [C8|F8] Processing fold...
#   > [TRAIN] R2: 0.9724 | RMSE: 1622 | MAE: 995 | Bias: 82.0
#   > [VAL]   R2: 0.9572 | RMSE: 1965 | MAE: 1200 | Bias: 68.2
#
# Config 8 SUMMARY:
#   [TRAIN AVG] MAE: 1021.7 | R2: 0.9698 | Bias: 84.2
#   [VAL AVG]   MAE: 1245.4 | R2: 0.9516 | Bias: 102.1 | RMSE: 2137.5
#
# ######## CONFIG 9/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 0.3}
#
# [C9|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9677 | RMSE: 1756 | MAE: 1006 | Bias: 86.2
#   > [VAL]   R2: 0.9586 | RMSE: 1935 | MAE: 1230 | Bias: 56.8
#
# [C9|F2] Processing fold...
#   > [TRAIN] R2: 0.9724 | RMSE: 1619 | MAE: 989 | Bias: 78.3
#   > [VAL]   R2: 0.9482 | RMSE: 2205 | MAE: 1266 | Bias: 85.0
#
# [C9|F3] Processing fold...
#   > [TRAIN] R2: 0.9709 | RMSE: 1661 | MAE: 979 | Bias: 80.7
#   > [VAL]   R2: 0.9474 | RMSE: 2223 | MAE: 1260 | Bias: 143.0
#
# [C9|F4] Processing fold...
#   > [TRAIN] R2: 0.9762 | RMSE: 1492 | MAE: 944 | Bias: 70.1
#   > [VAL]   R2: 0.9347 | RMSE: 2590 | MAE: 1271 | Bias: 122.6
#
# [C9|F5] Processing fold...
#   > [TRAIN] R2: 0.9761 | RMSE: 1505 | MAE: 917 | Bias: 65.8
#   > [VAL]   R2: 0.9579 | RMSE: 2012 | MAE: 1229 | Bias: 83.8
#
# [C9|F6] Processing fold...
#   > [TRAIN] R2: 0.9740 | RMSE: 1569 | MAE: 946 | Bias: 75.1
#   > [VAL]   R2: 0.9542 | RMSE: 2102 | MAE: 1225 | Bias: 108.6
#
# [C9|F7] Processing fold...
#   > [TRAIN] R2: 0.9706 | RMSE: 1670 | MAE: 1014 | Bias: 83.2
#   > [VAL]   R2: 0.9571 | RMSE: 2015 | MAE: 1218 | Bias: 126.1
#
# [C9|F8] Processing fold...
#   > [TRAIN] R2: 0.9727 | RMSE: 1614 | MAE: 996 | Bias: 80.1
#   > [VAL]   R2: 0.9568 | RMSE: 1974 | MAE: 1206 | Bias: 67.4
#
# Config 9 SUMMARY:
#   [TRAIN AVG] MAE: 973.9 | R2: 0.9726 | Bias: 77.4
#   [VAL AVG]   MAE: 1238.1 | R2: 0.9518 | Bias: 99.2 | RMSE: 2132.2
#
# ######## CONFIG 10/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 1.0}
#
# [C10|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9675 | RMSE: 1761 | MAE: 1002 | Bias: 87.1
#   > [VAL]   R2: 0.9587 | RMSE: 1932 | MAE: 1232 | Bias: 58.2
#
# [C10|F2] Processing fold...
#   > [TRAIN] R2: 0.9716 | RMSE: 1643 | MAE: 999 | Bias: 79.6
#   > [VAL]   R2: 0.9499 | RMSE: 2168 | MAE: 1267 | Bias: 89.9
#
# [C10|F3] Processing fold...
#   > [TRAIN] R2: 0.9730 | RMSE: 1602 | MAE: 936 | Bias: 76.9
#   > [VAL]   R2: 0.9493 | RMSE: 2182 | MAE: 1249 | Bias: 132.1
#
# [C10|F4] Processing fold...
#   > [TRAIN] R2: 0.9724 | RMSE: 1608 | MAE: 1005 | Bias: 77.9
#   > [VAL]   R2: 0.9342 | RMSE: 2599 | MAE: 1282 | Bias: 131.5
#
# [C10|F5] Processing fold...
#   > [TRAIN] R2: 0.9738 | RMSE: 1574 | MAE: 956 | Bias: 70.8
#   > [VAL]   R2: 0.9574 | RMSE: 2025 | MAE: 1235 | Bias: 85.7
#
# [C10|F6] Processing fold...
#   > [TRAIN] R2: 0.9728 | RMSE: 1604 | MAE: 967 | Bias: 77.6
#   > [VAL]   R2: 0.9523 | RMSE: 2144 | MAE: 1224 | Bias: 102.2
#
# [C10|F7] Processing fold...
#   > [TRAIN] R2: 0.9695 | RMSE: 1702 | MAE: 1028 | Bias: 86.2
#   > [VAL]   R2: 0.9578 | RMSE: 1998 | MAE: 1216 | Bias: 117.7
#
# [C10|F8] Processing fold...
#   > [TRAIN] R2: 0.9731 | RMSE: 1603 | MAE: 980 | Bias: 79.9
#   > [VAL]   R2: 0.9564 | RMSE: 1983 | MAE: 1205 | Bias: 64.0
#
# Config 10 SUMMARY:
#   [TRAIN AVG] MAE: 984.2 | R2: 0.9717 | Bias: 79.5
#   [VAL AVG]   MAE: 1238.8 | R2: 0.9520 | Bias: 97.7 | RMSE: 2128.8
#
# ######## CONFIG 11/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}
#
# [C11|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9639 | RMSE: 1855 | MAE: 1068 | Bias: 93.5
#   > [VAL]   R2: 0.9578 | RMSE: 1955 | MAE: 1245 | Bias: 56.1
#
# [C11|F2] Processing fold...
#   > [TRAIN] R2: 0.9664 | RMSE: 1785 | MAE: 1082 | Bias: 88.7
#   > [VAL]   R2: 0.9495 | RMSE: 2176 | MAE: 1281 | Bias: 87.8
#
# [C11|F3] Processing fold...
#   > [TRAIN] R2: 0.9676 | RMSE: 1754 | MAE: 1042 | Bias: 87.2
#   > [VAL]   R2: 0.9476 | RMSE: 2219 | MAE: 1265 | Bias: 143.4
#
# [C11|F4] Processing fold...
#   > [TRAIN] R2: 0.9682 | RMSE: 1727 | MAE: 1079 | Bias: 84.7
#   > [VAL]   R2: 0.9336 | RMSE: 2612 | MAE: 1293 | Bias: 127.9
#
# [C11|F5] Processing fold...
#   > [TRAIN] R2: 0.9705 | RMSE: 1672 | MAE: 1019 | Bias: 75.6
#   > [VAL]   R2: 0.9579 | RMSE: 2013 | MAE: 1237 | Bias: 86.4
#
# [C11|F6] Processing fold...
#   > [TRAIN] R2: 0.9684 | RMSE: 1728 | MAE: 1047 | Bias: 85.7
#   > [VAL]   R2: 0.9523 | RMSE: 2143 | MAE: 1240 | Bias: 112.6
#
# [C11|F7] Processing fold...
#   > [TRAIN] R2: 0.9684 | RMSE: 1731 | MAE: 1050 | Bias: 88.6
#   > [VAL]   R2: 0.9580 | RMSE: 1993 | MAE: 1218 | Bias: 127.6
#
# [C11|F8] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1696 | MAE: 1042 | Bias: 85.8
#   > [VAL]   R2: 0.9568 | RMSE: 1975 | MAE: 1212 | Bias: 69.9
#
# Config 11 SUMMARY:
#   [TRAIN AVG] MAE: 1053.7 | R2: 0.9679 | Bias: 86.2
#   [VAL AVG]   MAE: 1248.9 | R2: 0.9517 | Bias: 101.5 | RMSE: 2135.8
#
# ######## CONFIG 12/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 3.0}
#
# [C12|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9674 | RMSE: 1764 | MAE: 1012 | Bias: 85.3
#   > [VAL]   R2: 0.9583 | RMSE: 1943 | MAE: 1237 | Bias: 54.2
#
# [C12|F2] Processing fold...
#   > [TRAIN] R2: 0.9652 | RMSE: 1818 | MAE: 1105 | Bias: 90.1
#   > [VAL]   R2: 0.9476 | RMSE: 2218 | MAE: 1293 | Bias: 91.7
#
# [C12|F3] Processing fold...
#   > [TRAIN] R2: 0.9691 | RMSE: 1712 | MAE: 1014 | Bias: 82.3
#   > [VAL]   R2: 0.9474 | RMSE: 2222 | MAE: 1264 | Bias: 137.3
#
# [C12|F4] Processing fold...
#   > [TRAIN] R2: 0.9690 | RMSE: 1704 | MAE: 1071 | Bias: 82.7
#   > [VAL]   R2: 0.9338 | RMSE: 2608 | MAE: 1289 | Bias: 127.1
#
# [C12|F5] Processing fold...
#   > [TRAIN] R2: 0.9710 | RMSE: 1658 | MAE: 1011 | Bias: 74.5
#   > [VAL]   R2: 0.9571 | RMSE: 2032 | MAE: 1245 | Bias: 83.3
#
# [C12|F6] Processing fold...
#   > [TRAIN] R2: 0.9721 | RMSE: 1625 | MAE: 985 | Bias: 77.6
#   > [VAL]   R2: 0.9544 | RMSE: 2097 | MAE: 1231 | Bias: 105.4
#
# [C12|F7] Processing fold...
#   > [TRAIN] R2: 0.9708 | RMSE: 1665 | MAE: 1014 | Bias: 83.0
#   > [VAL]   R2: 0.9574 | RMSE: 2007 | MAE: 1221 | Bias: 122.4
#
# [C12|F8] Processing fold...
#   > [TRAIN] R2: 0.9700 | RMSE: 1692 | MAE: 1039 | Bias: 85.1
#   > [VAL]   R2: 0.9563 | RMSE: 1986 | MAE: 1218 | Bias: 66.0
#
# Config 12 SUMMARY:
#   [TRAIN AVG] MAE: 1031.3 | R2: 0.9693 | Bias: 82.6
#   [VAL AVG]   MAE: 1249.9 | R2: 0.9515 | Bias: 98.4 | RMSE: 2139.0
#
# ######## CONFIG 13/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 600, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 0.3}
#
# [C13|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9623 | RMSE: 1896 | MAE: 1109 | Bias: 97.8
#   > [VAL]   R2: 0.9577 | RMSE: 1956 | MAE: 1254 | Bias: 62.3
#
# [C13|F2] Processing fold...
#   > [TRAIN] R2: 0.9596 | RMSE: 1959 | MAE: 1197 | Bias: 106.1
#   > [VAL]   R2: 0.9487 | RMSE: 2195 | MAE: 1326 | Bias: 99.3
#
# [C13|F3] Processing fold...
#   > [TRAIN] R2: 0.9646 | RMSE: 1832 | MAE: 1099 | Bias: 93.9
#   > [VAL]   R2: 0.9465 | RMSE: 2242 | MAE: 1278 | Bias: 150.9
#
# [C13|F4] Processing fold...
#   > [TRAIN] R2: 0.9671 | RMSE: 1756 | MAE: 1110 | Bias: 90.2
#   > [VAL]   R2: 0.9338 | RMSE: 2608 | MAE: 1301 | Bias: 132.0
#
# [C13|F5] Processing fold...
#   > [TRAIN] R2: 0.9662 | RMSE: 1789 | MAE: 1100 | Bias: 86.1
#   > [VAL]   R2: 0.9561 | RMSE: 2055 | MAE: 1257 | Bias: 89.1
#
# [C13|F6] Processing fold...
#   > [TRAIN] R2: 0.9658 | RMSE: 1798 | MAE: 1098 | Bias: 92.5
#   > [VAL]   R2: 0.9496 | RMSE: 2204 | MAE: 1262 | Bias: 118.8
#
# [C13|F7] Processing fold...
#   > [TRAIN] R2: 0.9660 | RMSE: 1795 | MAE: 1097 | Bias: 95.6
#   > [VAL]   R2: 0.9574 | RMSE: 2008 | MAE: 1231 | Bias: 131.7
#
# [C13|F8] Processing fold...
#   > [TRAIN] R2: 0.9670 | RMSE: 1776 | MAE: 1098 | Bias: 94.0
#   > [VAL]   R2: 0.9562 | RMSE: 1989 | MAE: 1233 | Bias: 74.5
#
# Config 13 SUMMARY:
#   [TRAIN AVG] MAE: 1113.5 | R2: 0.9648 | Bias: 94.5
#   [VAL AVG]   MAE: 1267.6 | R2: 0.9507 | Bias: 107.3 | RMSE: 2157.0
#
# ######## CONFIG 14/15 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C14|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9664 | RMSE: 1791 | MAE: 1038 | Bias: 90.5
#   > [VAL]   R2: 0.9582 | RMSE: 1944 | MAE: 1241 | Bias: 59.6
#
# [C14|F2] Processing fold...
#   > [TRAIN] R2: 0.9725 | RMSE: 1616 | MAE: 993 | Bias: 79.5
#   > [VAL]   R2: 0.9510 | RMSE: 2144 | MAE: 1260 | Bias: 90.0
#
# [C14|F3] Processing fold...
#   > [TRAIN] R2: 0.9742 | RMSE: 1566 | MAE: 926 | Bias: 75.8
#   > [VAL]   R2: 0.9504 | RMSE: 2158 | MAE: 1248 | Bias: 127.8
#
# [C14|F4] Processing fold...
#   > [TRAIN] R2: 0.9740 | RMSE: 1560 | MAE: 988 | Bias: 76.2
#   > [VAL]   R2: 0.9338 | RMSE: 2607 | MAE: 1275 | Bias: 125.1
#
# [C14|F5] Processing fold...
#   > [TRAIN] R2: 0.9726 | RMSE: 1610 | MAE: 989 | Bias: 74.5
#   > [VAL]   R2: 0.9577 | RMSE: 2017 | MAE: 1228 | Bias: 92.5
#
# [C14|F6] Processing fold...
#   > [TRAIN] R2: 0.9728 | RMSE: 1603 | MAE: 969 | Bias: 80.5
#   > [VAL]   R2: 0.9531 | RMSE: 2125 | MAE: 1230 | Bias: 118.2
#
# [C14|F7] Processing fold...
#   > [TRAIN] R2: 0.9723 | RMSE: 1619 | MAE: 989 | Bias: 81.4
#   > [VAL]   R2: 0.9581 | RMSE: 1990 | MAE: 1212 | Bias: 118.2
#
# [C14|F8] Processing fold...
#   > [TRAIN] R2: 0.9703 | RMSE: 1683 | MAE: 1033 | Bias: 86.4
#   > [VAL]   R2: 0.9562 | RMSE: 1988 | MAE: 1217 | Bias: 72.9
#
# Config 14 SUMMARY:
#   [TRAIN AVG] MAE: 990.6 | R2: 0.9719 | Bias: 80.6
#   [VAL AVG]   MAE: 1238.7 | R2: 0.9523 | Bias: 100.5 | RMSE: 2121.8
#
# ######## CONFIG 15/15 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 63, 'max_iter': 600, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 0.3}
#
# [C15|F1] Processing fold...
#   > Features Used (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > [TRAIN] R2: 0.9639 | RMSE: 1856 | MAE: 1087 | Bias: 93.4
#   > [VAL]   R2: 0.9581 | RMSE: 1947 | MAE: 1251 | Bias: 57.8
#
# [C15|F2] Processing fold...
#   > [TRAIN] R2: 0.9632 | RMSE: 1869 | MAE: 1152 | Bias: 98.9
#   > [VAL]   R2: 0.9494 | RMSE: 2179 | MAE: 1299 | Bias: 94.7
#
# [C15|F3] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1692 | MAE: 1011 | Bias: 82.7
#   > [VAL]   R2: 0.9495 | RMSE: 2177 | MAE: 1258 | Bias: 131.9
#
# [C15|F4] Processing fold...
#   > [TRAIN] R2: 0.9659 | RMSE: 1787 | MAE: 1126 | Bias: 90.6
#   > [VAL]   R2: 0.9328 | RMSE: 2628 | MAE: 1312 | Bias: 135.0
#
# [C15|F5] Processing fold...
#   > [TRAIN] R2: 0.9694 | RMSE: 1700 | MAE: 1051 | Bias: 79.8
#   > [VAL]   R2: 0.9570 | RMSE: 2033 | MAE: 1247 | Bias: 90.2
#
# [C15|F6] Processing fold...
#   > [TRAIN] R2: 0.9678 | RMSE: 1745 | MAE: 1072 | Bias: 89.3
#   > [VAL]   R2: 0.9524 | RMSE: 2142 | MAE: 1252 | Bias: 118.4
#
# [C15|F7] Processing fold...
#   > [TRAIN] R2: 0.9700 | RMSE: 1686 | MAE: 1034 | Bias: 86.0
#   > [VAL]   R2: 0.9576 | RMSE: 2003 | MAE: 1225 | Bias: 121.1
#
# [C15|F8] Processing fold...
#   > [TRAIN] R2: 0.9697 | RMSE: 1702 | MAE: 1054 | Bias: 88.6
#   > [VAL]   R2: 0.9560 | RMSE: 1992 | MAE: 1226 | Bias: 67.5
#
# Config 15 SUMMARY:
#   [TRAIN AVG] MAE: 1073.5 | R2: 0.9675 | Bias: 88.7
#   [VAL AVG]   MAE: 1258.8 | R2: 0.9516 | Bias: 102.1 | RMSE: 2137.6
# # END OF SEARCH
#
# Top 5 Configurations by RMSE:
#     config_id  learning_rate  max_iter     val_rmse      val_mae    val_r2  \
# 5           6          0.070      1200  2111.994401  1233.552411  0.952776
# 13         14          0.100       800  2121.766015  1238.732559  0.952332
# 4           5          0.100      1000  2126.522553  1244.870298  0.952103
# 9          10          0.085       600  2128.778358  1238.777999  0.952019
# 8           9          0.085       600  2132.198474  1238.055680  0.951850
#
#     train_r2    val_bias
# 5   0.972899  101.460000
# 13  0.971890  100.544328
# 4   0.969950  100.612786
# 9   0.971700   97.663201
# 8   0.972566   99.165096
# Best Config found:
# {'min_samples_leaf': 16, 'max_leaf_nodes': 191, 'max_iter': 1200, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}

# %% [markdown]
# ##### 3.3.3.2. With Feature Selection - Top 80% Features by Importance <a id="agenoown80"></a>

# %%
# numeric features used by the model (year is replaced by age; previousOwners is excluded)
numeric_features = ["mileage", "engineSize", "tax", "mpg", "age"]

# shuffles the data, in order to (at least theoretically) have more balanced folds
# we will use an 8-fold cross-validation strategy
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# we explicitly exclude this feature from the model input
DROP_FROM_MODEL = ["previousOwners"]

# feature selection: keep 80% of the final encoded feature space
FS_KEEP_RATIO = 0.80

# RandomForest used only to rank feature importances for SelectFromModel
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

# hyperparameter space that we are going to use for random search
# each configuration will get 1 value from each of these lists
param_distributions = {
    "loss": ["squared_error"],
    "learning_rate": [0.07, 0.085, 0.1, 0.115],
    "max_iter": [600, 800, 1000, 1200],
    "max_leaf_nodes": [63, 127, 191, 255],
    "l2_regularization": [0.3, 1.0, 3.0],
    "min_samples_leaf": [12, 16, 20, 28],
    "max_depth": [15, 20, 25, None],
}

N_RANDOM_CONFIGS = 15  # short random search, enough for baseline results

# we get N_RANDOM_CONFIGS random parameter combinations from param_distributions
sampler = ParameterSampler(param_distributions, n_iter=N_RANDOM_CONFIGS, random_state=RANDOM_STATE)

search_results = []  # stores results for ranking
best_rmse = np.inf
best_config = None

# log setup (mainly for development and traceability)
log_dir = "gb_logs"
os.makedirs(log_dir, exist_ok=True)
log_filename = "2gb_noowners_age_logprice_fs80m_log.txt"
log_path = os.path.join(log_dir, log_filename)

# Note: this section is included mainly for organization purposes
with open(log_path, "w", encoding="utf-8") as log_file:

    def log(msg: str):
        print(msg)
        log_file.write(msg + "\n")
        log_file.flush()

    log("# =============================")
    log("# START OF HGB SEARCH (LOG TARGET + AGE FEATURE + FS 90%)")
    log("# METRICS ON ORIGINAL SCALE: R2, RMSE, MAE, BIAS")
    log(f"# LOG FILE SAVED TO: {log_path}")
    log("# =============================")

    for config_id, params in enumerate(sampler, start=1):
        log("")
        log(f"######## CONFIG {config_id}/{N_RANDOM_CONFIGS} ########")
        log(f"Parameters: {params}")

        fold_rmses_val, fold_maes_val, fold_r2s_val, fold_bias_val = [], [], [], []
        fold_rmses_tr,  fold_maes_tr,  fold_r2s_tr,  fold_bias_tr  = [], [], [], []
        fold_med_ae = []
        fold_nsel = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):

            X_train, X_val = X.iloc[train_idx].copy(), X.iloc[val_idx].copy()
            y_train, y_val = y.iloc[train_idx].copy(), y.iloc[val_idx].copy()

            # log-transform target for training
            y_train_log = np.log1p(y_train)

            log(f"\n[C{config_id}|F{fold}] Processing fold...")

            # -> Preprocessing steps (fit only on training fold, apply to both)
            year_state = fit_year_median(X_train, year_col="year", model_col="model")
            X_train = transform_year_with_model_median(X_train, state=year_state)
            X_val   = transform_year_with_model_median(X_val,   state=year_state)

            mileage_state = fit_mileage_imputer(X_train, mileage_col="mileage", do_abs=True)
            X_train = transform_mileage_imputer(X_train, state=mileage_state)
            X_val   = transform_mileage_imputer(X_val,   state=mileage_state)

            engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
            X_train = transform_engine_size_imputer(X_train, state=engine_state)
            X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

            X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
            X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

            mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
            X_train = transform_mpg_imputer(X_train, state=mpg_state)
            X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

            brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
            X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
            X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

            model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
            X_train, _, _ = transform_invalid_models(X_train, model_state)
            X_val,   _, _ = transform_invalid_models(X_val,   model_state)

            transm_state = fit_transmission_resolver(X_train, valid_transmissions)
            X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
            X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

            fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
            X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
            X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

            # -> Feature engineering: create age and drop year (do this after all year-based steps)
            X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
            X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

            # hard guarantee: previousOwners is not used by the model
            X_train = X_train.drop(columns=DROP_FROM_MODEL, errors="ignore")
            X_val   = X_val.drop(columns=DROP_FROM_MODEL, errors="ignore")

            # -> Feature encoding (categorical only)
            high_card_features = ["Brand", "model"]
            low_card_features  = [c for c in categorical_features if c not in high_card_features]

            te = MyTargetEncoder(smoothing=5)
            te.fit(X_train[high_card_features], y_train_log)  # fit using log-target
            X_train_high = te.transform(X_train[high_card_features])
            X_val_high   = te.transform(X_val[high_card_features])

            ohe = MyOneHotEncoder()
            ohe.fit(X_train[low_card_features])
            X_train_low = ohe.transform(X_train[low_card_features])
            X_val_low   = ohe.transform(X_val[low_card_features])

            X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
            X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

            # join numerical and categorical (encoded) features
            X_train_final = pd.concat([X_train[numeric_features], X_train_cat], axis=1)
            X_val_final   = pd.concat([X_val[numeric_features],   X_val_cat],   axis=1)

            # align columns to avoid mismatch due to encoding
            X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

            if fold == 1:
                feature_names = list(X_train_final.columns)
                log(f"  > Features before FS ({len(feature_names)}): {feature_names}")

            # -> Feature selection (keep top 90% features by RF importance)
            n_feats = X_train_final.shape[1]
            k = int(np.ceil(FS_KEEP_RATIO * n_feats))
            k = max(1, min(k, n_feats))

            rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
            rf_fs.fit(X_train_final, y_train_log)

            selector = SelectFromModel(
                estimator=rf_fs,
                threshold=-np.inf,  # keep the top max_features
                max_features=k,
                prefit=True
            )

            selected_cols = X_train_final.columns[selector.get_support()]
            fold_nsel.append(len(selected_cols))

            X_train_sel = X_train_final[selected_cols]
            X_val_sel   = X_val_final[selected_cols]

            if fold == 1:
                log(f"  > Selected features ({len(selected_cols)}/{n_feats}) with FS_KEEP_RATIO={FS_KEEP_RATIO:.2f}")

            # -> Model training (train on log-target)
            hgb_model = HistGradientBoostingRegressor(random_state=RANDOM_STATE, **params)
            hgb_model.fit(X_train_sel, y_train_log)

            # predictions (log scale), then invert to original scale
            y_pred_train_log = hgb_model.predict(X_train_sel)
            y_pred_val_log   = hgb_model.predict(X_val_sel)

            y_pred_train = np.expm1(y_pred_train_log)
            y_pred_val   = np.expm1(y_pred_val_log)

            # -> Metrics on original scale
            mae_tr  = mean_absolute_error(y_train, y_pred_train)
            rmse_tr = np.sqrt(mean_squared_error(y_train, y_pred_train))
            r2_tr   = r2_score(y_train, y_pred_train)
            bias_tr = np.mean(y_train - y_pred_train)

            mae_val  = mean_absolute_error(y_val, y_pred_val)
            rmse_val = np.sqrt(mean_squared_error(y_val, y_pred_val))
            r2_val   = r2_score(y_val, y_pred_val)
            bias_val = np.mean(y_val - y_pred_val)

            med_ae_val = median_absolute_error(y_val, y_pred_val)

            log(f"  > [TRAIN] R2: {r2_tr:.4f} | RMSE: {rmse_tr:.0f} | MAE: {mae_tr:.0f} | Bias: {bias_tr:.1f}")
            log(f"  > [VAL]   R2: {r2_val:.4f} | RMSE: {rmse_val:.0f} | MAE: {mae_val:.0f} | Bias: {bias_val:.1f}")

            fold_maes_tr.append(mae_tr);   fold_rmses_tr.append(rmse_tr);   fold_r2s_tr.append(r2_tr);   fold_bias_tr.append(bias_tr)
            fold_maes_val.append(mae_val); fold_rmses_val.append(rmse_val); fold_r2s_val.append(r2_val); fold_bias_val.append(bias_val)
            fold_med_ae.append(med_ae_val)

        mean_rmse_val = np.mean(fold_rmses_val)
        mean_mae_val  = np.mean(fold_maes_val)
        mean_r2_val   = np.mean(fold_r2s_val)
        mean_bias_val = np.mean(fold_bias_val)

        mean_mae_tr   = np.mean(fold_maes_tr)
        mean_r2_tr    = np.mean(fold_r2s_tr)
        mean_bias_tr  = np.mean(fold_bias_tr)

        mean_nsel = float(np.mean(fold_nsel))

        log("")
        log(f"Config {config_id} SUMMARY:")
        log(f"  Selected features (avg): {mean_nsel:.0f} / {X.shape[1]} (note: final space is after encoding)")
        log(f"  [TRAIN AVG] MAE: {mean_mae_tr:.1f} | R2: {mean_r2_tr:.4f} | Bias: {mean_bias_tr:.1f}")
        log(f"  [VAL AVG]   MAE: {mean_mae_val:.1f} | R2: {mean_r2_val:.4f} | Bias: {mean_bias_val:.1f} | RMSE: {mean_rmse_val:.1f}")

        search_results.append({
            "config_id": config_id,
            **params,

            "fs_keep_ratio": FS_KEEP_RATIO,
            "avg_selected_features": mean_nsel,

            "val_rmse": mean_rmse_val,
            "val_mae": mean_mae_val,
            "val_r2": mean_r2_val,
            "val_bias": mean_bias_val,

            "train_mae": mean_mae_tr,
            "train_r2": mean_r2_tr,
            "train_bias": mean_bias_tr,

            "val_med_ae": np.mean(fold_med_ae)
        })

        if mean_rmse_val < best_rmse:
            best_rmse = mean_rmse_val
            best_config = {**params}
            log(f"[NEW BEST RMSE] Config {config_id}")

    log("# END OF SEARCH")

# Results
results_df = pd.DataFrame(search_results)
results_df_sorted = results_df.sort_values(by="val_rmse", ascending=True)

print("\nTop 5 Configurations by RMSE:")
cols = [
    "config_id", "fs_keep_ratio", "avg_selected_features",
    "learning_rate", "max_iter", "max_leaf_nodes", "max_depth",
    "val_rmse", "val_mae", "val_r2", "train_r2", "val_bias"
]
display(results_df_sorted[cols].head(5))

print("\nBest Config found:")
print(best_config)
# Out:
# # =============================
# # START OF HGB SEARCH (LOG TARGET + AGE FEATURE + FS 90%)
# # METRICS ON ORIGINAL SCALE: R2, RMSE, MAE, BIAS
# # LOG FILE SAVED TO: gb_logs/2gb_noowners_age_logprice_fs80m_log.txt
# # =============================
#
# ######## CONFIG 1/15 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 255, 'max_iter': 800, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 0.3}
#
# [C1|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9689 | RMSE: 1722 | MAE: 987 | Bias: 85.2
#   > [VAL]   R2: 0.9586 | RMSE: 1936 | MAE: 1234 | Bias: 57.3
#
# [C1|F2] Processing fold...
#   > [TRAIN] R2: 0.9731 | RMSE: 1598 | MAE: 984 | Bias: 77.9
#   > [VAL]   R2: 0.9489 | RMSE: 2190 | MAE: 1266 | Bias: 93.5
#
# [C1|F3] Processing fold...
#   > [TRAIN] R2: 0.9760 | RMSE: 1509 | MAE: 882 | Bias: 70.6
#   > [VAL]   R2: 0.9502 | RMSE: 2162 | MAE: 1255 | Bias: 130.2
#
# [C1|F4] Processing fold...
#   > [TRAIN] R2: 0.9770 | RMSE: 1469 | MAE: 931 | Bias: 71.3
#   > [VAL]   R2: 0.9333 | RMSE: 2618 | MAE: 1272 | Bias: 119.8
#
# [C1|F5] Processing fold...
#   > [TRAIN] R2: 0.9774 | RMSE: 1461 | MAE: 898 | Bias: 64.5
#   > [VAL]   R2: 0.9568 | RMSE: 2039 | MAE: 1234 | Bias: 87.3
#
# [C1|F6] Processing fold...
#   > [TRAIN] R2: 0.9693 | RMSE: 1704 | MAE: 1038 | Bias: 87.5
#   > [VAL]   R2: 0.9502 | RMSE: 2192 | MAE: 1252 | Bias: 119.4
#
# [C1|F7] Processing fold...
#   > [TRAIN] R2: 0.9730 | RMSE: 1601 | MAE: 976 | Bias: 79.5
#   > [VAL]   R2: 0.9569 | RMSE: 2020 | MAE: 1221 | Bias: 130.2
#
# [C1|F8] Processing fold...
#   > [TRAIN] R2: 0.9764 | RMSE: 1500 | MAE: 924 | Bias: 74.5
#   > [VAL]   R2: 0.9566 | RMSE: 1979 | MAE: 1207 | Bias: 71.1
#
# Config 1 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 952.5 | R2: 0.9739 | Bias: 76.4
#   [VAL AVG]   MAE: 1242.7 | R2: 0.9514 | Bias: 101.1 | RMSE: 2141.9
# [NEW BEST RMSE] Config 1
#
# ######## CONFIG 2/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 255, 'max_iter': 600, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 1.0}
#
# [C2|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9682 | RMSE: 1743 | MAE: 997 | Bias: 83.5
#   > [VAL]   R2: 0.9589 | RMSE: 1928 | MAE: 1231 | Bias: 53.3
#
# [C2|F2] Processing fold...
#   > [TRAIN] R2: 0.9685 | RMSE: 1730 | MAE: 1060 | Bias: 84.7
#   > [VAL]   R2: 0.9487 | RMSE: 2195 | MAE: 1278 | Bias: 85.2
#
# [C2|F3] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1691 | MAE: 1001 | Bias: 81.4
#   > [VAL]   R2: 0.9472 | RMSE: 2228 | MAE: 1267 | Bias: 138.0
#
# [C2|F4] Processing fold...
#   > [TRAIN] R2: 0.9723 | RMSE: 1611 | MAE: 1014 | Bias: 77.5
#   > [VAL]   R2: 0.9322 | RMSE: 2639 | MAE: 1288 | Bias: 127.3
#
# [C2|F5] Processing fold...
#   > [TRAIN] R2: 0.9767 | RMSE: 1483 | MAE: 908 | Bias: 64.3
#   > [VAL]   R2: 0.9578 | RMSE: 2015 | MAE: 1226 | Bias: 89.5
#
# [C2|F6] Processing fold...
#   > [TRAIN] R2: 0.9717 | RMSE: 1636 | MAE: 993 | Bias: 80.3
#   > [VAL]   R2: 0.9530 | RMSE: 2129 | MAE: 1232 | Bias: 109.4
#
# [C2|F7] Processing fold...
#   > [TRAIN] R2: 0.9697 | RMSE: 1695 | MAE: 1031 | Bias: 84.7
#   > [VAL]   R2: 0.9567 | RMSE: 2024 | MAE: 1224 | Bias: 123.0
#
# [C2|F8] Processing fold...
#   > [TRAIN] R2: 0.9741 | RMSE: 1571 | MAE: 967 | Bias: 76.4
#   > [VAL]   R2: 0.9567 | RMSE: 1977 | MAE: 1206 | Bias: 69.6
#
# Config 2 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 996.2 | R2: 0.9714 | Bias: 79.1
#   [VAL AVG]   MAE: 1243.9 | R2: 0.9514 | Bias: 99.4 | RMSE: 2141.8
# [NEW BEST RMSE] Config 2
#
# ######## CONFIG 3/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C3|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9687 | RMSE: 1728 | MAE: 983 | Bias: 84.1
#   > [VAL]   R2: 0.9592 | RMSE: 1921 | MAE: 1223 | Bias: 53.8
#
# [C3|F2] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1691 | MAE: 1038 | Bias: 84.3
#   > [VAL]   R2: 0.9496 | RMSE: 2175 | MAE: 1272 | Bias: 88.7
#
# [C3|F3] Processing fold...
#   > [TRAIN] R2: 0.9735 | RMSE: 1587 | MAE: 932 | Bias: 75.8
#   > [VAL]   R2: 0.9496 | RMSE: 2176 | MAE: 1245 | Bias: 137.2
#
# [C3|F4] Processing fold...
#   > [TRAIN] R2: 0.9724 | RMSE: 1608 | MAE: 1009 | Bias: 78.1
#   > [VAL]   R2: 0.9344 | RMSE: 2596 | MAE: 1277 | Bias: 122.6
#
# [C3|F5] Processing fold...
#   > [TRAIN] R2: 0.9740 | RMSE: 1567 | MAE: 957 | Bias: 70.5
#   > [VAL]   R2: 0.9581 | RMSE: 2007 | MAE: 1231 | Bias: 85.3
#
# [C3|F6] Processing fold...
#   > [TRAIN] R2: 0.9714 | RMSE: 1644 | MAE: 993 | Bias: 80.7
#   > [VAL]   R2: 0.9536 | RMSE: 2116 | MAE: 1225 | Bias: 110.2
#
# [C3|F7] Processing fold...
#   > [TRAIN] R2: 0.9708 | RMSE: 1665 | MAE: 1005 | Bias: 83.7
#   > [VAL]   R2: 0.9580 | RMSE: 1993 | MAE: 1214 | Bias: 122.1
#
# [C3|F8] Processing fold...
#   > [TRAIN] R2: 0.9719 | RMSE: 1638 | MAE: 1008 | Bias: 81.9
#   > [VAL]   R2: 0.9562 | RMSE: 1988 | MAE: 1211 | Bias: 68.5
#
# Config 3 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 990.7 | R2: 0.9716 | Bias: 79.9
#   [VAL AVG]   MAE: 1237.2 | R2: 0.9523 | Bias: 98.5 | RMSE: 2121.5
# [NEW BEST RMSE] Config 3
#
# ######## CONFIG 4/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 600, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C4|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9647 | RMSE: 1835 | MAE: 1053 | Bias: 91.2
#   > [VAL]   R2: 0.9578 | RMSE: 1955 | MAE: 1245 | Bias: 58.8
#
# [C4|F2] Processing fold...
#   > [TRAIN] R2: 0.9676 | RMSE: 1754 | MAE: 1065 | Bias: 87.0
#   > [VAL]   R2: 0.9496 | RMSE: 2174 | MAE: 1274 | Bias: 89.0
#
# [C4|F3] Processing fold...
#   > [TRAIN] R2: 0.9693 | RMSE: 1707 | MAE: 1011 | Bias: 82.9
#   > [VAL]   R2: 0.9477 | RMSE: 2216 | MAE: 1258 | Bias: 142.9
#
# [C4|F4] Processing fold...
#   > [TRAIN] R2: 0.9703 | RMSE: 1668 | MAE: 1046 | Bias: 81.2
#   > [VAL]   R2: 0.9354 | RMSE: 2576 | MAE: 1282 | Bias: 125.2
#
# [C4|F5] Processing fold...
#   > [TRAIN] R2: 0.9698 | RMSE: 1691 | MAE: 1028 | Bias: 77.0
#   > [VAL]   R2: 0.9566 | RMSE: 2044 | MAE: 1246 | Bias: 86.3
#
# [C4|F6] Processing fold...
#   > [TRAIN] R2: 0.9703 | RMSE: 1675 | MAE: 1014 | Bias: 81.9
#   > [VAL]   R2: 0.9531 | RMSE: 2125 | MAE: 1229 | Bias: 113.3
#
# [C4|F7] Processing fold...
#   > [TRAIN] R2: 0.9658 | RMSE: 1801 | MAE: 1082 | Bias: 92.4
#   > [VAL]   R2: 0.9565 | RMSE: 2028 | MAE: 1233 | Bias: 120.4
#
# [C4|F8] Processing fold...
#   > [TRAIN] R2: 0.9691 | RMSE: 1716 | MAE: 1051 | Bias: 87.1
#   > [VAL]   R2: 0.9565 | RMSE: 1981 | MAE: 1216 | Bias: 76.8
#
# Config 4 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1043.7 | R2: 0.9684 | Bias: 85.1
#   [VAL AVG]   MAE: 1247.8 | R2: 0.9517 | Bias: 101.6 | RMSE: 2137.4
#
# ######## CONFIG 5/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C5|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9667 | RMSE: 1781 | MAE: 1022 | Bias: 87.0
#   > [VAL]   R2: 0.9586 | RMSE: 1936 | MAE: 1232 | Bias: 54.8
#
# [C5|F2] Processing fold...
#   > [TRAIN] R2: 0.9674 | RMSE: 1759 | MAE: 1074 | Bias: 88.9
#   > [VAL]   R2: 0.9495 | RMSE: 2177 | MAE: 1282 | Bias: 92.3
#
# [C5|F3] Processing fold...
#   > [TRAIN] R2: 0.9735 | RMSE: 1587 | MAE: 939 | Bias: 76.4
#   > [VAL]   R2: 0.9503 | RMSE: 2160 | MAE: 1250 | Bias: 138.2
#
# [C5|F4] Processing fold...
#   > [TRAIN] R2: 0.9714 | RMSE: 1637 | MAE: 1025 | Bias: 80.5
#   > [VAL]   R2: 0.9332 | RMSE: 2620 | MAE: 1274 | Bias: 129.0
#
# [C5|F5] Processing fold...
#   > [TRAIN] R2: 0.9747 | RMSE: 1546 | MAE: 945 | Bias: 68.7
#   > [VAL]   R2: 0.9578 | RMSE: 2015 | MAE: 1228 | Bias: 87.2
#
# [C5|F6] Processing fold...
#   > [TRAIN] R2: 0.9730 | RMSE: 1597 | MAE: 968 | Bias: 77.4
#   > [VAL]   R2: 0.9540 | RMSE: 2105 | MAE: 1229 | Bias: 107.2
#
# [C5|F7] Processing fold...
#   > [TRAIN] R2: 0.9711 | RMSE: 1657 | MAE: 1007 | Bias: 83.3
#   > [VAL]   R2: 0.9584 | RMSE: 1983 | MAE: 1211 | Bias: 117.1
#
# [C5|F8] Processing fold...
#   > [TRAIN] R2: 0.9727 | RMSE: 1615 | MAE: 996 | Bias: 81.6
#   > [VAL]   R2: 0.9569 | RMSE: 1972 | MAE: 1205 | Bias: 69.1
#
# Config 5 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 997.1 | R2: 0.9713 | Bias: 80.5
#   [VAL AVG]   MAE: 1238.9 | R2: 0.9523 | Bias: 99.3 | RMSE: 2121.2
# [NEW BEST RMSE] Config 5
#
# ######## CONFIG 6/15 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 191, 'max_iter': 1200, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}
#
# [C6|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9683 | RMSE: 1738 | MAE: 991 | Bias: 85.6
#   > [VAL]   R2: 0.9593 | RMSE: 1919 | MAE: 1222 | Bias: 58.3
#
# [C6|F2] Processing fold...
#   > [TRAIN] R2: 0.9694 | RMSE: 1705 | MAE: 1039 | Bias: 85.0
#   > [VAL]   R2: 0.9511 | RMSE: 2142 | MAE: 1270 | Bias: 89.9
#
# [C6|F3] Processing fold...
#   > [TRAIN] R2: 0.9736 | RMSE: 1582 | MAE: 937 | Bias: 76.3
#   > [VAL]   R2: 0.9502 | RMSE: 2163 | MAE: 1241 | Bias: 131.5
#
# [C6|F4] Processing fold...
#   > [TRAIN] R2: 0.9705 | RMSE: 1663 | MAE: 1044 | Bias: 83.2
#   > [VAL]   R2: 0.9333 | RMSE: 2617 | MAE: 1295 | Bias: 130.4
#
# [C6|F5] Processing fold...
#   > [TRAIN] R2: 0.9741 | RMSE: 1564 | MAE: 956 | Bias: 71.3
#   > [VAL]   R2: 0.9577 | RMSE: 2018 | MAE: 1232 | Bias: 91.3
#
# [C6|F6] Processing fold...
#   > [TRAIN] R2: 0.9723 | RMSE: 1617 | MAE: 976 | Bias: 80.8
#   > [VAL]   R2: 0.9527 | RMSE: 2135 | MAE: 1228 | Bias: 111.7
#
# [C6|F7] Processing fold...
#   > [TRAIN] R2: 0.9722 | RMSE: 1623 | MAE: 990 | Bias: 82.6
#   > [VAL]   R2: 0.9586 | RMSE: 1979 | MAE: 1206 | Bias: 125.0
#
# [C6|F8] Processing fold...
#   > [TRAIN] R2: 0.9736 | RMSE: 1589 | MAE: 981 | Bias: 80.1
#   > [VAL]   R2: 0.9573 | RMSE: 1962 | MAE: 1200 | Bias: 67.3
#
# Config 6 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 989.3 | R2: 0.9718 | Bias: 80.6
#   [VAL AVG]   MAE: 1236.8 | R2: 0.9525 | Bias: 100.7 | RMSE: 2117.0
# [NEW BEST RMSE] Config 6
#
# ######## CONFIG 7/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 800, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 0.3}
#
# [C7|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9637 | RMSE: 1861 | MAE: 1087 | Bias: 94.3
#   > [VAL]   R2: 0.9576 | RMSE: 1958 | MAE: 1249 | Bias: 65.9
#
# [C7|F2] Processing fold...
#   > [TRAIN] R2: 0.9693 | RMSE: 1706 | MAE: 1054 | Bias: 84.7
#   > [VAL]   R2: 0.9507 | RMSE: 2151 | MAE: 1267 | Bias: 85.8
#
# [C7|F3] Processing fold...
#   > [TRAIN] R2: 0.9692 | RMSE: 1710 | MAE: 1023 | Bias: 85.4
#   > [VAL]   R2: 0.9492 | RMSE: 2184 | MAE: 1254 | Bias: 138.2
#
# [C7|F4] Processing fold...
#   > [TRAIN] R2: 0.9624 | RMSE: 1876 | MAE: 1173 | Bias: 97.7
#   > [VAL]   R2: 0.9315 | RMSE: 2653 | MAE: 1331 | Bias: 135.8
#
# [C7|F5] Processing fold...
#   > [TRAIN] R2: 0.9698 | RMSE: 1691 | MAE: 1040 | Bias: 78.5
#   > [VAL]   R2: 0.9572 | RMSE: 2029 | MAE: 1237 | Bias: 87.6
#
# [C7|F6] Processing fold...
#   > [TRAIN] R2: 0.9655 | RMSE: 1807 | MAE: 1102 | Bias: 92.2
#   > [VAL]   R2: 0.9504 | RMSE: 2186 | MAE: 1258 | Bias: 116.7
#
# [C7|F7] Processing fold...
#   > [TRAIN] R2: 0.9639 | RMSE: 1849 | MAE: 1129 | Bias: 98.5
#   > [VAL]   R2: 0.9567 | RMSE: 2025 | MAE: 1248 | Bias: 124.3
#
# [C7|F8] Processing fold...
#   > [TRAIN] R2: 0.9696 | RMSE: 1703 | MAE: 1051 | Bias: 87.3
#   > [VAL]   R2: 0.9555 | RMSE: 2005 | MAE: 1229 | Bias: 74.3
#
# Config 7 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1082.3 | R2: 0.9667 | Bias: 89.8
#   [VAL AVG]   MAE: 1259.2 | R2: 0.9511 | Bias: 103.6 | RMSE: 2148.8
#
# ######## CONFIG 8/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C8|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9675 | RMSE: 1761 | MAE: 1010 | Bias: 87.3
#   > [VAL]   R2: 0.9581 | RMSE: 1947 | MAE: 1233 | Bias: 64.5
#
# [C8|F2] Processing fold...
#   > [TRAIN] R2: 0.9692 | RMSE: 1711 | MAE: 1047 | Bias: 86.0
#   > [VAL]   R2: 0.9509 | RMSE: 2146 | MAE: 1265 | Bias: 81.9
#
# [C8|F3] Processing fold...
#   > [TRAIN] R2: 0.9653 | RMSE: 1815 | MAE: 1079 | Bias: 92.7
#   > [VAL]   R2: 0.9443 | RMSE: 2286 | MAE: 1278 | Bias: 149.7
#
# [C8|F4] Processing fold...
#   > [TRAIN] R2: 0.9696 | RMSE: 1687 | MAE: 1060 | Bias: 84.3
#   > [VAL]   R2: 0.9335 | RMSE: 2614 | MAE: 1289 | Bias: 126.8
#
# [C8|F5] Processing fold...
#   > [TRAIN] R2: 0.9704 | RMSE: 1672 | MAE: 1018 | Bias: 77.5
#   > [VAL]   R2: 0.9573 | RMSE: 2026 | MAE: 1236 | Bias: 89.8
#
# [C8|F6] Processing fold...
#   > [TRAIN] R2: 0.9694 | RMSE: 1702 | MAE: 1029 | Bias: 84.6
#   > [VAL]   R2: 0.9522 | RMSE: 2147 | MAE: 1234 | Bias: 109.2
#
# [C8|F7] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1689 | MAE: 1025 | Bias: 86.8
#   > [VAL]   R2: 0.9578 | RMSE: 1997 | MAE: 1215 | Bias: 114.7
#
# [C8|F8] Processing fold...
#   > [TRAIN] R2: 0.9736 | RMSE: 1587 | MAE: 974 | Bias: 79.7
#   > [VAL]   R2: 0.9577 | RMSE: 1953 | MAE: 1197 | Bias: 68.6
#
# Config 8 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1030.3 | R2: 0.9694 | Bias: 84.9
#   [VAL AVG]   MAE: 1243.2 | R2: 0.9515 | Bias: 100.6 | RMSE: 2139.5
#
# ######## CONFIG 9/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 0.3}
#
# [C9|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9662 | RMSE: 1795 | MAE: 1030 | Bias: 88.9
#   > [VAL]   R2: 0.9587 | RMSE: 1934 | MAE: 1234 | Bias: 54.9
#
# [C9|F2] Processing fold...
#   > [TRAIN] R2: 0.9712 | RMSE: 1654 | MAE: 1004 | Bias: 79.9
#   > [VAL]   R2: 0.9493 | RMSE: 2181 | MAE: 1262 | Bias: 83.6
#
# [C9|F3] Processing fold...
#   > [TRAIN] R2: 0.9706 | RMSE: 1671 | MAE: 983 | Bias: 82.0
#   > [VAL]   R2: 0.9464 | RMSE: 2243 | MAE: 1263 | Bias: 142.4
#
# [C9|F4] Processing fold...
#   > [TRAIN] R2: 0.9747 | RMSE: 1541 | MAE: 970 | Bias: 73.5
#   > [VAL]   R2: 0.9342 | RMSE: 2600 | MAE: 1276 | Bias: 130.7
#
# [C9|F5] Processing fold...
#   > [TRAIN] R2: 0.9741 | RMSE: 1567 | MAE: 958 | Bias: 70.3
#   > [VAL]   R2: 0.9582 | RMSE: 2005 | MAE: 1228 | Bias: 82.0
#
# [C9|F6] Processing fold...
#   > [TRAIN] R2: 0.9736 | RMSE: 1581 | MAE: 956 | Bias: 75.9
#   > [VAL]   R2: 0.9531 | RMSE: 2125 | MAE: 1223 | Bias: 108.2
#
# [C9|F7] Processing fold...
#   > [TRAIN] R2: 0.9728 | RMSE: 1607 | MAE: 975 | Bias: 78.9
#   > [VAL]   R2: 0.9578 | RMSE: 1999 | MAE: 1210 | Bias: 122.7
#
# [C9|F8] Processing fold...
#   > [TRAIN] R2: 0.9724 | RMSE: 1624 | MAE: 1000 | Bias: 81.4
#   > [VAL]   R2: 0.9568 | RMSE: 1975 | MAE: 1211 | Bias: 68.7
#
# Config 9 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 984.6 | R2: 0.9719 | Bias: 78.9
#   [VAL AVG]   MAE: 1238.3 | R2: 0.9518 | Bias: 99.1 | RMSE: 2132.9
#
# ######## CONFIG 10/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 1.0}
#
# [C10|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9689 | RMSE: 1724 | MAE: 980 | Bias: 84.5
#   > [VAL]   R2: 0.9588 | RMSE: 1932 | MAE: 1225 | Bias: 59.4
#
# [C10|F2] Processing fold...
#   > [TRAIN] R2: 0.9720 | RMSE: 1630 | MAE: 997 | Bias: 79.8
#   > [VAL]   R2: 0.9508 | RMSE: 2148 | MAE: 1264 | Bias: 86.5
#
# [C10|F3] Processing fold...
#   > [TRAIN] R2: 0.9718 | RMSE: 1637 | MAE: 961 | Bias: 79.4
#   > [VAL]   R2: 0.9477 | RMSE: 2217 | MAE: 1256 | Bias: 141.8
#
# [C10|F4] Processing fold...
#   > [TRAIN] R2: 0.9736 | RMSE: 1574 | MAE: 986 | Bias: 76.4
#   > [VAL]   R2: 0.9336 | RMSE: 2612 | MAE: 1280 | Bias: 129.3
#
# [C10|F5] Processing fold...
#   > [TRAIN] R2: 0.9741 | RMSE: 1565 | MAE: 952 | Bias: 70.8
#   > [VAL]   R2: 0.9581 | RMSE: 2009 | MAE: 1234 | Bias: 88.7
#
# [C10|F6] Processing fold...
#   > [TRAIN] R2: 0.9687 | RMSE: 1719 | MAE: 1033 | Bias: 86.2
#   > [VAL]   R2: 0.9511 | RMSE: 2172 | MAE: 1239 | Bias: 114.0
#
# [C10|F7] Processing fold...
#   > [TRAIN] R2: 0.9728 | RMSE: 1605 | MAE: 970 | Bias: 79.4
#   > [VAL]   R2: 0.9579 | RMSE: 1996 | MAE: 1208 | Bias: 125.2
#
# [C10|F8] Processing fold...
#   > [TRAIN] R2: 0.9737 | RMSE: 1586 | MAE: 968 | Bias: 78.5
#   > [VAL]   R2: 0.9570 | RMSE: 1969 | MAE: 1207 | Bias: 68.4
#
# Config 10 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 981.0 | R2: 0.9719 | Bias: 79.4
#   [VAL AVG]   MAE: 1239.2 | R2: 0.9519 | Bias: 101.7 | RMSE: 2131.9
#
# ######## CONFIG 11/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}
#
# [C11|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9652 | RMSE: 1823 | MAE: 1047 | Bias: 90.7
#   > [VAL]   R2: 0.9576 | RMSE: 1959 | MAE: 1240 | Bias: 59.6
#
# [C11|F2] Processing fold...
#   > [TRAIN] R2: 0.9674 | RMSE: 1760 | MAE: 1072 | Bias: 87.0
#   > [VAL]   R2: 0.9503 | RMSE: 2160 | MAE: 1274 | Bias: 92.6
#
# [C11|F3] Processing fold...
#   > [TRAIN] R2: 0.9678 | RMSE: 1748 | MAE: 1033 | Bias: 85.7
#   > [VAL]   R2: 0.9471 | RMSE: 2229 | MAE: 1258 | Bias: 143.7
#
# [C11|F4] Processing fold...
#   > [TRAIN] R2: 0.9686 | RMSE: 1715 | MAE: 1072 | Bias: 83.9
#   > [VAL]   R2: 0.9335 | RMSE: 2614 | MAE: 1287 | Bias: 127.8
#
# [C11|F5] Processing fold...
#   > [TRAIN] R2: 0.9694 | RMSE: 1701 | MAE: 1035 | Bias: 77.2
#   > [VAL]   R2: 0.9570 | RMSE: 2034 | MAE: 1244 | Bias: 84.4
#
# [C11|F6] Processing fold...
#   > [TRAIN] R2: 0.9700 | RMSE: 1684 | MAE: 1020 | Bias: 83.0
#   > [VAL]   R2: 0.9531 | RMSE: 2126 | MAE: 1237 | Bias: 115.0
#
# [C11|F7] Processing fold...
#   > [TRAIN] R2: 0.9668 | RMSE: 1775 | MAE: 1071 | Bias: 91.0
#   > [VAL]   R2: 0.9571 | RMSE: 2015 | MAE: 1226 | Bias: 129.0
#
# [C11|F8] Processing fold...
#   > [TRAIN] R2: 0.9710 | RMSE: 1663 | MAE: 1022 | Bias: 84.0
#   > [VAL]   R2: 0.9574 | RMSE: 1961 | MAE: 1203 | Bias: 64.9
#
# Config 11 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1046.4 | R2: 0.9683 | Bias: 85.3
#   [VAL AVG]   MAE: 1246.2 | R2: 0.9516 | Bias: 102.1 | RMSE: 2137.2
#
# ######## CONFIG 12/15 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 3.0}
#
# [C12|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9678 | RMSE: 1754 | MAE: 1005 | Bias: 84.5
#   > [VAL]   R2: 0.9585 | RMSE: 1938 | MAE: 1229 | Bias: 53.6
#
# [C12|F2] Processing fold...
#   > [TRAIN] R2: 0.9693 | RMSE: 1709 | MAE: 1041 | Bias: 82.2
#   > [VAL]   R2: 0.9504 | RMSE: 2157 | MAE: 1265 | Bias: 85.6
#
# [C12|F3] Processing fold...
#   > [TRAIN] R2: 0.9666 | RMSE: 1781 | MAE: 1054 | Bias: 86.5
#   > [VAL]   R2: 0.9458 | RMSE: 2257 | MAE: 1272 | Bias: 140.3
#
# [C12|F4] Processing fold...
#   > [TRAIN] R2: 0.9720 | RMSE: 1620 | MAE: 1022 | Bias: 77.8
#   > [VAL]   R2: 0.9353 | RMSE: 2578 | MAE: 1279 | Bias: 126.1
#
# [C12|F5] Processing fold...
#   > [TRAIN] R2: 0.9732 | RMSE: 1594 | MAE: 976 | Bias: 69.9
#   > [VAL]   R2: 0.9566 | RMSE: 2044 | MAE: 1241 | Bias: 80.1
#
# [C12|F6] Processing fold...
#   > [TRAIN] R2: 0.9689 | RMSE: 1714 | MAE: 1038 | Bias: 84.3
#   > [VAL]   R2: 0.9532 | RMSE: 2124 | MAE: 1239 | Bias: 114.3
#
# [C12|F7] Processing fold...
#   > [TRAIN] R2: 0.9708 | RMSE: 1665 | MAE: 1011 | Bias: 81.4
#   > [VAL]   R2: 0.9578 | RMSE: 1998 | MAE: 1215 | Bias: 121.9
#
# [C12|F8] Processing fold...
#   > [TRAIN] R2: 0.9708 | RMSE: 1670 | MAE: 1027 | Bias: 82.9
#   > [VAL]   R2: 0.9565 | RMSE: 1982 | MAE: 1212 | Bias: 69.1
#
# Config 12 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1021.7 | R2: 0.9699 | Bias: 81.2
#   [VAL AVG]   MAE: 1244.1 | R2: 0.9517 | Bias: 98.9 | RMSE: 2134.9
#
# ######## CONFIG 13/15 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 600, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 0.3}
#
# [C13|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9632 | RMSE: 1874 | MAE: 1098 | Bias: 96.2
#   > [VAL]   R2: 0.9574 | RMSE: 1964 | MAE: 1252 | Bias: 61.8
#
# [C13|F2] Processing fold...
#   > [TRAIN] R2: 0.9634 | RMSE: 1863 | MAE: 1141 | Bias: 97.2
#   > [VAL]   R2: 0.9503 | RMSE: 2160 | MAE: 1294 | Bias: 99.7
#
# [C13|F3] Processing fold...
#   > [TRAIN] R2: 0.9645 | RMSE: 1835 | MAE: 1102 | Bias: 94.3
#   > [VAL]   R2: 0.9461 | RMSE: 2250 | MAE: 1285 | Bias: 147.0
#
# [C13|F4] Processing fold...
#   > [TRAIN] R2: 0.9664 | RMSE: 1775 | MAE: 1122 | Bias: 91.4
#   > [VAL]   R2: 0.9342 | RMSE: 2600 | MAE: 1303 | Bias: 134.5
#
# [C13|F5] Processing fold...
#   > [TRAIN] R2: 0.9653 | RMSE: 1812 | MAE: 1111 | Bias: 88.0
#   > [VAL]   R2: 0.9556 | RMSE: 2067 | MAE: 1265 | Bias: 94.1
#
# [C13|F6] Processing fold...
#   > [TRAIN] R2: 0.9659 | RMSE: 1797 | MAE: 1097 | Bias: 93.1
#   > [VAL]   R2: 0.9505 | RMSE: 2185 | MAE: 1259 | Bias: 122.4
#
# [C13|F7] Processing fold...
#   > [TRAIN] R2: 0.9658 | RMSE: 1800 | MAE: 1101 | Bias: 95.4
#   > [VAL]   R2: 0.9575 | RMSE: 2006 | MAE: 1232 | Bias: 128.6
#
# [C13|F8] Processing fold...
#   > [TRAIN] R2: 0.9666 | RMSE: 1785 | MAE: 1099 | Bias: 93.5
#   > [VAL]   R2: 0.9553 | RMSE: 2009 | MAE: 1240 | Bias: 79.1
#
# Config 13 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1108.9 | R2: 0.9651 | Bias: 93.6
#   [VAL AVG]   MAE: 1266.4 | R2: 0.9508 | Bias: 108.4 | RMSE: 2155.2
#
# ######## CONFIG 14/15 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C14|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9652 | RMSE: 1823 | MAE: 1057 | Bias: 92.5
#   > [VAL]   R2: 0.9580 | RMSE: 1951 | MAE: 1243 | Bias: 67.3
#
# [C14|F2] Processing fold...
#   > [TRAIN] R2: 0.9675 | RMSE: 1757 | MAE: 1075 | Bias: 88.7
#   > [VAL]   R2: 0.9499 | RMSE: 2168 | MAE: 1277 | Bias: 87.7
#
# [C14|F3] Processing fold...
#   > [TRAIN] R2: 0.9692 | RMSE: 1710 | MAE: 1021 | Bias: 85.6
#   > [VAL]   R2: 0.9464 | RMSE: 2244 | MAE: 1271 | Bias: 139.4
#
# [C14|F4] Processing fold...
#   > [TRAIN] R2: 0.9720 | RMSE: 1621 | MAE: 1025 | Bias: 81.1
#   > [VAL]   R2: 0.9335 | RMSE: 2613 | MAE: 1276 | Bias: 128.4
#
# [C14|F5] Processing fold...
#   > [TRAIN] R2: 0.9735 | RMSE: 1582 | MAE: 968 | Bias: 72.2
#   > [VAL]   R2: 0.9578 | RMSE: 2016 | MAE: 1227 | Bias: 84.6
#
# [C14|F6] Processing fold...
#   > [TRAIN] R2: 0.9710 | RMSE: 1657 | MAE: 1007 | Bias: 82.2
#   > [VAL]   R2: 0.9522 | RMSE: 2147 | MAE: 1240 | Bias: 106.9
#
# [C14|F7] Processing fold...
#   > [TRAIN] R2: 0.9720 | RMSE: 1629 | MAE: 997 | Bias: 83.6
#   > [VAL]   R2: 0.9588 | RMSE: 1974 | MAE: 1209 | Bias: 118.1
#
# [C14|F8] Processing fold...
#   > [TRAIN] R2: 0.9730 | RMSE: 1605 | MAE: 992 | Bias: 80.6
#   > [VAL]   R2: 0.9573 | RMSE: 1964 | MAE: 1204 | Bias: 67.3
#
# Config 14 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1017.8 | R2: 0.9704 | Bias: 83.3
#   [VAL AVG]   MAE: 1243.4 | R2: 0.9517 | Bias: 100.0 | RMSE: 2134.5
#
# ######## CONFIG 15/15 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 63, 'max_iter': 600, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 0.3}
#
# [C15|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9648 | RMSE: 1832 | MAE: 1071 | Bias: 91.2
#   > [VAL]   R2: 0.9584 | RMSE: 1941 | MAE: 1242 | Bias: 54.3
#
# [C15|F2] Processing fold...
#   > [TRAIN] R2: 0.9675 | RMSE: 1756 | MAE: 1087 | Bias: 89.3
#   > [VAL]   R2: 0.9510 | RMSE: 2145 | MAE: 1278 | Bias: 90.0
#
# [C15|F3] Processing fold...
#   > [TRAIN] R2: 0.9662 | RMSE: 1790 | MAE: 1075 | Bias: 90.8
#   > [VAL]   R2: 0.9484 | RMSE: 2201 | MAE: 1274 | Bias: 144.1
#
# [C15|F4] Processing fold...
#   > [TRAIN] R2: 0.9667 | RMSE: 1765 | MAE: 1121 | Bias: 90.7
#   > [VAL]   R2: 0.9344 | RMSE: 2597 | MAE: 1315 | Bias: 123.1
#
# [C15|F5] Processing fold...
#   > [TRAIN] R2: 0.9718 | RMSE: 1634 | MAE: 1014 | Bias: 75.6
#   > [VAL]   R2: 0.9569 | RMSE: 2036 | MAE: 1238 | Bias: 97.3
#
# [C15|F6] Processing fold...
#   > [TRAIN] R2: 0.9706 | RMSE: 1668 | MAE: 1015 | Bias: 81.4
#   > [VAL]   R2: 0.9535 | RMSE: 2117 | MAE: 1236 | Bias: 105.1
#
# [C15|F7] Processing fold...
#   > [TRAIN] R2: 0.9713 | RMSE: 1650 | MAE: 1016 | Bias: 83.8
#   > [VAL]   R2: 0.9584 | RMSE: 1984 | MAE: 1214 | Bias: 119.4
#
# [C15|F8] Processing fold...
#   > [TRAIN] R2: 0.9667 | RMSE: 1784 | MAE: 1109 | Bias: 95.0
#   > [VAL]   R2: 0.9549 | RMSE: 2016 | MAE: 1246 | Bias: 79.2
#
# Config 15 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1063.6 | R2: 0.9682 | Bias: 87.2
#   [VAL AVG]   MAE: 1255.3 | R2: 0.9520 | Bias: 101.5 | RMSE: 2129.5
# # END OF SEARCH
#
# Top 5 Configurations by RMSE:
#     config_id  fs_keep_ratio  avg_selected_features  learning_rate  max_iter  \
# 5           6            0.8                   12.0          0.070      1200
# 4           5            0.8                   12.0          0.100      1000
# 2           3            0.8                   12.0          0.070      1000
# 14         15            0.8                   12.0          0.115       600
# 9          10            0.8                   12.0          0.085       600
#
#     max_leaf_nodes  max_depth     val_rmse      val_mae    val_r2  train_r2  \
# 5              191       20.0  2116.974820  1236.810614  0.952526  0.971761
# 4              127       20.0  2121.218946  1238.917719  0.952332  0.971316
# 2              191       20.0  2121.478669  1237.194927  0.952336  0.971577
# 14              63       15.0  2129.507430  1255.327475  0.951988  0.968211
# 9              191        NaN  2131.900813  1239.206744  0.951855  0.971941
#
#       val_bias
# 5   100.680401
# 4    99.348072
# 2    98.529767
# 14  101.549300
# 9   101.659191
# Best Config found:
# {'min_samples_leaf': 16, 'max_leaf_nodes': 191, 'max_iter': 1200, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}

# %%
# numeric features used by the model (year is replaced by age; previousOwners is excluded)
numeric_features = ["mileage", "engineSize", "tax", "mpg", "age"]

# shuffles the data, in order to (at least theoretically) have more balanced folds
# we will use an 8-fold cross-validation strategy
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# we explicitly exclude this feature from the model input
DROP_FROM_MODEL = ["previousOwners"]

# feature selection: keep 80% of the final encoded feature space
FS_KEEP_RATIO = 0.80

# RandomForest used only to rank feature importances for SelectFromModel
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

# hyperparameter space that we are going to use for random search
# each configuration will get 1 value from each of these lists
param_distributions = {
    "loss": ["squared_error"],
    "learning_rate": [0.07, 0.085, 0.1, 0.115],
    "max_iter": [600, 800, 1000, 1200],
    "max_leaf_nodes": [63, 127, 191, 255],
    "l2_regularization": [0.3, 1.0, 3.0],
    "min_samples_leaf": [12, 16, 20, 28],
    "max_depth": [15, 20, 25, None],
}

N_RANDOM_CONFIGS = 55  # short random search, enough for baseline results

# we get N_RANDOM_CONFIGS random parameter combinations from param_distributions
sampler = ParameterSampler(param_distributions, n_iter=N_RANDOM_CONFIGS, random_state=RANDOM_STATE)

search_results = []  # stores results for ranking
best_rmse = np.inf
best_config = None

# log setup (mainly for development and traceability)
log_dir = "gb_logs"
os.makedirs(log_dir, exist_ok=True)
log_filename = "2gb_noowners_age_logprice_fs80m_log55it.txt"
log_path = os.path.join(log_dir, log_filename)

# Note: this section is included mainly for organization purposes
with open(log_path, "w", encoding="utf-8") as log_file:

    def log(msg: str):
        print(msg)
        log_file.write(msg + "\n")
        log_file.flush()

    log("# =============================")
    log("# START OF HGB SEARCH (LOG TARGET + AGE FEATURE + FS 90%)")
    log("# METRICS ON ORIGINAL SCALE: R2, RMSE, MAE, BIAS")
    log(f"# LOG FILE SAVED TO: {log_path}")
    log("# =============================")

    for config_id, params in enumerate(sampler, start=1):
        log("")
        log(f"######## CONFIG {config_id}/{N_RANDOM_CONFIGS} ########")
        log(f"Parameters: {params}")

        fold_rmses_val, fold_maes_val, fold_r2s_val, fold_bias_val = [], [], [], []
        fold_rmses_tr,  fold_maes_tr,  fold_r2s_tr,  fold_bias_tr  = [], [], [], []
        fold_med_ae = []
        fold_nsel = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):

            X_train, X_val = X.iloc[train_idx].copy(), X.iloc[val_idx].copy()
            y_train, y_val = y.iloc[train_idx].copy(), y.iloc[val_idx].copy()

            # log-transform target for training
            y_train_log = np.log1p(y_train)

            log(f"\n[C{config_id}|F{fold}] Processing fold...")

            # -> Preprocessing steps (fit only on training fold, apply to both)
            year_state = fit_year_median(X_train, year_col="year", model_col="model")
            X_train = transform_year_with_model_median(X_train, state=year_state)
            X_val   = transform_year_with_model_median(X_val,   state=year_state)

            mileage_state = fit_mileage_imputer(X_train, mileage_col="mileage", do_abs=True)
            X_train = transform_mileage_imputer(X_train, state=mileage_state)
            X_val   = transform_mileage_imputer(X_val,   state=mileage_state)

            engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
            X_train = transform_engine_size_imputer(X_train, state=engine_state)
            X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

            X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
            X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

            mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
            X_train = transform_mpg_imputer(X_train, state=mpg_state)
            X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

            brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
            X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
            X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

            model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
            X_train, _, _ = transform_invalid_models(X_train, model_state)
            X_val,   _, _ = transform_invalid_models(X_val,   model_state)

            transm_state = fit_transmission_resolver(X_train, valid_transmissions)
            X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
            X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

            fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
            X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
            X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

            # -> Feature engineering: create age and drop year (do this after all year-based steps)
            X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
            X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

            # hard guarantee: previousOwners is not used by the model
            X_train = X_train.drop(columns=DROP_FROM_MODEL, errors="ignore")
            X_val   = X_val.drop(columns=DROP_FROM_MODEL, errors="ignore")

            # -> Feature encoding (categorical only)
            high_card_features = ["Brand", "model"]
            low_card_features  = [c for c in categorical_features if c not in high_card_features]

            te = MyTargetEncoder(smoothing=5)
            te.fit(X_train[high_card_features], y_train_log)  # fit using log-target
            X_train_high = te.transform(X_train[high_card_features])
            X_val_high   = te.transform(X_val[high_card_features])

            ohe = MyOneHotEncoder()
            ohe.fit(X_train[low_card_features])
            X_train_low = ohe.transform(X_train[low_card_features])
            X_val_low   = ohe.transform(X_val[low_card_features])

            X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
            X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

            # join numerical and categorical (encoded) features
            X_train_final = pd.concat([X_train[numeric_features], X_train_cat], axis=1)
            X_val_final   = pd.concat([X_val[numeric_features],   X_val_cat],   axis=1)

            # align columns to avoid mismatch due to encoding
            X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

            if fold == 1:
                feature_names = list(X_train_final.columns)
                log(f"  > Features before FS ({len(feature_names)}): {feature_names}")

            # -> Feature selection (keep top 90% features by RF importance)
            n_feats = X_train_final.shape[1]
            k = int(np.ceil(FS_KEEP_RATIO * n_feats))
            k = max(1, min(k, n_feats))

            rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
            rf_fs.fit(X_train_final, y_train_log)

            selector = SelectFromModel(
                estimator=rf_fs,
                threshold=-np.inf,  # keep the top max_features
                max_features=k,
                prefit=True
            )

            selected_cols = X_train_final.columns[selector.get_support()]
            fold_nsel.append(len(selected_cols))

            X_train_sel = X_train_final[selected_cols]
            X_val_sel   = X_val_final[selected_cols]

            if fold == 1:
                log(f"  > Selected features ({len(selected_cols)}/{n_feats}) with FS_KEEP_RATIO={FS_KEEP_RATIO:.2f}")

            # -> Model training (train on log-target)
            hgb_model = HistGradientBoostingRegressor(random_state=RANDOM_STATE, **params)
            hgb_model.fit(X_train_sel, y_train_log)

            # predictions (log scale), then invert to original scale
            y_pred_train_log = hgb_model.predict(X_train_sel)
            y_pred_val_log   = hgb_model.predict(X_val_sel)

            y_pred_train = np.expm1(y_pred_train_log)
            y_pred_val   = np.expm1(y_pred_val_log)

            # -> Metrics on original scale
            mae_tr  = mean_absolute_error(y_train, y_pred_train)
            rmse_tr = np.sqrt(mean_squared_error(y_train, y_pred_train))
            r2_tr   = r2_score(y_train, y_pred_train)
            bias_tr = np.mean(y_train - y_pred_train)

            mae_val  = mean_absolute_error(y_val, y_pred_val)
            rmse_val = np.sqrt(mean_squared_error(y_val, y_pred_val))
            r2_val   = r2_score(y_val, y_pred_val)
            bias_val = np.mean(y_val - y_pred_val)

            med_ae_val = median_absolute_error(y_val, y_pred_val)

            log(f"  > [TRAIN] R2: {r2_tr:.4f} | RMSE: {rmse_tr:.0f} | MAE: {mae_tr:.0f} | Bias: {bias_tr:.1f}")
            log(f"  > [VAL]   R2: {r2_val:.4f} | RMSE: {rmse_val:.0f} | MAE: {mae_val:.0f} | Bias: {bias_val:.1f}")

            fold_maes_tr.append(mae_tr);   fold_rmses_tr.append(rmse_tr);   fold_r2s_tr.append(r2_tr);   fold_bias_tr.append(bias_tr)
            fold_maes_val.append(mae_val); fold_rmses_val.append(rmse_val); fold_r2s_val.append(r2_val); fold_bias_val.append(bias_val)
            fold_med_ae.append(med_ae_val)

        mean_rmse_val = np.mean(fold_rmses_val)
        mean_mae_val  = np.mean(fold_maes_val)
        mean_r2_val   = np.mean(fold_r2s_val)
        mean_bias_val = np.mean(fold_bias_val)

        mean_mae_tr   = np.mean(fold_maes_tr)
        mean_r2_tr    = np.mean(fold_r2s_tr)
        mean_bias_tr  = np.mean(fold_bias_tr)

        mean_nsel = float(np.mean(fold_nsel))

        log("")
        log(f"Config {config_id} SUMMARY:")
        log(f"  Selected features (avg): {mean_nsel:.0f} / {X.shape[1]} (note: final space is after encoding)")
        log(f"  [TRAIN AVG] MAE: {mean_mae_tr:.1f} | R2: {mean_r2_tr:.4f} | Bias: {mean_bias_tr:.1f}")
        log(f"  [VAL AVG]   MAE: {mean_mae_val:.1f} | R2: {mean_r2_val:.4f} | Bias: {mean_bias_val:.1f} | RMSE: {mean_rmse_val:.1f}")

        search_results.append({
            "config_id": config_id,
            **params,

            "fs_keep_ratio": FS_KEEP_RATIO,
            "avg_selected_features": mean_nsel,

            "val_rmse": mean_rmse_val,
            "val_mae": mean_mae_val,
            "val_r2": mean_r2_val,
            "val_bias": mean_bias_val,

            "train_mae": mean_mae_tr,
            "train_r2": mean_r2_tr,
            "train_bias": mean_bias_tr,

            "val_med_ae": np.mean(fold_med_ae)
        })

        if mean_rmse_val < best_rmse:
            best_rmse = mean_rmse_val
            best_config = {**params}
            log(f"[NEW BEST RMSE] Config {config_id}")

    log("# END OF SEARCH")

# Results
results_df = pd.DataFrame(search_results)
results_df_sorted = results_df.sort_values(by="val_rmse", ascending=True)
    
print("\nTop 5 Configurations by RMSE:")
cols = [
    "config_id", "fs_keep_ratio", "avg_selected_features",
    "learning_rate", "max_iter", "max_leaf_nodes", "max_depth",
    "val_rmse", "val_mae", "val_r2", "train_r2", "val_bias"
]
display(results_df_sorted[cols].head(5))

print("\nBest Config found:")
print(best_config)
# Out:
# # =============================
# # START OF HGB SEARCH (LOG TARGET + AGE FEATURE + FS 90%)
# # METRICS ON ORIGINAL SCALE: R2, RMSE, MAE, BIAS
# # LOG FILE SAVED TO: gb_logs/2gb_noowners_age_logprice_fs80m_log55it.txt
# # =============================
#
# ######## CONFIG 1/55 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 3.0}
#
# [C1|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9716 | RMSE: 1645 | MAE: 924 | Bias: 80.2
#   > [VAL]   R2: 0.9597 | RMSE: 1910 | MAE: 1215 | Bias: 48.7
#
# [C1|F2] Processing fold...
#   > [TRAIN] R2: 0.9751 | RMSE: 1537 | MAE: 944 | Bias: 74.8
#   > [VAL]   R2: 0.9510 | RMSE: 2145 | MAE: 1256 | Bias: 93.5
#
# [C1|F3] Processing fold...
#   > [TRAIN] R2: 0.9742 | RMSE: 1564 | MAE: 924 | Bias: 75.7
#   > [VAL]   R2: 0.9484 | RMSE: 2201 | MAE: 1248 | Bias: 131.0
#
# [C1|F4] Processing fold...
#   > [TRAIN] R2: 0.9750 | RMSE: 1529 | MAE: 963 | Bias: 75.3
#   > [VAL]   R2: 0.9347 | RMSE: 2589 | MAE: 1266 | Bias: 129.9
#
# [C1|F5] Processing fold...
#   > [TRAIN] R2: 0.9748 | RMSE: 1545 | MAE: 947 | Bias: 70.8
#   > [VAL]   R2: 0.9575 | RMSE: 2023 | MAE: 1227 | Bias: 96.9
#
# [C1|F6] Processing fold...
#   > [TRAIN] R2: 0.9741 | RMSE: 1565 | MAE: 949 | Bias: 77.7
#   > [VAL]   R2: 0.9531 | RMSE: 2126 | MAE: 1227 | Bias: 113.3
#
# [C1|F7] Processing fold...
#   > [TRAIN] R2: 0.9750 | RMSE: 1540 | MAE: 938 | Bias: 77.4
#   > [VAL]   R2: 0.9578 | RMSE: 1997 | MAE: 1204 | Bias: 123.5
#
# [C1|F8] Processing fold...
#   > [TRAIN] R2: 0.9769 | RMSE: 1485 | MAE: 917 | Bias: 73.9
#   > [VAL]   R2: 0.9568 | RMSE: 1974 | MAE: 1204 | Bias: 66.5
#
# Config 1 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 938.2 | R2: 0.9746 | Bias: 75.7
#   [VAL AVG]   MAE: 1230.7 | R2: 0.9524 | Bias: 100.4 | RMSE: 2120.7
# [NEW BEST RMSE] Config 1
#
# ######## CONFIG 2/55 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 255, 'max_iter': 800, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C2|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9669 | RMSE: 1777 | MAE: 1012 | Bias: 89.4
#   > [VAL]   R2: 0.9583 | RMSE: 1943 | MAE: 1233 | Bias: 59.1
#
# [C2|F2] Processing fold...
#   > [TRAIN] R2: 0.9747 | RMSE: 1549 | MAE: 945 | Bias: 74.8
#   > [VAL]   R2: 0.9501 | RMSE: 2164 | MAE: 1260 | Bias: 88.9
#
# [C2|F3] Processing fold...
#   > [TRAIN] R2: 0.9733 | RMSE: 1592 | MAE: 931 | Bias: 76.7
#   > [VAL]   R2: 0.9477 | RMSE: 2216 | MAE: 1256 | Bias: 134.8
#
# [C2|F4] Processing fold...
#   > [TRAIN] R2: 0.9776 | RMSE: 1448 | MAE: 915 | Bias: 70.2
#   > [VAL]   R2: 0.9334 | RMSE: 2615 | MAE: 1272 | Bias: 129.2
#
# [C2|F5] Processing fold...
#   > [TRAIN] R2: 0.9762 | RMSE: 1501 | MAE: 914 | Bias: 67.0
#   > [VAL]   R2: 0.9567 | RMSE: 2041 | MAE: 1234 | Bias: 86.8
#
# [C2|F6] Processing fold...
#   > [TRAIN] R2: 0.9740 | RMSE: 1570 | MAE: 947 | Bias: 77.4
#   > [VAL]   R2: 0.9513 | RMSE: 2167 | MAE: 1231 | Bias: 115.6
#
# [C2|F7] Processing fold...
#   > [TRAIN] R2: 0.9755 | RMSE: 1523 | MAE: 924 | Bias: 76.0
#   > [VAL]   R2: 0.9570 | RMSE: 2017 | MAE: 1214 | Bias: 121.0
#
# [C2|F8] Processing fold...
#   > [TRAIN] R2: 0.9744 | RMSE: 1562 | MAE: 963 | Bias: 80.2
#   > [VAL]   R2: 0.9562 | RMSE: 1987 | MAE: 1207 | Bias: 72.9
#
# Config 2 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 943.9 | R2: 0.9741 | Bias: 76.5
#   [VAL AVG]   MAE: 1238.4 | R2: 0.9513 | Bias: 101.0 | RMSE: 2143.8
#
# ######## CONFIG 3/55 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 63, 'max_iter': 1000, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 3.0}
#
# [C3|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9625 | RMSE: 1891 | MAE: 1115 | Bias: 98.7
#   > [VAL]   R2: 0.9574 | RMSE: 1963 | MAE: 1260 | Bias: 60.6
#
# [C3|F2] Processing fold...
#   > [TRAIN] R2: 0.9669 | RMSE: 1772 | MAE: 1099 | Bias: 91.5
#   > [VAL]   R2: 0.9517 | RMSE: 2128 | MAE: 1278 | Bias: 88.0
#
# [C3|F3] Processing fold...
#   > [TRAIN] R2: 0.9695 | RMSE: 1702 | MAE: 1023 | Bias: 85.0
#   > [VAL]   R2: 0.9505 | RMSE: 2157 | MAE: 1258 | Bias: 139.0
#
# [C3|F4] Processing fold...
#   > [TRAIN] R2: 0.9693 | RMSE: 1697 | MAE: 1080 | Bias: 85.9
#   > [VAL]   R2: 0.9344 | RMSE: 2595 | MAE: 1290 | Bias: 119.9
#
# [C3|F5] Processing fold...
#   > [TRAIN] R2: 0.9713 | RMSE: 1648 | MAE: 1023 | Bias: 78.7
#   > [VAL]   R2: 0.9574 | RMSE: 2024 | MAE: 1233 | Bias: 93.8
#
# [C3|F6] Processing fold...
#   > [TRAIN] R2: 0.9688 | RMSE: 1718 | MAE: 1052 | Bias: 88.3
#   > [VAL]   R2: 0.9526 | RMSE: 2138 | MAE: 1250 | Bias: 111.7
#
# [C3|F7] Processing fold...
#   > [TRAIN] R2: 0.9696 | RMSE: 1699 | MAE: 1044 | Bias: 89.0
#   > [VAL]   R2: 0.9577 | RMSE: 2001 | MAE: 1221 | Bias: 128.1
#
# [C3|F8] Processing fold...
#   > [TRAIN] R2: 0.9679 | RMSE: 1749 | MAE: 1088 | Bias: 93.9
#   > [VAL]   R2: 0.9556 | RMSE: 2001 | MAE: 1234 | Bias: 80.5
#
# Config 3 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1065.5 | R2: 0.9682 | Bias: 88.9
#   [VAL AVG]   MAE: 1252.8 | R2: 0.9522 | Bias: 102.7 | RMSE: 2125.8
#
# ######## CONFIG 4/55 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 600, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 0.3}
#
# [C4|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9631 | RMSE: 1877 | MAE: 1098 | Bias: 95.6
#   > [VAL]   R2: 0.9575 | RMSE: 1961 | MAE: 1249 | Bias: 63.0
#
# [C4|F2] Processing fold...
#   > [TRAIN] R2: 0.9634 | RMSE: 1863 | MAE: 1141 | Bias: 97.2
#   > [VAL]   R2: 0.9503 | RMSE: 2160 | MAE: 1294 | Bias: 99.7
#
# [C4|F3] Processing fold...
#   > [TRAIN] R2: 0.9647 | RMSE: 1829 | MAE: 1100 | Bias: 93.5
#   > [VAL]   R2: 0.9466 | RMSE: 2239 | MAE: 1287 | Bias: 144.8
#
# [C4|F4] Processing fold...
#   > [TRAIN] R2: 0.9648 | RMSE: 1815 | MAE: 1144 | Bias: 94.9
#   > [VAL]   R2: 0.9325 | RMSE: 2633 | MAE: 1318 | Bias: 135.9
#
# [C4|F5] Processing fold...
#   > [TRAIN] R2: 0.9658 | RMSE: 1798 | MAE: 1099 | Bias: 86.1
#   > [VAL]   R2: 0.9557 | RMSE: 2064 | MAE: 1260 | Bias: 90.3
#
# [C4|F6] Processing fold...
#   > [TRAIN] R2: 0.9660 | RMSE: 1794 | MAE: 1096 | Bias: 93.6
#   > [VAL]   R2: 0.9508 | RMSE: 2178 | MAE: 1255 | Bias: 127.0
#
# [C4|F7] Processing fold...
#   > [TRAIN] R2: 0.9659 | RMSE: 1798 | MAE: 1099 | Bias: 95.6
#   > [VAL]   R2: 0.9564 | RMSE: 2030 | MAE: 1236 | Bias: 129.3
#
# [C4|F8] Processing fold...
#   > [TRAIN] R2: 0.9665 | RMSE: 1789 | MAE: 1105 | Bias: 93.6
#   > [VAL]   R2: 0.9550 | RMSE: 2015 | MAE: 1243 | Bias: 78.1
#
# Config 4 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1110.2 | R2: 0.9650 | Bias: 93.8
#   [VAL AVG]   MAE: 1267.8 | R2: 0.9506 | Bias: 108.5 | RMSE: 2160.1
#
# ######## CONFIG 5/55 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 63, 'max_iter': 1200, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 0.3}
#
# [C5|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9664 | RMSE: 1792 | MAE: 1047 | Bias: 90.4
#   > [VAL]   R2: 0.9581 | RMSE: 1946 | MAE: 1233 | Bias: 56.6
#
# [C5|F2] Processing fold...
#   > [TRAIN] R2: 0.9682 | RMSE: 1738 | MAE: 1076 | Bias: 89.4
#   > [VAL]   R2: 0.9516 | RMSE: 2131 | MAE: 1273 | Bias: 96.1
#
# [C5|F3] Processing fold...
#   > [TRAIN] R2: 0.9660 | RMSE: 1795 | MAE: 1086 | Bias: 93.6
#   > [VAL]   R2: 0.9480 | RMSE: 2211 | MAE: 1280 | Bias: 146.5
#
# [C5|F4] Processing fold...
#   > [TRAIN] R2: 0.9672 | RMSE: 1754 | MAE: 1111 | Bias: 91.5
#   > [VAL]   R2: 0.9318 | RMSE: 2646 | MAE: 1304 | Bias: 130.4
#
# [C5|F5] Processing fold...
#   > [TRAIN] R2: 0.9696 | RMSE: 1697 | MAE: 1054 | Bias: 81.7
#   > [VAL]   R2: 0.9561 | RMSE: 2054 | MAE: 1246 | Bias: 97.0
#
# [C5|F6] Processing fold...
#   > [TRAIN] R2: 0.9673 | RMSE: 1758 | MAE: 1082 | Bias: 92.4
#   > [VAL]   R2: 0.9521 | RMSE: 2149 | MAE: 1259 | Bias: 124.6
#
# [C5|F7] Processing fold...
#   > [TRAIN] R2: 0.9667 | RMSE: 1778 | MAE: 1097 | Bias: 95.2
#   > [VAL]   R2: 0.9566 | RMSE: 2026 | MAE: 1242 | Bias: 128.1
#
# [C5|F8] Processing fold...
#   > [TRAIN] R2: 0.9680 | RMSE: 1748 | MAE: 1091 | Bias: 94.3
#   > [VAL]   R2: 0.9552 | RMSE: 2011 | MAE: 1243 | Bias: 75.6
#
# Config 5 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1080.7 | R2: 0.9674 | Bias: 91.1
#   [VAL AVG]   MAE: 1260.1 | R2: 0.9512 | Bias: 106.9 | RMSE: 2146.9
#
# ######## CONFIG 6/55 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 3.0}
#
# [C6|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9634 | RMSE: 1868 | MAE: 1083 | Bias: 96.7
#   > [VAL]   R2: 0.9577 | RMSE: 1957 | MAE: 1249 | Bias: 63.3
#
# [C6|F2] Processing fold...
#   > [TRAIN] R2: 0.9698 | RMSE: 1694 | MAE: 1045 | Bias: 86.2
#   > [VAL]   R2: 0.9516 | RMSE: 2131 | MAE: 1266 | Bias: 83.5
#
# [C6|F3] Processing fold...
#   > [TRAIN] R2: 0.9736 | RMSE: 1584 | MAE: 935 | Bias: 77.3
#   > [VAL]   R2: 0.9512 | RMSE: 2140 | MAE: 1242 | Bias: 129.4
#
# [C6|F4] Processing fold...
#   > [TRAIN] R2: 0.9700 | RMSE: 1676 | MAE: 1058 | Bias: 85.1
#   > [VAL]   R2: 0.9333 | RMSE: 2617 | MAE: 1292 | Bias: 130.7
#
# [C6|F5] Processing fold...
#   > [TRAIN] R2: 0.9735 | RMSE: 1584 | MAE: 980 | Bias: 72.9
#   > [VAL]   R2: 0.9572 | RMSE: 2028 | MAE: 1237 | Bias: 86.1
#
# [C6|F6] Processing fold...
#   > [TRAIN] R2: 0.9744 | RMSE: 1556 | MAE: 944 | Bias: 76.7
#   > [VAL]   R2: 0.9541 | RMSE: 2104 | MAE: 1233 | Bias: 112.4
#
# [C6|F7] Processing fold...
#   > [TRAIN] R2: 0.9719 | RMSE: 1632 | MAE: 997 | Bias: 83.3
#   > [VAL]   R2: 0.9575 | RMSE: 2004 | MAE: 1216 | Bias: 123.9
#
# [C6|F8] Processing fold...
#   > [TRAIN] R2: 0.9745 | RMSE: 1561 | MAE: 968 | Bias: 79.2
#   > [VAL]   R2: 0.9563 | RMSE: 1985 | MAE: 1204 | Bias: 69.0
#
# Config 6 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1001.0 | R2: 0.9714 | Bias: 82.2
#   [VAL AVG]   MAE: 1242.4 | R2: 0.9524 | Bias: 99.8 | RMSE: 2120.9
#
# ######## CONFIG 7/55 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 1.0}
#
# [C7|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9645 | RMSE: 1841 | MAE: 1061 | Bias: 91.1
#   > [VAL]   R2: 0.9582 | RMSE: 1945 | MAE: 1242 | Bias: 59.3
#
# [C7|F2] Processing fold...
#   > [TRAIN] R2: 0.9687 | RMSE: 1725 | MAE: 1052 | Bias: 84.2
#   > [VAL]   R2: 0.9499 | RMSE: 2168 | MAE: 1278 | Bias: 87.0
#
# [C7|F3] Processing fold...
#   > [TRAIN] R2: 0.9681 | RMSE: 1741 | MAE: 1028 | Bias: 85.2
#   > [VAL]   R2: 0.9458 | RMSE: 2257 | MAE: 1272 | Bias: 144.2
#
# [C7|F4] Processing fold...
#   > [TRAIN] R2: 0.9717 | RMSE: 1628 | MAE: 1022 | Bias: 77.3
#   > [VAL]   R2: 0.9346 | RMSE: 2592 | MAE: 1280 | Bias: 117.5
#
# [C7|F5] Processing fold...
#   > [TRAIN] R2: 0.9720 | RMSE: 1628 | MAE: 994 | Bias: 73.5
#   > [VAL]   R2: 0.9560 | RMSE: 2057 | MAE: 1245 | Bias: 88.3
#
# [C7|F6] Processing fold...
#   > [TRAIN] R2: 0.9680 | RMSE: 1741 | MAE: 1050 | Bias: 86.0
#   > [VAL]   R2: 0.9505 | RMSE: 2185 | MAE: 1248 | Bias: 117.5
#
# [C7|F7] Processing fold...
#   > [TRAIN] R2: 0.9676 | RMSE: 1753 | MAE: 1055 | Bias: 88.3
#   > [VAL]   R2: 0.9569 | RMSE: 2018 | MAE: 1224 | Bias: 120.2
#
# [C7|F8] Processing fold...
#   > [TRAIN] R2: 0.9720 | RMSE: 1634 | MAE: 1001 | Bias: 80.3
#   > [VAL]   R2: 0.9567 | RMSE: 1975 | MAE: 1205 | Bias: 63.8
#
# Config 7 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1032.8 | R2: 0.9691 | Bias: 83.2
#   [VAL AVG]   MAE: 1249.5 | R2: 0.9511 | Bias: 99.7 | RMSE: 2149.6
#
# ######## CONFIG 8/55 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 255, 'max_iter': 1000, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 1.0}
#
# [C8|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9695 | RMSE: 1706 | MAE: 972 | Bias: 83.4
#   > [VAL]   R2: 0.9590 | RMSE: 1925 | MAE: 1228 | Bias: 59.2
#
# [C8|F2] Processing fold...
#   > [TRAIN] R2: 0.9724 | RMSE: 1619 | MAE: 992 | Bias: 80.4
#   > [VAL]   R2: 0.9496 | RMSE: 2175 | MAE: 1263 | Bias: 93.1
#
# [C8|F3] Processing fold...
#   > [TRAIN] R2: 0.9758 | RMSE: 1517 | MAE: 881 | Bias: 71.9
#   > [VAL]   R2: 0.9492 | RMSE: 2184 | MAE: 1254 | Bias: 128.6
#
# [C8|F4] Processing fold...
#   > [TRAIN] R2: 0.9746 | RMSE: 1544 | MAE: 973 | Bias: 75.6
#   > [VAL]   R2: 0.9315 | RMSE: 2652 | MAE: 1287 | Bias: 128.3
#
# [C8|F5] Processing fold...
#   > [TRAIN] R2: 0.9749 | RMSE: 1542 | MAE: 940 | Bias: 70.3
#   > [VAL]   R2: 0.9570 | RMSE: 2034 | MAE: 1234 | Bias: 96.4
#
# [C8|F6] Processing fold...
#   > [TRAIN] R2: 0.9746 | RMSE: 1551 | MAE: 936 | Bias: 77.0
#   > [VAL]   R2: 0.9532 | RMSE: 2125 | MAE: 1232 | Bias: 111.8
#
# [C8|F7] Processing fold...
#   > [TRAIN] R2: 0.9757 | RMSE: 1517 | MAE: 921 | Bias: 75.8
#   > [VAL]   R2: 0.9569 | RMSE: 2019 | MAE: 1213 | Bias: 121.9
#
# [C8|F8] Processing fold...
#   > [TRAIN] R2: 0.9749 | RMSE: 1549 | MAE: 953 | Bias: 78.8
#   > [VAL]   R2: 0.9559 | RMSE: 1995 | MAE: 1211 | Bias: 74.3
#
# Config 8 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 946.1 | R2: 0.9740 | Bias: 76.6
#   [VAL AVG]   MAE: 1240.3 | R2: 0.9515 | Bias: 101.7 | RMSE: 2138.5
#
# ######## CONFIG 9/55 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 800, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 1.0}
#
# [C9|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9610 | RMSE: 1929 | MAE: 1133 | Bias: 99.4
#   > [VAL]   R2: 0.9573 | RMSE: 1965 | MAE: 1267 | Bias: 66.1
#
# [C9|F2] Processing fold...
#   > [TRAIN] R2: 0.9677 | RMSE: 1751 | MAE: 1075 | Bias: 86.4
#   > [VAL]   R2: 0.9504 | RMSE: 2158 | MAE: 1275 | Bias: 84.5
#
# [C9|F3] Processing fold...
#   > [TRAIN] R2: 0.9659 | RMSE: 1798 | MAE: 1083 | Bias: 89.8
#   > [VAL]   R2: 0.9475 | RMSE: 2220 | MAE: 1279 | Bias: 140.1
#
# [C9|F4] Processing fold...
#   > [TRAIN] R2: 0.9653 | RMSE: 1803 | MAE: 1135 | Bias: 91.1
#   > [VAL]   R2: 0.9336 | RMSE: 2612 | MAE: 1308 | Bias: 131.2
#
# [C9|F5] Processing fold...
#   > [TRAIN] R2: 0.9629 | RMSE: 1873 | MAE: 1149 | Bias: 92.8
#   > [VAL]   R2: 0.9552 | RMSE: 2076 | MAE: 1281 | Bias: 90.9
#
# [C9|F6] Processing fold...
#   > [TRAIN] R2: 0.9668 | RMSE: 1772 | MAE: 1084 | Bias: 89.5
#   > [VAL]   R2: 0.9516 | RMSE: 2159 | MAE: 1257 | Bias: 122.4
#
# [C9|F7] Processing fold...
#   > [TRAIN] R2: 0.9707 | RMSE: 1668 | MAE: 1021 | Bias: 83.9
#   > [VAL]   R2: 0.9587 | RMSE: 1976 | MAE: 1210 | Bias: 116.9
#
# [C9|F8] Processing fold...
#   > [TRAIN] R2: 0.9680 | RMSE: 1747 | MAE: 1080 | Bias: 90.2
#   > [VAL]   R2: 0.9561 | RMSE: 1990 | MAE: 1230 | Bias: 78.3
#
# Config 9 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1094.9 | R2: 0.9660 | Bias: 90.4
#   [VAL AVG]   MAE: 1263.4 | R2: 0.9513 | Bias: 103.8 | RMSE: 2144.5
#
# ######## CONFIG 10/55 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 1200, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 1.0}
#
# [C10|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9681 | RMSE: 1746 | MAE: 1005 | Bias: 84.9
#   > [VAL]   R2: 0.9590 | RMSE: 1927 | MAE: 1234 | Bias: 56.2
#
# [C10|F2] Processing fold...
#   > [TRAIN] R2: 0.9717 | RMSE: 1640 | MAE: 1002 | Bias: 78.5
#   > [VAL]   R2: 0.9502 | RMSE: 2161 | MAE: 1265 | Bias: 90.1
#
# [C10|F3] Processing fold...
#   > [TRAIN] R2: 0.9713 | RMSE: 1652 | MAE: 979 | Bias: 79.0
#   > [VAL]   R2: 0.9477 | RMSE: 2216 | MAE: 1258 | Bias: 138.5
#
# [C10|F4] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1680 | MAE: 1055 | Bias: 82.6
#   > [VAL]   R2: 0.9337 | RMSE: 2610 | MAE: 1289 | Bias: 130.4
#
# [C10|F5] Processing fold...
#   > [TRAIN] R2: 0.9738 | RMSE: 1573 | MAE: 966 | Bias: 70.0
#   > [VAL]   R2: 0.9581 | RMSE: 2008 | MAE: 1229 | Bias: 90.9
#
# [C10|F6] Processing fold...
#   > [TRAIN] R2: 0.9693 | RMSE: 1703 | MAE: 1033 | Bias: 84.0
#   > [VAL]   R2: 0.9511 | RMSE: 2171 | MAE: 1244 | Bias: 116.1
#
# [C10|F7] Processing fold...
#   > [TRAIN] R2: 0.9742 | RMSE: 1564 | MAE: 949 | Bias: 75.6
#   > [VAL]   R2: 0.9583 | RMSE: 1986 | MAE: 1205 | Bias: 115.5
#
# [C10|F8] Processing fold...
#   > [TRAIN] R2: 0.9732 | RMSE: 1599 | MAE: 987 | Bias: 79.7
#   > [VAL]   R2: 0.9570 | RMSE: 1969 | MAE: 1208 | Bias: 66.4
#
# Config 10 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 997.0 | R2: 0.9714 | Bias: 79.3
#   [VAL AVG]   MAE: 1241.7 | R2: 0.9519 | Bias: 100.5 | RMSE: 2130.9
#
# ######## CONFIG 11/55 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 600, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 3.0}
#
# [C11|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9669 | RMSE: 1777 | MAE: 1022 | Bias: 86.6
#   > [VAL]   R2: 0.9589 | RMSE: 1929 | MAE: 1233 | Bias: 56.4
#
# [C11|F2] Processing fold...
#   > [TRAIN] R2: 0.9716 | RMSE: 1642 | MAE: 1009 | Bias: 79.6
#   > [VAL]   R2: 0.9516 | RMSE: 2132 | MAE: 1258 | Bias: 87.0
#
# [C11|F3] Processing fold...
#   > [TRAIN] R2: 0.9706 | RMSE: 1670 | MAE: 992 | Bias: 81.3
#   > [VAL]   R2: 0.9496 | RMSE: 2176 | MAE: 1257 | Bias: 133.6
#
# [C11|F4] Processing fold...
#   > [TRAIN] R2: 0.9735 | RMSE: 1575 | MAE: 999 | Bias: 75.5
#   > [VAL]   R2: 0.9359 | RMSE: 2566 | MAE: 1269 | Bias: 127.3
#
# [C11|F5] Processing fold...
#   > [TRAIN] R2: 0.9708 | RMSE: 1663 | MAE: 1017 | Bias: 75.6
#   > [VAL]   R2: 0.9568 | RMSE: 2039 | MAE: 1246 | Bias: 88.2
#
# [C11|F6] Processing fold...
#   > [TRAIN] R2: 0.9716 | RMSE: 1638 | MAE: 993 | Bias: 79.0
#   > [VAL]   R2: 0.9537 | RMSE: 2112 | MAE: 1229 | Bias: 109.6
#
# [C11|F7] Processing fold...
#   > [TRAIN] R2: 0.9705 | RMSE: 1673 | MAE: 1024 | Bias: 84.0
#   > [VAL]   R2: 0.9580 | RMSE: 1994 | MAE: 1217 | Bias: 120.7
#
# [C11|F8] Processing fold...
#   > [TRAIN] R2: 0.9715 | RMSE: 1650 | MAE: 1020 | Bias: 82.3
#   > [VAL]   R2: 0.9575 | RMSE: 1957 | MAE: 1204 | Bias: 65.7
#
# Config 11 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1009.3 | R2: 0.9709 | Bias: 80.5
#   [VAL AVG]   MAE: 1239.2 | R2: 0.9527 | Bias: 98.6 | RMSE: 2113.2
# [NEW BEST RMSE] Config 11
#
# ######## CONFIG 12/55 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 255, 'max_iter': 800, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 3.0}
#
# [C12|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9643 | RMSE: 1846 | MAE: 1061 | Bias: 89.8
#   > [VAL]   R2: 0.9577 | RMSE: 1956 | MAE: 1244 | Bias: 58.2
#
# [C12|F2] Processing fold...
#   > [TRAIN] R2: 0.9695 | RMSE: 1702 | MAE: 1041 | Bias: 80.5
#   > [VAL]   R2: 0.9487 | RMSE: 2194 | MAE: 1280 | Bias: 83.5
#
# [C12|F3] Processing fold...
#   > [TRAIN] R2: 0.9684 | RMSE: 1732 | MAE: 1028 | Bias: 82.3
#   > [VAL]   R2: 0.9474 | RMSE: 2223 | MAE: 1271 | Bias: 134.7
#
# [C12|F4] Processing fold...
#   > [TRAIN] R2: 0.9701 | RMSE: 1674 | MAE: 1051 | Bias: 78.4
#   > [VAL]   R2: 0.9334 | RMSE: 2616 | MAE: 1292 | Bias: 127.5
#
# [C12|F5] Processing fold...
#   > [TRAIN] R2: 0.9696 | RMSE: 1696 | MAE: 1032 | Bias: 75.2
#   > [VAL]   R2: 0.9562 | RMSE: 2053 | MAE: 1256 | Bias: 79.5
#
# [C12|F6] Processing fold...
#   > [TRAIN] R2: 0.9683 | RMSE: 1732 | MAE: 1050 | Bias: 84.4
#   > [VAL]   R2: 0.9518 | RMSE: 2155 | MAE: 1247 | Bias: 107.3
#
# [C12|F7] Processing fold...
#   > [TRAIN] R2: 0.9702 | RMSE: 1682 | MAE: 1021 | Bias: 81.5
#   > [VAL]   R2: 0.9569 | RMSE: 2020 | MAE: 1224 | Bias: 123.9
#
# [C12|F8] Processing fold...
#   > [TRAIN] R2: 0.9713 | RMSE: 1655 | MAE: 1015 | Bias: 81.0
#   > [VAL]   R2: 0.9566 | RMSE: 1978 | MAE: 1210 | Bias: 74.3
#
# Config 12 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1037.2 | R2: 0.9690 | Bias: 81.6
#   [VAL AVG]   MAE: 1253.0 | R2: 0.9511 | Bias: 98.6 | RMSE: 2149.4
#
# ######## CONFIG 13/55 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 0.3}
#
# [C13|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9605 | RMSE: 1941 | MAE: 1127 | Bias: 99.6
#   > [VAL]   R2: 0.9558 | RMSE: 2001 | MAE: 1273 | Bias: 66.8
#
# [C13|F2] Processing fold...
#   > [TRAIN] R2: 0.9673 | RMSE: 1763 | MAE: 1075 | Bias: 85.8
#   > [VAL]   R2: 0.9502 | RMSE: 2162 | MAE: 1280 | Bias: 88.5
#
# [C13|F3] Processing fold...
#   > [TRAIN] R2: 0.9708 | RMSE: 1666 | MAE: 990 | Bias: 79.6
#   > [VAL]   R2: 0.9479 | RMSE: 2212 | MAE: 1258 | Bias: 137.8
#
# [C13|F4] Processing fold...
#   > [TRAIN] R2: 0.9658 | RMSE: 1790 | MAE: 1121 | Bias: 88.1
#   > [VAL]   R2: 0.9338 | RMSE: 2607 | MAE: 1310 | Bias: 126.0
#
# [C13|F5] Processing fold...
#   > [TRAIN] R2: 0.9668 | RMSE: 1773 | MAE: 1077 | Bias: 81.6
#   > [VAL]   R2: 0.9565 | RMSE: 2047 | MAE: 1256 | Bias: 88.7
#
# [C13|F6] Processing fold...
#   > [TRAIN] R2: 0.9703 | RMSE: 1675 | MAE: 1015 | Bias: 80.0
#   > [VAL]   R2: 0.9533 | RMSE: 2121 | MAE: 1236 | Bias: 108.3
#
# [C13|F7] Processing fold...
#   > [TRAIN] R2: 0.9652 | RMSE: 1816 | MAE: 1098 | Bias: 92.6
#   > [VAL]   R2: 0.9564 | RMSE: 2031 | MAE: 1239 | Bias: 123.9
#
# [C13|F8] Processing fold...
#   > [TRAIN] R2: 0.9673 | RMSE: 1767 | MAE: 1088 | Bias: 90.0
#   > [VAL]   R2: 0.9553 | RMSE: 2008 | MAE: 1235 | Bias: 77.7
#
# Config 13 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1073.8 | R2: 0.9667 | Bias: 87.2
#   [VAL AVG]   MAE: 1260.9 | R2: 0.9511 | Bias: 102.2 | RMSE: 2148.6
#
# ######## CONFIG 14/55 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 63, 'max_iter': 1000, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 3.0}
#
# [C14|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9671 | RMSE: 1771 | MAE: 1031 | Bias: 86.8
#   > [VAL]   R2: 0.9592 | RMSE: 1922 | MAE: 1230 | Bias: 52.1
#
# [C14|F2] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1690 | MAE: 1044 | Bias: 83.4
#   > [VAL]   R2: 0.9527 | RMSE: 2107 | MAE: 1265 | Bias: 91.6
#
# [C14|F3] Processing fold...
#   > [TRAIN] R2: 0.9657 | RMSE: 1805 | MAE: 1086 | Bias: 90.7
#   > [VAL]   R2: 0.9483 | RMSE: 2203 | MAE: 1277 | Bias: 146.0
#
# [C14|F4] Processing fold...
#   > [TRAIN] R2: 0.9705 | RMSE: 1663 | MAE: 1054 | Bias: 82.3
#   > [VAL]   R2: 0.9342 | RMSE: 2599 | MAE: 1281 | Bias: 125.3
#
# [C14|F5] Processing fold...
#   > [TRAIN] R2: 0.9696 | RMSE: 1696 | MAE: 1052 | Bias: 80.3
#   > [VAL]   R2: 0.9576 | RMSE: 2020 | MAE: 1244 | Bias: 87.4
#
# [C14|F6] Processing fold...
#   > [TRAIN] R2: 0.9682 | RMSE: 1733 | MAE: 1062 | Bias: 87.4
#   > [VAL]   R2: 0.9521 | RMSE: 2149 | MAE: 1252 | Bias: 120.2
#
# [C14|F7] Processing fold...
#   > [TRAIN] R2: 0.9694 | RMSE: 1703 | MAE: 1046 | Bias: 87.9
#   > [VAL]   R2: 0.9576 | RMSE: 2003 | MAE: 1226 | Bias: 126.3
#
# [C14|F8] Processing fold...
#   > [TRAIN] R2: 0.9678 | RMSE: 1754 | MAE: 1085 | Bias: 91.8
#   > [VAL]   R2: 0.9553 | RMSE: 2007 | MAE: 1233 | Bias: 77.0
#
# Config 14 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1057.5 | R2: 0.9685 | Bias: 86.3
#   [VAL AVG]   MAE: 1250.9 | R2: 0.9521 | Bias: 103.2 | RMSE: 2126.4
#
# ######## CONFIG 15/55 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 0.3}
#
# [C15|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9687 | RMSE: 1729 | MAE: 984 | Bias: 85.9
#   > [VAL]   R2: 0.9584 | RMSE: 1939 | MAE: 1232 | Bias: 53.7
#
# [C15|F2] Processing fold...
#   > [TRAIN] R2: 0.9716 | RMSE: 1641 | MAE: 1001 | Bias: 81.3
#   > [VAL]   R2: 0.9501 | RMSE: 2163 | MAE: 1265 | Bias: 93.2
#
# [C15|F3] Processing fold...
#   > [TRAIN] R2: 0.9719 | RMSE: 1633 | MAE: 968 | Bias: 81.1
#   > [VAL]   R2: 0.9475 | RMSE: 2221 | MAE: 1260 | Bias: 134.8
#
# [C15|F4] Processing fold...
#   > [TRAIN] R2: 0.9717 | RMSE: 1628 | MAE: 1022 | Bias: 79.8
#   > [VAL]   R2: 0.9346 | RMSE: 2593 | MAE: 1278 | Bias: 122.4
#
# [C15|F5] Processing fold...
#   > [TRAIN] R2: 0.9756 | RMSE: 1519 | MAE: 928 | Bias: 69.0
#   > [VAL]   R2: 0.9571 | RMSE: 2032 | MAE: 1233 | Bias: 90.7
#
# [C15|F6] Processing fold...
#   > [TRAIN] R2: 0.9750 | RMSE: 1538 | MAE: 930 | Bias: 74.5
#   > [VAL]   R2: 0.9540 | RMSE: 2105 | MAE: 1222 | Bias: 113.0
#
# [C15|F7] Processing fold...
#   > [TRAIN] R2: 0.9720 | RMSE: 1630 | MAE: 992 | Bias: 83.0
#   > [VAL]   R2: 0.9575 | RMSE: 2005 | MAE: 1219 | Bias: 124.3
#
# [C15|F8] Processing fold...
#   > [TRAIN] R2: 0.9734 | RMSE: 1594 | MAE: 979 | Bias: 81.9
#   > [VAL]   R2: 0.9568 | RMSE: 1975 | MAE: 1206 | Bias: 69.6
#
# Config 15 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 975.4 | R2: 0.9725 | Bias: 79.6
#   [VAL AVG]   MAE: 1239.4 | R2: 0.9520 | Bias: 100.2 | RMSE: 2129.3
#
# ######## CONFIG 16/55 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 0.3}
#
# [C16|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9688 | RMSE: 1725 | MAE: 980 | Bias: 82.7
#   > [VAL]   R2: 0.9591 | RMSE: 1923 | MAE: 1227 | Bias: 48.3
#
# [C16|F2] Processing fold...
#   > [TRAIN] R2: 0.9686 | RMSE: 1728 | MAE: 1060 | Bias: 85.6
#   > [VAL]   R2: 0.9489 | RMSE: 2190 | MAE: 1275 | Bias: 89.4
#
# [C16|F3] Processing fold...
#   > [TRAIN] R2: 0.9726 | RMSE: 1613 | MAE: 951 | Bias: 76.9
#   > [VAL]   R2: 0.9498 | RMSE: 2170 | MAE: 1253 | Bias: 138.1
#
# [C16|F4] Processing fold...
#   > [TRAIN] R2: 0.9733 | RMSE: 1580 | MAE: 998 | Bias: 74.6
#   > [VAL]   R2: 0.9342 | RMSE: 2601 | MAE: 1279 | Bias: 126.5
#
# [C16|F5] Processing fold...
#   > [TRAIN] R2: 0.9733 | RMSE: 1589 | MAE: 975 | Bias: 70.7
#   > [VAL]   R2: 0.9583 | RMSE: 2003 | MAE: 1232 | Bias: 82.2
#
# [C16|F6] Processing fold...
#   > [TRAIN] R2: 0.9701 | RMSE: 1680 | MAE: 1021 | Bias: 82.5
#   > [VAL]   R2: 0.9520 | RMSE: 2150 | MAE: 1241 | Bias: 110.3
#
# [C16|F7] Processing fold...
#   > [TRAIN] R2: 0.9702 | RMSE: 1682 | MAE: 1025 | Bias: 83.8
#   > [VAL]   R2: 0.9574 | RMSE: 2008 | MAE: 1216 | Bias: 121.3
#
# [C16|F8] Processing fold...
#   > [TRAIN] R2: 0.9724 | RMSE: 1623 | MAE: 1003 | Bias: 80.4
#   > [VAL]   R2: 0.9567 | RMSE: 1977 | MAE: 1211 | Bias: 68.0
#
# Config 16 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1001.5 | R2: 0.9712 | Bias: 79.6
#   [VAL AVG]   MAE: 1241.9 | R2: 0.9520 | Bias: 98.0 | RMSE: 2127.8
#
# ######## CONFIG 17/55 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 191, 'max_iter': 800, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 3.0}
#
# [C17|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9699 | RMSE: 1695 | MAE: 955 | Bias: 82.1
#   > [VAL]   R2: 0.9587 | RMSE: 1934 | MAE: 1227 | Bias: 54.3
#
# [C17|F2] Processing fold...
#   > [TRAIN] R2: 0.9731 | RMSE: 1598 | MAE: 977 | Bias: 76.9
#   > [VAL]   R2: 0.9513 | RMSE: 2137 | MAE: 1257 | Bias: 87.6
#
# [C17|F3] Processing fold...
#   > [TRAIN] R2: 0.9736 | RMSE: 1583 | MAE: 934 | Bias: 77.3
#   > [VAL]   R2: 0.9494 | RMSE: 2179 | MAE: 1252 | Bias: 137.1
#
# [C17|F4] Processing fold...
#   > [TRAIN] R2: 0.9702 | RMSE: 1670 | MAE: 1043 | Bias: 82.6
#   > [VAL]   R2: 0.9332 | RMSE: 2620 | MAE: 1291 | Bias: 127.4
#
# [C17|F5] Processing fold...
#   > [TRAIN] R2: 0.9738 | RMSE: 1575 | MAE: 963 | Bias: 71.2
#   > [VAL]   R2: 0.9574 | RMSE: 2024 | MAE: 1239 | Bias: 89.3
#
# [C17|F6] Processing fold...
#   > [TRAIN] R2: 0.9763 | RMSE: 1498 | MAE: 907 | Bias: 71.4
#   > [VAL]   R2: 0.9553 | RMSE: 2075 | MAE: 1219 | Bias: 107.4
#
# [C17|F7] Processing fold...
#   > [TRAIN] R2: 0.9743 | RMSE: 1560 | MAE: 947 | Bias: 76.3
#   > [VAL]   R2: 0.9585 | RMSE: 1983 | MAE: 1209 | Bias: 115.1
#
# [C17|F8] Processing fold...
#   > [TRAIN] R2: 0.9755 | RMSE: 1530 | MAE: 945 | Bias: 76.6
#   > [VAL]   R2: 0.9571 | RMSE: 1967 | MAE: 1198 | Bias: 78.5
#
# Config 17 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 958.8 | R2: 0.9733 | Bias: 76.8
#   [VAL AVG]   MAE: 1236.4 | R2: 0.9526 | Bias: 99.6 | RMSE: 2114.9
#
# ######## CONFIG 18/55 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 0.3}
#
# [C18|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9617 | RMSE: 1912 | MAE: 1110 | Bias: 99.9
#   > [VAL]   R2: 0.9569 | RMSE: 1976 | MAE: 1259 | Bias: 70.5
#
# [C18|F2] Processing fold...
#   > [TRAIN] R2: 0.9692 | RMSE: 1709 | MAE: 1043 | Bias: 85.1
#   > [VAL]   R2: 0.9502 | RMSE: 2162 | MAE: 1270 | Bias: 90.7
#
# [C18|F3] Processing fold...
#   > [TRAIN] R2: 0.9687 | RMSE: 1723 | MAE: 1019 | Bias: 85.9
#   > [VAL]   R2: 0.9474 | RMSE: 2222 | MAE: 1258 | Bias: 144.1
#
# [C18|F4] Processing fold...
#   > [TRAIN] R2: 0.9712 | RMSE: 1644 | MAE: 1030 | Bias: 80.7
#   > [VAL]   R2: 0.9340 | RMSE: 2603 | MAE: 1278 | Bias: 125.8
#
# [C18|F5] Processing fold...
#   > [TRAIN] R2: 0.9717 | RMSE: 1637 | MAE: 1003 | Bias: 75.2
#   > [VAL]   R2: 0.9575 | RMSE: 2023 | MAE: 1241 | Bias: 88.2
#
# [C18|F6] Processing fold...
#   > [TRAIN] R2: 0.9698 | RMSE: 1689 | MAE: 1023 | Bias: 84.3
#   > [VAL]   R2: 0.9517 | RMSE: 2159 | MAE: 1238 | Bias: 111.3
#
# [C18|F7] Processing fold...
#   > [TRAIN] R2: 0.9702 | RMSE: 1682 | MAE: 1020 | Bias: 85.6
#   > [VAL]   R2: 0.9576 | RMSE: 2004 | MAE: 1214 | Bias: 122.0
#
# [C18|F8] Processing fold...
#   > [TRAIN] R2: 0.9689 | RMSE: 1722 | MAE: 1058 | Bias: 88.5
#   > [VAL]   R2: 0.9566 | RMSE: 1980 | MAE: 1215 | Bias: 76.4
#
# Config 18 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1038.2 | R2: 0.9689 | Bias: 85.6
#   [VAL AVG]   MAE: 1246.7 | R2: 0.9515 | Bias: 103.6 | RMSE: 2141.0
#
# ######## CONFIG 19/55 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 191, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C19|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9694 | RMSE: 1709 | MAE: 973 | Bias: 83.6
#   > [VAL]   R2: 0.9589 | RMSE: 1928 | MAE: 1227 | Bias: 53.4
#
# [C19|F2] Processing fold...
#   > [TRAIN] R2: 0.9746 | RMSE: 1553 | MAE: 954 | Bias: 75.8
#   > [VAL]   R2: 0.9508 | RMSE: 2147 | MAE: 1254 | Bias: 95.6
#
# [C19|F3] Processing fold...
#   > [TRAIN] R2: 0.9719 | RMSE: 1632 | MAE: 966 | Bias: 80.0
#   > [VAL]   R2: 0.9474 | RMSE: 2223 | MAE: 1258 | Bias: 136.4
#
# [C19|F4] Processing fold...
#   > [TRAIN] R2: 0.9704 | RMSE: 1666 | MAE: 1049 | Bias: 83.8
#   > [VAL]   R2: 0.9328 | RMSE: 2628 | MAE: 1289 | Bias: 124.6
#
# [C19|F5] Processing fold...
#   > [TRAIN] R2: 0.9754 | RMSE: 1526 | MAE: 937 | Bias: 69.7
#   > [VAL]   R2: 0.9580 | RMSE: 2011 | MAE: 1228 | Bias: 87.8
#
# [C19|F6] Processing fold...
#   > [TRAIN] R2: 0.9721 | RMSE: 1625 | MAE: 982 | Bias: 81.0
#   > [VAL]   R2: 0.9520 | RMSE: 2151 | MAE: 1231 | Bias: 119.0
#
# [C19|F7] Processing fold...
#   > [TRAIN] R2: 0.9743 | RMSE: 1562 | MAE: 953 | Bias: 78.3
#   > [VAL]   R2: 0.9575 | RMSE: 2006 | MAE: 1213 | Bias: 124.6
#
# [C19|F8] Processing fold...
#   > [TRAIN] R2: 0.9763 | RMSE: 1505 | MAE: 930 | Bias: 76.1
#   > [VAL]   R2: 0.9565 | RMSE: 1980 | MAE: 1207 | Bias: 72.0
#
# Config 19 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 968.0 | R2: 0.9730 | Bias: 78.6
#   [VAL AVG]   MAE: 1238.4 | R2: 0.9517 | Bias: 101.7 | RMSE: 2134.2
#
# ######## CONFIG 20/55 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 255, 'max_iter': 1200, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}
#
# [C20|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9642 | RMSE: 1849 | MAE: 1063 | Bias: 91.2
#   > [VAL]   R2: 0.9578 | RMSE: 1955 | MAE: 1244 | Bias: 59.1
#
# [C20|F2] Processing fold...
#   > [TRAIN] R2: 0.9691 | RMSE: 1712 | MAE: 1046 | Bias: 82.3
#   > [VAL]   R2: 0.9477 | RMSE: 2216 | MAE: 1278 | Bias: 88.1
#
# [C20|F3] Processing fold...
#   > [TRAIN] R2: 0.9672 | RMSE: 1766 | MAE: 1045 | Bias: 86.5
#   > [VAL]   R2: 0.9466 | RMSE: 2239 | MAE: 1274 | Bias: 142.0
#
# [C20|F4] Processing fold...
#   > [TRAIN] R2: 0.9707 | RMSE: 1656 | MAE: 1043 | Bias: 79.3
#   > [VAL]   R2: 0.9334 | RMSE: 2616 | MAE: 1286 | Bias: 123.9
#
# [C20|F5] Processing fold...
#   > [TRAIN] R2: 0.9723 | RMSE: 1620 | MAE: 991 | Bias: 71.8
#   > [VAL]   R2: 0.9575 | RMSE: 2022 | MAE: 1243 | Bias: 83.4
#
# [C20|F6] Processing fold...
#   > [TRAIN] R2: 0.9710 | RMSE: 1655 | MAE: 1003 | Bias: 80.8
#   > [VAL]   R2: 0.9540 | RMSE: 2105 | MAE: 1227 | Bias: 107.4
#
# [C20|F7] Processing fold...
#   > [TRAIN] R2: 0.9689 | RMSE: 1718 | MAE: 1038 | Bias: 85.0
#   > [VAL]   R2: 0.9568 | RMSE: 2021 | MAE: 1227 | Bias: 127.5
#
# [C20|F8] Processing fold...
#   > [TRAIN] R2: 0.9683 | RMSE: 1738 | MAE: 1064 | Bias: 87.3
#   > [VAL]   R2: 0.9549 | RMSE: 2016 | MAE: 1234 | Bias: 80.4
#
# Config 20 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1036.6 | R2: 0.9690 | Bias: 83.0
#   [VAL AVG]   MAE: 1251.5 | R2: 0.9511 | Bias: 101.5 | RMSE: 2148.9
#
# ######## CONFIG 21/55 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 3.0}
#
# [C21|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9659 | RMSE: 1804 | MAE: 1041 | Bias: 90.8
#   > [VAL]   R2: 0.9591 | RMSE: 1925 | MAE: 1232 | Bias: 57.4
#
# [C21|F2] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1691 | MAE: 1035 | Bias: 83.3
#   > [VAL]   R2: 0.9511 | RMSE: 2142 | MAE: 1269 | Bias: 90.9
#
# [C21|F3] Processing fold...
#   > [TRAIN] R2: 0.9685 | RMSE: 1730 | MAE: 1031 | Bias: 87.5
#   > [VAL]   R2: 0.9483 | RMSE: 2203 | MAE: 1262 | Bias: 143.9
#
# [C21|F4] Processing fold...
#   > [TRAIN] R2: 0.9718 | RMSE: 1625 | MAE: 1028 | Bias: 81.0
#   > [VAL]   R2: 0.9365 | RMSE: 2555 | MAE: 1275 | Bias: 127.0
#
# [C21|F5] Processing fold...
#   > [TRAIN] R2: 0.9728 | RMSE: 1604 | MAE: 983 | Bias: 73.5
#   > [VAL]   R2: 0.9575 | RMSE: 2023 | MAE: 1234 | Bias: 87.0
#
# [C21|F6] Processing fold...
#   > [TRAIN] R2: 0.9701 | RMSE: 1683 | MAE: 1022 | Bias: 84.5
#   > [VAL]   R2: 0.9522 | RMSE: 2147 | MAE: 1238 | Bias: 113.7
#
# [C21|F7] Processing fold...
#   > [TRAIN] R2: 0.9736 | RMSE: 1583 | MAE: 968 | Bias: 78.9
#   > [VAL]   R2: 0.9584 | RMSE: 1984 | MAE: 1207 | Bias: 117.3
#
# [C21|F8] Processing fold...
#   > [TRAIN] R2: 0.9733 | RMSE: 1595 | MAE: 983 | Bias: 80.6
#   > [VAL]   R2: 0.9574 | RMSE: 1961 | MAE: 1206 | Bias: 72.5
#
# Config 21 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1011.4 | R2: 0.9707 | Bias: 82.5
#   [VAL AVG]   MAE: 1240.4 | R2: 0.9526 | Bias: 101.2 | RMSE: 2117.3
#
# ######## CONFIG 22/55 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 63, 'max_iter': 800, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 1.0}
#
# [C22|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9643 | RMSE: 1845 | MAE: 1073 | Bias: 92.3
#   > [VAL]   R2: 0.9582 | RMSE: 1944 | MAE: 1247 | Bias: 61.6
#
# [C22|F2] Processing fold...
#   > [TRAIN] R2: 0.9655 | RMSE: 1810 | MAE: 1108 | Bias: 91.6
#   > [VAL]   R2: 0.9502 | RMSE: 2161 | MAE: 1277 | Bias: 88.8
#
# [C22|F3] Processing fold...
#   > [TRAIN] R2: 0.9660 | RMSE: 1797 | MAE: 1075 | Bias: 90.6
#   > [VAL]   R2: 0.9473 | RMSE: 2224 | MAE: 1268 | Bias: 136.7
#
# [C22|F4] Processing fold...
#   > [TRAIN] R2: 0.9654 | RMSE: 1800 | MAE: 1127 | Bias: 90.3
#   > [VAL]   R2: 0.9345 | RMSE: 2594 | MAE: 1305 | Bias: 129.5
#
# [C22|F5] Processing fold...
#   > [TRAIN] R2: 0.9674 | RMSE: 1757 | MAE: 1075 | Bias: 82.2
#   > [VAL]   R2: 0.9569 | RMSE: 2037 | MAE: 1248 | Bias: 86.6
#
# [C22|F6] Processing fold...
#   > [TRAIN] R2: 0.9681 | RMSE: 1737 | MAE: 1055 | Bias: 87.4
#   > [VAL]   R2: 0.9524 | RMSE: 2142 | MAE: 1243 | Bias: 123.8
#
# [C22|F7] Processing fold...
#   > [TRAIN] R2: 0.9642 | RMSE: 1843 | MAE: 1122 | Bias: 96.9
#   > [VAL]   R2: 0.9561 | RMSE: 2037 | MAE: 1247 | Bias: 124.3
#
# [C22|F8] Processing fold...
#   > [TRAIN] R2: 0.9621 | RMSE: 1901 | MAE: 1158 | Bias: 101.6
#   > [VAL]   R2: 0.9539 | RMSE: 2040 | MAE: 1263 | Bias: 80.3
#
# Config 22 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1099.1 | R2: 0.9654 | Bias: 91.6
#   [VAL AVG]   MAE: 1262.3 | R2: 0.9512 | Bias: 104.0 | RMSE: 2147.4
#
# ######## CONFIG 23/55 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 800, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C23|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9572 | RMSE: 2020 | MAE: 1193 | Bias: 106.9
#   > [VAL]   R2: 0.9556 | RMSE: 2004 | MAE: 1292 | Bias: 72.9
#
# [C23|F2] Processing fold...
#   > [TRAIN] R2: 0.9657 | RMSE: 1806 | MAE: 1109 | Bias: 91.5
#   > [VAL]   R2: 0.9495 | RMSE: 2176 | MAE: 1281 | Bias: 92.4
#
# [C23|F3] Processing fold...
#   > [TRAIN] R2: 0.9657 | RMSE: 1804 | MAE: 1081 | Bias: 91.5
#   > [VAL]   R2: 0.9478 | RMSE: 2215 | MAE: 1273 | Bias: 140.4
#
# [C23|F4] Processing fold...
#   > [TRAIN] R2: 0.9636 | RMSE: 1846 | MAE: 1156 | Bias: 95.3
#   > [VAL]   R2: 0.9322 | RMSE: 2638 | MAE: 1322 | Bias: 135.4
#
# [C23|F5] Processing fold...
#   > [TRAIN] R2: 0.9681 | RMSE: 1736 | MAE: 1070 | Bias: 81.6
#   > [VAL]   R2: 0.9563 | RMSE: 2051 | MAE: 1253 | Bias: 88.9
#
# [C23|F6] Processing fold...
#   > [TRAIN] R2: 0.9632 | RMSE: 1867 | MAE: 1140 | Bias: 97.0
#   > [VAL]   R2: 0.9488 | RMSE: 2221 | MAE: 1277 | Bias: 127.9
#
# [C23|F7] Processing fold...
#   > [TRAIN] R2: 0.9691 | RMSE: 1712 | MAE: 1049 | Bias: 88.1
#   > [VAL]   R2: 0.9572 | RMSE: 2012 | MAE: 1220 | Bias: 122.5
#
# [C23|F8] Processing fold...
#   > [TRAIN] R2: 0.9690 | RMSE: 1719 | MAE: 1062 | Bias: 89.1
#   > [VAL]   R2: 0.9561 | RMSE: 1991 | MAE: 1227 | Bias: 74.2
#
# Config 23 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1107.6 | R2: 0.9652 | Bias: 92.6
#   [VAL AVG]   MAE: 1268.2 | R2: 0.9504 | Bias: 106.8 | RMSE: 2163.5
#
# ######## CONFIG 24/55 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 255, 'max_iter': 1200, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 3.0}
#
# [C24|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9668 | RMSE: 1781 | MAE: 1012 | Bias: 89.1
#   > [VAL]   R2: 0.9579 | RMSE: 1952 | MAE: 1236 | Bias: 56.3
#
# [C24|F2] Processing fold...
#   > [TRAIN] R2: 0.9716 | RMSE: 1643 | MAE: 1003 | Bias: 79.6
#   > [VAL]   R2: 0.9513 | RMSE: 2137 | MAE: 1263 | Bias: 91.5
#
# [C24|F3] Processing fold...
#   > [TRAIN] R2: 0.9730 | RMSE: 1600 | MAE: 936 | Bias: 77.5
#   > [VAL]   R2: 0.9483 | RMSE: 2204 | MAE: 1254 | Bias: 132.9
#
# [C24|F4] Processing fold...
#   > [TRAIN] R2: 0.9723 | RMSE: 1610 | MAE: 1005 | Bias: 78.8
#   > [VAL]   R2: 0.9337 | RMSE: 2610 | MAE: 1282 | Bias: 130.1
#
# [C24|F5] Processing fold...
#   > [TRAIN] R2: 0.9754 | RMSE: 1526 | MAE: 929 | Bias: 68.6
#   > [VAL]   R2: 0.9566 | RMSE: 2043 | MAE: 1229 | Bias: 84.3
#
# [C24|F6] Processing fold...
#   > [TRAIN] R2: 0.9755 | RMSE: 1522 | MAE: 917 | Bias: 73.8
#   > [VAL]   R2: 0.9542 | RMSE: 2102 | MAE: 1230 | Bias: 108.8
#
# [C24|F7] Processing fold...
#   > [TRAIN] R2: 0.9718 | RMSE: 1637 | MAE: 993 | Bias: 81.5
#   > [VAL]   R2: 0.9573 | RMSE: 2010 | MAE: 1218 | Bias: 127.1
#
# [C24|F8] Processing fold...
#   > [TRAIN] R2: 0.9760 | RMSE: 1513 | MAE: 927 | Bias: 75.3
#   > [VAL]   R2: 0.9574 | RMSE: 1961 | MAE: 1197 | Bias: 76.5
#
# Config 24 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 965.2 | R2: 0.9728 | Bias: 78.0
#   [VAL AVG]   MAE: 1238.5 | R2: 0.9521 | Bias: 100.9 | RMSE: 2127.4
#
# ######## CONFIG 25/55 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 255, 'max_iter': 600, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 0.3}
#
# [C25|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9645 | RMSE: 1839 | MAE: 1055 | Bias: 91.9
#   > [VAL]   R2: 0.9574 | RMSE: 1963 | MAE: 1247 | Bias: 65.1
#
# [C25|F2] Processing fold...
#   > [TRAIN] R2: 0.9691 | RMSE: 1714 | MAE: 1050 | Bias: 83.1
#   > [VAL]   R2: 0.9497 | RMSE: 2171 | MAE: 1274 | Bias: 86.6
#
# [C25|F3] Processing fold...
#   > [TRAIN] R2: 0.9710 | RMSE: 1659 | MAE: 980 | Bias: 79.4
#   > [VAL]   R2: 0.9481 | RMSE: 2208 | MAE: 1260 | Bias: 137.0
#
# [C25|F4] Processing fold...
#   > [TRAIN] R2: 0.9711 | RMSE: 1647 | MAE: 1040 | Bias: 79.2
#   > [VAL]   R2: 0.9322 | RMSE: 2639 | MAE: 1293 | Bias: 125.4
#
# [C25|F5] Processing fold...
#   > [TRAIN] R2: 0.9729 | RMSE: 1602 | MAE: 981 | Bias: 71.8
# ...
#
# [C48|F3] Processing fold...
#   > [TRAIN] R2: 0.9711 | RMSE: 1655 | MAE: 978 | Bias: 81.6
#   > [VAL]   R2: 0.9492 | RMSE: 2185 | MAE: 1251 | Bias: 136.0
#
# [C48|F4] Processing fold...
#   > [TRAIN] R2: 0.9657 | RMSE: 1792 | MAE: 1122 | Bias: 94.3
#   > [VAL]   R2: 0.9303 | RMSE: 2676 | MAE: 1321 | Bias: 143.1
#
# [C48|F5] Processing fold...
#   > [TRAIN] R2: 0.9749 | RMSE: 1542 | MAE: 947 | Bias: 70.2
#   > [VAL]   R2: 0.9578 | RMSE: 2015 | MAE: 1229 | Bias: 91.3
#
# [C48|F6] Processing fold...
#   > [TRAIN] R2: 0.9732 | RMSE: 1591 | MAE: 964 | Bias: 79.3
#   > [VAL]   R2: 0.9531 | RMSE: 2127 | MAE: 1220 | Bias: 110.6
#
# [C48|F7] Processing fold...
#   > [TRAIN] R2: 0.9700 | RMSE: 1688 | MAE: 1030 | Bias: 87.2
#   > [VAL]   R2: 0.9571 | RMSE: 2014 | MAE: 1221 | Bias: 129.7
#
# [C48|F8] Processing fold...
#   > [TRAIN] R2: 0.9767 | RMSE: 1492 | MAE: 922 | Bias: 75.4
#   > [VAL]   R2: 0.9574 | RMSE: 1961 | MAE: 1194 | Bias: 71.6
#
# Config 48 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 997.9 | R2: 0.9714 | Bias: 82.3
#   [VAL AVG]   MAE: 1241.7 | R2: 0.9518 | Bias: 103.9 | RMSE: 2132.8
#
# ######## CONFIG 49/55 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 191, 'max_iter': 1200, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C49|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9704 | RMSE: 1680 | MAE: 948 | Bias: 81.8
#   > [VAL]   R2: 0.9598 | RMSE: 1907 | MAE: 1217 | Bias: 58.4
#
# [C49|F2] Processing fold...
#   > [TRAIN] R2: 0.9731 | RMSE: 1599 | MAE: 977 | Bias: 78.6
#   > [VAL]   R2: 0.9512 | RMSE: 2139 | MAE: 1249 | Bias: 81.8
#
# [C49|F3] Processing fold...
#   > [TRAIN] R2: 0.9704 | RMSE: 1676 | MAE: 992 | Bias: 84.3
#   > [VAL]   R2: 0.9471 | RMSE: 2228 | MAE: 1253 | Bias: 146.3
#
# [C49|F4] Processing fold...
#   > [TRAIN] R2: 0.9728 | RMSE: 1597 | MAE: 1007 | Bias: 80.0
#   > [VAL]   R2: 0.9338 | RMSE: 2607 | MAE: 1283 | Bias: 125.9
#
# [C49|F5] Processing fold...
#   > [TRAIN] R2: 0.9723 | RMSE: 1617 | MAE: 984 | Bias: 75.3
#   > [VAL]   R2: 0.9572 | RMSE: 2029 | MAE: 1238 | Bias: 95.9
#
# [C49|F6] Processing fold...
#   > [TRAIN] R2: 0.9733 | RMSE: 1589 | MAE: 959 | Bias: 78.3
#   > [VAL]   R2: 0.9529 | RMSE: 2130 | MAE: 1224 | Bias: 107.7
#
# [C49|F7] Processing fold...
#   > [TRAIN] R2: 0.9727 | RMSE: 1609 | MAE: 978 | Bias: 82.0
#   > [VAL]   R2: 0.9581 | RMSE: 1991 | MAE: 1211 | Bias: 119.1
#
# [C49|F8] Processing fold...
#   > [TRAIN] R2: 0.9727 | RMSE: 1615 | MAE: 995 | Bias: 82.7
#   > [VAL]   R2: 0.9564 | RMSE: 1984 | MAE: 1206 | Bias: 73.9
#
# Config 49 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 980.0 | R2: 0.9722 | Bias: 80.4
#   [VAL AVG]   MAE: 1235.0 | R2: 0.9521 | Bias: 101.1 | RMSE: 2127.0
#
# ######## CONFIG 50/55 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 1200, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 0.3}
#
# [C50|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9640 | RMSE: 1854 | MAE: 1083 | Bias: 93.6
#   > [VAL]   R2: 0.9578 | RMSE: 1954 | MAE: 1248 | Bias: 61.1
#
# [C50|F2] Processing fold...
#   > [TRAIN] R2: 0.9687 | RMSE: 1724 | MAE: 1065 | Bias: 86.4
#   > [VAL]   R2: 0.9508 | RMSE: 2149 | MAE: 1273 | Bias: 89.3
#
# [C50|F3] Processing fold...
#   > [TRAIN] R2: 0.9665 | RMSE: 1782 | MAE: 1068 | Bias: 90.8
#   > [VAL]   R2: 0.9481 | RMSE: 2207 | MAE: 1272 | Bias: 144.4
#
# [C50|F4] Processing fold...
#   > [TRAIN] R2: 0.9648 | RMSE: 1816 | MAE: 1140 | Bias: 93.5
#   > [VAL]   R2: 0.9335 | RMSE: 2613 | MAE: 1311 | Bias: 133.9
#
# [C50|F5] Processing fold...
#   > [TRAIN] R2: 0.9683 | RMSE: 1732 | MAE: 1062 | Bias: 81.3
#   > [VAL]   R2: 0.9570 | RMSE: 2035 | MAE: 1245 | Bias: 91.9
#
# [C50|F6] Processing fold...
#   > [TRAIN] R2: 0.9646 | RMSE: 1829 | MAE: 1118 | Bias: 94.1
#   > [VAL]   R2: 0.9499 | RMSE: 2197 | MAE: 1271 | Bias: 119.1
#
# [C50|F7] Processing fold...
#   > [TRAIN] R2: 0.9673 | RMSE: 1761 | MAE: 1076 | Bias: 91.1
#   > [VAL]   R2: 0.9571 | RMSE: 2015 | MAE: 1232 | Bias: 122.0
#
# [C50|F8] Processing fold...
#   > [TRAIN] R2: 0.9689 | RMSE: 1724 | MAE: 1067 | Bias: 89.3
#   > [VAL]   R2: 0.9558 | RMSE: 1998 | MAE: 1228 | Bias: 77.6
#
# Config 50 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1084.9 | R2: 0.9666 | Bias: 90.0
#   [VAL AVG]   MAE: 1260.0 | R2: 0.9512 | Bias: 104.9 | RMSE: 2146.0
#
# ######## CONFIG 51/55 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 1200, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C51|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9664 | RMSE: 1790 | MAE: 1031 | Bias: 88.2
#   > [VAL]   R2: 0.9582 | RMSE: 1946 | MAE: 1236 | Bias: 57.1
#
# [C51|F2] Processing fold...
#   > [TRAIN] R2: 0.9687 | RMSE: 1723 | MAE: 1057 | Bias: 86.4
#   > [VAL]   R2: 0.9504 | RMSE: 2157 | MAE: 1270 | Bias: 85.4
#
# [C51|F3] Processing fold...
#   > [TRAIN] R2: 0.9651 | RMSE: 1819 | MAE: 1086 | Bias: 91.6
#   > [VAL]   R2: 0.9446 | RMSE: 2281 | MAE: 1283 | Bias: 150.2
#
# [C51|F4] Processing fold...
#   > [TRAIN] R2: 0.9683 | RMSE: 1723 | MAE: 1080 | Bias: 85.4
#   > [VAL]   R2: 0.9331 | RMSE: 2622 | MAE: 1296 | Bias: 128.8
#
# [C51|F5] Processing fold...
#   > [TRAIN] R2: 0.9729 | RMSE: 1601 | MAE: 982 | Bias: 71.9
#   > [VAL]   R2: 0.9579 | RMSE: 2013 | MAE: 1230 | Bias: 86.9
#
# [C51|F6] Processing fold...
#   > [TRAIN] R2: 0.9731 | RMSE: 1595 | MAE: 967 | Bias: 76.9
#   > [VAL]   R2: 0.9537 | RMSE: 2113 | MAE: 1227 | Bias: 101.9
#
# [C51|F7] Processing fold...
#   > [TRAIN] R2: 0.9723 | RMSE: 1621 | MAE: 991 | Bias: 81.1
#   > [VAL]   R2: 0.9581 | RMSE: 1992 | MAE: 1209 | Bias: 121.4
#
# [C51|F8] Processing fold...
#   > [TRAIN] R2: 0.9713 | RMSE: 1654 | MAE: 1022 | Bias: 83.2
#   > [VAL]   R2: 0.9569 | RMSE: 1973 | MAE: 1209 | Bias: 71.7
#
# Config 51 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1026.9 | R2: 0.9698 | Bias: 83.1
#   [VAL AVG]   MAE: 1245.1 | R2: 0.9516 | Bias: 100.4 | RMSE: 2137.2
#
# ######## CONFIG 52/55 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 191, 'max_iter': 1200, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 1.0}
#
# [C52|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9654 | RMSE: 1816 | MAE: 1041 | Bias: 88.4
#   > [VAL]   R2: 0.9583 | RMSE: 1943 | MAE: 1237 | Bias: 56.4
#
# [C52|F2] Processing fold...
#   > [TRAIN] R2: 0.9677 | RMSE: 1752 | MAE: 1064 | Bias: 83.7
#   > [VAL]   R2: 0.9497 | RMSE: 2173 | MAE: 1281 | Bias: 81.1
#
# [C52|F3] Processing fold...
#   > [TRAIN] R2: 0.9688 | RMSE: 1722 | MAE: 1016 | Bias: 82.4
#   > [VAL]   R2: 0.9466 | RMSE: 2240 | MAE: 1271 | Bias: 134.5
#
# [C52|F4] Processing fold...
#   > [TRAIN] R2: 0.9726 | RMSE: 1601 | MAE: 1007 | Bias: 75.5
#   > [VAL]   R2: 0.9331 | RMSE: 2622 | MAE: 1285 | Bias: 124.9
#
# [C52|F5] Processing fold...
#   > [TRAIN] R2: 0.9716 | RMSE: 1639 | MAE: 998 | Bias: 73.0
#   > [VAL]   R2: 0.9577 | RMSE: 2018 | MAE: 1241 | Bias: 84.8
#
# [C52|F6] Processing fold...
#   > [TRAIN] R2: 0.9706 | RMSE: 1668 | MAE: 1008 | Bias: 80.7
#   > [VAL]   R2: 0.9519 | RMSE: 2154 | MAE: 1235 | Bias: 105.3
#
# [C52|F7] Processing fold...
#   > [TRAIN] R2: 0.9682 | RMSE: 1738 | MAE: 1048 | Bias: 85.7
#   > [VAL]   R2: 0.9565 | RMSE: 2029 | MAE: 1230 | Bias: 126.1
#
# [C52|F8] Processing fold...
#   > [TRAIN] R2: 0.9739 | RMSE: 1578 | MAE: 970 | Bias: 76.1
#   > [VAL]   R2: 0.9571 | RMSE: 1967 | MAE: 1201 | Bias: 69.2
#
# Config 52 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1019.1 | R2: 0.9698 | Bias: 80.7
#   [VAL AVG]   MAE: 1247.5 | R2: 0.9513 | Bias: 97.8 | RMSE: 2143.3
#
# ######## CONFIG 53/55 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 255, 'max_iter': 1200, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 0.3}
#
# [C53|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9642 | RMSE: 1847 | MAE: 1057 | Bias: 90.6
#   > [VAL]   R2: 0.9575 | RMSE: 1961 | MAE: 1249 | Bias: 63.2
#
# [C53|F2] Processing fold...
#   > [TRAIN] R2: 0.9666 | RMSE: 1780 | MAE: 1079 | Bias: 87.0
#   > [VAL]   R2: 0.9480 | RMSE: 2208 | MAE: 1285 | Bias: 84.9
#
# [C53|F3] Processing fold...
#   > [TRAIN] R2: 0.9654 | RMSE: 1812 | MAE: 1072 | Bias: 88.9
#   > [VAL]   R2: 0.9443 | RMSE: 2288 | MAE: 1286 | Bias: 146.5
#
# [C53|F4] Processing fold...
#   > [TRAIN] R2: 0.9676 | RMSE: 1743 | MAE: 1083 | Bias: 83.5
#   > [VAL]   R2: 0.9322 | RMSE: 2639 | MAE: 1303 | Bias: 134.1
#
# [C53|F5] Processing fold...
#   > [TRAIN] R2: 0.9702 | RMSE: 1679 | MAE: 1021 | Bias: 75.6
#   > [VAL]   R2: 0.9563 | RMSE: 2051 | MAE: 1257 | Bias: 90.3
#
# [C53|F6] Processing fold...
#   > [TRAIN] R2: 0.9684 | RMSE: 1728 | MAE: 1047 | Bias: 86.0
#   > [VAL]   R2: 0.9523 | RMSE: 2144 | MAE: 1235 | Bias: 109.3
#
# [C53|F7] Processing fold...
#   > [TRAIN] R2: 0.9610 | RMSE: 1922 | MAE: 1144 | Bias: 99.4
#   > [VAL]   R2: 0.9540 | RMSE: 2086 | MAE: 1267 | Bias: 134.6
#
# [C53|F8] Processing fold...
#   > [TRAIN] R2: 0.9658 | RMSE: 1806 | MAE: 1100 | Bias: 91.9
#   > [VAL]   R2: 0.9539 | RMSE: 2039 | MAE: 1243 | Bias: 80.5
#
# Config 53 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1075.4 | R2: 0.9662 | Bias: 87.9
#   [VAL AVG]   MAE: 1265.6 | R2: 0.9498 | Bias: 105.4 | RMSE: 2177.1
#
# ######## CONFIG 54/55 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 255, 'max_iter': 1200, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 0.3}
#
# [C54|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9693 | RMSE: 1710 | MAE: 978 | Bias: 83.2
#   > [VAL]   R2: 0.9585 | RMSE: 1937 | MAE: 1234 | Bias: 57.3
#
# [C54|F2] Processing fold...
#   > [TRAIN] R2: 0.9754 | RMSE: 1529 | MAE: 935 | Bias: 72.5
#   > [VAL]   R2: 0.9503 | RMSE: 2158 | MAE: 1256 | Bias: 84.2
#
# [C54|F3] Processing fold...
#   > [TRAIN] R2: 0.9747 | RMSE: 1550 | MAE: 911 | Bias: 73.6
#   > [VAL]   R2: 0.9510 | RMSE: 2146 | MAE: 1253 | Bias: 132.8
#
# [C54|F4] Processing fold...
#   > [TRAIN] R2: 0.9763 | RMSE: 1490 | MAE: 948 | Bias: 72.5
#   > [VAL]   R2: 0.9334 | RMSE: 2616 | MAE: 1275 | Bias: 122.9
#
# [C54|F5] Processing fold...
#   > [TRAIN] R2: 0.9778 | RMSE: 1449 | MAE: 887 | Bias: 63.1
#   > [VAL]   R2: 0.9576 | RMSE: 2019 | MAE: 1227 | Bias: 86.2
#
# [C54|F6] Processing fold...
#   > [TRAIN] R2: 0.9756 | RMSE: 1519 | MAE: 924 | Bias: 73.7
#   > [VAL]   R2: 0.9540 | RMSE: 2106 | MAE: 1227 | Bias: 112.3
#
# [C54|F7] Processing fold...
#   > [TRAIN] R2: 0.9742 | RMSE: 1564 | MAE: 958 | Bias: 76.9
#   > [VAL]   R2: 0.9573 | RMSE: 2011 | MAE: 1212 | Bias: 121.0
#
# [C54|F8] Processing fold...
#   > [TRAIN] R2: 0.9731 | RMSE: 1601 | MAE: 993 | Bias: 81.4
#   > [VAL]   R2: 0.9558 | RMSE: 1998 | MAE: 1214 | Bias: 69.1
#
# Config 54 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 941.6 | R2: 0.9746 | Bias: 74.6
#   [VAL AVG]   MAE: 1237.4 | R2: 0.9522 | Bias: 98.2 | RMSE: 2124.0
#
# ######## CONFIG 55/55 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 63, 'max_iter': 1000, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 1.0}
#
# [C55|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (12/15) with FS_KEEP_RATIO=0.80
#   > [TRAIN] R2: 0.9670 | RMSE: 1775 | MAE: 1036 | Bias: 87.4
#   > [VAL]   R2: 0.9584 | RMSE: 1940 | MAE: 1239 | Bias: 50.2
#
# [C55|F2] Processing fold...
#   > [TRAIN] R2: 0.9670 | RMSE: 1771 | MAE: 1098 | Bias: 90.5
#   > [VAL]   R2: 0.9523 | RMSE: 2116 | MAE: 1278 | Bias: 94.0
#
# [C55|F3] Processing fold...
#   > [TRAIN] R2: 0.9669 | RMSE: 1772 | MAE: 1075 | Bias: 90.0
#   > [VAL]   R2: 0.9475 | RMSE: 2221 | MAE: 1275 | Bias: 150.0
#
# [C55|F4] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1678 | MAE: 1070 | Bias: 85.2
#   > [VAL]   R2: 0.9340 | RMSE: 2603 | MAE: 1288 | Bias: 124.9
#
# [C55|F5] Processing fold...
#   > [TRAIN] R2: 0.9674 | RMSE: 1755 | MAE: 1086 | Bias: 85.5
#   > [VAL]   R2: 0.9566 | RMSE: 2044 | MAE: 1261 | Bias: 88.2
#
# [C55|F6] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1689 | MAE: 1037 | Bias: 85.4
#   > [VAL]   R2: 0.9537 | RMSE: 2113 | MAE: 1245 | Bias: 114.9
#
# [C55|F7] Processing fold...
#   > [TRAIN] R2: 0.9695 | RMSE: 1700 | MAE: 1047 | Bias: 88.4
#   > [VAL]   R2: 0.9574 | RMSE: 2009 | MAE: 1221 | Bias: 123.9
#
# [C55|F8] Processing fold...
#   > [TRAIN] R2: 0.9716 | RMSE: 1647 | MAE: 1028 | Bias: 86.7
#   > [VAL]   R2: 0.9563 | RMSE: 1985 | MAE: 1222 | Bias: 70.2
#
# Config 55 SUMMARY:
#   Selected features (avg): 12 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1059.6 | R2: 0.9687 | Bias: 87.4
#   [VAL AVG]   MAE: 1253.6 | R2: 0.9520 | Bias: 102.0 | RMSE: 2128.8
# # END OF SEARCH
#
# Top 5 Configurations by RMSE:
#     config_id  fs_keep_ratio  avg_selected_features  learning_rate  max_iter  \
# 10         11            0.8                   12.0          0.100       600
# 16         17            0.8                   12.0          0.115       800
# 20         21            0.8                   12.0          0.085       800
# 0           1            0.8                   12.0          0.100       600
# 5           6            0.8                   12.0          0.100      1000
#
#     max_leaf_nodes  max_depth     val_rmse      val_mae    val_r2  train_r2  \
# 10             127       15.0  2113.186922  1239.187341  0.952742  0.970885
# 16             191       25.0  2114.854980  1236.397802  0.952616  0.973334
# 20             127       20.0  2117.302427  1240.438267  0.952551  0.970729
# 0              191       25.0  2120.670704  1230.744162  0.952379  0.974598
# 5              127        NaN  2120.935928  1242.359637  0.952374  0.971383
#
#       val_bias
# 10   98.572286
# 16   99.584691
# 20  101.202579
# 0   100.405661
# 5    99.807173
# Best Config found:
# {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 600, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 3.0}

# %% [markdown]
# ##### 3.3.3.3. With Feature Selection - Top 90% Features by Importance <a id="agenoown90"></a>

# %%
# numeric features used by the model (year is replaced by age; previousOwners is excluded)
numeric_features = ["mileage", "engineSize", "tax", "mpg", "age"]

# shuffles the data, in order to (at least theoretically) have more balanced folds
# we will use an 8-fold cross-validation strategy
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)

# we explicitly exclude this feature from the model input
DROP_FROM_MODEL = ["previousOwners"]

# feature selection: keep 90% of the final encoded feature space
FS_KEEP_RATIO = 0.90

# RandomForest used only to rank feature importances for SelectFromModel
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

# hyperparameter space that we are going to use for random search
# each configuration will get 1 value from each of these lists
param_distributions = {
    "loss": ["squared_error"],
    "learning_rate": [0.07, 0.085, 0.1, 0.115],
    "max_iter": [600, 800, 1000, 1200],
    "max_leaf_nodes": [63, 127, 191, 255],
    "l2_regularization": [0.3, 1.0, 3.0],
    "min_samples_leaf": [12, 16, 20, 28],
    "max_depth": [15, 20, 25, None],
}

N_RANDOM_CONFIGS = 25  # short random search, enough for baseline results

# we get N_RANDOM_CONFIGS random parameter combinations from param_distributions
sampler = ParameterSampler(param_distributions, n_iter=N_RANDOM_CONFIGS, random_state=RANDOM_STATE)

search_results = []  # stores results for ranking
best_rmse = np.inf
best_config = None

# log setup (mainly for development and traceability)
log_dir = "gb_logs"
os.makedirs(log_dir, exist_ok=True)
log_filename = "2gb_noowners_age_logprice_fs90m_log25it.txt"
log_path = os.path.join(log_dir, log_filename)

# Note: this section is included mainly for organization purposes
with open(log_path, "w", encoding="utf-8") as log_file:

    def log(msg: str):
        print(msg)
        log_file.write(msg + "\n")
        log_file.flush()

    log("# =============================")
    log("# START OF HGB SEARCH (LOG TARGET + AGE FEATURE + FS 90%)")
    log("# METRICS ON ORIGINAL SCALE: R2, RMSE, MAE, BIAS")
    log(f"# LOG FILE SAVED TO: {log_path}")
    log("# =============================")

    for config_id, params in enumerate(sampler, start=1):
        log("")
        log(f"######## CONFIG {config_id}/{N_RANDOM_CONFIGS} ########")
        log(f"Parameters: {params}")

        fold_rmses_val, fold_maes_val, fold_r2s_val, fold_bias_val = [], [], [], []
        fold_rmses_tr,  fold_maes_tr,  fold_r2s_tr,  fold_bias_tr  = [], [], [], []
        fold_med_ae = []
        fold_nsel = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):

            X_train, X_val = X.iloc[train_idx].copy(), X.iloc[val_idx].copy()
            y_train, y_val = y.iloc[train_idx].copy(), y.iloc[val_idx].copy()

            # log-transform target for training
            y_train_log = np.log1p(y_train)

            log(f"\n[C{config_id}|F{fold}] Processing fold...")

            # -> Preprocessing steps (fit only on training fold, apply to both)
            year_state = fit_year_median(X_train, year_col="year", model_col="model")
            X_train = transform_year_with_model_median(X_train, state=year_state)
            X_val   = transform_year_with_model_median(X_val,   state=year_state)

            mileage_state = fit_mileage_imputer(X_train, mileage_col="mileage", do_abs=True)
            X_train = transform_mileage_imputer(X_train, state=mileage_state)
            X_val   = transform_mileage_imputer(X_val,   state=mileage_state)

            engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
            X_train = transform_engine_size_imputer(X_train, state=engine_state)
            X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

            X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
            X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

            mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
            X_train = transform_mpg_imputer(X_train, state=mpg_state)
            X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

            brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
            X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
            X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

            model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
            X_train, _, _ = transform_invalid_models(X_train, model_state)
            X_val,   _, _ = transform_invalid_models(X_val,   model_state)

            transm_state = fit_transmission_resolver(X_train, valid_transmissions)
            X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
            X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

            fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
            X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
            X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

            # -> Feature engineering: create age and drop year (do this after all year-based steps)
            X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
            X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

            # hard guarantee: previousOwners is not used by the model
            X_train = X_train.drop(columns=DROP_FROM_MODEL, errors="ignore")
            X_val   = X_val.drop(columns=DROP_FROM_MODEL, errors="ignore")

            # -> Feature encoding (categorical only)
            high_card_features = ["Brand", "model"]
            low_card_features  = [c for c in categorical_features if c not in high_card_features]

            te = MyTargetEncoder(smoothing=5)
            te.fit(X_train[high_card_features], y_train_log)  # fit using log-target
            X_train_high = te.transform(X_train[high_card_features])
            X_val_high   = te.transform(X_val[high_card_features])

            ohe = MyOneHotEncoder()
            ohe.fit(X_train[low_card_features])
            X_train_low = ohe.transform(X_train[low_card_features])
            X_val_low   = ohe.transform(X_val[low_card_features])

            X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
            X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

            # join numerical and categorical (encoded) features
            X_train_final = pd.concat([X_train[numeric_features], X_train_cat], axis=1)
            X_val_final   = pd.concat([X_val[numeric_features],   X_val_cat],   axis=1)

            # align columns to avoid mismatch due to encoding
            X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

            if fold == 1:
                feature_names = list(X_train_final.columns)
                log(f"  > Features before FS ({len(feature_names)}): {feature_names}")

            # -> Feature selection (keep top 90% features by RF importance)
            n_feats = X_train_final.shape[1]
            k = int(np.ceil(FS_KEEP_RATIO * n_feats))
            k = max(1, min(k, n_feats))

            rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
            rf_fs.fit(X_train_final, y_train_log)

            selector = SelectFromModel(
                estimator=rf_fs,
                threshold=-np.inf,  # keep the top max_features
                max_features=k,
                prefit=True
            )

            selected_cols = X_train_final.columns[selector.get_support()]
            fold_nsel.append(len(selected_cols))

            X_train_sel = X_train_final[selected_cols]
            X_val_sel   = X_val_final[selected_cols]

            if fold == 1:
                log(f"  > Selected features ({len(selected_cols)}/{n_feats}) with FS_KEEP_RATIO={FS_KEEP_RATIO:.2f}")

            # -> Model training (train on log-target)
            hgb_model = HistGradientBoostingRegressor(random_state=RANDOM_STATE, **params)
            hgb_model.fit(X_train_sel, y_train_log)

            # predictions (log scale), then invert to original scale
            y_pred_train_log = hgb_model.predict(X_train_sel)
            y_pred_val_log   = hgb_model.predict(X_val_sel)

            y_pred_train = np.expm1(y_pred_train_log)
            y_pred_val   = np.expm1(y_pred_val_log)

            # -> Metrics on original scale
            mae_tr  = mean_absolute_error(y_train, y_pred_train)
            rmse_tr = np.sqrt(mean_squared_error(y_train, y_pred_train))
            r2_tr   = r2_score(y_train, y_pred_train)
            bias_tr = np.mean(y_train - y_pred_train)

            mae_val  = mean_absolute_error(y_val, y_pred_val)
            rmse_val = np.sqrt(mean_squared_error(y_val, y_pred_val))
            r2_val   = r2_score(y_val, y_pred_val)
            bias_val = np.mean(y_val - y_pred_val)

            med_ae_val = median_absolute_error(y_val, y_pred_val)

            log(f"  > [TRAIN] R2: {r2_tr:.4f} | RMSE: {rmse_tr:.0f} | MAE: {mae_tr:.0f} | Bias: {bias_tr:.1f}")
            log(f"  > [VAL]   R2: {r2_val:.4f} | RMSE: {rmse_val:.0f} | MAE: {mae_val:.0f} | Bias: {bias_val:.1f}")

            fold_maes_tr.append(mae_tr);   fold_rmses_tr.append(rmse_tr);   fold_r2s_tr.append(r2_tr);   fold_bias_tr.append(bias_tr)
            fold_maes_val.append(mae_val); fold_rmses_val.append(rmse_val); fold_r2s_val.append(r2_val); fold_bias_val.append(bias_val)
            fold_med_ae.append(med_ae_val)

        mean_rmse_val = np.mean(fold_rmses_val)
        mean_mae_val  = np.mean(fold_maes_val)
        mean_r2_val   = np.mean(fold_r2s_val)
        mean_bias_val = np.mean(fold_bias_val)

        mean_mae_tr   = np.mean(fold_maes_tr)
        mean_r2_tr    = np.mean(fold_r2s_tr)
        mean_bias_tr  = np.mean(fold_bias_tr)

        mean_nsel = float(np.mean(fold_nsel))

        log("")
        log(f"Config {config_id} SUMMARY:")
        log(f"  Selected features (avg): {mean_nsel:.0f} / {X.shape[1]} (note: final space is after encoding)")
        log(f"  [TRAIN AVG] MAE: {mean_mae_tr:.1f} | R2: {mean_r2_tr:.4f} | Bias: {mean_bias_tr:.1f}")
        log(f"  [VAL AVG]   MAE: {mean_mae_val:.1f} | R2: {mean_r2_val:.4f} | Bias: {mean_bias_val:.1f} | RMSE: {mean_rmse_val:.1f}")

        search_results.append({
            "config_id": config_id,
            **params,

            "fs_keep_ratio": FS_KEEP_RATIO,
            "avg_selected_features": mean_nsel,

            "val_rmse": mean_rmse_val,
            "val_mae": mean_mae_val,
            "val_r2": mean_r2_val,
            "val_bias": mean_bias_val,

            "train_mae": mean_mae_tr,
            "train_r2": mean_r2_tr,
            "train_bias": mean_bias_tr,

            "val_med_ae": np.mean(fold_med_ae)
        })

        if mean_rmse_val < best_rmse:
            best_rmse = mean_rmse_val
            best_config = {**params}
            log(f"[NEW BEST RMSE] Config {config_id}")

    log("# END OF SEARCH")

# Results
results_df = pd.DataFrame(search_results)
results_df_sorted = results_df.sort_values(by="val_rmse", ascending=True)

print("\nTop 5 Configurations by RMSE:")
cols = [
    "config_id", "fs_keep_ratio", "avg_selected_features",
    "learning_rate", "max_iter", "max_leaf_nodes", "max_depth",
    "val_rmse", "val_mae", "val_r2", "train_r2", "val_bias"
]
display(results_df_sorted[cols].head(5))

print("\nBest Config found:")
print(best_config)
# Out:
# # =============================
# # START OF HGB SEARCH (LOG TARGET + AGE FEATURE + FS 90%)
# # METRICS ON ORIGINAL SCALE: R2, RMSE, MAE, BIAS
# # LOG FILE SAVED TO: gb_logs/2gb_noowners_age_logprice_fs90m_log25it.txt
# # =============================
#
# ######## CONFIG 1/25 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 255, 'max_iter': 800, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 0.3}
#
# [C1|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9675 | RMSE: 1761 | MAE: 1007 | Bias: 86.2
#   > [VAL]   R2: 0.9584 | RMSE: 1940 | MAE: 1238 | Bias: 61.7
#
# [C1|F2] Processing fold...
#   > [TRAIN] R2: 0.9733 | RMSE: 1593 | MAE: 973 | Bias: 76.6
#   > [VAL]   R2: 0.9494 | RMSE: 2179 | MAE: 1265 | Bias: 92.5
#
# [C1|F3] Processing fold...
#   > [TRAIN] R2: 0.9740 | RMSE: 1570 | MAE: 920 | Bias: 74.4
#   > [VAL]   R2: 0.9493 | RMSE: 2183 | MAE: 1254 | Bias: 137.9
#
# [C1|F4] Processing fold...
#   > [TRAIN] R2: 0.9765 | RMSE: 1485 | MAE: 937 | Bias: 72.1
#   > [VAL]   R2: 0.9333 | RMSE: 2618 | MAE: 1274 | Bias: 121.1
#
# [C1|F5] Processing fold...
#   > [TRAIN] R2: 0.9775 | RMSE: 1459 | MAE: 889 | Bias: 64.5
#   > [VAL]   R2: 0.9571 | RMSE: 2032 | MAE: 1229 | Bias: 91.0
#
# [C1|F6] Processing fold...
#   > [TRAIN] R2: 0.9765 | RMSE: 1492 | MAE: 902 | Bias: 72.8
#   > [VAL]   R2: 0.9537 | RMSE: 2112 | MAE: 1237 | Bias: 114.3
#
# [C1|F7] Processing fold...
#   > [TRAIN] R2: 0.9740 | RMSE: 1570 | MAE: 951 | Bias: 76.7
#   > [VAL]   R2: 0.9570 | RMSE: 2016 | MAE: 1216 | Bias: 112.1
#
# [C1|F8] Processing fold...
#   > [TRAIN] R2: 0.9765 | RMSE: 1499 | MAE: 926 | Bias: 75.2
#   > [VAL]   R2: 0.9556 | RMSE: 2001 | MAE: 1210 | Bias: 74.6
#
# Config 1 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 938.2 | R2: 0.9745 | Bias: 74.8
#   [VAL AVG]   MAE: 1240.4 | R2: 0.9517 | Bias: 100.6 | RMSE: 2135.1
# [NEW BEST RMSE] Config 1
#
# ######## CONFIG 2/25 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 255, 'max_iter': 600, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 1.0}
#
# [C2|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9670 | RMSE: 1775 | MAE: 1015 | Bias: 85.8
#   > [VAL]   R2: 0.9583 | RMSE: 1943 | MAE: 1235 | Bias: 55.9
#
# [C2|F2] Processing fold...
#   > [TRAIN] R2: 0.9729 | RMSE: 1604 | MAE: 987 | Bias: 76.1
#   > [VAL]   R2: 0.9492 | RMSE: 2183 | MAE: 1262 | Bias: 83.7
#
# [C2|F3] Processing fold...
#   > [TRAIN] R2: 0.9706 | RMSE: 1670 | MAE: 990 | Bias: 80.4
#   > [VAL]   R2: 0.9488 | RMSE: 2193 | MAE: 1259 | Bias: 133.5
#
# [C2|F4] Processing fold...
#   > [TRAIN] R2: 0.9751 | RMSE: 1528 | MAE: 966 | Bias: 70.8
#   > [VAL]   R2: 0.9340 | RMSE: 2604 | MAE: 1280 | Bias: 123.4
#
# [C2|F5] Processing fold...
#   > [TRAIN] R2: 0.9710 | RMSE: 1656 | MAE: 1011 | Bias: 75.5
#   > [VAL]   R2: 0.9567 | RMSE: 2041 | MAE: 1252 | Bias: 86.5
#
# [C2|F6] Processing fold...
#   > [TRAIN] R2: 0.9712 | RMSE: 1650 | MAE: 999 | Bias: 80.6
#   > [VAL]   R2: 0.9535 | RMSE: 2118 | MAE: 1230 | Bias: 108.1
#
# [C2|F7] Processing fold...
#   > [TRAIN] R2: 0.9688 | RMSE: 1721 | MAE: 1045 | Bias: 85.9
#   > [VAL]   R2: 0.9571 | RMSE: 2014 | MAE: 1220 | Bias: 123.2
#
# [C2|F8] Processing fold...
#   > [TRAIN] R2: 0.9727 | RMSE: 1614 | MAE: 995 | Bias: 78.7
#   > [VAL]   R2: 0.9564 | RMSE: 1983 | MAE: 1211 | Bias: 70.8
#
# Config 2 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1001.0 | R2: 0.9712 | Bias: 79.2
#   [VAL AVG]   MAE: 1243.6 | R2: 0.9517 | Bias: 98.1 | RMSE: 2134.8
# [NEW BEST RMSE] Config 2
#
# ######## CONFIG 3/25 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C3|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9691 | RMSE: 1717 | MAE: 976 | Bias: 82.5
#   > [VAL]   R2: 0.9599 | RMSE: 1906 | MAE: 1216 | Bias: 48.9
#
# [C3|F2] Processing fold...
#   > [TRAIN] R2: 0.9694 | RMSE: 1705 | MAE: 1042 | Bias: 84.0
#   > [VAL]   R2: 0.9497 | RMSE: 2173 | MAE: 1269 | Bias: 86.9
#
# [C3|F3] Processing fold...
#   > [TRAIN] R2: 0.9713 | RMSE: 1651 | MAE: 974 | Bias: 80.5
#   > [VAL]   R2: 0.9474 | RMSE: 2223 | MAE: 1257 | Bias: 142.7
#
# [C3|F4] Processing fold...
#   > [TRAIN] R2: 0.9738 | RMSE: 1566 | MAE: 987 | Bias: 74.9
#   > [VAL]   R2: 0.9343 | RMSE: 2598 | MAE: 1279 | Bias: 130.6
#
# [C3|F5] Processing fold...
#   > [TRAIN] R2: 0.9731 | RMSE: 1595 | MAE: 972 | Bias: 72.2
#   > [VAL]   R2: 0.9577 | RMSE: 2018 | MAE: 1234 | Bias: 88.4
#
# [C3|F6] Processing fold...
#   > [TRAIN] R2: 0.9689 | RMSE: 1716 | MAE: 1032 | Bias: 85.7
#   > [VAL]   R2: 0.9502 | RMSE: 2191 | MAE: 1238 | Bias: 116.9
#
# [C3|F7] Processing fold...
#   > [TRAIN] R2: 0.9712 | RMSE: 1651 | MAE: 1004 | Bias: 83.2
#   > [VAL]   R2: 0.9581 | RMSE: 1992 | MAE: 1208 | Bias: 119.3
#
# [C3|F8] Processing fold...
#   > [TRAIN] R2: 0.9716 | RMSE: 1648 | MAE: 1015 | Bias: 82.6
#   > [VAL]   R2: 0.9569 | RMSE: 1972 | MAE: 1205 | Bias: 73.1
#
# Config 3 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1000.1 | R2: 0.9710 | Bias: 80.7
#   [VAL AVG]   MAE: 1238.0 | R2: 0.9517 | Bias: 100.8 | RMSE: 2134.2
# [NEW BEST RMSE] Config 3
#
# ######## CONFIG 4/25 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 600, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C4|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9658 | RMSE: 1806 | MAE: 1036 | Bias: 89.2
#   > [VAL]   R2: 0.9583 | RMSE: 1942 | MAE: 1236 | Bias: 57.9
#
# [C4|F2] Processing fold...
#   > [TRAIN] R2: 0.9678 | RMSE: 1748 | MAE: 1067 | Bias: 87.3
#   > [VAL]   R2: 0.9499 | RMSE: 2169 | MAE: 1280 | Bias: 88.9
#
# [C4|F3] Processing fold...
#   > [TRAIN] R2: 0.9671 | RMSE: 1768 | MAE: 1047 | Bias: 88.1
#   > [VAL]   R2: 0.9466 | RMSE: 2239 | MAE: 1266 | Bias: 139.7
#
# [C4|F4] Processing fold...
#   > [TRAIN] R2: 0.9723 | RMSE: 1610 | MAE: 1016 | Bias: 77.3
#   > [VAL]   R2: 0.9355 | RMSE: 2573 | MAE: 1273 | Bias: 125.3
#
# [C4|F5] Processing fold...
#   > [TRAIN] R2: 0.9701 | RMSE: 1682 | MAE: 1024 | Bias: 76.9
#   > [VAL]   R2: 0.9565 | RMSE: 2046 | MAE: 1243 | Bias: 88.5
#
# [C4|F6] Processing fold...
#   > [TRAIN] R2: 0.9686 | RMSE: 1723 | MAE: 1045 | Bias: 86.1
#   > [VAL]   R2: 0.9523 | RMSE: 2144 | MAE: 1234 | Bias: 113.0
#
# [C4|F7] Processing fold...
#   > [TRAIN] R2: 0.9673 | RMSE: 1762 | MAE: 1064 | Bias: 90.5
#   > [VAL]   R2: 0.9573 | RMSE: 2010 | MAE: 1225 | Bias: 125.8
#
# [C4|F8] Processing fold...
#   > [TRAIN] R2: 0.9674 | RMSE: 1763 | MAE: 1077 | Bias: 90.2
#   > [VAL]   R2: 0.9563 | RMSE: 1987 | MAE: 1220 | Bias: 70.3
#
# Config 4 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1046.9 | R2: 0.9683 | Bias: 85.7
#   [VAL AVG]   MAE: 1247.1 | R2: 0.9516 | Bias: 101.2 | RMSE: 2138.7
#
# ######## CONFIG 5/25 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C5|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9654 | RMSE: 1816 | MAE: 1046 | Bias: 90.1
#   > [VAL]   R2: 0.9587 | RMSE: 1934 | MAE: 1234 | Bias: 64.4
#
# [C5|F2] Processing fold...
#   > [TRAIN] R2: 0.9675 | RMSE: 1757 | MAE: 1072 | Bias: 88.8
#   > [VAL]   R2: 0.9507 | RMSE: 2151 | MAE: 1273 | Bias: 90.6
#
# [C5|F3] Processing fold...
#   > [TRAIN] R2: 0.9714 | RMSE: 1647 | MAE: 976 | Bias: 80.4
#   > [VAL]   R2: 0.9489 | RMSE: 2191 | MAE: 1256 | Bias: 136.4
#
# [C5|F4] Processing fold...
#   > [TRAIN] R2: 0.9680 | RMSE: 1732 | MAE: 1092 | Bias: 87.5
#   > [VAL]   R2: 0.9331 | RMSE: 2621 | MAE: 1303 | Bias: 132.2
#
# [C5|F5] Processing fold...
#   > [TRAIN] R2: 0.9727 | RMSE: 1608 | MAE: 981 | Bias: 72.5
#   > [VAL]   R2: 0.9574 | RMSE: 2024 | MAE: 1233 | Bias: 84.4
#
# [C5|F6] Processing fold...
#   > [TRAIN] R2: 0.9712 | RMSE: 1652 | MAE: 998 | Bias: 80.3
#   > [VAL]   R2: 0.9532 | RMSE: 2125 | MAE: 1232 | Bias: 107.6
#
# [C5|F7] Processing fold...
#   > [TRAIN] R2: 0.9689 | RMSE: 1717 | MAE: 1041 | Bias: 87.5
#   > [VAL]   R2: 0.9576 | RMSE: 2004 | MAE: 1224 | Bias: 123.4
#
# [C5|F8] Processing fold...
#   > [TRAIN] R2: 0.9745 | RMSE: 1559 | MAE: 962 | Bias: 76.8
#   > [VAL]   R2: 0.9573 | RMSE: 1964 | MAE: 1203 | Bias: 65.8
#
# Config 5 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1021.1 | R2: 0.9700 | Bias: 83.0
#   [VAL AVG]   MAE: 1244.9 | R2: 0.9521 | Bias: 100.6 | RMSE: 2126.5
# [NEW BEST RMSE] Config 5
#
# ######## CONFIG 6/25 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 191, 'max_iter': 1200, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}
#
# [C6|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9700 | RMSE: 1691 | MAE: 957 | Bias: 81.3
#   > [VAL]   R2: 0.9593 | RMSE: 1920 | MAE: 1221 | Bias: 53.8
#
# [C6|F2] Processing fold...
#   > [TRAIN] R2: 0.9717 | RMSE: 1638 | MAE: 1004 | Bias: 80.5
#   > [VAL]   R2: 0.9513 | RMSE: 2137 | MAE: 1261 | Bias: 96.7
#
# [C6|F3] Processing fold...
#   > [TRAIN] R2: 0.9727 | RMSE: 1610 | MAE: 953 | Bias: 79.0
#   > [VAL]   R2: 0.9493 | RMSE: 2183 | MAE: 1248 | Bias: 139.0
#
# [C6|F4] Processing fold...
#   > [TRAIN] R2: 0.9746 | RMSE: 1543 | MAE: 976 | Bias: 75.3
#   > [VAL]   R2: 0.9352 | RMSE: 2580 | MAE: 1273 | Bias: 127.4
#
# [C6|F5] Processing fold...
#   > [TRAIN] R2: 0.9754 | RMSE: 1526 | MAE: 933 | Bias: 69.1
#   > [VAL]   R2: 0.9576 | RMSE: 2019 | MAE: 1230 | Bias: 92.8
#
# [C6|F6] Processing fold...
#   > [TRAIN] R2: 0.9752 | RMSE: 1532 | MAE: 929 | Bias: 74.7
#   > [VAL]   R2: 0.9555 | RMSE: 2072 | MAE: 1219 | Bias: 107.3
#
# [C6|F7] Processing fold...
#   > [TRAIN] R2: 0.9709 | RMSE: 1660 | MAE: 1009 | Bias: 84.5
#   > [VAL]   R2: 0.9574 | RMSE: 2009 | MAE: 1211 | Bias: 121.1
#
# [C6|F8] Processing fold...
#   > [TRAIN] R2: 0.9726 | RMSE: 1617 | MAE: 993 | Bias: 82.3
#   > [VAL]   R2: 0.9567 | RMSE: 1976 | MAE: 1205 | Bias: 73.7
#
# Config 6 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 969.2 | R2: 0.9729 | Bias: 78.4
#   [VAL AVG]   MAE: 1233.6 | R2: 0.9528 | Bias: 101.5 | RMSE: 2112.0
# [NEW BEST RMSE] Config 6
#
# ######## CONFIG 7/25 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 800, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 0.3}
#
# [C7|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9618 | RMSE: 1909 | MAE: 1117 | Bias: 98.7
#   > [VAL]   R2: 0.9574 | RMSE: 1963 | MAE: 1260 | Bias: 64.8
#
# [C7|F2] Processing fold...
#   > [TRAIN] R2: 0.9641 | RMSE: 1845 | MAE: 1134 | Bias: 96.3
#   > [VAL]   R2: 0.9495 | RMSE: 2177 | MAE: 1293 | Bias: 94.5
#
# [C7|F3] Processing fold...
#   > [TRAIN] R2: 0.9610 | RMSE: 1923 | MAE: 1150 | Bias: 100.5
#   > [VAL]   R2: 0.9444 | RMSE: 2286 | MAE: 1302 | Bias: 154.5
#
# [C7|F4] Processing fold...
#   > [TRAIN] R2: 0.9692 | RMSE: 1698 | MAE: 1074 | Bias: 85.6
#   > [VAL]   R2: 0.9356 | RMSE: 2572 | MAE: 1284 | Bias: 125.1
#
# [C7|F5] Processing fold...
#   > [TRAIN] R2: 0.9697 | RMSE: 1694 | MAE: 1042 | Bias: 80.1
#   > [VAL]   R2: 0.9572 | RMSE: 2028 | MAE: 1237 | Bias: 87.7
#
# [C7|F6] Processing fold...
#   > [TRAIN] R2: 0.9686 | RMSE: 1724 | MAE: 1053 | Bias: 87.6
#   > [VAL]   R2: 0.9519 | RMSE: 2152 | MAE: 1243 | Bias: 111.5
#
# [C7|F7] Processing fold...
#   > [TRAIN] R2: 0.9683 | RMSE: 1734 | MAE: 1059 | Bias: 90.1
#   > [VAL]   R2: 0.9573 | RMSE: 2010 | MAE: 1224 | Bias: 117.1
#
# [C7|F8] Processing fold...
#   > [TRAIN] R2: 0.9683 | RMSE: 1739 | MAE: 1077 | Bias: 90.6
#   > [VAL]   R2: 0.9552 | RMSE: 2011 | MAE: 1237 | Bias: 75.9
#
# Config 7 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1088.2 | R2: 0.9664 | Bias: 91.2
#   [VAL AVG]   MAE: 1259.9 | R2: 0.9511 | Bias: 103.9 | RMSE: 2150.0
#
# ######## CONFIG 8/25 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C8|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9650 | RMSE: 1827 | MAE: 1054 | Bias: 92.7
#   > [VAL]   R2: 0.9576 | RMSE: 1959 | MAE: 1243 | Bias: 65.4
#
# [C8|F2] Processing fold...
#   > [TRAIN] R2: 0.9710 | RMSE: 1660 | MAE: 1014 | Bias: 82.5
#   > [VAL]   R2: 0.9503 | RMSE: 2158 | MAE: 1263 | Bias: 89.1
#
# [C8|F3] Processing fold...
#   > [TRAIN] R2: 0.9722 | RMSE: 1625 | MAE: 958 | Bias: 78.9
#   > [VAL]   R2: 0.9492 | RMSE: 2185 | MAE: 1246 | Bias: 135.9
#
# [C8|F4] Processing fold...
#   > [TRAIN] R2: 0.9702 | RMSE: 1672 | MAE: 1050 | Bias: 83.4
#   > [VAL]   R2: 0.9334 | RMSE: 2615 | MAE: 1290 | Bias: 131.0
#
# [C8|F5] Processing fold...
#   > [TRAIN] R2: 0.9713 | RMSE: 1649 | MAE: 1007 | Bias: 76.4
#   > [VAL]   R2: 0.9561 | RMSE: 2056 | MAE: 1246 | Bias: 92.2
#
# [C8|F6] Processing fold...
#   > [TRAIN] R2: 0.9722 | RMSE: 1621 | MAE: 980 | Bias: 79.2
#   > [VAL]   R2: 0.9537 | RMSE: 2113 | MAE: 1227 | Bias: 108.0
#
# [C8|F7] Processing fold...
#   > [TRAIN] R2: 0.9642 | RMSE: 1843 | MAE: 1115 | Bias: 98.5
#   > [VAL]   R2: 0.9556 | RMSE: 2050 | MAE: 1249 | Bias: 127.2
#
# [C8|F8] Processing fold...
#   > [TRAIN] R2: 0.9724 | RMSE: 1622 | MAE: 995 | Bias: 82.0
#   > [VAL]   R2: 0.9572 | RMSE: 1965 | MAE: 1200 | Bias: 68.2
#
# Config 8 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1021.7 | R2: 0.9698 | Bias: 84.2
#   [VAL AVG]   MAE: 1245.4 | R2: 0.9516 | Bias: 102.1 | RMSE: 2137.5
#
# ######## CONFIG 9/25 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 0.3}
#
# [C9|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9677 | RMSE: 1756 | MAE: 1006 | Bias: 86.2
#   > [VAL]   R2: 0.9586 | RMSE: 1935 | MAE: 1230 | Bias: 56.8
#
# [C9|F2] Processing fold...
#   > [TRAIN] R2: 0.9724 | RMSE: 1619 | MAE: 989 | Bias: 78.3
#   > [VAL]   R2: 0.9482 | RMSE: 2205 | MAE: 1266 | Bias: 85.0
#
# [C9|F3] Processing fold...
#   > [TRAIN] R2: 0.9709 | RMSE: 1661 | MAE: 979 | Bias: 80.7
#   > [VAL]   R2: 0.9474 | RMSE: 2223 | MAE: 1260 | Bias: 143.0
#
# [C9|F4] Processing fold...
#   > [TRAIN] R2: 0.9762 | RMSE: 1492 | MAE: 944 | Bias: 70.1
#   > [VAL]   R2: 0.9347 | RMSE: 2590 | MAE: 1271 | Bias: 122.6
#
# [C9|F5] Processing fold...
#   > [TRAIN] R2: 0.9761 | RMSE: 1505 | MAE: 917 | Bias: 65.8
#   > [VAL]   R2: 0.9579 | RMSE: 2012 | MAE: 1229 | Bias: 83.8
#
# [C9|F6] Processing fold...
#   > [TRAIN] R2: 0.9740 | RMSE: 1569 | MAE: 946 | Bias: 75.1
#   > [VAL]   R2: 0.9542 | RMSE: 2102 | MAE: 1225 | Bias: 108.6
#
# [C9|F7] Processing fold...
#   > [TRAIN] R2: 0.9706 | RMSE: 1670 | MAE: 1014 | Bias: 83.2
#   > [VAL]   R2: 0.9571 | RMSE: 2015 | MAE: 1218 | Bias: 126.1
#
# [C9|F8] Processing fold...
#   > [TRAIN] R2: 0.9727 | RMSE: 1614 | MAE: 996 | Bias: 80.1
#   > [VAL]   R2: 0.9568 | RMSE: 1974 | MAE: 1206 | Bias: 67.4
#
# Config 9 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 973.9 | R2: 0.9726 | Bias: 77.4
#   [VAL AVG]   MAE: 1238.1 | R2: 0.9518 | Bias: 99.2 | RMSE: 2132.2
#
# ######## CONFIG 10/25 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 1.0}
#
# [C10|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9675 | RMSE: 1761 | MAE: 1002 | Bias: 87.1
#   > [VAL]   R2: 0.9587 | RMSE: 1932 | MAE: 1232 | Bias: 58.2
#
# [C10|F2] Processing fold...
#   > [TRAIN] R2: 0.9716 | RMSE: 1643 | MAE: 999 | Bias: 79.6
#   > [VAL]   R2: 0.9499 | RMSE: 2168 | MAE: 1267 | Bias: 89.9
#
# [C10|F3] Processing fold...
#   > [TRAIN] R2: 0.9730 | RMSE: 1602 | MAE: 936 | Bias: 76.9
#   > [VAL]   R2: 0.9493 | RMSE: 2182 | MAE: 1249 | Bias: 132.1
#
# [C10|F4] Processing fold...
#   > [TRAIN] R2: 0.9724 | RMSE: 1608 | MAE: 1005 | Bias: 77.9
#   > [VAL]   R2: 0.9342 | RMSE: 2599 | MAE: 1282 | Bias: 131.5
#
# [C10|F5] Processing fold...
#   > [TRAIN] R2: 0.9738 | RMSE: 1574 | MAE: 956 | Bias: 70.8
#   > [VAL]   R2: 0.9574 | RMSE: 2025 | MAE: 1235 | Bias: 85.7
#
# [C10|F6] Processing fold...
#   > [TRAIN] R2: 0.9728 | RMSE: 1604 | MAE: 967 | Bias: 77.6
#   > [VAL]   R2: 0.9523 | RMSE: 2144 | MAE: 1224 | Bias: 102.2
#
# [C10|F7] Processing fold...
#   > [TRAIN] R2: 0.9695 | RMSE: 1702 | MAE: 1028 | Bias: 86.2
#   > [VAL]   R2: 0.9578 | RMSE: 1998 | MAE: 1216 | Bias: 117.7
#
# [C10|F8] Processing fold...
#   > [TRAIN] R2: 0.9731 | RMSE: 1603 | MAE: 980 | Bias: 79.9
#   > [VAL]   R2: 0.9564 | RMSE: 1983 | MAE: 1205 | Bias: 64.0
#
# Config 10 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 984.2 | R2: 0.9717 | Bias: 79.5
#   [VAL AVG]   MAE: 1238.8 | R2: 0.9520 | Bias: 97.7 | RMSE: 2128.8
#
# ######## CONFIG 11/25 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}
#
# [C11|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9639 | RMSE: 1855 | MAE: 1068 | Bias: 93.5
#   > [VAL]   R2: 0.9578 | RMSE: 1955 | MAE: 1245 | Bias: 56.1
#
# [C11|F2] Processing fold...
#   > [TRAIN] R2: 0.9664 | RMSE: 1785 | MAE: 1082 | Bias: 88.7
#   > [VAL]   R2: 0.9495 | RMSE: 2176 | MAE: 1281 | Bias: 87.8
#
# [C11|F3] Processing fold...
#   > [TRAIN] R2: 0.9676 | RMSE: 1754 | MAE: 1042 | Bias: 87.2
#   > [VAL]   R2: 0.9476 | RMSE: 2219 | MAE: 1265 | Bias: 143.4
#
# [C11|F4] Processing fold...
#   > [TRAIN] R2: 0.9682 | RMSE: 1727 | MAE: 1079 | Bias: 84.7
#   > [VAL]   R2: 0.9336 | RMSE: 2612 | MAE: 1293 | Bias: 127.9
#
# [C11|F5] Processing fold...
#   > [TRAIN] R2: 0.9705 | RMSE: 1672 | MAE: 1019 | Bias: 75.6
#   > [VAL]   R2: 0.9579 | RMSE: 2013 | MAE: 1237 | Bias: 86.4
#
# [C11|F6] Processing fold...
#   > [TRAIN] R2: 0.9684 | RMSE: 1728 | MAE: 1047 | Bias: 85.7
#   > [VAL]   R2: 0.9523 | RMSE: 2143 | MAE: 1240 | Bias: 112.6
#
# [C11|F7] Processing fold...
#   > [TRAIN] R2: 0.9684 | RMSE: 1731 | MAE: 1050 | Bias: 88.6
#   > [VAL]   R2: 0.9580 | RMSE: 1993 | MAE: 1218 | Bias: 127.6
#
# [C11|F8] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1696 | MAE: 1042 | Bias: 85.8
#   > [VAL]   R2: 0.9568 | RMSE: 1975 | MAE: 1212 | Bias: 69.9
#
# Config 11 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1053.7 | R2: 0.9679 | Bias: 86.2
#   [VAL AVG]   MAE: 1248.9 | R2: 0.9517 | Bias: 101.5 | RMSE: 2135.8
#
# ######## CONFIG 12/25 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 3.0}
#
# [C12|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9674 | RMSE: 1764 | MAE: 1012 | Bias: 85.3
#   > [VAL]   R2: 0.9583 | RMSE: 1943 | MAE: 1237 | Bias: 54.2
#
# [C12|F2] Processing fold...
#   > [TRAIN] R2: 0.9652 | RMSE: 1818 | MAE: 1105 | Bias: 90.1
#   > [VAL]   R2: 0.9476 | RMSE: 2218 | MAE: 1293 | Bias: 91.7
#
# [C12|F3] Processing fold...
#   > [TRAIN] R2: 0.9691 | RMSE: 1712 | MAE: 1014 | Bias: 82.3
#   > [VAL]   R2: 0.9474 | RMSE: 2222 | MAE: 1264 | Bias: 137.3
#
# [C12|F4] Processing fold...
#   > [TRAIN] R2: 0.9690 | RMSE: 1704 | MAE: 1071 | Bias: 82.7
#   > [VAL]   R2: 0.9338 | RMSE: 2608 | MAE: 1289 | Bias: 127.1
#
# [C12|F5] Processing fold...
#   > [TRAIN] R2: 0.9710 | RMSE: 1658 | MAE: 1011 | Bias: 74.5
#   > [VAL]   R2: 0.9571 | RMSE: 2032 | MAE: 1245 | Bias: 83.3
#
# [C12|F6] Processing fold...
#   > [TRAIN] R2: 0.9721 | RMSE: 1625 | MAE: 985 | Bias: 77.6
#   > [VAL]   R2: 0.9544 | RMSE: 2097 | MAE: 1231 | Bias: 105.4
#
# [C12|F7] Processing fold...
#   > [TRAIN] R2: 0.9708 | RMSE: 1665 | MAE: 1014 | Bias: 83.0
#   > [VAL]   R2: 0.9574 | RMSE: 2007 | MAE: 1221 | Bias: 122.4
#
# [C12|F8] Processing fold...
#   > [TRAIN] R2: 0.9700 | RMSE: 1692 | MAE: 1039 | Bias: 85.1
#   > [VAL]   R2: 0.9563 | RMSE: 1986 | MAE: 1218 | Bias: 66.0
#
# Config 12 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1031.3 | R2: 0.9693 | Bias: 82.6
#   [VAL AVG]   MAE: 1249.9 | R2: 0.9515 | Bias: 98.4 | RMSE: 2139.0
#
# ######## CONFIG 13/25 ########
# Parameters: {'min_samples_leaf': 20, 'max_leaf_nodes': 63, 'max_iter': 600, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 0.3}
#
# [C13|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9623 | RMSE: 1896 | MAE: 1109 | Bias: 97.8
#   > [VAL]   R2: 0.9577 | RMSE: 1956 | MAE: 1254 | Bias: 62.3
#
# [C13|F2] Processing fold...
#   > [TRAIN] R2: 0.9596 | RMSE: 1959 | MAE: 1197 | Bias: 106.1
#   > [VAL]   R2: 0.9487 | RMSE: 2195 | MAE: 1326 | Bias: 99.3
#
# [C13|F3] Processing fold...
#   > [TRAIN] R2: 0.9646 | RMSE: 1832 | MAE: 1099 | Bias: 93.9
#   > [VAL]   R2: 0.9465 | RMSE: 2242 | MAE: 1278 | Bias: 150.9
#
# [C13|F4] Processing fold...
#   > [TRAIN] R2: 0.9671 | RMSE: 1756 | MAE: 1110 | Bias: 90.2
#   > [VAL]   R2: 0.9338 | RMSE: 2608 | MAE: 1301 | Bias: 132.0
#
# [C13|F5] Processing fold...
#   > [TRAIN] R2: 0.9662 | RMSE: 1789 | MAE: 1100 | Bias: 86.1
#   > [VAL]   R2: 0.9561 | RMSE: 2055 | MAE: 1257 | Bias: 89.1
#
# [C13|F6] Processing fold...
#   > [TRAIN] R2: 0.9658 | RMSE: 1798 | MAE: 1098 | Bias: 92.5
#   > [VAL]   R2: 0.9496 | RMSE: 2204 | MAE: 1262 | Bias: 118.8
#
# [C13|F7] Processing fold...
#   > [TRAIN] R2: 0.9660 | RMSE: 1795 | MAE: 1097 | Bias: 95.6
#   > [VAL]   R2: 0.9574 | RMSE: 2008 | MAE: 1231 | Bias: 131.7
#
# [C13|F8] Processing fold...
#   > [TRAIN] R2: 0.9670 | RMSE: 1776 | MAE: 1098 | Bias: 94.0
#   > [VAL]   R2: 0.9562 | RMSE: 1989 | MAE: 1233 | Bias: 74.5
#
# Config 13 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1113.5 | R2: 0.9648 | Bias: 94.5
#   [VAL AVG]   MAE: 1267.6 | R2: 0.9507 | Bias: 107.3 | RMSE: 2157.0
#
# ######## CONFIG 14/25 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.1, 'l2_regularization': 1.0}
#
# [C14|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9664 | RMSE: 1791 | MAE: 1038 | Bias: 90.5
#   > [VAL]   R2: 0.9582 | RMSE: 1944 | MAE: 1241 | Bias: 59.6
#
# [C14|F2] Processing fold...
#   > [TRAIN] R2: 0.9725 | RMSE: 1616 | MAE: 993 | Bias: 79.5
#   > [VAL]   R2: 0.9510 | RMSE: 2144 | MAE: 1260 | Bias: 90.0
#
# [C14|F3] Processing fold...
#   > [TRAIN] R2: 0.9742 | RMSE: 1566 | MAE: 926 | Bias: 75.8
#   > [VAL]   R2: 0.9504 | RMSE: 2158 | MAE: 1248 | Bias: 127.8
#
# [C14|F4] Processing fold...
#   > [TRAIN] R2: 0.9740 | RMSE: 1560 | MAE: 988 | Bias: 76.2
#   > [VAL]   R2: 0.9338 | RMSE: 2607 | MAE: 1275 | Bias: 125.1
#
# [C14|F5] Processing fold...
#   > [TRAIN] R2: 0.9726 | RMSE: 1610 | MAE: 989 | Bias: 74.5
#   > [VAL]   R2: 0.9577 | RMSE: 2017 | MAE: 1228 | Bias: 92.5
#
# [C14|F6] Processing fold...
#   > [TRAIN] R2: 0.9728 | RMSE: 1603 | MAE: 969 | Bias: 80.5
#   > [VAL]   R2: 0.9531 | RMSE: 2125 | MAE: 1230 | Bias: 118.2
#
# [C14|F7] Processing fold...
#   > [TRAIN] R2: 0.9723 | RMSE: 1619 | MAE: 989 | Bias: 81.4
#   > [VAL]   R2: 0.9581 | RMSE: 1990 | MAE: 1212 | Bias: 118.2
#
# [C14|F8] Processing fold...
#   > [TRAIN] R2: 0.9703 | RMSE: 1683 | MAE: 1033 | Bias: 86.4
#   > [VAL]   R2: 0.9562 | RMSE: 1988 | MAE: 1217 | Bias: 72.9
#
# Config 14 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 990.6 | R2: 0.9719 | Bias: 80.6
#   [VAL AVG]   MAE: 1238.7 | R2: 0.9523 | Bias: 100.5 | RMSE: 2121.8
#
# ######## CONFIG 15/25 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 63, 'max_iter': 600, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 0.3}
#
# [C15|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9639 | RMSE: 1856 | MAE: 1087 | Bias: 93.4
#   > [VAL]   R2: 0.9581 | RMSE: 1947 | MAE: 1251 | Bias: 57.8
#
# [C15|F2] Processing fold...
#   > [TRAIN] R2: 0.9632 | RMSE: 1869 | MAE: 1152 | Bias: 98.9
#   > [VAL]   R2: 0.9494 | RMSE: 2179 | MAE: 1299 | Bias: 94.7
#
# [C15|F3] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1692 | MAE: 1011 | Bias: 82.7
#   > [VAL]   R2: 0.9495 | RMSE: 2177 | MAE: 1258 | Bias: 131.9
#
# [C15|F4] Processing fold...
#   > [TRAIN] R2: 0.9659 | RMSE: 1787 | MAE: 1126 | Bias: 90.6
#   > [VAL]   R2: 0.9328 | RMSE: 2628 | MAE: 1312 | Bias: 135.0
#
# [C15|F5] Processing fold...
#   > [TRAIN] R2: 0.9694 | RMSE: 1700 | MAE: 1051 | Bias: 79.8
#   > [VAL]   R2: 0.9570 | RMSE: 2033 | MAE: 1247 | Bias: 90.2
#
# [C15|F6] Processing fold...
#   > [TRAIN] R2: 0.9678 | RMSE: 1745 | MAE: 1072 | Bias: 89.3
#   > [VAL]   R2: 0.9524 | RMSE: 2142 | MAE: 1252 | Bias: 118.4
#
# [C15|F7] Processing fold...
#   > [TRAIN] R2: 0.9700 | RMSE: 1686 | MAE: 1034 | Bias: 86.0
#   > [VAL]   R2: 0.9576 | RMSE: 2003 | MAE: 1225 | Bias: 121.1
#
# [C15|F8] Processing fold...
#   > [TRAIN] R2: 0.9697 | RMSE: 1702 | MAE: 1054 | Bias: 88.6
#   > [VAL]   R2: 0.9560 | RMSE: 1992 | MAE: 1226 | Bias: 67.5
#
# Config 15 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1073.5 | R2: 0.9675 | Bias: 88.7
#   [VAL AVG]   MAE: 1258.8 | R2: 0.9516 | Bias: 102.1 | RMSE: 2137.6
#
# ######## CONFIG 16/25 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 3.0}
#
# [C16|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9665 | RMSE: 1788 | MAE: 1020 | Bias: 87.4
#   > [VAL]   R2: 0.9587 | RMSE: 1932 | MAE: 1231 | Bias: 53.0
#
# [C16|F2] Processing fold...
#   > [TRAIN] R2: 0.9695 | RMSE: 1702 | MAE: 1037 | Bias: 82.6
#   > [VAL]   R2: 0.9498 | RMSE: 2171 | MAE: 1269 | Bias: 88.0
#
# [C16|F3] Processing fold...
#   > [TRAIN] R2: 0.9619 | RMSE: 1901 | MAE: 1126 | Bias: 96.1
#   > [VAL]   R2: 0.9433 | RMSE: 2308 | MAE: 1290 | Bias: 153.7
#
# [C16|F4] Processing fold...
#   > [TRAIN] R2: 0.9683 | RMSE: 1724 | MAE: 1079 | Bias: 85.0
#   > [VAL]   R2: 0.9330 | RMSE: 2623 | MAE: 1298 | Bias: 128.7
#
# [C16|F5] Processing fold...
#   > [TRAIN] R2: 0.9723 | RMSE: 1619 | MAE: 986 | Bias: 72.5
#   > [VAL]   R2: 0.9565 | RMSE: 2045 | MAE: 1239 | Bias: 88.0
#
# [C16|F6] Processing fold...
#   > [TRAIN] R2: 0.9719 | RMSE: 1629 | MAE: 987 | Bias: 78.5
#   > [VAL]   R2: 0.9550 | RMSE: 2082 | MAE: 1225 | Bias: 103.3
#
# [C16|F7] Processing fold...
#   > [TRAIN] R2: 0.9685 | RMSE: 1729 | MAE: 1050 | Bias: 87.7
#   > [VAL]   R2: 0.9569 | RMSE: 2020 | MAE: 1225 | Bias: 123.0
#
# [C16|F8] Processing fold...
#   > [TRAIN] R2: 0.9721 | RMSE: 1631 | MAE: 1005 | Bias: 81.9
#   > [VAL]   R2: 0.9570 | RMSE: 1970 | MAE: 1209 | Bias: 65.5
#
# Config 16 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1036.2 | R2: 0.9689 | Bias: 84.0
#   [VAL AVG]   MAE: 1248.2 | R2: 0.9513 | Bias: 100.4 | RMSE: 2143.9
#
# ######## CONFIG 17/25 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 191, 'max_iter': 1000, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 1.0}
#
# [C17|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9697 | RMSE: 1702 | MAE: 962 | Bias: 81.2
#   > [VAL]   R2: 0.9597 | RMSE: 1909 | MAE: 1219 | Bias: 48.9
#
# [C17|F2] Processing fold...
#   > [TRAIN] R2: 0.9621 | RMSE: 1896 | MAE: 1133 | Bias: 96.2
#   > [VAL]   R2: 0.9473 | RMSE: 2224 | MAE: 1302 | Bias: 95.8
#
# [C17|F3] Processing fold...
#   > [TRAIN] R2: 0.9692 | RMSE: 1710 | MAE: 1003 | Bias: 82.8
#   > [VAL]   R2: 0.9460 | RMSE: 2252 | MAE: 1263 | Bias: 131.1
#
# [C17|F4] Processing fold...
#   > [TRAIN] R2: 0.9739 | RMSE: 1563 | MAE: 976 | Bias: 74.3
#   > [VAL]   R2: 0.9357 | RMSE: 2570 | MAE: 1274 | Bias: 127.2
#
# [C17|F5] Processing fold...
#   > [TRAIN] R2: 0.9700 | RMSE: 1686 | MAE: 1018 | Bias: 76.7
#   > [VAL]   R2: 0.9566 | RMSE: 2043 | MAE: 1251 | Bias: 88.2
#
# [C17|F6] Processing fold...
#   > [TRAIN] R2: 0.9724 | RMSE: 1615 | MAE: 971 | Bias: 78.1
#   > [VAL]   R2: 0.9542 | RMSE: 2102 | MAE: 1219 | Bias: 107.9
#
# [C17|F7] Processing fold...
#   > [TRAIN] R2: 0.9681 | RMSE: 1739 | MAE: 1041 | Bias: 87.5
#   > [VAL]   R2: 0.9565 | RMSE: 2028 | MAE: 1228 | Bias: 125.8
#
# [C17|F8] Processing fold...
#   > [TRAIN] R2: 0.9710 | RMSE: 1665 | MAE: 1010 | Bias: 82.8
#   > [VAL]   R2: 0.9561 | RMSE: 1990 | MAE: 1213 | Bias: 72.6
#
# Config 17 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1014.2 | R2: 0.9695 | Bias: 82.4
#   [VAL AVG]   MAE: 1246.1 | R2: 0.9515 | Bias: 99.7 | RMSE: 2139.8
#
# ######## CONFIG 18/25 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 127, 'max_iter': 1000, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 3.0}
#
# [C18|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9643 | RMSE: 1846 | MAE: 1071 | Bias: 92.5
#   > [VAL]   R2: 0.9576 | RMSE: 1958 | MAE: 1248 | Bias: 67.3
#
# [C18|F2] Processing fold...
#   > [TRAIN] R2: 0.9723 | RMSE: 1622 | MAE: 997 | Bias: 77.9
#   > [VAL]   R2: 0.9521 | RMSE: 2120 | MAE: 1256 | Bias: 84.6
#
# [C18|F3] Processing fold...
#   > [TRAIN] R2: 0.9700 | RMSE: 1688 | MAE: 999 | Bias: 82.3
#   > [VAL]   R2: 0.9477 | RMSE: 2216 | MAE: 1261 | Bias: 140.0
#
# [C18|F4] Processing fold...
#   > [TRAIN] R2: 0.9735 | RMSE: 1575 | MAE: 1000 | Bias: 76.2
#   > [VAL]   R2: 0.9362 | RMSE: 2561 | MAE: 1276 | Bias: 122.8
#
# [C18|F5] Processing fold...
#   > [TRAIN] R2: 0.9735 | RMSE: 1584 | MAE: 972 | Bias: 71.1
#   > [VAL]   R2: 0.9568 | RMSE: 2038 | MAE: 1240 | Bias: 85.6
#
# [C18|F6] Processing fold...
#   > [TRAIN] R2: 0.9726 | RMSE: 1610 | MAE: 979 | Bias: 78.3
#   > [VAL]   R2: 0.9547 | RMSE: 2089 | MAE: 1227 | Bias: 110.6
#
# [C18|F7] Processing fold...
#   > [TRAIN] R2: 0.9708 | RMSE: 1665 | MAE: 1021 | Bias: 84.8
#   > [VAL]   R2: 0.9572 | RMSE: 2012 | MAE: 1221 | Bias: 122.0
#
# [C18|F8] Processing fold...
#   > [TRAIN] R2: 0.9696 | RMSE: 1703 | MAE: 1054 | Bias: 87.3
#   > [VAL]   R2: 0.9554 | RMSE: 2006 | MAE: 1230 | Bias: 76.5
#
# Config 18 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1011.6 | R2: 0.9708 | Bias: 81.3
#   [VAL AVG]   MAE: 1244.9 | R2: 0.9522 | Bias: 101.2 | RMSE: 2125.0
#
# ######## CONFIG 19/25 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 63, 'max_iter': 600, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 3.0}
#
# [C19|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9651 | RMSE: 1824 | MAE: 1068 | Bias: 92.4
#   > [VAL]   R2: 0.9594 | RMSE: 1916 | MAE: 1234 | Bias: 54.3
#
# [C19|F2] Processing fold...
#   > [TRAIN] R2: 0.9681 | RMSE: 1741 | MAE: 1070 | Bias: 87.7
#   > [VAL]   R2: 0.9523 | RMSE: 2115 | MAE: 1266 | Bias: 97.4
#
# [C19|F3] Processing fold...
#   > [TRAIN] R2: 0.9634 | RMSE: 1864 | MAE: 1117 | Bias: 96.5
#   > [VAL]   R2: 0.9458 | RMSE: 2256 | MAE: 1288 | Bias: 150.6
#
# [C19|F4] Processing fold...
#   > [TRAIN] R2: 0.9648 | RMSE: 1817 | MAE: 1143 | Bias: 93.9
#   > [VAL]   R2: 0.9334 | RMSE: 2615 | MAE: 1317 | Bias: 133.8
#
# [C19|F5] Processing fold...
#   > [TRAIN] R2: 0.9681 | RMSE: 1737 | MAE: 1072 | Bias: 83.6
#   > [VAL]   R2: 0.9569 | RMSE: 2036 | MAE: 1244 | Bias: 93.3
#
# [C19|F6] Processing fold...
#   > [TRAIN] R2: 0.9671 | RMSE: 1763 | MAE: 1077 | Bias: 90.3
#   > [VAL]   R2: 0.9511 | RMSE: 2171 | MAE: 1253 | Bias: 122.3
#
# [C19|F7] Processing fold...
#   > [TRAIN] R2: 0.9680 | RMSE: 1743 | MAE: 1071 | Bias: 92.0
#   > [VAL]   R2: 0.9572 | RMSE: 2013 | MAE: 1226 | Bias: 124.4
#
# [C19|F8] Processing fold...
#   > [TRAIN] R2: 0.9682 | RMSE: 1743 | MAE: 1080 | Bias: 91.5
#   > [VAL]   R2: 0.9559 | RMSE: 1995 | MAE: 1230 | Bias: 77.4
#
# Config 19 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1087.2 | R2: 0.9666 | Bias: 91.0
#   [VAL AVG]   MAE: 1257.3 | R2: 0.9515 | Bias: 106.7 | RMSE: 2139.7
#
# ######## CONFIG 20/25 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 255, 'max_iter': 1200, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C20|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9657 | RMSE: 1809 | MAE: 1027 | Bias: 89.0
#   > [VAL]   R2: 0.9587 | RMSE: 1934 | MAE: 1232 | Bias: 61.0
#
# [C20|F2] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1690 | MAE: 1023 | Bias: 81.2
#   > [VAL]   R2: 0.9494 | RMSE: 2179 | MAE: 1264 | Bias: 88.6
#
# [C20|F3] Processing fold...
#   > [TRAIN] R2: 0.9718 | RMSE: 1636 | MAE: 956 | Bias: 78.0
#   > [VAL]   R2: 0.9497 | RMSE: 2173 | MAE: 1254 | Bias: 130.2
#
# [C20|F4] Processing fold...
#   > [TRAIN] R2: 0.9730 | RMSE: 1591 | MAE: 991 | Bias: 73.9
#   > [VAL]   R2: 0.9346 | RMSE: 2592 | MAE: 1274 | Bias: 129.5
#
# [C20|F5] Processing fold...
#   > [TRAIN] R2: 0.9729 | RMSE: 1601 | MAE: 967 | Bias: 70.9
#   > [VAL]   R2: 0.9574 | RMSE: 2024 | MAE: 1237 | Bias: 80.4
#
# [C20|F6] Processing fold...
#   > [TRAIN] R2: 0.9699 | RMSE: 1688 | MAE: 1009 | Bias: 81.8
#   > [VAL]   R2: 0.9509 | RMSE: 2176 | MAE: 1236 | Bias: 106.1
#
# [C20|F7] Processing fold...
#   > [TRAIN] R2: 0.9714 | RMSE: 1647 | MAE: 990 | Bias: 79.9
#   > [VAL]   R2: 0.9570 | RMSE: 2016 | MAE: 1217 | Bias: 118.9
#
# [C20|F8] Processing fold...
#   > [TRAIN] R2: 0.9717 | RMSE: 1644 | MAE: 1001 | Bias: 80.2
#   > [VAL]   R2: 0.9558 | RMSE: 1997 | MAE: 1209 | Bias: 72.6
#
# Config 20 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 995.7 | R2: 0.9708 | Bias: 79.4
#   [VAL AVG]   MAE: 1240.4 | R2: 0.9517 | Bias: 98.4 | RMSE: 2136.4
#
# ######## CONFIG 21/25 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 191, 'max_iter': 1200, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.115, 'l2_regularization': 0.3}
#
# [C21|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9673 | RMSE: 1767 | MAE: 1004 | Bias: 84.8
#   > [VAL]   R2: 0.9591 | RMSE: 1923 | MAE: 1229 | Bias: 54.6
#
# [C21|F2] Processing fold...
#   > [TRAIN] R2: 0.9681 | RMSE: 1740 | MAE: 1051 | Bias: 83.9
#   > [VAL]   R2: 0.9497 | RMSE: 2172 | MAE: 1274 | Bias: 87.0
#
# [C21|F3] Processing fold...
#   > [TRAIN] R2: 0.9689 | RMSE: 1718 | MAE: 1013 | Bias: 81.9
#   > [VAL]   R2: 0.9470 | RMSE: 2231 | MAE: 1269 | Bias: 129.7
#
# [C21|F4] Processing fold...
#   > [TRAIN] R2: 0.9729 | RMSE: 1594 | MAE: 1001 | Bias: 75.0
#   > [VAL]   R2: 0.9341 | RMSE: 2601 | MAE: 1278 | Bias: 124.2
#
# [C21|F5] Processing fold...
#   > [TRAIN] R2: 0.9734 | RMSE: 1587 | MAE: 966 | Bias: 68.6
#   > [VAL]   R2: 0.9579 | RMSE: 2012 | MAE: 1234 | Bias: 84.6
#
# [C21|F6] Processing fold...
#   > [TRAIN] R2: 0.9718 | RMSE: 1633 | MAE: 983 | Bias: 77.8
#   > [VAL]   R2: 0.9544 | RMSE: 2097 | MAE: 1220 | Bias: 104.5
#
# [C21|F7] Processing fold...
#   > [TRAIN] R2: 0.9650 | RMSE: 1823 | MAE: 1085 | Bias: 91.3
#   > [VAL]   R2: 0.9555 | RMSE: 2053 | MAE: 1242 | Bias: 126.7
#
# [C21|F8] Processing fold...
#   > [TRAIN] R2: 0.9740 | RMSE: 1574 | MAE: 963 | Bias: 77.0
#   > [VAL]   R2: 0.9561 | RMSE: 1991 | MAE: 1206 | Bias: 63.5
#
# Config 21 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1008.2 | R2: 0.9702 | Bias: 80.0
#   [VAL AVG]   MAE: 1244.0 | R2: 0.9517 | Bias: 96.8 | RMSE: 2135.1
#
# ######## CONFIG 22/25 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 3.0}
#
# [C22|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9657 | RMSE: 1808 | MAE: 1045 | Bias: 91.4
#   > [VAL]   R2: 0.9583 | RMSE: 1942 | MAE: 1238 | Bias: 56.9
#
# [C22|F2] Processing fold...
#   > [TRAIN] R2: 0.9734 | RMSE: 1589 | MAE: 980 | Bias: 77.5
#   > [VAL]   R2: 0.9520 | RMSE: 2122 | MAE: 1252 | Bias: 88.1
#
# [C22|F3] Processing fold...
#   > [TRAIN] R2: 0.9710 | RMSE: 1658 | MAE: 987 | Bias: 82.0
#   > [VAL]   R2: 0.9495 | RMSE: 2177 | MAE: 1253 | Bias: 138.5
#
# [C22|F4] Processing fold...
#   > [TRAIN] R2: 0.9720 | RMSE: 1620 | MAE: 1028 | Bias: 80.2
#   > [VAL]   R2: 0.9349 | RMSE: 2585 | MAE: 1279 | Bias: 129.1
#
# [C22|F5] Processing fold...
#   > [TRAIN] R2: 0.9743 | RMSE: 1561 | MAE: 961 | Bias: 71.0
#   > [VAL]   R2: 0.9567 | RMSE: 2041 | MAE: 1235 | Bias: 88.5
#
# [C22|F6] Processing fold...
#   > [TRAIN] R2: 0.9718 | RMSE: 1634 | MAE: 994 | Bias: 82.1
#   > [VAL]   R2: 0.9547 | RMSE: 2090 | MAE: 1225 | Bias: 115.5
#
# [C22|F7] Processing fold...
#   > [TRAIN] R2: 0.9719 | RMSE: 1632 | MAE: 1002 | Bias: 83.7
#   > [VAL]   R2: 0.9586 | RMSE: 1979 | MAE: 1209 | Bias: 128.9
#
# [C22|F8] Processing fold...
#   > [TRAIN] R2: 0.9735 | RMSE: 1591 | MAE: 986 | Bias: 81.4
#   > [VAL]   R2: 0.9571 | RMSE: 1967 | MAE: 1208 | Bias: 67.6
#
# Config 22 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 997.6 | R2: 0.9717 | Bias: 81.2
#   [VAL AVG]   MAE: 1237.5 | R2: 0.9527 | Bias: 101.6 | RMSE: 2113.0
#
# ######## CONFIG 23/25 ########
# Parameters: {'min_samples_leaf': 12, 'max_leaf_nodes': 63, 'max_iter': 1000, 'max_depth': 25, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 1.0}
#
# [C23|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9600 | RMSE: 1953 | MAE: 1153 | Bias: 104.5
#   > [VAL]   R2: 0.9568 | RMSE: 1976 | MAE: 1273 | Bias: 70.7
#
# [C23|F2] Processing fold...
#   > [TRAIN] R2: 0.9647 | RMSE: 1832 | MAE: 1128 | Bias: 96.5
#   > [VAL]   R2: 0.9504 | RMSE: 2156 | MAE: 1287 | Bias: 96.5
#
# [C23|F3] Processing fold...
#   > [TRAIN] R2: 0.9667 | RMSE: 1779 | MAE: 1069 | Bias: 91.2
#   > [VAL]   R2: 0.9494 | RMSE: 2181 | MAE: 1271 | Bias: 142.1
#
# [C23|F4] Processing fold...
#   > [TRAIN] R2: 0.9659 | RMSE: 1788 | MAE: 1135 | Bias: 95.0
#   > [VAL]   R2: 0.9332 | RMSE: 2619 | MAE: 1311 | Bias: 132.7
#
# [C23|F5] Processing fold...
#   > [TRAIN] R2: 0.9703 | RMSE: 1676 | MAE: 1042 | Bias: 80.8
#   > [VAL]   R2: 0.9568 | RMSE: 2037 | MAE: 1241 | Bias: 89.0
#
# [C23|F6] Processing fold...
#   > [TRAIN] R2: 0.9691 | RMSE: 1710 | MAE: 1050 | Bias: 88.4
#   > [VAL]   R2: 0.9532 | RMSE: 2124 | MAE: 1243 | Bias: 113.8
#
# [C23|F7] Processing fold...
#   > [TRAIN] R2: 0.9701 | RMSE: 1685 | MAE: 1039 | Bias: 87.9
#   > [VAL]   R2: 0.9581 | RMSE: 1992 | MAE: 1220 | Bias: 121.0
#
# [C23|F8] Processing fold...
#   > [TRAIN] R2: 0.9683 | RMSE: 1741 | MAE: 1087 | Bias: 93.3
#   > [VAL]   R2: 0.9556 | RMSE: 2002 | MAE: 1238 | Bias: 74.1
#
# Config 23 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1087.9 | R2: 0.9669 | Bias: 92.2
#   [VAL AVG]   MAE: 1260.4 | R2: 0.9517 | Bias: 105.0 | RMSE: 2136.0
#
# ######## CONFIG 24/25 ########
# Parameters: {'min_samples_leaf': 28, 'max_leaf_nodes': 191, 'max_iter': 600, 'max_depth': None, 'loss': 'squared_error', 'learning_rate': 0.085, 'l2_regularization': 0.3}
#
# [C24|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9664 | RMSE: 1790 | MAE: 1018 | Bias: 88.7
#   > [VAL]   R2: 0.9584 | RMSE: 1940 | MAE: 1234 | Bias: 57.4
#
# [C24|F2] Processing fold...
#   > [TRAIN] R2: 0.9710 | RMSE: 1660 | MAE: 1004 | Bias: 79.2
#   > [VAL]   R2: 0.9498 | RMSE: 2169 | MAE: 1265 | Bias: 88.1
#
# [C24|F3] Processing fold...
#   > [TRAIN] R2: 0.9651 | RMSE: 1821 | MAE: 1071 | Bias: 90.6
#   > [VAL]   R2: 0.9441 | RMSE: 2292 | MAE: 1280 | Bias: 142.1
#
# [C24|F4] Processing fold...
#   > [TRAIN] R2: 0.9729 | RMSE: 1594 | MAE: 996 | Bias: 76.0
#   > [VAL]   R2: 0.9337 | RMSE: 2610 | MAE: 1279 | Bias: 133.6
#
# [C24|F5] Processing fold...
#   > [TRAIN] R2: 0.9748 | RMSE: 1543 | MAE: 933 | Bias: 67.7
#   > [VAL]   R2: 0.9573 | RMSE: 2027 | MAE: 1236 | Bias: 85.6
#
# [C24|F6] Processing fold...
#   > [TRAIN] R2: 0.9727 | RMSE: 1607 | MAE: 964 | Bias: 77.6
#   > [VAL]   R2: 0.9539 | RMSE: 2109 | MAE: 1225 | Bias: 103.0
#
# [C24|F7] Processing fold...
#   > [TRAIN] R2: 0.9724 | RMSE: 1617 | MAE: 973 | Bias: 79.6
#   > [VAL]   R2: 0.9568 | RMSE: 2021 | MAE: 1214 | Bias: 120.8
#
# [C24|F8] Processing fold...
#   > [TRAIN] R2: 0.9735 | RMSE: 1590 | MAE: 967 | Bias: 78.3
#   > [VAL]   R2: 0.9574 | RMSE: 1961 | MAE: 1199 | Bias: 65.4
#
# Config 24 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 990.7 | R2: 0.9711 | Bias: 79.7
#   [VAL AVG]   MAE: 1241.5 | R2: 0.9514 | Bias: 99.5 | RMSE: 2141.1
#
# ######## CONFIG 25/25 ########
# Parameters: {'min_samples_leaf': 16, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 0.3}
#
# [C25|F1] Processing fold...
#   > Features before FS (15): ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
#   > Selected features (14/15) with FS_KEEP_RATIO=0.90
#   > [TRAIN] R2: 0.9688 | RMSE: 1725 | MAE: 982 | Bias: 84.0
#   > [VAL]   R2: 0.9596 | RMSE: 1913 | MAE: 1219 | Bias: 52.4
#
# [C25|F2] Processing fold...
#   > [TRAIN] R2: 0.9707 | RMSE: 1669 | MAE: 1025 | Bias: 82.1
#   > [VAL]   R2: 0.9517 | RMSE: 2128 | MAE: 1262 | Bias: 93.0
#
# [C25|F3] Processing fold...
#   > [TRAIN] R2: 0.9712 | RMSE: 1653 | MAE: 978 | Bias: 81.3
#   > [VAL]   R2: 0.9499 | RMSE: 2170 | MAE: 1246 | Bias: 134.2
#
# [C25|F4] Processing fold...
#   > [TRAIN] R2: 0.9721 | RMSE: 1617 | MAE: 1024 | Bias: 79.7
#   > [VAL]   R2: 0.9349 | RMSE: 2586 | MAE: 1278 | Bias: 119.3
#
# [C25|F5] Processing fold...
#   > [TRAIN] R2: 0.9700 | RMSE: 1684 | MAE: 1036 | Bias: 79.1
#   > [VAL]   R2: 0.9573 | RMSE: 2027 | MAE: 1244 | Bias: 83.7
#
# [C25|F6] Processing fold...
#   > [TRAIN] R2: 0.9748 | RMSE: 1543 | MAE: 938 | Bias: 75.0
#   > [VAL]   R2: 0.9552 | RMSE: 2078 | MAE: 1220 | Bias: 107.2
#
# [C25|F7] Processing fold...
#   > [TRAIN] R2: 0.9701 | RMSE: 1685 | MAE: 1034 | Bias: 87.2
#   > [VAL]   R2: 0.9581 | RMSE: 1991 | MAE: 1214 | Bias: 124.8
#
# [C25|F8] Processing fold...
#   > [TRAIN] R2: 0.9711 | RMSE: 1661 | MAE: 1028 | Bias: 85.0
#   > [VAL]   R2: 0.9560 | RMSE: 1992 | MAE: 1216 | Bias: 76.4
#
# Config 25 SUMMARY:
#   Selected features (avg): 14 / 10 (note: final space is after encoding)
#   [TRAIN AVG] MAE: 1005.7 | R2: 0.9711 | Bias: 81.7
#   [VAL AVG]   MAE: 1237.2 | R2: 0.9528 | Bias: 98.9 | RMSE: 2110.8
# [NEW BEST RMSE] Config 25
# # END OF SEARCH
#
# Top 5 Configurations by RMSE:
#     config_id  fs_keep_ratio  avg_selected_features  learning_rate  max_iter  \
# 24         25            0.9                   14.0          0.070       800
# 5           6            0.9                   14.0          0.070      1200
# 21         22            0.9                   14.0          0.085       800
# 13         14            0.9                   14.0          0.100       800
# 17         18            0.9                   14.0          0.115      1000
#
#     max_leaf_nodes  max_depth     val_rmse      val_mae    val_r2  train_r2  \
# 24             127       15.0  2110.752777  1237.158555  0.952829  0.971104
# 5              191       20.0  2111.994401  1233.552411  0.952776  0.972899
# 21             127       15.0  2112.996799  1237.483851  0.952735  0.971700
# 13             127       25.0  2121.766015  1238.732559  0.952332  0.971890
# 17             127       15.0  2124.988577  1244.935956  0.952221  0.970812
#
#       val_bias
# 24   98.881322
# 5   101.460000
# 21  101.627982
# 13  100.544328
# 17  101.167695
# Best Config found:
# {'min_samples_leaf': 16, 'max_leaf_nodes': 127, 'max_iter': 800, 'max_depth': 15, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 0.3}

# %% [markdown]
# ## 4. Final Model: Selected Configuration and Submission File <a id="finalconfig"></a>

# %% [markdown]
# ### 4.1. Cross-Validation Results (8-Folds CV)

# %%
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
final_params = {
    "min_samples_leaf": 16,
    "max_leaf_nodes": 191,
    "max_iter": 1200,
    "max_depth": 20,
    "loss": "squared_error",
    "learning_rate": 0.07,
    "l2_regularization": 3.0,
}


cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]
high_card_features = ["Brand", "model"]
low_card_features = [c for c in categorical_features if c not in high_card_features]
low_card_curr = low_card_features  # sem engine_bin

results = []

print(f"\n--- 8-FOLD CV | HGB (log target) | params={final_params} | FS_KEEP_RATIO={FS_KEEP_RATIO} ---\n")

for fold, (train_idx, val_idx) in enumerate(kf.split(X), start=1):
    # -----------------------------
    # Split
    # -----------------------------
    X_train = X.iloc[train_idx].copy()
    X_val   = X.iloc[val_idx].copy()
    y_train = y.iloc[train_idx].copy()
    y_val   = y.iloc[val_idx].copy()

    # log-target só no treino
    y_train_log = np.log1p(y_train.astype(float))

    # -----------------------------
    # String normalization (fold-wise)
    # -----------------------------
    for col in cols_to_normalize:
        if col in X_train.columns:
            X_train[col] = fill_unknown(X_train[col])
            X_train = column_string_transformer(X_train, column=col, remove_middle_spaces=True, allow_extra_chars="")
        if col in X_val.columns:
            X_val[col] = fill_unknown(X_val[col])
            X_val = column_string_transformer(X_val, column=col, remove_middle_spaces=True, allow_extra_chars="")

    # Restrict to expected schema
    expected_cols = [c for c in (numeric_features + categorical_features) if c in X_train.columns]
    X_train = X_train[expected_cols].copy()
    X_val   = X_val.reindex(columns=expected_cols, fill_value=np.nan).copy()

    # -----------------------------
    # Fit + transform (NO LEAKAGE): fit no train, aplica no val
    # -----------------------------
    year_state = fit_year_median(X_train, year_col="year", model_col="model")
    X_train = transform_year_with_model_median(X_train, state=year_state)
    X_val   = transform_year_with_model_median(X_val,   state=year_state)

    mileage_state = fit_mileage_imputer(X_train, mileage_col="mileage", do_abs=True)
    X_train = transform_mileage_imputer(X_train, state=mileage_state)
    X_val   = transform_mileage_imputer(X_val,   state=mileage_state)

    engine_state = fit_engine_size_imputer(X_train, engine_col="engineSize")
    X_train = transform_engine_size_imputer(X_train, state=engine_state)
    X_val   = transform_engine_size_imputer(X_val,   state=engine_state)

    X_train = transform_tax_custom_rules(X_train, "tax", "year", "fuelType", "engineSize")
    X_val   = transform_tax_custom_rules(X_val,   "tax", "year", "fuelType", "engineSize")

    mpg_state = fit_mpg_imputer(X_train, mpg_col="mpg", do_abs=True)
    X_train = transform_mpg_imputer(X_train, state=mpg_state)
    X_val   = transform_mpg_imputer(X_val,   state=mpg_state)

    brand_state = fit_ambiguous_brand_resolver(X_train, valid_brands)
    X_train, _, _ = transform_ambiguous_brands(X_train, brand_state)
    X_val,   _, _ = transform_ambiguous_brands(X_val,   brand_state)

    model_state = fit_invalid_model_resolver(X_train, valid_models_by_brand)
    X_train, _, _ = transform_invalid_models(X_train, model_state)
    X_val,   _, _ = transform_invalid_models(X_val,   model_state)

    transm_state = fit_transmission_resolver(X_train, valid_transmissions)
    X_train, _, _ = transform_transmission_resolver(X_train, transm_state)
    X_val,   _, _ = transform_transmission_resolver(X_val,   transm_state)

    fuel_state = fit_fueltype_resolver(X_train, valid_fueltypes)
    X_train, _, _ = transform_fueltype_resolver(X_train, fuel_state)
    X_val,   _, _ = transform_fueltype_resolver(X_val,   fuel_state)

    # -----------------------------
    # Feature engineering: ONLY AGE (drop year)
    # -----------------------------
    X_train = create_age_and_drop_year(X_train, year_col="year", base_year=2020)
    X_val   = create_age_and_drop_year(X_val,   year_col="year", base_year=2020)

    # -----------------------------
    # Encoding (fit no train com LOG target)
    # -----------------------------
    te = MyTargetEncoder(smoothing=5)
    te.fit(X_train[high_card_features], y_train_log)
    X_train_high = te.transform(X_train[high_card_features])
    X_val_high   = te.transform(X_val[high_card_features])

    ohe = MyOneHotEncoder()
    ohe.fit(X_train[low_card_curr])
    X_train_low = ohe.transform(X_train[low_card_curr])
    X_val_low   = ohe.transform(X_val[low_card_curr])

    X_train_cat = pd.concat([X_train_high, X_train_low], axis=1)
    X_val_cat   = pd.concat([X_val_high,   X_val_low],   axis=1)

    drop_for_numeric = set(high_card_features + low_card_curr)
    numeric_features_curr = [c for c in X_train.columns if c not in drop_for_numeric]

    X_train_final = pd.concat([X_train[numeric_features_curr], X_train_cat], axis=1)
    X_val_final   = pd.concat([X_val[numeric_features_curr],   X_val_cat],   axis=1)

    X_val_final = X_val_final.reindex(columns=X_train_final.columns, fill_value=0)

    # >>> NEW: print columns used by the model matrix (before FS)
    feature_names_pre_fs = list(X_train_final.columns)
    print(f"\n[Fold {fold}] Features BEFORE FS ({len(feature_names_pre_fs)}):")
    print(feature_names_pre_fs)

    # -----------------------------
    # Feature Selection (mantida; FS_KEEP_RATIO=1 => seleciona tudo)
    # -----------------------------
    n_feats = X_train_final.shape[1]
    k = int(np.ceil(FS_KEEP_RATIO * n_feats))
    k = max(1, min(k, n_feats))

    rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
    rf_fs.fit(X_train_final, y_train_log)

    selector = SelectFromModel(
        estimator=rf_fs,
        threshold=-np.inf,
        max_features=k,
        prefit=True
    )

    selected_cols = X_train_final.columns[selector.get_support()]
    X_train_sel = X_train_final[selected_cols]
    X_val_sel   = X_val_final[selected_cols]

    # >>> NEW: print columns actually used after FS
    feature_names_post_fs = list(selected_cols)
    print(f"[Fold {fold}] Features AFTER FS ({len(feature_names_post_fs)}):")
    print(feature_names_post_fs)

    # -----------------------------

    # -----------------------------
    hgb = HistGradientBoostingRegressor(random_state=RANDOM_STATE, **final_params)
    hgb.fit(X_train_sel, y_train_log)

    pred_tr_log  = hgb.predict(X_train_sel)
    pred_val_log = hgb.predict(X_val_sel)

    pred_tr  = np.expm1(pred_tr_log)
    pred_val = np.expm1(pred_val_log)



    tr_rmse = rmse(y_train, pred_tr)
    tr_mae  = float(mean_absolute_error(y_train, pred_tr))
    tr_r2   = float(r2_score(y_train, pred_tr))
    tr_bias = bias(y_train, pred_tr)

    val_rmse = rmse(y_val, pred_val)
    val_mae  = float(mean_absolute_error(y_val, pred_val))
    val_r2   = float(r2_score(y_val, pred_val))
    val_bias = bias(y_val, pred_val)

    print(
        f"[Fold {fold}] "
        f"TRAIN -> RMSE: {tr_rmse:.1f} | MAE: {tr_mae:.1f} | R2: {tr_r2:.4f} | Bias: {tr_bias:.1f}   ||   "
        f"VAL -> RMSE: {val_rmse:.1f} | MAE: {val_mae:.1f} | R2: {val_r2:.4f} | Bias: {val_bias:.1f}"
    )

    results.append({
        "fold": fold,
        "n_features_total": int(n_feats),
        "n_features_selected": int(len(selected_cols)),
        "train_rmse": tr_rmse, "train_mae": tr_mae, "train_r2": tr_r2, "train_bias": tr_bias,
        "val_rmse": val_rmse, "val_mae": val_mae, "val_r2": val_r2, "val_bias": val_bias,
    })

# -----------------------------
# Summary
# -----------------------------
results_df = pd.DataFrame(results)

print("\n--- CV SUMMARY (mean ± std) ---")
for split in ["train", "val"]:
    print(
        f"{split.upper()} | "
        f"RMSE: {results_df[f'{split}_rmse'].mean():.1f} ± {results_df[f'{split}_rmse'].std(ddof=1):.1f} | "
        f"MAE: {results_df[f'{split}_mae'].mean():.1f} ± {results_df[f'{split}_mae'].std(ddof=1):.1f} | "
        f"R2: {results_df[f'{split}_r2'].mean():.4f} ± {results_df[f'{split}_r2'].std(ddof=1):.4f} | "
        f"Bias: {results_df[f'{split}_bias'].mean():.1f} ± {results_df[f'{split}_bias'].std(ddof=1):.1f}"
    )

display(results_df)
# Out:
# --- 8-FOLD CV | HGB (log target) | params={'min_samples_leaf': 16, 'max_leaf_nodes': 191, 'max_iter': 1200, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0} | FS_KEEP_RATIO=1 ---
#
#
# [Fold 1] Features BEFORE FS (15):
# ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
# [Fold 1] Features AFTER FS (15):
# ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
# [Fold 1] TRAIN -> RMSE: 1690.8 | MAE: 957.3 | R2: 0.9700 | Bias: 81.3   ||   VAL -> RMSE: 1920.0 | MAE: 1221.0 | R2: 0.9593 | Bias: 53.8
#
# [Fold 2] Features BEFORE FS (15):
# ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
# [Fold 2] Features AFTER FS (15):
# ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
# [Fold 2] TRAIN -> RMSE: 1638.1 | MAE: 1003.7 | R2: 0.9717 | Bias: 80.5   ||   VAL -> RMSE: 2136.7 | MAE: 1260.7 | R2: 0.9513 | Bias: 96.7
#
# [Fold 3] Features BEFORE FS (15):
# ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
# [Fold 3] Features AFTER FS (15):
# ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
# [Fold 3] TRAIN -> RMSE: 1609.7 | MAE: 952.6 | R2: 0.9727 | Bias: 79.0   ||   VAL -> RMSE: 2182.9 | MAE: 1248.0 | R2: 0.9493 | Bias: 139.0
#
# [Fold 4] Features BEFORE FS (15):
# ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
# [Fold 4] Features AFTER FS (15):
# ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
# [Fold 4] TRAIN -> RMSE: 1543.0 | MAE: 975.7 | R2: 0.9746 | Bias: 75.3   ||   VAL -> RMSE: 2580.3 | MAE: 1273.1 | R2: 0.9352 | Bias: 127.4
#
# [Fold 5] Features BEFORE FS (15):
# ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
# [Fold 5] Features AFTER FS (15):
# ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
# [Fold 5] TRAIN -> RMSE: 1525.5 | MAE: 933.3 | R2: 0.9754 | Bias: 69.1   ||   VAL -> RMSE: 2019.4 | MAE: 1230.1 | R2: 0.9576 | Bias: 92.8
#
# [Fold 6] Features BEFORE FS (15):
# ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
# [Fold 6] Features AFTER FS (15):
# ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
# [Fold 6] TRAIN -> RMSE: 1531.9 | MAE: 929.3 | R2: 0.9752 | Bias: 74.7   ||   VAL -> RMSE: 2072.1 | MAE: 1218.7 | R2: 0.9555 | Bias: 107.3
#
# [Fold 7] Features BEFORE FS (15):
# ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
# [Fold 7] Features AFTER FS (15):
# ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
# [Fold 7] TRAIN -> RMSE: 1660.0 | MAE: 1009.2 | R2: 0.9709 | Bias: 84.5   ||   VAL -> RMSE: 2008.6 | MAE: 1211.3 | R2: 0.9574 | Bias: 121.1
#
# [Fold 8] Features BEFORE FS (15):
# ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
# [Fold 8] Features AFTER FS (15):
# ['mileage', 'engineSize', 'tax', 'mpg', 'age', 'Brand', 'model', 'transmission_AUTOMATIC', 'transmission_MANUAL', 'transmission_SEMIAUTO', 'fuelType_DIESEL', 'fuelType_ELECTRIC', 'fuelType_HYBRID', 'fuelType_OTHER', 'fuelType_PETROL']
# [Fold 8] TRAIN -> RMSE: 1617.4 | MAE: 992.7 | R2: 0.9726 | Bias: 82.3   ||   VAL -> RMSE: 1976.0 | MAE: 1205.5 | R2: 0.9567 | Bias: 73.7
#
# --- CV SUMMARY (mean ± std) ---
# TRAIN | RMSE: 1602.1 ± 62.2 | MAE: 969.2 ± 30.9 | R2: 0.9729 ± 0.0020 | Bias: 78.4 ± 5.0
# VAL | RMSE: 2112.0 ± 207.4 | MAE: 1233.6 ± 24.4 | R2: 0.9528 ± 0.0079 | Bias: 101.5 ± 28.4
#    fold  n_features_total  n_features_selected   train_rmse    train_mae  \
# 0     1                15                   15  1690.840272   957.302614
# 1     2                15                   15  1638.102206  1003.656594
# 2     3                15                   15  1609.709646   952.609596
# 3     4                15                   15  1543.035301   975.738547
# 4     5                15                   15  1525.545420   933.325651
# 5     6                15                   15  1531.944302   929.346081
# 6     7                15                   15  1660.004736  1009.211515
# 7     8                15                   15  1617.352295   992.747558
#
#    train_r2  train_bias     val_rmse      val_mae    val_r2    val_bias
# 0  0.970038   81.340715  1919.977900  1221.045460  0.959268   53.751121
# 1  0.971738   80.532673  2136.676157  1260.689474  0.951341   96.651356
# 2  0.972705   79.009149  2182.895375  1247.956760  0.949268  139.015925
# 3  0.974582   75.296113  2580.308078  1273.091000  0.935187  127.376579
# 4  0.975400   69.076626  2019.394598  1230.127736  0.957611   92.796370
# 5  0.975187   74.748381  2072.067785  1218.702126  0.955456  107.273989
# 6  0.970943   84.476513  2008.597532  1211.339706  0.957356  121.078708
# 7  0.972597   82.345923  1976.037786  1205.467024  0.956722   73.735954

# %% [markdown]
# ### 4.2. Final Model and Kaggle Submission

# %%
numeric_features = ["year", "mileage", "engineSize", "tax", "mpg"]



final_params = {
    "min_samples_leaf": 16,
    "max_leaf_nodes": 191,
    "max_iter": 1200,
    "max_depth": 20,
    "loss": "squared_error",
    "learning_rate": 0.07,
    "l2_regularization": 3.0,
}

# FS_KEEP_RATIO=1 => keeps all features (no real selection), but kept here to match your structure
FS_KEEP_RATIO = 1
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

print(f"- using params: {final_params}")
print(f"- FS_KEEP_RATIO: {FS_KEEP_RATIO}")

# ==============================================================================
# 1) LOAD TEST + IDS
# ==============================================================================
try:
    test_df_raw = pd.read_csv("test.csv")
except:
    test_df_raw = pd.read_csv("../../project_data/test.csv")

ID_CANDIDATES = ["id", "carID", "carId", "car_id"]
ID_COL = next((c for c in ID_CANDIDATES if c in test_df_raw.columns), None)

if ID_COL is not None:
    test_ids = test_df_raw[ID_COL].copy()
    test_df = test_df_raw.drop(columns=[ID_COL]).copy()
else:
    test_ids = test_df_raw.index.copy()
    test_df = test_df_raw.copy()

# ==============================================================================
# 2) START DATA (LOG TARGET)
# ==============================================================================
X_full = X.copy()
y_full = y.copy()
y_full_log = np.log1p(y_full)  # LOG TARGET (as requested)

cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]
high_card_features = ["Brand", "model"]
low_card_features = [c for c in categorical_features if c not in high_card_features]

# IMPORTANT: you are NOT using engine_bin anymore, so low_card_curr is just low_card_features
low_card_curr = low_card_features

# ==============================================================================
# 3) STRING NORMALIZATION (TRAIN + TEST)
# ==============================================================================
for col in cols_to_normalize:
    if col in X_full.columns:
        X_full[col] = fill_unknown(X_full[col])
        X_full = column_string_transformer(
            X_full, column=col, remove_middle_spaces=True, allow_extra_chars=""
        )
    if col in test_df.columns:
        test_df[col] = fill_unknown(test_df[col])
        test_df = column_string_transformer(
            test_df, column=col, remove_middle_spaces=True, allow_extra_chars=""
        )

# Restrict to expected columns (train schema)
expected_cols = [c for c in (numeric_features + categorical_features) if c in X_full.columns]
X_full = X_full[expected_cols].copy()
X_test = test_df.reindex(columns=expected_cols, fill_value=np.nan).copy()

# ==============================================================================
# 4) FIT + TRANSFORM ON FULL TRAIN
# ==============================================================================
print("- fitting transforms on full train")

year_state = fit_year_median(X_full, year_col="year", model_col="model")
X_full = transform_year_with_model_median(X_full, state=year_state)

mileage_state = fit_mileage_imputer(X_full, mileage_col="mileage", do_abs=True)
X_full = transform_mileage_imputer(X_full, state=mileage_state)

engine_state = fit_engine_size_imputer(X_full, engine_col="engineSize")
X_full = transform_engine_size_imputer(X_full, state=engine_state)

X_full = transform_tax_custom_rules(X_full, "tax", "year", "fuelType", "engineSize")

mpg_state = fit_mpg_imputer(X_full, mpg_col="mpg", do_abs=True)
X_full = transform_mpg_imputer(X_full, state=mpg_state)

brand_state = fit_ambiguous_brand_resolver(X_full, valid_brands)
X_full, _, _ = transform_ambiguous_brands(X_full, brand_state)

model_state = fit_invalid_model_resolver(X_full, valid_models_by_brand)
X_full, _, _ = transform_invalid_models(X_full, model_state)

transm_state = fit_transmission_resolver(X_full, valid_transmissions)
X_full, _, _ = transform_transmission_resolver(X_full, transm_state)

fuel_state = fit_fueltype_resolver(X_full, valid_fueltypes)
X_full, _, _ = transform_fueltype_resolver(X_full, fuel_state)

# ==============================================================================
# 5) FEATURE ENGINEERING: ONLY AGE (drop year)
# ==============================================================================
print("- creating engineered features on full train")
X_full = create_age_and_drop_year(X_full, year_col="year", base_year=2020)

# ==============================================================================
# 6) ENCODING (FIT ON FULL TRAIN) using LOG TARGET
# ==============================================================================
print("- fitting encoders on full train")

te = MyTargetEncoder(smoothing=5)
te.fit(X_full[high_card_features], y_full_log)
X_full_high = te.transform(X_full[high_card_features])

ohe = MyOneHotEncoder()
ohe.fit(X_full[low_card_curr])
X_full_low = ohe.transform(X_full[low_card_curr])

X_full_cat = pd.concat([X_full_high, X_full_low], axis=1)

drop_for_numeric = set(high_card_features + low_card_curr)
numeric_features_curr = [c for c in X_full.columns if c not in drop_for_numeric]

X_full_final = pd.concat([X_full[numeric_features_curr], X_full_cat], axis=1)
print(f"- train matrix shape: {X_full_final.shape}")

# ==============================================================================
# 7) FEATURE SELECTION (kept but FS_KEEP_RATIO=1 => keeps all)
# ==============================================================================
print("- fitting feature selector (RF)")

n_feats = X_full_final.shape[1]
k = int(np.ceil(FS_KEEP_RATIO * n_feats))
k = max(1, min(k, n_feats))

rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
rf_fs.fit(X_full_final, y_full_log)

selector = SelectFromModel(
    estimator=rf_fs,
    threshold=-np.inf,
    max_features=k,
    prefit=True
)

selected_cols = X_full_final.columns[selector.get_support()]
X_full_sel = X_full_final[selected_cols]
print(f"- selected features: {len(selected_cols)}/{n_feats}")

# ==============================================================================
# 8) TRAIN FINAL HGB (LOG TARGET)
# ==============================================================================
print("- training final HGB")
hgb_final = HistGradientBoostingRegressor(random_state=RANDOM_STATE, **final_params)
hgb_final.fit(X_full_sel, y_full_log)
print("- model trained")

# ==============================================================================
# 9) TRANSFORM TEST (TRANSFORM-ONLY) + SAME AGE + SAME ENCODING + SAME FS
# ==============================================================================
print("- transforming test set")

X_test = transform_year_with_model_median(X_test, state=year_state)
X_test = transform_mileage_imputer(X_test, state=mileage_state)
X_test = transform_engine_size_imputer(X_test, state=engine_state)
X_test = transform_tax_custom_rules(X_test, "tax", "year", "fuelType", "engineSize")
X_test = transform_mpg_imputer(X_test, state=mpg_state)

X_test, _, _ = transform_ambiguous_brands(X_test, brand_state)
X_test, _, _ = transform_invalid_models(X_test, model_state)
X_test, _, _ = transform_transmission_resolver(X_test, transm_state)
X_test, _, _ = transform_fueltype_resolver(X_test, fuel_state)

# same FE: ONLY AGE
X_test = create_age_and_drop_year(X_test, year_col="year", base_year=2020)

# encoding transform-only
X_test_high = te.transform(X_test[high_card_features])
X_test_low  = ohe.transform(X_test[low_card_curr])
X_test_cat  = pd.concat([X_test_high, X_test_low], axis=1)

drop_for_numeric = set(high_card_features + low_card_curr)
numeric_features_curr_test = [c for c in X_test.columns if c not in drop_for_numeric]

X_test_final = pd.concat([X_test[numeric_features_curr_test], X_test_cat], axis=1)

# align to train columns before selecting
X_test_final = X_test_final.reindex(columns=X_full_final.columns, fill_value=0)

# apply same selected columns
X_test_sel = X_test_final.reindex(columns=selected_cols, fill_value=0)

print(f"- test matrix shape: {X_test_sel.shape}")

# ==============================================================================
# 10) PREDICT + SUBMISSION (invert log1p)
# ==============================================================================
pred_log = hgb_final.predict(X_test_sel)
pred_final = np.expm1(pred_log)
pred_final = np.maximum(pred_final, 0)

submission = pd.DataFrame({
    (ID_COL if ID_COL is not None else "id"): test_ids,
    "price": pred_final
})

submission_filename = "submission_hgb_log_target__3_attempt.csv"
submission.to_csv(submission_filename, index=False)

print(f"- saved: {submission_filename}")
print(submission.head())
# Out:
# - using params: {'min_samples_leaf': 16, 'max_leaf_nodes': 191, 'max_iter': 1200, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}
# - FS_KEEP_RATIO: 1
# - fitting transforms on full train
# - creating engineered features on full train
# - fitting encoders on full train
# - train matrix shape: (75973, 15)
# - fitting feature selector (RF)
# - selected features: 15/15
# - training final HGB
# - model trained
# - transforming test set
# - test matrix shape: (32567, 15)
# - saved: submission_hgb_log_target__3_attempt.csv
#     carID         price
# 0   89856   7130.742853
# 1  106581  22058.834011
# 2   80886  13851.540187
# 3  100174  16987.308813
# 4   81376  23209.124763

# %% [markdown]
# ### 4.3. Visual Evaluation and Key Takeaways

# %%
numeric_features = ["year", "mileage", "engineSize", "tax", "mpg"]



final_params = {
    "min_samples_leaf": 16,
    "max_leaf_nodes": 191,
    "max_iter": 1200,
    "max_depth": 20,
    "loss": "squared_error",
    "learning_rate": 0.07,
    "l2_regularization": 3.0,
}

# FS_KEEP_RATIO=1 => keeps all features (no real selection), but kept here to match your structure
FS_KEEP_RATIO = 1
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

print(f"- using params: {final_params}")
print(f"- FS_KEEP_RATIO: {FS_KEEP_RATIO}")

# ==============================================================================
# 1) LOAD TEST + IDS
# ==============================================================================
try:
    test_df_raw = pd.read_csv("test.csv")
except:
    test_df_raw = pd.read_csv("../../project_data/test.csv")

ID_CANDIDATES = ["id", "carID", "carId", "car_id"]
ID_COL = next((c for c in ID_CANDIDATES if c in test_df_raw.columns), None)

if ID_COL is not None:
    test_ids = test_df_raw[ID_COL].copy()
    test_df = test_df_raw.drop(columns=[ID_COL]).copy()
else:
    test_ids = test_df_raw.index.copy()
    test_df = test_df_raw.copy()

# ==============================================================================
# 2) START DATA (LOG TARGET)
# ==============================================================================
X_full = X.copy()
y_full = y.copy()
y_full_log = np.log1p(y_full)  # LOG TARGET (as requested)

cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]
high_card_features = ["Brand", "model"]
low_card_features = [c for c in categorical_features if c not in high_card_features]

# IMPORTANT: you are NOT using engine_bin anymore, so low_card_curr is just low_card_features
low_card_curr = low_card_features

# ==============================================================================
# 3) STRING NORMALIZATION (TRAIN + TEST)
# ==============================================================================
for col in cols_to_normalize:
    if col in X_full.columns:
        X_full[col] = fill_unknown(X_full[col])
        X_full = column_string_transformer(
            X_full, column=col, remove_middle_spaces=True, allow_extra_chars=""
        )
    if col in test_df.columns:
        test_df[col] = fill_unknown(test_df[col])
        test_df = column_string_transformer(
            test_df, column=col, remove_middle_spaces=True, allow_extra_chars=""
        )

# Restrict to expected columns (train schema)
expected_cols = [c for c in (numeric_features + categorical_features) if c in X_full.columns]
X_full = X_full[expected_cols].copy()
X_test = test_df.reindex(columns=expected_cols, fill_value=np.nan).copy()

# ==============================================================================
# 4) FIT + TRANSFORM ON FULL TRAIN
# ==============================================================================
print("- fitting transforms on full train")

year_state = fit_year_median(X_full, year_col="year", model_col="model")
X_full = transform_year_with_model_median(X_full, state=year_state)

mileage_state = fit_mileage_imputer(X_full, mileage_col="mileage", do_abs=True)
X_full = transform_mileage_imputer(X_full, state=mileage_state)

engine_state = fit_engine_size_imputer(X_full, engine_col="engineSize")
X_full = transform_engine_size_imputer(X_full, state=engine_state)

X_full = transform_tax_custom_rules(X_full, "tax", "year", "fuelType", "engineSize")

mpg_state = fit_mpg_imputer(X_full, mpg_col="mpg", do_abs=True)
X_full = transform_mpg_imputer(X_full, state=mpg_state)

brand_state = fit_ambiguous_brand_resolver(X_full, valid_brands)
X_full, _, _ = transform_ambiguous_brands(X_full, brand_state)

model_state = fit_invalid_model_resolver(X_full, valid_models_by_brand)
X_full, _, _ = transform_invalid_models(X_full, model_state)

transm_state = fit_transmission_resolver(X_full, valid_transmissions)
X_full, _, _ = transform_transmission_resolver(X_full, transm_state)

fuel_state = fit_fueltype_resolver(X_full, valid_fueltypes)
X_full, _, _ = transform_fueltype_resolver(X_full, fuel_state)

# ==============================================================================
# 5) FEATURE ENGINEERING: ONLY AGE (drop year)
# ==============================================================================
print("- creating engineered features on full train")
X_full = create_age_and_drop_year(X_full, year_col="year", base_year=2020)

# ==============================================================================
# 6) ENCODING (FIT ON FULL TRAIN) using LOG TARGET
# ==============================================================================
print("- fitting encoders on full train")

te = MyTargetEncoder(smoothing=5)
te.fit(X_full[high_card_features], y_full_log)
X_full_high = te.transform(X_full[high_card_features])

ohe = MyOneHotEncoder()
ohe.fit(X_full[low_card_curr])
X_full_low = ohe.transform(X_full[low_card_curr])

X_full_cat = pd.concat([X_full_high, X_full_low], axis=1)

drop_for_numeric = set(high_card_features + low_card_curr)
numeric_features_curr = [c for c in X_full.columns if c not in drop_for_numeric]

X_full_final = pd.concat([X_full[numeric_features_curr], X_full_cat], axis=1)
print(f"- train matrix shape: {X_full_final.shape}")

# ==============================================================================
# 7) FEATURE SELECTION (kept but FS_KEEP_RATIO=1 => keeps all)
# ==============================================================================
print("- fitting feature selector (RF)")

n_feats = X_full_final.shape[1]
k = int(np.ceil(FS_KEEP_RATIO * n_feats))
k = max(1, min(k, n_feats))

rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
rf_fs.fit(X_full_final, y_full_log)

selector = SelectFromModel(
    estimator=rf_fs,
    threshold=-np.inf,
    max_features=k,
    prefit=True
)

selected_cols = X_full_final.columns[selector.get_support()]
X_full_sel = X_full_final[selected_cols]
print(f"- selected features: {len(selected_cols)}/{n_feats}")

# ==============================================================================
# 7.1) RF-BASED FEATURE IMPORTANCE / SPLIT FREQUENCY (applies to rf_fs, not HGB)
# ==============================================================================

RF_NAME = "RF (Feature Selector) — Diagnostics"

# Feature importances from the RF used in SelectFromModel
try:
    plot_feature_importance_fs(rf_fs, RF_NAME, top=20)
except Exception as e:
    print(f"Skipping plot_feature_importance_fs for {RF_NAME}: {e}")

# Split frequency across RF trees (how often each feature is used in splits)
try:
    split_freq_df = compute_split_frequency_fs(rf_fs)
    display(split_freq_df.head(25))
except Exception as e:
    print(f"Skipping compute_split_frequency_fs for {RF_NAME}: {e}")

# ==============================================================================
# 8) TRAIN FINAL HGB (LOG TARGET)
# ==============================================================================
print("- training final HGB")
hgb_final = HistGradientBoostingRegressor(random_state=RANDOM_STATE, **final_params)
hgb_final.fit(X_full_sel, y_full_log)
print("- model trained")

# ==============================================================================
# 8.1) VISUAL DIAGNOSTICS (ON FULL TRAIN)  <-- paste here, after "- model trained"
# ==============================================================================

# Your model predicts log1p(price), so use the *_fs helpers (they expm1 back to price)
MODEL_NAME = "HGB (log1p target) — Final Config"

# Predicted vs True 
plot_pred_vs_true_fs(hgb_final, MODEL_NAME)

# Residuals vs Predicted 
plot_residuals_fs(hgb_final, MODEL_NAME)

# Residual distribution
plot_residual_distribution_fs(hgb_final, MODEL_NAME)

# Permutation importance (must be computed in log-space to match model outputs)
plot_permutation_importance_fs(
    hgb_final,
    MODEL_NAME,
    n_repeats=5,   # reduce to 3 if it's too slow
    top=20
)

RUN_SHAP = True
if RUN_SHAP:
    try:
        import shap
        apply_shap_fs(hgb_final, X_full_sel, model_name=MODEL_NAME, sample_size=2000)
    except Exception as e:
        print(f"Skipping SHAP due to: {e}")

# ==============================================================================
# 9) TRANSFORM TEST (TRANSFORM-ONLY) + SAME AGE + SAME ENCODING + SAME FS
# ==============================================================================
print("- transforming test set")

X_test = transform_year_with_model_median(X_test, state=year_state)
X_test = transform_mileage_imputer(X_test, state=mileage_state)
X_test = transform_engine_size_imputer(X_test, state=engine_state)
X_test = transform_tax_custom_rules(X_test, "tax", "year", "fuelType", "engineSize")
X_test = transform_mpg_imputer(X_test, state=mpg_state)

X_test, _, _ = transform_ambiguous_brands(X_test, brand_state)
X_test, _, _ = transform_invalid_models(X_test, model_state)
X_test, _, _ = transform_transmission_resolver(X_test, transm_state)
X_test, _, _ = transform_fueltype_resolver(X_test, fuel_state)

# same FE: ONLY AGE
X_test = create_age_and_drop_year(X_test, year_col="year", base_year=2020)

# encoding transform-only
X_test_high = te.transform(X_test[high_card_features])
X_test_low  = ohe.transform(X_test[low_card_curr])
X_test_cat  = pd.concat([X_test_high, X_test_low], axis=1)

drop_for_numeric = set(high_card_features + low_card_curr)
numeric_features_curr_test = [c for c in X_test.columns if c not in drop_for_numeric]

X_test_final = pd.concat([X_test[numeric_features_curr_test], X_test_cat], axis=1)

# align to train columns before selecting
X_test_final = X_test_final.reindex(columns=X_full_final.columns, fill_value=0)

# apply same selected columns
X_test_sel = X_test_final.reindex(columns=selected_cols, fill_value=0)

print(f"- test matrix shape: {X_test_sel.shape}")

# ==============================================================================
# 10) PREDICT + SUBMISSION (invert log1p)
# ==============================================================================
pred_log = hgb_final.predict(X_test_sel)
pred_final = np.expm1(pred_log)
pred_final = np.maximum(pred_final, 0)

submission = pd.DataFrame({
    (ID_COL if ID_COL is not None else "id"): test_ids,
    "price": pred_final
})

submission_filename = "submission_hgb_log_target_finalsubmission__.csv"
submission.to_csv(submission_filename, index=False)

print(f"- saved: {submission_filename}")
print(submission.head())
# Out:
# - using params: {'min_samples_leaf': 16, 'max_leaf_nodes': 191, 'max_iter': 1200, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}
# - FS_KEEP_RATIO: 1
# - fitting transforms on full train
# - creating engineered features on full train
# - fitting encoders on full train
# - train matrix shape: (75973, 15)
# - fitting feature selector (RF)
# - selected features: 15/15
# /var/folders/bd/t15rp69d53n0dgbv492qs36h0000gn/T/ipykernel_99412/1042059889.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="importance", y="feature", data=imp_df, palette="viridis")
#                    feature  split_count
# 7                  mileage      2749709
# 6                      mpg      1022040
# 0                    model       676177
# 3                      tax       523950
# 2                      age       456328
# 5                    Brand       372439
# 1               engineSize       338462
# 8   transmission_AUTOMATIC        68797
# 9    transmission_SEMIAUTO        64717
# 12         fuelType_DIESEL        53862
# 4          fuelType_PETROL        52946
# 10     transmission_MANUAL        29226
# 13         fuelType_HYBRID        12635
# 11          fuelType_OTHER         3245
# 14       fuelType_ELECTRIC           55
# - training final HGB
# - model trained
# /var/folders/bd/t15rp69d53n0dgbv492qs36h0000gn/T/ipykernel_99412/4128551160.py:50: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="importance", y="feature", data=imp_df, palette="magma")
# - transforming test set
# - test matrix shape: (32567, 15)
# - saved: submission_hgb_log_target_finalsubmission__.csv
#     carID         price
# 0   89856   7130.742853
# 1  106581  22058.834011
# 2   80886  13851.540187
# 3  100174  16987.308813
# 4   81376  23209.124763
# Exception ignored in: <function ResourceTracker.__del__ at 0x104f2de40>
# Traceback (most recent call last):
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x102839e40>
# Traceback (most recent call last):
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x103475e40>
# Traceback (most recent call last):
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x1064ede40>
# Traceback (most recent call last):
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x104eede40>
# Traceback (most recent call last):
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x1069a1e40>
# Traceback (most recent call last):
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x107105e40>
# Traceback (most recent call last):
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x1023cde40>
# Traceback (most recent call last):
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes

# %%
numeric_features = ["year", "mileage", "engineSize", "tax", "mpg"]



final_params = {
    "min_samples_leaf": 16,
    "max_leaf_nodes": 191,
    "max_iter": 1200,
    "max_depth": 20,
    "loss": "squared_error",
    "learning_rate": 0.07,
    "l2_regularization": 3.0,
}

# FS_KEEP_RATIO=1 => keeps all features (no real selection), but kept here to match your structure
FS_KEEP_RATIO = 1
RF_FS_PARAMS = {
    "n_estimators": 500,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf": 2,
    "max_features": "sqrt",
    "bootstrap": True,
}

print(f"- using params: {final_params}")
print(f"- FS_KEEP_RATIO: {FS_KEEP_RATIO}")

# ==============================================================================
# 1) LOAD TEST + IDS
# ==============================================================================
try:
    test_df_raw = pd.read_csv("test.csv")
except:
    test_df_raw = pd.read_csv("../../project_data/test.csv")

ID_CANDIDATES = ["id", "carID", "carId", "car_id"]
ID_COL = next((c for c in ID_CANDIDATES if c in test_df_raw.columns), None)

if ID_COL is not None:
    test_ids = test_df_raw[ID_COL].copy()
    test_df = test_df_raw.drop(columns=[ID_COL]).copy()
else:
    test_ids = test_df_raw.index.copy()
    test_df = test_df_raw.copy()

# ==============================================================================
# 2) START DATA (LOG TARGET)
# ==============================================================================
X_full = X.copy()
y_full = y.copy()
y_full_log = np.log1p(y_full)  # LOG TARGET (as requested)

cols_to_normalize = ["Brand", "model", "transmission", "fuelType"]
high_card_features = ["Brand", "model"]
low_card_features = [c for c in categorical_features if c not in high_card_features]

# IMPORTANT: you are NOT using engine_bin anymore, so low_card_curr is just low_card_features
low_card_curr = low_card_features

# ==============================================================================
# 3) STRING NORMALIZATION (TRAIN + TEST)
# ==============================================================================
for col in cols_to_normalize:
    if col in X_full.columns:
        X_full[col] = fill_unknown(X_full[col])
        X_full = column_string_transformer(
            X_full, column=col, remove_middle_spaces=True, allow_extra_chars=""
        )
    if col in test_df.columns:
        test_df[col] = fill_unknown(test_df[col])
        test_df = column_string_transformer(
            test_df, column=col, remove_middle_spaces=True, allow_extra_chars=""
        )

# Restrict to expected columns (train schema)
expected_cols = [c for c in (numeric_features + categorical_features) if c in X_full.columns]
X_full = X_full[expected_cols].copy()
X_test = test_df.reindex(columns=expected_cols, fill_value=np.nan).copy()

# ==============================================================================
# 4) FIT + TRANSFORM ON FULL TRAIN
# ==============================================================================
print("- fitting transforms on full train")

year_state = fit_year_median(X_full, year_col="year", model_col="model")
X_full = transform_year_with_model_median(X_full, state=year_state)

mileage_state = fit_mileage_imputer(X_full, mileage_col="mileage", do_abs=True)
X_full = transform_mileage_imputer(X_full, state=mileage_state)

engine_state = fit_engine_size_imputer(X_full, engine_col="engineSize")
X_full = transform_engine_size_imputer(X_full, state=engine_state)

X_full = transform_tax_custom_rules(X_full, "tax", "year", "fuelType", "engineSize")

mpg_state = fit_mpg_imputer(X_full, mpg_col="mpg", do_abs=True)
X_full = transform_mpg_imputer(X_full, state=mpg_state)

brand_state = fit_ambiguous_brand_resolver(X_full, valid_brands)
X_full, _, _ = transform_ambiguous_brands(X_full, brand_state)

model_state = fit_invalid_model_resolver(X_full, valid_models_by_brand)
X_full, _, _ = transform_invalid_models(X_full, model_state)

transm_state = fit_transmission_resolver(X_full, valid_transmissions)
X_full, _, _ = transform_transmission_resolver(X_full, transm_state)

fuel_state = fit_fueltype_resolver(X_full, valid_fueltypes)
X_full, _, _ = transform_fueltype_resolver(X_full, fuel_state)

# ==============================================================================
# 5) FEATURE ENGINEERING: ONLY AGE (drop year)
# ==============================================================================
print("- creating engineered features on full train")
X_full = create_age_and_drop_year(X_full, year_col="year", base_year=2020)

# ==============================================================================
# 6) ENCODING (FIT ON FULL TRAIN) using LOG TARGET
# ==============================================================================
print("- fitting encoders on full train")

te = MyTargetEncoder(smoothing=5)
te.fit(X_full[high_card_features], y_full_log)
X_full_high = te.transform(X_full[high_card_features])

ohe = MyOneHotEncoder()
ohe.fit(X_full[low_card_curr])
X_full_low = ohe.transform(X_full[low_card_curr])

X_full_cat = pd.concat([X_full_high, X_full_low], axis=1)

drop_for_numeric = set(high_card_features + low_card_curr)
numeric_features_curr = [c for c in X_full.columns if c not in drop_for_numeric]

X_full_final = pd.concat([X_full[numeric_features_curr], X_full_cat], axis=1)
print(f"- train matrix shape: {X_full_final.shape}")

# ==============================================================================
# 7) FEATURE SELECTION (kept but FS_KEEP_RATIO=1 => keeps all)
# ==============================================================================
print("- fitting feature selector (RF)")

n_feats = X_full_final.shape[1]
k = int(np.ceil(FS_KEEP_RATIO * n_feats))
k = max(1, min(k, n_feats))

rf_fs = RandomForestRegressor(**RF_FS_PARAMS)
rf_fs.fit(X_full_final, y_full_log)

selector = SelectFromModel(
    estimator=rf_fs,
    threshold=-np.inf,
    max_features=k,
    prefit=True
)

selected_cols = X_full_final.columns[selector.get_support()]
X_full_sel = X_full_final[selected_cols]
print(f"- selected features: {len(selected_cols)}/{n_feats}")

# ==============================================================================
# 7.1) RF-BASED FEATURE IMPORTANCE / SPLIT FREQUENCY (applies to rf_fs, not HGB)
# ==============================================================================

RF_NAME = "RF (Feature Selector) — Diagnostics"

# Feature importances from the RF used in SelectFromModel
try:
    plot_feature_importance_fs(rf_fs, RF_NAME, top=20)
except Exception as e:
    print(f"Skipping plot_feature_importance_fs for {RF_NAME}: {e}")

# Split frequency across RF trees (how often each feature is used in splits)
try:
    split_freq_df = compute_split_frequency_fs(rf_fs)
    display(split_freq_df.head(25))
except Exception as e:
    print(f"Skipping compute_split_frequency_fs for {RF_NAME}: {e}")

# ==============================================================================
# 8) TRAIN FINAL HGB (LOG TARGET)
# ==============================================================================
print("- training final HGB")
hgb_final = HistGradientBoostingRegressor(random_state=RANDOM_STATE, **final_params)
hgb_final.fit(X_full_sel, y_full_log)
print("- model trained")

# ==============================================================================
# 8.1) VISUAL DIAGNOSTICS (ON FULL TRAIN)  <-- paste here, after "- model trained"
# ==============================================================================

# Your model predicts log1p(price), so use the *_fs helpers (they expm1 back to price)
MODEL_NAME = "HGB (log1p target) — Final Config"

# Predicted vs True 
plot_pred_vs_true_fs(hgb_final, MODEL_NAME)

# Residuals vs Predicted 
plot_residuals_fs(hgb_final, MODEL_NAME)

# Residual distribution
plot_residual_distribution_fs(hgb_final, MODEL_NAME)

# Permutation importance (must be computed in log-space to match model outputs)
plot_permutation_importance_fs(
    hgb_final,
    MODEL_NAME,
    n_repeats=5,   # reduce to 3 if it's too slow
    top=20
)

RUN_SHAP = True
if RUN_SHAP:
    try:
        import shap
        apply_shap_fs(hgb_final, X_full_sel, model_name=MODEL_NAME, sample_size=2000)
    except Exception as e:
        print(f"Skipping SHAP due to: {e}")

# ==============================================================================
# 9) TRANSFORM TEST (TRANSFORM-ONLY) + SAME AGE + SAME ENCODING + SAME FS
# ==============================================================================
print("- transforming test set")

X_test = transform_year_with_model_median(X_test, state=year_state)
X_test = transform_mileage_imputer(X_test, state=mileage_state)
X_test = transform_engine_size_imputer(X_test, state=engine_state)
X_test = transform_tax_custom_rules(X_test, "tax", "year", "fuelType", "engineSize")
X_test = transform_mpg_imputer(X_test, state=mpg_state)

X_test, _, _ = transform_ambiguous_brands(X_test, brand_state)
X_test, _, _ = transform_invalid_models(X_test, model_state)
X_test, _, _ = transform_transmission_resolver(X_test, transm_state)
X_test, _, _ = transform_fueltype_resolver(X_test, fuel_state)

# same FE: ONLY AGE
X_test = create_age_and_drop_year(X_test, year_col="year", base_year=2020)

# encoding transform-only
X_test_high = te.transform(X_test[high_card_features])
X_test_low  = ohe.transform(X_test[low_card_curr])
X_test_cat  = pd.concat([X_test_high, X_test_low], axis=1)

drop_for_numeric = set(high_card_features + low_card_curr)
numeric_features_curr_test = [c for c in X_test.columns if c not in drop_for_numeric]

X_test_final = pd.concat([X_test[numeric_features_curr_test], X_test_cat], axis=1)

# align to train columns before selecting
X_test_final = X_test_final.reindex(columns=X_full_final.columns, fill_value=0)

# apply same selected columns
X_test_sel = X_test_final.reindex(columns=selected_cols, fill_value=0)

print(f"- test matrix shape: {X_test_sel.shape}")

# ==============================================================================
# 10) PREDICT + SUBMISSION (invert log1p)
# ==============================================================================
pred_log = hgb_final.predict(X_test_sel)
pred_final = np.expm1(pred_log)
pred_final = np.maximum(pred_final, 0)

submission = pd.DataFrame({
    (ID_COL if ID_COL is not None else "id"): test_ids,
    "price": pred_final
})

submission_filename = "submission_hgb_log_target_finalsubmission__.csv"
submission.to_csv(submission_filename, index=False)

print(f"- saved: {submission_filename}")
print(submission.head())
# Out:
# - using params: {'min_samples_leaf': 16, 'max_leaf_nodes': 191, 'max_iter': 1200, 'max_depth': 20, 'loss': 'squared_error', 'learning_rate': 0.07, 'l2_regularization': 3.0}
# - FS_KEEP_RATIO: 1
# - fitting transforms on full train
# - creating engineered features on full train
# - fitting encoders on full train
# - train matrix shape: (75973, 15)
# - fitting feature selector (RF)
# - selected features: 15/15
# /var/folders/bd/t15rp69d53n0dgbv492qs36h0000gn/T/ipykernel_99412/1042059889.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="importance", y="feature", data=imp_df, palette="viridis")
#                    feature  split_count
# 7                  mileage      2749709
# 6                      mpg      1022040
# 0                    model       676177
# 3                      tax       523950
# 2                      age       456328
# 5                    Brand       372439
# 1               engineSize       338462
# 8   transmission_AUTOMATIC        68797
# 9    transmission_SEMIAUTO        64717
# 12         fuelType_DIESEL        53862
# 4          fuelType_PETROL        52946
# 10     transmission_MANUAL        29226
# 13         fuelType_HYBRID        12635
# 11          fuelType_OTHER         3245
# 14       fuelType_ELECTRIC           55
# - training final HGB
# - model trained
# /var/folders/bd/t15rp69d53n0dgbv492qs36h0000gn/T/ipykernel_99412/4128551160.py:50: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="importance", y="feature", data=imp_df, palette="magma")
#   0%|          | 0/2000 [00:00<?, ?it/s]
# Exception ignored in: <function ResourceTracker.__del__ at 0x102d79e40>
# Traceback (most recent call last):
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x102151e40>
# Traceback (most recent call last):
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x107029e40>
# Traceback (most recent call last):
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x1057f9e40>
# Traceback (most recent call last):
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x1054ede40>
# Traceback (most recent call last):
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x1059f9e40>
# Traceback (most recent call last):
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x106d75e40>
# Traceback (most recent call last):
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x104bb5e40>
# Traceback (most recent call last):
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/Users/franciscafernandes/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 219
#     217 try:
#     218     import shap
# --> 219     apply_shap_fs(hgb_final, X_full_sel, model_name=MODEL_NAME, sample_size=2000)
#     220 except Exception as e:
#     221     print(f"Skipping SHAP due to: {e}")
#
# File /var/folders/bd/t15rp69d53n0dgbv492qs36h0000gn/T/ipykernel_99412/2697768544.py:68, in apply_shap_fs(model, X, model_name, sample_size)
#      66     background = X.sample(min(200, len(X)), random_state=42)
#      67     explainer = shap.KernelExplainer(model.predict, background)
# ---> 68     shap_values = explainer.shap_values(X_sample)
#      70 # ---- 3. SHAP PLOTS ----
#      71 print(f"\nSHAP for {model_name} (sample size = {len(X_sample)})")
#
# File ~/anaconda3/lib/python3.13/site-packages/shap/explainers/_kernel.py:275, in KernelExplainer.shap_values(self, X, **kwargs)
#     273 if self.keep_index:
#     274     data = convert_to_instance_with_index(data, column_name, index_value[i : i + 1], index_name)
# --> 275 explanations.append(self.explain(data, **kwargs))
#     276 if kwargs.get("gc_collect", False):
#     277     gc.collect()
#
# File ~/anaconda3/lib/python3.13/site-packages/shap/explainers/_kernel.py:479, in KernelExplainer.explain(self, incoming_instance, **kwargs)
#     476     self.kernelWeights[nfixed_samples:] *= weight_left / self.kernelWeights[nfixed_samples:].sum()
#     478 # execute the model on the synthetic samples we have created
# --> 479 self.run()
#     481 # solve then expand the feature importance (Shapley value) vector to contain the non-varying features
#     482 phi = np.zeros((self.data.groups_size, self.D))
#
# File ~/anaconda3/lib/python3.13/site-packages/shap/explainers/_kernel.py:624, in KernelExplainer.run(self)
#     622     if self.keep_index_ordered:
#     623         data = data.sort_index()
# --> 624 modelOut = self.model.f(data)
#     625 if isinstance(modelOut, (pd.DataFrame, pd.Series)):
#     626     modelOut = modelOut.values
#
# File ~/anaconda3/lib/python3.13/site-packages/sklearn/ensemble/_hist_gradient_boosting/gradient_boosting.py:1751, in HistGradientBoostingRegressor.predict(self, X)
#    1748 check_is_fitted(self)
#    1749 # Return inverse link of raw predictions after converting
#    1750 # shape (n_samples, 1) to (n_samples,)
# -> 1751 return self._loss.link.inverse(self._raw_predict(X).ravel())
#
# File ~/anaconda3/lib/python3.13/site-packages/sklearn/ensemble/_hist_gradient_boosting/gradient_boosting.py:1269, in BaseHistGradientBoosting._raw_predict(self, X, n_threads)
#    1265 # We intentionally decouple the number of threads used at prediction
#    1266 # time from the number of threads used at fit time because the model
#    1267 # can be deployed on a different machine for prediction purposes.
#    1268 n_threads = _openmp_effective_n_threads(n_threads)
# -> 1269 self._predict_iterations(
#    1270     X, self._predictors, raw_predictions, is_binned, n_threads
#    1271 )
#    1272 return raw_predictions
#
# File ~/anaconda3/lib/python3.13/site-packages/sklearn/ensemble/_hist_gradient_boosting/gradient_boosting.py:1297, in BaseHistGradientBoosting._predict_iterations(self, X, predictors, raw_predictions, is_binned, n_threads)
#    1290 else:
#    1291     predict = partial(
#    1292         predictor.predict,
#    1293         known_cat_bitsets=known_cat_bitsets,
#    1294         f_idx_map=f_idx_map,
#    1295         n_threads=n_threads,
#    1296     )
# -> 1297 raw_predictions[:, k] += predict(X)
#
# File ~/anaconda3/lib/python3.13/site-packages/sklearn/ensemble/_hist_gradient_boosting/predictor.py:71, in TreePredictor.predict(self, X, known_cat_bitsets, f_idx_map, n_threads)
#      47 """Predict raw values for non-binned data.
#      48
#      49 Parameters
#    (...)
#      67     The raw predicted values.
#      68 """
#      69 out = np.empty(X.shape[0], dtype=Y_DTYPE)
# ---> 71 _predict_from_raw_data(
#      72     self.nodes,
#      73     X,
#      74     self.raw_left_cat_bitsets,
#      75     known_cat_bitsets,
#      76     f_idx_map,
#      77     n_threads,
#      78     out,
#      79 )
#      80 return out
#
# KeyboardInterrupt:

# %%
apply_shap_fs(hgb_final, X_full_sel, model_name=MODEL_NAME, sample_size=2000)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# SHAP for HGB (log1p target) — Final Config (sample size = 2000)
# /var/folders/bd/t15rp69d53n0dgbv492qs36h0000gn/T/ipykernel_99412/2697768544.py:73: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values, X_sample, plot_type="bar", show=True)
# /var/folders/bd/t15rp69d53n0dgbv492qs36h0000gn/T/ipykernel_99412/2697768544.py:74: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values, X_sample, show=True)

# %% [markdown]
# ## 5. Conclusions
